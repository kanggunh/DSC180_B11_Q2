# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_json('data/finetuned_llama_output.json')
data = df.T.sort_index()

# %% [markdown]
# It seems like the pin_structure was not successfully extracted so we will be dropping this column entirely. Control PCE and Control

# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem

# Function to clean and standardize data
def clean_data(df):
    # Convert PCE and VOC to numeric
    for col in ['control_pce', 'control_voc', 'treated_pce', 'treated_voc']:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    # Drop rows where treated_pce or passivating_molecule is missing
    df = df.dropna(subset=['treated_pce', 'passivating_molecule', 'perovskite_composition'])

    return df

data = clean_data(data)


data.to_csv("cleaned_data.csv", index=False)

# %%
data.isna().sum(axis=0)
# Out:
# control_pce                  59
# control_voc                  73
# treated_pce                   0
# treated_voc                  10
# passivating_molecule          0
# perovskite_composition        0
# electron_transport_layer     19
# hole_transport_layer         20
# pin_nip_structure             0
# stability_tests               0
# pin_structure               107
# dtype: int64

# %%
list(data['passivating_molecule'])
# Out:
# ['4-chlorobenzenesulfonate (4Cl-BZS)',
#  'BA2MA2Pb3I10',
#  'vinylbenzylammonium bromide (VBABr)',
#  'iso-BAI',
#  'phenylethylammonium',
#  '2-(pyren-1-yl)ethan-1-amine',
#  'Tosylate ([TsO] -)',
#  'Benzotriazole',
#  'n-butylammonium bromide (BABr)',
#  '2-(9H-carbazol-9-yl)ethyl] phosphonic acid (2PACz)',
#  '2-phenylethylammonium iodide (PEAI), 4-chlorophenylethylammonium iodide (Cl-PEAI), and 4-fluorophenylethylammonium iodide (F-PEAI)',
#  'phenylethylammonium (PEAI) and 4-fluoro-phenylethylammonium iodide (F-PEAI)',
#  'CF3 PEAI',
#  'hexyltrimethylammonium bromide',
#  '2-thiophenemethylammonium iodide (TMAI) and phenylethylammonium iodide (PEAI)',
#  '3,4,5-trifluoroanilinium (345FAn)',
#  'n-octylammonium bromide (C8 Br)',
#  'Cyclohexylmethylammonium iodide (CMAI)',
#  '3-fluoro-phenethylammonium (3F-PEA)',
#  'Cs2PbI2Cl2',
#  'CF3-PEA',
#  'ammonia',
#  '3-(aminomethyl)pyridine (3-APy)',
#  'CH3NH3+',
#  'Benzene',
#  'C60',
#  '1,3-propylene diammonium (PDA)',
# ...

# %%
list(cleaned_data['passivating_molecule'].apply(lambda x: x.split(' ')))
# Out:
# [['4-chlorobenzenesulfonate', '(4Cl-BZS)'],
#  ['BA2MA2Pb3I10'],
#  ['vinylbenzylammonium', 'bromide', '(VBABr)'],
#  ['iso-BAI'],
#  ['phenylethylammonium'],
#  ['2-(pyren-1-yl)ethan-1-amine'],
#  ['Tosylate', '([TsO]', '-)'],
#  ['Benzotriazole'],
#  ['n-butylammonium', 'bromide', '(BABr)'],
#  ['2-(9H-carbazol-9-yl)ethyl]', 'phosphonic', 'acid', '(2PACz)'],
#  ['2-phenylethylammonium',
#   'iodide',
#   '(PEAI),',
#   '4-chlorophenylethylammonium',
#   'iodide',
#   '(Cl-PEAI),',
#   'and',
#   '4-fluorophenylethylammonium',
#   'iodide',
#   '(F-PEAI)'],
#  ['phenylethylammonium',
#   '(PEAI)',
#   'and',
#   '4-fluoro-phenylethylammonium',
#   'iodide',
#   '(F-PEAI)'],
#  ['CF3', 'PEAI'],
#  ['hexyltrimethylammonium', 'bromide'],
#  ['2-thiophenemethylammonium',
#   'iodide',
#   '(TMAI)',
#   'and',
#   'phenylethylammonium',
#   'iodide',
#   '(PEAI)'],
#  ['3,4,5-trifluoroanilinium', '(345FAn)'],
#  ['n-octylammonium', 'bromide', '(C8', 'Br)'],
# ...

# %%
list(cleaned_data['perovskite_composition'])#.apply(lambda x: x.split(' ')))
# Out:
# ['α-phase FAPbI3',
#  'BA2MA2Pb3I10',
#  '(FAPbI3)0.95(MAPbBr3)0.05',
#  'FA(MA)PbI3',
#  'PEA2(CH3NH3)n-1Pb(nI3n+1)',
#  'CsPbI2Br',
#  '(FAPbI3) 0.95 (MAPbBr3) 0.05',
#  'FAPbI3',
#  'Cs0.17 FA0.83 Pb(I0.6 Br0.4 ) 3',
#  'Cs0.12 FA0.8 MA0.08 PbI1.8 Br1.2',
#  'Cs 0.05 (FA 0.9 MA 0.1 ) 0.95 Pb(I 0.85 Br 0.15 ) 3',
#  'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.9 Br 0.1 ) 3',
#  'FAPbI3',
#  'Cs0.05 FA0.81 MA0.14 PbI2.55 Br0.45',
#  '[(FAPbI3)0.87(MAPbBr3)0.13]0.92(CsPbI3)0.08',
#  'Cs0.05MA0.05FA0.9Pb(I0.95Br0.05)3',
#  '(FAPbI3)0.92(MAPbBr3)0.08',
#  'α-formamidinium lead triiodide (FAPbI3)',
#  'Cs0.05MA0.1FA0.85PbI3',
#  'CsPbI3',
#  'CsPbI3-xBrx',
#  'α-FAPbI3',
#  'Rb0.05Cs0.05MA0.05FA0.85Pb(I0.95Br0.05)3',
#  'CH3NH3PbI3',
#  'FAPbI3',
#  'Cs0.05(FA0.83MA0.17)0.95Pb(I0.83Br0.17)3',
#  'Cs0.2FA0.8Pb(I0.6Br0.4)3',
#  '[FAPbI3]0.87[MABr3]0.13[CspI3]0.08',
#  'Cs0.03(FA0.90MA0.10)0.97PbI3',
#  'PbI2 :PbBr2 :FAI:MAI:CsI:MACl = 0.98:0.02:0.81:0.04:0.05:0.20',
#  'FAPbI3',
# ...

# %%
pcp.get_compounds("vinylbenzylammonium bromide", 'name')
# Out:
# []

# %%
import pubchempy as pcp

# Function to fetch SMILES from PubChem
def fetch_smiles_from_name(molecule_name):
    try:
        # Search for the molecule in PubChem by name
        compounds = pcp.get_compounds(molecule_name, 'name')
        if compounds:
            return compounds[0].isomeric_smiles  # Return the first match's SMILES
        else:
            print(f"No SMILES found for {molecule_name}")
            return None
    except Exception as e:
        print(f"Error fetching SMILES for {molecule_name}: {e}")
        return None

# Example list of molecules
molecules = ["isopropylammonium chloride", "c60", "Tosylate", "phenylethylammonium", "4-chlorobenzenesulfonate", "Benzene", "C6H6", "cyclohexane", "4-trifluoromethyl-phenylammonium"]
# molecules = ["Benzene", "C6H6", "cyclohexane"]
# molecules = ["4-fluoroaniline", "phenylethylammonium"]


# Convert each molecule name to SMILES
for molecule in molecules:
    smiles = fetch_smiles_from_name(molecule)
    print(f"Molecule: {molecule}, SMILES: {smiles}")
# Out:
# Molecule: isopropylammonium chloride, SMILES: CC(C)[NH3+].[Cl-]
# Molecule: c60, SMILES: C12=C3C4=C5C6=C1C7=C8C9=C1C%10=C%11C(=C29)C3=C2C3=C4C4=C5C5=C9C6=C7C6=C7C8=C1C1=C8C%10=C%10C%11=C2C2=C3C3=C4C4=C5C5=C%11C%12=C(C6=C95)C7=C1C1=C%12C5=C%11C4=C3C3=C5C(=C81)C%10=C23
# Molecule: Tosylate, SMILES: CC1=CC=C(C=C1)S(=O)(=O)[O-]
# Molecule: 4-chlorobenzenesulfonate, SMILES: C1=CC(=CC=C1S(=O)(=O)[O-])Cl
# Molecule: Benzene, SMILES: C1=CC=CC=C1
# Molecule: C6H6, SMILES: C1=CC=CC=C1
# Molecule: cyclohexane, SMILES: C1CCCCC1
# No SMILES found for 4-trifluoromethyl-phenylammonium
# Molecule: 4-trifluoromethyl-phenylammonium, SMILES: None

# %%
import re

# Define hardcoded SMILES dictionary for multi-letter molecules
smiles_dict = {
    "FA": "NC(=NH)N",  # Formamidinium
    "MA": "C[NH3+]",   # Methylammonium
    "Cs": "[Cs]",      # Cesium
    "Rb": "[Rb]",      # Rubidium
    "BA": "CCCC[NH3+]",  # Butylammonium
    "PEA": "CC1=CC=CC=C1[NH3+]",  # Phenylethylammonium
}

def parse_perovskite_to_smiles(composition):
    # Regular expression: captures multi-letter molecules & single-letter elements with optional fractions
    pattern = r"([A-Z][a-z]*)(\s*[\d\.]+)?"
    matches = re.findall(pattern, composition)

    smiles_result = []

    for element, _ in matches:
        if element in smiles_dict:
            smiles_result.append(smiles_dict[element])  # Convert known molecules to SMILES
        else:
            smiles_result.append(element)  # Keep single-letter elements as-is (e.g., Pb, Sn, I)

    return " ".join(smiles_result)  # Join into final SMILES-like format

# Example compositions
composition_1 = "FA 0.7 MA 0.3 Pb 0.5 Sn 0.5 I 3"
composition_2 = "Cs0.05 FA0.85 MA0.10 Pb(I0.97 Br0.03)3"

# Convert compositions to SMILES
smiles_1 = parse_perovskite_to_smiles(composition_1)
smiles_2 = parse_perovskite_to_smiles(composition_2)

print("SMILES Representation 1:", smiles_1)
print("SMILES Representation 2:", smiles_2)
# Out:
# SMILES Representation 1: F A M A Pb Sn I
# SMILES Representation 2: [Cs] F A M A Pb I Br

# %%
import pandas as pd
from descriptastorus.descriptors.DescriptorGenerator import MakeGenerator
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
generator = MakeGenerator(("RDKit2D",))

# %%
generator
