# %% [markdown]
# ## This is the new schema for annotation.csv for evluation 2 and 3

# %%
import pandas as pd
import json

# %%
irrelevent_papers = [26,28,29,30,32,33,34,35,38,43,44,45,52,54,55,56,57,58,63,66,68,69,70,78,80,83,84,86,87,88,89,90,91,92,93,94,98,100,101,102,103,104,105,106,108,109,110,111,112,115,116,117,119,121,125,128,129,130,134,136,138,139, 140]
relevent_bad = [1, 18, 20, 25, 27, 41, 51, 61, 71, 76, 135, 141, 145]

relevent_good = [i for i in range(0, 150) if i not in irrelevent_papers and i not in relevent_bad]

# %%
# Open and load the JSON file
with open('annotations_flattened.json', 'r') as file:
    data = json.load(file)

df_info = []
key_none = []
# Iterate through the elements
for key, item in data.items():
    print(key, item)
    if item == None:
        df_info.append([key, item])
        key_none.append(int(key))
        
    else: 
        for passivating, dictionary in item.items():
            print(dictionary)
            df_info.append([key, dictionary])
# Out:
# 134 None
# 141 {'phenethylammonium Iodide': {'perovskite_composition': None, 'electron_transport_layer': 'boron chloride subphthalocyanine / fullerene bilayer', 'hole_transport_layer': None, 'structure_pin_nip': 'PIN', 'passivating_molecule': 'phenethylammonium Iodide', 'control_pce': '20.2', 'treated_pce': '22.0', 'control_voc': None, 'treated_voc': '1.16', 'test_1': {'stability_type': 'ISOSD', 'humidity': '85', 'temperature': '85', 'time': '816', 'efficiency_cont': '80', 'efficiency_tret': '80'}, 'test_2': {'stability_type': 'ISOSO1', 'humidity': None, 'temperature': None, 'time': '1272', 'efficiency_cont': None, 'efficiency_tret': '95'}}}
# ...

# %%
## Paper 7 value
{"phenethylammonium iodide": {"perovskite_composition": "Cs0.05(MA)0.16(FA)0.79Pb(I0.83Br0.17 )3", "electron_transport_layer": "C60", "hole_transport_layer": null, "structure_pin_nip": "NIP", "passivating_molecule": "4-tert-butyl-benzylammonium", "control_pce": "20.1", "treated_pce": "23.4", "control_voc": "1.05", "treated_voc": "1.11", "test_2_2": {"stability_type": "ISOSL3", "humidity": "50", "temperature": "90", "time": "100", "efficiency_cont": "0", "efficiency_tret": "95"}}, "4-bromophenylethylammonium": {"perovskite_composition": "Cs0.05(MA)0.16(FA)0.79Pb(I0.83Br0.17 )3", "electron_transport_layer": "C60", "hole_transport_layer": null, "structure_pin_nip": "NIP", "passivating_molecule": "4-tert-butyl-benzylammonium", "control_pce": "20.1", "treated_pce": "23.4", "control_voc": "1.05", "treated_voc": "1.11"}, "4-chlorophenylethylammonium": {"perovskite_composition": "Cs0.05(MA)0.16(FA)0.79Pb(I0.83Br0.17 )3", "electron_transport_layer": "C60", "hole_transport_layer": null, "structure_pin_nip": "NIP", "passivating_molecule": "4-tert-butyl-benzylammonium", "control_pce": "20.1", "treated_pce": "23.4", "control_voc": "1.05", "treated_voc": "1.11"}, "butylammonium iodide": {"perovskite_composition": "Cs0.05(MA)0.16(FA)0.79Pb(I0.83Br0.17 )3", "electron_transport_layer": "C60", "hole_transport_layer": null, "structure_pin_nip": "NIP", "passivating_molecule": "4-tert-butyl-benzylammonium", "control_pce": "20.1", "treated_pce": "23.4", "control_voc": "1.05", "treated_voc": "1.11", "test_2_2": {"stability_type": "ISOSL3", "humidity": "50", "temperature": "90", "time": "100", "efficiency_cont": "0", "efficiency_tret": "95"}}, "benzylammonium": {"perovskite_composition": "Cs0.05(MA)0.16(FA)0.79Pb(I0.83Br0.17 )3", "electron_transport_layer": "C60", "hole_transport_layer": null, "structure_pin_nip": "NIP", "passivating_molecule": "4-tert-butyl-benzylammonium", "control_pce": "20.1", "treated_pce": "23.4", "control_voc": "1.05", "treated_voc": "1.11", "test_2_2": {"stability_type": "ISOSL3", "humidity": "50", "temperature": "90", "time": "100", "efficiency_cont": "0", "efficiency_tret": "95"}}, "(ethylenedioxy)bis(ethylammonium) lead iodide": {"perovskite_composition": "Cs0.05(MA)0.16(FA)0.79Pb(I0.83Br0.17 )3", "electron_transport_layer": "C60", "hole_transport_layer": null, "structure_pin_nip": "NIP", "passivating_molecule": "4-tert-butyl-benzylammonium", "control_pce": "20.1", "treated_pce": "23.4", "control_voc": "1.05", "treated_voc": "1.11", "test_2": {"stability_type": "ISOSL1", "humidity": "65", "temperature": null, "time": "1000", "efficiency_cont": null, "efficiency_tret": "90"}}, "dodecylammonium iodide": {"perovskite_composition": "Cs0.05(MA)0.16(FA)0.79Pb(I0.83Br0.17 )3", "electron_transport_layer": "C60", "hole_transport_layer": null, "structure_pin_nip": "NIP", "passivating_molecule": "4-tert-butyl-benzylammonium", "control_pce": "20.1", "treated_pce": "23.4", "control_voc": "1.05", "treated_voc": "1.11", "test_1": {"stability_type": "ISOSD1", "humidity": "85", "temperature": null, "time": "100", "efficiency_cont": "60", "efficiency_tret": "90"}, "test_3": {"stability_type": "ISOST", "humidity": null, "temperature": "65", "time": "100", "efficiency_cont": "40", "efficiency_tret": "80"}}, "phenylethylammonium lead iodide": {"perovskite_composition": "Cs0.05(MA)0.16(FA)0.79Pb(I0.83Br0.17 )3", "electron_transport_layer": "C60", "hole_transport_layer": null, "structure_pin_nip": "NIP", "passivating_molecule": "4-tert-butyl-benzylammonium", "control_pce": "20.1", "treated_pce": "23.4", "control_voc": "1.05", "treated_voc": "1.11", "test_1_2": {"stability_type": "ISOSD", "humidity": "60", "temperature": null, "time": "1300", "efficiency_cont": null, "efficiency_tret": "90"}, "test_3_2": {"stability_type": "ISOST", "humidity": null, "temperature": "60", "time": "100", "efficiency_cont": null, "efficiency_tret": "75"}}, "4-tert-butyl-benzylammonium": {"perovskite_composition": "Cs0.05(MA)0.16(FA)0.79Pb(I0.83Br0.17 )3", "electron_transport_layer": "C60", "hole_transport_layer": null, "structure_pin_nip": "NIP", "passivating_molecule": "4-tert-butyl-benzylammonium", "control_pce": "20.1", "treated_pce": "23.4", "control_voc": "1.05", "treated_voc": "1.11", "test_1_2": {"stability_type": "ISOSD", "humidity": "60", "temperature": null, "time": "1300", "efficiency_cont": null, "efficiency_tret": "90"}}}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ...

# %%
bad_paper = relevent_bad + irrelevent_papers
len(bad_paper)
# Out:
# 76

# %%
len(key_none)
# Out:
# 64

# %%
df = pd.DataFrame(df_info, columns=['paper_num', 'output'])
df
# Out:
#     paper_num                                             output
# 0         134                                               None
# 1         141  {'perovskite_composition': None, 'electron_tra...
# 2          37  {'perovskite_composition': '(Cs0.2FA0.8Pb(I0.6...
# 3          62  {'perovskite_composition': 'MAPbI 3', 'electro...
# 4          25                                               None
# ..        ...                                                ...
# 192        27  {'perovskite_composition': None, 'electron_tra...
# 193       136                                               None
# 194        97  {'perovskite_composition': 'Cs 0.05 (FA0.92MA0...
# 195       129                                               None
# 196       144  {'perovskite_composition': None, 'electron_tra...
#
# [197 rows x 2 columns]

# %%
df.to_csv("Schema_2/data/annotation_flat.csv")

# %%
# df.to_csv("Schema_3_flat/data/annotation_flat.csv")
