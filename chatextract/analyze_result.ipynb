# %%
import pandas as pd

# %%
paragraph_pce = pd.read_csv("extracted_02_04-235449_149ParagraphPCE.csv", header=None)
paragraph_pce.columns = ["passage","DOI",'Material', "PCE", "Unit", "Valid_Material(bool)", "Valid_Metric(bool)", "Valid_Unit(bool)"]
paragraph_pce
# Out:
#                                               passage  \
# 0   All-perovskite tandem solar cells with improve...
# 1   All-perovskite tandem solar cells with improve...
# 2   All-perovskite tandem solar cells with improve...
# 3   All-perovskite tandem solar cells with improve...
# 4   All-perovskite tandem solar cells with improve...
# 5   All-perovskite tandem solar cells with improve...
# 6   All-perovskite tandem solar cells with improve...
# 7   All-perovskite tandem solar cells with improve...
# 8   All-perovskite tandem solar cells with improve...
# 9   All-perovskite tandem solar cells with improve...
# 10  All-perovskite tandem solar cells with improve...
# 11  All-perovskite tandem solar cells with improve...
# 12  All-perovskite tandem solar cells with improve...
# 13  All-perovskite tandem solar cells with improve...
# 14  All-perovskite tandem solar cells with improve...
# 15  All-perovskite tandem solar cells with improve...
#
# ...

# %% [markdown]
# Get only the row that has metric and unit.

# %%
paragraph_pce_clean = paragraph_pce[(paragraph_pce["Valid_Metric(bool)"] == 1) & (paragraph_pce["Valid_Unit(bool)"] == 1)]
paragraph_pce_clean
# Out:
#                                               passage  \
# 0   All-perovskite tandem solar cells with improve...
# 1   All-perovskite tandem solar cells with improve...
# 2   All-perovskite tandem solar cells with improve...
# 3   All-perovskite tandem solar cells with improve...
# 4   All-perovskite tandem solar cells with improve...
# 6   All-perovskite tandem solar cells with improve...
# 8   All-perovskite tandem solar cells with improve...
# 9   All-perovskite tandem solar cells with improve...
# 10  All-perovskite tandem solar cells with improve...
# 11  All-perovskite tandem solar cells with improve...
#
#                                            DOI  \
# 0   https://doi.org/10.1038/s41586-021-04372-8
# 1   https://doi.org/10.1038/s41586-021-04372-8
# 2   https://doi.org/10.1038/s41586-021-04372-8
# 3   https://doi.org/10.1038/s41586-021-04372-8
# 4   https://doi.org/10.1038/s41586-021-04372-8
# 6   https://doi.org/10.1038/s41586-021-04372-8
# ...
