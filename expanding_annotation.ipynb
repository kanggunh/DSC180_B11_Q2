# %% [markdown]
# # Expand the annotation from evaluation_final and perform some inspection

# %%
import pandas as pd
import ast

# Load the dataset
annotation_df = pd.read_csv("annotation.csv")

# %%
# Convert string representation of dictionary into actual dictionary
expanded_data = []
for index, row in annotation_df.iterrows():
    row_dict = ast.literal_eval(row['output'])  # Convert string to dictionary
    
    # Extract common fields
    common_fields = {
        "paper_num": row['first_num'],  # Track the first_num
        "perovskite_composition": row_dict.get("perovskite_composition"),
        "electron_transport_layer": row_dict.get("electron_transport_layer"),
        "hole_transport_layer": row_dict.get("hole_transport_layer"),
        "structure_pin_nip": row_dict.get("structure_pin_nip"),
    }

    # Extract test data
    for key, test_data in row_dict.items():
        if key.startswith("test_"):
            test_row = common_fields.copy()
            test_row["test"] = key  # Store test name
            test_row.update(test_data)  # Merge test details
            expanded_data.append(test_row)

# Convert list of dictionaries into DataFrame
df_expanded = pd.DataFrame(expanded_data)

# # Fill missing passivating_molecule values based on the first test in each group
# df_expanded['passivating_molecule'] = df_expanded.groupby('perovskite_composition')['passivating_molecule'].transform(lambda x: x.ffill())

# %%
df_expanded
# Out:
#      paper_num              perovskite_composition electron_transport_layer  \
# 0            0               Cs0.05FA0.85MA0.1PbI3                      C60
# 1            1                                None                 TinOxide
# 2            2                          (BA)2PbI 4              tin dioxide
# 3            2                          (BA)2PbI 4              tin dioxide
# 4            2                          (BA)2PbI 4              tin dioxide
# ..         ...                                 ...                      ...
# 227        147                             FAPbI 3                     None
# 228        147                             FAPbI 3                     None
# 229        148  Cs0.05FA0.85MA0.10Pb(I0.97Br0.03)3                     None
# 230        148  Cs0.05FA0.85MA0.10Pb(I0.97Br0.03)3                     None
# 231        149              FA0.7MA0.3Pb0.5Sn0.5I3                      C60
#
#     hole_transport_layer structure_pin_nip      test stability_type  \
# 0     2PACz and Me-4PACz               PIN    test_1          ISOSL
# 1                   PTAA               PIN    test_1          ISOST
# 2           Spiro-OMeTAD               NIP    test_1          ISOSL
# 3           Spiro-OMeTAD               NIP  test_1_2          ISOSD
# 4           Spiro-OMeTAD               NIP    test_2         ISOSLT
# ..                   ...               ...       ...            ...
# 227         Spiro-OMeTAD               NIP    test_1          ISOSD
# 228         Spiro-OMeTAD               NIP    test_2         ISOSLT
# 229         Spiro-OMeTAD               NIP  test_1_2         ISOSLT
# 230         Spiro-OMeTAD               NIP    test_1           None
# 231                 None              None    test_1         ISOSLT
#
#                                   passivating_molecule humidity temperature  \
# 0                   4-chlorobenzenesulfonate (4Cl-BZS)     None        65.0
# 1                                    phenethylammonium     None        85.0
# 2                                                 None     85.0        25.0
# 3                                                 None     85.0        85.0
# 4                                                 None     None        25.0
# ..                                                 ...      ...         ...
# 227  carbazole-triphenylamine and phenylammonium io...     85.0        85.0
# 228  carbazole-triphenylamine and phenylammonium io...     None        None
# 229                         phenylethylammonium iodide    50-70        None
# 230                 4-tert-butyl-benzylammonium iodide     None        None
# 231                   4-trifluoromethyl-phenylammonium    30-50        35.0
#
#        time  control_pce  treated_pce  control_voc  treated_voc  \
# 0    1200.0         24.0         26.9          NaN         1.18
# 1     500.0          NaN         19.1          NaN         1.16
# 2    1620.0         22.3         24.3          NaN         1.18
# 3    1056.0          NaN         21.3          NaN          NaN
# 4    1620.0          NaN         24.0          NaN          NaN
# ..      ...          ...          ...          ...          ...
# 227  1000.0         22.3          NaN          NaN         1.11
# 228  1100.0          NaN         24.7          NaN          NaN
# 229   500.0          NaN          NaN          NaN          NaN
# 230     NaN         21.2         22.7         1.09         1.12
# 231   600.0          NaN         26.4          NaN          NaN
#
#     efficiency_control  efficiency_tret  efficiency_cont
# 0                 None             95.0              NaN
# 1                 None              NaN              NaN
# 2                 None             98.0             58.6
# 3                 None             94.0              NaN
# 4                 None             98.0              NaN
# ..                 ...              ...              ...
# 227               None             92.3              NaN
# 228               None             94.6             66.6
# 229               None             84.0             70.0
# 230               None             95.0              NaN
# 231               None             90.0              NaN
#
# [232 rows x 18 columns]

# %% [markdown]
# # Inspect passivating molecule

# %%
data_inspect = df_expanded['passivating_molecule'].value_counts()

for index, value in data_inspect.iteritems():
    print(index)
# Out:
# ortho-(phenylene)di(ethylammonium) iodide
# phenethylammonium iodide
# fluorophenylethylammonium iodide
# PCBM
# butylammonium
# FAPbI3
# oleylammonium iodide
# poly(methyl methacrylate)
# ethylenediammonium diiodide
# phenylethylammonium iodide
# carbazole-triphenylamine and phenylammonium iodide units
# 3-diammonium iodide,propane-1
# MA +
# 4-tert-butyl-benzylammonium iodide
# 2-thiopheneethylammonium iodide
# (phenethylamino)methaniminium iodide
# MAPbBr3
# quanternary ammonium halides
# n-hexyl trimethyl ammonium bromide
# europium ion pair
# FA
# ortho-carborane
# 4-fluoroaniline
# oleylamine
# 4-trifluorophenylethylammonium iodide
# chlorine-rich mixed-halide perovskite interlayer
# lead iodide
# formate
# 4-fluorophenylethylammonium iodide
# Piperazinium Diiodide
# piperazinium iodide
# Titanium dioxide
# Butylammonium bromide
# ferrocenyl-bis-thiophene-2-carboxylate
# lead oxalate
# zinc-based halogenometallate
# sodium thioglycolate
# 4-chlorobenzenesulfonate (4Cl-BZS)
# NOTE:This is how to prepare the PSC,relevent...?
# CF3 -PEAI
# butylammonium iodide
# iso-butylamine iodide
# (ethylenedioxy)bis(ethylammonium)
# ethylammonium pyrene
# EDBE
# OATsO
# OABF4
# benzotriazole
# butylammonium bromide
# 2-thiopheneethylammonium chloride
# chlorophenylethylammonium iodide
# CF3-phenethylammonium
# 2-thiophenemethylammonium iodide
# 3,4,5-trifluoroanilinium
# phenylethylammonium lead iodide
# cyclohexylmethylammonium iodide
# trifluoromethylphenylethylammonium
# 3-(aminomethyl)pyridine
# tri-octyl phosphine oxide
# 1,3-propylene diammonium
# 2-thiophenemethylammonium bromide
# azetidinium lead iodide
# Lithium Fluoride
# PS Plastic Foam 1%
# n-butylamine iodide
# DMePDAI 2
# methylammonium
# phenethylammonium
# 4-trifluoromethyl-phenylammonium

# %% [markdown]
# ### Passivating issues
# Can't convert into SMILES
# - iso-butylamine iodide --> paper 5: butylamine iodide is convertable
# - EDBE -->
# - intermediate negative Î”E vac
# - chlorophenylethylammonium iodide
# - fluorophenylethylammonium iodide
# - CF3-phenethylammonium
# - 3,4,5-trifluoroanilinium
# - cyclohexylmethylammonium iodide dissolved in
# - tri-octyl phosphine oxide
# - azetidinium lead iodide
# - DMePDAI 2
# - NIP
# - NOTE:This is how to prepare the PSC,relevent...?
# - poly(methyl methacrylate)
# - CF3 -PEAI
# - 4-fluorophenylethylammonium iodide
# - (phenethylamino)methaniminium iodide
# - Methylammonium Lead Bromide
# - HTAB
# - FAPbI3
# - MAPbI 3
# - NIP
# - ISOSLT
# - ferrocenyl-bis-thiophene-2-carboxylate
# - fluorophenylethylammonium iodide
# - 4-trifluoromethyl-phenylammonium

# %%
passivatin = df_expanded[["paper_num","passivating_molecule"]]
passivatin = passivatin[passivatin['passivating_molecule'] == "EDBE"]
passivatin
# Out:
#     paper_num passivating_molecule
# 10          9                 EDBE
