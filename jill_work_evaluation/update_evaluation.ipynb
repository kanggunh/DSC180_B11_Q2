# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from difflib import SequenceMatcher
import numpy as np
import json
import os
import xml.etree.ElementTree as ET 
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
#extraction performed by Llama fine tuned (Nic)
extraction_df = pd.read_csv("data/150_papers_json.csv")[["id", "first_num", "output"]]
extraction_df = extraction_df.sort_values(by = ['first_num'])
extraction_df
# Out:
#          id  first_num                                             output
# 0      0_54          0  {"perovskite_composition": "Cs 0.05 FA 0.85 MA...
# 1      1_22          1  {"perovskite_composition": null, "electron_tra...
# 2      2_75          2  {"perovskite_composition": "dibutylammonium le...
# 3      3_52          3  {"perovskite_composition": "Cs0.05(MA0.10FA0.8...
# 4      4_26          4  {"perovskite_composition": "(MAPbBr3)0.05(FAPb...
# ..      ...        ...                                                ...
# 144  145_31        145  {"perovskite_composition": "Cs0.05(MA0.17FA0.8...
# 145  146_36        146  {"perovskite_composition": "Cs0.05(MA0.05FA0.9...
# 146  147_41        147  {"perovskite_composition": "formamidinium lead...
# 147  148_26        148  {"perovskite_composition": "Cs0.05FA0.85MA0.10...
# 148  149_28        149  {"perovskite_composition": "FA0.7MA0.3Pb0.5Sn0...
#
# [149 rows x 3 columns]

# %% [markdown]
# # This file compares the teamtat annotation (Json) with Extraction performed by finetuned llama (Json)

# %% [markdown]
# ### We will first compare paper #0

# %%
first_paper = extraction_df.iloc[0]

# %%
##This is copy and paste, the teamtat xml --> json is done below. This is just testing. 
annotation = {'control_pce': '24', 'structure_pin_nip': 'PIN', 'test_1': {'efficiency_tret': '95%', 'time': '1200', 'stability_type': 'ISOSL', 'temperature': '65', 'treatment_element': '4-chlorobenzenesulfonate (4Cl-BZS)'}, 'passivating_molecule': '4-chlorobenzenesulfonate (4Cl-BZS)', 'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3', 'hole_transport_layer': '2PACz and Me-4PACz', 'treated_pce': '26.9', 'treated_voc': '1.18', 'electron_transport_layer': 'C60'}
annotation
# Out:
# {'control_pce': '24',
#  'structure_pin_nip': 'PIN',
#  'test_1': {'efficiency_tret': '95%',
#   'time': '1200',
#   'stability_type': 'ISOSL',
#   'temperature': '65',
#   'treatment_element': '4-chlorobenzenesulfonate (4Cl-BZS)'},
#  'passivating_molecule': '4-chlorobenzenesulfonate (4Cl-BZS)',
#  'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3',
#  'hole_transport_layer': '2PACz and Me-4PACz',
#  'treated_pce': '26.9',
#  'treated_voc': '1.18',
#  'electron_transport_layer': 'C60'}

# %%
def str_toJson(string):
    ##The json output from Llama dataframe was not in correct json format
    #We will change the single quotes to double quotes
    # We will change the None to null

    json_string = string.replace("'", '"').replace("None", "null")

    try:
        # Try to load the JSON string
        json_object = json.loads(json_string)
        return json_object
    except json.JSONDecodeError as e:
        # Catch JSONDecodeError if the string is not valid JSON
        print(f"Error decoding JSON: {e}")
        return None
    except Exception as e:
        # Catch any other exceptions
        print(f"An error occurred: {e}")
        return None

# %%
first_extract = extraction_df.iloc[1]
extraction_str = first_extract['output']
extraction = str_toJson(extraction_str)
extraction
# Out:
# {'perovskite_composition': None,
#  'electron_transport_layer': 'TinOxide',
#  'hole_transport_layer': 'poly[bis(4-phenyl) (2,4,6-trimethylphenyl)amine] (PTAA)',
#  'structure_pin_nip': 'PIN',
#  'test_1': {'stability_type': 'ISOST',
#   'passivating_molecule': 'phenethylammonium',
#   'humidity': None,
#   'temperature': '85',
#   'time': '500',
#   'control_pce': None,
#   'treated_pce': '19.1',
#   'control_voc': None,
#   'treated_voc': '1.16',
#   'efficiency_control': None,
#   'efficiency_tret': None}}

# %%
def compare_data(labeled_data, extracted_data, numerical_tolerance=0.05):
    results = {}
    total_fields = len(labeled_data)
    matched_fields = 0
    numerical_differences = []

    for key, value in labeled_data.items():
        if key in extracted_data:
            extracted_value = extracted_data[key]

            # Exact match
            if value == extracted_value:
                matched_fields += 1
                results[key] = "Match"

            # Numerical comparison
            elif isinstance(value, (int, float)) and isinstance(extracted_value, (int, float)):
                if abs(value - extracted_value) <= numerical_tolerance * abs(value):
                    matched_fields += 1
                    numerical_differences.append(abs(value - extracted_value))
                    results[key] = "Numerical Match"
                else:
                    results[key] = "Numerical Mismatch"

            # Fuzzy string match
            elif isinstance(value, str) and isinstance(extracted_value, str):
                similarity = SequenceMatcher(None, value.lower(), extracted_value.lower()).ratio()
                if similarity > 0.8:  # Threshold for similarity
                    matched_fields += 1
                    results[key] = f"Fuzzy Match ({similarity:.2f})"
                else:
                    results[key] = f"Mismatch ({similarity:.2f})"

            else:
                results[key] = "Mismatch"
        else:
            results[key] = "Missing in Extracted Data"

    accuracy = matched_fields / total_fields
    mean_absolute_error = np.mean(numerical_differences) if numerical_differences else None

    return {
        "results": results,
        "accuracy": accuracy,
        "mean_absolute_error": mean_absolute_error,
        "matched_fields": matched_fields,
        "total_fields": total_fields
    }

# %%
annotation
# Out:
# {'control_pce': '24',
#  'structure_pin_nip': 'PIN',
#  'test_1': {'efficiency_tret': '95%',
#   'time': '1200',
#   'stability_type': 'ISOSL',
#   'temperature': '65',
#   'treatment_element': '4-chlorobenzenesulfonate (4Cl-BZS)'},
#  'passivating_molecule': '4-chlorobenzenesulfonate (4Cl-BZS)',
#  'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3',
#  'hole_transport_layer': '2PACz and Me-4PACz',
#  'treated_pce': '26.9',
#  'treated_voc': '1.18',
#  'electron_transport_layer': 'C60'}

# %%
extraction
# Out:
# {'perovskite_composition': None,
#  'electron_transport_layer': 'TinOxide',
#  'hole_transport_layer': 'poly[bis(4-phenyl) (2,4,6-trimethylphenyl)amine] (PTAA)',
#  'structure_pin_nip': 'PIN',
#  'test_1': {'stability_type': 'ISOST',
#   'passivating_molecule': 'phenethylammonium',
#   'humidity': None,
#   'temperature': '85',
#   'time': '500',
#   'control_pce': None,
#   'treated_pce': '19.1',
#   'control_voc': None,
#   'treated_voc': '1.16',
#   'efficiency_control': None,
#   'efficiency_tret': None}}

# %%
comparison_result = compare_data(annotation, extraction)
print(comparison_result)
# Out:
# {'results': {'control_pce': 'Missing in Extracted Data', 'structure_pin_nip': 'Match', 'test_1': 'Mismatch', 'passivating_molecule': 'Missing in Extracted Data', 'perovskite_composition': 'Mismatch', 'hole_transport_layer': 'Mismatch (0.14)', 'treated_pce': 'Missing in Extracted Data', 'treated_voc': 'Missing in Extracted Data', 'electron_transport_layer': 'Mismatch (0.00)'}, 'accuracy': 0.1111111111111111, 'mean_absolute_error': None, 'matched_fields': 1, 'total_fields': 9}

# %% [markdown]
# ## Retrieving teamtat label

# %%
def parse_bioc(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    
    data = { }
    concept_ids = set()
    relations = {}
    for relation in root.findall(".//relation"):
        test_name = relation.find("infon[@key='type']").text
        node_ids = [node.get("refid") for node in relation.findall("node")]
        for node_id in node_ids:
            relations[node_id] = test_name

    for annotation in root.findall(".//annotation"):
        node_id = annotation.get("id")
        var_name = annotation.find("infon[@key='type']").text
        concept_id = annotation.find("infon[@key='identifier']").text
        value = annotation.find("text").text
        if node_id in relations:
            stability_test = relations[node_id]
            if stability_test not in data:
                data[stability_test] = {}
            if concept_id is None:
                concept_id = value
            data[stability_test][var_name] = concept_id
            concept_ids.add(concept_id)

        if concept_id is None:
            concept_id = value
        if concept_id in concept_ids: # duplicate annotation
            continue
        concept_ids.add(concept_id)
        if var_name not in data:
            data[var_name] = concept_id
        else:
            if isinstance(data[var_name], list):
                data[var_name].append(value)
            else:
                data[var_name] = [data[var_name], value]
    
    return data

# %%
def extract_papernum(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    first_text = root.find(".//text")
    full_text = first_text.text
    
    ##We want to extract article number from this format
    #Method: split by spaces and extract the last element in the list
    text_list = full_text.split()
    paper_num = text_list[-1]
    return paper_num

# %%
## See if we can extract the paper number correctly
counter = 0
bioc_dir = "data/biocs"
for filename in os.listdir(bioc_dir):
    if filename.endswith(".xml"):
        file_path = os.path.join(bioc_dir, filename)
        paper_num = extract_papernum(file_path)
        # print(paper_num)
        counter += 1
print(counter)
# Out:
# 149

# %%
bioc_dir = "data/biocs"
label_data = {}
for filename in os.listdir(bioc_dir):
    if filename.endswith(".xml"):
        file_path = os.path.join(bioc_dir, filename)
        paper_num = extract_papernum(file_path)
        row = parse_bioc(file_path)
        if len(row.keys()) > 0:
            label_data[paper_num] = row

print(label_data)   
print(f"There are {len(label_data)} annotated papers")
# Out:
# {'0': {'control_pce': '24', 'structure_pin_nip': 'PIN', 'test_1': {'efficiency_tret': '95%', 'time': '1200', 'stability_type': 'ISOSL', 'temperature': '65', 'treatment_element': '4-chlorobenzenesulfonate (4Cl-BZS)'}, 'passivating_molecule': '4-chlorobenzenesulfonate (4Cl-BZS)', 'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3', 'hole_transport_layer': '2PACz and Me-4PACz', 'treated_pce': '26.9', 'treated_voc': '1.18', 'electron_transport_layer': 'C60'}, '1': {'passivating_molecule': 'phenethylammonium', 'treated_pce': '23.32', 'electron_transport_layer': ['HC(NH 2 ) 2 -CH 3 NH 3', 'SnO 2'], 'structure_pin_nip': 'PIN', 'hole_transport_layer': ['Spiro-OMeTAD', 'poly[bis(4-phenyl) (2,4,6-trimethylphenyl)amine] (PTAA)'], 'treated_voc': '1.16', 'test_1': {'temperature': '85', 'time': '500', 'stability_type': 'ISOST', 'treatment_element': 'phenethylammonium', 'treated_pce': '19.1'}}, '5': {'structure_pin_nip': 'NIP', 'passivating_molecule': ['iso-butylamine iodide', 'BAI'], 'electron_transport_layer': ['indium tin oxide', 'C 60'], 'hole_transport_layer': 'Spiro-OMeTAD', 'performance_1': {'treatment_element': 'iso-butylamine iodide', 'treated_voc': '1.135', 'treated_pce': '22.1'}, 'perovskite_composition': 'butylammonium lead iodide'}, '6': {'passivating_molecule': ['phenylethylammonium iodide', 'methylammonium iodide'], 'treated_pce': '15.3', 'perovskite_composition': 'Methylammonium Lead Iodide', 'electron_transport_layer': 'Titanium dioxide', 'test_1': {'treated_pce': '16.6', 'time': '1344', 'efficiency_tret': '0.97', 'stability_type': 'ISOSD', 'treatment_element': 'n=10'}, 'hole_transport_layer': 'Spiro-OMeTAD', 'performance_1': {'treatment_element': 'n=60', 'treated_voc': '1.06', 'treated_pce': '18.40'}, 'performance_2': {'treatment_element': 'n=40', 'treated_voc': '1.09', 'treated_pce': '18.24'}, 'performance_3': {'treatment_element': 'n=10', 'treated_voc': '1.16', 'treated_pce': '18.89'}}, '7': {'structure_pin_nip': 'NIP', 'electron_transport_layer': 'C 60', 'passivating_molecule': 'phenethylammonium', 'perovskite_composition': ['4-bromophenylethylammonium', '4-chlorophenylethylammonium'], 'test_1': {'passivating_molecule': '(EDBE)PbI 4', 'efficiency_tret': '0.9', 'time': '1000', 'humidity': '65'}}, '8': {'structure_pin_nip': 'NIP', 'electron_transport_layer': 'Tin Oxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'performance_1': {'perovskite_molecule': 'ethylammonium', 'treated_pce': '22.4', 'control_element': 'without PREA', 'treatment_element': 'ethylammonium', 'control_pce': '19.3', 'treated_voc': '1.177'}, 'performance_2': {'perovskite_molecule': 'methylammonium', 'treated_pce': '20.9', 'treated_voc': '1.167'}, 'performance_3': {'perovskite_molecule': 'pyrene-based ammonium', 'treated_pce': '19.5', 'treated_voc': '1.066'}, 'test_1': {'temperature': '40', 'time': '2000', 'stability_type': 'ISOSLT', 'treatment_element': 'ethylammonium', 'efficiency_tret': '0.85', 'efficiency_cont': '0.6'}, 'perovskite_molecule': 'ethylammonium pyrene'}, '9': {'passivating_molecule': ['diammonium iodides', 'C8', 'EDBE'], 'electron_transport_layer': 'PCBM', 'perovskite_composition': 'CH 3 NH 3 PbI 3', 'treated_pce': '17.6', 'control_pce': '14.64'}, '10': {'passivating_molecule': ['octylammonium tosylate', 'OABF4', 'intermediate negative ΔE vac'], 'electron_transport_layer': 'TinOxide', 'hole_transport_layer': ['Spiro-OMeTAD', 'spiro-MeOTAD'], 'structure_pin_nip': 'NIP', 'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05', 'perovskite_molecule': ['formamidinium', 'methylammonium'], 'treated_pce': '24.41', 'test_1': {'stability_type': 'ISOSL', 'temperature': '40', 'treatment_element': 'OATsO', 'efficiency_tret': '0.915', 'time': '500', 'passivating_molecule': 'OABF4'}}, '11': {'perovskite_molecule': 'benzotriazole', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'test_1': {'temperature': 'room temperature', 'control_pce': '20.2', 'treated_voc': '1.16', 'additive_molecule': 'BTaBr', 'treated_pce': '21.8', 'st ...
# There are 144 annotated papers

# %% [markdown]
# ### Remove journal_publication and date_published key from teamtat since xml file didn't mentioned them.

# %%
def take_out_keys(json_obj, keys_to_remove):
    ##This function will be irrelevant Hopefully after we have markdown text to annotate and have publication info in the text
    if isinstance(json_obj, dict):
        # Process dictionaries
        return {
            key: take_out_keys(value, keys_to_remove)
            for key, value in json_obj.items()
            if key not in keys_to_remove
        }
    elif isinstance(json_obj, list):
        # Process lists
        return [take_out_keys(item, keys_to_remove) for item in json_obj]
    else:
        # Return the value as is for non-dict and non-list items
        return json_obj
key_remove = {'journal_publication', 'date_published'}

# %%
clean_label_data = take_out_keys(label_data, key_remove)
clean_label_data
# Out:
# {'0': {'control_pce': '24',
#   'structure_pin_nip': 'PIN',
#   'test_1': {'efficiency_tret': '95%',
#    'time': '1200',
#    'stability_type': 'ISOSL',
#    'temperature': '65',
#    'treatment_element': '4-chlorobenzenesulfonate (4Cl-BZS)'},
#   'passivating_molecule': '4-chlorobenzenesulfonate (4Cl-BZS)',
#   'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3',
#   'hole_transport_layer': '2PACz and Me-4PACz',
#   'treated_pce': '26.9',
#   'treated_voc': '1.18',
#   'electron_transport_layer': 'C60'},
#  '1': {'passivating_molecule': 'phenethylammonium',
#   'treated_pce': '23.32',
#   'electron_transport_layer': ['HC(NH 2 ) 2 -CH 3 NH 3', 'SnO 2'],
#   'structure_pin_nip': 'PIN',
#   'hole_transport_layer': ['Spiro-OMeTAD',
#    'poly[bis(4-phenyl) (2,4,6-trimethylphenyl)amine] (PTAA)'],
#   'treated_voc': '1.16',
#   'test_1': {'temperature': '85',
#    'time': '500',
#    'stability_type': 'ISOST',
#    'treatment_element': 'phenethylammonium',
#    'treated_pce': '19.1'}},
#  '5': {'structure_pin_nip': 'NIP',
#   'passivating_molecule': ['iso-butylamine iodide', 'BAI'],
#   'electron_transport_layer': ['indium tin oxide', 'C 60'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_1': {'treatment_element': 'iso-butylamine iodide',
#    'treated_voc': '1.135',
#    'treated_pce': '22.1'},
#   'perovskite_composition': 'butylammonium lead iodide'},
#  '6': {'passivating_molecule': ['phenylethylammonium iodide',
#    'methylammonium iodide'],
#   'treated_pce': '15.3',
#   'perovskite_composition': 'Methylammonium Lead Iodide',
#   'electron_transport_layer': 'Titanium dioxide',
#   'test_1': {'treated_pce': '16.6',
#    'time': '1344',
#    'efficiency_tret': '0.97',
#    'stability_type': 'ISOSD',
#    'treatment_element': 'n=10'},
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_1': {'treatment_element': 'n=60',
#    'treated_voc': '1.06',
#    'treated_pce': '18.40'},
#   'performance_2': {'treatment_element': 'n=40',
#    'treated_voc': '1.09',
#    'treated_pce': '18.24'},
#   'performance_3': {'treatment_element': 'n=10',
#    'treated_voc': '1.16',
#    'treated_pce': '18.89'}},
#  '7': {'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'C 60',
#   'passivating_molecule': 'phenethylammonium',
#   'perovskite_composition': ['4-bromophenylethylammonium',
#    '4-chlorophenylethylammonium'],
#   'test_1': {'passivating_molecule': '(EDBE)PbI 4',
#    'efficiency_tret': '0.9',
#    'time': '1000',
#    'humidity': '65'}},
#  '8': {'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'Tin Oxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_1': {'perovskite_molecule': 'ethylammonium',
#    'treated_pce': '22.4',
#    'control_element': 'without PREA',
#    'treatment_element': 'ethylammonium',
#    'control_pce': '19.3',
#    'treated_voc': '1.177'},
#   'performance_2': {'perovskite_molecule': 'methylammonium',
#    'treated_pce': '20.9',
#    'treated_voc': '1.167'},
#   'performance_3': {'perovskite_molecule': 'pyrene-based ammonium',
#    'treated_pce': '19.5',
#    'treated_voc': '1.066'},
#   'test_1': {'temperature': '40',
#    'time': '2000',
#    'stability_type': 'ISOSLT',
#    'treatment_element': 'ethylammonium',
#    'efficiency_tret': '0.85',
#    'efficiency_cont': '0.6'},
#   'perovskite_molecule': 'ethylammonium pyrene'},
#  '9': {'passivating_molecule': ['diammonium iodides', 'C8', 'EDBE'],
#   'electron_transport_layer': 'PCBM',
#   'perovskite_composition': 'CH 3 NH 3 PbI 3',
#   'treated_pce': '17.6',
#   'control_pce': '14.64'},
#  '10': {'passivating_molecule': ['octylammonium tosylate',
#    'OABF4',
#    'intermediate negative ΔE vac'],
#   'electron_transport_layer': 'TinOxide',
#   'hole_transport_layer': ['Spiro-OMeTAD', 'spiro-MeOTAD'],
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'perovskite_molecule': ['formamidinium', 'methylammonium'],
#   'treated_pce': '24.41',
#   'test_1': {'stability_type': 'ISOSL',
#    'temperature': '40',
#    'treatment_element': 'OATsO',
#    'efficiency_tret': '0.915',
#    'time': '500',
#    'passivating_molecule': 'OABF4'}},
#  '11': {'perovskite_molecule': 'benzotriazole',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'temperature': 'room temperature',
#    'control_pce': '20.2',
#    'treated_voc': '1.16',
#    'additive_molecule': 'BTaBr',
#    'treated_pce': '21.8',
#    'stability_type': 'ISOSL',
#    'time': '24',
#    'efficiency_cont': '0.98',
#    'efficiency_tret': '1.02'},
#   'structure_pin_nip': 'NIP',
#   'control_voc': '1.11'},
#  '12': {'passivating_molecule': 'butylammonium bromide',
#   'control_voc': ['1.24', '17.5'],
#   'treated_voc': '1.31',
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '19.8',
#   'test_1': {'efficiency_tret': 'exhibit stable V OC over time',
#    'stability_type': 'ISOSL',
#    'time': '20'},
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': 'Cs0.15FA0.85PbI2.19Br0.81'},
#  '13': {'passivating_molecule': '2-thiopheneethylammonium chloride',
#   'treated_voc': '1.29',
#   'test_1': {'treated_voc': '1.29',
#    'treated_pce': '23.8',
#    'treatment_element': '2-thiopheneethylammonium chloride',
#    'control_element': 'without TEACl PDT',
#    'stability_type': 'ISOST',
#    'temperature': '60',
#    'efficiency_tret': '0.92',
#    'time': '195 h',
#    'efficiency_cont': '0.82',
#    'control_pce': '(T80: ≈9 h'},
#   'electron_transport_layer': 'PCBM',
#   'perovskite_composition': 'Cs 0.12 FA 0.8 MA 0.08 PbI 1.8 Br 1.',
#   'structure_pin_nip': 'PIN'},
#  '14': {'treatment_element': 'phenethylammonium iodide',
#   'passivating_molecule': ['chlorophenylethylammonium iodide',
#    'fluorophenylethylammonium iodide'],
#   'treated_pce': '23.7',
#   'treated_voc': '1.184',
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'PCBM',
#   'test_1': {'treatment_element': 'phenethylammonium iodide',
#    'stability_type': 'ISOSL',
#    'efficiency_cont': '0.9',
#    'time': '33',
#    'efficiency_tret': '1',
#    'control_voc': '1.109',
#    'control_pce': '21.58'},
#   'perovskite_composition': ['Cs 0.1 FA 0.9 PbI 2.9 Br 0.1',
#    'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.85 Br 0.15 ) 3'],
#   'structure_pin_nip': 'PIN'},
#  '15': {'structure_pin_nip': 'PIN',
#   'passivating_molecule': ['chlorophenylethylammonium iodide',
#    '4-fluoro-phenylethylammonium iodide'],
#   'perovskite_composition': 'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.9 Br 0.1 ) 3',
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'PCBM',
#   'control_pce': '21.78',
#   'control_voc': '1.11',
#   'treated_voc': '1.17',
#   'treated_pce': '23.79'},
#  '16': {'structure_pin_nip': ['NIP',
#    'glass/ITO/PEDOT:PSS/perovskite/spiro-OMeTAD/Ag'],
#   'passivating_molecule': 'CF3-phenethylammonium',
#   'electron_transport_layer': 'TinOxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FAPbI3',
#   'control_voc': '1.04',
#   'control_pce': '18.87',
#   'treated_voc': '1.11',
#   'treated_pce': '21.05'},
#  '17': {'treatment_element': 'hexyltrimethyl ammouniumbromide',
#   'structure_pin_nip': 'NIP',
#   'control_element': 'without HTAB',
#   'test_1': {'treatment_element': 'hexyltrimethyl ammouniumbromide',
#    'treated_pce': '18.5',
#    'time': '48',
#    'efficiency_tret': '0.86',
#    'stability_type': 'ISOSL'},
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'SnO 2',
#   'perovskite_composition': 'Cs 0.05 FA 0.81 MA 0.14 PbI 2.55 Br 0.45',
#   'control_voc': '1.16',
#   'control_pce': '20.04',
#   'treated_voc': '1.19',
#   'treated_pce': '20.94'},
#  '18': {'passivating_molecule': ['phenylethylammonium',
#    '2-thiophenemethylammonium iodide'],
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'Tin Oxide',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '19': {'test_1': {'passivating_molecule': 'fluorinated aniliniums',
#    'treated_pce': '24.09%',
#    'temperature': '85',
#    'humidity': '50',
#    'time': '1560',
#    'stability_type': 'ISOSLT'},
#   'perovskite_composition': ['Cs 0.05 MA 0.05 FA 0.9 Pb(I 0.95 Br 0.05 ) 3',
#    'Cs 0.05 MA 0.15 FA 0.8 PbI 3'],
#   'passivating_molecule': '3,4,5-trifluoroanilinium',
#   'hole_transport_layer': '2PACz',
#   'test_2': {'stability_type': 'ISOSL',
#    'humidity': '50',
#    'temperature': '85',
#    'treated_pce': '21.5',
#    'time': '1586',
#    'efficiency_tret': '0.84'},
#   'electron_transport_layer': 'C60',
#   'control_pce': '21',
#   'control_voc': '1.269',
#   'treated_voc': '1.271'},
#  '20': {'passivating_molecule': 'phenylethylammonium lead iodide',
#   'perovskite_composition': 'Methylammonium Lead Iodide'},
#  '21': {'hole_transport_layer': 'Spiro-OMeTAD',
#   'electron_transport_layer': 'Titanium dioxide',
#   'perovskite_composition': '(FAPbI3)0.92(MAPbBr3)0.08',
#   'treated_pce': '22.6'},
#  '22': {'perovskite_composition': 'Formamidinium lead triiodide',
#   'passivating_molecule': 'cyclohexylmethylammonium iodide dissolved in',
#   'additive_molecule': ['isopropanol', 'chloroform'],
#   'test_3': {'control_element': 'pristine perovskite film',
#    'temperature': '50',
#    'humidity': '40',
#    'stability_type': 'ISOSD2',
#    'time': '500',
#    'treatment_element': 'chloroform',
#    'efficiency_tret': 'isopropanol',
#    'efficiency_cont': '0.4'},
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '21.07',
#   'treated_voc': '1.154',
#   'test_1': {'stability_type': 'ISOSL',
#    'humidity': '20-30',
#    'time': '2400',
#    'efficiency_tret': '0.91',
#    'treatment_element': 'isopropanol',
#    'efficiency_cont': '0.85'},
#   'test_2': {'stability_type': 'ISOSLT',
#    'temperature': '25',
#    'efficiency_cont': '0.76',
#    'time': '1050',
#    'treatment_element': 'chloroform',
#    'efficiency_tret': '0.95'},
#   'performance_1': {'additive_molecule': 'isopropanol',
#    'treated_pce': '23.77',
#    'treated_voc': '1.145'},
#   'performance_2': {'additive_molecule': 'chloroform',
#    'treated_pce': '23.94',
#    'treated_voc': '1.149',
#    'control_voc': '1.092',
#    'control_pce': '21.40'}},
#  '23': {'structure_pin_nip': 'NIP',
#   'perovskite_composition': ['Tin dioxide', 'Cs 0.05 MA 0.1 FA 0.85 PbI 3'],
#   'perovskite_molecule': ['methylammonium', 'FA'],
#   'additive_molecule': 'methylammonium iodide',
#   'passivating_molecule': 'phenethylammonium iodide',
#   'treated_pce': '23.91',
#   'test_1': {'temperature': '25',
#    'humidity': '50',
#    'time': '1000',
#    'efficiency_tret': '1',
#    'stability_type': 'ISOSL1'},
#   'test_2': {'stability_type': 'ISOSL3',
#    'efficiency_tret': '0.92',
#    'time': '500',
#    'treatment_element': '2D post-treatmen',
#    'temperature': '65'},
#   'treated_voc': '1.15'},
#  '24': {'perovskite_composition': 'Cesium lead iodide',
#   'treatment_element': 'dicesium diododichloroplumbate',
#   'treated_pce': '17.4',
#   'hole_transport_layer': 'copper(I) thiocyanate',
#   'electron_transport_layer': 'Titanium dioxide',
#   'test_1': {'stability_type': 'ISOSD',
#    'treatment_element': 'dicesium diododichloroplumbate',
#    'treated_pce': '17.4',
#    'time': '2100',
#    'temperature': '110',
#    'efficiency_tret': '0.8'},
#   'control_pce': '14.9'},
#  '25': {'additive_molecule': 'formamidinium',
#   'perovskite_composition': 'formamidinium lead iodide'},
#  '26': {'perovskite_composition': ['Methylammonium Lead Chloride',
#    'MAPbBr 3',
#    'MAPbI 3']},
#  '27': {'passivating_molecule': 'trifluoromethylphenylethylammonium',
#   'structure_pin_nip': 'NIP',
#   'treatment_element': 'buckminsterfullerene',
#   'treated_voc': '1.23',
#   'treated_pce': '18.5',
#   'test_1': {'treatment_element': 'buckminsterfullerene',
#    'treated_pce': '18.5',
#    'treated_voc': '1.23',
#    'time': '2000',
#    'efficiency_tret': '1',
#    'stability_type': 'ISOSLT'}},
#  '28': {'perovskite_composition': 'Cesium lead iodide'},
#  '30': {'treatment_element': ['ammonia post-healing', 'NH 3 -FACsPbI 3'],
#   'treated_pce': '23.21',
#   'structure_pin_nip': 'NIP',
#   'test_1': {'treated_pce': '23.21',
#    'treated_voc': '1.16',
#    'control_pce': '10.92',
#    'control_element': 'formamidinium cesium lead iodide',
#    'stability_type': 'ISOSLT',
#    'time': '500',
#    'perovskite_composition': 'ammonia healed formamidinium cesium lead iodide',
#    'efficiency_tret': '0.8'},
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'electron_transport_layer': ['Titanium dioxide', 'SnO 2']},
#  '31': {'passivating_molecule': '3-(aminomethyl)pyridine',
#   'structure_pin_nip': 'PIN',
#   'efficiency_tret': '0.87',
#   'temperature': '55',
#   'hole_transport_layer': 'MeO-2PACZ',
#   'perovskite_composition': 'Rb0.05Cs0.05MA0.05FA0.85Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'control_pce': '23.39',
#   'treated_pce': '25.49',
#   'treated_voc': '1.19',
#   'test_3': {'treatment_element': '3-(aminomethyl)pyridine',
#    'temperature': '85',
#    'humidity': '85',
#    'perovskite_composition': 'ISOSD3',
#    'efficiency_tret': '0.94',
#    'time': '850'},
#   'test_1': {'stability_type': 'ISOSLT',
#    'temperature': '55',
#    'efficiency_tret': '0.87',
#    'time': '2428',
#    'efficiency_cont': '0.76'},
#   'test_2': {'temperature': '65',
#    'stability_type': 'ISOSL2',
#    'efficiency_tret': '0.9',
#    'time': '1315'}},
#  '32': {'perovskite_composition': 'Methylammonium Lead Iodide'},
#  '33': {'additive_molecule': 'benzene',
#   'perovskite_composition': 'formamidinium lead iodide'},
#  '35': {'perovskite_composition': '(CsPbI3)0.05[(FAPbI3)0.83(MAPbBr3)0.17]0.95',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '36': {'structure_pin_nip': 'PIN',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'perovskite_composition': 'FA0.8MA0.2PbI 3',
#   'passivating_molecule': 'tri-octyl phosphine oxide',
#   'hole_transport_layer': 'poly(triarylamine)',
#   'control_voc': ['21.2', '1.079'],
#   'treated_pce': '22.46',
#   'treated_voc': '1.098'},
#  '37': {'passivating_molecule': '1,3-propylene diammonium',
#   'test_1': {'treated_voc': '1.35',
#    'treated_pce': '19.0',
#    'time': '700',
#    'treatment_element': '1,3-propylene diammonium',
#    'efficiency_tret': '1'},
#   'test_2': {'treated_voc': '2.19',
#    'treated_pce': '26.3',
#    'efficiency_tret': '0.86',
#    'time': '500'}},
#  '39': {'hole_transport_layer': 'Spiro-OMeTAD',
#   'passivating_molecule': '2-thiophenemethylammonium bromide',
#   'perovskite_composition': '(FAPbI 3 ) 0.87(MAPbBr3)0.13]0.92(CsPbI3)0.08',
#   'performance_1': {'passivating_molecule': '2-thiophenemethylammonium bromide',
#    'treated_voc': '1.153'},
#   'performance_2': {'passivating_molecule': '2-thiophenemethylammonium bromide',
#    'treated_voc': '1.193',
#    'treated_pce': '20.82',
#    'control_voc': '1.09',
#    'control_pce': '20.7'},
#   'performance_3': {'passivating_molecule': '2-thiophenemethylammonium bromide',
#    'treated_voc': '1.175'},
#   'test_1': {'stability_type': 'ISOSLT',
#    'time': '1000',
#    'efficiency_cont': '0.65',
#    'treatment_element': '2-thiophenemethylammonium bromide',
#    'efficiency_tret': '0.75'},
#   'electron_transport_layer': 'Titanium dioxide'},
#  '40': {'test_1': {'stability_type': 'ISOSD',
#    'temperature': '85',
#    'humidity': '85',
#    'treatment_element': 'oleylammonium iodide',
#    'treated_pce': '24.3',
#    'efficiency_tret': '0.95',
#    'time': '1000'},
#   'hole_transport_layer': 'PTAA'},
#  '41': {'treated_pce': '23.9',
#   'time': '1000',
#   'passivating_molecule': ['ortho-(phenylene)di(ethylammonium) iodide',
#    'lightsoaking conditions',
#    'spiro-OMeTAD'],
#   'structure_pin_nip': 'NIP',
#   'treated_voc': '1.157',
#   'control_pce': '21.94',
#   'control_voc': '1.135',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'humidity': '40-50',
#    'efficiency_cont': '0.58',
#    'control_pce': '20.82',
#    'time': '1008',
#    'efficiency_tret': '0.85',
#    'treated_pce': '22.65'},
#   'test_2': {'stability_type': 'ISOST',
#    'temperature': '85',
#    'treatment_element': 'ortho-(phenylene)di(ethylammonium) iodide',
#    'passivating_molecule': '22.38',
#    'efficiency_tret': '0.75',
#    'time': '1000',
#    'efficiency_cont': '0.51',
#    'control_pce': '20.32'},
#   'test_3': {'passivating_molecule': 'ISOSLT',
#    'treatment_element': 'ortho-(phenylene)di(ethylammonium) iodide',
#    'efficiency_tret': '0.9',
#    'time': '1100',
#    'efficiency_cont': '0.6'}},
#  '42': {'passivating_molecule': 'azetidinium lead iodide',
#   'treated_pce': '22.4',
#   'treated_voc': ['1.18', '1.14'],
#   'structure_pin_nip': 'secondary perovskite growth',
#   'perovskite_composition': 'Cs 0.05 MA 0.1 FA 0.85 PbI 2.7 Br 0.3',
#   'test_1': {'treatment_element': 'azetidinium lead iodide',
#    'stability_type': 'ISOSL',
#    'time': '1000',
#    'temperature': '52',
#    'efficiency_tret': '0.85',
#    'efficiency_cont': '0.47'},
#   'control_voc': '1.07'},
#  '43': {'treatment_element': 'Chemical polishing of perovskite surface',
#   'control_pce': '23.07',
#   'treated_pce': '24.50',
#   'perovskite_composition': 'formamidinium lead iodide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'control_element': 'untreated perovskite film',
#    'treatment_element': 'Chemical Polishing',
#    'efficiency_cont': '0.0965',
#    'efficiency_tret': '0.4796',
#    'stability_type': 'ISOSD',
#    'humidity': '80',
#    'time': '500'},
#   'control_voc': '1.121',
#   'treated_voc': '1.150'},
#  '44': {'structure_pin_nip': 'PIN',
#   'treated_pce': '21.12',
#   'electron_transport_layer': ['heavily doped polycrystalline silicon,n-type',
#    'SiOx']},
#  '45': {'electron_transport_layer': ['heavily doped polycrystalline silicon',
#    'SiO 2']},
#  '46': {'stability_type': 'ISOSLT',
#   'test_1': {'humidity': '25',
#    'treatment_element': 'PFN-P2',
#    'treated_pce': '19.6',
#    'passivating_molecule': '1.143',
#    'time': '100',
#    'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.6'},
#   'time': '100',
#   'passivating_molecule': ['Lithium Fluoride',
#    'poly[(9,9-bis(30-((N,N-dimethyl)-N-ethylammonium)-propyl)-2,7-fluorene)alt-2,7-(9,9-dioctylfluorene)] dibromide'],
#   'structure_pin_nip': 'PIN',
#   'perovskite_composition': 'CsPbI 0.05 [(FAPbI 3 ) 0.89 (MAPbBr 3 ) 0.11 ] 0.95',
#   'treated_voc': '1.16 V'},
#  '47': {'hole_transport_layer': 'PTAA',
#   'perovskite_composition': ['Cs0.05FA0.81MA0.14PbI2.55Br0.45', 'MAPbI3'],
#   'stability_type': 'ISOSLT',
#   'humidity': '60',
#   'temperature': '65',
#   'additive_molecule': 'capping lead oxysalt thin layers',
#   'test_1': {'treatment_element': 'CsFAMA',
#    'efficiency_tret': '0.968',
#    'stability_type': 'ISOSLT',
#    'time': '1200',
#    'temperature': '65',
#    'treated_pce': '24.2',
#    'control_pce': '18.2'}},
#  '48': {'hole_transport_layer': 'PTAA',
#   'control_voc': '1.07',
#   'control_pce': '16.9',
#   'performance_1': {'passivating_molecule': 'PS Plastic Foam 1%',
#    'treated_voc': '1.10',
#    'treated_pce': '20.3'},
#   'structure_pin_nip': 'PIN'},
#  '49': {'passivating_molecule': ['n-butylamine acetate',
#    'n-butylamine iodide'],
#   'treated_pce': '16.25',
#   'treated_voc': '1.31',
#   'electron_transport_layer': 'indium tin oxide',
#   'hole_transport_layer': ['Spiro-OMeTAD', 'spiro-OMeTAD/chlorobenzene'],
#   'test_1': {'stability_type': 'ISOSL',
#    'humidity': '65',
#    'time': '4680',
#    'treatment_element': 'QW device',
#    'efficiency_tret': '0.938',
#    'control_element': 'MQW device',
#    'efficiency_cont': '0.506'},
#   'test_2': {'stability_type': 'ISOST',
#    'efficiency_tret': '0.957',
#    'temperature': '85',
#    'time': '558',
#    'efficiency_cont': '0.591'},
#   'test_3': {'treatment_element': 'QW device',
#    'efficiency_tret': '0.962',
#    'stability_type': 'ISOSL',
#    'time': '1100',
#    'control_element': 'MQW device',
#    'efficiency_cont': '0.708'}},
#  '50': {'passivating_molecule': ['allylammonium',
#    'phenethylammonium',
#    'butylammonium'],
#   'test_1': {'treated_pce': '16.5',
#    'treatment_element': 'allylammonium',
#    'efficiency_tret': '0.9',
#    'time': '650',
#    'passivating_molecule': 'ISOSL'},
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_1': {'passivating_molecule': 'allylammonium',
#    'treated_pce': '21',
#    'treatment_element': 'ALA 2 (MA 0.14 FA 0.81 Cs 0.05 ) 9 -Pb 10 (I 0.85 Br 0.15 ) 29'},
#   'performance_2': {'treated_pce': '12.1',
#    'passivating_molecule': 'phenethylammonium'},
#   'performance_3': {'treated_pce': '11.5',
#    'passivating_molecule': 'butylammonium'}},
#  '51': {'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'Methylammonium Lead Iodide',
#   'additive_molecule': 'quaternary ammonium iodide'},
#  '53': {'passivating_molecule': 'DMePDAI 2',
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': ['TitaniumDioxide', 'SnO 2'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FA0.85MA0.1Cs0.05PbI2.9Br0.1',
#   'test_1': {'treatment_element': 'DMePDAI 2',
#    'stability_type': 'ISOSL1',
#    'control_pce': '22.0',
#    'treated_pce': '24.7',
#    'perovskite_composition': 'FA0.97MA0.03PbI2.91Br0.09',
#    'temperature': '40',
#    'efficiency_tret': '0.9',
#    'time': '1000',
#    'efficiency_cont': '0.57'},
#   'treatment_element': ['DMePDAPbI4', 'BDAI2'],
#   'test_2': {'stability_type': 'ISOSD',
#    'humidity': '85',
#    'time': '740',
#    'efficiency_cont': '0.27',
#    'efficiency_tret': '0.73'},
#   'test_3': {'treatment_element': 'DMePDAPbI4',
#    'stability_type': 'ISOST',
#    'temperature': '85',
#    'time': '1008',
#    'humidity': '5',
#    'efficiency_cont': '0.29',
#    'efficiency_tret': '0.81'},
#   'efficiency_tret': '0.53'},
#  '54': {'structure_pin_nip': 'NIP',
#   'performance_1': {'perovskite_composition': 'Cs0.17FA0.83Pb(I0.83Br0.17)3',
#    'treated_pce': '17.7'},
#   'performance_2': {'perovskite_composition': 'Methylammonium Lead Iodide',
#    'treated_pce': '13'},
#   'performance_3': {'perovskite_composition': 'MAPb(I0.33Br0.67)3',
#    'treated_pce': '6'},
#   'performance_4': {'perovskite_composition': 'Methylammonium Lead Bromide',
#    'treated_pce': '3.2'}},
#  '55': {'perovskite_composition': 'methylammonium lead iodide',
#   'perovskite_molecule': ['Iodide ion', 'Pb 2 þ', 'CH 3 NH 3 þ']},
#  '56': {'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3',
#   'hole_transport_layer': ['4-ethylenedioxythiophene) polystyrene sulfonate,poly(3',
#    'Spiro-OMeTAD'],
#   'electron_transport_layer': ['indium-doped tin oxide', 'C 60', 'TiO 2'],
#   'structure_pin_nip': 'NIP'},
#  '57': {'structure_pin_nip': 'PIN',
#   'perovskite_composition': ['MA0.07FA0.93PbI3',
#    'Cs 0.05 (FA 0.83 MA 0.17 ) 0.95 Pb(I 0.83 Br 0.17 ) 3'],
#   'hole_transport_layer': 'poly(triarylamine)',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'treated_pce': '22.5',
#   'treated_voc': '1.098',
#   'test_1': {'stability_type': 'ISOSLT',
#    'temperature': '27',
#    'efficiency_tret': '0.95',
#    'time': '350',
#    'treated_pce': '21'}},
#  '58': {'electron_transport_layer': ['Tin Oxide', 'C 60'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FA0.83Cs0.17Pb(I0.83Br0.17)3',
#   'treated_pce': '18.5'},
#  '59': {'passivating_molecule': ['phenethylammonium iodide',
#    'glass/ITO/PTAA/FA 0.8 Cs 0.2 Pb-(I 0.7 Br 0.3 ) 3 /C 60 /bathocuproine (BCP)/Ag'],
#   'treated_pce': ['19.07', '18.6%'],
#   'treated_voc': '1.25',
#   'perovskite_composition': ['FA 0.8 Cs 0.2 Pb(I 0.7 Br 0.3 ) 3', 'MAPbI 3'],
#   'structure_pin_nip': 'poly(triarylamine) (PTAA)/ indium tin oxide (ITO)/glass substrates',
#   'additive_molecule': 'Pb(SCN) 2',
#   'control_voc': '1.16',
#   'control_pce': '17.5'},
#  '60': {'hole_transport_layer': 'Spiro-OMeTAD',
#   'passivating_molecule': ['vinylbenzylammonium bromide',
#    't prolonging the exposure of 3D perovskite surfaces to a dilute ligand-solution modifies the width distribution of quantum wells in the 2D/3D heterojunction.'],
#   'electron_transport_layer': 'TinOxide',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'structure_pin_nip': 'NIP',
#   'treatment_element': '30 s of soaking time',
#   'treated_pce': '21.7'},
#  '61': {'passivating_molecule': 'methylammonium lead iodide',
#   'additive_molecule': 'butylamine vapor',
#   'structure_pin_nip': 'NIP',
#   'test_2': {'treatment_element': 'butylamine vapor',
#    'additive_molecule': 'ISOSL',
#    'temperature': 'room temperature',
#    'humidity': '40',
#    'efficiency_tret': '0.92',
#    'time': '600'},
#   'test_1': {'stability_type': 'ISOST',
#    'temperature': '85',
#    'humidity': '30',
#    'efficiency_tret': '0.6',
#    'time': '125'}},
#  '62': {'passivating_molecule': ['methylammonium lead iodide', 'BAI'],
#   'treated_pce': ['16.5', '17.30'],
#   'test_1': {'stability_type': 'ISOSL',
#    'efficiency_tret': '0.81',
#    'time': '720',
#    'humidity': '55',
#    'efficiency_cont': '0.44'},
#   'test_2': {'efficiency_tret': '0.74',
#    'time': '720',
#    'temperature': '80',
#    'stability_type': 'ISOST',
#    'control_element': 'methylammonium lead iodide',
#    'efficiency_cont': '0.27'},
#   'perovskite_composition': 'CH 3 NH 3 PbI 3',
#   'structure_pin_nip': 'NIP',
#   'efficiency_tret': '0.83'},
#  '63': {'performance_1': {'perovskite_composition': 'CH3NH3PbI3',
#    'temperature': '100 °C',
#    'treated_pce': '11.66'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '64': {'additive_molecule': 'PAPER THE FAILED??',
#   'structure_pin_nip': 'PIN',
#   'hole_transport_layer': ['molybdenum oxide', 'TaTm'],
#   'electron_transport_layer': ['MAPI', 'fullerene', 'bathocuproine'],
#   'performance_3': {'control_element': 'MAPI',
#    'control_pce': '18.6',
#    'treatment_element': 'MAPI/2D',
#    'treated_pce': '17.0'},
#   'performance_1': {'treatment_element': '2D/MAPI/2D', 'treated_pce': '13.9'},
#   'performance_2': {'treatment_element': '2D/MAPI', 'treated_pce': '18.3'}},
#  '65': {'perovskite_composition': ['phenylethylammonium methylammonium lead iodide',
#    '(MA)[PbI 3 ]'],
#   'treated_voc': '1.18',
#   'treated_pce': '4.73',
#   'performance_1': {'control_element': 'methylammonium lead iodide',
#    'treated_pce': '4.73',
#    'treatment_element': 'phenylethylammonium methylammonium lead iodide'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '66': {'control_element': 'glue-based encapsulation method',
#   'stability_type': ['ISOSD1',
#    'Damp Heat Stability Testing',
#    'outdoor operation in a roof-top test installation'],
#   'test_1': {'temperature': '21',
#    'humidity': '30',
#    'stability_type': 'ISOSD1',
#    'time': '1566',
#    'control_element': 'glue-based encapsulation method',
#    'efficiency_cont': '0.93',
#    'treatment_element': 'lamination based encapsulation method',
#    'efficiency_tret': '0.95'},
#   'test_2': {'temperature': '85',
#    'humidity': '85',
#    'stability_type': 'ISOSD3',
#    'efficiency_cont': '0.32',
#    'time': '48'},
#   'test_3': {'stability_type': 'ISOSO3',
#    'humidity': '60-100',
#    'control_element': 'glue-based encapsulation method',
#    'efficiency_cont': '0.49',
#    'time': '4380',
#    'treatment_element': 'lamination based encapsulation method',
#    'efficiency_tret': '0.99'},
#   'perovskite_composition': 'Cs0.15FA0.85PbI2.55Br0.45'},
#  '67': {'structure_pin_nip': ['NIP', 'p-i-n'],
#   'stability_type': 'ISOSL1',
#   'test_2': {'structure_pin_nip': 'PIN',
#    'efficiency_tret': '0.95',
#    'time': '800',
#    'treated_pce': '21.3',
#    'stability_type': 'ISOSL2',
#    'temperature': '85'},
#   'test_3': {'efficiency_tret': '1',
#    'time': '500',
#    'treated_pce': '7',
#    'stability_type': 'ISOSD1'},
#   'test_1': {'stability_type': 'ISOSLT',
#    'electron_transport_layer': 'TinOxide',
#    'perovskite_composition': 'FA0.83Cs0.17PbI2.7Br0.3',
#    'hole_transport_layer': 'polybisphenyl(trimethylphenyl)amine',
#    'efficiency_tret': '0.96',
#    'temperature': '250'}},
#  '68': {'electron_transport_layer': ['aluminum-doped zin oxide', 'tin oxide'],
#   'treatment_element': 'aluminium-doped zinc oxide / tin oxide bilayer',
#   'hole_transport_layer': 'PEDOT:PSS',
#   'passivating_molecule': ['PCBM', 'MAPbI 3'],
#   'perovskite_composition': 'CH3NH3PbI3',
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '12.8',
#   'test_1': {'stability_type': 'ISOSLT',
#    'temperature': '23',
#    'humidity': '50',
#    'treatment_element': 'aluminum-doped zin oxide',
#    'efficiency_cont': '0',
#    'efficiency_tret': '1',
#    'time': '4300'},
#   'test_2': {'stability_type': 'ISOSLT',
#    'temperature': '60',
#    'control_element': 'aluminum-doped zin oxide',
#    'efficiency_cont': '0',
#    'treatment_element': 'aluminium-doped zinc oxide / tin oxide bilayer',
#    'efficiency_tret': '0.99',
#    'time': '1032'}},
#  '69': {'electron_transport_layer': ['TinOxide', 'Al:ZnO'],
#   'time': ['1000', '3000 h'],
#   'stability_type': 'ISOSL',
#   'temperature': '60',
#   'structure_pin_nip': 'PIN',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'passivating_molecule': 'PCBM',
#   'treatment_element': 'Tin Oxide Grown by S-ALD',
#   'control_element': 'Tin Oxide Grown by B-ALD',
#   'test_1': {'temperature': '25',
#    'humidity': '60',
#    'control_element': 'SnO x grown at a substrate speed of 80 mm s -1',
#    'efficiency_cont': '0',
#    'treatment_element': 'SnO x has been grown at 20 mm s -1',
#    'efficiency_tret': '0.9',
#    'time': '1000'}},
#  '70': {'hole_transport_layer': 'Spiro-OMeTAD',
#   'metal_contact': ['Chromium', 'gold', 'Ag'],
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'FA0.83MA0.17Pb-(I0.83Br0.17)3',
#   'treated_pce': '20.6',
#   'test_2': {'temperature': '20',
#    'stability_type': 'ISOST',
#    'time': '15',
#    'treated_pce': '17.7'},
#   'electron_transport_layer': 'TinOxide',
#   'test_1': {'temperature': '75',
#    'stability_type': 'ISOST',
#    'treatment_element': 'Cr/Au',
#    'treated_pce': '19.4'}},
#  '71': {'perovskite_composition': ['(BA)2(MA)3Pb4I13', 'CH 3 NH 3 PbI 3'],
#   'perovskite_molecule': 'butylammonium'},
#  '72': {'test_1': {'efficiency_tret': '0.99',
#    'treatment_element': '2.5D devices',
#    'treated_pce': '19.9',
#    'stability_type': 'ISOST',
#    'time': '80',
#    'control_element': '3D device',
#    'efficiency_cont': '0.5',
#    'temperature': 'room temperature',
#    'control_pce': '20'},
#   'time': '80',
#   'structure_pin_nip': 'NIP',
#   'passivating_molecule': ['ligand allylammonium', 'poly(methyl methacrylate'],
#   'perovskite_composition': 'Cs0.05FA0.8MA0.15PbI2.88Br0.04Cl0.08'},
#  '73': {'test_1': {'treatment_element': 'CF3 -PEAI',
#    'treated_pce': '23.6',
#    'efficiency_tret': '0.821',
#    'stability_type': 'ISOSLT',
#    'time': '1800',
#    'temperature': '50',
#    'humidity': '50',
#    'control_element': 'pristine perovskite films',
#    'control_pce': '21.4',
#    'efficiency_cont': '0.672'},
#   'additive_molecule': 'dibutyl sulfoxide',
#   'efficiency_tret': '0.982',
#   'stability_type': 'ISOSD',
#   'temperature': '85',
#   'time': '1000',
#   'passivating_molecule': ['3,5-bis(trifluoromethyl) phenethylammonium iodide',
#    '2CF 3 -PEAI'],
#   'structure_pin_nip': ['NIP', 'p-i-n'],
#   'performance_1': {'control_element': '0% DBSO',
#    'treatment_element': '10% DBSO',
#    'control_voc': '1.024',
#    'treated_voc': '1.091',
#    'treated_pce': '22.6'},
#   'test_2': {'stability_type': 'ISOSD',
#    'treatment_element': 'CF3 -PEAI',
#    'treated_pce': '24.8',
#    'efficiency_tret': '0.911',
#    'temperature': '85',
#    'humidity': '85',
#    'time': '1000',
#    'control_element': 'pristine perovskite',
#    'efficiency_cont': '0.713'},
#   'treated_pce': '25.1%'},
#  '74': {'treatment_element': 'self-polymerization of ethylene dimethacrylate and polyhedral oligomeric silsesquioxane',
#   'passivating_molecule': ['cross linked polymer',
#    '4-fluorophenylethylammonium iodide'],
#   'treated_pce': '21.2',
#   'efficiency_tret': '0.9',
#   'time': '4390',
#   'stability_type': 'ISOSLT',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'tin dioxide',
#   'temperature': '60',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'structure_pin_nip': 'NIP',
#   'performance_3': {'control_element': '3D perovskite',
#    'treatment_element': '3D/CLP/2D',
#    'control_pce': '18.83',
#    'treated_pce': '20.29'},
#   'performance_1': {'treatment_element': '3D/2D', 'treated_pce': '19.81'},
#   'performance_2': {'treatment_element': '3D/CLP', 'treated_pce': '19.91'},
#   'treated_voc': '1.13',
#   'test_1': {'stability_type': 'ISOSLT',
#    'temperature': '60',
#    'efficiency_tret': '0.9',
#    'treatment_element': '3D/CLP/2D',
#    'time': '5000'}},
#  '77': {'additive_molecule': '(phenethylamino)methaniminium',
#   'structure_pin_nip': 'PIN',
#   'test_1': {'treatment_element': '(phenethylamino)methaniminium',
#    'efficiency_tret': '0.9',
#    'stability_type': 'ISOSLT',
#    'temperature': '90',
#    'time': '1500'},
#   'control_pce': ['https://doi.org/10.1038/s41560-023-01362-0', '21.2%'],
#   'passivating_molecule': '(phenethylamino)methaniminium iodide',
#   'perovskite_composition': 'FA0.9Cs0.1Pb3',
#   'control_element': 'without PEAMAI',
#   'treatment_element': 'PEAMA + device',
#   'treated_pce': '24.1',
#   'temperature': '85'},
#  '78': {'perovskite_composition': 'formamidinium lead iodide',
#   'additive_molecule': ['dimethylsulfoxide', 'PbI2-(DMSO)'],
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '19.2'},
#  '79': {'electron_transport_layer': ['TinOxide', 'TiO 2'],
#   'treated_pce': '20.51',
#   'structure_pin_nip': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'control_pce': '18.5',
#    'treated_voc': '1.09',
#    'treatment_element': 'TinOxide',
#    'control_element': 'TitaniumDioxide',
#    'treated_pce': '20.51',
#    'stability_type': 'ISOSL',
#    'temperature': '28',
#    'humidity': '37'},
#   'passivating_molecule': 'Lead Iodide',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'perovskite_molecule': ['Formamidinium Lead Iodide', 'MAPbBr 3']},
#  '80': {'passivating_molecule': 'poly(methyl methacrylate)',
#   'additive_molecule': ['dimethylformamide', 'dimethyl sulfoxide (DMSO'],
#   'test_1': {'treatment_element': 'poly(methyl methacrylate)',
#    'treated_pce': '21.6',
#    'treated_voc': '1.14',
#    'efficiency_tret': '96.7',
#    'stability_type': 'ISOSD'},
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'TitaniumDioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '81': {'test_1': {'treatment_element': 'chlorine capped TitaniumDioxide',
#    'treated_pce': '20.9',
#    'efficiency_tret': '0.9',
#    'time': '500',
#    'stability_type': 'ISOSL'},
#   'perovskite_composition': ['FA 0.85 MA 0.15 PbI 2.55 Br 0.45',
#    'Cs 0.05 FA 0.81 MA 0.14 PbI 2.55 Br 0.45'],
#   'electron_transport_layer': 'TitaniumDioxide',
#   'control_voc': '1.06',
#   'treated_voc': '1.14',
#   'control_pce': '15.8',
#   'test_2': {'stability_type': 'ISOSD',
#    'treatment_element': 'chlorine capped TitaniumDioxide',
#    'efficiency_tret': '0.95',
#    'time': '1440',
#    'efficiency_cont': '0.38'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '82': {'structure_pin_nip': 'PIN',
#   'treated_pce': '20.59',
#   'passivating_molecule': ['quanternary ammonium halides', 'PCBM'],
#   'additive_molecule': 'CH 3 NH 3 PbI 3',
#   'control_voc': '1.04',
#   'control_pce': '17.1',
#   'test_1': {'stability_type': 'ISOSD',
#    'temperature': 'room temperature',
#    'humidity': '55-85',
#    'treatment_element': 'choline chloride layers',
#    'efficiency_tret': '1',
#    'control_element': 'L-α-phosphatidylcholin',
#    'efficiency_cont': '0.7',
#    'time': '800'},
#   'test_2': {'treatment_element': 'choline chloride',
#    'treated_pce': '21.1',
#    'efficiency_tret': '0.86',
#    'stability_type': 'ISOSL',
#    'time': '26'}},
#  '83': {'structure_pin_nip': 'PIN',
#   'electron_transport_layer': 'TitaniumDioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'stability_type': 'ISOSD',
#    'temperature': '25',
#    'humidity': '40',
#    'time': '792',
#    'treatment_element': 'MAPbI 3 homojunction',
#    'treated_pce': '20.27',
#    'efficiency_tret': '0.96',
#    'control_element': 'MAPbI 3 standard',
#    'efficiency_cont': '0.94',
#    'control_pce': '17.39'}},
#  '84': {'structure_pin_nip': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'hole_transport_layer': 'Spiro-OMeTAD',
#    'treated_pce': '23.2',
#    'stability_type': 'ISOST',
#    'efficiency_cont': '0.95',
#    'temperature': '60'},
#   'perovskite_composition': '(FAPbI 3 ) 0.95 (MAPbBr 3 ) 0.05',
#   'test_2': {'treatment_element': 'DM',
#    'efficiency_tret': '0.926',
#    'time': '310',
#    'stability_type': 'ISOSL'}},
#  '85': {'hole_transport_layer': 'Poly(3-hexylthiophene)',
#   'test_1': {'perovskite_molecule': 'HTAB',
#    'humidity': '0.85',
#    'time': '1370',
#    'stability_type': 'ISOSL',
#    'efficiency_tret': '0.95'},
#   'treated_pce': '22.7',
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'HTAB 0.3 (FAPbI 3 ) 0.95 (MAPbBr 3 ) 0.05'},
#  '86': {'electron_transport_layer': ['EDTA-complexed SnO2', 'SnO 2'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'control_pce': '18.93',
#   'control_voc': '1.10',
#   'treated_voc': '1.11',
#   'treated_pce': '21.6',
#   'test_1': {'treatment_element': 'EDTA-complexed SnO2',
#    'efficiency_tret': '0.92',
#    'time': '2880',
#    'stability_type': 'ISOSD',
#    'control_element': 'SnO 2',
#    'efficiency_cont': '0.74'},
#   'test_2': {'temperature': '120',
#    'stability_type': 'ISOSL',
#    'treatment_element': 'EDTA-complexed SnO2',
#    'efficiency_tret': '0.86',
#    'control_element': 'TinOxide',
#    'efficiency_cont': '0.38'}},
#  '87': {'structure_pin_nip': 'NIP',
#   'test_1': {'passivating_molecule': 'europium ion pair',
#    'efficiency_tret': '0.92',
#    'stability_type': 'ISOSL',
#    'time': '1000'},
#   'treated_pce': '21.52',
#   'test_2': {'stability_type': 'ISOST',
#    'efficiency_tret': '0.91',
#    'temperature': '85',
#    'treatment_element': 'Eu 3+ -Eu 2+'}},
#  '88': {'treated_pce': ['21.46', '20.56'],
#   'perovskite_molecule': ['caesium',
#    'methylammonium (MA)',
#    'formamidinium (FA)'],
#   'perovskite_composition': ['CsFAMA', 'CaFAMA-F'],
#   'efficiency_tret': '0.9',
#   'time': '1,000',
#   'additive_molecule': ['alkali halide, NaX (X = I, Br, Cl or F)',
#    'fluoride-containing material'],
#   'structure_pin_nip': 'NIP',
#   'test_1': {'treatment_element': 'fluoride-containing perovskite',
#    'treated_pce': '21.46',
#    'efficiency_tret': '0.9',
#    'stability_type': 'ISOSL',
#    'control_element': 'CsFAMA',
#    'control_pce': '19.03'},
#   'control_pce': '48.86',
#   'test_2': {'treatment_element': 'CsFAMA-F',
#    'stability_type': 'ISOST',
#    'efficiency_tret': '0.9',
#    'temperature': '85',
#    'time': '1,000',
#    'control_element': 'CsFAMA',
#    'efficiency_cont': '0.5'},
#   'test_3': {'stability_type': 'ISOSD',
#    'humidity': '0.25-0.45',
#    'treatment_element': 'CsFAMA-F',
#    'efficiency_tret': '0.9',
#    'time': '6,000'},
#   'temperature': '25-40'},
#  '89': {'perovskite_molecule': 'FAPbI3',
#   'perovskite_composition': ['Cs0.05(MA0.85FA0.15)0.95Pb(I0.85Br0.15)3',
#    'BA2MA3PbI13'],
#   'treated_pce': '20.87',
#   'structure_pin_nip': 'NIP',
#   'treated_voc': '1.145'},
#  '90': {'perovskite_composition': '(FAPbI 3 ) 0.85 (MAPbBr 3 ) 0.15',
#   'treated_pce': ['20.7', '19.8'],
#   'perovskite_molecule': ['MA +', 'MAPbI 3'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'structure_pin_nip': 'NIP',
#   'control_pce': '18.7',
#   'treated_voc': '1.17'},
#  '91': {'perovskite_molecule': 'Formamidinium Lead Iodide',
#   'additive_molecule': ['methylammonium chloride', 'MA-40'],
#   'treated_pce': ['23.36', '24.02'],
#   'treated_voc': '1.130',
#   'test_1': {'temperature': '25',
#    'stability_type': 'ISOSL',
#    'humidity': '25',
#    'efficiency_tret': '0.9',
#    'time': '1,200',
#    'treatment_element': 'methylammonium chloride - 40%'},
#   'test_2': {'temperature': '40',
#    'stability_type': 'ISOST',
#    'control_element': 'methylammonium chloride',
#    'efficiency_cont': '0.6',
#    'time': '300',
#    'treatment_element': 'methylammonium chloride - 40%',
#    'efficiency_tret': '0.9'}},
#  '92': {'electron_transport_layer': ['BaSnO3', 'Li-doped TiO 2', 'TiO 2'],
#   'treated_pce': '21.3',
#   'control_pce': '20',
#   'structure_pin_nip': 'NIP',
#   'test_1': {'stability_type': 'ISOSL',
#    'humidity': '40',
#    'treatment_element': 'mp-BSO',
#    'control_element': 'mp-TiO 2',
#    'efficiency_cont': '0.5',
#    'electron_transport_layer': '24',
#    'efficiency_tret': '0.9'},
#   'test_3': {'treatment_element': 'BSO-based',
#    'electron_transport_layer': 'ISOSLT',
#    'temperature': '450',
#    'efficiency_tret': '0.67'},
#   'test_2': {'stability_type': 'ISOSD',
#    'temperature': '25',
#    'humidity': '25',
#    'time': '500',
#    'efficiency_tret': '1',
#    'control_pce': '1.5 G'}},
#  '93': {'perovskite_molecule': ['formamidinium lead iodide',
#    'MAPbI 3',
#    'FA 0.5 MA 0.5 PbI 3'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'electron_transport_layer': 'TinOxide',
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '21.21'},
#  '94': {'hole_transport_layer': ['Spiro-OMeTAD',
#    'polymeric poly(4-vinylpyridine)'],
#   'efficiency_tret': '0.8',
#   'time': '6000',
#   'test_1': {'stability_type': 'ISOSL',
#    'hole_transport_layer': 'polymeric poly(4-vinylpyridine)',
#    'humidity': '25-50',
#    'efficiency_tret': '0.8',
#    'time': '6000',
#    'treated_pce': '20.6',
#    'temperature': '25-40'},
#   'treated_pce': '20.6',
#   'control_pce': '19.11',
#   'structure_pin_nip': 'PIN',
#   'test_2': {'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.9',
#    'time': '700',
#    'efficiency_cont': '0.8'},
#   'test_3': {'treatment_element': 'polymeric poly(4-vinylpyridine)',
#    'stability_type': 'ISOST',
#    'efficiency_tret': '0.8',
#    'temperature': '85',
#    'time': '300'}},
#  '95': {'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'passivating_molecule': ['butylammonium iodide',
#    'octylammonium iodide',
#    'dodecylammonium iodide'],
#   'performance_1': {'passivating_molecule': 'octylammonium iodide',
#    'treated_pce': '22.9'},
#   'electron_transport_layer': 'TitaniumDioxide',
#   'performance_2': {'treated_pce': '15.1',
#    'passivating_molecule': 'dodecylammonium iodide',
#    'control_pce': '5.9'},
#   'hole_transport_layer': ['DM', 'Spiro-OMeTAD'],
#   'performance_3': {'passivating_molecule': 'oleylammonium iodide',
#    'treated_pce': '23.3'},
#   'test_2': {'stability_type': 'ISOSD',
#    'temperature': '65',
#    'humidity': '65',
#    'time': '100',
#    'control_element': 'butylammonium iodide',
#    'efficiency_cont': '0.2',
#    'treatment_element': 'dodecylammonium iodide',
#    'efficiency_tret': '0.9',
#    'control_pce': '85'},
#   'test_1': {'temperature': '25', 'humidity': '85'}},
#  '96': {'passivating_molecule': ['NOTE:Assume tinacetylacetonate is additive',
#    'fluorine-doped SnO 2 (FTO)/c-TiO 2 /SnO 2 / perovskite/spiro-OMeTAD/gold'],
#   'performance_1': {'treated_pce': '21.12', 'additive_molecule': 'Chlorine'},
#   'performance_2': {'additive_molecule': 'Bromide', 'treated_pce': '20'},
#   'performance_3': {'treatment_element': 'c-TiO 2 /Cl 2',
#    'treated_pce': '22.19'},
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '97': {'treated_pce': '22.3',
#   'time': '1000',
#   'stability_type': 'ISOSLT',
#   'treatment_element': 'anchoring alkylamine ligands',
#   'efficiency_tret': '1',
#   'control_pce': '20.5',
#   'performance_1': {'passivating_molecule': 'oleylamine', 'treated_pce': '22'},
#   'structure_pin_nip': 'PIN',
#   'test_1': {'passivating_molecule': 'ISOSLT',
#    'efficiency_cont': '0.58',
#    'treatment_element': 'anchoring alkylamine ligands',
#    'efficiency_tret': '1',
#    'time': '1000',
#    'treated_pce': '21.6'},
#   'test_2': {'passivating_molecule': 'ISOST',
#    'temperature': '85',
#    'efficiency_tret': '0.9',
#    'treatment_element': 'anchoring alkylamine ligands',
#    'time': '1020'},
#   'perovskite_composition': 'Cs 0.05 (FA0.92MA0.08)0.95Pb(I0.92Br0.08)3',
#   'performance_2': {'control_pce': '19.2',
#    'control_element': 'pristine CsFAMA',
#    'treated_pce': '21.2',
#    'treatment_element': 'CsFAMA device with AALs.'}},
#  '98': {'additive_molecule': 'FN-Br',
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'methylammonium lead iodide',
#   'treated_pce': '21.54',
#   'efficiency_tret': '0.92',
#   'test_1': {'time': '4',
#    'stability_type': 'ISOSLT',
#    'humidity': '60',
#    'control_element': 'TBP/LiTFSI doped spiro-OMeTAD',
#    'efficiency_cont': '0.3',
#    'treatment_element': 'FN-Br/FK209',
#    'efficiency_tret': '0.95'},
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_1': {'control_pce': '17.29',
#    'treatment_element': 'FN-Br',
#    'treated_pce': '19.31'}},
#  '99': {'passivating_molecule': 'chlorine-rich mixed-halide perovskite interlayer',
#   'test_2': {'treatment_element': 'chlorine-rich mixed-halide perovskite interlayer',
#    'time': '500',
#    'passivating_molecule': 'ISOSLT',
#    'efficiency_tret': '0.82'},
#   'test_1': {'treated_pce': '21.01',
#    'efficiency_tret': '0.94',
#    'time': '180',
#    'stability_type': 'ISOSO',
#    'efficiency_cont': '0'},
#   'efficiency_tret': '0.82',
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': ['TitaniumDioxide', 'SnO 2'],
#   'control_pce': '18.08'},
#  '100': {'electron_transport_layer': 'Lanthanum oxide',
#   'control_element': 'TinOxide',
#   'treatment_element': 'Lanthanum oxide / Tin Oxide Bilayer',
#   'treated_pce': ['23.24', '23.07%'],
#   'test_1': {'treatment_element': 'Lanthanum oxide / Tin Oxide Bilayer',
#    'efficiency_tret': '0.975',
#    'stability_type': 'ISOSL',
#    'time': '1920',
#    'control_element': 'TinOxide',
#    'efficiency_cont': '0.927'},
#   'test_2': {'efficiency_tret': '0.91',
#    'time': '180',
#    'stability_type': 'ISOSLT',
#    'treatment_element': 'Lanthanum oxide / Tin Oxide Bilayer',
#    'control_element': 'TinOxide',
#    'efficiency_cont': '0.83'},
#   'control_pce': '21.17',
#   'structure_pin_nip': 'NIP',
#   'test_3': {'electron_transport_layer': 'ISOSL',
#    'humidity': '75',
#    'time': '120',
#    'treatment_element': 'Lanthanum oxide / Tin Oxide Bilayer',
#    'efficiency_tret': '0.8',
#    'control_element': 'TinOxide',
#    'efficiency_cont': '0.71'},
#   'performance_1': {'electron_transport_layer': 'Lanthanum oxide / Tin Oxide Bilayer',
#    'treated_pce': '23.2'}},
#  '101': {'control_pce': ['c', '19.09', 'r', '(19.65'],
#   'additive_molecule': ['diethylene glycol', '3%', '10%'],
#   'treated_pce': ['20.10', '19.90', '16.71%'],
#   'efficiency_tret': '0.9225',
#   'time': '720',
#   'treatment_element': '0%',
#   'structure_pin_nip': 'NIP',
#   'test_1': {'stability_type': 'ISOSL',
#    'temperature': '25',
#    'humidity': '20-30',
#    'efficiency_tret': '0.87'},
#   'performance_1': {'control_element': '0%',
#    'control_pce': '18.57',
#    'treatment_element': '3% diethylene glycol',
#    'treated_pce': '16.78',
#    'additive_molecule': '10% diethylene glycol'}},
#  '102': {'perovskite_composition': 'formamidinium lead iodide',
#   'treated_pce': '20.71',
#   'perovskite_molecule': 'lead iodide',
#   'structure_pin_nip': 'NIP',
#   'treated_voc': '1.114',
#   'test_1': {'stability_type': 'ISOSL',
#    'humidity': '20',
#    'efficiency_tret': '0.8',
#    'time': '720'},
#   'test_2': {'stability_type': 'ISOSLT',
#    'humidity': '30',
#    'control_pce': '17.23',
#    'efficiency_tret': '0.92',
#    'treated_pce': '21.48',
#    'time': '1.6'}},
#  '103': {'perovskite_composition': ['alpha phase formamidinium lead iodide',
#    '[(FAPbI 3 ) 0.95 (MAPbBr 3 ) 0.05 ]'],
#   'additive_molecule': 'methylenediammonium dichloride',
#   'test_1': {'treatment_element': 'methylenediammonium dichloride',
#    'treated_pce': '23.7',
#    'efficiency_tret': '0.9',
#    'time': '600',
#    'stability_type': 'ISOSO'},
#   'test_2': {'additive_molecule': 'ISOSD',
#    'efficiency_tret': '0.9',
#    'humidity': '85',
#    'temperature': '25',
#    'efficiency_cont': '0.4'},
#   'test_3': {'stability_type': 'ISOST',
#    'temperature': '150',
#    'humidity': '25',
#    'efficiency_cont': '0.2',
#    'efficiency_tret': '0.9'}},
#  '104': {'electron_transport_layer': 'tin dioxide',
#   'treated_pce': '25.2',
#   'perovskite_composition': 'Methylammonium Lead Bromide',
#   'test_1': {'treatment_element': 'tin dioxide',
#    'efficiency_tret': '1',
#    'time': '3600',
#    'stability_type': 'ISOSLT'},
#   'test_2': {'efficiency_tret': '0.8',
#    'time': '500',
#    'stability_type': 'ISOSLT'}},
#  '105': {'electron_transport_layer': ['titanium oxynitride', 'TiO x'],
#   'treated_pce': ['22.6', '23.09%'],
#   'structure_pin_nip': 'NIP',
#   'control_pce': '21.26',
#   'test_1': {'treatment_element': 'titanium oxynitride',
#    'treated_pce': '22.82',
#    'time': '250',
#    'stability_type': 'ISOSL',
#    'efficiency_tret': '0.987',
#    'control_element': 'TItanium oxide',
#    'control_pce': '20.24',
#    'efficiency_cont': '0.965'},
#   'test_2': {'stability_type': 'ISOSD',
#    'temperature': '85',
#    'humidity': '85'}},
#  '106': {'test_1': {'treated_pce': '22.02',
#    'stability_type': 'ISOSLT',
#    'time': '1000',
#    'temperature': '85',
#    'treatment_element': 'ZrL3:bis-C60',
#    'efficiency_tret': '0.92'},
#   'structure_pin_nip': 'PIN',
#   'performance_2': {'control_element': 'without any EEL',
#    'control_pce': '18.8',
#    'electron_transport_layer': 'ZrL3:bis-C60',
#    'treated_pce': '22.02',
#    'treated_voc': '1.20'},
#   'performance_1': {'electron_transport_layer': 'zirconium-based MOF',
#    'treated_pce': '20.34'},
#   'electron_transport_layer': 'C60',
# ...
#   'treated_voc': ['1.13', '1.18'],
#   'test_3': {'stability_type': 'ISOST',
#    'efficiency_cont': '0.63',
#    'temperature': '-60',
#    'efficiency_tret': '0.887'}},
#  '125': {'test_2': {'additive_molecule': 'selenophene',
#    'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.89',
#    'time': '500',
#    'temperature': '85'},
#   'test_1': {'efficiency_tret': '0.91',
#    'time': '3190',
#    'stability_type': 'ISOSLT',
#    'temperature': '45'},
#   'perovskite_composition': ['FACsPb(Br0.13I0.87)3', 'Cs 0.1 FA 0.9 PbI 3'],
#   'electron_transport_layer': 'tin dioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'control_pce': '20.9',
#   'treated_pce': '23.4',
#   'temperature': '85',
#   'stability_type': 'ISOSD',
#   'efficiency_tret': '0.8',
#   'time': '1750',
#   'test_3': {'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.8',
#    'time': '960'}},
#  '126': {'passivating_molecule': 'lead oxalate',
#   'perovskite_composition': 'formamidinium lead iodide',
#   'treated_pce': '25.39',
#   'test_1': {'efficiency_tret': '0.92',
#    'stability_type': 'ISOSLT',
#    'time': '550',
#    'control_pce': '23.43',
#    'control_voc': '1.16',
#    'treated_pce': '25.39',
#    'treated_voc': '1.18',
#    'efficiency_cont': '0.6'},
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'tin dioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'additive_molecule': 'formamidinium chloride'},
#  '127': {'passivating_molecule': 'zinc-based halogenometallate',
#   'structure_pin_nip': 'PIN',
#   'test_1': {'treated_pce': '24.1',
#    'efficiency_tret': '0.945',
#    'time': '1009',
#    'stability_type': 'ISOSLT'},
#   'hole_transport_layer': 'poly(triarylamine)',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'treated_voc': '1.198'},
#  '128': {'additive_molecule': 'aminoindan hydrochloride',
#   'test_1': {'treated_pce': '25.12',
#    'efficiency_tret': '0.98',
#    'time': '1500',
#    'perovskite_composition': 'ISOSLT',
#    'temperature': '55',
#    'efficiency_cont': '0.78',
#    'control_pce': '21.73'},
#   'test_2': {'efficiency_tret': '0.92',
#    'time': '1200',
#    'temperature': '85',
#    'humidity': '85',
#    'structure_pin_nip': 'PIN',
#    'stability_type': 'ISOST1'},
#   'stability_type': 'ISOST1',
#   'hole_transport_layer': 'poly(triarylamine)',
#   'perovskite_composition': 'Cs0.05FA0.95PbI3',
#   'electron_transport_layer': 'PCBM',
#   'control_pce': '21.94',
#   'control_voc': '1.122',
#   'treated_voc': '1.156'},
#  '129': {'structure_pin_nip': 'PIN',
#   'treated_pce': '24.8',
#   'test_1': {'efficiency_tret': '0.98',
#    'temperature': '65',
#    'stability_type': 'ISOSLT',
#    'time': '1200',
#    'efficiency_cont': '0.7'},
#   'test_2': {'additive_molecule': '4-guanidinobenzoic acid hydrochloride',
#    'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.9',
#    'time': '500',
#    'efficiency_cont': '0.3'},
#   'treated_voc': '1.19',
#   'hole_transport_layer': '(2,7-Dimethoxy-9H-carbazol-9-yl)methyl phosphonic acid',
#   'electron_transport_layer': 'buckminsterfullerene'},
#  '130': {'treated_pce': '25.4',
#   'additive_molecule': ['pentanamidine hydrochlorid',
#    'Butylamidine hydrochloride',
#    'propionamidine hydrochloride'],
#   'performance_1': {'additive_molecule': 'pentanamidine hydrochlorid',
#    'treated_pce': '24.0',
#    'control_pce': '22.9',
#    'treated_voc': '1.18',
#    'control_voc': '1.13'},
#   'test_1': {'temperature': '30',
#    'efficiency_cont': '0.7',
#    'additive_molecule': 'pentanamidine hydrochlorid',
#    'efficiency_tret': '0.95',
#    'time': '1000',
#    'stability_type': 'ISOSL3'},
#   'test_2': {'additive_molecule': 'pentanamidine hydrochlorid',
#    'temperature': '65',
#    'humidity': '85',
#    'efficiency_tret': '0.82',
#    'time': '500',
#    'efficiency_cont': '0.63'},
#   'performance_2': {'additive_molecule': 'pentanamidine hydrochlorid',
#    'treated_pce': '20.4',
#    'control_pce': '18.9'}},
#  '131': {'treated_pce': '25.5',
#   'structure_pin_nip': ['PIN', 'porous insulator contact'],
#   'control_pce': '23',
#   'control_voc': '1.13',
#   'treated_voc': '1.19',
#   'test_1': {'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.98',
#    'temperature': '85',
#    'time': '1000'}},
#  '132': {'additive_molecule': '1-dodecanethiol',
#   'hole_transport_layer': ['Spiro-OMeTAD', 'DDT-treated spiro-OMeTAD'],
#   'treated_pce': '23.1',
#   'efficiency_tret': '0.9',
#   'time': '1000',
#   'perovskite_composition': 'Cs0.05(FAPbI3)0.85(MAPbBr3)0.15',
#   'performance_1': {'control_pce': '22.7',
#    'control_voc': '1.171',
#    'treated_pce': '23.1',
#    'treated_voc': '1.198'},
#   'test_2': {'additive_molecule': '1-dodecanethiol',
#    'stability_type': 'ISOSLT',
#    'temperature': '50-85',
#    'efficiency_tret': '0.95'},
#   'test_1': {'stability_type': 'ISOSD',
#    'humidity': '50',
#    'efficiency_cont': '0.68',
#    'time': '430',
#    'efficiency_tret': '0.97'},
#   'test_3': {'stability_type': 'ISOSLT',
#    'efficiency_cont': '0.1',
#    'time': '2000',
#    'efficiency_tret': '0.93',
#    'additive_molecule': '1-dodecanethiol'}},
#  '133': {'test_1': {'passivating_molecule': 'sodium thioglycolate',
#    'treated_pce': '24.56',
#    'treated_voc': '1.19',
#    'efficiency_tret': '0.96',
#    'time': '900',
#    'stability_type': 'ISOSLT'},
#   'perovskite_composition': 'Cs0.05FA0.9MA0.05Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'hole_transport_layer': 'Me-4PACz',
#   'structure_pin_nip': 'PIN',
#   'performance_1': {'control_voc': '1.14',
#    'treated_voc': '1.19',
#    'passivating_molecule': 'sodium thioglycolate',
#    'treated_pce': '24.2',
#    'control_pce': '22.5'}},
#  '134': {'additive_molecule': 'guanabenz acetate salt',
#   'treated_pce': '25.08',
#   'stability_type': ['ISOSLT', 'damp heat conditions'],
#   'efficiency_tret': '0.85',
#   'temperature': '85',
#   'test_2': {'efficiency_tret': '0.97',
#    'time': '2000',
#    'efficiency_cont': '0.68',
#    'humidity': '20',
#    'temperature': '25',
#    'stability_type': 'ISOSD'},
#   'perovskite_composition': 'FA0.98MA0.02Pbl3',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'treated_voc': '1.174',
#   'structure_pin_nip': 'NIP',
#   'test_1': {'stability_type': 'ISOSLT',
#    'temperature': '50',
#    'efficiency_tret': '0.85',
#    'time': '300',
#    'efficiency_cont': '0.6',
#    'additive_molecule': 'ISOSLT',
#    'humidity': '85'},
#   'test_3': {'efficiency_tret': '0.85',
#    'time': '260',
#    'stability_type': 'ISOSD',
#    'temperature': '85',
#    'humidity': '85'}},
#  '135': {'hole_transport_layer': ['nickel oxide',
#    '4-(3,11-dimethoxy-7H-dibenzo[c,g]carbazol-7-yl)butyl)phosphonic acid'],
#   'treated_pce': '25.6',
#   'treated_voc': '1.19',
#   'efficiency_tret': '0.9',
#   'stability_type': 'ISOSLT',
#   'temperature': ['65', '25°'],
#   'time': '1200',
#   'structure_pin_nip': 'PIN',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'passivating_molecule': 'methylammonium iodide',
#   'test_2': {'stability_type': 'ISOSL2',
#    'treatment_element': 'nickel oxide',
#    'efficiency_tret': '0.65',
#    'temperature': '85',
#    'time': '1200'},
#   'test_1': {'treatment_element': '11-dimethoxy-7H-dibenzo[c,4-(3,g]carbazol-7-yl)butyl)phosphonic acid',
#    'efficiency_tret': '0.53',
#    'temperature': '85',
#    'time': '800'},
#   'test_3': {'treatment_element': 'NiO x /MeO-4PADBC',
#    'efficiency_tret': '0.74',
#    'time': '1200',
#    'temperature': '85'}},
#  '136': {'performance_1': {'hole_transport_layer': '2-(4-(bis(4-methoxyphenyl)amino)phenyl)-1-cyanovinyl)phosphonic acid',
#    'treated_pce': '25.4',
#    'treated_voc': '1.21'},
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'performance_2': {'hole_transport_layer': 'poly(triarylamine)',
#    'treated_pce': '22.6',
#    'treated_voc': '1.13'},
#   'performance_3': {'hole_transport_layer': "2,2'-(9,6-diyl)bis(4-(1H-pyrazol-1-yl)-phenyl)amine,9-dimethyl-9H-carbazol-3",
#    'treated_pce': '23.4',
#    'treated_voc': '1.17'},
#   'electron_transport_layer': 'buckminsterfullerene',
#   'test_1': {'humidity': '30-40',
#    'temperature': '2000',
#    'stability_type': 'ISOSL1',
#    'efficiency_tret': '0.9'},
#   'test_2': {'additive_molecule': '2-(4-(bis(4-methoxyphenyl)amino)phenyl)-1-cyanovinyl)phosphonic acid',
#    'stability_type': 'ISOSD',
#    'efficiency_tret': '0.95',
#    'time': '500',
#    'temperature': '85',
#    'humidity': '85'}},
#  '137': {'structure_pin_nip': 'PIN',
#   'passivating_molecule': ['3-(methylthio)propylamine hydroiodide',
#    'propane-1,3-diammonium iodide'],
#   'test_2': {'treatment_element': '3-diammonium iodide,propane-1 / 3-(methylthio)propylamine hydroiodide bilayer',
#    'time': '2000',
#    'temperature': '65',
#    'stability_type': 'ISOSL3',
#    'efficiency_tret': '0.96',
#    'efficiency_cont': '0.7',
#    'humidity': '50'},
#   'electron_transport_layer': 'buckminsterfullerene',
#   'treated_pce': '26.4',
#   'treated_voc': '1.17',
#   'test_1': {'time': '1600',
#    'temperature': '85',
#    'stability_type': 'ISOSD2',
#    'efficiency_tret': '0.95',
#    'efficiency_cont': '0.84'}},
#  '138': {'treated_pce': '25.3',
#   'test_1': {'efficiency_tret': '0.95',
#    'temperature': '65',
#    'humidity': '50',
#    'time': '1000',
#    'treatment_element': '3-MPA at a molar ratio of 1:9 with 2PACz',
#    'stability_type': 'ISOSL3'},
#   'additive_molecule': ['2-(9H-carbazol-9-yl)ethyl)phosphonic acid',
#    '3-mercaptopropionic acid'],
#   'perovskite_composition': 'Cs0.05MA0.10FA0.85PbI3',
#   'structure_pin_nip': 'NIP'},
#  '139': {'additive_molecule': '1-(phenylsulfonyl)pyrrole',
#   'structure_pin_nip': 'PIN',
#   'hole_transport_layer': 'poly(triaryl)amine',
#   'perovskite_composition': 'FA0.95Cs0.05PbI3',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'control_pce': '23.72',
#   'control_voc': '1.145',
#   'treated_voc': '1.164',
#   'test_2': {'treatment_element': '1-(phenylsulfonyl)pyrrole',
#    'temperature': '85',
#    'humidity': '85',
#    'efficiency_tret': '0.9',
#    'time': '300',
#    'efficiency_cont': '0.8',
#    'stability_type': 'ISOSD3',
#    'control_pce': '19.2',
#    'treated_pce': '21.8'},
#   'test_1': {'efficiency_tret': '0.92',
#    'time': '2500',
#    'efficiency_cont': '0.8',
#    'stability_type': 'ISOSL1',
#    'control_pce': '25.40',
#    'treated_pce': '23.54'}},
#  '140': {'perovskite_composition': 'formamidinium lead halides',
#   'test_1': {'treated_pce': '25.8',
#    'efficiency_tret': '0.94',
#    'time': '1258',
#    'temperature': '50'}},
#  '141': {'electron_transport_layer': ['boron chloride subphthalocyanine / fullerene bilayer',
#    'Cl 6 SubPc'],
#   'treated_pce': '21.3',
#   'test_1': {'efficiency_tret': '0.8',
#    'time': '816',
#    'stability_type': 'ISOSD',
#    'temperature': '85',
#    'humidity': '85',
#    'treatment_element': 'boron chloride subphthalocyanine / fullerene bilayer',
#    'control_element': 'buckminsterfullerene',
#    'efficiency_cont': '0.8'},
#   'test_2': {'efficiency_tret': '0.95',
#    'time': '1272',
#    'stability_type': 'ISOSO1'},
#   'structure_pin_nip': 'PIN',
#   'temperature': ['23.5', 'room temperature', '80 °C', '(85 °C'],
#   'humidity': '34'},
#  '142': {'treatment_element': '3D-2D perovskite-perovskite planar heterojunction',
#   'test_2': {'treated_pce': '16.13',
#    'efficiency_tret': '0.74',
#    'additive_molecule': '720',
#    'temperature': '85'},
#   'test_1': {'efficiency_tret': '0.71', 'time': '1200', 'humidity': '65'}},
#  '143': {'hole_transport_layer': ['copper(I) thiocyanate', 'spiro-OMeTAD'],
#   'perovskite_composition': '(FAPbI3)0.77(MAPbBr3)0.14(CsPbI3)0.09',
#   'passivating_molecule': ['phenylethylammonium iodide', 'FPEAI'],
#   'performance_3': {'treatment_element': 'copper(I) thiocyanate',
#    'passivating_molecule': 'fluorophenylethylammonium iodide',
#    'treated_pce': '18.03',
#    'treated_voc': '1.085',
#    'control_element': 'Spiro-OMeTAD',
#    'control_pce': '17.66',
#    'control_voc': '1.099'},
#   'performance_1': {'treated_pce': '18.09',
#    'treated_voc': '1.130',
#    'control_pce': '18.77',
#    'control_voc': '1.088'},
#   'performance_2': {'passivating_molecule': 'phenylethylammonium iodide',
#    'treated_pce': '18.01',
#    'treated_voc': '1.102',
#    'control_pce': '19.30',
#    'control_voc': '1.151'}},
#  '144': {'passivating_molecule': 'ethylenediammonium diiodide',
#   'additive_molecule': 'glycine hydrochloride',
#   'treated_pce': '23.6'},
#  '145': {'passivating_molecule': '4-fluoroaniline',
#   'treated_pce': '20.48',
#   'perovskite_composition': 'Cs0.05(MA0.17FA0.83)0.95Pb(I0.83Br0.17)3',
#   'control_pce': '17.8',
#   'control_voc': '1.02',
#   'treated_voc': '1.13',
#   'test_1': {'treatment_element': '4-fluoroaniline',
#    'efficiency_tret': '0.75',
#    'time': '95',
#    'efficiency_cont': '0.5',
#    'stability_type': 'ISOSLT'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '146': {'passivating_molecule': 'ortho-carborane',
#   'additive_molecule': 'phenylamino groups',
#   'test_1': {'efficiency_tret': '0.97',
#    'time': '400',
#    'treated_pce': '23.05',
#    'efficiency_cont': '0.89',
#    'humidity': '30',
#    'temperature': '40'},
#   'perovskite_composition': 'Cs0.05(MA0.05FA0.95)0.95Pb(I0.95Br0.05)3',
#   'treated_voc': '1.170'},
#  '147': {'passivating_molecule': 'carbazole-triphenylamine and phenylammonium iodide units',
#   'test_2': {'treatment_element': 'carbazole-triphenylamine and phenylammonium iodide units',
#    'treated_pce': '24.7',
#    'efficiency_tret': '0.946',
#    'time': '1100',
#    'stability_type': 'ISOSLT',
#    'efficiency_cont': '0.666'},
#   'test_1': {'efficiency_tret': '0.923',
#    'time': '1000',
#    'stability_type': 'ISOSD',
#    'temperature': '85',
#    'humidity': '85'},
#   'treated_voc': ['1.161', '1,112'],
#   'control_pce': '22.3',
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'formamidinium lead iodide',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '148': {'test_1': {'humidity': '50-70',
#    'passivating_molecule': 'phenylethylammonium iodide',
#    'efficiency_tret': '0.95',
#    'time': '500',
#    'stability_type': 'ISOSLT',
#    'treated_pce': '0.84',
#    'efficiency_cont': '0.7'},
#   'performance_1': {'treated_pce': '23.5',
#    'treated_voc': '1.142',
#    'control_voc': '1.091',
#    'control_pce': '21.2',
#    'passivating_molecule': '4-tert-butyl-benzylammonium iodide'},
#   'perovskite_composition': 'Cs0.05FA0.85MA0.10Pb(I0.97Br0.03)3',
#   'structure_pin_nip': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_2': {'treated_voc': '1.122', 'treated_pce': '22.7'}},
#  '149': {'electron_transport_layer': 'buckminsterfullerene',
#   'passivating_molecule': ['4-trifluoromethyl-phenylammonium',
#    'phenethylammonium',
#    'phenylammonium'],
#   'test_1': {'passivating_molecule': '4-trifluoromethyl-phenylammonium',
#    'treated_pce': '26.4',
#    'efficiency_tret': '0.9',
#    'time': '600',
#    'stability_type': 'ISOSLT',
#    'humidity': '30-50',
#    'temperature': '35'},
#   'perovskite_composition': 'FA0.7MA0.3Pb0.5Sn0.5I3'},
#  '2': {'perovskite_composition': 'dibutylammonium lead iodide',
#   'treated_voc': '1.185',
#   'treated_pce': '24.35',
#   'test_1': {'efficiency_tret': '0.973',
#    'time': '1083',
#    'stability_type': 'ISOSD',
#    'temperature': '25',
#    'humidity': '85',
#    'treatment_element': 'SIG-2D',
#    'control_element': 'unencapsulated',
#    'efficiency_cont': '0.586',
#    'treated_pce': '21.34'},
#   'test_2': {'efficiency_tret': '0.98',
#    'time': '1620',
#    'treatment_element': 'SIG',
#    'stability_type': 'ISOSLT',
#    'temperature': '25',
#    'treated_pce': '24.06'},
#   'structure_pin_nip': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'control_pce': ['22.39', '>'],
#   'treatment_element': 'SIG60',
#   'stability_type': 'ISOSL',
#   'efficiency_tret': '1',
#   'time': '7000',
#   'passivating_molecule': 'butylamine',
#   'electron_transport_layer': 'tin dioxide'},
#  '3': {'test_1': {'treated_pce': '24.5',
#    'treated_voc': '1.20',
#    'treatment_element': 'BA2MA2Pb3I10',
#    'stability_type': 'ISOSL1',
#    'efficiency_tret': '0.99',
#    'time': '2000',
#    'efficiency_cont': '0.25'},
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'Cs0.05(MA0.10FA0.85)Pb(I0.90Br0.10)3',
#   'electron_transport_layer': 'tin dioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '4': {'additive_molecule': '4vinylbenzylammonium bromide',
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'tin dioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': '(MAPbBr3)0.05(FAPbI3)0.95'}}

# %% [markdown]
# ## Retrieving LLama Prediction

# %%
import json

# Path to your JSON file
file_path = '../data/deepseek_5_progressive.json'

# Open and load the JSON file
with open(file_path, 'r') as file:
    llama_data = json.load(file)

# Print the data to verify
print(llama_data)
print(f"There are {len(llama_data)} papers that llama evaluated")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 7
#       4 file_path = '../data/deepseek_5_progressive.json'
#       6 # Open and load the JSON file
# ----> 7 with open(file_path, 'r') as file:
#       8     llama_data = json.load(file)
#      10 # Print the data to verify
#
# File c:\Users\Luna\anaconda3\envs\dsc80\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/deepseek_5_progressive.json'

# %% [markdown]
# ### Clean Llama predictoin to get rid of key with None and 'Not mentioned' value

# %%
# Recursive function to clean the JSON
def clean_json(obj):
    if isinstance(obj, dict):
        # Recursively process dictionary
        return {
            key: clean_json(value)
            for key, value in obj.items()
            if value not in ['None', None, "Not mentioned"]
        }
    elif isinstance(obj, list):
        # Recursively process list
        return [clean_json(item) for item in obj if item not in ['None', None, "Not mentioned"]]
    else:
        # Return the value as is
        return obj

# %%
filtered_llama_data = clean_json(llama_data)
filtered_llama_data
# Out:
# {'103': {'control_pce': 14.44,
#   'control_voc': 0.926,
#   'treated_pce': 23.7,
#   'treated_voc': 1.47,
#   'passivating_molecule': 'Methylenediammonium chloride (MDACl2)',
#   'perovskite_composition': 'FAPbI3 with 3.8 mol% MDACl2',
#   'electron_transport_layer': 'TiO2 (mesoporous)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuPC',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 600,
#     'humidity': '20-30%',
#     'control_efficiency': 14.44,
#     'treatment_efficiency': 23.7}]},
#  '77': {'control_pce': '21.2',
#   'control_voc': '1.07',
#   'treated_pce': '24.1',
#   'treated_voc': '1.14',
#   'passivating_molecule': 'PEAMAI',
#   'perovskite_composition': 'FA 0.9 Cs 0.1 PbI 3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '55',
#     'time': '800',
#     'humidity': 'N/A',
#     'control_efficiency': '90',
#     'treatment_efficiency': '90'},
#    {'test_name': 'ISOS-E',
#     'temperature': '85',
#     'time': '1500',
#     'humidity': 'N/A',
#     'control_efficiency': '20',
#     'treatment_efficiency': '90'}]},
#  '104': {'treated_pce': '25.2',
#   'treated_voc': '1196',
#   'passivating_molecule': 'methylammonium bromide (MAPbBr3)',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1I',
#     'temperature': '45',
#     'time': '3600',
#     'humidity': 'ambient',
#     'control_efficiency': '25.2',
#     'treatment_efficiency': '25.2'}]},
#  '79': {'control_pce': 19.9,
#   'control_voc': 1.09,
#   'treated_pce': 19.9,
#   'treated_voc': 1.09,
#   'passivating_molecule': 'PbI2',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '40 days',
#     'humidity': 'dry air',
#     'control_efficiency': 19.9,
#     'treatment_efficiency': 19.9}]},
#  '138': {'control_pce': 24.6,
#   'treated_pce': 25.3,
#   'passivating_molecule': '2PACz and 3-MPA',
#   'perovskite_composition': 'Cs0.05MA0.10FA0.85PbI3',
#   'electron_transport_layer': 'FTO',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': 65,
#     'time': 1000,
#     'humidity': '50% RH',
#     'control_efficiency': 24.6,
#     'treatment_efficiency': 24.8}]},
#  '144': {'control_pce': 19.3,
#   'control_voc': 0.76,
#   'treated_pce': 21.0,
#   'treated_voc': 0.88,
#   'passivating_molecule': 'GlyHCl',
#   'perovskite_composition': 'Cs0.1FA0.6MA0.3Sn0.5Pb0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': '100 days',
#     'humidity': 'controlled (glovebox)',
#     'control_efficiency': 19.3,
#     'treatment_efficiency': 21.0}]},
#  '37': {'control_pce': 0.19,
#   'control_voc': 1.35,
#   'treated_pce': 0.263,
#   'treated_voc': 2.19,
#   'passivating_molecule': '1,3-propanediammonium iodide',
#   'perovskite_composition': 'Cs0.2FA0.8Pb(I0.6Br0.4)3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient air',
#     'control_efficiency': 0.19,
#     'treatment_efficiency': 0.263},
#    {'test_name': 'ISOS-LT',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient air',
#     'control_efficiency': 0.19,
#     'treatment_efficiency': 0.263}]},
#  '143': {'control_pce': '18.09',
#   'control_voc': '1.16',
#   'treated_pce': '18.09',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'CuSCN',
#   'perovskite_composition': '(FAPbI3)0.77 (MAPbBr3)0.14 (CsPbI3)0.09',
#   'electron_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuSCN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '400 days',
#     'humidity': '40-70%',
#     'control_efficiency': '18.09',
#     'treatment_efficiency': '18.09'}]},
#  '30': {'control_pce': 10.92,
#   'control_voc': 1.16,
#   'treated_pce': 23.21,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'NH3',
#   'perovskite_composition': 'FACsPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'PTAB',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21},
#    {'test_name': 'ISOS-L',
#     'temperature': 100,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21},
#    {'test_name': 'ISOS-T',
#     'temperature': -15,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21}]},
#  '2': {'control_pce': 0.2239,
#   'control_voc': 1098,
#   'treated_pce': 0.2459,
#   'treated_voc': 1185,
#   'passivating_molecule': '(BA)2PbI4',
#   'perovskite_composition': '(BA)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1056,
#     'humidity': '85% relative humidity',
#     'control_efficiency': 0.2239,
#     'treatment_efficiency': 0.2435}]},
#  '93': {'treated_pce': 20.5,
#   'perovskite_composition': 'FA1-x MAx PbI2.87 Br0.13(Cl)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '131': {'control_pce': '25.5%',
#   'control_voc': '1.208 V',
#   'treated_pce': '25.5%',
#   'treated_voc': '1.208 V',
#   'passivating_molecule': 'Al2O3',
#   'perovskite_composition': '1.55 eV',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz/PTAA',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '85°C',
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '98%',
#     'treatment_efficiency': '20%'}]},
#  '42': {'control_pce': 19.52,
#   'control_voc': 1.07,
#   'treated_pce': 22.03,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'AzPbI3',
#   'perovskite_composition': 'Cs0.05 MA0.1 FA0.85 PbI2.7 Br0.3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 52,
#     'time': 1000,
#     'control_efficiency': 47,
#     'treatment_efficiency': 85}]},
#  '5': {'control_pce': 22.1,
#   'control_voc': 1135,
#   'treated_pce': 22.1,
#   'treated_voc': 1205,
#   'passivating_molecule': 'iso-BAI and n-BAI',
#   'perovskite_composition': 'FA(MA)PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '94': {'control_pce': '19.11',
#   'control_voc': '1.112',
#   'treated_pce': '20.6',
#   'treated_voc': '1.129',
#   'passivating_molecule': 'P4VP',
#   'perovskite_composition': 'Perovskite',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'P4VP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25-40 °C',
#     'time': '6000 h',
#     'humidity': '25-50% RH',
#     'control_efficiency': '19.11',
#     'treatment_efficiency': '20.6'}]},
#  '136': {'control_pce': '25.4',
#   'control_voc': '1.21',
#   'treated_pce': '23.4',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'MPA-CPA',
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'MPA-CPA',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '45',
#     'time': '500 hours',
#     'humidity': '30-40% RH',
#     'control_efficiency': '25.4',
#     'treatment_efficiency': '23.4'},
#    {'test_name': 'damp heat',
#     'temperature': '85',
#     'time': '500 hours',
#     'humidity': '85% RH',
#     'control_efficiency': '25.4',
#     'treatment_efficiency': '23.4'}]},
#  '45': {'control_pce': '25.1',
#   'treated_pce': '25.1',
#   'perovskite_composition': 'poly-Si/c-Si',
#   'electron_transport_layer': 'c-Si',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'p-poly-Si',
#   'stability_tests': []},
#  '39': {'control_pce': 20.7,
#   'control_voc': 1.09,
#   'treated_pce': 20.82,
#   'treated_voc': 1.193,
#   'passivating_molecule': '2-TMABr',
#   'perovskite_composition': '[ (FAPbI3)0.87 (MAPbBr3)0.13 ]0.92 (CsPbI3)0.08',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 25,
#     'time': 1000,
#     'humidity': 'inert atmosphere (Ar)',
#     'control_efficiency': 20.7,
#     'treatment_efficiency': 20.82}]},
#  '127': {'control_pce': 18.5,
#   'control_voc': 1.048,
#   'treated_pce': 24.1,
#   'treated_voc': 1.198,
#   'passivating_molecule': 'tris(2,4-di-tert-butylphenyl) phosphite (TPPi)',
#   'perovskite_composition': 'PEA2ZnX4 (X = Cl/I)',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'Standard thermal stability test',
#     'temperature': 85,
#     'time': '1009 hours',
#     'humidity': 'controlled environment',
#     'control_efficiency': 18.5,
#     'treatment_efficiency': 24.1}]},
#  '54': {'passivating_molecule': 'Methylammonium iodide or bromide',
#   'perovskite_composition': 'Mixed halide perovskite (e.g., MAPbI3, MAPbBr3)',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{}]},
#  '85': {'control_pce': 16,
#   'control_voc': 0.8,
#   'treated_pce': 22.7,
#   'treated_voc': 1.0,
#   'passivating_molecule': 'n-hexyl trimethyl ammonium bromide',
#   'perovskite_composition': 'FAPbI3:MAPbBr3:HTAB = 0.3:0.95:0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'P3HT',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1008,
#     'humidity': '85%',
#     'control_efficiency': 80,
#     'treatment_efficiency': 0}]},
#  '28': {'control_pce': 0.17,
#   'control_voc': 1.2,
#   'treated_pce': 0.17,
#   'treated_voc': 1.2,
#   'perovskite_composition': 'CsPbI3',
#   'electron_transport_layer': 'TPBi',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '120': {'control_pce': 23.0,
#   'control_voc': 1.13,
#   'treated_pce': 25.0,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'ferrocenyl-bis-thiophene-2-carboxylate',
#   'perovskite_composition': '(FA0.98MA0.02)0.95Cs0.05Pb(I0.95Br0.02)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'poly(triaryl amine)',
#   'stability_tests': [{'test_name': 'IEC61215:2016',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 72,
#     'treatment_efficiency': 98}]},
#  '53': {'control_pce': '4.9%',
#   'treated_pce': '24.7%',
#   'passivating_molecule': 'DMePDAI2',
#   'perovskite_composition': 'FA0.85MA0.1Cs0.05PbI2.9Br0.1',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': '40°C',
#     'time': '1000 hours',
#     'humidity': 'N2',
#     'control_efficiency': '20.5%',
#     'treatment_efficiency': '23.1%'}]},
#  '82': {'control_pce': '17.1',
#   'control_voc': '1.04',
#   'treated_pce': '20.59',
#   'treated_voc': '1.13',
#   'passivating_molecule': 'Choline chloride',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Humidity stability test',
#     'time': 'Over one month',
#     'humidity': '50-85% RH',
#     'control_efficiency': '17.1%',
#     'treatment_efficiency': '20.59%'}]},
#  '21': {'control_pce': 22.6,
#   'treated_pce': 19.14,
#   'passivating_molecule': 'LP layer',
#   'perovskite_composition': '3D perovskite',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient',
#     'control_efficiency': 22.6,
#     'treatment_efficiency': 19.14}]},
#  '129': {'control_pce': 24.8,
#   'control_voc': 1.19,
#   'treated_pce': 24.5,
#   'treated_voc': 1.19,
#   'passivating_molecule': 'GBAC',
#   'perovskite_composition': 'Cs0.06MA0.14FA0.80PbI3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'DC-PA',
#   'stability_tests': [{'test_name': 'JET certification',
#     'temperature': 65,
#     'time': 1200,
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': 24.5,
#     'treatment_efficiency': 24.5},
#    {'test_name': 'Thermal stability',
#     'temperature': 65,
#     'time': 1200,
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': 24.8,
#     'treatment_efficiency': 24.8}]},
#  '13': {'control_pce': 25.7,
#   'control_voc': 1.15,
#   'treated_pce': 15.1,
#   'treated_voc': 1.29,
#   'passivating_molecule': '2-thiopheneethylammonium chloride',
#   'perovskite_composition': 'Cs0.12FA0.8PbI1.8Br1.2',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': '2PACz',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 265,
#     'humidity': 'ambient',
#     'control_efficiency': 13.1,
#     'treatment_efficiency': 15.1}]},
#  '14': {'control_pce': 25.5,
#   'control_voc': 1.184,
#   'treated_pce': 23.7,
#   'treated_voc': 1.184,
#   'passivating_molecule': 'F-PEAI',
#   'perovskite_composition': 'Cs0.1FA0.9PbI2.9Br0.1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{}]},
#  '68': {'control_pce': 12.8,
#   'control_voc': 0.95,
#   'treated_pce': 12.8,
#   'treated_voc': 0.95,
#   'passivating_molecule': 'SnOx',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'AZO',
#   'stability_tests': [{'temperature': 60,
#     'time': 1000,
#     'humidity': 'ambient air',
#     'control_efficiency': 12.8,
#     'treatment_efficiency': 12.8}]},
#  '66': {'control_pce': 25.5,
#   'control_voc': 0.8,
#   'treated_pce': 45,
#   'treated_voc': 0.8,
#   'perovskite_composition': 'Cs0.15FA0.85PbI2.55Br0.45',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'damp heat',
#     'temperature': 85,
#     'time': 1000,
#     'humidity': '85% RH',
#     'control_efficiency': 25.5,
#     'treatment_efficiency': 45}]},
#  '115': {'control_pce': '24.04',
#   'control_voc': '0.08 cm²',
#   'treated_pce': '23.15',
#   'treated_voc': '23.15',
#   'passivating_molecule': 'anisole',
#   'perovskite_composition': 'FA1-x-yMAxCsyPbI3-zBrz',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '95%',
#     'treatment_efficiency': '75%'},
#    {'test_name': 'SPO',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '5%',
#     'treatment_efficiency': '20%'}]},
#  '61': {'passivating_molecule': 'butylamine',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'temperature': 85,
#     'time': '125 hours',
#     'humidity': 'N2 atmosphere'}]},
#  '112': {'control_pce': 21.8,
#   'control_voc': 1.14,
#   'treated_pce': 23.2,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Benzylhydrazine hydrochloride (BHC)',
#   'perovskite_composition': 'MA0.7FA0.3PbI3',
#   'electron_transport_layer': 'Poly[bis(4-phenyl)(2,4,6-trimethylphenyl)amine] (PTAA)',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'Indium tin oxide (ITO)',
#   'stability_tests': [{'test_name': 'Stability under AM 1.5G light',
#     'temperature': 65,
#     'time': '1000 hours',
#     'humidity': '60% ± 10%',
#     'control_efficiency': 19.2,
#     'treatment_efficiency': 23.2}]},
#  '4': {'control_pce': '19.93',
#   'control_voc': '1.06',
#   'treated_pce': '21.90',
#   'treated_voc': '1.14',
#   'passivating_molecule': '4-vinylbenzylammonium bromide (VBABr)',
#   'perovskite_composition': '[[(VBABr)₂ (FA₉₅MA₀₅)ₙ₋₁ Pb₃ₙ₊₁]',
#   'electron_transport_layer': 'SnO₂',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '95': {'treated_pce': 22.9,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'octylammonium iodide',
#   'perovskite_composition': 'FAPbI3·0.95 and MAPbBr3·0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 65,
#     'time': '100 hours',
#     'humidity': '65% RH',
#     'treatment_efficiency': 22.9},
#    {'test_name': 'ISOS-H',
#     'temperature': 85,
#     'time': '100 hours',
#     'humidity': '85% RH'}]},
#  '137': {'control_pce': 23.0,
#   'control_voc': 1.12,
#   'treated_pce': 25.5,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'PDAI2 and 3MTPAI',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.90PbI3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx/4PACz',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1600,
#     'humidity': 'Nitrogen',
#     'control_efficiency': 23.0,
#     'treatment_efficiency': 25.5},
#    {'test_name': 'ISOS-L',
#     'temperature': 65,
#     'time': 2000,
#     'humidity': 'Air with 50% RH',
#     'control_efficiency': 23.0,
#     'treatment_efficiency': 25.5}]},
#  '44': {'control_pce': 25.8,
#   'control_voc': 731,
#   'treated_pce': 21.12,
#   'perovskite_composition': 'SiOx',
#   'electron_transport_layer': 'n+ poly-Si',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'n+ poly-Si'},
#  '3': {'control_pce': 24.5,
#   'control_voc': 1.2,
#   'treated_pce': 24.5,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'BA2MA2Pb3I10',
#   'perovskite_composition': 'Cs0.05(MA0.10FA0.85)Pb(I0.90Br0.10)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': 55,
#     'time': 2000,
#     'humidity': '70% RH',
#     'control_efficiency': 21,
#     'treatment_efficiency': 22.93}]},
#  '92': {'treated_pce': 21.3,
#   'passivating_molecule': 'BaSnO3',
#   'perovskite_composition': 'BaSnO3',
#   'electron_transport_layer': 'BaSnO3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD, PTAA',
#   'stability_tests': [{'temperature': 25,
#     'time': '24 hours',
#     'humidity': '40% RH',
#     'control_efficiency': 21.3,
#     'treatment_efficiency': 21.7}]},
#  '130': {'control_pce': 22.9,
#   'control_voc': 1.1,
#   'treated_pce': 25.4,
#   'treated_voc': 1.15,
#   'passivating_molecule': 'Pentanamidine hydrochloride (PAD)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 30,
#     'time': '1000 h',
#     'humidity': 'ambient',
#     'control_efficiency': 22.9,
#     'treatment_efficiency': 25.4},
#    {'test_name': 'ISOS-L',
#     'temperature': 65,
#     'time': '500 h',
#     'humidity': '85% RH',
#     'control_efficiency': 22.9,
#     'treatment_efficiency': 25.4}]},
#  '43': {'control_pce': '24.50%',
#   'control_voc': '1.150 V',
#   'treated_pce': '24.50%',
#   'treated_voc': '1.121 V',
#   'passivating_molecule': 'Benzylamine hydroiodide (BAHI)',
#   'perovskite_composition': 'FA0.90MA0.10PbI3•(CsPbI3)0.05 with excess PbI2',
#   'electron_transport_layer': 'TiO2 (mesoporous)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '80 °C',
#     'time': '500 h',
#     'humidity': '20-30% RH',
#     'control_efficiency': '24.50%',
#     'treatment_efficiency': '47.96 ± 3.21%'}]},
#  '142': {'control_pce': 13.15,
#   'treated_pce': 16.13,
#   'passivating_molecule': 'formamidinium iodide (FAI)',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Modified BA2MA(n)Pb(n+1)I3n+1',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 65,
#     'time': '50 days',
#     'humidity': '65%',
#     'control_efficiency': 71},
#    {'test_name': 'ISOS-T',
#     'temperature': 85,
#     'time': '30 days',
#     'control_efficiency': 74},
#    {'test_name': 'ISOS-L', 'time': '24 hours', 'control_efficiency': 90}]},
#  '31': {'control_pce': 23.39,
#   'control_voc': 1.12,
#   'treated_pce': 25.49,
#   'treated_voc': 1.19,
#   'passivating_molecule': '3-aminomethyl pyridine (3-APy)',
#   'perovskite_composition': 'Rb0.05 Cs0.05 MA0.05 FA0.85 PbI0.95 Br0.05',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '850 hours',
#     'humidity': '85% relative humidity',
#     'control_efficiency': '22.85%',
#     'treatment_efficiency': '25.35%'},
#    {'test_name': 'ISOS-L',
#     'temperature': 55,
#     'time': '2,400 hours',
#     'humidity': 'air',
#     'control_efficiency': '22.3%',
#     'treatment_efficiency': '24.6%'},
#    {'test_name': 'ISOS-T'}]},
#  '139': {'control_pce': 25.2,
#   'control_voc': 1.145,
#   'treated_pce': 26.1,
#   'treated_voc': 1.164,
#   'passivating_molecule': '1-(phenylsulfonyl)pyrrole',
#   'perovskite_composition': 'FA0.95Cs0.05PbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '2500h',
#     'humidity': '85%RH',
#     'control_efficiency': 80,
#     'treatment_efficiency': 92}]},
#  '145': {'control_pce': 17.08,
#   'control_voc': 1.02,
#   'treated_pce': 20.48,
#   'treated_voc': 1.13,
#   'passivating_molecule': '4-fluoroaniline (FAL)',
#   'perovskite_composition': 'Cs0.05(MA0.17FA0.83)0.95PbI0.83Br0.17',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 66,
#     'humidity': '85-95% RH',
#     'control_efficiency': 17.08,
#     'treatment_efficiency': 20.48},
#    {'test_name': 'ISOS-L',
#     'temperature': 85,
#     'time': 100,
#     'humidity': '85% RH'}]},
#  '36': {'control_pce': '20%',
#   'control_voc': '0.23 V',
#   'treated_pce': '19.6%',
#   'treated_voc': '0.19 V',
#   'passivating_molecule': 'C60',
#   'perovskite_composition': 'Cs0.05(FA0.83MA0.17)0.95Pb(I0.83Br0.17)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'pin',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '-20°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'},
#    {'test_name': 'ISOS-L',
#     'temperature': '80°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'},
#    {'test_name': 'ISOS-T',
#     'temperature': '-10°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'}]},
#  '78': {'control_voc': 1.06,
#   'treated_pce': 20.2,
#   'treated_voc': 1.06,
#   'passivating_molecule': 'DMSO',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '76': {'perovskite_composition': '2D lead halide perovskites',
#   'electron_transport_layer': 'organic spacer ligands',
#   'pin_nip_structure': '2D',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 140,
#     'time': '60 min',
#     'humidity': 'dry'},
#    {'test_name': 'ISOS-L',
#     'temperature': 23,
#     'time': 'room temperature',
#     'humidity': 'dry'}]},
#  '105': {'control_pce': '21.65%',
#   'control_voc': '1.172 V',
#   'treated_pce': '23.33%',
#   'treated_voc': '1.193 V',
#   'passivating_molecule': 'PMMA:PCBM',
#   'perovskite_composition': 'TiOxNy',
#   'electron_transport_layer': 'TiOxNy',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'P3HT:CuPc',
#   'stability_tests': [{'test_name': 'damp-heat',
#     'temperature': '85',
#     'time': '1000 hours',
#     'humidity': '85% relative humidity',
#     'control_efficiency': '96.5%',
#     'treatment_efficiency': '98.7%'}]},
#  '71': {'control_pce': 5,
#   'control_voc': 0.05,
#   'treated_pce': 15.3,
#   'treated_voc': 1.7,
#   'passivating_molecule': '(BA)2(MA)3Pb4I13',
#   'perovskite_composition': '(BA)2(MA)3Pb4I13',
#   'electron_transport_layer': 'BA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 260},
#    {'test_name': 'ISOS-L', 'temperature': 240}]},
#  '102': {'control_pce': 17.87,
#   'control_voc': 1.05,
#   'treated_pce': 21.07,
#   'treated_voc': 1.12,
#   'passivating_molecule': 'MACl',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{}]},
#  '113': {'treated_pce': 25.8,
#   'treated_voc': 1.1885,
#   'passivating_molecule': 'FASnCl x',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1I',
#     'temperature': 25,
#     'time': 500,
#     'control_efficiency': 25.5,
#     'treatment_efficiency': 25.8}]},
#  '67': {'passivating_molecule': 'formamidinium (FA)',
#   'perovskite_composition': 'FAPbI3 and CsPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L1',
#     'temperature': 298,
#     'time': '1000 hours',
#     'humidity': '25% RH'},
#    {'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH'},
#    {'test_name': 'ISOS-L2',
#     'temperature': 65,
#     'time': '1000 hours',
#     'humidity': '60% RH'},
#    {'test_name': 'ISOS-L3',
#     'temperature': 110,
#     'time': '2000 hours',
#     'humidity': 'unknown'}]},
#  '114': {'control_pce': 20.76,
#   'control_voc': 1.06,
#   'treated_pce': 23.37,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Piperazinium iodide (PI)',
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': []},
#  '15': {'control_pce': '21.78',
#   'control_voc': '1.11',
#   'treated_pce': '23.34',
#   'treated_voc': '1.15',
#   'passivating_molecule': 'Cl-PEAI and F-PEAI',
#   'perovskite_composition': 'Cs0.05(FA5/6MA1/6)0.95PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'temperature': '300'}]},
#  '69': {'passivating_molecule': 'SnOx',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'Al:ZnO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PEDOT:PSS',
#   'stability_tests': [{'temperature': 25, 'humidity': '60% RH'},
#    {'temperature': 60}]},
#  '12': {'control_pce': 16.7,
#   'control_voc': 1.23,
#   'treated_pce': 19.4,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylammonium bromide (BABr)',
#   'perovskite_composition': 'Cs0.17 FA0.83 Pb(I0.6 Br0.4)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'J-V measurements',
#     'temperature': 25,
#     'time': 'continuous illumination',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4},
#    {'test_name': 'PCE under different treatments',
#     'temperature': 25,
#     'time': 'under constant voltage',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4}]},
#  '128': {'control_pce': '24.6',
#   'control_voc': '1.16',
#   'treated_pce': '25.12',
#   'treated_voc': '1.165',
#   'passivating_molecule': '2-aminoindan hydrochloride (AICl)',
#   'perovskite_composition': 'Cs0.05FA0.95PbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '85',
#     'time': '1200 hours',
#     'humidity': '85% RH',
#     'control_efficiency': '24.32',
#     'treatment_efficiency': '24.58'},
#    {'test_name': 'ISOS-D',
#     'temperature': '55',
#     'time': '1500 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '21.73',
#     'treatment_efficiency': '24.42'}]},
#  '27': {'control_pce': '14.4',
#   'control_voc': '1.01',
#   'treated_pce': '18.5',
#   'treated_voc': '1.23',
#   'passivating_molecule': 'CF3-PEA',
#   'perovskite_composition': 'CsPbI3-xBrx',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '25',
#     'time': '1000',
#     'humidity': 'ambient',
#     'control_efficiency': '14.4',
#     'treatment_efficiency': '18.5'}]},
#  '20': {'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'MAPbI3, (PEA)2PbI4',
#   'electron_transport_layer': 'PMMA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{}]},
#  '121': {'control_pce': '26.08',
#   'treated_pce': '25.73',
#   'passivating_molecule': 'formamidinium lead iodide (FAPbI3)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'temperature': '60-80 °C',
#     'time': '40 min',
#     'humidity': 'controlled',
#     'control_efficiency': '26.08%',
#     'treatment_efficiency': '25.73%'}]},
#  '52': {'control_pce': '19.1%',
#   'control_voc': '658.4 mV',
#   'passivating_molecule': 'Al2O3',
#   'perovskite_composition': 'CH3NH3Pb',
#   'electron_transport_layer': 'Al-BSF',
#   'pin_nip_structure': 'PERC',
#   'hole_transport_layer': 'Al-BSF'},
#  '83': {'control_pce': '21.3',
#   'control_voc': '1.13',
#   'treated_pce': '21.38',
#   'treated_voc': '1.12',
#   'passivating_molecule': 'MAI and FA',
#   'perovskite_composition': 'MAPbI3 and FA0.15MA0.85PbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '792 hours',
#     'humidity': '40 ± 10%',
#     'control_efficiency': '21.3',
#     'treatment_efficiency': '21.38'}]},
#  '126': {'control_pce': 23.43,
#   'control_voc': 1.16,
#   'treated_pce': 25.39,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'PbC2O4',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': 550,
#     'humidity': 'ambient air',
#     'control_efficiency': 92,
#     'treatment_efficiency': 92}]},
#  '55': {'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'},
#    {'test_name': 'ISOS-L',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'}]},
#  '84': {'control_pce': 21.6,
#   'control_voc': 1.24,
#   'treated_pce': 23.2,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'DM',
#   'perovskite_composition': '(FAPbI3)0.95 (MAPbBr3)0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'DM',
#   'stability_tests': [{'test_name': 'thermal stability test',
#     'temperature': 60,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 70,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 80,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3}]},
#  '29': {'passivating_molecule': 'butylamine',
#   'perovskite_composition': 'PbI2-based',
#   'electron_transport_layer': 'linear PEI',
#   'stability_tests': []},
#  '18': {'control_pce': '26%',
#   'passivating_molecule': 'TMAI',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'SnO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'lower'},
#    {'test_name': 'ISOS-L',
#     'temperature': 100,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'higher'}]},
#  '117': {'control_pce': 22.2,
#   'control_voc': 1.15,
#   'treated_pce': 25.1,
#   'treated_voc': 1.17,
#   'passivating_molecule': '4-tert-butyl-1-methylpyridinium bis(trifluoromethanesulfonyl)imide (TBMP + TFSI -)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Stability test',
#     'temperature': '70 ± 5% RH',
#     'time': 'Long-term exposure',
#     'humidity': 'High relative humidity',
#     'control_efficiency': '22.2%',
#     'treatment_efficiency': '25.1%'}]},
#  '64': {'control_pce': 18.6,
#   'control_voc': 1057,
#   'treated_pce': 17.0,
#   'treated_voc': 1062,
#   'passivating_molecule': 'PEA2PbI4',
#   'perovskite_composition': 'Both MAPI and PEA2PbI4',
#   'electron_transport_layer': 'MoO3 and TATM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60'},
#  '110': {'control_pce': '23.92',
#   'control_voc': '1.15',
#   'treated_pce': '25.6',
#   'treated_voc': '1.21',
#   'passivating_molecule': 'formate',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'm-TiO2',
#   'stability_tests': [{'test_name': 'stability tests',
#     'temperature': '25 °C',
#     'time': '1000 h',
#     'humidity': '20% relative humidity',
#     'control_efficiency': '23.92',
#     'treatment_efficiency': '25.6'}]},
#  '11': {'control_pce': '20.2',
#   'control_voc': '1.11',
#   'treated_pce': '21.8',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'BTaBr',
#   'perovskite_composition': '(BTa)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '24 hours',
#     'humidity': 'ambient air',
#     'control_efficiency': '21.8',
#     'treatment_efficiency': '21.8'}]},
#  '16': {'control_pce': 18.87,
#   'control_voc': 1.04,
#   'treated_pce': 21.05,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'CF3PEAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '119': {'control_pce': 20.5,
#   'control_voc': 1.09,
#   'treated_pce': 23.9,
#   'treated_voc': 1.15,
#   'passivating_molecule': '1,1,2,2,3,3-hexafluoropropane-1,3-disulfonimide',
#   'perovskite_composition': 'formamidinium-based perovskite',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'HFDF',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 200,
#     'humidity': 'Not specified',
#     'control_efficiency': 23.9,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'ISOS-L',
#     'temperature': 85,
#     'time': 1000,
#     'humidity': 'Not specified',
#     'control_efficiency': 20.5,
#     'treatment_efficiency': 21.2}]},
#  '23': {'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'Cs0.05MA0.1FA0.85PbI3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L3',
#     'temperature': '65°C',
#     'time': '500 hours',
#     'humidity': 'Not explicitly mentioned',
#     'control_efficiency': '23.91%',
#     'treatment_efficiency': '92% of initial PCE'}]},
#  '58': {'control_pce': '25.5%',
#   'treated_pce': '18.5%',
#   'passivating_molecule': 'PCBM',
#   'perovskite_composition': 'FA0.83Cs0.17PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'poly-TPD or NiOx',
#   'stability_tests': [{}]},
#  '89': {'treated_pce': '20.87%',
#   'treated_voc': '413 mV',
#   'passivating_molecule': 'formamidine acetate (FAAc)',
#   'perovskite_composition': '(FA, MA, Cs)Pb(I, Br)3'},
#  '24': {'control_pce': '14.9',
#   'treated_pce': '17.4',
#   'passivating_molecule': 'Cs2PbI2Cl2',
#   'perovskite_composition': 'CsPbI3',
#   'electron_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuSCN',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 110,
#     'time': 2100,
#     'control_efficiency': 14.9,
#     'treatment_efficiency': 17.4}]},
#  '56': {'control_pce': 25.5,
#   'control_voc': 1.22,
#   'treated_pce': 20.5,
#   'treated_voc': 1.22,
#   'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{}]},
#  '125': {'control_pce': '91%',
#   'control_voc': '1.14 V',
#   'treated_pce': '23.7%',
#   'treated_voc': '1.14 V',
#   'passivating_molecule': 'Selenophene',
#   'perovskite_composition': 'FA0.9Cs0.1PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85°C',
#     'time': '3190 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '91%',
#     'treatment_efficiency': '91%'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '1000 hours',
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': '45°C',
#     'time': '500 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '80%',
#     'treatment_efficiency': '80%'}]},
#  '87': {'treated_pce': 21.52,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'FAI',
#   'perovskite_composition': 'CsI:20 mg, PbI2:530 mg, PbBr2:20 mg, PbCl2:20 mg, MAI:5 mg',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'temperature': 85,
#     'time': 1500,
#     'control_efficiency': 100,
#     'treatment_efficiency': 89}]},
#  '51': {'control_pce': '25%',
#   'treated_pce': '2x',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN'},
#  '122': {'control_pce': 25.6,
#   'control_voc': 1.182,
#   'treated_pce': 25.6,
#   'treated_voc': 1.182,
#   'passivating_molecule': '(PbI2)2RbCl',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'thermal stability test',
#     'temperature': 85,
#     'time': 500,
#     'humidity': 'Unknown',
#     'control_efficiency': 80,
#     'treatment_efficiency': 96}]},
#  '80': {'control_pce': 21.6,
#   'control_voc': 1.14,
#   'treated_pce': 21.6,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'PMMA',
#   'perovskite_composition': 'Mixed cation perovskite (FAI, PbI2, MABr, PbBr2)',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': '2 months',
#     'humidity': 'ambient air',
#     'control_efficiency': 21.0,
#     'treatment_efficiency': 21.0}]},
#  '0': {'control_pce': '25.5',
#   'control_voc': '1.17',
#   'treated_pce': '24.7',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'formamidinium lead triiodide (FAPbI3)',
#   'electron_transport_layer': 'Cs2O',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '1500',
#     'humidity': '50',
#     'control_efficiency': '19.9',
#     'treatment_efficiency': '95'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65',
#     'time': '1200',
#     'humidity': '50',
#     'control_efficiency': '23.2',
#     'treatment_efficiency': '91'}]},
#  '91': {'control_pce': '19.66',
#   'control_voc': '1.027',
#   'treated_pce': '24.02',
#   'treated_voc': '1.130',
#   'passivating_molecule': 'methylammonium chloride (MACl)',
#   'perovskite_composition': 'formamidinium lead iodide (FAPbI3)',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '1200 hours',
#     'humidity': 'Room temperature',
#     'control_efficiency': '90',
#     'treatment_efficiency': '90'},
#    {'test_name': 'ISOS-L',
#     'temperature': 40,
#     'time': '300 hours',
#     'humidity': '40°C',
#     'control_efficiency': '60',
#     'treatment_efficiency': '90'}]},
#  '40': {'control_pce': 24.3,
#   'control_voc': 1.2,
#   'treated_pce': 24.3,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'Oleylammonium iodide (OLAI)',
#   'perovskite_composition': 'Cs0.03(FA0.90MA0.10)PbI3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'damp-heat',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 24.3,
#     'treatment_efficiency': 19.3}]},
#  '133': {'control_pce': '22.34%',
#   'control_voc': '1.14 V',
#   'treated_pce': '24.04%',
#   'treated_voc': '1.19 V',
#   'passivating_molecule': 'Sodium thioglycolate',
#   'perovskite_composition': 'FA0.75MA0.25PbI3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '25 °C',
#     'time': '900 hours',
#     'humidity': 'controlled',
#     'control_efficiency': '22.34%',
#     'treatment_efficiency': '24.04%'},
#    {'test_name': 'AM1.5G',
#     'temperature': '25 °C',
#     'time': '800 hours',
#     'humidity': 'controlled',
#     'control_efficiency': '22.25%',
#     'treatment_efficiency': '23.5%'}]},
#  '7': {'control_pce': 23.5,
#   'control_voc': 1.2,
#   'treated_pce': 28.7,
#   'treated_voc': 1.5,
#   'passivating_molecule': '4-FPEA',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Au',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '24 hours',
#     'humidity': '50% RH',
#     'control_efficiency': 22.5,
#     'treatment_efficiency': 28.7},
#    {'test_name': 'ISOS-L',
#     'temperature': 60,
#     'time': '48 hours',
#     'humidity': '30% RH',
#     'control_efficiency': 23.5,
#     'treatment_efficiency': 28.7}]},
#  '96': {'control_pce': 22.19,
#   'control_voc': 1.13,
#   'treated_pce': 16.7,
#   'passivating_molecule': 'tin(II) acetylacetonate',
#   'perovskite_composition': 'lead halide perovskite',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 160,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 200,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 220,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 350,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7}]},
#  '47': {'treated_pce': 21.1,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'PbSO4',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 65,
#     'time': '1200 hours',
#     'humidity': 'air, RH ~60%',
#     'control_efficiency': 21.1,
#     'treatment_efficiency': 96.8}]},
#  '134': {'control_pce': 23.13,
#   'control_voc': 1.141,
#   'treated_pce': 25.08,
#   'treated_voc': 1.174,
#   'passivating_molecule': 'Guanabenz acetate salt',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Moisture stability test',
#     'temperature': 55,
#     'time': '24 hours',
#     'humidity': '55% RH',
#     'control_efficiency': 23.13,
#     'treatment_efficiency': 25.32},
#    {'test_name': 'Damp heat test',
#     'temperature': 85,
#     'time': '300 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 23.13,
#     'treatment_efficiency': 25.08}]},
#  '148': {'control_pce': 20.1,
#   'control_voc': 1.077,
#   'treated_pce': 23.5,
#   'treated_voc': 1.142,
#   'passivating_molecule': '4-tert-butylbenzylammonium iodide (tBBAI)',
#   'perovskite_composition': 'Cs0.05FA0.85MA0.10PbI0.97Br0.03',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 50,
#     'time': '500 hours',
#     'humidity': '50-70% RH',
#     'control_efficiency': 20.1,
#     'treatment_efficiency': 23.5}]},
#  '9': {'control_pce': 14.64,
#   'treated_pce': 17.6,
#   'passivating_molecule': 'C8',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'NiOx'},
#  '98': {'control_pce': '24.2',
#   'control_voc': '1.28',
#   'treated_pce': '21.54',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'FN-Br',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'MPP under 1-sun illumination',
#     'temperature': '25',
#     'time': '500',
#     'humidity': 'Ambient air',
#     'control_efficiency': '21.54',
#     'treatment_efficiency': '20.24'}]},
#  '49': {'control_pce': '13.81',
#   'control_voc': '1.12',
#   'treated_pce': '16.25',
#   'treated_voc': '1.31',
#   'passivating_molecule': 'n-butylamine acetate (BAAc)',
#   'perovskite_composition': '(BA)2(MA)n-1Pb3n+1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '558',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '13.81',
#     'treatment_efficiency': '16.25'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65 ± 10%',
#     'time': '4680',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '49.4',
#     'treatment_efficiency': '93.8'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '85',
#     'time': '1100',
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': '70.8',
#     'treatment_efficiency': '96.2'}]},
#  '35': {'perovskite_composition': 'CsPbI3_0.05(FAPbI3_0.83MAPbBr3_0.17)_0.95',
#   'electron_transport_layer': 'C60, PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PEDOT:PSS, PC61BM',
#   'stability_tests': []},
#  '146': {'control_pce': 21.5,
#   'control_voc': 1.128,
#   'treated_pce': 23.04,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'CB-NH2',
#   'perovskite_composition': 'Cs0.05FA0.95PbI0.95Br0.05',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
# ...
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 100,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6},
#    {'test_name': 'ISOS-LT',
#     'temperature': 60,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6}]},
#  '59': {'control_pce': '19.07',
#   'control_voc': '1.25',
#   'treated_pce': '19.07',
#   'treated_voc': '1.25',
#   'passivating_molecule': 'phenethylammonium iodide',
#   'perovskite_composition': 'FA0.8Cs0.2PbI0.7Br0.3',
#   'electron_transport_layer': 'poly(triarylamine)',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{}]},
#  '88': {'control_pce': 19.03,
#   'control_voc': 0.92,
#   'treated_pce': 21.46,
#   'treated_voc': 0.94,
#   'passivating_molecule': 'NaF',
#   'perovskite_composition': 'Cs0.05FA0.54MA0.41PbI0.98Br0.02)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1000,
#     'control_efficiency': 19.03,
#     'treatment_efficiency': 21.46}]},
#  '25': {'passivating_molecule': 'formamidinium',
#   'perovskite_composition': 'FAPbI3, FAPbBr3',
#   'stability_tests': []},
#  '22': {'control_pce': 25.5,
#   'control_voc': 1.092,
#   'treated_pce': 24.0,
#   'treated_voc': 1.154,
#   'passivating_molecule': 'Cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PCBM',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 50,
#     'time': 500,
#     'humidity': '40 ± 10%',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 93},
#    {'test_name': 'ISOS-L',
#     'temperature': 50,
#     'time': 500,
#     'humidity': '40 ± 10%',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 93}]},
#  '17': {'control_pce': 25.2,
#   'control_voc': 1.16,
#   'treated_pce': 22.02,
#   'treated_voc': 1.19,
#   'passivating_molecule': 'hexyltrimethylammonium bromide',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': '1F-PTAA',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': '1F-PTAA',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '90 min',
#     'humidity': 'N2-filled glove-box',
#     'control_efficiency': 20.04,
#     'treatment_efficiency': 22.16}]},
#  '118': {'control_pce': 0.1961,
#   'control_voc': 1.16,
#   'treated_pce': 0.2154,
#   'treated_voc': 1.24,
#   'passivating_molecule': 'n-Butylammonium bromide (BABr)',
#   'perovskite_composition': '1.63 eV bandgap system (RbCsMAFA)',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 35,
#     'time': '24 h',
#     'humidity': '20-30% RH',
#     'control_efficiency': 0.1961,
#     'treatment_efficiency': 0.2154},
#    {'test_name': 'ISOS-L',
#     'temperature': 60,
#     'time': '500 h',
#     'humidity': '30-40% RH',
#     'control_efficiency': 0.1961,
#     'treatment_efficiency': 0.2154}]},
#  '10': {'treated_pce': 24.41,
#   'treated_voc': 4.77,
#   'passivating_molecule': 'OATsO',
#   'perovskite_composition': '(FAPbI3)0.95((MAPbBr3)0.05)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'test_name': 'OC',
#     'temperature': 40,
#     'time': '1,000 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41},
#    {'test_name': 'MPP',
#     'temperature': 40,
#     'time': '800 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41}]},
#  '111': {'treated_pce': 23.9,
#   'treated_voc': 0.68,
#   'passivating_molecule': 'isopropylammonium chloride',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-MeOTAD',
#   'stability_tests': [{}]},
#  '62': {'control_pce': 17.3,
#   'control_voc': 1.01,
#   'treated_pce': 16.5,
#   'treated_voc': 1.02,
#   'passivating_molecule': 'BAI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 55,
#     'time': '30 days',
#     'humidity': '55% RH',
#     'control_efficiency': 44,
#     'treatment_efficiency': 83},
#    {'test_name': 'ISOS-L',
#     'temperature': 80,
#     'time': '30 days',
#     'humidity': '80°C',
#     'control_efficiency': 27,
#     'treatment_efficiency': 73}]},
#  '19': {'treated_pce': 24.09,
#   'passivating_molecule': '3FPEA',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.9Pb(I0.95Br0.05)3',
#   'electron_transport_layer': '2PACz',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': 85,
#     'time': 1560,
#     'humidity': '50% RH',
#     'treatment_efficiency': 24.09}]},
#  '116': {'control_pce': 23.44,
#   'control_voc': 1.152,
#   'treated_pce': 24.82,
#   'treated_voc': 1.1814,
#   'passivating_molecule': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': 500,
#     'control_efficiency': 13.74,
#     'treatment_efficiency': 87}]},
#  '65': {'control_pce': 4.73,
#   'control_voc': 1.18,
#   'treated_pce': 4.73,
#   'treated_voc': 1.18,
#   'passivating_molecule': '(PEA)2(MA)2[Pb3I10]',
#   'perovskite_composition': '(PEA)2(MA)2[Pb3I10]',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '52',
#     'time': '40 days',
#     'humidity': '52% relative humidity',
#     'control_efficiency': 4.73,
#     'treatment_efficiency': 4.73}]},
#  '107': {'treated_pce': 21.25,
#   'passivating_molecule': 'SF-PEA',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 1000,
#     'time': '1000',
#     'humidity': '50-60%',
#     'treatment_efficiency': 0.91}]},
#  '74': {'control_pce': 21.2,
#   'control_voc': 1.13,
#   'passivating_molecule': 'CLP',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 4390,
#     'humidity': 'N2',
#     'control_efficiency': 21.2,
#     'treatment_efficiency': 21.2}]},
#  '100': {'control_pce': '23.24',
#   'control_voc': '1.17',
#   'treated_pce': '22.54',
#   'treated_voc': '1.16',
#   'electron_transport_layer': 'In2O3/SnO2',
#   'hole_transport_layer': 'SnO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25 °C',
#     'time': '80 days',
#     'humidity': 'N2',
#     'control_efficiency': '97.5%',
#     'treatment_efficiency': '91%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': '75% RH',
#     'time': '120 h',
#     'humidity': 'High',
#     'control_efficiency': '71%',
#     'treatment_efficiency': '80%'}]},
#  '73': {'control_pce': 22.6,
#   'control_voc': 1.176,
#   'treated_pce': 25.1,
#   'treated_voc': 1.176,
#   'passivating_molecule': '2CF3-PEAI',
#   'perovskite_composition': 'FA0.98Cs0.02PbI3',
#   'electron_transport_layer': 'p-PY',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'temperature': 85,
#     'time': 1000,
#     'humidity': '85% RH',
#     'control_efficiency': 97.4}]},
#  '109': {'control_pce': '17.27%',
#   'control_voc': '1.13 V',
#   'treated_pce': '25.7%',
#   'treated_voc': '1.16 V',
#   'passivating_molecule': 'PAA',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': '25°C',
#     'time': '1000 hours',
#     'humidity': '25% RH',
#     'control_efficiency': '25.7%',
#     'treatment_efficiency': '80%'},
#    {'test_name': 'Shelf life',
#     'temperature': '25°C',
#     'time': '1000 hours',
#     'humidity': '25% RH',
#     'control_efficiency': '17.27%',
#     'treatment_efficiency': '25.7%'}]},
#  '33': {'control_pce': 25,
#   'treated_pce': 25,
#   'passivating_molecule': 'Benzene',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'FAI-terminated',
#   'hole_transport_layer': 'PbI2',
#   'stability_tests': []},
#  '140': {'control_pce': '26.07%',
#   'control_voc': '25.8%',
#   'treated_pce': '24.63%',
#   'treated_voc': '26.07%',
#   'passivating_molecule': 'HFB',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'temperature': '50 ± 5 °C',
#     'time': '1258 h',
#     'control_efficiency': '26.07%',
#     'treatment_efficiency': '24.63%'}]},
#  '8': {'control_pce': '20.1',
#   'control_voc': '1.16',
#   'treated_pce': '23.0',
#   'treated_voc': '1.177',
#   'passivating_molecule': 'PREA',
#   'perovskite_composition': 'CsPbI2Br',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'ambient',
#     'control_efficiency': '85',
#     'treatment_efficiency': '60'}]},
#  '99': {'control_pce': 18.08,
#   'control_voc': 1.087,
#   'treated_pce': 21.01,
#   'treated_voc': 1.146,
#   'passivating_molecule': 'ClMPI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Outdoor Solar Irradiation',
#     'temperature': 25,
#     'time': 180,
#     'humidity': 'outdoor',
#     'control_efficiency': 16.25,
#     'treatment_efficiency': 20.17},
#    {'test_name': 'UV Irradiation',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'controlled',
#     'control_efficiency': 10,
#     'treatment_efficiency': 82},
#    {'test_name': '1-Sun Illumination with UV Filter',
#     'temperature': 25,
#     'time': 200,
#     'humidity': 'indoor',
#     'control_efficiency': 50,
#     'treatment_efficiency': 90}]},
#  '48': {'control_pce': '16.9',
#   'control_voc': '1.07',
#   'treated_pce': '20.3',
#   'treated_voc': '1.10',
#   'passivating_molecule': 'Fluoro-silane',
#   'perovskite_composition': 'Perovskite films',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA:F4-TCNQ',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 'Room temperature',
#     'time': 'After fabrication',
#     'humidity': '40%',
#     'control_efficiency': '16.9',
#     'treatment_efficiency': '18.9'}]},
#  '34': {'stability_tests': []},
#  '147': {'control_pce': 22.3,
#   'control_voc': 1.112,
#   'treated_pce': 24.7,
#   'treated_voc': 1.161,
#   'passivating_molecule': 'CBz-PAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'P3HT',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Damp heat test',
#     'temperature': 85,
#     'time': '1,000 h',
#     'humidity': '85% relative humidity',
#     'control_efficiency': 66.6,
#     'treatment_efficiency': 92.3},
#    {'test_name': 'MPP tracking',
#     'temperature': 45,
#     'time': '1,100 h',
#     'control_efficiency': 66.6,
#     'treatment_efficiency': 94.6}]},
#  '6': {'control_pce': '20.1',
#   'control_voc': '1.03',
#   'treated_pce': '15.3',
#   'treated_voc': '1.06',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'PEA2PbI4',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'null',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '100',
#     'time': '36',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-L',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '55',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '90',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'}]},
#  '97': {'treated_pce': '22.3',
#   'treated_voc': '1.17',
#   'passivating_molecule': 'Oleylamine (OAm)',
#   'perovskite_composition': 'Cs 0.05 (FA 0.92 MA 0.08) 0.95 Pb(I 0.92 Br 0.08) 3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '70-75 °C',
#     'time': '1,800 h',
#     'humidity': 'Air',
#     'control_efficiency': '22.3%',
#     'treatment_efficiency': '23.0%'}]},
#  '46': {'control_voc': 1.12,
#   'treated_pce': 20,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'PFN-P2',
#   'perovskite_composition': 'CsPbI0.05[(FAPbI3)0.89]',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': 25,
#     'time': '100 hours',
#     'humidity': 'air',
#     'control_efficiency': 19.83,
#     'treatment_efficiency': 20}]},
#  '135': {'control_pce': '25.6',
#   'control_voc': '1.19',
#   'treated_pce': '25.6',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'MeO-4PADBC',
#   'perovskite_composition': 'Perovskite (assumed standard formula)',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'MeO-4PADBC',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '65',
#     'time': '1200',
#     'control_efficiency': '25.6',
#     'treatment_efficiency': '90'}]},
#  '149': {'control_pce': '22.2',
#   'control_voc': '0.841',
#   'treated_pce': '24.3',
#   'treated_voc': '2.03',
#   'passivating_molecule': 'CF3-PA',
#   'perovskite_composition': 'FA0.75MA0.25Pb0.5Sn0.5I3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'VNPB',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '35',
#     'humidity': '30-50%',
#     'control_efficiency': '22.2',
#     'treatment_efficiency': '24.3'}]},
#  '1': {'control_pce': 20,
#   'control_voc': 1.18,
#   'treated_pce': 23.32,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'FA 1-x MA x PbI 3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 500,
#     'control_efficiency': 20,
#     'treatment_efficiency': 23.32}]},
#  '90': {'control_pce': 20.7,
#   'control_voc': 1.17,
#   'treated_pce': 20.7,
#   'treated_voc': 1.17,
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '41': {'control_pce': 20.71,
#   'control_voc': 1.135,
#   'treated_pce': 23.9,
#   'treated_voc': 1.157,
#   'passivating_molecule': 'o-PDEAI2',
#   'perovskite_composition': 'PDEAI2',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Humidity test',
#     'temperature': 40,
#     'time': '24 hours',
#     'humidity': '40-50% RH',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Thermal stability',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Module performance',
#     'temperature': 'Module performance',
#     'time': 'Module performance',
#     'humidity': 'Module performance',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 23.9}]}}

# %%
def drop_fake_stability(obj):
    for value in obj.values():
        if 'stability_tests' in value:
            value['stability_tests'] = [
                test for test in value['stability_tests'] if len(test.keys()) > 1
            ]
    return obj

# %%
filtered_llama_data = drop_fake_stability(filtered_llama_data)
filtered_llama_data
# Out:
# {'103': {'control_pce': 14.44,
#   'control_voc': 0.926,
#   'treated_pce': 23.7,
#   'treated_voc': 1.47,
#   'passivating_molecule': 'Methylenediammonium chloride (MDACl2)',
#   'perovskite_composition': 'FAPbI3 with 3.8 mol% MDACl2',
#   'electron_transport_layer': 'TiO2 (mesoporous)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuPC',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 600,
#     'humidity': '20-30%',
#     'control_efficiency': 14.44,
#     'treatment_efficiency': 23.7}]},
#  '77': {'control_pce': '21.2',
#   'control_voc': '1.07',
#   'treated_pce': '24.1',
#   'treated_voc': '1.14',
#   'passivating_molecule': 'PEAMAI',
#   'perovskite_composition': 'FA 0.9 Cs 0.1 PbI 3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '55',
#     'time': '800',
#     'humidity': 'N/A',
#     'control_efficiency': '90',
#     'treatment_efficiency': '90'},
#    {'test_name': 'ISOS-E',
#     'temperature': '85',
#     'time': '1500',
#     'humidity': 'N/A',
#     'control_efficiency': '20',
#     'treatment_efficiency': '90'}]},
#  '104': {'treated_pce': '25.2',
#   'treated_voc': '1196',
#   'passivating_molecule': 'methylammonium bromide (MAPbBr3)',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1I',
#     'temperature': '45',
#     'time': '3600',
#     'humidity': 'ambient',
#     'control_efficiency': '25.2',
#     'treatment_efficiency': '25.2'}]},
#  '79': {'control_pce': 19.9,
#   'control_voc': 1.09,
#   'treated_pce': 19.9,
#   'treated_voc': 1.09,
#   'passivating_molecule': 'PbI2',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '40 days',
#     'humidity': 'dry air',
#     'control_efficiency': 19.9,
#     'treatment_efficiency': 19.9}]},
#  '138': {'control_pce': 24.6,
#   'treated_pce': 25.3,
#   'passivating_molecule': '2PACz and 3-MPA',
#   'perovskite_composition': 'Cs0.05MA0.10FA0.85PbI3',
#   'electron_transport_layer': 'FTO',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': 65,
#     'time': 1000,
#     'humidity': '50% RH',
#     'control_efficiency': 24.6,
#     'treatment_efficiency': 24.8}]},
#  '144': {'control_pce': 19.3,
#   'control_voc': 0.76,
#   'treated_pce': 21.0,
#   'treated_voc': 0.88,
#   'passivating_molecule': 'GlyHCl',
#   'perovskite_composition': 'Cs0.1FA0.6MA0.3Sn0.5Pb0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': '100 days',
#     'humidity': 'controlled (glovebox)',
#     'control_efficiency': 19.3,
#     'treatment_efficiency': 21.0}]},
#  '37': {'control_pce': 0.19,
#   'control_voc': 1.35,
#   'treated_pce': 0.263,
#   'treated_voc': 2.19,
#   'passivating_molecule': '1,3-propanediammonium iodide',
#   'perovskite_composition': 'Cs0.2FA0.8Pb(I0.6Br0.4)3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient air',
#     'control_efficiency': 0.19,
#     'treatment_efficiency': 0.263},
#    {'test_name': 'ISOS-LT',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient air',
#     'control_efficiency': 0.19,
#     'treatment_efficiency': 0.263}]},
#  '143': {'control_pce': '18.09',
#   'control_voc': '1.16',
#   'treated_pce': '18.09',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'CuSCN',
#   'perovskite_composition': '(FAPbI3)0.77 (MAPbBr3)0.14 (CsPbI3)0.09',
#   'electron_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuSCN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '400 days',
#     'humidity': '40-70%',
#     'control_efficiency': '18.09',
#     'treatment_efficiency': '18.09'}]},
#  '30': {'control_pce': 10.92,
#   'control_voc': 1.16,
#   'treated_pce': 23.21,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'NH3',
#   'perovskite_composition': 'FACsPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'PTAB',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21},
#    {'test_name': 'ISOS-L',
#     'temperature': 100,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21},
#    {'test_name': 'ISOS-T',
#     'temperature': -15,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21}]},
#  '2': {'control_pce': 0.2239,
#   'control_voc': 1098,
#   'treated_pce': 0.2459,
#   'treated_voc': 1185,
#   'passivating_molecule': '(BA)2PbI4',
#   'perovskite_composition': '(BA)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1056,
#     'humidity': '85% relative humidity',
#     'control_efficiency': 0.2239,
#     'treatment_efficiency': 0.2435}]},
#  '93': {'treated_pce': 20.5,
#   'perovskite_composition': 'FA1-x MAx PbI2.87 Br0.13(Cl)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '131': {'control_pce': '25.5%',
#   'control_voc': '1.208 V',
#   'treated_pce': '25.5%',
#   'treated_voc': '1.208 V',
#   'passivating_molecule': 'Al2O3',
#   'perovskite_composition': '1.55 eV',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz/PTAA',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '85°C',
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '98%',
#     'treatment_efficiency': '20%'}]},
#  '42': {'control_pce': 19.52,
#   'control_voc': 1.07,
#   'treated_pce': 22.03,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'AzPbI3',
#   'perovskite_composition': 'Cs0.05 MA0.1 FA0.85 PbI2.7 Br0.3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 52,
#     'time': 1000,
#     'control_efficiency': 47,
#     'treatment_efficiency': 85}]},
#  '5': {'control_pce': 22.1,
#   'control_voc': 1135,
#   'treated_pce': 22.1,
#   'treated_voc': 1205,
#   'passivating_molecule': 'iso-BAI and n-BAI',
#   'perovskite_composition': 'FA(MA)PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '94': {'control_pce': '19.11',
#   'control_voc': '1.112',
#   'treated_pce': '20.6',
#   'treated_voc': '1.129',
#   'passivating_molecule': 'P4VP',
#   'perovskite_composition': 'Perovskite',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'P4VP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25-40 °C',
#     'time': '6000 h',
#     'humidity': '25-50% RH',
#     'control_efficiency': '19.11',
#     'treatment_efficiency': '20.6'}]},
#  '136': {'control_pce': '25.4',
#   'control_voc': '1.21',
#   'treated_pce': '23.4',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'MPA-CPA',
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'MPA-CPA',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '45',
#     'time': '500 hours',
#     'humidity': '30-40% RH',
#     'control_efficiency': '25.4',
#     'treatment_efficiency': '23.4'},
#    {'test_name': 'damp heat',
#     'temperature': '85',
#     'time': '500 hours',
#     'humidity': '85% RH',
#     'control_efficiency': '25.4',
#     'treatment_efficiency': '23.4'}]},
#  '45': {'control_pce': '25.1',
#   'treated_pce': '25.1',
#   'perovskite_composition': 'poly-Si/c-Si',
#   'electron_transport_layer': 'c-Si',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'p-poly-Si',
#   'stability_tests': []},
#  '39': {'control_pce': 20.7,
#   'control_voc': 1.09,
#   'treated_pce': 20.82,
#   'treated_voc': 1.193,
#   'passivating_molecule': '2-TMABr',
#   'perovskite_composition': '[ (FAPbI3)0.87 (MAPbBr3)0.13 ]0.92 (CsPbI3)0.08',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 25,
#     'time': 1000,
#     'humidity': 'inert atmosphere (Ar)',
#     'control_efficiency': 20.7,
#     'treatment_efficiency': 20.82}]},
#  '127': {'control_pce': 18.5,
#   'control_voc': 1.048,
#   'treated_pce': 24.1,
#   'treated_voc': 1.198,
#   'passivating_molecule': 'tris(2,4-di-tert-butylphenyl) phosphite (TPPi)',
#   'perovskite_composition': 'PEA2ZnX4 (X = Cl/I)',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'Standard thermal stability test',
#     'temperature': 85,
#     'time': '1009 hours',
#     'humidity': 'controlled environment',
#     'control_efficiency': 18.5,
#     'treatment_efficiency': 24.1}]},
#  '54': {'passivating_molecule': 'Methylammonium iodide or bromide',
#   'perovskite_composition': 'Mixed halide perovskite (e.g., MAPbI3, MAPbBr3)',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': []},
#  '85': {'control_pce': 16,
#   'control_voc': 0.8,
#   'treated_pce': 22.7,
#   'treated_voc': 1.0,
#   'passivating_molecule': 'n-hexyl trimethyl ammonium bromide',
#   'perovskite_composition': 'FAPbI3:MAPbBr3:HTAB = 0.3:0.95:0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'P3HT',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1008,
#     'humidity': '85%',
#     'control_efficiency': 80,
#     'treatment_efficiency': 0}]},
#  '28': {'control_pce': 0.17,
#   'control_voc': 1.2,
#   'treated_pce': 0.17,
#   'treated_voc': 1.2,
#   'perovskite_composition': 'CsPbI3',
#   'electron_transport_layer': 'TPBi',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '120': {'control_pce': 23.0,
#   'control_voc': 1.13,
#   'treated_pce': 25.0,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'ferrocenyl-bis-thiophene-2-carboxylate',
#   'perovskite_composition': '(FA0.98MA0.02)0.95Cs0.05Pb(I0.95Br0.02)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'poly(triaryl amine)',
#   'stability_tests': [{'test_name': 'IEC61215:2016',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 72,
#     'treatment_efficiency': 98}]},
#  '53': {'control_pce': '4.9%',
#   'treated_pce': '24.7%',
#   'passivating_molecule': 'DMePDAI2',
#   'perovskite_composition': 'FA0.85MA0.1Cs0.05PbI2.9Br0.1',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': '40°C',
#     'time': '1000 hours',
#     'humidity': 'N2',
#     'control_efficiency': '20.5%',
#     'treatment_efficiency': '23.1%'}]},
#  '82': {'control_pce': '17.1',
#   'control_voc': '1.04',
#   'treated_pce': '20.59',
#   'treated_voc': '1.13',
#   'passivating_molecule': 'Choline chloride',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Humidity stability test',
#     'time': 'Over one month',
#     'humidity': '50-85% RH',
#     'control_efficiency': '17.1%',
#     'treatment_efficiency': '20.59%'}]},
#  '21': {'control_pce': 22.6,
#   'treated_pce': 19.14,
#   'passivating_molecule': 'LP layer',
#   'perovskite_composition': '3D perovskite',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient',
#     'control_efficiency': 22.6,
#     'treatment_efficiency': 19.14}]},
#  '129': {'control_pce': 24.8,
#   'control_voc': 1.19,
#   'treated_pce': 24.5,
#   'treated_voc': 1.19,
#   'passivating_molecule': 'GBAC',
#   'perovskite_composition': 'Cs0.06MA0.14FA0.80PbI3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'DC-PA',
#   'stability_tests': [{'test_name': 'JET certification',
#     'temperature': 65,
#     'time': 1200,
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': 24.5,
#     'treatment_efficiency': 24.5},
#    {'test_name': 'Thermal stability',
#     'temperature': 65,
#     'time': 1200,
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': 24.8,
#     'treatment_efficiency': 24.8}]},
#  '13': {'control_pce': 25.7,
#   'control_voc': 1.15,
#   'treated_pce': 15.1,
#   'treated_voc': 1.29,
#   'passivating_molecule': '2-thiopheneethylammonium chloride',
#   'perovskite_composition': 'Cs0.12FA0.8PbI1.8Br1.2',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': '2PACz',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 265,
#     'humidity': 'ambient',
#     'control_efficiency': 13.1,
#     'treatment_efficiency': 15.1}]},
#  '14': {'control_pce': 25.5,
#   'control_voc': 1.184,
#   'treated_pce': 23.7,
#   'treated_voc': 1.184,
#   'passivating_molecule': 'F-PEAI',
#   'perovskite_composition': 'Cs0.1FA0.9PbI2.9Br0.1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '68': {'control_pce': 12.8,
#   'control_voc': 0.95,
#   'treated_pce': 12.8,
#   'treated_voc': 0.95,
#   'passivating_molecule': 'SnOx',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'AZO',
#   'stability_tests': [{'temperature': 60,
#     'time': 1000,
#     'humidity': 'ambient air',
#     'control_efficiency': 12.8,
#     'treatment_efficiency': 12.8}]},
#  '66': {'control_pce': 25.5,
#   'control_voc': 0.8,
#   'treated_pce': 45,
#   'treated_voc': 0.8,
#   'perovskite_composition': 'Cs0.15FA0.85PbI2.55Br0.45',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'damp heat',
#     'temperature': 85,
#     'time': 1000,
#     'humidity': '85% RH',
#     'control_efficiency': 25.5,
#     'treatment_efficiency': 45}]},
#  '115': {'control_pce': '24.04',
#   'control_voc': '0.08 cm²',
#   'treated_pce': '23.15',
#   'treated_voc': '23.15',
#   'passivating_molecule': 'anisole',
#   'perovskite_composition': 'FA1-x-yMAxCsyPbI3-zBrz',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '95%',
#     'treatment_efficiency': '75%'},
#    {'test_name': 'SPO',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '5%',
#     'treatment_efficiency': '20%'}]},
#  '61': {'passivating_molecule': 'butylamine',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'temperature': 85,
#     'time': '125 hours',
#     'humidity': 'N2 atmosphere'}]},
#  '112': {'control_pce': 21.8,
#   'control_voc': 1.14,
#   'treated_pce': 23.2,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Benzylhydrazine hydrochloride (BHC)',
#   'perovskite_composition': 'MA0.7FA0.3PbI3',
#   'electron_transport_layer': 'Poly[bis(4-phenyl)(2,4,6-trimethylphenyl)amine] (PTAA)',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'Indium tin oxide (ITO)',
#   'stability_tests': [{'test_name': 'Stability under AM 1.5G light',
#     'temperature': 65,
#     'time': '1000 hours',
#     'humidity': '60% ± 10%',
#     'control_efficiency': 19.2,
#     'treatment_efficiency': 23.2}]},
#  '4': {'control_pce': '19.93',
#   'control_voc': '1.06',
#   'treated_pce': '21.90',
#   'treated_voc': '1.14',
#   'passivating_molecule': '4-vinylbenzylammonium bromide (VBABr)',
#   'perovskite_composition': '[[(VBABr)₂ (FA₉₅MA₀₅)ₙ₋₁ Pb₃ₙ₊₁]',
#   'electron_transport_layer': 'SnO₂',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '95': {'treated_pce': 22.9,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'octylammonium iodide',
#   'perovskite_composition': 'FAPbI3·0.95 and MAPbBr3·0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 65,
#     'time': '100 hours',
#     'humidity': '65% RH',
#     'treatment_efficiency': 22.9},
#    {'test_name': 'ISOS-H',
#     'temperature': 85,
#     'time': '100 hours',
#     'humidity': '85% RH'}]},
#  '137': {'control_pce': 23.0,
#   'control_voc': 1.12,
#   'treated_pce': 25.5,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'PDAI2 and 3MTPAI',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.90PbI3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx/4PACz',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1600,
#     'humidity': 'Nitrogen',
#     'control_efficiency': 23.0,
#     'treatment_efficiency': 25.5},
#    {'test_name': 'ISOS-L',
#     'temperature': 65,
#     'time': 2000,
#     'humidity': 'Air with 50% RH',
#     'control_efficiency': 23.0,
#     'treatment_efficiency': 25.5}]},
#  '44': {'control_pce': 25.8,
#   'control_voc': 731,
#   'treated_pce': 21.12,
#   'perovskite_composition': 'SiOx',
#   'electron_transport_layer': 'n+ poly-Si',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'n+ poly-Si'},
#  '3': {'control_pce': 24.5,
#   'control_voc': 1.2,
#   'treated_pce': 24.5,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'BA2MA2Pb3I10',
#   'perovskite_composition': 'Cs0.05(MA0.10FA0.85)Pb(I0.90Br0.10)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': 55,
#     'time': 2000,
#     'humidity': '70% RH',
#     'control_efficiency': 21,
#     'treatment_efficiency': 22.93}]},
#  '92': {'treated_pce': 21.3,
#   'passivating_molecule': 'BaSnO3',
#   'perovskite_composition': 'BaSnO3',
#   'electron_transport_layer': 'BaSnO3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD, PTAA',
#   'stability_tests': [{'temperature': 25,
#     'time': '24 hours',
#     'humidity': '40% RH',
#     'control_efficiency': 21.3,
#     'treatment_efficiency': 21.7}]},
#  '130': {'control_pce': 22.9,
#   'control_voc': 1.1,
#   'treated_pce': 25.4,
#   'treated_voc': 1.15,
#   'passivating_molecule': 'Pentanamidine hydrochloride (PAD)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 30,
#     'time': '1000 h',
#     'humidity': 'ambient',
#     'control_efficiency': 22.9,
#     'treatment_efficiency': 25.4},
#    {'test_name': 'ISOS-L',
#     'temperature': 65,
#     'time': '500 h',
#     'humidity': '85% RH',
#     'control_efficiency': 22.9,
#     'treatment_efficiency': 25.4}]},
#  '43': {'control_pce': '24.50%',
#   'control_voc': '1.150 V',
#   'treated_pce': '24.50%',
#   'treated_voc': '1.121 V',
#   'passivating_molecule': 'Benzylamine hydroiodide (BAHI)',
#   'perovskite_composition': 'FA0.90MA0.10PbI3•(CsPbI3)0.05 with excess PbI2',
#   'electron_transport_layer': 'TiO2 (mesoporous)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '80 °C',
#     'time': '500 h',
#     'humidity': '20-30% RH',
#     'control_efficiency': '24.50%',
#     'treatment_efficiency': '47.96 ± 3.21%'}]},
#  '142': {'control_pce': 13.15,
#   'treated_pce': 16.13,
#   'passivating_molecule': 'formamidinium iodide (FAI)',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Modified BA2MA(n)Pb(n+1)I3n+1',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 65,
#     'time': '50 days',
#     'humidity': '65%',
#     'control_efficiency': 71},
#    {'test_name': 'ISOS-T',
#     'temperature': 85,
#     'time': '30 days',
#     'control_efficiency': 74},
#    {'test_name': 'ISOS-L', 'time': '24 hours', 'control_efficiency': 90}]},
#  '31': {'control_pce': 23.39,
#   'control_voc': 1.12,
#   'treated_pce': 25.49,
#   'treated_voc': 1.19,
#   'passivating_molecule': '3-aminomethyl pyridine (3-APy)',
#   'perovskite_composition': 'Rb0.05 Cs0.05 MA0.05 FA0.85 PbI0.95 Br0.05',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '850 hours',
#     'humidity': '85% relative humidity',
#     'control_efficiency': '22.85%',
#     'treatment_efficiency': '25.35%'},
#    {'test_name': 'ISOS-L',
#     'temperature': 55,
#     'time': '2,400 hours',
#     'humidity': 'air',
#     'control_efficiency': '22.3%',
#     'treatment_efficiency': '24.6%'}]},
#  '139': {'control_pce': 25.2,
#   'control_voc': 1.145,
#   'treated_pce': 26.1,
#   'treated_voc': 1.164,
#   'passivating_molecule': '1-(phenylsulfonyl)pyrrole',
#   'perovskite_composition': 'FA0.95Cs0.05PbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '2500h',
#     'humidity': '85%RH',
#     'control_efficiency': 80,
#     'treatment_efficiency': 92}]},
#  '145': {'control_pce': 17.08,
#   'control_voc': 1.02,
#   'treated_pce': 20.48,
#   'treated_voc': 1.13,
#   'passivating_molecule': '4-fluoroaniline (FAL)',
#   'perovskite_composition': 'Cs0.05(MA0.17FA0.83)0.95PbI0.83Br0.17',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 66,
#     'humidity': '85-95% RH',
#     'control_efficiency': 17.08,
#     'treatment_efficiency': 20.48},
#    {'test_name': 'ISOS-L',
#     'temperature': 85,
#     'time': 100,
#     'humidity': '85% RH'}]},
#  '36': {'control_pce': '20%',
#   'control_voc': '0.23 V',
#   'treated_pce': '19.6%',
#   'treated_voc': '0.19 V',
#   'passivating_molecule': 'C60',
#   'perovskite_composition': 'Cs0.05(FA0.83MA0.17)0.95Pb(I0.83Br0.17)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'pin',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '-20°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'},
#    {'test_name': 'ISOS-L',
#     'temperature': '80°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'},
#    {'test_name': 'ISOS-T',
#     'temperature': '-10°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'}]},
#  '78': {'control_voc': 1.06,
#   'treated_pce': 20.2,
#   'treated_voc': 1.06,
#   'passivating_molecule': 'DMSO',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '76': {'perovskite_composition': '2D lead halide perovskites',
#   'electron_transport_layer': 'organic spacer ligands',
#   'pin_nip_structure': '2D',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 140,
#     'time': '60 min',
#     'humidity': 'dry'},
#    {'test_name': 'ISOS-L',
#     'temperature': 23,
#     'time': 'room temperature',
#     'humidity': 'dry'}]},
#  '105': {'control_pce': '21.65%',
#   'control_voc': '1.172 V',
#   'treated_pce': '23.33%',
#   'treated_voc': '1.193 V',
#   'passivating_molecule': 'PMMA:PCBM',
#   'perovskite_composition': 'TiOxNy',
#   'electron_transport_layer': 'TiOxNy',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'P3HT:CuPc',
#   'stability_tests': [{'test_name': 'damp-heat',
#     'temperature': '85',
#     'time': '1000 hours',
#     'humidity': '85% relative humidity',
#     'control_efficiency': '96.5%',
#     'treatment_efficiency': '98.7%'}]},
#  '71': {'control_pce': 5,
#   'control_voc': 0.05,
#   'treated_pce': 15.3,
#   'treated_voc': 1.7,
#   'passivating_molecule': '(BA)2(MA)3Pb4I13',
#   'perovskite_composition': '(BA)2(MA)3Pb4I13',
#   'electron_transport_layer': 'BA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 260},
#    {'test_name': 'ISOS-L', 'temperature': 240}]},
#  '102': {'control_pce': 17.87,
#   'control_voc': 1.05,
#   'treated_pce': 21.07,
#   'treated_voc': 1.12,
#   'passivating_molecule': 'MACl',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': []},
#  '113': {'treated_pce': 25.8,
#   'treated_voc': 1.1885,
#   'passivating_molecule': 'FASnCl x',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1I',
#     'temperature': 25,
#     'time': 500,
#     'control_efficiency': 25.5,
#     'treatment_efficiency': 25.8}]},
#  '67': {'passivating_molecule': 'formamidinium (FA)',
#   'perovskite_composition': 'FAPbI3 and CsPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L1',
#     'temperature': 298,
#     'time': '1000 hours',
#     'humidity': '25% RH'},
#    {'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH'},
#    {'test_name': 'ISOS-L2',
#     'temperature': 65,
#     'time': '1000 hours',
#     'humidity': '60% RH'},
#    {'test_name': 'ISOS-L3',
#     'temperature': 110,
#     'time': '2000 hours',
#     'humidity': 'unknown'}]},
#  '114': {'control_pce': 20.76,
#   'control_voc': 1.06,
#   'treated_pce': 23.37,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Piperazinium iodide (PI)',
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': []},
#  '15': {'control_pce': '21.78',
#   'control_voc': '1.11',
#   'treated_pce': '23.34',
#   'treated_voc': '1.15',
#   'passivating_molecule': 'Cl-PEAI and F-PEAI',
#   'perovskite_composition': 'Cs0.05(FA5/6MA1/6)0.95PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '69': {'passivating_molecule': 'SnOx',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'Al:ZnO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PEDOT:PSS',
#   'stability_tests': [{'temperature': 25, 'humidity': '60% RH'}]},
#  '12': {'control_pce': 16.7,
#   'control_voc': 1.23,
#   'treated_pce': 19.4,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylammonium bromide (BABr)',
#   'perovskite_composition': 'Cs0.17 FA0.83 Pb(I0.6 Br0.4)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'J-V measurements',
#     'temperature': 25,
#     'time': 'continuous illumination',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4},
#    {'test_name': 'PCE under different treatments',
#     'temperature': 25,
#     'time': 'under constant voltage',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4}]},
#  '128': {'control_pce': '24.6',
#   'control_voc': '1.16',
#   'treated_pce': '25.12',
#   'treated_voc': '1.165',
#   'passivating_molecule': '2-aminoindan hydrochloride (AICl)',
#   'perovskite_composition': 'Cs0.05FA0.95PbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '85',
#     'time': '1200 hours',
#     'humidity': '85% RH',
#     'control_efficiency': '24.32',
#     'treatment_efficiency': '24.58'},
#    {'test_name': 'ISOS-D',
#     'temperature': '55',
#     'time': '1500 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '21.73',
#     'treatment_efficiency': '24.42'}]},
#  '27': {'control_pce': '14.4',
#   'control_voc': '1.01',
#   'treated_pce': '18.5',
#   'treated_voc': '1.23',
#   'passivating_molecule': 'CF3-PEA',
#   'perovskite_composition': 'CsPbI3-xBrx',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '25',
#     'time': '1000',
#     'humidity': 'ambient',
#     'control_efficiency': '14.4',
#     'treatment_efficiency': '18.5'}]},
#  '20': {'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'MAPbI3, (PEA)2PbI4',
#   'electron_transport_layer': 'PMMA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '121': {'control_pce': '26.08',
#   'treated_pce': '25.73',
#   'passivating_molecule': 'formamidinium lead iodide (FAPbI3)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'temperature': '60-80 °C',
#     'time': '40 min',
#     'humidity': 'controlled',
#     'control_efficiency': '26.08%',
#     'treatment_efficiency': '25.73%'}]},
#  '52': {'control_pce': '19.1%',
#   'control_voc': '658.4 mV',
#   'passivating_molecule': 'Al2O3',
#   'perovskite_composition': 'CH3NH3Pb',
#   'electron_transport_layer': 'Al-BSF',
#   'pin_nip_structure': 'PERC',
#   'hole_transport_layer': 'Al-BSF'},
#  '83': {'control_pce': '21.3',
#   'control_voc': '1.13',
#   'treated_pce': '21.38',
#   'treated_voc': '1.12',
#   'passivating_molecule': 'MAI and FA',
#   'perovskite_composition': 'MAPbI3 and FA0.15MA0.85PbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '792 hours',
#     'humidity': '40 ± 10%',
#     'control_efficiency': '21.3',
#     'treatment_efficiency': '21.38'}]},
#  '126': {'control_pce': 23.43,
#   'control_voc': 1.16,
#   'treated_pce': 25.39,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'PbC2O4',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': 550,
#     'humidity': 'ambient air',
#     'control_efficiency': 92,
#     'treatment_efficiency': 92}]},
#  '55': {'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'},
#    {'test_name': 'ISOS-L',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'}]},
#  '84': {'control_pce': 21.6,
#   'control_voc': 1.24,
#   'treated_pce': 23.2,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'DM',
#   'perovskite_composition': '(FAPbI3)0.95 (MAPbBr3)0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'DM',
#   'stability_tests': [{'test_name': 'thermal stability test',
#     'temperature': 60,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 70,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 80,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3}]},
#  '29': {'passivating_molecule': 'butylamine',
#   'perovskite_composition': 'PbI2-based',
#   'electron_transport_layer': 'linear PEI',
#   'stability_tests': []},
#  '18': {'control_pce': '26%',
#   'passivating_molecule': 'TMAI',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'SnO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'lower'},
#    {'test_name': 'ISOS-L',
#     'temperature': 100,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'higher'}]},
#  '117': {'control_pce': 22.2,
#   'control_voc': 1.15,
#   'treated_pce': 25.1,
#   'treated_voc': 1.17,
#   'passivating_molecule': '4-tert-butyl-1-methylpyridinium bis(trifluoromethanesulfonyl)imide (TBMP + TFSI -)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Stability test',
#     'temperature': '70 ± 5% RH',
#     'time': 'Long-term exposure',
#     'humidity': 'High relative humidity',
#     'control_efficiency': '22.2%',
#     'treatment_efficiency': '25.1%'}]},
#  '64': {'control_pce': 18.6,
#   'control_voc': 1057,
#   'treated_pce': 17.0,
#   'treated_voc': 1062,
#   'passivating_molecule': 'PEA2PbI4',
#   'perovskite_composition': 'Both MAPI and PEA2PbI4',
#   'electron_transport_layer': 'MoO3 and TATM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60'},
#  '110': {'control_pce': '23.92',
#   'control_voc': '1.15',
#   'treated_pce': '25.6',
#   'treated_voc': '1.21',
#   'passivating_molecule': 'formate',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'm-TiO2',
#   'stability_tests': [{'test_name': 'stability tests',
#     'temperature': '25 °C',
#     'time': '1000 h',
#     'humidity': '20% relative humidity',
#     'control_efficiency': '23.92',
#     'treatment_efficiency': '25.6'}]},
#  '11': {'control_pce': '20.2',
#   'control_voc': '1.11',
#   'treated_pce': '21.8',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'BTaBr',
#   'perovskite_composition': '(BTa)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '24 hours',
#     'humidity': 'ambient air',
#     'control_efficiency': '21.8',
#     'treatment_efficiency': '21.8'}]},
#  '16': {'control_pce': 18.87,
#   'control_voc': 1.04,
#   'treated_pce': 21.05,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'CF3PEAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '119': {'control_pce': 20.5,
#   'control_voc': 1.09,
#   'treated_pce': 23.9,
#   'treated_voc': 1.15,
#   'passivating_molecule': '1,1,2,2,3,3-hexafluoropropane-1,3-disulfonimide',
#   'perovskite_composition': 'formamidinium-based perovskite',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'HFDF',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 200,
#     'humidity': 'Not specified',
#     'control_efficiency': 23.9,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'ISOS-L',
#     'temperature': 85,
#     'time': 1000,
#     'humidity': 'Not specified',
#     'control_efficiency': 20.5,
#     'treatment_efficiency': 21.2}]},
#  '23': {'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'Cs0.05MA0.1FA0.85PbI3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L3',
#     'temperature': '65°C',
#     'time': '500 hours',
#     'humidity': 'Not explicitly mentioned',
#     'control_efficiency': '23.91%',
#     'treatment_efficiency': '92% of initial PCE'}]},
#  '58': {'control_pce': '25.5%',
#   'treated_pce': '18.5%',
#   'passivating_molecule': 'PCBM',
#   'perovskite_composition': 'FA0.83Cs0.17PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'poly-TPD or NiOx',
#   'stability_tests': []},
#  '89': {'treated_pce': '20.87%',
#   'treated_voc': '413 mV',
#   'passivating_molecule': 'formamidine acetate (FAAc)',
#   'perovskite_composition': '(FA, MA, Cs)Pb(I, Br)3'},
#  '24': {'control_pce': '14.9',
#   'treated_pce': '17.4',
#   'passivating_molecule': 'Cs2PbI2Cl2',
#   'perovskite_composition': 'CsPbI3',
#   'electron_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuSCN',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 110,
#     'time': 2100,
#     'control_efficiency': 14.9,
#     'treatment_efficiency': 17.4}]},
#  '56': {'control_pce': 25.5,
#   'control_voc': 1.22,
#   'treated_pce': 20.5,
#   'treated_voc': 1.22,
#   'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '125': {'control_pce': '91%',
#   'control_voc': '1.14 V',
#   'treated_pce': '23.7%',
#   'treated_voc': '1.14 V',
#   'passivating_molecule': 'Selenophene',
#   'perovskite_composition': 'FA0.9Cs0.1PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85°C',
#     'time': '3190 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '91%',
#     'treatment_efficiency': '91%'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '1000 hours',
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': '45°C',
#     'time': '500 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '80%',
#     'treatment_efficiency': '80%'}]},
#  '87': {'treated_pce': 21.52,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'FAI',
#   'perovskite_composition': 'CsI:20 mg, PbI2:530 mg, PbBr2:20 mg, PbCl2:20 mg, MAI:5 mg',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'temperature': 85,
#     'time': 1500,
#     'control_efficiency': 100,
#     'treatment_efficiency': 89}]},
#  '51': {'control_pce': '25%',
#   'treated_pce': '2x',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN'},
#  '122': {'control_pce': 25.6,
#   'control_voc': 1.182,
#   'treated_pce': 25.6,
#   'treated_voc': 1.182,
#   'passivating_molecule': '(PbI2)2RbCl',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'thermal stability test',
#     'temperature': 85,
#     'time': 500,
#     'humidity': 'Unknown',
#     'control_efficiency': 80,
#     'treatment_efficiency': 96}]},
#  '80': {'control_pce': 21.6,
#   'control_voc': 1.14,
#   'treated_pce': 21.6,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'PMMA',
#   'perovskite_composition': 'Mixed cation perovskite (FAI, PbI2, MABr, PbBr2)',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': '2 months',
#     'humidity': 'ambient air',
#     'control_efficiency': 21.0,
#     'treatment_efficiency': 21.0}]},
#  '0': {'control_pce': '25.5',
#   'control_voc': '1.17',
#   'treated_pce': '24.7',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'formamidinium lead triiodide (FAPbI3)',
#   'electron_transport_layer': 'Cs2O',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '1500',
#     'humidity': '50',
#     'control_efficiency': '19.9',
#     'treatment_efficiency': '95'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65',
#     'time': '1200',
#     'humidity': '50',
#     'control_efficiency': '23.2',
#     'treatment_efficiency': '91'}]},
#  '91': {'control_pce': '19.66',
#   'control_voc': '1.027',
#   'treated_pce': '24.02',
#   'treated_voc': '1.130',
#   'passivating_molecule': 'methylammonium chloride (MACl)',
#   'perovskite_composition': 'formamidinium lead iodide (FAPbI3)',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '1200 hours',
#     'humidity': 'Room temperature',
#     'control_efficiency': '90',
#     'treatment_efficiency': '90'},
#    {'test_name': 'ISOS-L',
#     'temperature': 40,
#     'time': '300 hours',
#     'humidity': '40°C',
#     'control_efficiency': '60',
#     'treatment_efficiency': '90'}]},
#  '40': {'control_pce': 24.3,
#   'control_voc': 1.2,
#   'treated_pce': 24.3,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'Oleylammonium iodide (OLAI)',
#   'perovskite_composition': 'Cs0.03(FA0.90MA0.10)PbI3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'damp-heat',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 24.3,
#     'treatment_efficiency': 19.3}]},
#  '133': {'control_pce': '22.34%',
#   'control_voc': '1.14 V',
#   'treated_pce': '24.04%',
#   'treated_voc': '1.19 V',
#   'passivating_molecule': 'Sodium thioglycolate',
#   'perovskite_composition': 'FA0.75MA0.25PbI3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '25 °C',
#     'time': '900 hours',
#     'humidity': 'controlled',
#     'control_efficiency': '22.34%',
#     'treatment_efficiency': '24.04%'},
#    {'test_name': 'AM1.5G',
#     'temperature': '25 °C',
#     'time': '800 hours',
#     'humidity': 'controlled',
#     'control_efficiency': '22.25%',
#     'treatment_efficiency': '23.5%'}]},
#  '7': {'control_pce': 23.5,
#   'control_voc': 1.2,
#   'treated_pce': 28.7,
#   'treated_voc': 1.5,
#   'passivating_molecule': '4-FPEA',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Au',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '24 hours',
#     'humidity': '50% RH',
#     'control_efficiency': 22.5,
#     'treatment_efficiency': 28.7},
#    {'test_name': 'ISOS-L',
#     'temperature': 60,
#     'time': '48 hours',
#     'humidity': '30% RH',
#     'control_efficiency': 23.5,
#     'treatment_efficiency': 28.7}]},
#  '96': {'control_pce': 22.19,
#   'control_voc': 1.13,
#   'treated_pce': 16.7,
#   'passivating_molecule': 'tin(II) acetylacetonate',
#   'perovskite_composition': 'lead halide perovskite',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 160,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 200,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 220,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 350,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7}]},
#  '47': {'treated_pce': 21.1,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'PbSO4',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 65,
#     'time': '1200 hours',
#     'humidity': 'air, RH ~60%',
#     'control_efficiency': 21.1,
#     'treatment_efficiency': 96.8}]},
#  '134': {'control_pce': 23.13,
#   'control_voc': 1.141,
#   'treated_pce': 25.08,
#   'treated_voc': 1.174,
#   'passivating_molecule': 'Guanabenz acetate salt',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Moisture stability test',
#     'temperature': 55,
#     'time': '24 hours',
#     'humidity': '55% RH',
#     'control_efficiency': 23.13,
#     'treatment_efficiency': 25.32},
#    {'test_name': 'Damp heat test',
#     'temperature': 85,
#     'time': '300 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 23.13,
#     'treatment_efficiency': 25.08}]},
#  '148': {'control_pce': 20.1,
#   'control_voc': 1.077,
#   'treated_pce': 23.5,
#   'treated_voc': 1.142,
#   'passivating_molecule': '4-tert-butylbenzylammonium iodide (tBBAI)',
#   'perovskite_composition': 'Cs0.05FA0.85MA0.10PbI0.97Br0.03',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 50,
#     'time': '500 hours',
#     'humidity': '50-70% RH',
#     'control_efficiency': 20.1,
#     'treatment_efficiency': 23.5}]},
#  '9': {'control_pce': 14.64,
#   'treated_pce': 17.6,
#   'passivating_molecule': 'C8',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'NiOx'},
#  '98': {'control_pce': '24.2',
#   'control_voc': '1.28',
#   'treated_pce': '21.54',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'FN-Br',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'MPP under 1-sun illumination',
#     'temperature': '25',
#     'time': '500',
#     'humidity': 'Ambient air',
#     'control_efficiency': '21.54',
#     'treatment_efficiency': '20.24'}]},
#  '49': {'control_pce': '13.81',
#   'control_voc': '1.12',
#   'treated_pce': '16.25',
#   'treated_voc': '1.31',
#   'passivating_molecule': 'n-butylamine acetate (BAAc)',
#   'perovskite_composition': '(BA)2(MA)n-1Pb3n+1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '558',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '13.81',
#     'treatment_efficiency': '16.25'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65 ± 10%',
#     'time': '4680',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '49.4',
#     'treatment_efficiency': '93.8'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '85',
#     'time': '1100',
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': '70.8',
#     'treatment_efficiency': '96.2'}]},
#  '35': {'perovskite_composition': 'CsPbI3_0.05(FAPbI3_0.83MAPbBr3_0.17)_0.95',
#   'electron_transport_layer': 'C60, PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PEDOT:PSS, PC61BM',
#   'stability_tests': []},
#  '146': {'control_pce': 21.5,
#   'control_voc': 1.128,
#   'treated_pce': 23.04,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'CB-NH2',
#   'perovskite_composition': 'Cs0.05FA0.95PbI0.95Br0.05',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': 40,
# ...
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 100,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6},
#    {'test_name': 'ISOS-LT',
#     'temperature': 60,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6}]},
#  '59': {'control_pce': '19.07',
#   'control_voc': '1.25',
#   'treated_pce': '19.07',
#   'treated_voc': '1.25',
#   'passivating_molecule': 'phenethylammonium iodide',
#   'perovskite_composition': 'FA0.8Cs0.2PbI0.7Br0.3',
#   'electron_transport_layer': 'poly(triarylamine)',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '88': {'control_pce': 19.03,
#   'control_voc': 0.92,
#   'treated_pce': 21.46,
#   'treated_voc': 0.94,
#   'passivating_molecule': 'NaF',
#   'perovskite_composition': 'Cs0.05FA0.54MA0.41PbI0.98Br0.02)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1000,
#     'control_efficiency': 19.03,
#     'treatment_efficiency': 21.46}]},
#  '25': {'passivating_molecule': 'formamidinium',
#   'perovskite_composition': 'FAPbI3, FAPbBr3',
#   'stability_tests': []},
#  '22': {'control_pce': 25.5,
#   'control_voc': 1.092,
#   'treated_pce': 24.0,
#   'treated_voc': 1.154,
#   'passivating_molecule': 'Cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PCBM',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 50,
#     'time': 500,
#     'humidity': '40 ± 10%',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 93},
#    {'test_name': 'ISOS-L',
#     'temperature': 50,
#     'time': 500,
#     'humidity': '40 ± 10%',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 93}]},
#  '17': {'control_pce': 25.2,
#   'control_voc': 1.16,
#   'treated_pce': 22.02,
#   'treated_voc': 1.19,
#   'passivating_molecule': 'hexyltrimethylammonium bromide',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': '1F-PTAA',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': '1F-PTAA',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '90 min',
#     'humidity': 'N2-filled glove-box',
#     'control_efficiency': 20.04,
#     'treatment_efficiency': 22.16}]},
#  '118': {'control_pce': 0.1961,
#   'control_voc': 1.16,
#   'treated_pce': 0.2154,
#   'treated_voc': 1.24,
#   'passivating_molecule': 'n-Butylammonium bromide (BABr)',
#   'perovskite_composition': '1.63 eV bandgap system (RbCsMAFA)',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 35,
#     'time': '24 h',
#     'humidity': '20-30% RH',
#     'control_efficiency': 0.1961,
#     'treatment_efficiency': 0.2154},
#    {'test_name': 'ISOS-L',
#     'temperature': 60,
#     'time': '500 h',
#     'humidity': '30-40% RH',
#     'control_efficiency': 0.1961,
#     'treatment_efficiency': 0.2154}]},
#  '10': {'treated_pce': 24.41,
#   'treated_voc': 4.77,
#   'passivating_molecule': 'OATsO',
#   'perovskite_composition': '(FAPbI3)0.95((MAPbBr3)0.05)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'test_name': 'OC',
#     'temperature': 40,
#     'time': '1,000 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41},
#    {'test_name': 'MPP',
#     'temperature': 40,
#     'time': '800 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41}]},
#  '111': {'treated_pce': 23.9,
#   'treated_voc': 0.68,
#   'passivating_molecule': 'isopropylammonium chloride',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-MeOTAD',
#   'stability_tests': []},
#  '62': {'control_pce': 17.3,
#   'control_voc': 1.01,
#   'treated_pce': 16.5,
#   'treated_voc': 1.02,
#   'passivating_molecule': 'BAI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 55,
#     'time': '30 days',
#     'humidity': '55% RH',
#     'control_efficiency': 44,
#     'treatment_efficiency': 83},
#    {'test_name': 'ISOS-L',
#     'temperature': 80,
#     'time': '30 days',
#     'humidity': '80°C',
#     'control_efficiency': 27,
#     'treatment_efficiency': 73}]},
#  '19': {'treated_pce': 24.09,
#   'passivating_molecule': '3FPEA',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.9Pb(I0.95Br0.05)3',
#   'electron_transport_layer': '2PACz',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': 85,
#     'time': 1560,
#     'humidity': '50% RH',
#     'treatment_efficiency': 24.09}]},
#  '116': {'control_pce': 23.44,
#   'control_voc': 1.152,
#   'treated_pce': 24.82,
#   'treated_voc': 1.1814,
#   'passivating_molecule': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': 500,
#     'control_efficiency': 13.74,
#     'treatment_efficiency': 87}]},
#  '65': {'control_pce': 4.73,
#   'control_voc': 1.18,
#   'treated_pce': 4.73,
#   'treated_voc': 1.18,
#   'passivating_molecule': '(PEA)2(MA)2[Pb3I10]',
#   'perovskite_composition': '(PEA)2(MA)2[Pb3I10]',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '52',
#     'time': '40 days',
#     'humidity': '52% relative humidity',
#     'control_efficiency': 4.73,
#     'treatment_efficiency': 4.73}]},
#  '107': {'treated_pce': 21.25,
#   'passivating_molecule': 'SF-PEA',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 1000,
#     'time': '1000',
#     'humidity': '50-60%',
#     'treatment_efficiency': 0.91}]},
#  '74': {'control_pce': 21.2,
#   'control_voc': 1.13,
#   'passivating_molecule': 'CLP',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 4390,
#     'humidity': 'N2',
#     'control_efficiency': 21.2,
#     'treatment_efficiency': 21.2}]},
#  '100': {'control_pce': '23.24',
#   'control_voc': '1.17',
#   'treated_pce': '22.54',
#   'treated_voc': '1.16',
#   'electron_transport_layer': 'In2O3/SnO2',
#   'hole_transport_layer': 'SnO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25 °C',
#     'time': '80 days',
#     'humidity': 'N2',
#     'control_efficiency': '97.5%',
#     'treatment_efficiency': '91%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': '75% RH',
#     'time': '120 h',
#     'humidity': 'High',
#     'control_efficiency': '71%',
#     'treatment_efficiency': '80%'}]},
#  '73': {'control_pce': 22.6,
#   'control_voc': 1.176,
#   'treated_pce': 25.1,
#   'treated_voc': 1.176,
#   'passivating_molecule': '2CF3-PEAI',
#   'perovskite_composition': 'FA0.98Cs0.02PbI3',
#   'electron_transport_layer': 'p-PY',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'temperature': 85,
#     'time': 1000,
#     'humidity': '85% RH',
#     'control_efficiency': 97.4}]},
#  '109': {'control_pce': '17.27%',
#   'control_voc': '1.13 V',
#   'treated_pce': '25.7%',
#   'treated_voc': '1.16 V',
#   'passivating_molecule': 'PAA',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': '25°C',
#     'time': '1000 hours',
#     'humidity': '25% RH',
#     'control_efficiency': '25.7%',
#     'treatment_efficiency': '80%'},
#    {'test_name': 'Shelf life',
#     'temperature': '25°C',
#     'time': '1000 hours',
#     'humidity': '25% RH',
#     'control_efficiency': '17.27%',
#     'treatment_efficiency': '25.7%'}]},
#  '33': {'control_pce': 25,
#   'treated_pce': 25,
#   'passivating_molecule': 'Benzene',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'FAI-terminated',
#   'hole_transport_layer': 'PbI2',
#   'stability_tests': []},
#  '140': {'control_pce': '26.07%',
#   'control_voc': '25.8%',
#   'treated_pce': '24.63%',
#   'treated_voc': '26.07%',
#   'passivating_molecule': 'HFB',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'temperature': '50 ± 5 °C',
#     'time': '1258 h',
#     'control_efficiency': '26.07%',
#     'treatment_efficiency': '24.63%'}]},
#  '8': {'control_pce': '20.1',
#   'control_voc': '1.16',
#   'treated_pce': '23.0',
#   'treated_voc': '1.177',
#   'passivating_molecule': 'PREA',
#   'perovskite_composition': 'CsPbI2Br',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'ambient',
#     'control_efficiency': '85',
#     'treatment_efficiency': '60'}]},
#  '99': {'control_pce': 18.08,
#   'control_voc': 1.087,
#   'treated_pce': 21.01,
#   'treated_voc': 1.146,
#   'passivating_molecule': 'ClMPI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Outdoor Solar Irradiation',
#     'temperature': 25,
#     'time': 180,
#     'humidity': 'outdoor',
#     'control_efficiency': 16.25,
#     'treatment_efficiency': 20.17},
#    {'test_name': 'UV Irradiation',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'controlled',
#     'control_efficiency': 10,
#     'treatment_efficiency': 82},
#    {'test_name': '1-Sun Illumination with UV Filter',
#     'temperature': 25,
#     'time': 200,
#     'humidity': 'indoor',
#     'control_efficiency': 50,
#     'treatment_efficiency': 90}]},
#  '48': {'control_pce': '16.9',
#   'control_voc': '1.07',
#   'treated_pce': '20.3',
#   'treated_voc': '1.10',
#   'passivating_molecule': 'Fluoro-silane',
#   'perovskite_composition': 'Perovskite films',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA:F4-TCNQ',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 'Room temperature',
#     'time': 'After fabrication',
#     'humidity': '40%',
#     'control_efficiency': '16.9',
#     'treatment_efficiency': '18.9'}]},
#  '34': {'stability_tests': []},
#  '147': {'control_pce': 22.3,
#   'control_voc': 1.112,
#   'treated_pce': 24.7,
#   'treated_voc': 1.161,
#   'passivating_molecule': 'CBz-PAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'P3HT',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Damp heat test',
#     'temperature': 85,
#     'time': '1,000 h',
#     'humidity': '85% relative humidity',
#     'control_efficiency': 66.6,
#     'treatment_efficiency': 92.3},
#    {'test_name': 'MPP tracking',
#     'temperature': 45,
#     'time': '1,100 h',
#     'control_efficiency': 66.6,
#     'treatment_efficiency': 94.6}]},
#  '6': {'control_pce': '20.1',
#   'control_voc': '1.03',
#   'treated_pce': '15.3',
#   'treated_voc': '1.06',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'PEA2PbI4',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'null',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '100',
#     'time': '36',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-L',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '55',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '90',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'}]},
#  '97': {'treated_pce': '22.3',
#   'treated_voc': '1.17',
#   'passivating_molecule': 'Oleylamine (OAm)',
#   'perovskite_composition': 'Cs 0.05 (FA 0.92 MA 0.08) 0.95 Pb(I 0.92 Br 0.08) 3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '70-75 °C',
#     'time': '1,800 h',
#     'humidity': 'Air',
#     'control_efficiency': '22.3%',
#     'treatment_efficiency': '23.0%'}]},
#  '46': {'control_voc': 1.12,
#   'treated_pce': 20,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'PFN-P2',
#   'perovskite_composition': 'CsPbI0.05[(FAPbI3)0.89]',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': 25,
#     'time': '100 hours',
#     'humidity': 'air',
#     'control_efficiency': 19.83,
#     'treatment_efficiency': 20}]},
#  '135': {'control_pce': '25.6',
#   'control_voc': '1.19',
#   'treated_pce': '25.6',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'MeO-4PADBC',
#   'perovskite_composition': 'Perovskite (assumed standard formula)',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'MeO-4PADBC',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '65',
#     'time': '1200',
#     'control_efficiency': '25.6',
#     'treatment_efficiency': '90'}]},
#  '149': {'control_pce': '22.2',
#   'control_voc': '0.841',
#   'treated_pce': '24.3',
#   'treated_voc': '2.03',
#   'passivating_molecule': 'CF3-PA',
#   'perovskite_composition': 'FA0.75MA0.25Pb0.5Sn0.5I3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'VNPB',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '35',
#     'humidity': '30-50%',
#     'control_efficiency': '22.2',
#     'treatment_efficiency': '24.3'}]},
#  '1': {'control_pce': 20,
#   'control_voc': 1.18,
#   'treated_pce': 23.32,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'FA 1-x MA x PbI 3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 500,
#     'control_efficiency': 20,
#     'treatment_efficiency': 23.32}]},
#  '90': {'control_pce': 20.7,
#   'control_voc': 1.17,
#   'treated_pce': 20.7,
#   'treated_voc': 1.17,
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '41': {'control_pce': 20.71,
#   'control_voc': 1.135,
#   'treated_pce': 23.9,
#   'treated_voc': 1.157,
#   'passivating_molecule': 'o-PDEAI2',
#   'perovskite_composition': 'PDEAI2',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Humidity test',
#     'temperature': 40,
#     'time': '24 hours',
#     'humidity': '40-50% RH',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Thermal stability',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Module performance',
#     'temperature': 'Module performance',
#     'time': 'Module performance',
#     'humidity': 'Module performance',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 23.9}]}}

# %% [markdown]
# ### Subsetting the LLama Prediction since we only have 54 true lables

# %%
# Extract the subset from json_150 where keys match with json_54
subset_llama = {key: filtered_llama_data[key] for key in label_data.keys() if key in filtered_llama_data}

# Print the result
print(len(subset_llama))
# Out:
# 54

# %% [markdown]
# ## First, we will evaluate one pair of papers and adjust specific formatting

# %%
##0th paper prediction
subset_llama
# Out:
# {'19': {'treated_pce': 24.09,
#   'passivating_molecule': '3FPEA',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.9Pb(I0.95Br0.05)3',
#   'electron_transport_layer': '2PACz',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': 85,
#     'time': 1560,
#     'humidity': '50% RH',
#     'treatment_efficiency': 24.09}]},
#  '84': {'control_pce': 21.6,
#   'control_voc': 1.24,
#   'treated_pce': 23.2,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'DM',
#   'perovskite_composition': '(FAPbI3)0.95 (MAPbBr3)0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'DM',
#   'stability_tests': [{'test_name': 'thermal stability test',
#     'temperature': 60,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 70,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 80,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3}]},
#  '56': {'control_pce': 25.5,
#   'control_voc': 1.22,
#   'treated_pce': 20.5,
#   'treated_voc': 1.22,
#   'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '82': {'control_pce': '17.1',
#   'control_voc': '1.04',
#   'treated_pce': '20.59',
#   'treated_voc': '1.13',
#   'passivating_molecule': 'Choline chloride',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Humidity stability test',
#     'time': 'Over one month',
#     'humidity': '50-85% RH',
#     'control_efficiency': '17.1%',
#     'treatment_efficiency': '20.59%'}]},
#  '55': {'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'},
#    {'test_name': 'ISOS-L',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'}]},
#  '88': {'control_pce': 19.03,
#   'control_voc': 0.92,
#   'treated_pce': 21.46,
#   'treated_voc': 0.94,
#   'passivating_molecule': 'NaF',
#   'perovskite_composition': 'Cs0.05FA0.54MA0.41PbI0.98Br0.02)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1000,
#     'control_efficiency': 19.03,
#     'treatment_efficiency': 21.46}]},
#  '92': {'treated_pce': 21.3,
#   'passivating_molecule': 'BaSnO3',
#   'perovskite_composition': 'BaSnO3',
#   'electron_transport_layer': 'BaSnO3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD, PTAA',
#   'stability_tests': [{'temperature': 25,
#     'time': '24 hours',
#     'humidity': '40% RH',
#     'control_efficiency': 21.3,
#     'treatment_efficiency': 21.7}]},
#  '5': {'control_pce': 22.1,
#   'control_voc': 1135,
#   'treated_pce': 22.1,
#   'treated_voc': 1205,
#   'passivating_molecule': 'iso-BAI and n-BAI',
#   'perovskite_composition': 'FA(MA)PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '18': {'control_pce': '26%',
#   'passivating_molecule': 'TMAI',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'SnO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'lower'},
#    {'test_name': 'ISOS-L',
#     'temperature': 100,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'higher'}]},
#  '9': {'control_pce': 14.64,
#   'treated_pce': 17.6,
#   'passivating_molecule': 'C8',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'NiOx'},
#  '13': {'control_pce': 25.7,
#   'control_voc': 1.15,
#   'treated_pce': 15.1,
#   'treated_voc': 1.29,
#   'passivating_molecule': '2-thiopheneethylammonium chloride',
#   'perovskite_composition': 'Cs0.12FA0.8PbI1.8Br1.2',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': '2PACz',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 265,
#     'humidity': 'ambient',
#     'control_efficiency': 13.1,
#     'treatment_efficiency': 15.1}]},
#  '86': {'control_pce': 21.6,
#   'control_voc': 1.11,
#   'treated_pce': 21.6,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'EDTA-complexed SnO2',
#   'perovskite_composition': 'FA0.95Cs0.05PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 100,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6},
#    {'test_name': 'ISOS-LT',
#     'temperature': 60,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6}]},
#  '80': {'control_pce': 21.6,
#   'control_voc': 1.14,
#   'treated_pce': 21.6,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'PMMA',
#   'perovskite_composition': 'Mixed cation perovskite (FAI, PbI2, MABr, PbBr2)',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': '2 months',
#     'humidity': 'ambient air',
#     'control_efficiency': 21.0,
#     'treatment_efficiency': 21.0}]},
#  '89': {'treated_pce': '20.87%',
#   'treated_voc': '413 mV',
#   'passivating_molecule': 'formamidine acetate (FAAc)',
#   'perovskite_composition': '(FA, MA, Cs)Pb(I, Br)3'},
#  '46': {'control_voc': 1.12,
#   'treated_pce': 20,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'PFN-P2',
#   'perovskite_composition': 'CsPbI0.05[(FAPbI3)0.89]',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': 25,
#     'time': '100 hours',
#     'humidity': 'air',
#     'control_efficiency': 19.83,
#     'treatment_efficiency': 20}]},
#  '6': {'control_pce': '20.1',
#   'control_voc': '1.03',
#   'treated_pce': '15.3',
#   'treated_voc': '1.06',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'PEA2PbI4',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'null',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '100',
#     'time': '36',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-L',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '55',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '90',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'}]},
#  '114': {'control_pce': 20.76,
#   'control_voc': 1.06,
#   'treated_pce': 23.37,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Piperazinium iodide (PI)',
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': []},
#  '83': {'control_pce': '21.3',
#   'control_voc': '1.13',
#   'treated_pce': '21.38',
#   'treated_voc': '1.12',
#   'passivating_molecule': 'MAI and FA',
#   'perovskite_composition': 'MAPbI3 and FA0.15MA0.85PbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '792 hours',
#     'humidity': '40 ± 10%',
#     'control_efficiency': '21.3',
#     'treatment_efficiency': '21.38'}]},
#  '17': {'control_pce': 25.2,
#   'control_voc': 1.16,
#   'treated_pce': 22.02,
#   'treated_voc': 1.19,
#   'passivating_molecule': 'hexyltrimethylammonium bromide',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': '1F-PTAA',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': '1F-PTAA',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '90 min',
#     'humidity': 'N2-filled glove-box',
#     'control_efficiency': 20.04,
#     'treatment_efficiency': 22.16}]},
#  '53': {'control_pce': '4.9%',
#   'treated_pce': '24.7%',
#   'passivating_molecule': 'DMePDAI2',
#   'perovskite_composition': 'FA0.85MA0.1Cs0.05PbI2.9Br0.1',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': '40°C',
#     'time': '1000 hours',
#     'humidity': 'N2',
#     'control_efficiency': '20.5%',
#     'treatment_efficiency': '23.1%'}]},
#  '49': {'control_pce': '13.81',
#   'control_voc': '1.12',
#   'treated_pce': '16.25',
#   'treated_voc': '1.31',
#   'passivating_molecule': 'n-butylamine acetate (BAAc)',
#   'perovskite_composition': '(BA)2(MA)n-1Pb3n+1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '558',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '13.81',
#     'treatment_efficiency': '16.25'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65 ± 10%',
#     'time': '4680',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '49.4',
#     'treatment_efficiency': '93.8'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '85',
#     'time': '1100',
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': '70.8',
#     'treatment_efficiency': '96.2'}]},
#  '79': {'control_pce': 19.9,
#   'control_voc': 1.09,
#   'treated_pce': 19.9,
#   'treated_voc': 1.09,
#   'passivating_molecule': 'PbI2',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '40 days',
#     'humidity': 'dry air',
#     'control_efficiency': 19.9,
#     'treatment_efficiency': 19.9}]},
#  '90': {'control_pce': 20.7,
#   'control_voc': 1.17,
#   'treated_pce': 20.7,
#   'treated_voc': 1.17,
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '0': {'control_pce': '25.5',
#   'control_voc': '1.17',
#   'treated_pce': '24.7',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'formamidinium lead triiodide (FAPbI3)',
#   'electron_transport_layer': 'Cs2O',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '1500',
#     'humidity': '50',
#     'control_efficiency': '19.9',
#     'treatment_efficiency': '95'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65',
#     'time': '1200',
#     'humidity': '50',
#     'control_efficiency': '23.2',
#     'treatment_efficiency': '91'}]},
#  '47': {'treated_pce': 21.1,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'PbSO4',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 65,
#     'time': '1200 hours',
#     'humidity': 'air, RH ~60%',
#     'control_efficiency': 21.1,
#     'treatment_efficiency': 96.8}]},
#  '41': {'control_pce': 20.71,
#   'control_voc': 1.135,
#   'treated_pce': 23.9,
#   'treated_voc': 1.157,
#   'passivating_molecule': 'o-PDEAI2',
#   'perovskite_composition': 'PDEAI2',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Humidity test',
#     'temperature': 40,
#     'time': '24 hours',
#     'humidity': '40-50% RH',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Thermal stability',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Module performance',
#     'temperature': 'Module performance',
#     'time': 'Module performance',
#     'humidity': 'Module performance',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 23.9}]},
#  '40': {'control_pce': 24.3,
#   'control_voc': 1.2,
#   'treated_pce': 24.3,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'Oleylammonium iodide (OLAI)',
#   'perovskite_composition': 'Cs0.03(FA0.90MA0.10)PbI3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'damp-heat',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 24.3,
#     'treatment_efficiency': 19.3}]},
#  '12': {'control_pce': 16.7,
#   'control_voc': 1.23,
#   'treated_pce': 19.4,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylammonium bromide (BABr)',
#   'perovskite_composition': 'Cs0.17 FA0.83 Pb(I0.6 Br0.4)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'J-V measurements',
#     'temperature': 25,
#     'time': 'continuous illumination',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4},
#    {'test_name': 'PCE under different treatments',
#     'temperature': 25,
#     'time': 'under constant voltage',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4}]},
#  '59': {'control_pce': '19.07',
#   'control_voc': '1.25',
#   'treated_pce': '19.07',
#   'treated_voc': '1.25',
#   'passivating_molecule': 'phenethylammonium iodide',
#   'perovskite_composition': 'FA0.8Cs0.2PbI0.7Br0.3',
#   'electron_transport_layer': 'poly(triarylamine)',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '14': {'control_pce': 25.5,
#   'control_voc': 1.184,
#   'treated_pce': 23.7,
#   'treated_voc': 1.184,
#   'passivating_molecule': 'F-PEAI',
#   'perovskite_composition': 'Cs0.1FA0.9PbI2.9Br0.1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '50': {'control_pce': '11-12%',
#   'control_voc': '1.08 V',
#   'treated_pce': '14.4%',
#   'treated_voc': '1.05 V',
#   'passivating_molecule': 'allylamine',
#   'perovskite_composition': '(C4H9NH3+)2Pb10I29',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25 °C',
#     'time': '650 h',
#     'humidity': 'ambient',
#     'control_efficiency': '11.2%',
#     'treatment_efficiency': '14.4%'}]},
#  '58': {'control_pce': '25.5%',
#   'treated_pce': '18.5%',
#   'passivating_molecule': 'PCBM',
#   'perovskite_composition': 'FA0.83Cs0.17PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'poly-TPD or NiOx',
#   'stability_tests': []},
#  '2': {'control_pce': 0.2239,
#   'control_voc': 1098,
#   'treated_pce': 0.2459,
#   'treated_voc': 1185,
#   'passivating_molecule': '(BA)2PbI4',
#   'perovskite_composition': '(BA)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1056,
#     'humidity': '85% relative humidity',
#     'control_efficiency': 0.2239,
#     'treatment_efficiency': 0.2435}]},
#  '3': {'control_pce': 24.5,
#   'control_voc': 1.2,
#   'treated_pce': 24.5,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'BA2MA2Pb3I10',
#   'perovskite_composition': 'Cs0.05(MA0.10FA0.85)Pb(I0.90Br0.10)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': 55,
#     'time': 2000,
#     'humidity': '70% RH',
#     'control_efficiency': 21,
#     'treatment_efficiency': 22.93}]},
#  '81': {'control_pce': '20.1',
#   'control_voc': '1.06',
#   'treated_pce': '19.5',
#   'treated_voc': '1.15',
#   'passivating_molecule': 'Cl-capped TiO2 colloidal nanocrystal film',
#   'perovskite_composition': 'MAPbI3-xClx',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'dry',
#     'control_efficiency': 90,
#     'treatment_efficiency': 97}]},
#  '93': {'treated_pce': 20.5,
#   'perovskite_composition': 'FA1-x MAx PbI2.87 Br0.13(Cl)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '10': {'treated_pce': 24.41,
#   'treated_voc': 4.77,
#   'passivating_molecule': 'OATsO',
#   'perovskite_composition': '(FAPbI3)0.95((MAPbBr3)0.05)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'test_name': 'OC',
#     'temperature': 40,
#     'time': '1,000 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41},
#    {'test_name': 'MPP',
#     'temperature': 40,
#     'time': '800 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41}]},
#  '15': {'control_pce': '21.78',
#   'control_voc': '1.11',
#   'treated_pce': '23.34',
#   'treated_voc': '1.15',
#   'passivating_molecule': 'Cl-PEAI and F-PEAI',
#   'perovskite_composition': 'Cs0.05(FA5/6MA1/6)0.95PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '149': {'control_pce': '22.2',
#   'control_voc': '0.841',
#   'treated_pce': '24.3',
#   'treated_voc': '2.03',
#   'passivating_molecule': 'CF3-PA',
#   'perovskite_composition': 'FA0.75MA0.25Pb0.5Sn0.5I3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'VNPB',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '35',
#     'humidity': '30-50%',
#     'control_efficiency': '22.2',
#     'treatment_efficiency': '24.3'}]},
#  '11': {'control_pce': '20.2',
#   'control_voc': '1.11',
#   'treated_pce': '21.8',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'BTaBr',
#   'perovskite_composition': '(BTa)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '24 hours',
#     'humidity': 'ambient air',
#     'control_efficiency': '21.8',
#     'treatment_efficiency': '21.8'}]},
#  '7': {'control_pce': 23.5,
#   'control_voc': 1.2,
#   'treated_pce': 28.7,
#   'treated_voc': 1.5,
#   'passivating_molecule': '4-FPEA',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Au',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '24 hours',
#     'humidity': '50% RH',
#     'control_efficiency': 22.5,
#     'treatment_efficiency': 28.7},
#    {'test_name': 'ISOS-L',
#     'temperature': 60,
#     'time': '48 hours',
#     'humidity': '30% RH',
#     'control_efficiency': 23.5,
#     'treatment_efficiency': 28.7}]},
#  '1': {'control_pce': 20,
#   'control_voc': 1.18,
#   'treated_pce': 23.32,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'FA 1-x MA x PbI 3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 500,
#     'control_efficiency': 20,
#     'treatment_efficiency': 23.32}]},
#  '117': {'control_pce': 22.2,
#   'control_voc': 1.15,
#   'treated_pce': 25.1,
#   'treated_voc': 1.17,
#   'passivating_molecule': '4-tert-butyl-1-methylpyridinium bis(trifluoromethanesulfonyl)imide (TBMP + TFSI -)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Stability test',
#     'temperature': '70 ± 5% RH',
#     'time': 'Long-term exposure',
#     'humidity': 'High relative humidity',
#     'control_efficiency': '22.2%',
#     'treatment_efficiency': '25.1%'}]},
#  '42': {'control_pce': 19.52,
#   'control_voc': 1.07,
#   'treated_pce': 22.03,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'AzPbI3',
#   'perovskite_composition': 'Cs0.05 MA0.1 FA0.85 PbI2.7 Br0.3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 52,
#     'time': 1000,
#     'control_efficiency': 47,
#     'treatment_efficiency': 85}]},
#  '43': {'control_pce': '24.50%',
#   'control_voc': '1.150 V',
#   'treated_pce': '24.50%',
#   'treated_voc': '1.121 V',
#   'passivating_molecule': 'Benzylamine hydroiodide (BAHI)',
#   'perovskite_composition': 'FA0.90MA0.10PbI3•(CsPbI3)0.05 with excess PbI2',
#   'electron_transport_layer': 'TiO2 (mesoporous)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '80 °C',
#     'time': '500 h',
#     'humidity': '20-30% RH',
#     'control_efficiency': '24.50%',
#     'treatment_efficiency': '47.96 ± 3.21%'}]},
#  '85': {'control_pce': 16,
#   'control_voc': 0.8,
#   'treated_pce': 22.7,
#   'treated_voc': 1.0,
#   'passivating_molecule': 'n-hexyl trimethyl ammonium bromide',
#   'perovskite_composition': 'FAPbI3:MAPbBr3:HTAB = 0.3:0.95:0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'P3HT',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1008,
#     'humidity': '85%',
#     'control_efficiency': 80,
#     'treatment_efficiency': 0}]},
#  '8': {'control_pce': '20.1',
#   'control_voc': '1.16',
#   'treated_pce': '23.0',
#   'treated_voc': '1.177',
#   'passivating_molecule': 'PREA',
#   'perovskite_composition': 'CsPbI2Br',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'ambient',
#     'control_efficiency': '85',
#     'treatment_efficiency': '60'}]},
#  '116': {'control_pce': 23.44,
#   'control_voc': 1.152,
#   'treated_pce': 24.82,
#   'treated_voc': 1.1814,
#   'passivating_molecule': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': 500,
#     'control_efficiency': 13.74,
#     'treatment_efficiency': 87}]},
#  '91': {'control_pce': '19.66',
#   'control_voc': '1.027',
#   'treated_pce': '24.02',
#   'treated_voc': '1.130',
#   'passivating_molecule': 'methylammonium chloride (MACl)',
#   'perovskite_composition': 'formamidinium lead iodide (FAPbI3)',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '1200 hours',
#     'humidity': 'Room temperature',
#     'control_efficiency': '90',
#     'treatment_efficiency': '90'},
#    {'test_name': 'ISOS-L',
#     'temperature': 40,
#     'time': '300 hours',
#     'humidity': '40°C',
#     'control_efficiency': '60',
#     'treatment_efficiency': '90'}]},
#  '57': {'treated_pce': 22.5,
#   'treated_voc': 1.098,
#   'perovskite_composition': 'MA 0.07 FA 0.93 PbI 3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'pin',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'temperature': 25,
#     'time': 350,
#     'control_efficiency': 22.5,
#     'treatment_efficiency': 22.5}]},
#  '87': {'treated_pce': 21.52,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'FAI',
#   'perovskite_composition': 'CsI:20 mg, PbI2:530 mg, PbBr2:20 mg, PbCl2:20 mg, MAI:5 mg',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'temperature': 85,
#     'time': 1500,
#     'control_efficiency': 100,
#     'treatment_efficiency': 89}]},
#  '115': {'control_pce': '24.04',
#   'control_voc': '0.08 cm²',
#   'treated_pce': '23.15',
#   'treated_voc': '23.15',
#   'passivating_molecule': 'anisole',
#   'perovskite_composition': 'FA1-x-yMAxCsyPbI3-zBrz',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '95%',
#     'treatment_efficiency': '75%'},
#    {'test_name': 'SPO',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '5%',
#     'treatment_efficiency': '20%'}]},
#  '16': {'control_pce': 18.87,
#   'control_voc': 1.04,
#   'treated_pce': 21.05,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'CF3PEAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '48': {'control_pce': '16.9',
#   'control_voc': '1.07',
#   'treated_pce': '20.3',
#   'treated_voc': '1.10',
#   'passivating_molecule': 'Fluoro-silane',
#   'perovskite_composition': 'Perovskite films',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA:F4-TCNQ',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 'Room temperature',
#     'time': 'After fabrication',
#     'humidity': '40%',
#     'control_efficiency': '16.9',
#     'treatment_efficiency': '18.9'}]}}

# %%
#The actual label
clean_label_data
# Out:
# {'0': {'control_pce': '24',
#   'structure_pin_nip': 'PIN',
#   'test_1': {'efficiency_tret': '95%',
#    'time': '1200',
#    'stability_type': 'ISOSL',
#    'temperature': '65',
#    'treatment_element': '4-chlorobenzenesulfonate (4Cl-BZS)'},
#   'passivating_molecule': '4-chlorobenzenesulfonate (4Cl-BZS)',
#   'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3',
#   'hole_transport_layer': '2PACz and Me-4PACz',
#   'treated_pce': '26.9',
#   'treated_voc': '1.18',
#   'electron_transport_layer': 'C60'},
#  '1': {'passivating_molecule': 'phenethylammonium',
#   'treated_pce': '23.32',
#   'electron_transport_layer': ['HC(NH 2 ) 2 -CH 3 NH 3', 'SnO 2'],
#   'structure_pin_nip': 'PIN',
#   'hole_transport_layer': ['Spiro-OMeTAD',
#    'poly[bis(4-phenyl) (2,4,6-trimethylphenyl)amine] (PTAA)'],
#   'treated_voc': '1.16',
#   'test_1': {'temperature': '85',
#    'time': '500',
#    'stability_type': 'ISOST',
#    'treatment_element': 'phenethylammonium',
#    'treated_pce': '19.1'}},
#  '5': {'structure_pin_nip': 'NIP',
#   'passivating_molecule': ['iso-butylamine iodide', 'BAI'],
#   'electron_transport_layer': ['indium tin oxide', 'C 60'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_1': {'treatment_element': 'iso-butylamine iodide',
#    'treated_voc': '1.135',
#    'treated_pce': '22.1'},
#   'perovskite_composition': 'butylammonium lead iodide'},
#  '6': {'passivating_molecule': ['phenylethylammonium iodide',
#    'methylammonium iodide'],
#   'treated_pce': '15.3',
#   'perovskite_composition': 'Methylammonium Lead Iodide',
#   'electron_transport_layer': 'Titanium dioxide',
#   'test_1': {'treated_pce': '16.6',
#    'time': '1344',
#    'efficiency_tret': '0.97',
#    'stability_type': 'ISOSD',
#    'treatment_element': 'n=10'},
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_1': {'treatment_element': 'n=60',
#    'treated_voc': '1.06',
#    'treated_pce': '18.40'},
#   'performance_2': {'treatment_element': 'n=40',
#    'treated_voc': '1.09',
#    'treated_pce': '18.24'},
#   'performance_3': {'treatment_element': 'n=10',
#    'treated_voc': '1.16',
#    'treated_pce': '18.89'}},
#  '7': {'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'C 60',
#   'passivating_molecule': 'phenethylammonium',
#   'perovskite_composition': ['4-bromophenylethylammonium',
#    '4-chlorophenylethylammonium'],
#   'test_1': {'passivating_molecule': '(EDBE)PbI 4',
#    'efficiency_tret': '0.9',
#    'time': '1000',
#    'humidity': '65'}},
#  '8': {'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'Tin Oxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_1': {'perovskite_molecule': 'ethylammonium',
#    'treated_pce': '22.4',
#    'control_element': 'without PREA',
#    'treatment_element': 'ethylammonium',
#    'control_pce': '19.3',
#    'treated_voc': '1.177'},
#   'performance_2': {'perovskite_molecule': 'methylammonium',
#    'treated_pce': '20.9',
#    'treated_voc': '1.167'},
#   'performance_3': {'perovskite_molecule': 'pyrene-based ammonium',
#    'treated_pce': '19.5',
#    'treated_voc': '1.066'},
#   'test_1': {'temperature': '40',
#    'time': '2000',
#    'stability_type': 'ISOSLT',
#    'treatment_element': 'ethylammonium',
#    'efficiency_tret': '0.85',
#    'efficiency_cont': '0.6'},
#   'perovskite_molecule': 'ethylammonium pyrene'},
#  '9': {'passivating_molecule': ['diammonium iodides', 'C8', 'EDBE'],
#   'electron_transport_layer': 'PCBM',
#   'perovskite_composition': 'CH 3 NH 3 PbI 3',
#   'treated_pce': '17.6',
#   'control_pce': '14.64'},
#  '10': {'passivating_molecule': ['octylammonium tosylate',
#    'OABF4',
#    'intermediate negative ΔE vac'],
#   'electron_transport_layer': 'TinOxide',
#   'hole_transport_layer': ['Spiro-OMeTAD', 'spiro-MeOTAD'],
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'perovskite_molecule': ['formamidinium', 'methylammonium'],
#   'treated_pce': '24.41',
#   'test_1': {'stability_type': 'ISOSL',
#    'temperature': '40',
#    'treatment_element': 'OATsO',
#    'efficiency_tret': '0.915',
#    'time': '500',
#    'passivating_molecule': 'OABF4'}},
#  '11': {'perovskite_molecule': 'benzotriazole',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'temperature': 'room temperature',
#    'control_pce': '20.2',
#    'treated_voc': '1.16',
#    'additive_molecule': 'BTaBr',
#    'treated_pce': '21.8',
#    'stability_type': 'ISOSL',
#    'time': '24',
#    'efficiency_cont': '0.98',
#    'efficiency_tret': '1.02'},
#   'structure_pin_nip': 'NIP',
#   'control_voc': '1.11'},
#  '12': {'passivating_molecule': 'butylammonium bromide',
#   'control_voc': ['1.24', '17.5'],
#   'treated_voc': '1.31',
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '19.8',
#   'test_1': {'efficiency_tret': 'exhibit stable V OC over time',
#    'stability_type': 'ISOSL',
#    'time': '20'},
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': 'Cs0.15FA0.85PbI2.19Br0.81'},
#  '13': {'passivating_molecule': '2-thiopheneethylammonium chloride',
#   'treated_voc': '1.29',
#   'test_1': {'treated_voc': '1.29',
#    'treated_pce': '23.8',
#    'treatment_element': '2-thiopheneethylammonium chloride',
#    'control_element': 'without TEACl PDT',
#    'stability_type': 'ISOST',
#    'temperature': '60',
#    'efficiency_tret': '0.92',
#    'time': '195 h',
#    'efficiency_cont': '0.82',
#    'control_pce': '(T80: ≈9 h'},
#   'electron_transport_layer': 'PCBM',
#   'perovskite_composition': 'Cs 0.12 FA 0.8 MA 0.08 PbI 1.8 Br 1.',
#   'structure_pin_nip': 'PIN'},
#  '14': {'treatment_element': 'phenethylammonium iodide',
#   'passivating_molecule': ['chlorophenylethylammonium iodide',
#    'fluorophenylethylammonium iodide'],
#   'treated_pce': '23.7',
#   'treated_voc': '1.184',
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'PCBM',
#   'test_1': {'treatment_element': 'phenethylammonium iodide',
#    'stability_type': 'ISOSL',
#    'efficiency_cont': '0.9',
#    'time': '33',
#    'efficiency_tret': '1',
#    'control_voc': '1.109',
#    'control_pce': '21.58'},
#   'perovskite_composition': ['Cs 0.1 FA 0.9 PbI 2.9 Br 0.1',
#    'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.85 Br 0.15 ) 3'],
#   'structure_pin_nip': 'PIN'},
#  '15': {'structure_pin_nip': 'PIN',
#   'passivating_molecule': ['chlorophenylethylammonium iodide',
#    '4-fluoro-phenylethylammonium iodide'],
#   'perovskite_composition': 'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.9 Br 0.1 ) 3',
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'PCBM',
#   'control_pce': '21.78',
#   'control_voc': '1.11',
#   'treated_voc': '1.17',
#   'treated_pce': '23.79'},
#  '16': {'structure_pin_nip': ['NIP',
#    'glass/ITO/PEDOT:PSS/perovskite/spiro-OMeTAD/Ag'],
#   'passivating_molecule': 'CF3-phenethylammonium',
#   'electron_transport_layer': 'TinOxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FAPbI3',
#   'control_voc': '1.04',
#   'control_pce': '18.87',
#   'treated_voc': '1.11',
#   'treated_pce': '21.05'},
#  '17': {'treatment_element': 'hexyltrimethyl ammouniumbromide',
#   'structure_pin_nip': 'NIP',
#   'control_element': 'without HTAB',
#   'test_1': {'treatment_element': 'hexyltrimethyl ammouniumbromide',
#    'treated_pce': '18.5',
#    'time': '48',
#    'efficiency_tret': '0.86',
#    'stability_type': 'ISOSL'},
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'SnO 2',
#   'perovskite_composition': 'Cs 0.05 FA 0.81 MA 0.14 PbI 2.55 Br 0.45',
#   'control_voc': '1.16',
#   'control_pce': '20.04',
#   'treated_voc': '1.19',
#   'treated_pce': '20.94'},
#  '18': {'passivating_molecule': ['phenylethylammonium',
#    '2-thiophenemethylammonium iodide'],
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'Tin Oxide',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '19': {'test_1': {'passivating_molecule': 'fluorinated aniliniums',
#    'treated_pce': '24.09%',
#    'temperature': '85',
#    'humidity': '50',
#    'time': '1560',
#    'stability_type': 'ISOSLT'},
#   'perovskite_composition': ['Cs 0.05 MA 0.05 FA 0.9 Pb(I 0.95 Br 0.05 ) 3',
#    'Cs 0.05 MA 0.15 FA 0.8 PbI 3'],
#   'passivating_molecule': '3,4,5-trifluoroanilinium',
#   'hole_transport_layer': '2PACz',
#   'test_2': {'stability_type': 'ISOSL',
#    'humidity': '50',
#    'temperature': '85',
#    'treated_pce': '21.5',
#    'time': '1586',
#    'efficiency_tret': '0.84'},
#   'electron_transport_layer': 'C60',
#   'control_pce': '21',
#   'control_voc': '1.269',
#   'treated_voc': '1.271'},
#  '20': {'passivating_molecule': 'phenylethylammonium lead iodide',
#   'perovskite_composition': 'Methylammonium Lead Iodide'},
#  '21': {'hole_transport_layer': 'Spiro-OMeTAD',
#   'electron_transport_layer': 'Titanium dioxide',
#   'perovskite_composition': '(FAPbI3)0.92(MAPbBr3)0.08',
#   'treated_pce': '22.6'},
#  '22': {'perovskite_composition': 'Formamidinium lead triiodide',
#   'passivating_molecule': 'cyclohexylmethylammonium iodide dissolved in',
#   'additive_molecule': ['isopropanol', 'chloroform'],
#   'test_3': {'control_element': 'pristine perovskite film',
#    'temperature': '50',
#    'humidity': '40',
#    'stability_type': 'ISOSD2',
#    'time': '500',
#    'treatment_element': 'chloroform',
#    'efficiency_tret': 'isopropanol',
#    'efficiency_cont': '0.4'},
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '21.07',
#   'treated_voc': '1.154',
#   'test_1': {'stability_type': 'ISOSL',
#    'humidity': '20-30',
#    'time': '2400',
#    'efficiency_tret': '0.91',
#    'treatment_element': 'isopropanol',
#    'efficiency_cont': '0.85'},
#   'test_2': {'stability_type': 'ISOSLT',
#    'temperature': '25',
#    'efficiency_cont': '0.76',
#    'time': '1050',
#    'treatment_element': 'chloroform',
#    'efficiency_tret': '0.95'},
#   'performance_1': {'additive_molecule': 'isopropanol',
#    'treated_pce': '23.77',
#    'treated_voc': '1.145'},
#   'performance_2': {'additive_molecule': 'chloroform',
#    'treated_pce': '23.94',
#    'treated_voc': '1.149',
#    'control_voc': '1.092',
#    'control_pce': '21.40'}},
#  '23': {'structure_pin_nip': 'NIP',
#   'perovskite_composition': ['Tin dioxide', 'Cs 0.05 MA 0.1 FA 0.85 PbI 3'],
#   'perovskite_molecule': ['methylammonium', 'FA'],
#   'additive_molecule': 'methylammonium iodide',
#   'passivating_molecule': 'phenethylammonium iodide',
#   'treated_pce': '23.91',
#   'test_1': {'temperature': '25',
#    'humidity': '50',
#    'time': '1000',
#    'efficiency_tret': '1',
#    'stability_type': 'ISOSL1'},
#   'test_2': {'stability_type': 'ISOSL3',
#    'efficiency_tret': '0.92',
#    'time': '500',
#    'treatment_element': '2D post-treatmen',
#    'temperature': '65'},
#   'treated_voc': '1.15'},
#  '24': {'perovskite_composition': 'Cesium lead iodide',
#   'treatment_element': 'dicesium diododichloroplumbate',
#   'treated_pce': '17.4',
#   'hole_transport_layer': 'copper(I) thiocyanate',
#   'electron_transport_layer': 'Titanium dioxide',
#   'test_1': {'stability_type': 'ISOSD',
#    'treatment_element': 'dicesium diododichloroplumbate',
#    'treated_pce': '17.4',
#    'time': '2100',
#    'temperature': '110',
#    'efficiency_tret': '0.8'},
#   'control_pce': '14.9'},
#  '25': {'additive_molecule': 'formamidinium',
#   'perovskite_composition': 'formamidinium lead iodide'},
#  '26': {'perovskite_composition': ['Methylammonium Lead Chloride',
#    'MAPbBr 3',
#    'MAPbI 3']},
#  '27': {'passivating_molecule': 'trifluoromethylphenylethylammonium',
#   'structure_pin_nip': 'NIP',
#   'treatment_element': 'buckminsterfullerene',
#   'treated_voc': '1.23',
#   'treated_pce': '18.5',
#   'test_1': {'treatment_element': 'buckminsterfullerene',
#    'treated_pce': '18.5',
#    'treated_voc': '1.23',
#    'time': '2000',
#    'efficiency_tret': '1',
#    'stability_type': 'ISOSLT'}},
#  '28': {'perovskite_composition': 'Cesium lead iodide'},
#  '30': {'treatment_element': ['ammonia post-healing', 'NH 3 -FACsPbI 3'],
#   'treated_pce': '23.21',
#   'structure_pin_nip': 'NIP',
#   'test_1': {'treated_pce': '23.21',
#    'treated_voc': '1.16',
#    'control_pce': '10.92',
#    'control_element': 'formamidinium cesium lead iodide',
#    'stability_type': 'ISOSLT',
#    'time': '500',
#    'perovskite_composition': 'ammonia healed formamidinium cesium lead iodide',
#    'efficiency_tret': '0.8'},
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'electron_transport_layer': ['Titanium dioxide', 'SnO 2']},
#  '31': {'passivating_molecule': '3-(aminomethyl)pyridine',
#   'structure_pin_nip': 'PIN',
#   'efficiency_tret': '0.87',
#   'temperature': '55',
#   'hole_transport_layer': 'MeO-2PACZ',
#   'perovskite_composition': 'Rb0.05Cs0.05MA0.05FA0.85Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'control_pce': '23.39',
#   'treated_pce': '25.49',
#   'treated_voc': '1.19',
#   'test_3': {'treatment_element': '3-(aminomethyl)pyridine',
#    'temperature': '85',
#    'humidity': '85',
#    'perovskite_composition': 'ISOSD3',
#    'efficiency_tret': '0.94',
#    'time': '850'},
#   'test_1': {'stability_type': 'ISOSLT',
#    'temperature': '55',
#    'efficiency_tret': '0.87',
#    'time': '2428',
#    'efficiency_cont': '0.76'},
#   'test_2': {'temperature': '65',
#    'stability_type': 'ISOSL2',
#    'efficiency_tret': '0.9',
#    'time': '1315'}},
#  '32': {'perovskite_composition': 'Methylammonium Lead Iodide'},
#  '33': {'additive_molecule': 'benzene',
#   'perovskite_composition': 'formamidinium lead iodide'},
#  '35': {'perovskite_composition': '(CsPbI3)0.05[(FAPbI3)0.83(MAPbBr3)0.17]0.95',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '36': {'structure_pin_nip': 'PIN',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'perovskite_composition': 'FA0.8MA0.2PbI 3',
#   'passivating_molecule': 'tri-octyl phosphine oxide',
#   'hole_transport_layer': 'poly(triarylamine)',
#   'control_voc': ['21.2', '1.079'],
#   'treated_pce': '22.46',
#   'treated_voc': '1.098'},
#  '37': {'passivating_molecule': '1,3-propylene diammonium',
#   'test_1': {'treated_voc': '1.35',
#    'treated_pce': '19.0',
#    'time': '700',
#    'treatment_element': '1,3-propylene diammonium',
#    'efficiency_tret': '1'},
#   'test_2': {'treated_voc': '2.19',
#    'treated_pce': '26.3',
#    'efficiency_tret': '0.86',
#    'time': '500'}},
#  '39': {'hole_transport_layer': 'Spiro-OMeTAD',
#   'passivating_molecule': '2-thiophenemethylammonium bromide',
#   'perovskite_composition': '(FAPbI 3 ) 0.87(MAPbBr3)0.13]0.92(CsPbI3)0.08',
#   'performance_1': {'passivating_molecule': '2-thiophenemethylammonium bromide',
#    'treated_voc': '1.153'},
#   'performance_2': {'passivating_molecule': '2-thiophenemethylammonium bromide',
#    'treated_voc': '1.193',
#    'treated_pce': '20.82',
#    'control_voc': '1.09',
#    'control_pce': '20.7'},
#   'performance_3': {'passivating_molecule': '2-thiophenemethylammonium bromide',
#    'treated_voc': '1.175'},
#   'test_1': {'stability_type': 'ISOSLT',
#    'time': '1000',
#    'efficiency_cont': '0.65',
#    'treatment_element': '2-thiophenemethylammonium bromide',
#    'efficiency_tret': '0.75'},
#   'electron_transport_layer': 'Titanium dioxide'},
#  '40': {'test_1': {'stability_type': 'ISOSD',
#    'temperature': '85',
#    'humidity': '85',
#    'treatment_element': 'oleylammonium iodide',
#    'treated_pce': '24.3',
#    'efficiency_tret': '0.95',
#    'time': '1000'},
#   'hole_transport_layer': 'PTAA'},
#  '41': {'treated_pce': '23.9',
#   'time': '1000',
#   'passivating_molecule': ['ortho-(phenylene)di(ethylammonium) iodide',
#    'lightsoaking conditions',
#    'spiro-OMeTAD'],
#   'structure_pin_nip': 'NIP',
#   'treated_voc': '1.157',
#   'control_pce': '21.94',
#   'control_voc': '1.135',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'humidity': '40-50',
#    'efficiency_cont': '0.58',
#    'control_pce': '20.82',
#    'time': '1008',
#    'efficiency_tret': '0.85',
#    'treated_pce': '22.65'},
#   'test_2': {'stability_type': 'ISOST',
#    'temperature': '85',
#    'treatment_element': 'ortho-(phenylene)di(ethylammonium) iodide',
#    'passivating_molecule': '22.38',
#    'efficiency_tret': '0.75',
#    'time': '1000',
#    'efficiency_cont': '0.51',
#    'control_pce': '20.32'},
#   'test_3': {'passivating_molecule': 'ISOSLT',
#    'treatment_element': 'ortho-(phenylene)di(ethylammonium) iodide',
#    'efficiency_tret': '0.9',
#    'time': '1100',
#    'efficiency_cont': '0.6'}},
#  '42': {'passivating_molecule': 'azetidinium lead iodide',
#   'treated_pce': '22.4',
#   'treated_voc': ['1.18', '1.14'],
#   'structure_pin_nip': 'secondary perovskite growth',
#   'perovskite_composition': 'Cs 0.05 MA 0.1 FA 0.85 PbI 2.7 Br 0.3',
#   'test_1': {'treatment_element': 'azetidinium lead iodide',
#    'stability_type': 'ISOSL',
#    'time': '1000',
#    'temperature': '52',
#    'efficiency_tret': '0.85',
#    'efficiency_cont': '0.47'},
#   'control_voc': '1.07'},
#  '43': {'treatment_element': 'Chemical polishing of perovskite surface',
#   'control_pce': '23.07',
#   'treated_pce': '24.50',
#   'perovskite_composition': 'formamidinium lead iodide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'control_element': 'untreated perovskite film',
#    'treatment_element': 'Chemical Polishing',
#    'efficiency_cont': '0.0965',
#    'efficiency_tret': '0.4796',
#    'stability_type': 'ISOSD',
#    'humidity': '80',
#    'time': '500'},
#   'control_voc': '1.121',
#   'treated_voc': '1.150'},
#  '44': {'structure_pin_nip': 'PIN',
#   'treated_pce': '21.12',
#   'electron_transport_layer': ['heavily doped polycrystalline silicon,n-type',
#    'SiOx']},
#  '45': {'electron_transport_layer': ['heavily doped polycrystalline silicon',
#    'SiO 2']},
#  '46': {'stability_type': 'ISOSLT',
#   'test_1': {'humidity': '25',
#    'treatment_element': 'PFN-P2',
#    'treated_pce': '19.6',
#    'passivating_molecule': '1.143',
#    'time': '100',
#    'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.6'},
#   'time': '100',
#   'passivating_molecule': ['Lithium Fluoride',
#    'poly[(9,9-bis(30-((N,N-dimethyl)-N-ethylammonium)-propyl)-2,7-fluorene)alt-2,7-(9,9-dioctylfluorene)] dibromide'],
#   'structure_pin_nip': 'PIN',
#   'perovskite_composition': 'CsPbI 0.05 [(FAPbI 3 ) 0.89 (MAPbBr 3 ) 0.11 ] 0.95',
#   'treated_voc': '1.16 V'},
#  '47': {'hole_transport_layer': 'PTAA',
#   'perovskite_composition': ['Cs0.05FA0.81MA0.14PbI2.55Br0.45', 'MAPbI3'],
#   'stability_type': 'ISOSLT',
#   'humidity': '60',
#   'temperature': '65',
#   'additive_molecule': 'capping lead oxysalt thin layers',
#   'test_1': {'treatment_element': 'CsFAMA',
#    'efficiency_tret': '0.968',
#    'stability_type': 'ISOSLT',
#    'time': '1200',
#    'temperature': '65',
#    'treated_pce': '24.2',
#    'control_pce': '18.2'}},
#  '48': {'hole_transport_layer': 'PTAA',
#   'control_voc': '1.07',
#   'control_pce': '16.9',
#   'performance_1': {'passivating_molecule': 'PS Plastic Foam 1%',
#    'treated_voc': '1.10',
#    'treated_pce': '20.3'},
#   'structure_pin_nip': 'PIN'},
#  '49': {'passivating_molecule': ['n-butylamine acetate',
#    'n-butylamine iodide'],
#   'treated_pce': '16.25',
#   'treated_voc': '1.31',
#   'electron_transport_layer': 'indium tin oxide',
#   'hole_transport_layer': ['Spiro-OMeTAD', 'spiro-OMeTAD/chlorobenzene'],
#   'test_1': {'stability_type': 'ISOSL',
#    'humidity': '65',
#    'time': '4680',
#    'treatment_element': 'QW device',
#    'efficiency_tret': '0.938',
#    'control_element': 'MQW device',
#    'efficiency_cont': '0.506'},
#   'test_2': {'stability_type': 'ISOST',
#    'efficiency_tret': '0.957',
#    'temperature': '85',
#    'time': '558',
#    'efficiency_cont': '0.591'},
#   'test_3': {'treatment_element': 'QW device',
#    'efficiency_tret': '0.962',
#    'stability_type': 'ISOSL',
#    'time': '1100',
#    'control_element': 'MQW device',
#    'efficiency_cont': '0.708'}},
#  '50': {'passivating_molecule': ['allylammonium',
#    'phenethylammonium',
#    'butylammonium'],
#   'test_1': {'treated_pce': '16.5',
#    'treatment_element': 'allylammonium',
#    'efficiency_tret': '0.9',
#    'time': '650',
#    'passivating_molecule': 'ISOSL'},
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_1': {'passivating_molecule': 'allylammonium',
#    'treated_pce': '21',
#    'treatment_element': 'ALA 2 (MA 0.14 FA 0.81 Cs 0.05 ) 9 -Pb 10 (I 0.85 Br 0.15 ) 29'},
#   'performance_2': {'treated_pce': '12.1',
#    'passivating_molecule': 'phenethylammonium'},
#   'performance_3': {'treated_pce': '11.5',
#    'passivating_molecule': 'butylammonium'}},
#  '51': {'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'Methylammonium Lead Iodide',
#   'additive_molecule': 'quaternary ammonium iodide'},
#  '53': {'passivating_molecule': 'DMePDAI 2',
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': ['TitaniumDioxide', 'SnO 2'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FA0.85MA0.1Cs0.05PbI2.9Br0.1',
#   'test_1': {'treatment_element': 'DMePDAI 2',
#    'stability_type': 'ISOSL1',
#    'control_pce': '22.0',
#    'treated_pce': '24.7',
#    'perovskite_composition': 'FA0.97MA0.03PbI2.91Br0.09',
#    'temperature': '40',
#    'efficiency_tret': '0.9',
#    'time': '1000',
#    'efficiency_cont': '0.57'},
#   'treatment_element': ['DMePDAPbI4', 'BDAI2'],
#   'test_2': {'stability_type': 'ISOSD',
#    'humidity': '85',
#    'time': '740',
#    'efficiency_cont': '0.27',
#    'efficiency_tret': '0.73'},
#   'test_3': {'treatment_element': 'DMePDAPbI4',
#    'stability_type': 'ISOST',
#    'temperature': '85',
#    'time': '1008',
#    'humidity': '5',
#    'efficiency_cont': '0.29',
#    'efficiency_tret': '0.81'},
#   'efficiency_tret': '0.53'},
#  '54': {'structure_pin_nip': 'NIP',
#   'performance_1': {'perovskite_composition': 'Cs0.17FA0.83Pb(I0.83Br0.17)3',
#    'treated_pce': '17.7'},
#   'performance_2': {'perovskite_composition': 'Methylammonium Lead Iodide',
#    'treated_pce': '13'},
#   'performance_3': {'perovskite_composition': 'MAPb(I0.33Br0.67)3',
#    'treated_pce': '6'},
#   'performance_4': {'perovskite_composition': 'Methylammonium Lead Bromide',
#    'treated_pce': '3.2'}},
#  '55': {'perovskite_composition': 'methylammonium lead iodide',
#   'perovskite_molecule': ['Iodide ion', 'Pb 2 þ', 'CH 3 NH 3 þ']},
#  '56': {'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3',
#   'hole_transport_layer': ['4-ethylenedioxythiophene) polystyrene sulfonate,poly(3',
#    'Spiro-OMeTAD'],
#   'electron_transport_layer': ['indium-doped tin oxide', 'C 60', 'TiO 2'],
#   'structure_pin_nip': 'NIP'},
#  '57': {'structure_pin_nip': 'PIN',
#   'perovskite_composition': ['MA0.07FA0.93PbI3',
#    'Cs 0.05 (FA 0.83 MA 0.17 ) 0.95 Pb(I 0.83 Br 0.17 ) 3'],
#   'hole_transport_layer': 'poly(triarylamine)',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'treated_pce': '22.5',
#   'treated_voc': '1.098',
#   'test_1': {'stability_type': 'ISOSLT',
#    'temperature': '27',
#    'efficiency_tret': '0.95',
#    'time': '350',
#    'treated_pce': '21'}},
#  '58': {'electron_transport_layer': ['Tin Oxide', 'C 60'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FA0.83Cs0.17Pb(I0.83Br0.17)3',
#   'treated_pce': '18.5'},
#  '59': {'passivating_molecule': ['phenethylammonium iodide',
#    'glass/ITO/PTAA/FA 0.8 Cs 0.2 Pb-(I 0.7 Br 0.3 ) 3 /C 60 /bathocuproine (BCP)/Ag'],
#   'treated_pce': ['19.07', '18.6%'],
#   'treated_voc': '1.25',
#   'perovskite_composition': ['FA 0.8 Cs 0.2 Pb(I 0.7 Br 0.3 ) 3', 'MAPbI 3'],
#   'structure_pin_nip': 'poly(triarylamine) (PTAA)/ indium tin oxide (ITO)/glass substrates',
#   'additive_molecule': 'Pb(SCN) 2',
#   'control_voc': '1.16',
#   'control_pce': '17.5'},
#  '60': {'hole_transport_layer': 'Spiro-OMeTAD',
#   'passivating_molecule': ['vinylbenzylammonium bromide',
#    't prolonging the exposure of 3D perovskite surfaces to a dilute ligand-solution modifies the width distribution of quantum wells in the 2D/3D heterojunction.'],
#   'electron_transport_layer': 'TinOxide',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'structure_pin_nip': 'NIP',
#   'treatment_element': '30 s of soaking time',
#   'treated_pce': '21.7'},
#  '61': {'passivating_molecule': 'methylammonium lead iodide',
#   'additive_molecule': 'butylamine vapor',
#   'structure_pin_nip': 'NIP',
#   'test_2': {'treatment_element': 'butylamine vapor',
#    'additive_molecule': 'ISOSL',
#    'temperature': 'room temperature',
#    'humidity': '40',
#    'efficiency_tret': '0.92',
#    'time': '600'},
#   'test_1': {'stability_type': 'ISOST',
#    'temperature': '85',
#    'humidity': '30',
#    'efficiency_tret': '0.6',
#    'time': '125'}},
#  '62': {'passivating_molecule': ['methylammonium lead iodide', 'BAI'],
#   'treated_pce': ['16.5', '17.30'],
#   'test_1': {'stability_type': 'ISOSL',
#    'efficiency_tret': '0.81',
#    'time': '720',
#    'humidity': '55',
#    'efficiency_cont': '0.44'},
#   'test_2': {'efficiency_tret': '0.74',
#    'time': '720',
#    'temperature': '80',
#    'stability_type': 'ISOST',
#    'control_element': 'methylammonium lead iodide',
#    'efficiency_cont': '0.27'},
#   'perovskite_composition': 'CH 3 NH 3 PbI 3',
#   'structure_pin_nip': 'NIP',
#   'efficiency_tret': '0.83'},
#  '63': {'performance_1': {'perovskite_composition': 'CH3NH3PbI3',
#    'temperature': '100 °C',
#    'treated_pce': '11.66'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '64': {'additive_molecule': 'PAPER THE FAILED??',
#   'structure_pin_nip': 'PIN',
#   'hole_transport_layer': ['molybdenum oxide', 'TaTm'],
#   'electron_transport_layer': ['MAPI', 'fullerene', 'bathocuproine'],
#   'performance_3': {'control_element': 'MAPI',
#    'control_pce': '18.6',
#    'treatment_element': 'MAPI/2D',
#    'treated_pce': '17.0'},
#   'performance_1': {'treatment_element': '2D/MAPI/2D', 'treated_pce': '13.9'},
#   'performance_2': {'treatment_element': '2D/MAPI', 'treated_pce': '18.3'}},
#  '65': {'perovskite_composition': ['phenylethylammonium methylammonium lead iodide',
#    '(MA)[PbI 3 ]'],
#   'treated_voc': '1.18',
#   'treated_pce': '4.73',
#   'performance_1': {'control_element': 'methylammonium lead iodide',
#    'treated_pce': '4.73',
#    'treatment_element': 'phenylethylammonium methylammonium lead iodide'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '66': {'control_element': 'glue-based encapsulation method',
#   'stability_type': ['ISOSD1',
#    'Damp Heat Stability Testing',
#    'outdoor operation in a roof-top test installation'],
#   'test_1': {'temperature': '21',
#    'humidity': '30',
#    'stability_type': 'ISOSD1',
#    'time': '1566',
#    'control_element': 'glue-based encapsulation method',
#    'efficiency_cont': '0.93',
#    'treatment_element': 'lamination based encapsulation method',
#    'efficiency_tret': '0.95'},
#   'test_2': {'temperature': '85',
#    'humidity': '85',
#    'stability_type': 'ISOSD3',
#    'efficiency_cont': '0.32',
#    'time': '48'},
#   'test_3': {'stability_type': 'ISOSO3',
#    'humidity': '60-100',
#    'control_element': 'glue-based encapsulation method',
#    'efficiency_cont': '0.49',
#    'time': '4380',
#    'treatment_element': 'lamination based encapsulation method',
#    'efficiency_tret': '0.99'},
#   'perovskite_composition': 'Cs0.15FA0.85PbI2.55Br0.45'},
#  '67': {'structure_pin_nip': ['NIP', 'p-i-n'],
#   'stability_type': 'ISOSL1',
#   'test_2': {'structure_pin_nip': 'PIN',
#    'efficiency_tret': '0.95',
#    'time': '800',
#    'treated_pce': '21.3',
#    'stability_type': 'ISOSL2',
#    'temperature': '85'},
#   'test_3': {'efficiency_tret': '1',
#    'time': '500',
#    'treated_pce': '7',
#    'stability_type': 'ISOSD1'},
#   'test_1': {'stability_type': 'ISOSLT',
#    'electron_transport_layer': 'TinOxide',
#    'perovskite_composition': 'FA0.83Cs0.17PbI2.7Br0.3',
#    'hole_transport_layer': 'polybisphenyl(trimethylphenyl)amine',
#    'efficiency_tret': '0.96',
#    'temperature': '250'}},
#  '68': {'electron_transport_layer': ['aluminum-doped zin oxide', 'tin oxide'],
#   'treatment_element': 'aluminium-doped zinc oxide / tin oxide bilayer',
#   'hole_transport_layer': 'PEDOT:PSS',
#   'passivating_molecule': ['PCBM', 'MAPbI 3'],
#   'perovskite_composition': 'CH3NH3PbI3',
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '12.8',
#   'test_1': {'stability_type': 'ISOSLT',
#    'temperature': '23',
#    'humidity': '50',
#    'treatment_element': 'aluminum-doped zin oxide',
#    'efficiency_cont': '0',
#    'efficiency_tret': '1',
#    'time': '4300'},
#   'test_2': {'stability_type': 'ISOSLT',
#    'temperature': '60',
#    'control_element': 'aluminum-doped zin oxide',
#    'efficiency_cont': '0',
#    'treatment_element': 'aluminium-doped zinc oxide / tin oxide bilayer',
#    'efficiency_tret': '0.99',
#    'time': '1032'}},
#  '69': {'electron_transport_layer': ['TinOxide', 'Al:ZnO'],
#   'time': ['1000', '3000 h'],
#   'stability_type': 'ISOSL',
#   'temperature': '60',
#   'structure_pin_nip': 'PIN',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'passivating_molecule': 'PCBM',
#   'treatment_element': 'Tin Oxide Grown by S-ALD',
#   'control_element': 'Tin Oxide Grown by B-ALD',
#   'test_1': {'temperature': '25',
#    'humidity': '60',
#    'control_element': 'SnO x grown at a substrate speed of 80 mm s -1',
#    'efficiency_cont': '0',
#    'treatment_element': 'SnO x has been grown at 20 mm s -1',
#    'efficiency_tret': '0.9',
#    'time': '1000'}},
#  '70': {'hole_transport_layer': 'Spiro-OMeTAD',
#   'metal_contact': ['Chromium', 'gold', 'Ag'],
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'FA0.83MA0.17Pb-(I0.83Br0.17)3',
#   'treated_pce': '20.6',
#   'test_2': {'temperature': '20',
#    'stability_type': 'ISOST',
#    'time': '15',
#    'treated_pce': '17.7'},
#   'electron_transport_layer': 'TinOxide',
#   'test_1': {'temperature': '75',
#    'stability_type': 'ISOST',
#    'treatment_element': 'Cr/Au',
#    'treated_pce': '19.4'}},
#  '71': {'perovskite_composition': ['(BA)2(MA)3Pb4I13', 'CH 3 NH 3 PbI 3'],
#   'perovskite_molecule': 'butylammonium'},
#  '72': {'test_1': {'efficiency_tret': '0.99',
#    'treatment_element': '2.5D devices',
#    'treated_pce': '19.9',
#    'stability_type': 'ISOST',
#    'time': '80',
#    'control_element': '3D device',
#    'efficiency_cont': '0.5',
#    'temperature': 'room temperature',
#    'control_pce': '20'},
#   'time': '80',
#   'structure_pin_nip': 'NIP',
#   'passivating_molecule': ['ligand allylammonium', 'poly(methyl methacrylate'],
#   'perovskite_composition': 'Cs0.05FA0.8MA0.15PbI2.88Br0.04Cl0.08'},
#  '73': {'test_1': {'treatment_element': 'CF3 -PEAI',
#    'treated_pce': '23.6',
#    'efficiency_tret': '0.821',
#    'stability_type': 'ISOSLT',
#    'time': '1800',
#    'temperature': '50',
#    'humidity': '50',
#    'control_element': 'pristine perovskite films',
#    'control_pce': '21.4',
#    'efficiency_cont': '0.672'},
#   'additive_molecule': 'dibutyl sulfoxide',
#   'efficiency_tret': '0.982',
#   'stability_type': 'ISOSD',
#   'temperature': '85',
#   'time': '1000',
#   'passivating_molecule': ['3,5-bis(trifluoromethyl) phenethylammonium iodide',
#    '2CF 3 -PEAI'],
#   'structure_pin_nip': ['NIP', 'p-i-n'],
#   'performance_1': {'control_element': '0% DBSO',
#    'treatment_element': '10% DBSO',
#    'control_voc': '1.024',
#    'treated_voc': '1.091',
#    'treated_pce': '22.6'},
#   'test_2': {'stability_type': 'ISOSD',
#    'treatment_element': 'CF3 -PEAI',
#    'treated_pce': '24.8',
#    'efficiency_tret': '0.911',
#    'temperature': '85',
#    'humidity': '85',
#    'time': '1000',
#    'control_element': 'pristine perovskite',
#    'efficiency_cont': '0.713'},
#   'treated_pce': '25.1%'},
#  '74': {'treatment_element': 'self-polymerization of ethylene dimethacrylate and polyhedral oligomeric silsesquioxane',
#   'passivating_molecule': ['cross linked polymer',
#    '4-fluorophenylethylammonium iodide'],
#   'treated_pce': '21.2',
#   'efficiency_tret': '0.9',
#   'time': '4390',
#   'stability_type': 'ISOSLT',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'tin dioxide',
#   'temperature': '60',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'structure_pin_nip': 'NIP',
#   'performance_3': {'control_element': '3D perovskite',
#    'treatment_element': '3D/CLP/2D',
#    'control_pce': '18.83',
#    'treated_pce': '20.29'},
#   'performance_1': {'treatment_element': '3D/2D', 'treated_pce': '19.81'},
#   'performance_2': {'treatment_element': '3D/CLP', 'treated_pce': '19.91'},
#   'treated_voc': '1.13',
#   'test_1': {'stability_type': 'ISOSLT',
#    'temperature': '60',
#    'efficiency_tret': '0.9',
#    'treatment_element': '3D/CLP/2D',
#    'time': '5000'}},
#  '77': {'additive_molecule': '(phenethylamino)methaniminium',
#   'structure_pin_nip': 'PIN',
#   'test_1': {'treatment_element': '(phenethylamino)methaniminium',
#    'efficiency_tret': '0.9',
#    'stability_type': 'ISOSLT',
#    'temperature': '90',
#    'time': '1500'},
#   'control_pce': ['https://doi.org/10.1038/s41560-023-01362-0', '21.2%'],
#   'passivating_molecule': '(phenethylamino)methaniminium iodide',
#   'perovskite_composition': 'FA0.9Cs0.1Pb3',
#   'control_element': 'without PEAMAI',
#   'treatment_element': 'PEAMA + device',
#   'treated_pce': '24.1',
#   'temperature': '85'},
#  '78': {'perovskite_composition': 'formamidinium lead iodide',
#   'additive_molecule': ['dimethylsulfoxide', 'PbI2-(DMSO)'],
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '19.2'},
#  '79': {'electron_transport_layer': ['TinOxide', 'TiO 2'],
#   'treated_pce': '20.51',
#   'structure_pin_nip': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'control_pce': '18.5',
#    'treated_voc': '1.09',
#    'treatment_element': 'TinOxide',
#    'control_element': 'TitaniumDioxide',
#    'treated_pce': '20.51',
#    'stability_type': 'ISOSL',
#    'temperature': '28',
#    'humidity': '37'},
#   'passivating_molecule': 'Lead Iodide',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'perovskite_molecule': ['Formamidinium Lead Iodide', 'MAPbBr 3']},
#  '80': {'passivating_molecule': 'poly(methyl methacrylate)',
#   'additive_molecule': ['dimethylformamide', 'dimethyl sulfoxide (DMSO'],
#   'test_1': {'treatment_element': 'poly(methyl methacrylate)',
#    'treated_pce': '21.6',
#    'treated_voc': '1.14',
#    'efficiency_tret': '96.7',
#    'stability_type': 'ISOSD'},
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'TitaniumDioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '81': {'test_1': {'treatment_element': 'chlorine capped TitaniumDioxide',
#    'treated_pce': '20.9',
#    'efficiency_tret': '0.9',
#    'time': '500',
#    'stability_type': 'ISOSL'},
#   'perovskite_composition': ['FA 0.85 MA 0.15 PbI 2.55 Br 0.45',
#    'Cs 0.05 FA 0.81 MA 0.14 PbI 2.55 Br 0.45'],
#   'electron_transport_layer': 'TitaniumDioxide',
#   'control_voc': '1.06',
#   'treated_voc': '1.14',
#   'control_pce': '15.8',
#   'test_2': {'stability_type': 'ISOSD',
#    'treatment_element': 'chlorine capped TitaniumDioxide',
#    'efficiency_tret': '0.95',
#    'time': '1440',
#    'efficiency_cont': '0.38'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '82': {'structure_pin_nip': 'PIN',
#   'treated_pce': '20.59',
#   'passivating_molecule': ['quanternary ammonium halides', 'PCBM'],
#   'additive_molecule': 'CH 3 NH 3 PbI 3',
#   'control_voc': '1.04',
#   'control_pce': '17.1',
#   'test_1': {'stability_type': 'ISOSD',
#    'temperature': 'room temperature',
#    'humidity': '55-85',
#    'treatment_element': 'choline chloride layers',
#    'efficiency_tret': '1',
#    'control_element': 'L-α-phosphatidylcholin',
#    'efficiency_cont': '0.7',
#    'time': '800'},
#   'test_2': {'treatment_element': 'choline chloride',
#    'treated_pce': '21.1',
#    'efficiency_tret': '0.86',
#    'stability_type': 'ISOSL',
#    'time': '26'}},
#  '83': {'structure_pin_nip': 'PIN',
#   'electron_transport_layer': 'TitaniumDioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'stability_type': 'ISOSD',
#    'temperature': '25',
#    'humidity': '40',
#    'time': '792',
#    'treatment_element': 'MAPbI 3 homojunction',
#    'treated_pce': '20.27',
#    'efficiency_tret': '0.96',
#    'control_element': 'MAPbI 3 standard',
#    'efficiency_cont': '0.94',
#    'control_pce': '17.39'}},
#  '84': {'structure_pin_nip': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'test_1': {'hole_transport_layer': 'Spiro-OMeTAD',
#    'treated_pce': '23.2',
#    'stability_type': 'ISOST',
#    'efficiency_cont': '0.95',
#    'temperature': '60'},
#   'perovskite_composition': '(FAPbI 3 ) 0.95 (MAPbBr 3 ) 0.05',
#   'test_2': {'treatment_element': 'DM',
#    'efficiency_tret': '0.926',
#    'time': '310',
#    'stability_type': 'ISOSL'}},
#  '85': {'hole_transport_layer': 'Poly(3-hexylthiophene)',
#   'test_1': {'perovskite_molecule': 'HTAB',
#    'humidity': '0.85',
#    'time': '1370',
#    'stability_type': 'ISOSL',
#    'efficiency_tret': '0.95'},
#   'treated_pce': '22.7',
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'HTAB 0.3 (FAPbI 3 ) 0.95 (MAPbBr 3 ) 0.05'},
#  '86': {'electron_transport_layer': ['EDTA-complexed SnO2', 'SnO 2'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'control_pce': '18.93',
#   'control_voc': '1.10',
#   'treated_voc': '1.11',
#   'treated_pce': '21.6',
#   'test_1': {'treatment_element': 'EDTA-complexed SnO2',
#    'efficiency_tret': '0.92',
#    'time': '2880',
#    'stability_type': 'ISOSD',
#    'control_element': 'SnO 2',
#    'efficiency_cont': '0.74'},
#   'test_2': {'temperature': '120',
#    'stability_type': 'ISOSL',
#    'treatment_element': 'EDTA-complexed SnO2',
#    'efficiency_tret': '0.86',
#    'control_element': 'TinOxide',
#    'efficiency_cont': '0.38'}},
#  '87': {'structure_pin_nip': 'NIP',
#   'test_1': {'passivating_molecule': 'europium ion pair',
#    'efficiency_tret': '0.92',
#    'stability_type': 'ISOSL',
#    'time': '1000'},
#   'treated_pce': '21.52',
#   'test_2': {'stability_type': 'ISOST',
#    'efficiency_tret': '0.91',
#    'temperature': '85',
#    'treatment_element': 'Eu 3+ -Eu 2+'}},
#  '88': {'treated_pce': ['21.46', '20.56'],
#   'perovskite_molecule': ['caesium',
#    'methylammonium (MA)',
#    'formamidinium (FA)'],
#   'perovskite_composition': ['CsFAMA', 'CaFAMA-F'],
#   'efficiency_tret': '0.9',
#   'time': '1,000',
#   'additive_molecule': ['alkali halide, NaX (X = I, Br, Cl or F)',
#    'fluoride-containing material'],
#   'structure_pin_nip': 'NIP',
#   'test_1': {'treatment_element': 'fluoride-containing perovskite',
#    'treated_pce': '21.46',
#    'efficiency_tret': '0.9',
#    'stability_type': 'ISOSL',
#    'control_element': 'CsFAMA',
#    'control_pce': '19.03'},
#   'control_pce': '48.86',
#   'test_2': {'treatment_element': 'CsFAMA-F',
#    'stability_type': 'ISOST',
#    'efficiency_tret': '0.9',
#    'temperature': '85',
#    'time': '1,000',
#    'control_element': 'CsFAMA',
#    'efficiency_cont': '0.5'},
#   'test_3': {'stability_type': 'ISOSD',
#    'humidity': '0.25-0.45',
#    'treatment_element': 'CsFAMA-F',
#    'efficiency_tret': '0.9',
#    'time': '6,000'},
#   'temperature': '25-40'},
#  '89': {'perovskite_molecule': 'FAPbI3',
#   'perovskite_composition': ['Cs0.05(MA0.85FA0.15)0.95Pb(I0.85Br0.15)3',
#    'BA2MA3PbI13'],
#   'treated_pce': '20.87',
#   'structure_pin_nip': 'NIP',
#   'treated_voc': '1.145'},
#  '90': {'perovskite_composition': '(FAPbI 3 ) 0.85 (MAPbBr 3 ) 0.15',
#   'treated_pce': ['20.7', '19.8'],
#   'perovskite_molecule': ['MA +', 'MAPbI 3'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'structure_pin_nip': 'NIP',
#   'control_pce': '18.7',
#   'treated_voc': '1.17'},
#  '91': {'perovskite_molecule': 'Formamidinium Lead Iodide',
#   'additive_molecule': ['methylammonium chloride', 'MA-40'],
#   'treated_pce': ['23.36', '24.02'],
#   'treated_voc': '1.130',
#   'test_1': {'temperature': '25',
#    'stability_type': 'ISOSL',
#    'humidity': '25',
#    'efficiency_tret': '0.9',
#    'time': '1,200',
#    'treatment_element': 'methylammonium chloride - 40%'},
#   'test_2': {'temperature': '40',
#    'stability_type': 'ISOST',
#    'control_element': 'methylammonium chloride',
#    'efficiency_cont': '0.6',
#    'time': '300',
#    'treatment_element': 'methylammonium chloride - 40%',
#    'efficiency_tret': '0.9'}},
#  '92': {'electron_transport_layer': ['BaSnO3', 'Li-doped TiO 2', 'TiO 2'],
#   'treated_pce': '21.3',
#   'control_pce': '20',
#   'structure_pin_nip': 'NIP',
#   'test_1': {'stability_type': 'ISOSL',
#    'humidity': '40',
#    'treatment_element': 'mp-BSO',
#    'control_element': 'mp-TiO 2',
#    'efficiency_cont': '0.5',
#    'electron_transport_layer': '24',
#    'efficiency_tret': '0.9'},
#   'test_3': {'treatment_element': 'BSO-based',
#    'electron_transport_layer': 'ISOSLT',
#    'temperature': '450',
#    'efficiency_tret': '0.67'},
#   'test_2': {'stability_type': 'ISOSD',
#    'temperature': '25',
#    'humidity': '25',
#    'time': '500',
#    'efficiency_tret': '1',
#    'control_pce': '1.5 G'}},
#  '93': {'perovskite_molecule': ['formamidinium lead iodide',
#    'MAPbI 3',
#    'FA 0.5 MA 0.5 PbI 3'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'electron_transport_layer': 'TinOxide',
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '21.21'},
#  '94': {'hole_transport_layer': ['Spiro-OMeTAD',
#    'polymeric poly(4-vinylpyridine)'],
#   'efficiency_tret': '0.8',
#   'time': '6000',
#   'test_1': {'stability_type': 'ISOSL',
#    'hole_transport_layer': 'polymeric poly(4-vinylpyridine)',
#    'humidity': '25-50',
#    'efficiency_tret': '0.8',
#    'time': '6000',
#    'treated_pce': '20.6',
#    'temperature': '25-40'},
#   'treated_pce': '20.6',
#   'control_pce': '19.11',
#   'structure_pin_nip': 'PIN',
#   'test_2': {'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.9',
#    'time': '700',
#    'efficiency_cont': '0.8'},
#   'test_3': {'treatment_element': 'polymeric poly(4-vinylpyridine)',
#    'stability_type': 'ISOST',
#    'efficiency_tret': '0.8',
#    'temperature': '85',
#    'time': '300'}},
#  '95': {'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'passivating_molecule': ['butylammonium iodide',
#    'octylammonium iodide',
#    'dodecylammonium iodide'],
#   'performance_1': {'passivating_molecule': 'octylammonium iodide',
#    'treated_pce': '22.9'},
#   'electron_transport_layer': 'TitaniumDioxide',
#   'performance_2': {'treated_pce': '15.1',
#    'passivating_molecule': 'dodecylammonium iodide',
#    'control_pce': '5.9'},
#   'hole_transport_layer': ['DM', 'Spiro-OMeTAD'],
#   'performance_3': {'passivating_molecule': 'oleylammonium iodide',
#    'treated_pce': '23.3'},
#   'test_2': {'stability_type': 'ISOSD',
#    'temperature': '65',
#    'humidity': '65',
#    'time': '100',
#    'control_element': 'butylammonium iodide',
#    'efficiency_cont': '0.2',
#    'treatment_element': 'dodecylammonium iodide',
#    'efficiency_tret': '0.9',
#    'control_pce': '85'},
#   'test_1': {'temperature': '25', 'humidity': '85'}},
#  '96': {'passivating_molecule': ['NOTE:Assume tinacetylacetonate is additive',
#    'fluorine-doped SnO 2 (FTO)/c-TiO 2 /SnO 2 / perovskite/spiro-OMeTAD/gold'],
#   'performance_1': {'treated_pce': '21.12', 'additive_molecule': 'Chlorine'},
#   'performance_2': {'additive_molecule': 'Bromide', 'treated_pce': '20'},
#   'performance_3': {'treatment_element': 'c-TiO 2 /Cl 2',
#    'treated_pce': '22.19'},
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '97': {'treated_pce': '22.3',
#   'time': '1000',
#   'stability_type': 'ISOSLT',
#   'treatment_element': 'anchoring alkylamine ligands',
#   'efficiency_tret': '1',
#   'control_pce': '20.5',
#   'performance_1': {'passivating_molecule': 'oleylamine', 'treated_pce': '22'},
#   'structure_pin_nip': 'PIN',
#   'test_1': {'passivating_molecule': 'ISOSLT',
#    'efficiency_cont': '0.58',
#    'treatment_element': 'anchoring alkylamine ligands',
#    'efficiency_tret': '1',
#    'time': '1000',
#    'treated_pce': '21.6'},
#   'test_2': {'passivating_molecule': 'ISOST',
#    'temperature': '85',
#    'efficiency_tret': '0.9',
#    'treatment_element': 'anchoring alkylamine ligands',
#    'time': '1020'},
#   'perovskite_composition': 'Cs 0.05 (FA0.92MA0.08)0.95Pb(I0.92Br0.08)3',
#   'performance_2': {'control_pce': '19.2',
#    'control_element': 'pristine CsFAMA',
#    'treated_pce': '21.2',
#    'treatment_element': 'CsFAMA device with AALs.'}},
#  '98': {'additive_molecule': 'FN-Br',
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'methylammonium lead iodide',
#   'treated_pce': '21.54',
#   'efficiency_tret': '0.92',
#   'test_1': {'time': '4',
#    'stability_type': 'ISOSLT',
#    'humidity': '60',
#    'control_element': 'TBP/LiTFSI doped spiro-OMeTAD',
#    'efficiency_cont': '0.3',
#    'treatment_element': 'FN-Br/FK209',
#    'efficiency_tret': '0.95'},
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_1': {'control_pce': '17.29',
#    'treatment_element': 'FN-Br',
#    'treated_pce': '19.31'}},
#  '99': {'passivating_molecule': 'chlorine-rich mixed-halide perovskite interlayer',
#   'test_2': {'treatment_element': 'chlorine-rich mixed-halide perovskite interlayer',
#    'time': '500',
#    'passivating_molecule': 'ISOSLT',
#    'efficiency_tret': '0.82'},
#   'test_1': {'treated_pce': '21.01',
#    'efficiency_tret': '0.94',
#    'time': '180',
#    'stability_type': 'ISOSO',
#    'efficiency_cont': '0'},
#   'efficiency_tret': '0.82',
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': ['TitaniumDioxide', 'SnO 2'],
#   'control_pce': '18.08'},
#  '100': {'electron_transport_layer': 'Lanthanum oxide',
#   'control_element': 'TinOxide',
#   'treatment_element': 'Lanthanum oxide / Tin Oxide Bilayer',
#   'treated_pce': ['23.24', '23.07%'],
#   'test_1': {'treatment_element': 'Lanthanum oxide / Tin Oxide Bilayer',
#    'efficiency_tret': '0.975',
#    'stability_type': 'ISOSL',
#    'time': '1920',
#    'control_element': 'TinOxide',
#    'efficiency_cont': '0.927'},
#   'test_2': {'efficiency_tret': '0.91',
#    'time': '180',
#    'stability_type': 'ISOSLT',
#    'treatment_element': 'Lanthanum oxide / Tin Oxide Bilayer',
#    'control_element': 'TinOxide',
#    'efficiency_cont': '0.83'},
#   'control_pce': '21.17',
#   'structure_pin_nip': 'NIP',
#   'test_3': {'electron_transport_layer': 'ISOSL',
#    'humidity': '75',
#    'time': '120',
#    'treatment_element': 'Lanthanum oxide / Tin Oxide Bilayer',
#    'efficiency_tret': '0.8',
#    'control_element': 'TinOxide',
#    'efficiency_cont': '0.71'},
#   'performance_1': {'electron_transport_layer': 'Lanthanum oxide / Tin Oxide Bilayer',
#    'treated_pce': '23.2'}},
#  '101': {'control_pce': ['c', '19.09', 'r', '(19.65'],
#   'additive_molecule': ['diethylene glycol', '3%', '10%'],
#   'treated_pce': ['20.10', '19.90', '16.71%'],
#   'efficiency_tret': '0.9225',
#   'time': '720',
#   'treatment_element': '0%',
#   'structure_pin_nip': 'NIP',
#   'test_1': {'stability_type': 'ISOSL',
#    'temperature': '25',
#    'humidity': '20-30',
#    'efficiency_tret': '0.87'},
#   'performance_1': {'control_element': '0%',
#    'control_pce': '18.57',
#    'treatment_element': '3% diethylene glycol',
#    'treated_pce': '16.78',
#    'additive_molecule': '10% diethylene glycol'}},
#  '102': {'perovskite_composition': 'formamidinium lead iodide',
#   'treated_pce': '20.71',
#   'perovskite_molecule': 'lead iodide',
#   'structure_pin_nip': 'NIP',
#   'treated_voc': '1.114',
#   'test_1': {'stability_type': 'ISOSL',
#    'humidity': '20',
#    'efficiency_tret': '0.8',
#    'time': '720'},
#   'test_2': {'stability_type': 'ISOSLT',
#    'humidity': '30',
#    'control_pce': '17.23',
#    'efficiency_tret': '0.92',
#    'treated_pce': '21.48',
#    'time': '1.6'}},
#  '103': {'perovskite_composition': ['alpha phase formamidinium lead iodide',
#    '[(FAPbI 3 ) 0.95 (MAPbBr 3 ) 0.05 ]'],
#   'additive_molecule': 'methylenediammonium dichloride',
#   'test_1': {'treatment_element': 'methylenediammonium dichloride',
#    'treated_pce': '23.7',
#    'efficiency_tret': '0.9',
#    'time': '600',
#    'stability_type': 'ISOSO'},
#   'test_2': {'additive_molecule': 'ISOSD',
#    'efficiency_tret': '0.9',
#    'humidity': '85',
#    'temperature': '25',
#    'efficiency_cont': '0.4'},
#   'test_3': {'stability_type': 'ISOST',
#    'temperature': '150',
#    'humidity': '25',
#    'efficiency_cont': '0.2',
#    'efficiency_tret': '0.9'}},
#  '104': {'electron_transport_layer': 'tin dioxide',
#   'treated_pce': '25.2',
#   'perovskite_composition': 'Methylammonium Lead Bromide',
#   'test_1': {'treatment_element': 'tin dioxide',
#    'efficiency_tret': '1',
#    'time': '3600',
#    'stability_type': 'ISOSLT'},
#   'test_2': {'efficiency_tret': '0.8',
#    'time': '500',
#    'stability_type': 'ISOSLT'}},
#  '105': {'electron_transport_layer': ['titanium oxynitride', 'TiO x'],
#   'treated_pce': ['22.6', '23.09%'],
#   'structure_pin_nip': 'NIP',
#   'control_pce': '21.26',
#   'test_1': {'treatment_element': 'titanium oxynitride',
#    'treated_pce': '22.82',
#    'time': '250',
#    'stability_type': 'ISOSL',
#    'efficiency_tret': '0.987',
#    'control_element': 'TItanium oxide',
#    'control_pce': '20.24',
#    'efficiency_cont': '0.965'},
#   'test_2': {'stability_type': 'ISOSD',
#    'temperature': '85',
#    'humidity': '85'}},
#  '106': {'test_1': {'treated_pce': '22.02',
#    'stability_type': 'ISOSLT',
#    'time': '1000',
#    'temperature': '85',
#    'treatment_element': 'ZrL3:bis-C60',
#    'efficiency_tret': '0.92'},
#   'structure_pin_nip': 'PIN',
#   'performance_2': {'control_element': 'without any EEL',
#    'control_pce': '18.8',
#    'electron_transport_layer': 'ZrL3:bis-C60',
#    'treated_pce': '22.02',
#    'treated_voc': '1.20'},
#   'performance_1': {'electron_transport_layer': 'zirconium-based MOF',
#    'treated_pce': '20.34'},
#   'electron_transport_layer': 'C60',
# ...
#   'treated_voc': ['1.13', '1.18'],
#   'test_3': {'stability_type': 'ISOST',
#    'efficiency_cont': '0.63',
#    'temperature': '-60',
#    'efficiency_tret': '0.887'}},
#  '125': {'test_2': {'additive_molecule': 'selenophene',
#    'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.89',
#    'time': '500',
#    'temperature': '85'},
#   'test_1': {'efficiency_tret': '0.91',
#    'time': '3190',
#    'stability_type': 'ISOSLT',
#    'temperature': '45'},
#   'perovskite_composition': ['FACsPb(Br0.13I0.87)3', 'Cs 0.1 FA 0.9 PbI 3'],
#   'electron_transport_layer': 'tin dioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'control_pce': '20.9',
#   'treated_pce': '23.4',
#   'temperature': '85',
#   'stability_type': 'ISOSD',
#   'efficiency_tret': '0.8',
#   'time': '1750',
#   'test_3': {'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.8',
#    'time': '960'}},
#  '126': {'passivating_molecule': 'lead oxalate',
#   'perovskite_composition': 'formamidinium lead iodide',
#   'treated_pce': '25.39',
#   'test_1': {'efficiency_tret': '0.92',
#    'stability_type': 'ISOSLT',
#    'time': '550',
#    'control_pce': '23.43',
#    'control_voc': '1.16',
#    'treated_pce': '25.39',
#    'treated_voc': '1.18',
#    'efficiency_cont': '0.6'},
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'tin dioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'additive_molecule': 'formamidinium chloride'},
#  '127': {'passivating_molecule': 'zinc-based halogenometallate',
#   'structure_pin_nip': 'PIN',
#   'test_1': {'treated_pce': '24.1',
#    'efficiency_tret': '0.945',
#    'time': '1009',
#    'stability_type': 'ISOSLT'},
#   'hole_transport_layer': 'poly(triarylamine)',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'treated_voc': '1.198'},
#  '128': {'additive_molecule': 'aminoindan hydrochloride',
#   'test_1': {'treated_pce': '25.12',
#    'efficiency_tret': '0.98',
#    'time': '1500',
#    'perovskite_composition': 'ISOSLT',
#    'temperature': '55',
#    'efficiency_cont': '0.78',
#    'control_pce': '21.73'},
#   'test_2': {'efficiency_tret': '0.92',
#    'time': '1200',
#    'temperature': '85',
#    'humidity': '85',
#    'structure_pin_nip': 'PIN',
#    'stability_type': 'ISOST1'},
#   'stability_type': 'ISOST1',
#   'hole_transport_layer': 'poly(triarylamine)',
#   'perovskite_composition': 'Cs0.05FA0.95PbI3',
#   'electron_transport_layer': 'PCBM',
#   'control_pce': '21.94',
#   'control_voc': '1.122',
#   'treated_voc': '1.156'},
#  '129': {'structure_pin_nip': 'PIN',
#   'treated_pce': '24.8',
#   'test_1': {'efficiency_tret': '0.98',
#    'temperature': '65',
#    'stability_type': 'ISOSLT',
#    'time': '1200',
#    'efficiency_cont': '0.7'},
#   'test_2': {'additive_molecule': '4-guanidinobenzoic acid hydrochloride',
#    'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.9',
#    'time': '500',
#    'efficiency_cont': '0.3'},
#   'treated_voc': '1.19',
#   'hole_transport_layer': '(2,7-Dimethoxy-9H-carbazol-9-yl)methyl phosphonic acid',
#   'electron_transport_layer': 'buckminsterfullerene'},
#  '130': {'treated_pce': '25.4',
#   'additive_molecule': ['pentanamidine hydrochlorid',
#    'Butylamidine hydrochloride',
#    'propionamidine hydrochloride'],
#   'performance_1': {'additive_molecule': 'pentanamidine hydrochlorid',
#    'treated_pce': '24.0',
#    'control_pce': '22.9',
#    'treated_voc': '1.18',
#    'control_voc': '1.13'},
#   'test_1': {'temperature': '30',
#    'efficiency_cont': '0.7',
#    'additive_molecule': 'pentanamidine hydrochlorid',
#    'efficiency_tret': '0.95',
#    'time': '1000',
#    'stability_type': 'ISOSL3'},
#   'test_2': {'additive_molecule': 'pentanamidine hydrochlorid',
#    'temperature': '65',
#    'humidity': '85',
#    'efficiency_tret': '0.82',
#    'time': '500',
#    'efficiency_cont': '0.63'},
#   'performance_2': {'additive_molecule': 'pentanamidine hydrochlorid',
#    'treated_pce': '20.4',
#    'control_pce': '18.9'}},
#  '131': {'treated_pce': '25.5',
#   'structure_pin_nip': ['PIN', 'porous insulator contact'],
#   'control_pce': '23',
#   'control_voc': '1.13',
#   'treated_voc': '1.19',
#   'test_1': {'stability_type': 'ISOSLT',
#    'efficiency_tret': '0.98',
#    'temperature': '85',
#    'time': '1000'}},
#  '132': {'additive_molecule': '1-dodecanethiol',
#   'hole_transport_layer': ['Spiro-OMeTAD', 'DDT-treated spiro-OMeTAD'],
#   'treated_pce': '23.1',
#   'efficiency_tret': '0.9',
#   'time': '1000',
#   'perovskite_composition': 'Cs0.05(FAPbI3)0.85(MAPbBr3)0.15',
#   'performance_1': {'control_pce': '22.7',
#    'control_voc': '1.171',
#    'treated_pce': '23.1',
#    'treated_voc': '1.198'},
#   'test_2': {'additive_molecule': '1-dodecanethiol',
#    'stability_type': 'ISOSLT',
#    'temperature': '50-85',
#    'efficiency_tret': '0.95'},
#   'test_1': {'stability_type': 'ISOSD',
#    'humidity': '50',
#    'efficiency_cont': '0.68',
#    'time': '430',
#    'efficiency_tret': '0.97'},
#   'test_3': {'stability_type': 'ISOSLT',
#    'efficiency_cont': '0.1',
#    'time': '2000',
#    'efficiency_tret': '0.93',
#    'additive_molecule': '1-dodecanethiol'}},
#  '133': {'test_1': {'passivating_molecule': 'sodium thioglycolate',
#    'treated_pce': '24.56',
#    'treated_voc': '1.19',
#    'efficiency_tret': '0.96',
#    'time': '900',
#    'stability_type': 'ISOSLT'},
#   'perovskite_composition': 'Cs0.05FA0.9MA0.05Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'hole_transport_layer': 'Me-4PACz',
#   'structure_pin_nip': 'PIN',
#   'performance_1': {'control_voc': '1.14',
#    'treated_voc': '1.19',
#    'passivating_molecule': 'sodium thioglycolate',
#    'treated_pce': '24.2',
#    'control_pce': '22.5'}},
#  '134': {'additive_molecule': 'guanabenz acetate salt',
#   'treated_pce': '25.08',
#   'stability_type': ['ISOSLT', 'damp heat conditions'],
#   'efficiency_tret': '0.85',
#   'temperature': '85',
#   'test_2': {'efficiency_tret': '0.97',
#    'time': '2000',
#    'efficiency_cont': '0.68',
#    'humidity': '20',
#    'temperature': '25',
#    'stability_type': 'ISOSD'},
#   'perovskite_composition': 'FA0.98MA0.02Pbl3',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'treated_voc': '1.174',
#   'structure_pin_nip': 'NIP',
#   'test_1': {'stability_type': 'ISOSLT',
#    'temperature': '50',
#    'efficiency_tret': '0.85',
#    'time': '300',
#    'efficiency_cont': '0.6',
#    'additive_molecule': 'ISOSLT',
#    'humidity': '85'},
#   'test_3': {'efficiency_tret': '0.85',
#    'time': '260',
#    'stability_type': 'ISOSD',
#    'temperature': '85',
#    'humidity': '85'}},
#  '135': {'hole_transport_layer': ['nickel oxide',
#    '4-(3,11-dimethoxy-7H-dibenzo[c,g]carbazol-7-yl)butyl)phosphonic acid'],
#   'treated_pce': '25.6',
#   'treated_voc': '1.19',
#   'efficiency_tret': '0.9',
#   'stability_type': 'ISOSLT',
#   'temperature': ['65', '25°'],
#   'time': '1200',
#   'structure_pin_nip': 'PIN',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'passivating_molecule': 'methylammonium iodide',
#   'test_2': {'stability_type': 'ISOSL2',
#    'treatment_element': 'nickel oxide',
#    'efficiency_tret': '0.65',
#    'temperature': '85',
#    'time': '1200'},
#   'test_1': {'treatment_element': '11-dimethoxy-7H-dibenzo[c,4-(3,g]carbazol-7-yl)butyl)phosphonic acid',
#    'efficiency_tret': '0.53',
#    'temperature': '85',
#    'time': '800'},
#   'test_3': {'treatment_element': 'NiO x /MeO-4PADBC',
#    'efficiency_tret': '0.74',
#    'time': '1200',
#    'temperature': '85'}},
#  '136': {'performance_1': {'hole_transport_layer': '2-(4-(bis(4-methoxyphenyl)amino)phenyl)-1-cyanovinyl)phosphonic acid',
#    'treated_pce': '25.4',
#    'treated_voc': '1.21'},
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'performance_2': {'hole_transport_layer': 'poly(triarylamine)',
#    'treated_pce': '22.6',
#    'treated_voc': '1.13'},
#   'performance_3': {'hole_transport_layer': "2,2'-(9,6-diyl)bis(4-(1H-pyrazol-1-yl)-phenyl)amine,9-dimethyl-9H-carbazol-3",
#    'treated_pce': '23.4',
#    'treated_voc': '1.17'},
#   'electron_transport_layer': 'buckminsterfullerene',
#   'test_1': {'humidity': '30-40',
#    'temperature': '2000',
#    'stability_type': 'ISOSL1',
#    'efficiency_tret': '0.9'},
#   'test_2': {'additive_molecule': '2-(4-(bis(4-methoxyphenyl)amino)phenyl)-1-cyanovinyl)phosphonic acid',
#    'stability_type': 'ISOSD',
#    'efficiency_tret': '0.95',
#    'time': '500',
#    'temperature': '85',
#    'humidity': '85'}},
#  '137': {'structure_pin_nip': 'PIN',
#   'passivating_molecule': ['3-(methylthio)propylamine hydroiodide',
#    'propane-1,3-diammonium iodide'],
#   'test_2': {'treatment_element': '3-diammonium iodide,propane-1 / 3-(methylthio)propylamine hydroiodide bilayer',
#    'time': '2000',
#    'temperature': '65',
#    'stability_type': 'ISOSL3',
#    'efficiency_tret': '0.96',
#    'efficiency_cont': '0.7',
#    'humidity': '50'},
#   'electron_transport_layer': 'buckminsterfullerene',
#   'treated_pce': '26.4',
#   'treated_voc': '1.17',
#   'test_1': {'time': '1600',
#    'temperature': '85',
#    'stability_type': 'ISOSD2',
#    'efficiency_tret': '0.95',
#    'efficiency_cont': '0.84'}},
#  '138': {'treated_pce': '25.3',
#   'test_1': {'efficiency_tret': '0.95',
#    'temperature': '65',
#    'humidity': '50',
#    'time': '1000',
#    'treatment_element': '3-MPA at a molar ratio of 1:9 with 2PACz',
#    'stability_type': 'ISOSL3'},
#   'additive_molecule': ['2-(9H-carbazol-9-yl)ethyl)phosphonic acid',
#    '3-mercaptopropionic acid'],
#   'perovskite_composition': 'Cs0.05MA0.10FA0.85PbI3',
#   'structure_pin_nip': 'NIP'},
#  '139': {'additive_molecule': '1-(phenylsulfonyl)pyrrole',
#   'structure_pin_nip': 'PIN',
#   'hole_transport_layer': 'poly(triaryl)amine',
#   'perovskite_composition': 'FA0.95Cs0.05PbI3',
#   'electron_transport_layer': 'buckminsterfullerene',
#   'control_pce': '23.72',
#   'control_voc': '1.145',
#   'treated_voc': '1.164',
#   'test_2': {'treatment_element': '1-(phenylsulfonyl)pyrrole',
#    'temperature': '85',
#    'humidity': '85',
#    'efficiency_tret': '0.9',
#    'time': '300',
#    'efficiency_cont': '0.8',
#    'stability_type': 'ISOSD3',
#    'control_pce': '19.2',
#    'treated_pce': '21.8'},
#   'test_1': {'efficiency_tret': '0.92',
#    'time': '2500',
#    'efficiency_cont': '0.8',
#    'stability_type': 'ISOSL1',
#    'control_pce': '25.40',
#    'treated_pce': '23.54'}},
#  '140': {'perovskite_composition': 'formamidinium lead halides',
#   'test_1': {'treated_pce': '25.8',
#    'efficiency_tret': '0.94',
#    'time': '1258',
#    'temperature': '50'}},
#  '141': {'electron_transport_layer': ['boron chloride subphthalocyanine / fullerene bilayer',
#    'Cl 6 SubPc'],
#   'treated_pce': '21.3',
#   'test_1': {'efficiency_tret': '0.8',
#    'time': '816',
#    'stability_type': 'ISOSD',
#    'temperature': '85',
#    'humidity': '85',
#    'treatment_element': 'boron chloride subphthalocyanine / fullerene bilayer',
#    'control_element': 'buckminsterfullerene',
#    'efficiency_cont': '0.8'},
#   'test_2': {'efficiency_tret': '0.95',
#    'time': '1272',
#    'stability_type': 'ISOSO1'},
#   'structure_pin_nip': 'PIN',
#   'temperature': ['23.5', 'room temperature', '80 °C', '(85 °C'],
#   'humidity': '34'},
#  '142': {'treatment_element': '3D-2D perovskite-perovskite planar heterojunction',
#   'test_2': {'treated_pce': '16.13',
#    'efficiency_tret': '0.74',
#    'additive_molecule': '720',
#    'temperature': '85'},
#   'test_1': {'efficiency_tret': '0.71', 'time': '1200', 'humidity': '65'}},
#  '143': {'hole_transport_layer': ['copper(I) thiocyanate', 'spiro-OMeTAD'],
#   'perovskite_composition': '(FAPbI3)0.77(MAPbBr3)0.14(CsPbI3)0.09',
#   'passivating_molecule': ['phenylethylammonium iodide', 'FPEAI'],
#   'performance_3': {'treatment_element': 'copper(I) thiocyanate',
#    'passivating_molecule': 'fluorophenylethylammonium iodide',
#    'treated_pce': '18.03',
#    'treated_voc': '1.085',
#    'control_element': 'Spiro-OMeTAD',
#    'control_pce': '17.66',
#    'control_voc': '1.099'},
#   'performance_1': {'treated_pce': '18.09',
#    'treated_voc': '1.130',
#    'control_pce': '18.77',
#    'control_voc': '1.088'},
#   'performance_2': {'passivating_molecule': 'phenylethylammonium iodide',
#    'treated_pce': '18.01',
#    'treated_voc': '1.102',
#    'control_pce': '19.30',
#    'control_voc': '1.151'}},
#  '144': {'passivating_molecule': 'ethylenediammonium diiodide',
#   'additive_molecule': 'glycine hydrochloride',
#   'treated_pce': '23.6'},
#  '145': {'passivating_molecule': '4-fluoroaniline',
#   'treated_pce': '20.48',
#   'perovskite_composition': 'Cs0.05(MA0.17FA0.83)0.95Pb(I0.83Br0.17)3',
#   'control_pce': '17.8',
#   'control_voc': '1.02',
#   'treated_voc': '1.13',
#   'test_1': {'treatment_element': '4-fluoroaniline',
#    'efficiency_tret': '0.75',
#    'time': '95',
#    'efficiency_cont': '0.5',
#    'stability_type': 'ISOSLT'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '146': {'passivating_molecule': 'ortho-carborane',
#   'additive_molecule': 'phenylamino groups',
#   'test_1': {'efficiency_tret': '0.97',
#    'time': '400',
#    'treated_pce': '23.05',
#    'efficiency_cont': '0.89',
#    'humidity': '30',
#    'temperature': '40'},
#   'perovskite_composition': 'Cs0.05(MA0.05FA0.95)0.95Pb(I0.95Br0.05)3',
#   'treated_voc': '1.170'},
#  '147': {'passivating_molecule': 'carbazole-triphenylamine and phenylammonium iodide units',
#   'test_2': {'treatment_element': 'carbazole-triphenylamine and phenylammonium iodide units',
#    'treated_pce': '24.7',
#    'efficiency_tret': '0.946',
#    'time': '1100',
#    'stability_type': 'ISOSLT',
#    'efficiency_cont': '0.666'},
#   'test_1': {'efficiency_tret': '0.923',
#    'time': '1000',
#    'stability_type': 'ISOSD',
#    'temperature': '85',
#    'humidity': '85'},
#   'treated_voc': ['1.161', '1,112'],
#   'control_pce': '22.3',
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'formamidinium lead iodide',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '148': {'test_1': {'humidity': '50-70',
#    'passivating_molecule': 'phenylethylammonium iodide',
#    'efficiency_tret': '0.95',
#    'time': '500',
#    'stability_type': 'ISOSLT',
#    'treated_pce': '0.84',
#    'efficiency_cont': '0.7'},
#   'performance_1': {'treated_pce': '23.5',
#    'treated_voc': '1.142',
#    'control_voc': '1.091',
#    'control_pce': '21.2',
#    'passivating_molecule': '4-tert-butyl-benzylammonium iodide'},
#   'perovskite_composition': 'Cs0.05FA0.85MA0.10Pb(I0.97Br0.03)3',
#   'structure_pin_nip': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'performance_2': {'treated_voc': '1.122', 'treated_pce': '22.7'}},
#  '149': {'electron_transport_layer': 'buckminsterfullerene',
#   'passivating_molecule': ['4-trifluoromethyl-phenylammonium',
#    'phenethylammonium',
#    'phenylammonium'],
#   'test_1': {'passivating_molecule': '4-trifluoromethyl-phenylammonium',
#    'treated_pce': '26.4',
#    'efficiency_tret': '0.9',
#    'time': '600',
#    'stability_type': 'ISOSLT',
#    'humidity': '30-50',
#    'temperature': '35'},
#   'perovskite_composition': 'FA0.7MA0.3Pb0.5Sn0.5I3'},
#  '2': {'perovskite_composition': 'dibutylammonium lead iodide',
#   'treated_voc': '1.185',
#   'treated_pce': '24.35',
#   'test_1': {'efficiency_tret': '0.973',
#    'time': '1083',
#    'stability_type': 'ISOSD',
#    'temperature': '25',
#    'humidity': '85',
#    'treatment_element': 'SIG-2D',
#    'control_element': 'unencapsulated',
#    'efficiency_cont': '0.586',
#    'treated_pce': '21.34'},
#   'test_2': {'efficiency_tret': '0.98',
#    'time': '1620',
#    'treatment_element': 'SIG',
#    'stability_type': 'ISOSLT',
#    'temperature': '25',
#    'treated_pce': '24.06'},
#   'structure_pin_nip': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'control_pce': ['22.39', '>'],
#   'treatment_element': 'SIG60',
#   'stability_type': 'ISOSL',
#   'efficiency_tret': '1',
#   'time': '7000',
#   'passivating_molecule': 'butylamine',
#   'electron_transport_layer': 'tin dioxide'},
#  '3': {'test_1': {'treated_pce': '24.5',
#    'treated_voc': '1.20',
#    'treatment_element': 'BA2MA2Pb3I10',
#    'stability_type': 'ISOSL1',
#    'efficiency_tret': '0.99',
#    'time': '2000',
#    'efficiency_cont': '0.25'},
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'Cs0.05(MA0.10FA0.85)Pb(I0.90Br0.10)3',
#   'electron_transport_layer': 'tin dioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '4': {'additive_molecule': '4vinylbenzylammonium bromide',
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'tin dioxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': '(MAPbBr3)0.05(FAPbI3)0.95'}}

# %% [markdown]
# #### Evaluation in parts
# - numerical data
# - text data (molecule)
# - stability
#     - Change how to parse xml
#     - Change the output of the model as ID but no specification on number

# %%
## We need precision and recall for EACH variable
## For each variable, calculate the F1 score - There is F1 score for each variable
## Take a weighted average ***For now, just take the average.

# %% [markdown]
# Variables (number)
# - control_pce
# - treatment_pce
# - control_voc
# - treatment_voc
#
# Variable (text)
# - structure_pin_nip
# - passivating_molecule
# - perovskite_composition
# - hole_transport_layer
# - electron_transport_layer
#
# Stability (later)

# %%
def check_float(value):
    for char in value:
        if (char == ".") | (char.isdigit()):
            continue
        else:
            return False
    return True

# %%
import re

def check_float(value):
    """Returns True if value can be converted to a float, otherwise False."""
    try:
        float(value)
        return True
    except ValueError:
        return False

def clean_numeric_value(value):
    """
    Cleans a numeric value by removing non-numeric characters except decimals.
    Ensures the output is either a float or a string that can be converted.
    """
    if value is None:
        return None
    
    value = str(value).strip()  # Convert to string and remove leading/trailing spaces
    cleaned_value = re.sub(r"[^\d.]", "", value)  # Remove all non-numeric characters except "."

    return cleaned_value if check_float(cleaned_value) else None

def numerical_comparison(id, label_annotation, extraction_annotation, numerical_tolerance=0.1):
    """
    Compares numerical values with a tolerance, handling different formatting issues.
    """
    if id not in extraction_annotation:
        return "FN"  # False Negative: Missing extracted value
    
    label_data = label_annotation.get(id)
    extract_data = extraction_annotation.get(id)

    # Clean and convert numeric values
    label_data = clean_numeric_value(label_data)
    extract_data = clean_numeric_value(extract_data)

    if label_data is None or extract_data is None:
        return "FN"  # False Negative: If either value is invalid

    label_data = float(label_data)
    extract_data = float(extract_data)

    # Apply numerical tolerance check
    if abs(label_data - extract_data) <= numerical_tolerance * abs(label_data):
        return "TP"  # True Positive: Correct numerical extraction
    else:
        return "FP"  # False Positive: Incorrect numerical extraction

# %%
from difflib import SequenceMatcher

def text_comparison(id, label_annotation, extraction_annotation, text_similarity_threshold=0.8):
    """Compares text values using string similarity matching."""

    # Handle special case for structure_pin_nip
    key_to_check = "pin_nip_structure" if id == "structure_pin_nip" else id

    # If the key is missing in the extracted annotation, return False Negative
    if key_to_check not in extraction_annotation:
        return "FN"

    label_data = label_annotation.get(id, "")
    extract_data = extraction_annotation.get(key_to_check, "")

    # Convert lists to strings if necessary
    if isinstance(label_data, list):
        label_data = " ".join(map(str, label_data))  # Convert list to string
    if isinstance(extract_data, list):
        extract_data = " ".join(map(str, extract_data))  # Convert list to string

    # Ensure values are strings
    if not isinstance(label_data, str) or not isinstance(extract_data, str):
        return "FP"  # If data is still not a string, return False Positive

    # Compute similarity score
    similarity = SequenceMatcher(None, label_data.lower(), extract_data.lower()).ratio()

    return "TP" if similarity > text_similarity_threshold else "FP"

# %%
def stability_comparison(id, label_annotation, extraction_annotation):
    # Ensure "stability_tests" exists and is a list
    if "stability_tests" not in extraction_annotation or not isinstance(extraction_annotation["stability_tests"], list):
        return "FN"  # No stability test data found

    # If "stability_tests" is empty, return False Negative
    if len(extraction_annotation["stability_tests"]) == 0:
        return "FN"

    for dictionary in extraction_annotation["stability_tests"]:
        # Skip if "test_name" is missing or invalid
        if "test_name" not in dictionary or not isinstance(dictionary["test_name"], str):
            continue
        
        test_name = dictionary["test_name"]
        if id[4] == test_name[-1]:  # Match last character of ID and test name
            return "TP"  # True Positive: Test correctly extracted

    return "FN"  # No match found

# %%
def safe_division(numerator, denominator):
    """Returns division result, or 0 if the denominator is zero."""
    return numerator / denominator if denominator != 0 else 0

def compare_json(labeled_data, extracted_data):
    """
    Compare labeled and extracted JSON data for correctness.

    TP: Correct value extracted by LLM.
    FN: LLM didn't extract this variable.
    FP: LLM extracted a value, but it was incorrect.
    """
    
    numerical_variables = ["control_pce", "treated_pce", "control_voc", "treated_voc"]
    text_variables = ["structure_pin_nip", "passivating_molecule", "perovskite_composition", 
                      "electron_transport_layer", "hole_transport_layer"]
    
    # Initialize comparison dictionaries
    numerical_dict = {var: {"TP": 0, "FP": 0, "FN": 0} for var in numerical_variables}
    text_dict = {var: {"TP": 0, "FP": 0, "FN": 0} for var in text_variables}
    stability_dict = {
        "ISOS-D": {"TP": 0, "FP": 0, "FN": 0},
        "ISOS-L": {"TP": 0, "FP": 0, "FN": 0},
        "ISOS-T": {"TP": 0, "FP": 0, "FN": 0}
    }

    for key, label_value in labeled_data.items():
        if key not in extracted_data:
            print(f"Extraction was not performed. Paper num: {key}")
            continue
        
        extracted_value = extracted_data[key]

        for id, label in label_value.items():
            # Handle numerical values
            if id in numerical_variables:
                if isinstance(label, str) and label.replace(".", "").isdigit():
                    result = numerical_comparison(id, label_value, extracted_value)
                    numerical_dict[id][result] += 1

            # Handle text values
            elif id in text_variables:
                if isinstance(label, str):
                    result = text_comparison(id, label_value, extracted_value)
                    text_dict[id][result] += 1

            # Handle stability tests
            elif "ISOS" in id:
                result = stability_comparison(id, label_value, extracted_value)
                stability_type = f"ISOS-{id[4]}"  # Extract stability type
                if stability_type in stability_dict:
                    stability_dict[stability_type][result] += 1

    # Merge all results
    combined_dict = {**numerical_dict, **text_dict, **stability_dict}
    print("Performance for each variable in dictionary:", combined_dict)

    # Compute precision, recall, and F1-score
    variable_list, precision_list, recall_list, f1_list = [], [], [], []
    for variable, performance in combined_dict.items():
        TP, FP, FN = performance["TP"], performance["FP"], performance["FN"]
        
        precision = safe_division(TP, TP + FP)
        recall = safe_division(TP, TP + FN)
        f1 = safe_division(2 * precision * recall, precision + recall)

        variable_list.append(variable)
        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)

    return variable_list, precision_list, recall_list, f1_list

# %%
variables, precisions, recalls, f1s = compare_json(clean_label_data, subset_llama)
# Out:
# Performance for each variable in dictionary: {'control_pce': {'TP': 4, 'FP': 1, 'FN': 1}, 'treated_pce': {'TP': 9, 'FP': 0, 'FN': 0}, 'control_voc': {'TP': 5, 'FP': 1, 'FN': 2}, 'treated_voc': {'TP': 8, 'FP': 3, 'FN': 1}, 'structure_pin_nip': {'TP': 7, 'FP': 17, 'FN': 1}, 'passivating_molecule': {'TP': 6, 'FP': 13, 'FN': 1}, 'perovskite_composition': {'TP': 15, 'FP': 19, 'FN': 1}, 'electron_transport_layer': {'TP': 12, 'FP': 14, 'FN': 1}, 'hole_transport_layer': {'TP': 27, 'FP': 12, 'FN': 0}, 'ISOS-D': {'TP': 11, 'FP': 0, 'FN': 8}, 'ISOS-L': {'TP': 2, 'FP': 0, 'FN': 22}, 'ISOS-T': {'TP': 0, 'FP': 0, 'FN': 4}}

# %% [markdown]
# ## Calculate Macro f1 score

# %%
def macro_f1(f1_list, weight = None):
    if weight == None:
        #If no weight given, do unweighted average of f1 score
        return sum(f1_list) / len(f1_list)
    total_f1 = 0
    for i in range(len(f1_list)):
        total_f1 += (f1_list[i] * weight[i])
    return total_f1 / sum(weight)

# %%
## The macro f1 score unweighted
macro_f1(f1s)
# Out:
# 0.599084595959596

# %% [markdown]
# ### This concludes the pipeline of evaluating extraction quality

# %% [markdown]
# # Todo:
# - stability evaluation
#     - Need to reiterate on the teamtat annotation
#
# - Putting weights on F1 Score

# %% [markdown]
# ## Stability annotation brainstorm
#
# - We will have as at most 5 realation (if there is an overlap, choose the stability test that offers more info)
#     - Exp there is ISOS L1 and ISOS L2. If there is more iformation in IsosL2, use that as a test and compare on ISOSL that llama extracted (if any)
# - We will iterate through different test recorded on annotation and compared it with suitable stability extracted on Llama
