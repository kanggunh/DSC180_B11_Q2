# %%
import pandas as pd

df = pd.read_csv('data_with_smiles.csv')

print(df.head())
print(df.info())
# Out:
#    Unnamed: 0        perovskite_composition electron_transport_layer  \
# 0           0                        MAPbI3                PEDOT:PSS
# 1           3  Cs 0.05 FA 0.9 MA 0.05 PbI 3                      NaN
# 2           6       FA0.83Cs0.17PbI0.6Br0.4                     PTAA
# 3           7                           NaN                      NaN
# 4          18                           NaN                      NaN
#
#   pin_nip_structure hole_transport_layer     passivating_molecule  \
# 0               NIP                 PCBM                     DAAB
# 1               NaN                  NaN  Cyanoguanidine diiodide
# 2               PIN               PFN-Br               [BMP][BF4]
# 3               NaN                  NaN      Thioacetamide (TAA)
# 4               NaN                  NaN     2-Mercaptopyrimidine
#
#    control_pce  control_voc  treated_pce  treated_voc  ...  \
# 0         4.50         0.87        12.60        0.920  ...
# 1        20.44      1077.00        23.04     1119.000  ...
# 2          NaN          NaN          NaN          NaN  ...
# 3          NaN          NaN        17.86        0.971  ...
# 4          NaN          NaN        21.70        1.120  ...
#
#   control_fill_factor treated_fill_factor controljsc  treatedjsc  \
# 0                 NaN                 NaN        NaN         NaN
# 1                 NaN                 NaN        NaN         NaN
# 2                 NaN                 NaN        NaN         NaN
# 3                 NaN                 NaN        NaN         NaN
# 4                 NaN                 NaN        NaN         NaN
#
#    treated_hysteresis_index binding_energy fill_factor treated_iscc  \
# 0                       NaN            NaN         NaN          NaN
# 1                       NaN            NaN         NaN          NaN
# 2                       NaN            NaN         NaN          NaN
# 3                       NaN            NaN         NaN          NaN
# 4                       NaN            NaN         NaN          NaN
#
#                                 IUPAC_passivator  \
# 0                          diammonium azobenzene
# 1                        Cyanoguanidine diiodide
# 2  1-Butyl-3-methylimidazolium tetrafluoroborate
# 3                                  Thioacetamide
# 4                           2-Mercaptopyrimidine
#
#                            passivator_smiles
# 0  N(=NC1=CC=CC=C1)C1=CC=CC=C1.[NH4+].[NH4+]
# 1                     [I-].[I-].C(#N)NC(=N)N
# 2         F[B-](F)(F)F.C(CCC)N1C=[N+](C=C1)C
# 3                                  C(C)(=S)N
# 4                               SC1=NC=CC=N1
#
# [5 rows x 38 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                758 non-null    int64
#  1   perovskite_composition    308 non-null    object
#  2   electron_transport_layer  282 non-null    object
#  3   pin_nip_structure         210 non-null    object
#  4   hole_transport_layer      236 non-null    object
#  5   passivating_molecule      758 non-null    object
#  6   control_pce               401 non-null    float64
#  7   control_voc               328 non-null    float64
#  8   treated_pce               553 non-null    float64
#  9   treated_voc               394 non-null    float64
#  10  test_1                    704 non-null    object
#  11  test_2                    191 non-null    object
#  12  structure_pin_nip         6 non-null      object
#  13  treated_jsc               14 non-null     float64
#  14  treated_ff                31 non-null     float64
#  15  test_3                    62 non-null     object
#  16  test_4                    8 non-null      object
#  17  test_5                    1 non-null      object
#  18  test_6                    1 non-null      object
#  19  test_7                    1 non-null      object
#  20  test_8                    1 non-null      object
#  21  test_9                    0 non-null      float64
#  22  test_10                   0 non-null      float64
#  23  control_jsc               3 non-null      float64
#  24  control_ff                6 non-null      float64
#  25  control_pec               0 non-null      float64
#  26  treated_eqe               0 non-null      float64
#  27  treated_stabilized_pce    0 non-null      float64
#  28  control_fill_factor       0 non-null      float64
#  29  treated_fill_factor       0 non-null      float64
#  30  controljsc                0 non-null      float64
#  31  treatedjsc                1 non-null      float64
#  32  treated_hysteresis_index  1 non-null      float64
#  33  binding_energy            0 non-null      float64
#  34  fill_factor               1 non-null      float64
#  35  treated_iscc              1 non-null      float64
#  36  IUPAC_passivator          742 non-null    object
#  37  passivator_smiles         758 non-null    object
# dtypes: float64(21), int64(1), object(16)
# memory usage: 225.2+ KB
# None

# %%
import pandas as pd
import ast

# Define a function to expand rows by tests
def expand_rows_by_tests(df):
    # Create a list to store the expanded rows
    expanded_rows = []
    
    # Iterate through each row in the dataframe
    for _, row in df.iterrows():
        # Iterate through test columns
        for i in range(1, 11):  # Assuming test_1 to test_10
            test_column = f'test_{i}'
            test_data = row[test_column]
            if pd.notnull(test_data):
                try:
                    test_list = ast.literal_eval(test_data)
                    if isinstance(test_list, dict):
                        test_list = [test_list]
                    for test_dict in test_list:
                        new_row = row.drop([f'test_{j}' for j in range(1, 11)])
                        # Add test details to the new row
                        for key, value in test_dict.items():
                            new_row[key] = value
                        expanded_rows.append(new_row)
                except (ValueError, SyntaxError):
                    print(f"Could not parse test data: {test_data}")

    # Create a new dataframe from the expanded rows
    expanded_df = pd.DataFrame(expanded_rows)
    return expanded_df

# Apply the function to expand the rows
expanded_df = expand_rows_by_tests(df)

# %%
expanded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 969 entries, 0 to 757
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                969 non-null    int64
#  1   perovskite_composition    401 non-null    object
#  2   electron_transport_layer  366 non-null    object
#  3   pin_nip_structure         280 non-null    object
#  4   hole_transport_layer      303 non-null    object
#  5   passivating_molecule      969 non-null    object
#  6   control_pce               542 non-null    float64
#  7   control_voc               446 non-null    float64
#  8   treated_pce               732 non-null    float64
#  9   treated_voc               526 non-null    float64
#  10  structure_pin_nip         9 non-null      object
#  11  treated_jsc               19 non-null     float64
#  12  treated_ff                42 non-null     float64
#  13  control_jsc               4 non-null      float64
#  14  control_ff                9 non-null      float64
#  15  control_pec               0 non-null      float64
#  16  treated_eqe               0 non-null      float64
#  17  treated_stabilized_pce    0 non-null      float64
#  18  control_fill_factor       0 non-null      float64
#  19  treated_fill_factor       0 non-null      float64
#  20  controljsc                0 non-null      float64
#  21  treatedjsc                2 non-null      float64
#  22  treated_hysteresis_index  2 non-null      float64
#  23  binding_energy            0 non-null      float64
#  24  fill_factor               1 non-null      float64
#  25  treated_iscc              1 non-null      float64
#  26  IUPAC_passivator          957 non-null    object
#  27  passivator_smiles         969 non-null    object
#  28  test_name                 875 non-null    object
#  29  temperature               746 non-null    object
#  30  time                      849 non-null    object
#  31  humidity                  450 non-null    object
#  32  retained_percentage_cont  715 non-null    object
#  33  retained_percentage_tret  611 non-null    object
#  34  stability_type            26 non-null     object
#  35  retained_proportion_cont  22 non-null     float64
#  36  retained_proportion_tret  18 non-null     float64
# dtypes: float64(21), int64(1), object(15)
# memory usage: 287.7+ KB

# %%
print("Temperature Values:")
print(expanded_df['temperature'].to_list())

print("\nTime Values:")
print(expanded_df['time'].to_list())

print("\nHumidity Values:")
print(expanded_df['humidity'].to_list())
# Out:
# Temperature Values:
# [30, 30, None, None, None, None, 200, 800, 45, 45, 85, 85, 85, 40, 65, 25, 25, None, None, None, 30, '30 days', 50, None, None, None, None, None, None, 25, 85, 365, 25, 25, None, None, None, 25, 25, None, 85, None, 25, 60, 80, 1000, 85, None, 85, 1000, 25, 25, 65, 30, 50, None, 1400, 120, 45, None, None, 25, None, 'Room temperature', '20 ± 5 °C', 85, 60, None, 27, 25, 25, 26, None, '15-25°C', None, None, 35, 35, None, 25, 25, 25, 85, 25, '50-60', 60, 80, 303, 1000, 25, None, 45, 85, 25, 25, 85, None, 100, 30, None, 300, None, None, 25, None, 'ambient', 25, 25, 45, 40, 25, 55, 65, None, 25, 1, 50, 25, None, None, None, 65, 25, 20, 20, 300, 20, None, 25, 25, 80, 'Room temperature', 25, 25, 25, 'room temperature (25 °C)', '25 °C', '30 ± 10%RH air', 85, None, None, None, 25, 25, 25, 85, 25, 25, 45, 45, 45, None, None, 25, 30, 65, None, 50, None, None, None, 100, 100, 30, 25, 25, 25, 25, 25, '50-80', 25, 85, 25, 1000, 60, 300, 27, None, 25, 40, 25, 85, None, 25, '25 °C', 20, None, 60, 200, 40, 25, 25, '300 ppm O2 and 20% RH', 500, None, None, None, None, None, 100, 40, 40, 50, '25-30 °C', '65 °C', '85 °C', '65 °C', '85 °C', '65 °C', '85 °C', '1 Sun white LED', None, 25, 300, 25, 260, 20, 60, 25, None, 25, 25, 25, 25, 40, 60, 'ambient', 25, 25, 50, 25, 65, 25, 25, None, '15-35 °C', 25, None, None, 25, 35, None, 50, 85, 85, None, 120, 25, 25, 65, 'dry air', 100, None, 22, 100, 3100, 70, 30, 70, None, None, 25, 85, 25, 25, 85, None, None, 40, 10, 25, None, None, None, 1000, 1400, 65, None, None, 25, 373, 25, None, 25, 25, 65, 85, 80, 25, 30, 35, 25, 85, 85, None, '40-45 °C', 300, 100, 300, 80, '25-30 °C', '25-30 °C', 25, None, None, None, None, 25, 85, 20, 65, 60, 60, 25, 25, 30, 250, 25, 6, None, 500, 40, 20, 35, 4000, 1000, 25, 25, 20, 55, 1500, 25, 30, 85, 25, None, 25, 85, 65, None, 25, 85, 25, 85, 25, 65, 22, 22, 22, 22, None, 2000, 1000, 25, 25, 25, 25, 80, 25, None, 40, 25, 1800, 658, None, 25, None, '25 1C', 25, 25, None, None, None, 25, 25, None, 40, None, 25, 80, 60, 60, None, None, 25, 25, 25, 85, 1000, 6, 25, 50, 80, 25, 25, 25, 25, 85, 1000, None, None, 25, 30, 50, 85, 20, 25, 65, 25, 100, 500, 100, 'air', 25, 85, 35, 65, 85, None, 25, None, None, 343, 53, None, None, None, 30, 1100, 25, None, None, None, None, 600, 1000, None, 'Room temperature (20-40% RH)', '85°C', 25, 20, 'N2 atmosphere', None, 35, 65, 30, 30, None, 25, 25, 60, 85, 30, 85, 90, 25, 25, None, 25, 1000, None, 25, 25, 25, None, 'air and nitrogen atmospheres', None, None, 20.0, 60, 25, 85, 25, 25, 45, None, None, 150, 65, 85, 25, 18, 60, 25, 25, None, None, 25, 25, 25, 120, 35, 60, 85, None, 700, None, None, None, None, 30, 25, 25, 85, 85, None, 25, None, None, None, 25, 85, 500, 30, 3000, None, 10, 100, 'desiccated conditions', 25, 30, 25, 25, 30, 30, 25, None, 100, 25, 65, None, 85, None, '20-25 °C', 60, 25, 20, 20, 40, 25, 20, 85, None, 'room temperature', 40, None, 25, 25, 60, 25, 25, 20, None, 85, None, 65, None, 25, 25, 25, 25, 25, None, '25 °C', 30, 25, 25, 2000, 450, 85, 25, 'Nitrogen', 25, None, None, 70, None, 25, 25, 30, 85, 25, 30, 85, 25, 25, 55, None, 60, None, 20, 25, 85, 85, 25, None, 25, 85, 25, 25, 65, 25, 25, 30, 120, 40, 85, None, 300, 20, 22, 45, 85, None, 25, 25, 70, 25, None, 60, 25, 85, None, 150, 25, 25, 25, 85, 30, 85, 'room temperature', '85 °C', 'AM1.5 illumination', 'room temperature', 85, 25, 85, None, 20, 25, 25, '15-25 °C', 50, 25, 50, 25, 24, 20, 85, 25, 40, 80, 55, 85, None, 'Room temperature', 85, None, 25, 85, 1000, 25, 25, 100, None, None, 85, 25, 60, 60, None, None, 25, 25, 25, None, None, None, None, None, 35, 45, None, None, '20-25 °C', 25, 23, 25, 25, 25, None, 25, 'Room temperature (assumed ~25°C)', 'Room temperature (assumed ~25°C)', 50, 60, 50, 25, 25, None, None, 500, None, 30, 0, None, None, '500 h', 60, 25, 30, 50, 80, 25, 60, 'room temperature', 'light/oxygen conditions', 'room temperature', '35 ± 5% RH', 20, 85, 140, 25, 25, 25, None, 160, 25, 25, 25, 25, None, 25, 85, 25, None, 25, 25, 25, 'room temperature' ...
#
# Time Values:
# [1000, 1000, 60, 97, 672, None, 24, 800, 60, 500, 50, 50, 120, 900, 700, 18, 16, 24, 150000, 23, 600, '30 days', 600, None, None, None, None, None, None, 1176, 60, 70, 0.7000000000000001, 1250, 316, None, None, 480, 1500, None, 1500, 1992, 1000, 10000, 1000, '1000 h', '1000 h', None, 750, 1000, 500, 300, 500, 700, 400, 1900, '1400 h', 400, 1000, '3 weeks', None, '2000 hours', 1000, '30 days', '76 days', 1000, 1500, 5000, '25 days', 330, 10, 1400, 78, '1200 hours', '25 days', '4 times', 1344, 1344, 500, 1000, 2000, 20000, 1000, 1200, 500, '60 days', '30 days', 1500, 1000, 2000, 1000, 3100, 600, 1000, 2000, 500, None, 60, 24, 60, 50, 450, 450, 8000, 9.5, '3 weeks', 8, 1301, 20, 1000, 29, 1000, 1200, None, 10, '1000 h', 720, 1000, None, None, None, 300, 1000, 200, 200, 2, 2000, None, 500, 500, 500, 600, 1000, 130, 30, '1000 hours', '1000 hours', 2000, 12, 560, 1200, 1000, 1080, 300, 1440, 1300, 850, 400, 1100, 1100, 1100, '200 hours', 180, 865, 760, 312, 720, 1000, 2000, 1000, None, None, None, 720, 110, 6, 1000, 60, '24 hours', '60 days', '1800 s', 240, 12400, '1000 hours', 240, '1 hour', 750, None, 500, 2000, 275, 300, None, 1300, '1800 hours', 700, None, 300, 200, 500, 60, 1000, 336, 500, None, None, None, None, None, 500, 1000, 1200, 1000, '900 h', '600 h', '600 h', '600 h', '600 h', '600 h', '600 h', '300 h', 2000, 1000, 'Short-term (during film formation)', 'During film drying', 'Varied temperatures', 40, 900, 1000, None, 100, 1000, 1000, 65, 230, '24 hours', '43.41 min', 290, 1050, 120, 'Long-term (several days)', 'Under hot pressing in N2-filled glove box', 1400, 1000, 100, 850, 144, '30 days', 28, 10, 1600, None, 330, 2000, 200, 200, 60, 500, 500, 500, 2000, 1, 500, 2500, None, '3100 hours', '72 hours', 1000, 200, 'Indoor stability assessment following ISOS-L protocol (reported during the year 2024 only)', 400, 2000, 1000, 1000, 1000, 350, 5000, 10, 108, 7100, 29, 450, '1500 hours', '1 week', '1000 hours', '1400 hours', 480, 650, 1400, 6000, '960 hours', 1000, 62, 1000, 850, '4 days', '4 days', 600, 1200, 41, 2000, 3, 1500, 500, 1000, 1200, None, None, None, '10 min', '14 days', '10 days', 1800, '1 month', 600, 1000, 1500, 1000, 500, 21, 1800, '24 hours', '24 hours', 600, 420, 840, 250, 1540, '6 days', 4080, '500 s', 7000, 10, 720, '4000 s', '1000 hours', 600, 1000, 656, 2400, '1500 hours', 14, 1000, 1250, 40, '106.1 h', 1500, 1000, 1200, None, 3000, 1000, 196, 1200, 2000, 240, 75, 60, None, 75, 20000, '2000 h', '1000 h', 500, 1000, 1700, 30, 7, 32, 45, 1000, 8, '1800 h', '658 h', 600, 10208, None, '16 hours', 1500, 900, None, '300 s', None, 3384, 2112, None, 500, 0.25, 800, 800, 1300, 1300, 300, None, 1152, 1000, 1000, 1000, '1000 hours', '6 months', '24 hours', 25, None, 1000, 1000, 1200, 800, 400, 1000, 340, 1000, 15, 1500, 50, 500, 500, 1000, 1000, 60, 1, 5, 300, '30 days', 1000, 500, 320, 320, 3, None, 2000, None, None, None, 72, None, None, 19, '1 month', '1100 hours', '24 hours', None, 54, None, None, 600, 1000, None, '45 days', '10 days', 180, 1000, '1000 hours', None, 2034, 193, 72, 300, None, 1600, 800, 1300, 1200, 1000, 1000, 2160, 24, 500, 300, 2300, 1000, 2000, 1000, 2000, 850, '8 μs', '800 h and 1000 h', None, None, 200, 60, 1000, 1081, 24, 3000, 500, 720, '1.2 × 10^6 shots', None, 400, 500, 200, 240, '24 hours', 1370, 1200, '10 16 e per cm²', 2, 672, 5200, 700, 60, 7200, 2000, 162, 500, 30, None, None, None, None, 816, 1600, 1000, 600, 500, 5000, 180, None, None, None, 1200, 600, 10, None, '10000 hours', 1500, 700, 10, 'over 50 days', 100, 1800, 145, 11, 1920, 10, 336, None, 240, 2400, 288, 1500, 600, 1826, '1000 h', 1200, 300, 250, 500, 2000, 2000, 600, 400, 600, 1700, 760, 60, 1000, 1000, 300, None, 1200, 720, 600, 300, 1900, 250, 6, None, 1300, 3500, 500, 1600, None, '500 hours', 2000, 10, 31, '24 h', '450 h', '200 h', 120, 2700, 1560, 913, 500, 7, 600, 1200, 1200, 780, 500, 1600, 840, 500, 488, 490, 2136, None, 1, 5000, 2100, 200, 1200, 320, 40, None, 1000, 500, 594, 33.2, 300, '24 hours', 1000, 2000,  ...
#
# Humidity Values:
# [70, 70, None, None, None, None, None, None, 45, '45%', 0, 85, 0, None, None, None, 35, None, None, None, '30-40%', '80 %', None, None, None, None, None, None, None, '30-35%', None, None, 60, 55, None, None, None, 30, None, None, 'Moist air with 70 ± 5% RH', None, 'ambient air', None, None, None, None, None, None, None, 35, 0, 0, 35, None, '45', None, None, None, 'ambient', None, None, None, '20%-60% relative humidity', '<5% RH', None, 70, None, '70% RH', 50, None, None, None, '25-50% relative humidity', None, None, '50-60%', '50-60%', None, 15, None, None, None, 50, None, 'dry', '30% relative humidity', 50, 50, None, None, None, None, 45, None, None, None, None, None, None, None, None, None, 35, None, 'ambient', None, None, None, '40 %', '70% relative humidity', 30, 65, None, 20, None, None, None, None, None, None, 'Nitrogen atmosphere', '50 ± 5%', 48, 48, None, '10-20%', None, 45, '25% ± 5%', 'N2', '30-50%', 20, 20, '50-80 %', 'dry (pure oxygen)', '50 ± 5% RH', '30 ± 10%RH air', 'open-air', 'open-air', '50-60%', '35-45%', None, None, None, None, None, 60, '45 %', '45 %', '45 %', None, None, None, 40, None, None, None, None, None, None, None, None, '30-45%', None, None, None, None, 50, '50-80', None, None, '<20', None, None, '25% RH', 35, None, 'dry air', 40, None, None, None, None, '60-70% RH', '40-60', None, 45, None, '30-40%', '20-30%', 'Not explicitly mentioned', 20, None, None, None, None, None, None, 'B85%', None, None, None, '35-45% RH', 'N2 glove box', 'N2 glove box', '20% RH', '20% RH', '70% RH', '70% RH', 'ambient', None, '5-10%', 34, 34, None, None, 15, '40 ± 10 %', None, None, None, 60, 40, None, 50, None, 0, 12, '50%', '30-40% RH', None, '30-35%', 20, None, '40-90%', None, '50 ± 5% RH', None, 20, 40, None, None, 85, 85, None, None, 65, 25, None, None, None, None, 35, None, None, None, '30% relative humidity', 'dry atmosphere', None, None, 55, 'N2 atmosphere', None, None, None, None, None, 40, '10-20% RH', 70, None, 'null', '45%', '40% humidity', 'moderate humidity', None, None, None, None, None, '40-55%', None, 25, None, None, None, 40, 30, 30, '35% relative humidity', None, 85, None, None, None, None, None, None, None, '30-40% RH', '65% RH', None, None, '40-50%', None, None, '20 ± 5%', 'N2 atmosphere', '25-35%', None, 30, 30, 30, 50, 30, 0, None, None, None, None, None, 50, 5, None, None, 5, 50, 30, 80, 35, 50, 30, 30, '50%-60%', None, 60, None, None, None, 35, 85, None, 85, None, None, 50, 50, None, 50, None, None, None, None, None, None, None, None, None, None, None, '<5%', '10% humidity', None, None, 5, None, '70% RH', 50, None, None, None, None, 'dry', 'air', None, 25, None, None, None, 60, 60, None, None, 25, 50, 85, 85, None, None, None, 'relative humidity', None, 30, 35, 25, 85, None, 'air', None, None, 20, 50, 'N/A', 'dry', 40, 'N2', 'ambient air', '25-30%', None, None, None, '20 ± 5% RH', 40, None, 35, 65, 85, None, 10, None, None, None, 53, None, None, None, 30, '20-30% RH', '30% RH', None, None, None, None, None, None, None, '20-40% RH', 'N2 glove box (RH < 10%)', 50, 5, None, None, 35, None, 35, '30% relative humidity', None, '50-60%', 35, 60, None, 30, 85, None, 50, '30-40% RH', 'high (>50% RH)', 25, 30, None, None, 'N2 with 50-100 ppm O2', None, None, None, None, None, 40, 70, nan, None, 50, None, None, 'ambient', None, None, None, 'Nitrogen environment', 'Ambient air', 30, 50, 'air', '20% ± 5%', None, None, 'ambient air (RH < 10%)', 25, None, 100, '35% RH', '60% RH', '85% RH', None, None, None, None, None, None, None, None, None, 85, None, 40, None, None, None, None, 50, None, None, 50, None, '35-40%', 30, None, 'controlled', 'controlled environment', '30% RH', 20, 60, '30%', None, None, None, None, 30, None, '30 AE 10%', None, None, '30-60% RH', None, '20-40%', 35, None, None, 25, 20, None, None, '5%-8% RH', None, None, 'dry', '20-50', None, None, None, '20% ± 5%', '20-30% RH', None, 40, None, None, None, 25, 25, '30-40%', '20-25%', None, 'null mentioned', 40, '35-45%', 20, None, None, None, None ...

# %%
print("\%_cont Values:")
print(expanded_df['retained_percentage_cont'].to_list())

print("\%_tret Values:")
print(expanded_df['retained_percentage_tret'].to_list())
# Out:
# \%_cont Values:
# [90, 90, 77, None, 78, None, None, 100, 100, 48.0, 80, 79, 15, 30, 50, 80, None, nan, None, None, 80, 46, 94, 100, None, 75, 70, 65, 100, 87, 23, None, None, 42, None, 31.33, 79, None, 80.2, 56, 90, 85.5, 51.1, None, 56, 10.92, None, 96, 90.9, 95, 25, 19.72, 50, 30, 98.7, None, 87.5, 90, 52, None, None, 92.31, 70, 69, 91, 60, 70, 65, 80, 190, 65.5, 88, 80, 66, 2.88, None, 75.84, 75.84, 90, 93.3, None, 92, nan, nan, nan, 70, 70, 100, None, 85, 54, 90, 54, 76, 50, 32, None, 57.9, 14.7, 49.2, 100, 82.9, 93, 80, 18.9, 100, None, 98.3, 50, 90, 83, 96.8, 15, None, 20, 75, 70, 50, None, None, None, 80, None, 71, 71, None, 57, None, 63.5, 74.49, None, 57, 96.26, 0.03, 90, 88, None, 80, 80, None, 95, 77, 91, 50, 0.85, None, None, 90, 84, 72, 70, None, 9.5, 94, 72, 90, 56, 58, 40, None, None, 100, 85, 71, 90, 90, 90, None, 85, nan, nan, nan, nan, 95, 63, 82, 94, None, 87, 95, 95, 88, 100, 96, 17.88, nan, None, 60, 83, 9, 21.32, 52, nan, 63, 66, 13.6, 58.0, None, None, 90, 0, 86, 94, 89, 70, 68, 68, 62, 48, 35, 65, 100, 63.7, 30, 50, 60, 100, 90, 90.05, 85, 100, 70, 61, 94.74, 82, 95, 100, 90, 40, 73.27, 100, None, 90, 57.4, 80, None, None, None, 69, 80, 83, None, 80, None, None, None, 95, 62, 90, 28, 96, 85, 12.9, 81, None, 82, 58, 93, None, 'Above 90%', 80, 70, 85, 65, 82, 61, 71, None, 19, 82.0, 83, None, 91.3, 72.01, 60, 40, 90, 82, 60, None, 93, 45, 13.78, 58, 67.7, 90, None, 90, 20, 77, 67, None, 95, 90, 87, None, None, None, None, 100, 60, 37, 97, None, 70, 65, 60.5, 71, None, 81, 67, 84.55, 84.57, 90, 93, 88, 23.6, 90, 50, None, 0.34, 85.88, None, 63.1, 98, 69, 92, 85, 70, 30, 80.4, None, 92, 80, 20, 50, 44, 54, 94, 66.85, 81, 82, 95, 40.4, 70.0, 42.1, 60, None, None, 50, 25.0, 95, None, 73.4, 22.02, None, 96, 97, 78, 96, 90, None, 98, 80, 93, 98, None, None, 90, None, None, None, None, 95.4, 82.8, None, 90, 50, 31, 30, 90, 49, 70, None, 70.25, 76.33, 56.38, 8.71, 85, None, 100, 0, None, 97.61, None, 80, None, 63, None, 80.0, None, 58, 85, 100, 29.95, 25.12, 54.5, 78, 15, 98, None, 73, 91, 91, 36, 63, 47, 74, None, 57, None, None, 70, None, None, 30, None, 84, 52, 85, None, 90, None, None, 96, 78, None, 30, 50, 32.7, 62, 79, None, 30, 35, 10, 87, None, 86, 78.4, 87, None, 80, None, 72, None, 89, 43, 87, 90, 22.5, 30, None, 66, None, 78, 61.77, None, 73, 76, 36, 96.6, 60, 80, 95, 80, 75, None, 70, 89.83, 60.11, 75, 85, 48, 64.9, 93, None, 90, 74, 60, 20, 80, None, None, None, None, 36.6, None, None, None, 40, 90, 82, 65.3, 69.7, 82.1, 80, 60, 15, None, None, None, None, 16.5, 96.0, 60, 80, None, None, 85, 79, 99.3, 88.6, 90, 80, 80, None, None, 90, None, 50.0, 73, 53, 90, 93, 65, 77, 35, None, 80, 57.1, 54.9, 98, 19, 61.5, 81.2, 58, nan, nan, None, 94, 80, 95, 60, 92.6, 8.8, None, None, 80, None, 80, None, None, 20, 40, 'less than 45%', 71, 90, 80, 80, 78.7, 75, 77, None, 93, 20, 90, 95, None, 96.8, 20, 90, 63, 85.97, 46.56, 77.05, 97.52, 75.1, 5, 65.3, 68.4, 94, 95, 50, nan, None, None, None, 100, 100, 97, 55, 97, 71.66, 70, 40, None, None, 70, 80, 11.03, 35, 27, 50, 94, None, 79, 61.6, 81, None, 92, None, None, 74, 85, 61, None, 32, 83, 51, 94.2, 58.2, 60.3, 95, 50, 80, 30, 89, 81.1, 80, 80, nan, 59, 85, 30, 5, None, 70.4, 94, None, 50, 30, 96.5, 63.7, None, 85, 35, 100, 65, 80, 65, nan, nan, nan, 85, 80, nan, 50.32, 70, 90, 70, None, 100, 80, None, 86.2, None, None, None, 91, None, None, None, None, nan, 75, None, None, None, 95, None, 84.53, '31.22', None, 90, 80, 92, None, 80, None, None, 290, None, 30, 33, None, 3.55, 90, 84, 91.2, 17, 90, 29.8, 0, 80, 68, None, 19.2, 67, 68, 66.6, 7.5, 91.44, 83.9, 75.9, None, 100, 94.69, 55, 17, 78, 90, None, None, 20, None, 90, None, 85, 90, 81.3, 91, 90, 30, 17, 42, 37, None, None, 95, 96, 100, None, 94, 90, 85, 90, 100, 82.7, None, nan, nan, nan, None, None, None, None, 75, 95.84, 60, 17.2, 80, 70, 60, 80, 90, 70.0, 30, 90, 62, None, None, None, None, None, 48.9, 90, 96, 95, None, None, 26.5, None, None, None, None, 57.6, 40, 92, '80', 90, None, 59.7, None, 87, 100, 90, 90, 90, 77.9, 70 ...
# \%_tret Values:
# [68, 50, 83, 90.0, 88, None, None, 100, 100, 80.5, 87, 89, 120, 90, 90, 80, 93.29, nan, 50, None, 97.1, 68, 94, 100, None, 80, 85, 75, 100, 93, 53, 80, None, 94, None, 31.33, 76, 90, None, 56, 90, 96.2, 91.5, None, 92, None, 11.04, 80, None, None, 85, 90, 70, 69, 98.7, 91, None, None, None, 'Excellent colloidal stability', None, None, None, 89, None, 87, 90, 85, None, 80, 81.5, None, None, 95, None, None, 84.27, 85.5, None, 93.2, 93.2, None, nan, nan, nan, 90, 90, 100, None, 80, 92, 64, 12, 90, 87, 79, None, None, 85.2, 76.3, 70, None, None, None, None, None, 75, 90, 70, None, None, 90.5, 15, 42, 60, 20, 85, 90, None, None, None, None, 80, 78, 78, None, 90, None, 87.1, 96.03, 95.62, 78, 96.26, 0.09, None, None, 91, 80, None, 85, None, None, 100, 50, 0.85, 0.8200000000000001, 0.7000000000000001, 90, 86, 83, 70, '100', None, None, 85, None, 42, 84, 30, None, None, 100, 75, 85, 90, 90, 90, None, 75, nan, nan, nan, nan, None, 81, 84, None, None, None, None, None, None, 100, None, None, nan, None, 90, None, 90, 95, 100, nan, 95.0, 89.5, 20.83, 90.98, None, None, 85, 100, 93, None, None, 90, 88, 86, 84, 80, 76, 95, 100, 99.0, 40, 70, 60, 100, None, 73.91, 92, 80, 90, 83.7, None, None, 97, 100, 80, 96.2, 98.22, 100, 100, 100, 78.1, None, None, 80, None, 77, 80, 81.6, 67.7, 90, 86, 86, 86, 95, 89, 90, 91, None, 91, 15.8, None, 45, None, 80, None, 90, 'Above 90%', 90, 92, None, 85, None, None, None, 17.4, 19, 79.6, None, 100, None, 87.02, 90, 90, None, 95, 96, None, 93, 78, 18.61, 92, 83.4, 30, 30, 61, 80, 87, 93, None, None, None, None, 93, None, None, None, 100, 81, 62, 90, 99.7, 86, 87, 97, 91, 92, None, 93, 84.57, 84.55, None, None, 63, 86.9, 89.13, 90, None, 0.34, None, 63.49, 87.1, None, 89, 92, 90, 70, 70, 92.6, None, 83, None, 80, 100, 82, 81, None, None, None, None, None, 85.1, 89.6, 90.1, None, None, None, 60, 92.0, None, 90, 94.5, 98.7, None, 96, None, 28.9, None, None, 25.05, None, 83, None, 85.5, None, None, None, 95.9, None, None, None, None, 86.6, None, 90, 70, 82, 85, 92, 81, 70, None, 95.75, 76.33, 66.03, 7.52, None, 99, 100, 100, 100, None, 92.27, None, 60, None, None, 94.0, 92.2, 72, None, 100, 81.06, 72.03, 93.98, 94, 85, 96.8, None, None, None, None, 86, 85, 76, 91, 100, 96, None, None, 70, 100, 100, 85, None, 95, 74, 75, None, None, None, None, None, 91.15, None, 70, 85, 100, 90, None, None, 70, 80, 60, 96, None, None, None, None, 88, 70, 70, 92, None, 97, 73, None, 90, 17.83, 90, 100, 88, 100, 90, None, None, 98, 91, 87, None, 70, None, 95, 80, None, None, None, None, 92.57, 95, 75, 92, 93.2, 95, 46.2, 85, 87, 97, 80, None, 91, 80, 90, None, None, 20952, 207.5, 8.1, 88, 85, None, 89.6, 90.1, 89.7, 42, None, None, None, 96.4, 90.1, None, None, None, 89, 80, 95, '100% (no degradation observed)', 75, 90, None, None, None, None, 80, None, 100, 96, 96, 84.5, 73, 84, None, None, None, None, 71, 90, 91, 94.4, 78, None, 77, None, 75.4, 86, nan, nan, None, None, 95, 20, 3.48, None, None, None, 100, 80, 80, 94, 90, None, 93, 88, 'more than 70%', 89, 80, 17, 42, None, 92, 93, 96, 93, 18.9, None, 91, 91, None, 80, 90, 88, None, 97.53, 96.5, None, 61.3, None, 89.1, 82.8, None, 88, 78, nan, None, 83.0, 83.0, 100, 100, 97, 43, None, 87, 85, 90, 82, None, 50, 100, 92.7, 85, 85, 83, None, 93, 94, 77.5, 93, 80.4, None, None, None, 80, 85, 93, None, 66, 91, 79, None, 74.43, 92.9, 1, 92, None, 82, None, 98.5, 80, 80, nan, 90, 90, 93, 87, 90, 97.0, None, 93, 100, 100, 94.9, None, None, 85, 55, 100, 81, None, 70, nan, nan, nan, None, None, nan, 92.89, 75, 90, 70, None, None, 90, None, None, None, 15, None, None, None, None, None, 95, nan, 86, None, None, None, 95, None, 94.66, '50.18', '50.18', None, None, None, 80, 96, None, None, None, None, 70, 91, None, None, 90, 88, 98.1, 84, 90, 35.8, 60, None, 78, None, None, 90, 83, 98.4, 93.1, None, None, 90.1, None, 100, None, 94, 93, 89, 93.17, 80, None, 90, None, 90, 100, 93, 73, 92.7, 91, 90, 81, 85, 88, 76, 95, None, None, None, 100, None, None, 90, 75, 60, 100, None, 80.3, nan, nan, nan ...

# %%
import pandas as pd
import re

# Define the conversion functions
def convert_values(values, value_type):
    def convert_temperature(value):
        if isinstance(value, (int, float)):
            return value
        value = str(value).strip().lower()
        
        if '-' in value:
            try:
                parts = value.split('-')
                return (float(parts[0]) + float(parts[1])) / 2
            except ValueError:
                return None
        
        if '±' in value:
            try:
                num = float(value.split('±')[0].strip())
                return num
            except ValueError:
                return None
        
        if 'room temperature' in value or 'ambient' in value:
            return 25.0
        
        temp_match = re.match(r"(\d+)(°[cfk]+)?", value)
        if temp_match:
            return float(temp_match.group(1))
        
        return None

    def convert_time(value):
        if isinstance(value, (int, float)):
            return value
        value = str(value).strip().lower()

        if 'h' in value or 'hour' in value:
            try:
                return float(value.replace('h', '').replace('hour', '').strip())
            except ValueError:
                return None
        
        if 'days' in value:
            try:
                return float(value.replace('days', '').strip()) * 24
            except ValueError:
                return None
        if 'weeks' in value:
            try:
                return float(value.replace('weeks', '').strip()) * 7 * 24
            except ValueError:
                return None
        if 'months' in value:
            try:
                return float(value.replace('months', '').strip()) * 30 * 24
            except ValueError:
                return None
        if 'min' in value or 'minute' in value:
            try:
                return float(value.replace('min', '').replace('minute', '').strip()) / 60
            except ValueError:
                return None
        if 's' in value or 'second' in value:
            try:
                return float(value.replace('s', '').replace('second', '').strip()) / 3600
            except ValueError:
                return None

        return None

    def convert_humidity(value):
        if isinstance(value, (int, float)):
            return value
        value = str(value).strip().lower()

        # Handle ranges like "30-40%" and "20-30% RH"
        if '-' in value and '%' in value:
            try:
                parts = value.split('-')
                return (float(parts[0].replace('%', '').strip()) + float(parts[1].replace('%', '').strip())) / 2
            except ValueError:
                return None
        
        # Handle values with ± like "50 ± 5%" or "70 ± 5% RH"
        if '±' in value:
            try:
                num = float(value.split('±')[0].replace('%', '').strip())
                return num
            except ValueError:
                return None

        # Handle percentages like "45%" or "80 %"
        if '%' in value:
            try:
                return float(value.replace('%', '').strip())
            except ValueError:
                return None

        # Handle specific strings like "ambient", "dry", "high", "low"
        if 'ambient' in value:
            return 52.0  # Arbitrary average value for ambient humidity
        if 'dry' in value:
            return 0.1  # Dry air, 0% RH
        if 'high' in value:
            return 72.0  # High humidity, arbitrary value like 70%
        if 'low' in value:
            return 22.0  # Low humidity, arbitrary value like 20%
        if 'n2' in value:  # For N2 atmosphere or N2 glove box
            return 0.2  # Typically low humidity in inert atmospheres

        # Handle descriptive strings like "moist air with 70 ± 5% RH"
        if 'rh' in value:
            try:
                num = re.search(r"(\d+(\.\d+)?)", value)
                if num:
                    return float(num.group(1))
            except ValueError:
                return None
        
        return None

    def process_values(values, value_type):
        if value_type == "temperature":
            return [convert_temperature(v) for v in values]
        elif value_type == "time":
            return [convert_time(v) for v in values]
        elif value_type == "humidity":
            return [convert_humidity(v) for v in values]
        else:
            return []

    return process_values(values, value_type)


def clean_percentage(value):
    if pd.isnull(value):
        return np.nan
    if isinstance(value, (int, float)):
        return float(value)
    value = str(value).lower().strip()

    # Handle 'null', 'n/a', etc.
    if value in ['null', 'n/a', 'none', '-', 'na']:
        return np.nan

    # Handle ranges like '80-90%'
    range_match = re.match(r'(\d+)\s*[-–]\s*(\d+)', value)
    if range_match:
        nums = [float(range_match.group(1)), float(range_match.group(2))]
        return np.mean(nums)

    # Handle '70 ± 5%'
    plus_minus_match = re.match(r'(\d+)\s*±\s*(\d+)', value)
    if plus_minus_match:
        return float(plus_minus_match.group(1))

    # Extract single number (with or without %)
    num_match = re.search(r'(\d+\.?\d*)', value)
    if num_match:
        return float(num_match.group(1))

    return np.nan

expanded_df['retained_percentage_cont'] = expanded_df['retained_percentage_cont'].apply(clean_percentage)
expanded_df['retained_percentage_tret'] = expanded_df['retained_percentage_tret'].apply(clean_percentage)


for col in ['temperature', 'time', 'humidity']:
    expanded_df[col] = expanded_df[col].apply(lambda x: convert_values([x], col)[0])   

# Check result
print(expanded_df[['temperature', 'time', 'humidity']].head())
print(expanded_df[['temperature', 'time', 'humidity']].dtypes)
print(expanded_df.info())
# Out:
#    temperature    time  humidity
# 0         30.0  1000.0      70.0
# 0         30.0  1000.0      70.0
# 1          NaN    60.0       NaN
# 4          NaN    97.0       NaN
# 6          NaN   672.0       NaN
# temperature    float64
# time           float64
# humidity       float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 969 entries, 0 to 757
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                969 non-null    int64
#  1   perovskite_composition    401 non-null    object
#  2   electron_transport_layer  366 non-null    object
#  3   pin_nip_structure         280 non-null    object
#  4   hole_transport_layer      303 non-null    object
#  5   passivating_molecule      969 non-null    object
#  6   control_pce               542 non-null    float64
#  7   control_voc               446 non-null    float64
#  8   treated_pce               732 non-null    float64
#  9   treated_voc               526 non-null    float64
#  10  structure_pin_nip         9 non-null      object
#  11  treated_jsc               19 non-null     float64
#  12  treated_ff                42 non-null     float64
#  13  control_jsc               4 non-null      float64
#  14  control_ff                9 non-null      float64
#  15  control_pec               0 non-null      float64
#  16  treated_eqe               0 non-null      float64
#  17  treated_stabilized_pce    0 non-null      float64
#  18  control_fill_factor       0 non-null      float64
#  19  treated_fill_factor       0 non-null      float64
#  20  controljsc                0 non-null      float64
#  21  treatedjsc                2 non-null      float64
#  22  treated_hysteresis_index  2 non-null      float64
#  23  binding_energy            0 non-null      float64
#  24  fill_factor               1 non-null      float64
#  25  treated_iscc              1 non-null      float64
#  26  IUPAC_passivator          957 non-null    object
#  27  passivator_smiles         969 non-null    object
#  28  test_name                 875 non-null    object
#  29  temperature               723 non-null    float64
#  30  time                      779 non-null    float64
#  31  humidity                  342 non-null    float64
#  32  retained_percentage_cont  715 non-null    float64
#  33  retained_percentage_tret  610 non-null    float64
#  34  stability_type            26 non-null     object
#  35  retained_proportion_cont  22 non-null     float64
#  36  retained_proportion_tret  18 non-null     float64
# dtypes: float64(26), int64(1), object(10)
# memory usage: 287.7+ KB
# None

# %%
# print("Temperature Values:")
# print(expanded_df['temperature'].to_list())

# print("\nTime Values:")
# print(expanded_df['time'].to_list())

# print("\nHumidity Values:")
# print(expanded_df['humidity'].to_list())

# %% [markdown]
# ### kangs df

# %%
df_expanded = pd.read_csv('df_expanded.csv')

print(df_expanded.head())
print(df_expanded.info())
# Out:
#    first_num        perovskite_composition electron_transport_layer  \
# 0          0  Cs 0.05 FA 0.85 MA 0.1 PbI 3                      C60
# 1          1                           NaN                 TinOxide
# 2          2   dibutylammonium lead iodide              tin dioxide
# 3          2   dibutylammonium lead iodide              tin dioxide
# 4          2   dibutylammonium lead iodide              tin dioxide
#
#                                 hole_transport_layer structure_pin_nip  \
# 0                                 2PACz and Me-4PACz               PIN
# 1  poly[bis(4-phenyl) (2,4,6-trimethylphenyl)amin...               PIN
# 2                                       Spiro-OMeTAD               NIP
# 3                                       Spiro-OMeTAD               NIP
# 4                                       Spiro-OMeTAD               NIP
#
#        test stability_type                passivating_molecule  humidity  \
# 0    test_1          ISOSL  4-chlorobenzenesulfonate (4Cl-BZS)       NaN
# 1    test_1          ISOST                   phenethylammonium       NaN
# 2    test_1          ISOSL                          butylamine      85.0
# 3  test_1_2          ISOSD                                 NaN      85.0
# 4    test_2         ISOSLT                                 NaN       NaN
#
#    temperature    time  control_pce  treated_pce  control_voc  treated_voc  \
# 0         65.0  1200.0         24.0         26.9          NaN         1.18
# 1         85.0   500.0          NaN         19.1          NaN         1.16
# 2         25.0  1620.0          NaN         24.3          NaN         1.18
# 3         85.0  1056.0          NaN         21.3          NaN          NaN
# 4         25.0  1620.0          NaN         24.0          NaN          NaN
#
#    efficiency_control  efficiency_tret  efficiency_cont
# 0                 NaN            95.00              NaN
# 1                 NaN              NaN              NaN
# 2                 NaN             0.98             0.58
# 3                 NaN             0.94              NaN
# 4                 NaN             0.98              NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   first_num                 234 non-null    int64
#  1   perovskite_composition    163 non-null    object
#  2   electron_transport_layer  129 non-null    object
#  3   hole_transport_layer      138 non-null    object
#  4   structure_pin_nip         161 non-null    object
#  5   test                      234 non-null    object
#  6   stability_type            161 non-null    object
#  7   passivating_molecule      85 non-null     object
#  8   humidity                  78 non-null     float64
#  9   temperature               122 non-null    float64
#  10  time                      176 non-null    float64
#  11  control_pce               71 non-null     float64
#  12  treated_pce               142 non-null    float64
#  13  control_voc               39 non-null     float64
#  14  treated_voc               78 non-null     float64
#  15  efficiency_control        0 non-null      float64
#  16  efficiency_tret           194 non-null    float64
#  17  efficiency_cont           97 non-null     float64
# dtypes: float64(10), int64(1), object(7)
# memory usage: 33.0+ KB
# None

# %%
expanded_df = expanded_df.drop(columns=['Unnamed: 0'])

expanded_df = expanded_df.dropna(axis=1, how='all')

expanded_df = expanded_df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

expanded_df = expanded_df.drop_duplicates()

expanded_df = expanded_df.dropna(subset=['control_pce', 'control_voc', 'treated_pce', 'treated_voc'])

expanded_df = expanded_df.reset_index(drop=True)

print(expanded_df.head())
print(expanded_df.info())
# Out:
#          perovskite_composition electron_transport_layer pin_nip_structure  \
# 0                        MAPbI3                PEDOT:PSS               NIP
# 1                        MAPbI3                PEDOT:PSS               NIP
# 2  Cs 0.05 FA 0.9 MA 0.05 PbI 3                      NaN               NaN
# 3    FA 0.6 MA 0.4 PbI2.7 Cl0.3                     SnO2               NIP
# 4                        MAPbI3                     SnO2               NIP
#
#   hole_transport_layer                               passivating_molecule  \
# 0                 PCBM                                               DAAB
# 1                 PCBM                                               DAAB
# 2                  NaN                            Cyanoguanidine diiodide
# 3         Spiro-OMeTAD  4-chlorobenzylammonium chloride (75%) and 4-ch...
# 4         Spiro-OMeTAD                 4-fluorobenzamine trifluoroacetate
#
#    control_pce  control_voc  treated_pce  treated_voc structure_pin_nip  ...  \
# 0         4.50         0.87        12.60         0.92               NaN  ...
# 1         4.50         0.87        12.60         0.92               NaN  ...
# 2        20.44      1077.00        23.04      1119.00               NaN  ...
# 3        18.31         1.06        21.00         1.12               NaN  ...
# 4        19.19         1.09        21.01         1.13               NaN  ...
#
#                            passivator_smiles  test_name  temperature    time  \
# 0  N(=NC1=CC=CC=C1)C1=CC=CC=C1.[NH4+].[NH4+]     ISOS-L         30.0  1000.0
# 1  N(=NC1=CC=CC=C1)C1=CC=CC=C1.[NH4+].[NH4+]     ISOS-L         30.0  1000.0
# 2                     [I-].[I-].C(#N)NC(=N)N     ISOS-D          NaN    60.0
# 3               [Cl-].ClC1=CC=C(C[NH3+])C=C1     ISOS-L          NaN   672.0
# 4             FC(C(=O)O)(F)F.FC1=CC=C(C=C1)N     ISOS-T         45.0   500.0
#
#    humidity  retained_percentage_cont  retained_percentage_tret  \
# 0      70.0                      90.0                      68.0
# 1      70.0                      90.0                      50.0
# 2       NaN                      77.0                      83.0
# 3       NaN                      78.0                      88.0
# 4      45.0                      48.0                      80.5
#
#    stability_type retained_proportion_cont retained_proportion_tret
# 0             NaN                      NaN                      NaN
# 1             NaN                      NaN                      NaN
# 2             NaN                      NaN                      NaN
# 3             NaN                      NaN                      NaN
# 4             NaN                      NaN                      NaN
#
# [5 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   perovskite_composition    250 non-null    object
#  1   electron_transport_layer  257 non-null    object
#  2   pin_nip_structure         206 non-null    object
#  3   hole_transport_layer      215 non-null    object
#  4   passivating_molecule      427 non-null    object
#  5   control_pce               427 non-null    float64
#  6   control_voc               427 non-null    float64
#  7   treated_pce               427 non-null    float64
#  8   treated_voc               427 non-null    float64
#  9   structure_pin_nip         8 non-null      object
#  10  treated_jsc               16 non-null     float64
#  11  treated_ff                39 non-null     float64
#  12  control_jsc               4 non-null      float64
#  13  control_ff                9 non-null      float64
#  14  treatedjsc                2 non-null      float64
#  15  treated_hysteresis_index  2 non-null      float64
#  16  fill_factor               0 non-null      float64
#  17  treated_iscc              0 non-null      float64
#  18  IUPAC_passivator          422 non-null    object
#  19  passivator_smiles         427 non-null    object
#  20  test_name                 394 non-null    object
#  21  temperature               350 non-null    float64
#  22  time                      377 non-null    float64
#  23  humidity                  203 non-null    float64
#  24  retained_percentage_cont  354 non-null    float64
#  25  retained_percentage_tret  320 non-null    float64
#  26  stability_type            13 non-null     object
#  27  retained_proportion_cont  14 non-null     float64
#  28  retained_proportion_tret  11 non-null     float64
# dtypes: float64(19), object(10)
# memory usage: 96.9+ KB
# None
# /var/folders/00/dfc6l5fn61s09z4jy0lqyz_w0000gn/T/ipykernel_94038/678833733.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   expanded_df = expanded_df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df_expanded = df_expanded.drop(columns=['efficiency_control'])
expanded_df = expanded_df.rename(columns={
    'retained_percentage_cont': 'efficiency_cont',
    'retained_percentage_tret': 'efficiency_tret'
})

print(df_expanded.info())
print(expanded_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   first_num                 234 non-null    int64
#  1   perovskite_composition    163 non-null    object
#  2   electron_transport_layer  129 non-null    object
#  3   hole_transport_layer      138 non-null    object
#  4   structure_pin_nip         161 non-null    object
#  5   test                      234 non-null    object
#  6   stability_type            161 non-null    object
#  7   passivating_molecule      85 non-null     object
#  8   humidity                  78 non-null     float64
#  9   temperature               122 non-null    float64
#  10  time                      176 non-null    float64
#  11  control_pce               71 non-null     float64
#  12  treated_pce               142 non-null    float64
#  13  control_voc               39 non-null     float64
#  14  treated_voc               78 non-null     float64
#  15  efficiency_tret           194 non-null    float64
#  16  efficiency_cont           97 non-null     float64
# dtypes: float64(9), int64(1), object(7)
# memory usage: 31.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   perovskite_composition    250 non-null    object
#  1   electron_transport_layer  257 non-null    object
#  2   pin_nip_structure         206 non-null    object
#  3   hole_transport_layer      215 non-null    object
#  4   passivating_molecule      427 non-null    object
#  5   control_pce               427 non-null    float64
#  6   control_voc               427 non-null    float64
#  7   treated_pce               427 non-null    float64
#  8   treated_voc               427 non-null    float64
#  9   structure_pin_nip         8 non-null      object
#  10  treated_jsc               16 non-null     float64
#  11  treated_ff                39 non-null     float64
#  12  control_jsc               4 non-null      float64
#  13  control_ff                9 non-null      float64
#  14  treatedjsc                2 non-null      float64
#  15  treated_hysteresis_index  2 non-null      float64
#  16  fill_factor               0 non-null      float64
#  17  treated_iscc              0 non-null      float64
#  18  IUPAC_passivator          422 non-null    object
#  19  passivator_smiles         427 non-null    object
#  20  test_name                 394 non-null    object
#  21  temperature               350 non-null    float64
#  22  time                      377 non-null    float64
#  23  humidity                  203 non-null    float64
#  24  efficiency_cont           354 non-null    float64
#  25  efficiency_tret           320 non-null    float64
#  26  stability_type            13 non-null     object
#  27  retained_proportion_cont  14 non-null     float64
#  28  retained_proportion_tret  11 non-null     float64
# dtypes: float64(19), object(10)
# memory usage: 96.9+ KB
# None

# %%
common_columns = df_expanded.columns.intersection(expanded_df.columns)

df_subset = expanded_df[common_columns]

df_combined = pd.concat([df_expanded, df_subset], ignore_index=True)

print(df_combined.shape)
print(df_combined.columns)
print(df_combined.info())

df_combined
# Out:
# (661, 17)
# Index(['first_num', 'perovskite_composition', 'electron_transport_layer',
#        'hole_transport_layer', 'structure_pin_nip', 'test', 'stability_type',
#        'passivating_molecule', 'humidity', 'temperature', 'time',
#        'control_pce', 'treated_pce', 'control_voc', 'treated_voc',
#        'efficiency_tret', 'efficiency_cont'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 661 entries, 0 to 660
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   first_num                 234 non-null    float64
#  1   perovskite_composition    413 non-null    object
#  2   electron_transport_layer  386 non-null    object
#  3   hole_transport_layer      353 non-null    object
#  4   structure_pin_nip         169 non-null    object
#  5   test                      234 non-null    object
#  6   stability_type            174 non-null    object
#  7   passivating_molecule      512 non-null    object
#  8   humidity                  281 non-null    float64
#  9   temperature               472 non-null    float64
#  10  time                      553 non-null    float64
#  11  control_pce               498 non-null    float64
#  12  treated_pce               569 non-null    float64
#  13  control_voc               466 non-null    float64
#  14  treated_voc               505 non-null    float64
#  15  efficiency_tret           514 non-null    float64
#  16  efficiency_cont           451 non-null    float64
# dtypes: float64(10), object(7)
# memory usage: 87.9+ KB
# None
#      first_num         perovskite_composition electron_transport_layer  \
# 0          0.0   Cs 0.05 FA 0.85 MA 0.1 PbI 3                      C60
# 1          1.0                            NaN                 TinOxide
# 2          2.0    dibutylammonium lead iodide              tin dioxide
# 3          2.0    dibutylammonium lead iodide              tin dioxide
# 4          2.0    dibutylammonium lead iodide              tin dioxide
# ..         ...                            ...                      ...
# 656        NaN                            NaN                      NaN
# 657        NaN  Cs0.17 FA0.83 Pb(I0.6 Br0.4)3                     SnO2
# 658        NaN                         CsPbI3                     TiO2
# 659        NaN                         MAPbI3                     PCBM
# 660        NaN         Cu2ZnSn(S,Se)4 (C:SSe)                      NaN
#
#                                   hole_transport_layer structure_pin_nip  \
# 0                                   2PACz and Me-4PACz               PIN
# 1    poly[bis(4-phenyl) (2,4,6-trimethylphenyl)amin...               PIN
# 2                                         Spiro-OMeTAD               NIP
# 3                                         Spiro-OMeTAD               NIP
# 4                                         Spiro-OMeTAD               NIP
# ..                                                 ...               ...
# 656                                                NaN               NaN
# 657                                                NaN               NaN
# 658                                       spiro-OMeTAD               NaN
# 659                                               NiOx               NaN
# 660                                                NaN               NaN
#
#          test stability_type                passivating_molecule  humidity  \
# 0      test_1          ISOSL  4-chlorobenzenesulfonate (4Cl-BZS)       NaN
# 1      test_1          ISOST                   phenethylammonium       NaN
# 2      test_1          ISOSL                          butylamine      85.0
# 3    test_1_2          ISOSD                                 NaN      85.0
# 4      test_2         ISOSLT                                 NaN       NaN
# ..        ...            ...                                 ...       ...
# 656       NaN            NaN                         prolinamide       NaN
# 657       NaN            NaN                           BA2 PbBr4       NaN
# 658       NaN            NaN      n-octylammonium iodide (n-OAI)       NaN
# 659       NaN            NaN                                 PbS       NaN
# 660       NaN           None                        Vanadium (V)       NaN
#
#      temperature    time  control_pce  treated_pce  control_voc  treated_voc  \
# 0           65.0  1200.0        24.00        26.90          NaN        1.180
# 1           85.0   500.0          NaN        19.10          NaN        1.160
# 2           25.0  1620.0          NaN        24.30          NaN        1.180
# 3           85.0  1056.0          NaN        21.30          NaN          NaN
# 4           25.0  1620.0          NaN        24.00          NaN          NaN
# ..           ...     ...          ...          ...          ...          ...
# 656         25.0  1550.0        22.67        24.61        1.128        1.169
# 657       1000.0  1200.0        19.24        43.70        1.300        1.110
# 658         25.0  1500.0        18.60        19.80        1.180        1.230
# 659        400.0     NaN        15.26        18.74        1.002        1.025
# 660          NaN     NaN         8.28        11.11        0.454        0.458
#
#      efficiency_tret  efficiency_cont
# 0              95.00              NaN
# 1                NaN              NaN
# 2               0.98             0.58
# 3               0.94              NaN
# 4               0.98              NaN
# ..               ...              ...
# 656            90.00            10.00
# 657            83.00            61.00
# 658              NaN              NaN
# 659              NaN              NaN
# 660              NaN              NaN
#
# [661 rows x 17 columns]

# %%
df_combined.to_csv('cleaned_data_fix.csv', index=False)
