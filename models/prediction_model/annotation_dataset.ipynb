# %%
import pandas as pd
import ast
import numpy as np
import pubchempy as pcp
from rdkit import Chem
from rdkit.Chem import Descriptors, rdMolDescriptors

# %%
annotation_df = pd.read_csv('annotation.csv')
annotation_df
# Out:
#      first_num                                             output
# 0            0  {'perovskite_composition': 'Cs 0.05 FA 0.85 MA...
# 1            1  {'perovskite_composition': None, 'electron_tra...
# 2            2  {'perovskite_composition': 'dibutylammonium le...
# 3            3  {'perovskite_composition': 'Cs0.05(MA0.10FA0.8...
# 4            4  {'perovskite_composition': '(MAPbBr3)0.05(FAPb...
# ..         ...                                                ...
# 144        145  {'perovskite_composition': 'Cs0.05(MA0.17FA0.8...
# 145        146  {'perovskite_composition': 'Cs0.05(MA0.05FA0.9...
# 146        147  {'perovskite_composition': 'formamidinium lead...
# 147        148  {'perovskite_composition': 'Cs0.05FA0.85MA0.10...
# 148        149  {'perovskite_composition': 'FA0.7MA0.3Pb0.5Sn0...
#
# [149 rows x 2 columns]

# %%
sample_data = annotation_df['output']


# Convert string representation of dictionary into actual dictionary
expanded_data = []
for row in sample_data:
    row_dict = ast.literal_eval(row)  # Convert string to dictionary
    
    # Extract common fields
    common_fields = {
        "perovskite_composition": row_dict.get("perovskite_composition"),
        "electron_transport_layer": row_dict.get("electron_transport_layer"),
        "hole_transport_layer": row_dict.get("hole_transport_layer"),
        "structure_pin_nip": row_dict.get("structure_pin_nip"),
    }

    # Extract test data
    for key, test_data in row_dict.items():
        if key.startswith("test_"):
            test_row = common_fields.copy()
            test_row["test"] = key  # Store test name
            test_row.update(test_data)  # Merge test details
            expanded_data.append(test_row)

# Convert list of dictionaries into DataFrame
df_expanded = pd.DataFrame(expanded_data)

# Fill missing passivating_molecule values based on the first test in each group
df_expanded['passivating_molecule'] = df_expanded.groupby('perovskite_composition')['passivating_molecule'].transform(lambda x: x.ffill())

# %%
df_expanded
# Out:
#                  perovskite_composition electron_transport_layer  \
# 0          Cs 0.05 FA 0.85 MA 0.1 PbI 3                      C60
# 1                                  None                 TinOxide
# 2           dibutylammonium lead iodide              tin dioxide
# 3           dibutylammonium lead iodide              tin dioxide
# 4           dibutylammonium lead iodide              tin dioxide
# ..                                  ...                      ...
# 229           formamidinium lead iodide                     None
# 230           formamidinium lead iodide                     None
# 231  Cs0.05FA0.85MA0.10Pb(I0.97Br0.03)3                     None
# 232  Cs0.05FA0.85MA0.10Pb(I0.97Br0.03)3                     None
# 233              FA0.7MA0.3Pb0.5Sn0.5I3     buckminsterfullerene
#
#                                   hole_transport_layer structure_pin_nip  \
# 0                                   2PACz and Me-4PACz               PIN
# 1    poly[bis(4-phenyl) (2,4,6-trimethylphenyl)amin...               PIN
# 2                                         Spiro-OMeTAD               NIP
# 3                                         Spiro-OMeTAD               NIP
# 4                                         Spiro-OMeTAD               NIP
# ..                                                 ...               ...
# 229                                       Spiro-OMeTAD               NIP
# 230                                       Spiro-OMeTAD               NIP
# 231                                       Spiro-OMeTAD               NIP
# 232                                       Spiro-OMeTAD               NIP
# 233                                               None              None
#
#          test stability_type  \
# 0      test_1          ISOSL
# 1      test_1          ISOST
# 2      test_1          ISOSL
# 3    test_1_2          ISOSD
# 4      test_2         ISOSLT
# ..        ...            ...
# 229    test_1          ISOSD
# 230    test_2         ISOSLT
# 231  test_1_2         ISOSLT
# 232    test_1           None
# 233    test_1         ISOSLT
#
#                                   passivating_molecule  humidity  temperature  \
# 0                   4-chlorobenzenesulfonate (4Cl-BZS)       NaN         65.0
# 1                                                  NaN       NaN         85.0
# 2                                           butylamine      85.0         25.0
# 3                                           butylamine      85.0         85.0
# 4                                           butylamine       NaN         25.0
# ..                                                 ...       ...          ...
# 229  carbazole-triphenylamine and phenylammonium io...      85.0         85.0
# 230  carbazole-triphenylamine and phenylammonium io...       NaN          NaN
# 231                         phenylethylammonium iodide     507.0          NaN
# 232                 4-tert-butyl-benzylammonium iodide       NaN          NaN
# 233                   4-trifluoromethyl-phenylammonium     305.0         35.0
#
#        time  control_pce  treated_pce  control_voc  treated_voc  \
# 0    1200.0         24.0        26.90          NaN         1.18
# 1     500.0          NaN        19.10          NaN         1.16
# 2    1620.0          NaN        24.30          NaN         1.18
# 3    1056.0          NaN        21.30          NaN          NaN
# 4    1620.0          NaN        24.00          NaN          NaN
# ..      ...          ...          ...          ...          ...
# 229  1000.0         22.3          NaN          NaN         1.11
# 230  1100.0          NaN        24.70          NaN          NaN
# 231   500.0          NaN         0.84          NaN          NaN
# 232     NaN         21.2        22.70         1.09         1.12
# 233   600.0          NaN        26.40          NaN          NaN
#
#     efficiency_control  efficiency_tret  efficiency_cont
# 0                 None            95.00              NaN
# 1                 None              NaN              NaN
# 2                 None             0.98             0.58
# 3                 None             0.94              NaN
# 4                 None             0.98              NaN
# ..                 ...              ...              ...
# 229               None             0.92              NaN
# 230               None             0.94             0.66
# 231               None              NaN             0.70
# 232               None             0.95              NaN
# 233               None             0.90              NaN
#
# [234 rows x 17 columns]

# %%
df_expanded.isna().sum()
# Out:
# perovskite_composition       71
# electron_transport_layer    105
# hole_transport_layer         96
# structure_pin_nip            73
# test                          0
# stability_type               73
# passivating_molecule        131
# humidity                    156
# temperature                 112
# time                         58
# control_pce                 163
# treated_pce                  92
# control_voc                 195
# treated_voc                 156
# efficiency_control          234
# efficiency_tret              40
# efficiency_cont             137
# dtype: int64

# %%
# Function to select columns
def select_data(df):
    # Convert PCE and VOC to numeric
    for col in ['control_pce', 'control_voc', 'treated_pce', 'treated_voc']:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    # Drop rows where treated_pce or passivating_molecule is missing
    df = df.dropna(subset=['treated_pce', 'passivating_molecule', 'perovskite_composition'])

    return df

data = select_data(df_expanded)
data.head()
# Out:
#          perovskite_composition electron_transport_layer hole_transport_layer  \
# 0  Cs 0.05 FA 0.85 MA 0.1 PbI 3                      C60   2PACz and Me-4PACz
# 2   dibutylammonium lead iodide              tin dioxide         Spiro-OMeTAD
# 3   dibutylammonium lead iodide              tin dioxide         Spiro-OMeTAD
# 4   dibutylammonium lead iodide              tin dioxide         Spiro-OMeTAD
# 6     butylammonium lead iodide     buckminsterfullerene         Spiro-OMeTAD
#
#   structure_pin_nip      test stability_type  \
# 0               PIN    test_1          ISOSL
# 2               NIP    test_1          ISOSL
# 3               NIP  test_1_2          ISOSD
# 4               NIP    test_2         ISOSLT
# 6               NIP    test_1           None
#
#                  passivating_molecule  humidity  temperature    time  \
# 0  4-chlorobenzenesulfonate (4Cl-BZS)       NaN         65.0  1200.0
# 2                          butylamine      85.0         25.0  1620.0
# 3                          butylamine      85.0         85.0  1056.0
# 4                          butylamine       NaN         25.0  1620.0
# 6               iso-butylamine iodide       NaN          NaN     NaN
#
#    control_pce  treated_pce  control_voc  treated_voc efficiency_control  \
# 0         24.0         26.9          NaN         1.18               None
# 2          NaN         24.3          NaN         1.18               None
# 3          NaN         21.3          NaN          NaN               None
# 4          NaN         24.0          NaN          NaN               None
# 6          NaN         22.1          NaN         1.13               None
#
#    efficiency_tret  efficiency_cont
# 0            95.00              NaN
# 2             0.98             0.58
# 3             0.94              NaN
# 4             0.98              NaN
# 6              NaN              NaN

# %%
def fetch_smiles_from_name(molecule_name):
    try:
        # Search for the molecule in PubChem by name
        compounds = pcp.get_compounds(molecule_name, 'name')
        if compounds:
            return compounds[0].isomeric_smiles  # Return the first match's SMILES
        else:
            return np.nan
    except Exception as e:
        print(f"Error fetching SMILES for {molecule_name}: {e}")
        return None

# %%
import re

def fix_unmatched_brackets(s):
    """
    Fixes unmatched brackets in the given string by adding the correct brackets where necessary.

    :param s: Input string with potential unmatched brackets.
    :return: A corrected string with properly balanced brackets.
    """
    opening = "({["
    closing = ")}]"
    match = {')': '(', '}': '{', ']': '['}
    stack = []

    # Step 1: Identify missing closing brackets
    fixed_s = []
    for char in s:
        if char in opening:
            stack.append(char)
            fixed_s.append(char)
        elif char in closing:
            if stack and stack[-1] == match[char]:
                stack.pop()
                fixed_s.append(char)
            else:
                # Add missing opening bracket before unmatched closing
                fixed_s.insert(0, match[char])
                fixed_s.append(char)
        else:
            fixed_s.append(char)

    # Step 2: Add missing closing brackets at the end
    while stack:
        open_bracket = stack.pop()
        fixed_s.append(closing[opening.index(open_bracket)])

    return "".join(fixed_s)


def get_chemical_names(chemical_list):
    cleaned_list = []
    for name in chemical_list:
        # Remove text inside parentheses only if it's extra information (abbreviations)
        name = re.sub(r"\s*\([^)]*\)$", "", name).strip() 
        # Remove spaces after a closing bracket (ensure proper chemical formatting)
        name = re.sub(r"\] +", "]", name)

        cleaned_list.append(name)

    return cleaned_list

# %%
data['passivating_molecule']
# Out:
# 0                     4-chlorobenzenesulfonate (4Cl-BZS)
# 2                                             butylamine
# 3                                             butylamine
# 4                                             butylamine
# 6                                  iso-butylamine iodide
#                              ...
# 228                                      ortho-carborane
# 230    carbazole-triphenylamine and phenylammonium io...
# 231                           phenylethylammonium iodide
# 232                   4-tert-butyl-benzylammonium iodide
# 233                     4-trifluoromethyl-phenylammonium
# Name: passivating_molecule, Length: 67, dtype: object

# %%
fetch_smiles_from_name(get_chemical_names([fix_unmatched_brackets('4-chlorobenzenesulfonate (4Cl-BZS)')]))
# Out:
# 'C1=CC(=CC=C1S(=O)(=O)[O-])Cl'

# %%
lst = data['passivating_molecule']
lst
# Out:
# 0                     4-chlorobenzenesulfonate (4Cl-BZS)
# 2                                             butylamine
# 3                                             butylamine
# 4                                             butylamine
# 6                                  iso-butylamine iodide
#                              ...
# 228                                      ortho-carborane
# 230    carbazole-triphenylamine and phenylammonium io...
# 231                           phenylethylammonium iodide
# 232                   4-tert-butyl-benzylammonium iodide
# 233                     4-trifluoromethyl-phenylammonium
# Name: passivating_molecule, Length: 67, dtype: object

# %%
cleaned_list = lst.apply(lambda x: fix_unmatched_brackets(x))
cleaned_list
# Out:
# 0                     4-chlorobenzenesulfonate (4Cl-BZS)
# 2                                             butylamine
# 3                                             butylamine
# 4                                             butylamine
# 6                                  iso-butylamine iodide
#                              ...
# 228                                      ortho-carborane
# 230    carbazole-triphenylamine and phenylammonium io...
# 231                           phenylethylammonium iodide
# 232                   4-tert-butyl-benzylammonium iodide
# 233                     4-trifluoromethyl-phenylammonium
# Name: passivating_molecule, Length: 67, dtype: object

# %%
cleaned_list = get_chemical_names(cleaned_list)

# %%
cleaned_list
# Out:
# ['4-chlorobenzenesulfonate',
#  'butylamine',
#  'butylamine',
#  'butylamine',
#  'iso-butylamine iodide',
#  'phenylethylammonium iodide',
#  'EDBE',
#  'intermediate negative ΔE vac',
#  'butylammonium bromide',
#  '2-thiopheneethylammonium chloride',
#  '2-thiopheneethylammonium chloride',
#  'chlorophenylethylammonium iodide',
#  'fluorophenylethylammonium iodide',
#  'CF3-phenethylammonium',
#  '3,4,5-trifluoroanilinium',
#  '3,4,5-trifluoroanilinium',
#  'cyclohexylmethylammonium iodide dissolved in',
#  'phenethylammonium iodide',
#  '3-(aminomethyl)pyridine',
#  'tri-octyl phosphine oxide',
#  '2-thiophenemethylammonium bromide',
#  'azetidinium lead iodide',
#  'Lithium Fluoride',
#  'DMePDAI 2',
#  'DMePDAI 2',
#  'NIP',
#  'NOTE:This is how to prepare the PSC,relevent...?',
#  'methylammonium lead iodide',
#  'methylammonium',
#  'methylammonium lead iodide',
#  'poly',
#  'CF3 -PEAI',
#  'CF3 -PEAI',
#  'CF3 -PEAI',
#  '4-fluorophenylethylammonium iodide',
#  '(phenethylamino)methaniminium iodide',
#  'Methylammonium Lead Bromide',
#  'HTAB',
#  'formamidinium',
#  'FAPbI3',
#  'MAPbI 3',
#  'oleylammonium iodide',
#  'NIP',
#  'ISOSLT',
#  'methylammonium',
#  'lead iodide',
#  'lead iodide',
#  'oleylammonium iodide',
#  'lead iodide',
#  'formate',
#  'lead iodide',
#  'Piperazinium Diiodide',
#  'Titanium dioxide',
#  'Titanium dioxide',
#  'Butylammonium bromide',
#  'ferrocenyl-bis-thiophene-2-carboxylate',
#  'Titanium dioxide',
#  'oleylammonium iodide',
#  'lead oxalate',
#  'sodium thioglycolate',
#  'fluorophenylethylammonium iodide',
#  '4-fluoroaniline',
#  'ortho-carborane',
#  'carbazole-triphenylamine and phenylammonium iodide units',
#  'phenylethylammonium iodide',
#  '4-tert-butyl-benzylammonium iodide',
#  '4-trifluoromethyl-phenylammonium']

# %%
data
# Out:
#                        perovskite_composition electron_transport_layer  \
# 0                Cs 0.05 FA 0.85 MA 0.1 PbI 3                      C60
# 2                 dibutylammonium lead iodide              tin dioxide
# 3                 dibutylammonium lead iodide              tin dioxide
# 4                 dibutylammonium lead iodide              tin dioxide
# 6                   butylammonium lead iodide     buckminsterfullerene
# ..                                        ...                      ...
# 228  Cs0.05(MA0.05FA0.95)0.95Pb(I0.95Br0.05)3                     None
# 230                 formamidinium lead iodide                     None
# 231        Cs0.05FA0.85MA0.10Pb(I0.97Br0.03)3                     None
# 232        Cs0.05FA0.85MA0.10Pb(I0.97Br0.03)3                     None
# 233                    FA0.7MA0.3Pb0.5Sn0.5I3     buckminsterfullerene
#
#     hole_transport_layer structure_pin_nip      test stability_type  \
# 0     2PACz and Me-4PACz               PIN    test_1          ISOSL
# 2           Spiro-OMeTAD               NIP    test_1          ISOSL
# 3           Spiro-OMeTAD               NIP  test_1_2          ISOSD
# 4           Spiro-OMeTAD               NIP    test_2         ISOSLT
# 6           Spiro-OMeTAD               NIP    test_1           None
# ..                   ...               ...       ...            ...
# 228                 None              None    test_1           None
# 230         Spiro-OMeTAD               NIP    test_2         ISOSLT
# 231         Spiro-OMeTAD               NIP  test_1_2         ISOSLT
# 232         Spiro-OMeTAD               NIP    test_1           None
# 233                 None              None    test_1         ISOSLT
#
#                                   passivating_molecule  humidity  temperature  \
# 0                   4-chlorobenzenesulfonate (4Cl-BZS)       NaN         65.0
# 2                                           butylamine      85.0         25.0
# 3                                           butylamine      85.0         85.0
# 4                                           butylamine       NaN         25.0
# 6                                iso-butylamine iodide       NaN          NaN
# ..                                                 ...       ...          ...
# 228                                    ortho-carborane      30.0         40.0
# 230  carbazole-triphenylamine and phenylammonium io...       NaN          NaN
# 231                         phenylethylammonium iodide     507.0          NaN
# 232                 4-tert-butyl-benzylammonium iodide       NaN          NaN
# 233                   4-trifluoromethyl-phenylammonium     305.0         35.0
#
#        time  control_pce  treated_pce  control_voc  treated_voc  \
# 0    1200.0         24.0        26.90          NaN         1.18
# 2    1620.0          NaN        24.30          NaN         1.18
# 3    1056.0          NaN        21.30          NaN          NaN
# 4    1620.0          NaN        24.00          NaN          NaN
# 6       NaN          NaN        22.10          NaN         1.13
# ..      ...          ...          ...          ...          ...
# 228   400.0          NaN        23.00          NaN         1.17
# 230  1100.0          NaN        24.70          NaN          NaN
# 231   500.0          NaN         0.84          NaN          NaN
# 232     NaN         21.2        22.70         1.09         1.12
# 233   600.0          NaN        26.40          NaN          NaN
#
#     efficiency_control  efficiency_tret  efficiency_cont  \
# 0                 None            95.00              NaN
# 2                 None             0.98             0.58
# 3                 None             0.94              NaN
# 4                 None             0.98              NaN
# 6                 None              NaN              NaN
# ..                 ...              ...              ...
# 228               None             0.97             0.89
# 230               None             0.94             0.66
# 231               None              NaN             0.70
# 232               None             0.95              NaN
# 233               None             0.90              NaN
#
#                           passivating_molecule_cleaned
# 0                             4-chlorobenzenesulfonate
# 2                                           butylamine
# 3                                           butylamine
# 4                                           butylamine
# 6                                iso-butylamine iodide
# ..                                                 ...
# 228                                    ortho-carborane
# 230  carbazole-triphenylamine and phenylammonium io...
# 231                         phenylethylammonium iodide
# 232                 4-tert-butyl-benzylammonium iodide
# 233                   4-trifluoromethyl-phenylammonium
#
# [67 rows x 18 columns]

# %%
data['passivating_molecule_cleaned'] = cleaned_list
# Out:
# /var/folders/_c/tmnx15c54v7cn_b4tx022flc0000gn/T/ipykernel_1617/76848575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['passivating_molecule_cleaned'] = cleaned_list

# %%
# Example input list
lst = data['passivating_molecule']

# Cleaning the list
cleaned_list = lst.apply(lambda x: fix_unmatched_brackets(x))
cleaned_list = get_chemical_names(cleaned_list)

# Output result

# %%
data['passivating_molecule_SMILES'] = data['passivating_molecule_cleaned'].apply(fetch_smiles_from_name)
# Out:
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# Error fetching SMILES for nan: 'float' object is not iterable
# /var/folders/_c/tmnx15c54v7cn_b4tx022flc0000gn/T/ipykernel_1617/3093823273.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['passivating_molecule_SMILES'] = data['passivating_molecule_cleaned'].apply(fetch_smiles_from_name)

# %%
pd.read_json('/Users/kanggun/Documents/DSC180_B11_Q2/data/json_output_deepseek8b/deepseek_8b_newschema_1_OG.json')
# Out:
#                                                                         77   \
# perovskite_composition                                       FA0.9Cs0.1PbI3
# electron_transport_layer                                                C60
# pin_nip_structure                                                       PIN
# hole_transport_layer                                                   PTAA
# test_1                    {'test_name': 'ISOS-L', 'temperature': 85, 'ti...
# test_2                                                                  NaN
# passivating_molecule                                                    NaN
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         104  \
# perovskite_composition                                               FAPbI3
# electron_transport_layer                                               SnO2
# pin_nip_structure                                                       PIN
# hole_transport_layer                                           Spiro-OMeTAD
# test_1                    {'test_name': 'ISOS-L', 'temperature': 45, 'ti...
# test_2                                                                  NaN
# passivating_molecule                                                    NaN
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         79   \
# perovskite_composition                           (FAPbI3)0.97 (MAPbBr3)0.03
# electron_transport_layer                                               SnO2
# pin_nip_structure                                                     n-i-p
# hole_transport_layer                                           Spiro-OMeTAD
# test_1                    {'test_name': 'ISOS-D', 'temperature': '28 °C'...
# test_2                    {'test_name': 'ISOS-L', 'temperature': '28 °C'...
# passivating_molecule                                                    NaN
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         138  \
# perovskite_composition                        Cs 0.05 MA 0.10 FA 0.85 PbI 3
# electron_transport_layer                                                FTO
# pin_nip_structure                                                       PIN
# hole_transport_layer                                            2PACz:3-MPA
# test_1                    {'test_name': 'ISOS-L', 'temperature': 65, 'ti...
# test_2                                                                  NaN
# passivating_molecule                                                    NaN
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         144  \
# perovskite_composition                          Cs0.1FA0.6MA0.3Sn0.5Pb0.5I3
# electron_transport_layer                                          PEDOT:PSS
# pin_nip_structure                                  Not explicitly mentioned
# hole_transport_layer                                                   PTAA
# test_1                    {'test_name': 'ISOS-D', 'temperature': 25, 'ti...
# test_2                                                                  NaN
# passivating_molecule                                                    NaN
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         37   \
# perovskite_composition                             Cs0.2FA0.8Pb(I0.6Br0.4)3
# electron_transport_layer                                               NiOx
# pin_nip_structure                                                      None
# hole_transport_layer                                               Me-4PACz
# test_1                    {'test_name': 'ISOS-LT', 'temperature': None, ...
# test_2                                                                  NaN
# passivating_molecule                1,3-propylene diammonium iodide (PDAI2)
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         143  \
# perovskite_composition              (FAPbI3)0.77 (MAPbBr3)0.14 (CsPbI3)0.09
# electron_transport_layer                                              CuSCN
# pin_nip_structure                                                       NIP
# hole_transport_layer                                                  CuSCN
# test_1                    {'test_name': 'ISOS-D', 'temperature': 25, 'ti...
# test_2                                                                  NaN
# passivating_molecule                                                    NaN
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         30   \
# perovskite_composition                                       FA0.9Cs0.1PbI3
# electron_transport_layer                                               None
# pin_nip_structure                                                       PIN
# hole_transport_layer                                           Spiro-OMeTAD
# test_1                    {'test_name': 'shelf stability', 'temperature'...
# test_2                                                                  NaN
# passivating_molecule                                                    NH3
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         2    \
# perovskite_composition                                            (BA)₂PbI₄
# electron_transport_layer                 FTO (fluorine-doped tin(IV) oxide)
# pin_nip_structure                                                       PIN
# hole_transport_layer                               Spiro-OMeTAD, P3HT, PTAA
# test_1                    {'test_name': 'damp heat test', 'temperature':...
# test_2                                                                  NaN
# passivating_molecule                                              (BA)₂PbI₄
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                         93   ... 34   \
# perovskite_composition    FA 1-x MA x PbI 2.87 Br 0.13 (Cl)  ... NaN
# electron_transport_layer                               SnO2  ... NaN
# pin_nip_structure                                       PIN  ... NaN
# hole_transport_layer                           spiro-OMeTAD  ... NaN
# test_1                                                 None  ... NaN
# test_2                                                  NaN  ... NaN
# passivating_molecule                                    NaN  ... NaN
# test_3                                                  NaN  ... NaN
# control_pce                                             NaN  ... NaN
# control_voc                                             NaN  ... NaN
# treated_pce                                             NaN  ... NaN
# treated_voc                                             NaN  ... NaN
# test_4                                                  NaN  ... NaN
#
#                                                                         147  \
# perovskite_composition                                               FAPbI3
# electron_transport_layer                                               SnO2
# pin_nip_structure                                                       NIP
# hole_transport_layer                                           Spiro-OMeTAD
# test_1                    {'test_name': 'Damp heat test', 'temperature':...
# test_2                                                                  NaN
# passivating_molecule                                                    NaN
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         6    \
# perovskite_composition                                               MAPbI3
# electron_transport_layer                                               TiO2
# pin_nip_structure                                                       PIN
# hole_transport_layer                                           spiro-OMeTAD
# test_1                    {'test_name': 'ISOS-D', 'temperature': 90, 'ti...
# test_2                                                                  NaN
# passivating_molecule                                                    NaN
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         97   \
# perovskite_composition    Cs 0.05 (FA 0.92 MA 0.08) 0.95 Pb(I 0.92 Br 0....
# electron_transport_layer                                               None
# pin_nip_structure                                                       NIP
# hole_transport_layer                                                   PTAA
# test_1                    {'test_name': 'MPP tracking', 'temperature': 1...
# test_2                                                                  NaN
# passivating_molecule                                       Oleylamine (OAm)
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         46   \
# perovskite_composition            CsPbI0.05[(FAPbI3)0.89 (MAPbBr3)0.11]0.95
# electron_transport_layer                                                C60
# pin_nip_structure                                                       PIN
# hole_transport_layer                                                   PTAA
# test_1                    {'test_name': 'ISOS-L', 'temperature': 25, 'ti...
# test_2                                                                  NaN
# passivating_molecule                                                    NaN
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         135  \
# perovskite_composition                                Cs0.05FA0.85MA0.1PbI3
# electron_transport_layer    2D passivation layer (CF3-PEAI and MAI mixture)
# pin_nip_structure                                                       PIN
# hole_transport_layer                                        NiOx/MeO-4PADBC
# test_1                    {'test_name': 'ISOS-L', 'temperature': 65, 'ti...
# test_2                    {'test_name': 'ISOS-T', 'temperature': 85, 'ti...
# passivating_molecule                                                    NaN
# test_3                    {'test_name': 'ISOS-LC', 'temperature': 100, '...
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         1    \
# perovskite_composition                                       FA1-x MAx PbI3
# electron_transport_layer                                               SnO2
# pin_nip_structure                                                      None
# hole_transport_layer                                           spiro-OMeTAD
# test_1                    {'test_name': 'ISOS-D', 'temperature': 85, 'ti...
# test_2                                                                  NaN
# passivating_molecule                                                    NaN
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         90   \
# perovskite_composition                           (FAPbI3)0.85 (MAPbBr3)0.15
# electron_transport_layer                                               SnO2
# pin_nip_structure                                                       PIN
# hole_transport_layer                                           Spiro-OMeTAD
# test_1                    {'test_name': None, 'temperature': None, 'time...
# test_2                                                                  NaN
# passivating_molecule                                                   None
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         41   \
# perovskite_composition            (FAPbI3)0.98(CsI)0.05(PEAI)0.04(MACl)0.05
# electron_transport_layer                                               TiO2
# pin_nip_structure                                                      None
# hole_transport_layer                                           Spiro-OMeTAD
# test_1                    {'test_name': None, 'temperature': None, 'time...
# test_2                                                                  NaN
# passivating_molecule                                               o-PDEAI2
# test_3                                                                  NaN
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
#                                                                         132
# perovskite_composition                      Cs0.05(FAPbI3)0.85(MAPbBr3)0.15
# electron_transport_layer                                               SnO2
# pin_nip_structure                                                       PIN
# hole_transport_layer                                           spiro-OMeTAD
# test_1                    {'test_name': 'Wetting stability', 'temperatur...
# test_2                    {'test_name': 'Thermal stability', 'temperatur...
# passivating_molecule                                                    NaN
# test_3                    {'test_name': 'Illumination stability', 'tempe...
# control_pce                                                             NaN
# control_voc                                                             NaN
# treated_pce                                                             NaN
# treated_voc                                                             NaN
# test_4                                                                  NaN
#
# [13 rows x 129 columns]

# %%
pd.read_json('/Users/kanggun/Documents/DSC180_B11_Q2/data/json_output_deepseek8b_newschema/deepseek_4_updateprompt.json')
# Out:
#                                                                         17   \
# perovskite_composition                           Methylammonium Lead Iodide
# electron_transport_layer                                               None
# structure_pin_nip                                                       NIP
# hole_transport_layer                                                   None
# test_1                    {'stability_type': 'ISOS-L', 'temperature': 10...
# test_2                    {'stability_type': 'ISOS-T', 'temperature': 60...
# test_3                                                                  NaN
#
#                                                                         100  \
# perovskite_composition                                                 None
# electron_transport_layer                                titanium oxynitride
# structure_pin_nip                                                       NIP
# hole_transport_layer                                              P3HT:CuPc
# test_1                    {'stability_type': 'ISOS-L', 'temperature': 85...
# test_2                                                                  NaN
# test_3                                                                  NaN
#
#                                                                         107  \
# perovskite_composition                                       MA0.7FA0.3PbI3
# electron_transport_layer                                                C60
# structure_pin_nip                                                       PIN
# hole_transport_layer                                                   PTAA
# test_1                    {'stability_type': 'ISOS-LT', 'temperature': 6...
# test_2                                                                  NaN
# test_3                                                                  NaN
#
#                                                                         10   \
# perovskite_composition                Cs 0.12 FA 0.8 MA 0.08 PbI 1.8 Br 1.2
# electron_transport_layer                                               PCBM
# structure_pin_nip                                                       PIN
# hole_transport_layer                                                  2PACz
# test_1                    {'stability_type': 'thermal stability', 'tempe...
# test_2                                                                  NaN
# test_3                                                                  NaN
#
#                                                                         109  \
# perovskite_composition            Cs 0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3
# electron_transport_layer                               buckminsterfullerene
# structure_pin_nip                                                       PIN
# hole_transport_layer                                     poly(triarylamine)
# test_1                    {'stability_type': 'ISOS-LT', 'temperature': 2...
# test_2                                                                  NaN
# test_3                                                                  NaN
#
#                                                                         62   \
# perovskite_composition                            Cs0.15FA0.85PbI2.55Br0.45
# electron_transport_layer                                               None
# structure_pin_nip                                                       PIN
# hole_transport_layer                                                   None
# test_1                    {'stability_type': 'ISOS-D1', 'temperature': 2...
# test_2                    {'stability_type': 'ISOS-D3', 'temperature': 8...
# test_3                    {'stability_type': 'ISOS-O3', 'temperature': N...
#
#                                                                         19   \
# perovskite_composition                         Formamidinium lead triiodide
# electron_transport_layer                                               None
# structure_pin_nip                                                       NIP
# hole_transport_layer                                                   None
# test_1                    {'stability_type': 'ISOS-D', 'temperature': 25...
# test_2                    {'stability_type': 'ISOS-L', 'temperature': 25...
# test_3                    {'stability_type': 'ISOS-LT', 'temperature': 5...
#
#                                                                         65   \
# perovskite_composition                                           CH3NH3PbI3
# electron_transport_layer                                               SnOx
# structure_pin_nip                                                       PIN
# hole_transport_layer                                                 Al:ZnO
# test_1                    {'stability_type': 'ISOS-D', 'temperature': 25...
# test_2                                                                  NaN
# test_3                                                                  NaN
#
#                                                 147  \
# perovskite_composition    (MAPbBr3)0.05(FAPbI3)0.95
# electron_transport_layer                       SnO2
# structure_pin_nip                               NIP
# hole_transport_layer                   Spiro-OMeTAD
# test_1                                         None
# test_2                                          NaN
# test_3                                          NaN
#
#                                                                         81
# perovskite_composition                                                 None
# electron_transport_layer                                EDTA-complexed SnO2
# structure_pin_nip                                                      None
# hole_transport_layer                                           spiro-OMeTAD
# test_1                    {'stability_type': 'ISOS-D', 'temperature': 12...
# test_2                                                                  NaN
# test_3                                                                  NaN
