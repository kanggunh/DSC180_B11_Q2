# %% [markdown]
# # This file compares the teamtat annotation with Extraction performed (Json)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from difflib import SequenceMatcher
import numpy as np
import json
import os
import xml.etree.ElementTree as ET 
import pandas as pd
import re
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## File Preparation

# %%
def str_toJson(string):
    ##The json output from annotation dataframe was not in correct json format
    # We will change the None to null
    json_string = string.replace("None", "null")

    try:
        # Try to load the JSON string
        json_object = json.loads(json_string)
        return json_object
    except json.JSONDecodeError as e:
        # Catch JSONDecodeError if the string is not valid JSON
        print(f"Error decoding JSON: {e}")
        return None
    except Exception as e:
        # Catch any other exceptions
        print(f"An error occurred: {e}")
        return None

# %%
def include_passivating(dictionary):
    ##In extraction json, realized that some extraction has passivating molecule that is NOT included in its stability testing. 
    ## Since passivating molecule (if exist) needs to be in stability testing (nexted dictionary), we will transfer the information and spit out a cleaned dictionary. 
    if "passivating_molecule" in dictionary.keys():
        passivating = dictionary['passivating_molecule']
        del dictionary['passivating_molecule']
        
        for entity in dictionary.keys():
            if entity.startswith('test'):
                # print(i['entity'])
                if type(dictionary[entity]) == dict:
                    if 'passivating_molecule' in dictionary[entity].keys():
                        continue
                    else:
                        # print("Have to include passivating molecule in tests")
                        dictionary[entity]['passivating_molecule'] = passivating
        
    return dictionary

# %%
## Convert all numerical data into float for both
def convert_numeric(dictionary):
    numerical_key = ['temperature', 'time', 'humidity', 'efficiency_cont', 'efficiency_tret', 'control_pce', 'treated_pce', 'control_voc', 'treated_voc']

    translation_table = str.maketrans('', '', 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!@#$%^&*()')
    for key in dictionary.keys():
        if (key.startswith('test')) & (type(dictionary[key]) == dict):
            for entity in dictionary[key].keys():
                if entity in numerical_key:
                    # print(dictionary[key][entity])
                    if isinstance(dictionary[key][entity], str): 
                        substitute = re.sub(r'[^0-9.]', '', dictionary[key][entity][:4])
                        if len(substitute) != 0:
                            numerical_value = float(substitute)
                            dictionary[key][entity] = numerical_value
                        else:
                            dictionary[key][entity] = None
    return dictionary

# %%
def convert_efficiency(dictionary):
    entity_decimal = ['efficiency_cont','efficiency_tret']
    for key in dictionary.keys():
        if (key.startswith('test')) & (type(dictionary[key]) == dict):
            for entity in dictionary[key].keys():
                if (entity in entity_decimal) and (dictionary[key][entity] != None):
                    if dictionary[key][entity] == dictionary[key][entity] > 1:
                        dictionary[key][entity] = dictionary[key][entity] / 100
    return dictionary

# %% [markdown]
# #### Analyzing these outputs
#
# Annotation notes:
# - THE 4 basic variable that is to compare is PEROVSKITE COMPOSITION, ETL, HTL, STRUCTURE
# - Stability entity: efficiency_control is wrong, All value is None, so ignore.
# - Common entity: ['stability_type', 'passivating_molecule', 'humidity', 'temperature', 'time', 'control_pce', 'treated_pce', 'control_voc', 'treated_voc', 'efficiency_tret']
#     - 'efficiency_cont' are included or not
#
# - the efficiency in extracted data need to be converted to decimals since it is in percentage SOMETIMES
#     - 'control_efficiency' and 'treatment_efficiency can be ignored
#
#
# Extraction notes:
# - some extraction has passivating molecule that is NOT included in its stability testing.

# %% [markdown]
# ### Loading Teamtat Annotation as dataframe

# %%
#Teamtat Annotation
annotation_df = pd.read_csv("../data/150_papers_json.csv")[["id", "first_num", "output"]]
annotation_df = annotation_df.sort_values(by = ['first_num'])

# %%
##Change the format (minor) to be converted to json
annotation_df['output'] = annotation_df['output'].apply(str_toJson)
annotation_df
# Out:
#          id  first_num                                             output
# 0      0_54          0  {'perovskite_composition': 'Cs 0.05 FA 0.85 MA...
# 1      1_22          1  {'perovskite_composition': None, 'electron_tra...
# 2      2_75          2  {'perovskite_composition': 'dibutylammonium le...
# 3      3_52          3  {'perovskite_composition': 'Cs0.05(MA0.10FA0.8...
# 4      4_26          4  {'perovskite_composition': '(MAPbBr3)0.05(FAPb...
# ..      ...        ...                                                ...
# 144  145_31        145  {'perovskite_composition': 'Cs0.05(MA0.17FA0.8...
# 145  146_36        146  {'perovskite_composition': 'Cs0.05(MA0.05FA0.9...
# 146  147_41        147  {'perovskite_composition': 'formamidinium lead...
# 147  148_26        148  {'perovskite_composition': 'Cs0.05FA0.85MA0.10...
# 148  149_28        149  {'perovskite_composition': 'FA0.7MA0.3Pb0.5Sn0...
#
# [149 rows x 3 columns]

# %%
annotation_df['output'] = annotation_df['output'].apply(convert_numeric)

# %% [markdown]
# ### Loading in JSON extraction

# %%
## extraction performed by Llama (Daniel)
# Read JSON from a file
with open("../data/deepseek_finetuned.json", 'r') as f:
    extraction = json.load(f)

extraction_df = pd.DataFrame(list(extraction.items()), columns=['paper_num', 'output'])
extraction_df['paper_num'] = pd.to_numeric(extraction_df['paper_num'])
extraction_df = extraction_df.sort_values('paper_num')
extraction_df
# Out:
#      paper_num                                             output
# 111          0  {'perovskite_composition': 'FAPbI3', 'electron...
# 67           1  {'perovskite_composition': 'FA1-x MAx PbI3 (FA...
# 46           2  {'perovskite_composition': 'FA0.85Cs0.15PbI2.8...
# 30           3  {'perovskite_composition': 'Cs0.05(MA0.10FA0.8...
# 27           4  {'perovskite_composition': None, 'electron_tra...
# ..         ...                                                ...
# 52         145  {'perovskite_composition': 'Cs0.05(MA0.17FA0.8...
# 73         146  {'perovskite_composition': 'Cs0.05(FA0.05MA0.9...
# 102        147  {'perovskite_composition': 'FAPbI3', 'electron...
# 80         148  {'perovskite_composition': 'Cs0.05 FA0.85 MA0....
# 95         149  {'perovskite_composition': 'FA0.8Cs0.2Pb0.5Sn0...
#
# [126 rows x 2 columns]

# %%
extraction_df['output'] = extraction_df['output'].apply(include_passivating)
extraction_df
# Out:
#      paper_num                                             output
# 111          0  {'perovskite_composition': 'FAPbI3', 'electron...
# 67           1  {'perovskite_composition': 'FA1-x MAx PbI3 (FA...
# 46           2  {'perovskite_composition': 'FA0.85Cs0.15PbI2.8...
# 30           3  {'perovskite_composition': 'Cs0.05(MA0.10FA0.8...
# 27           4  {'perovskite_composition': None, 'electron_tra...
# ..         ...                                                ...
# 52         145  {'perovskite_composition': 'Cs0.05(MA0.17FA0.8...
# 73         146  {'perovskite_composition': 'Cs0.05(FA0.05MA0.9...
# 102        147  {'perovskite_composition': 'FAPbI3', 'electron...
# 80         148  {'perovskite_composition': 'Cs0.05 FA0.85 MA0....
# 95         149  {'perovskite_composition': 'FA0.8Cs0.2Pb0.5Sn0...
#
# [126 rows x 2 columns]

# %%
extraction_df['output'] = extraction_df['output'].apply(convert_numeric)
annotation_df['output'] = annotation_df['output'].apply(convert_numeric)

# %%
extraction_df['output'] = extraction_df['output'].apply(convert_efficiency)

# %% [markdown]
# ## Merging dataframe

# %%
evaluate_df = annotation_df.merge(extraction_df, left_on='first_num', right_on='paper_num')[["paper_num", "output_x",'output_y']]
evaluate_df.columns = ['paper_num', 'annotation', 'extracted']
evaluate_df
# Out:
#      paper_num                                         annotation  \
# 0            0  {'perovskite_composition': 'Cs 0.05 FA 0.85 MA...
# 1            1  {'perovskite_composition': None, 'electron_tra...
# 2            2  {'perovskite_composition': 'dibutylammonium le...
# 3            3  {'perovskite_composition': 'Cs0.05(MA0.10FA0.8...
# 4            4  {'perovskite_composition': '(MAPbBr3)0.05(FAPb...
# ..         ...                                                ...
# 121        145  {'perovskite_composition': 'Cs0.05(MA0.17FA0.8...
# 122        146  {'perovskite_composition': 'Cs0.05(MA0.05FA0.9...
# 123        147  {'perovskite_composition': 'formamidinium lead...
# 124        148  {'perovskite_composition': 'Cs0.05FA0.85MA0.10...
# 125        149  {'perovskite_composition': 'FA0.7MA0.3Pb0.5Sn0...
#
#                                              extracted
# 0    {'perovskite_composition': 'FAPbI3', 'electron...
# 1    {'perovskite_composition': 'FA1-x MAx PbI3 (FA...
# 2    {'perovskite_composition': 'FA0.85Cs0.15PbI2.8...
# 3    {'perovskite_composition': 'Cs0.05(MA0.10FA0.8...
# 4    {'perovskite_composition': None, 'electron_tra...
# ..                                                 ...
# 121  {'perovskite_composition': 'Cs0.05(MA0.17FA0.8...
# 122  {'perovskite_composition': 'Cs0.05(FA0.05MA0.9...
# 123  {'perovskite_composition': 'FAPbI3', 'electron...
# 124  {'perovskite_composition': 'Cs0.05 FA0.85 MA0....
# 125  {'perovskite_composition': 'FA0.8Cs0.2Pb0.5Sn0...
#
# [126 rows x 3 columns]

# %%
# evaluate_df.to_csv('merged.csv', index=False)

# %%
for row in evaluate_df.itertuples():
    label_value = row.annotation
    extracted_value = row.extracted

    print(label_value)
    print(extracted_value)
# Out:
# {'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3', 'electron_transport_layer': 'C60', 'hole_transport_layer': '2PACz and Me-4PACz', 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': 'ISOSL', 'passivating_molecule': '4-chlorobenzenesulfonate (4Cl-BZS)', 'humidity': None, 'temperature': 65.0, 'time': 1200.0, 'control_pce': 24.0, 'treated_pce': 26.9, 'control_voc': None, 'treated_voc': 1.18, 'efficiency_control': None, 'efficiency_tret': 95.0}}
# {'perovskite_composition': 'FAPbI3', 'electron_transport_layer': 'Spiro-OMeTAD', 'hole_transport_layer': 'C60', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L-3', 'temperature': 65.0, 'humidity': 50.0, 'retained_proportion_cont': '0.95', 'retained_proportion_tret': '0.95', 'passivating_molecule': 'cyclohexylmethylammonium iodide', 'control_pce': 24.7, 'control_voc': 1.18, 'treated_pce': 25.7, 'treated_voc': 1.15}}
# {'perovskite_composition': None, 'electron_transport_layer': 'TinOxide', 'hole_transport_layer': 'poly[bis(4-phenyl) (2,4,6-trimethylphenyl)amine] (PTAA)', 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': 'ISOST', 'passivating_molecule': 'phenethylammonium', 'humidity': None, 'temperature': 85.0, 'time': 500.0, 'control_pce': None, 'treated_pce': 19.1, 'control_voc': None, 'treated_voc': 1.16, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': 'FA1-x MAx PbI3 (FA: HC(NH2)2; MA: CH3NH3)', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 85.0, 'time': 500.0, 'humidity': 25.0, 'retained_proportion_cont': '20', 'retained_proportion_tret': '40', 'passivating_molecule': 'phenethylammonium iodide (PEAI)', 'control_pce': 21.2, 'control_voc': 1.12, 'treated_pce': 23.3, 'treated_voc': 1.18}}
# {'perovskite_composition': 'dibutylammonium lead iodide', 'electron_transport_layer': 'tin dioxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': 'ISOSL', 'passivating_molecule': 'butylamine', 'humidity': 85.0, 'temperature': 25.0, 'time': 1620.0, 'control_pce': None, 'treated_pce': 24.3, 'control_voc': None, 'treated_voc': 1.18, 'efficiency_control': None, 'efficiency_tret': 0.98, 'efficiency_cont': 0.58}, 'test_1_2': {'stability_type': 'ISOSD', 'passivating_molecule': None, 'humidity': 85.0, 'temperature': 85.0, 'time': 1056.0, 'control_pce': None, 'treated_pce': 21.3, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.94}, 'test_2': {'stability_type': 'ISOSLT', 'passivating_molecule': None, 'humidity': None, 'temperature': 25.0, 'time': 1620.0, 'control_pce': None, 'treated_pce': 24.0, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.98}}
# {'perovskite_composition': 'FA0.85Cs0.15PbI2.85I3', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'humidity', 'temperature': 85.0, 'humidity': 85.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '0.97', 'passivating_molecule': '(BA)2PbI4', 'control_pce': 21.3, 'control_voc': 1.12, 'treated_pce': 24.0, 'treated_voc': 1.18}}
# {'perovskite_composition': 'Cs0.05(MA0.10FA0.85)Pb(I0.90Br0.10)3', 'electron_transport_layer': 'tin dioxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': 'ISOSL1', 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': 2000.0, 'control_pce': None, 'treated_pce': 24.5, 'control_voc': None, 'treated_voc': 1.2, 'efficiency_control': None, 'efficiency_tret': 0.99, 'efficiency_cont': 0.25}}
# {'perovskite_composition': 'Cs0.05(MA0.10FA0.85)Pb(I0.90Br0.10)3', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'n-i-p', 'test_1': {'test_name': 'ISOS-L-1', 'temperature': 60.0, 'time': 1000.0, 'humidity': 70.0, 'retained_proportion_cont': '0.25', 'retained_proportion_tret': '0.99', 'passivating_molecule': None, 'control_pce': 21.0, 'control_voc': 1.09, 'treated_pce': 24.5, 'treated_voc': 1.2}}
# {'perovskite_composition': '(MAPbBr3)0.05(FAPbI3)0.95', 'electron_transport_layer': 'tin dioxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP'}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': None, 'pin_nip_structure': None, 'test_1': {'test_name': 'ISOS-L', 'temperature': None, 'time': None, 'humidity': None, 'retained_proportion_cont': None, 'retained_proportion_tret': '21.9', 'passivating_molecule': '4-vinylbenzylammonium bromide', 'control_pce': 19.9, 'control_voc': 1.06, 'treated_pce': 21.0, 'treated_voc': 1.1}}
# {'perovskite_composition': 'butylammonium lead iodide', 'electron_transport_layer': 'buckminsterfullerene', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': None, 'passivating_molecule': 'iso-butylamine iodide', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': None, 'treated_pce': 22.1, 'control_voc': None, 'treated_voc': 1.13, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': 'FA(MA)PbI3', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure': 'PIN', 'stability_tests': [{'test_name': 'ISOS-D', 'temperature': '85', 'humidity': '85', 'time': '1000', 'retained_proportion_cont': None, 'retained_proportion_tret': '100', 'passivating_molecule': 'n-BAI and iso-BAI', 'control_pce': None, 'treated_pce': '22.1', 'control_voc': None, 'treated_voc': '1135'}]}
# {'perovskite_composition': 'Methylammonium Lead Iodide', 'electron_transport_layer': 'Titanium dioxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': None, 'test_1': {'stability_type': 'ISOSD', 'passivating_molecule': 'phenylethylammonium iodide', 'humidity': None, 'temperature': None, 'time': 1344.0, 'control_pce': None, 'treated_pce': 18.8, 'control_voc': None, 'treated_voc': 1.16, 'efficiency_control': None, 'efficiency_tret': 0.97}}
# {'perovskite_composition': 'PEA2(CH3NH3)2Pb2I7', 'electron_transport_layer': 'Titanium dioxide (TiO2)', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'humidity': 90.0, 'retained_proportion_cont': '0.8', 'retained_proportion_tret': '0.92', 'passivating_molecule': 'phenylethylammonium iodide', 'control_pce': 17.2, 'control_voc': 1.09, 'treated_pce': 18.4, 'treated_voc': 1.16}}
# {'perovskite_composition': None, 'electron_transport_layer': 'Tin Oxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': 'ISOSLT', 'passivating_molecule': 'ethylammonium pyrene', 'humidity': None, 'temperature': 40.0, 'time': 2000.0, 'control_pce': 19.3, 'treated_pce': 22.4, 'control_voc': None, 'treated_voc': 1.17, 'efficiency_control': None, 'efficiency_tret': 0.85, 'efficiency_cont': 0.6}}
# {'perovskite_composition': 'CsFAMAPbI3', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 40.0, 'humidity': 306.0, 'retained_proportion_cont': '0.85', 'retained_proportion_tret': '0.92', 'passivating_molecule': '4-ethyl-1H-pyrrole-2-carboxylic acid', 'control_pce': 20.1, 'control_voc': 1.16, 'treated_pce': 23.0, 'treated_voc': 1.18}}
# {'perovskite_composition': 'CH 3 NH 3 PbI 3', 'electron_transport_layer': 'PCBM', 'hole_transport_layer': None, 'structure_pin_nip': None, 'test_1': {'stability_type': None, 'passivating_molecule': 'EDBE', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': 14.6, 'treated_pce': 17.6, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': 'CH3NH3PbI3', 'electron_transport_layer': 'PCBM', 'hole_transport_layer': 'CuOx', 'structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 60.0, 'humidity': None, 'retained_proportion_cont': '85', 'retained_proportion_tret': '90', 'passivating_molecule': None, 'control_pce': 14.6, 'control_voc': None, 'treated_pce': 17.6, 'treated_voc': None}}
# {'perovskite_composition': 'Cs0.15FA0.85PbI2.19Br0.81', 'electron_transport_layer': None, 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': 'ISOSL', 'passivating_molecule': 'butylammonium bromide', 'humidity': None, 'temperature': None, 'time': 20.0, 'control_pce': None, 'treated_pce': 19.8, 'control_voc': 17.5, 'treated_voc': 1.31, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': 'Cs0.17FA0.83Pb(I0.6Br0.4)3', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'time': 1000.0, 'humidity': 203.0, 'retained_proportion_cont': '0.8', 'retained_proportion_tret': '19.4', 'passivating_molecule': 'n-butylammonium bromide (BABr)', 'control_pce': 16.7, 'control_voc': 1.23, 'treated_pce': 19.8, 'treated_voc': 1.31}}
# {'perovskite_composition': 'Cs 0.12 FA 0.8 MA 0.08 PbI 1.8 Br 1.', 'electron_transport_layer': 'PCBM', 'hole_transport_layer': None, 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': None, 'passivating_molecule': '2-thiopheneethylammonium chloride', 'humidity': None, 'temperature': None, 'time': 195.0, 'control_pce': 80.0, 'treated_pce': 23.8, 'control_voc': None, 'treated_voc': 1.29, 'efficiency_control': None, 'efficiency_tret': None}, 'test_1_2': {'stability_type': 'ISOST', 'passivating_molecule': None, 'humidity': None, 'temperature': 60.0, 'time': 265.0, 'control_pce': None, 'treated_pce': 23.8, 'control_voc': None, 'treated_voc': 1.29, 'efficiency_control': None, 'efficiency_tret': 0.92, 'efficiency_cont': 0.82}}
# {'perovskite_composition': 'Cs0.12FA0.8MA0.08PbI1.8Br1.2', 'electron_transport_layer': 'PCBM', 'hole_transport_layer': '2PACz', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 60.0, 'time': 1000.0, 'humidity': 30.0, 'retained_proportion_cont': '0.95', 'retained_proportion_tret': '0.97', 'passivating_molecule': "2,2',2',2'-tetrakis(4-ethylammonium) 1,3,5-triazine", 'control_pce': 12.7, 'control_voc': 1.19, 'treated_pce': 15.1, 'treated_voc': 1.29}}
# {'perovskite_composition': 'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.85 Br 0.15 ) 3', 'electron_transport_layer': 'PCBM', 'hole_transport_layer': 'PTAA', 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': 'ISOSL', 'passivating_molecule': 'chlorophenylethylammonium iodide', 'humidity': None, 'temperature': None, 'time': 33.0, 'control_pce': 21.5, 'treated_pce': 23.7, 'control_voc': 1.1, 'treated_voc': 1.18, 'efficiency_control': None, 'efficiency_tret': 1.0, 'efficiency_cont': 0.9}}
# {'perovskite_composition': 'Cs0.1FA0.9PbI3', 'electron_transport_layer': 'PCBM', 'hole_transport_layer': 'PTAA', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'time': 1000.0, 'humidity': 506.0, 'retained_proportion_cont': '20', 'retained_proportion_tret': '40', 'passivating_molecule': 'PEAI, Cl-PEAI, F-PEAI', 'control_pce': 21.5, 'control_voc': 1.1, 'treated_pce': 23.7, 'treated_voc': 1.15}}
# {'perovskite_composition': 'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.9 Br 0.1 ) 3', 'electron_transport_layer': 'PCBM', 'hole_transport_layer': 'PTAA', 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': None, 'passivating_molecule': 'fluorophenylethylammonium iodide', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': 21.7, 'treated_pce': 23.7, 'control_voc': 1.11, 'treated_voc': 1.17, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': 'Cs0.05(FA0.05MA0.95)0.95Pb(I0.9Br0.1)3', 'electron_transport_layer': "6,6'-bis(2,4-dimethylphenyl)-[2,2:6,6]-bicyclo[2.2.2]oct-2-1,3,5-triyl-1,3,5-trisubstituted fullerene", 'hole_transport_layer': 'piperidinium-based hole transport material', 'pin_nip_structure': 'inverted', 'test_1': {'test_name': 'ISOS-L', 'temperature': 23.0, 'time': 1000.0, 'humidity': 50.0, 'retained_proportion_cont': '0.85', 'retained_proportion_tret': '0.92', 'passivating_molecule': '4-chlorophenylethylammonium iodide', 'control_pce': 21.7, 'control_voc': 1.11, 'treated_pce': 23.4, 'treated_voc': 1.17}}
# {'perovskite_composition': 'FAPbI3', 'electron_transport_layer': 'TinOxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NiP', 'test_1': {'stability_type': None, 'passivating_molecule': 'CF3-phenethylammonium', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': 18.8, 'treated_pce': 21.0, 'control_voc': 1.04, 'treated_voc': 1.11, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': None, 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'humidity': 657.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '98.83', 'passivating_molecule': 'CF3PEAI', 'control_pce': 20.5, 'control_voc': 1.09, 'treated_pce': 21.0, 'treated_voc': 1.11}, 'test_2': {'test_name': 'ISOS-D', 'temperature': 85.0, 'humidity': 510.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '96.98', 'passivating_molecule': 'CF3PEAI2D', 'control_pce': 18.8, 'control_voc': 1.04, 'treated_pce': 21.0, 'treated_voc': 1.01}}
# {'perovskite_composition': 'Cs 0.05 FA 0.81 MA 0.14 PbI 2.55 Br 0.45', 'electron_transport_layer': 'SnO 2', 'hole_transport_layer': 'PTAA', 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': 'ISOSL', 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': 48.0, 'control_pce': 20.0, 'treated_pce': 20.9, 'control_voc': 1.16, 'treated_voc': 1.19, 'efficiency_control': None, 'efficiency_tret': 0.86}}
# {'perovskite_composition': 'Cs0.05 FA0.81 MA0.14 PbI2.55 Br0.45', 'electron_transport_layer': 'C60', 'hole_transport_layer': '1F-PTAA', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'humidity': 707.0, 'time': 48.0, 'retained_proportion_cont': '0.3', 'retained_proportion_tret': '0.8', 'passivating_molecule': 'hexyltrimethylammonium bromide', 'control_pce': 20.9, 'control_voc': 1.16, 'treated_pce': 22.0, 'treated_voc': 1.19}}
# {'perovskite_composition': None, 'electron_transport_layer': 'Tin Oxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': None, 'passivating_molecule': '2-thiophenemethylammonium iodide', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': 'FA0.83MA0.17PbI3', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'device_structure': 'n-i-p', 'stability_test': None}
# {'perovskite_composition': 'Cs 0.05 MA 0.05 FA 0.9 Pb(I 0.95 Br 0.05 ) 3', 'electron_transport_layer': 'C60', 'hole_transport_layer': '2PACz', 'structure_pin_nip': None, 'test_1': {'stability_type': 'ISOSLT', 'passivating_molecule': '3,4,5-trifluoroanilinium', 'humidity': 50.0, 'temperature': 85.0, 'time': 1560.0, 'control_pce': 21.0, 'treated_pce': 24.0, 'control_voc': 1.26, 'treated_voc': 1.27, 'efficiency_control': None, 'efficiency_tret': None}, 'test_2': {'stability_type': 'ISOSL', 'passivating_molecule': None, 'humidity': 50.0, 'temperature': 85.0, 'time': 1586.0, 'control_pce': None, 'treated_pce': 21.5, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.84}}
# {'perovskite_composition': 'Cs0.05MA0.05FA0.9Pb(I0.95Br0.05)3', 'electron_transport_layer': 'C60', 'hole_transport_layer': '2PACz', 'stability_tests': [{'test_name': 'ISOS-L-3', 'temperature': '85', 'humidity': '50', 'retained_proportion_cont': None, 'retained_proportion_tret': '0.84', 'control_pce': '19.9', 'treated_pce': '24.09', 'control_voc': None, 'treated_voc': '1.16', 'passivating_molecule': '3,4,5-trifluoroanilinium (345FAn)', 'device_type': 'inverted'}], 'device_info': {'perovskite_composition': 'Cs0.05MA0.15FA0.8PbI3', 'electron_transport_layer': 'C60', 'hole_transport_layer': '2PACz', 'structure': 'PIN'}}
# {'perovskite_composition': 'Methylammonium Lead Iodide', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None, 'test_1': {'stability_type': None, 'passivating_molecule': 'phenylethylammonium lead iodide', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': 'MAPbI3', 'electron_transport_layer': 'Titanium dioxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'NIP', 'tests': [{'test_name': 'ISOS-L', 'temperature': '100', 'humidity': '30-40', 'time': '450', 'passivating_molecule': '2D/3D perovskite', 'control_pce': None, 'control_voc': None, 'treated_pce': '8.91', 'treated_voc': '1.16', 'retained_proportion_cont': '0.91', 'retained_proportion_tret': '0.85'}, {'test_name': 'ISOS-D', 'temperature': '60', 'humidity': '30-40', 'time': '24', 'passivating_molecule': None, 'control_pce': None, 'control_voc': None, 'treated_pce': None, 'treated_voc': None, 'retained_proportion_cont': '1', 'retained_proportion_tret': '0.5'}]}
# {'perovskite_composition': '(FAPbI3)0.92(MAPbBr3)0.08', 'electron_transport_layer': 'Titanium dioxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': None, 'test_1': {'stability_type': None, 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': None, 'control_pce': None, 'treated_pce': 22.6, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3', 'electron_transport_layer': 'Titanium dioxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'humidity': None, 'retained_proportion_cont': None, 'retained_proportion_tret': '92.5', 'passivating_molecule': 'n-hexylammonium bromide and n-octylammonium bromide', 'control_pce': 21.5, 'control_voc': 1.13, 'treated_pce': 23.1, 'treated_voc': 1.15}}
# {'perovskite_composition': 'Formamidinium lead triiodide', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': None, 'passivating_molecule': 'cyclohexylmethylammonium iodide dissolved in', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': 21.4, 'treated_pce': 23.9, 'control_voc': 1.09, 'treated_voc': 1.14, 'efficiency_control': None, 'efficiency_tret': 0.95}, 'test_1_2': {'stability_type': 'ISOSL', 'passivating_molecule': None, 'humidity': 203.0, 'temperature': None, 'time': 2400.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.91, 'efficiency_cont': 0.85}, 'test_2': {'stability_type': 'ISOSLT', 'passivating_molecule': None, 'humidity': None, 'temperature': 25.0, 'time': 1050.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.95, 'efficiency_cont': 0.76}, 'test_3_2': {'stability_type': 'ISOSD2', 'passivating_molecule': None, 'humidity': 40.0, 'temperature': 50.0, 'time': 500.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': None, 'efficiency_cont': 0.4}, 'test_3': {'stability_type': None, 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': None, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.93}}
# {'perovskite_composition': 'FAPbI3', 'electron_transport_layer': 'TiO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 50.0, 'time': 500.0, 'humidity': 40.0, 'retained_proportion_cont': 'null', 'retained_proportion_tret': '93', 'passivating_molecule': 'cyclohexylmethylammonium iodide', 'control_pce': 21.0, 'control_voc': 1.15, 'treated_pce': 21.0, 'treated_voc': 1.15}}
# {'perovskite_composition': 'Cs0.05MA0.1FA0.85PbI3', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': 'ISOSL1', 'passivating_molecule': 'phenethylammonium iodide', 'humidity': 50.0, 'temperature': 25.0, 'time': 1000.0, 'control_pce': None, 'treated_pce': 23.9, 'control_voc': None, 'treated_voc': 1.15, 'efficiency_control': None, 'efficiency_tret': 1.0}, 'test_2': {'stability_type': 'ISOSL3', 'passivating_molecule': None, 'humidity': None, 'temperature': 65.0, 'time': 500.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.92}}
# {'perovskite_composition': 'Cs0.05(MA0.1FA0.85PbI3)3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'NiOx', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 50.0, 'time': 1000.0, 'humidity': 50.0, 'retained_proportion_cont': '0.01', 'retained_proportion_tret': '0.99', 'passivating_molecule': '3F-PEA', 'control_pce': 23.9, 'control_voc': 1.15, 'treated_pce': 23.9, 'treated_voc': 1.15}}
# {'perovskite_composition': 'Cesium lead iodide', 'electron_transport_layer': 'Titanium dioxide', 'hole_transport_layer': 'copper(I) thiocyanate', 'structure_pin_nip': None, 'test_1': {'stability_type': 'ISOSD', 'passivating_molecule': None, 'humidity': None, 'temperature': 110.0, 'time': 2100.0, 'control_pce': 14.9, 'treated_pce': 17.4, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.8}}
# {'perovskite_composition': 'Cs0.15FA0.85MA0.05PbI3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L-3', 'temperature': 35.0, 'humidity': 42.0, 'time': 3531.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '0.8', 'passivating_molecule': 'Cs2PbI2Cl2', 'control_pce': None, 'control_voc': None, 'treated_pce': 17.4, 'treated_voc': 1.16}}
# {'perovskite_composition': 'formamidinium lead iodide', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None}
# {'perovskite_composition': 'formamidinium lead iodide (FAPbI3)', 'electron_transport_layer': None, 'hole_transport_layer': None, 'pin_nip_structure': None, 'test_1': {'test_name': 'ISOS-L', 'temperature': 85.0, 'time': 1000.0, 'humidity': None, 'passivating_molecule': 'formamidinium', 'control_pce': None, 'treated_pce': None, 'retained_proportion_cont': None, 'retained_proportion_tret': '0.05', 'control_voc': None, 'treated_voc': None}, 'test_2': {'test_name': 'ISOS-D', 'temperature': 120.0, 'time': 24.0, 'humidity': None, 'passivating_molecule': 'formamidinium', 'control_pce': None, 'treated_pce': None, 'retained_proportion_cont': None, 'retained_proportion_tret': '0.2', 'control_voc': None, 'treated_voc': None}}
# {'perovskite_composition': 'Methylammonium Lead Iodide', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None}
# {'perovskite_composition': 'MAPbCl3, MAPbBr3, MAPbI3', 'electron_transport_layer': None, 'hole_transport_layer': None, 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 60.0, 'humidity': 304.0, 'retained_proportion_cont': '0.5', 'retained_proportion_tret': '0.8', 'passivating_molecule': 'methylamine', 'control_pce': 3.1, 'control_voc': 0.92, 'treated_pce': 4.8, 'treated_voc': 1.15}}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': 'ISOSLT', 'passivating_molecule': 'trifluoromethylphenylethylammonium', 'humidity': None, 'temperature': None, 'time': 2000.0, 'control_pce': None, 'treated_pce': 18.5, 'control_voc': None, 'treated_voc': 1.23, 'efficiency_control': None, 'efficiency_tret': 1.0}}
# {'perovskite_composition': 'CsPbI3-xBrx', 'electron_transport_layer': 'C60', 'hole_transport_layer': None, 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 35.0, 'humidity': 304.0, 'retained_proportion_cont': '0.84', 'retained_proportion_tret': '0.96', 'passivating_molecule': '4-(Trifluoromethyl) phenethylammonium (CF3-PEA)', 'control_pce': 18.5, 'control_voc': 1.01, 'treated_pce': 25.6, 'treated_voc': 2.0}}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': None, 'pin_nip_structure': None, 'test_1': {'test_name': 'ISOS-L', 'temperature': 65.0, 'humidity': 65.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '85', 'passivating_molecule': 'butylamine', 'control_pce': None, 'treated_pce': 25.5, 'control_voc': None, 'treated_voc': 1.1}, 'test_2': {'test_name': 'ISOS-D', 'temperature': 110.0, 'humidity': 50.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '75', 'passivating_molecule': None, 'control_pce': None, 'treated_pce': 24.8, 'control_voc': None, 'treated_voc': 1.1}}
# {'perovskite_composition': 'ammonia healed formamidinium cesium lead iodide', 'electron_transport_layer': 'tin dioxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': 'ISOSLT', 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': 500.0, 'control_pce': 10.9, 'treated_pce': 23.2, 'control_voc': None, 'treated_voc': 1.16, 'efficiency_control': None, 'efficiency_tret': 0.8}}
# {'perovskite_composition': 'FA0.9Cs0.1PbI3', 'electron_transport_layer': 'Spiro-OMeTAD', 'hole_transport_layer': 'boric acid-doped TiO2', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L-2', 'temperature': 60.0, 'time': 1000.0, 'humidity': None, 'retained_proportion_cont': '0.85', 'retained_proportion_tret': '0.95', 'passivating_molecule': None, 'control_pce': 22.2, 'control_voc': 1.16, 'treated_pce': 23.2, 'treated_voc': 1.17}}
# {'perovskite_composition': 'ISOSD3', 'electron_transport_layer': 'buckminsterfullerene', 'hole_transport_layer': 'MeO-2PACZ', 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': 'ISOSLT', 'passivating_molecule': '3-(aminomethyl)pyridine', 'humidity': None, 'temperature': 55.0, 'time': 2428.0, 'control_pce': 23.3, 'treated_pce': 25.4, 'control_voc': None, 'treated_voc': 1.19, 'efficiency_control': None, 'efficiency_tret': 0.87, 'efficiency_cont': 0.76}, 'test_2': {'stability_type': 'ISOSL2', 'passivating_molecule': None, 'humidity': None, 'temperature': 65.0, 'time': 1315.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.9}, 'test_3': {'stability_type': None, 'passivating_molecule': None, 'humidity': 85.0, 'temperature': 85.0, 'time': 850.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.94}}
# {'perovskite_composition': 'FA0.85MA0.15PbI3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'Spiro-OMeTAD', 'test_1': {'test_name': 'ISOS-L-1', 'temperature': 55.0, 'humidity': None, 'retained_proportion_cont': '76', 'retained_proportion_tret': '87', 'control_pce': 22.8, 'treated_pce': 25.3, 'control_voc': 1.12, 'treated_voc': 1.15, 'passivating_molecule': '3-(aminomethyl)pyridine'}, 'test_2': {'test_name': 'ISOS-L-2', 'temperature': 65.0, 'humidity': None, 'retained_proportion_cont': '90', 'retained_proportion_tret': '94', 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'passivating_molecule': '3-(aminomethyl)pyridine'}, 'test_3': {'test_name': 'ISOS-D-3', 'temperature': 85.0, 'humidity': 85.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '94', 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'passivating_molecule': '3-(aminomethyl)pyridine'}}
# {'perovskite_composition': 'Methylammonium Lead Iodide', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None}
# {'perovskite_composition': 'CH3NH3PbI3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'humidity': 506.0, 'retained_proportion_cont': '0.7', 'retained_proportion_tret': '0.85', 'passivating_molecule': 'none', 'control_pce': 15.4, 'control_voc': 1.07, 'treated_pce': 21.3, 'treated_voc': 1.15}}
# {'perovskite_composition': 'formamidinium lead iodide', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None}
# {'perovskite_composition': 'formamidinium lead iodide (FAPbI3)', 'electron_transport_layer': None, 'hole_transport_layer': None, 'pin_nip_structure': None, 'test_1': {'test_name': 'ISOS-L', 'temperature': 60.0, 'time': 720.0, 'humidity': 657.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '0.9', 'passivating_molecule': 'benzene', 'control_pce': None, 'treated_pce': 25.1, 'treated_voc': None}}
# {'perovskite_composition': '(CsPbI3)0.05[(FAPbI3)0.83(MAPbBr3)0.17]0.95', 'electron_transport_layer': None, 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': None}
# {'perovskite_composition': 'CsPbI3-0.05-(FAPbI3)0.83-(MAPbBr3)0.17', 'electron_transport_layer': 'PEDOT:PSS', 'hole_transport_layer': 'P3HT', 'pin_nip_structure': None, 'test_1': {'test_name': 'PL', 'temperature': 445.0, 'humidity': None, 'retained_proportion_cont': None, 'retained_proportion_tret': None, 'passivating_molecule': None, 'control_pce': None, 'control_voc': None, 'treated_pce': None, 'treated_voc': None}}
# {'perovskite_composition': 'FA0.8MA0.2PbI 3', 'electron_transport_layer': 'buckminsterfullerene', 'hole_transport_layer': 'poly(triarylamine)', 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': None, 'passivating_molecule': 'tri-octyl phosphine oxide', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': None, 'treated_pce': 22.4, 'control_voc': 1.07, 'treated_voc': 1.09, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': 'Cs0.05(FA0.83MA0.17)0.95Pb(I0.83Br0.17)3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'PTAA:PFN', 'structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'humidity': 506.0, 'retained_proportion_cont': '0.8', 'retained_proportion_tret': '0.92', 'passivating_molecule': 'LiF', 'control_pce': 21.3, 'control_voc': 1.14, 'treated_pce': 23.1, 'treated_voc': 1.18}}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None, 'test_1': {'stability_type': None, 'passivating_molecule': '1,3-propylene diammonium', 'humidity': None, 'temperature': None, 'time': 700.0, 'control_pce': None, 'treated_pce': 19.0, 'control_voc': None, 'treated_voc': 1.35, 'efficiency_control': None, 'efficiency_tret': 1.0}, 'test_2': {'stability_type': None, 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': 500.0, 'control_pce': None, 'treated_pce': 26.3, 'control_voc': None, 'treated_voc': 2.19, 'efficiency_control': None, 'efficiency_tret': 0.86}}
# {'perovskite_composition': 'Cs0.2FA0.8Pb(I0.6Br0.4)3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'NiOx/Me-4PACz', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'time': 500.0, 'humidity': 253.0, 'retained_proportion_cont': '0.7', 'retained_proportion_tret': '0.86', 'passivating_molecule': '1,3-propane diammonium iodide', 'control_pce': 23.5, 'control_voc': 1.23, 'treated_pce': 26.2, 'treated_voc': 2.13}}
# {'perovskite_composition': '(FAPbI 3 ) 0.87(MAPbBr3)0.13]0.92(CsPbI3)0.08', 'electron_transport_layer': 'Titanium dioxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': None, 'test_1': {'stability_type': 'ISOSLT', 'passivating_molecule': '2-thiophenemethylammonium bromide', 'humidity': None, 'temperature': None, 'time': 1000.0, 'control_pce': 20.7, 'treated_pce': 20.8, 'control_voc': 1.09, 'treated_voc': 1.17, 'efficiency_control': None, 'efficiency_tret': 0.75, 'efficiency_cont': 0.65}}
# {'perovskite_composition': '[(FAPbI3)0.87(MAPbBr3)0.13]0.92(CSPbI3)0.08', 'electron_transport_layer': 'TiO2', 'hole_transport_layer': 'spiro-OMeTAD', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 100.0, 'time': 1000.0, 'humidity': None, 'retained_proportion_cont': '0.7', 'retained_proportion_tret': '0.9', 'passivating_molecule': '2-TMAI', 'control_pce': 20.7, 'control_voc': 1.09, 'treated_pce': 19.9, 'treated_voc': 1.09}}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': 'PTAA', 'structure_pin_nip': None, 'test_1': {'stability_type': 'ISOSD', 'passivating_molecule': 'oleylammonium iodide', 'humidity': 85.0, 'temperature': 85.0, 'time': 1000.0, 'control_pce': None, 'treated_pce': 24.3, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.95}}
# {'perovskite_composition': 'FAMAPbI3 and MAPbI3 layers (two-step method)', 'electron_transport_layer': 'C60', 'hole_transport_layer': '2D PACz', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-D', 'temperature': 85.0, 'humidity': 85.0, 'retained_proportion_cont': '0.05', 'retained_proportion_tret': '0.95', 'passivating_molecule': 'Oleylammonium iodide', 'control_pce': 21.8, 'control_voc': 1.12, 'treated_pce': 24.3, 'treated_voc': 1.2}}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': None, 'passivating_molecule': 'SnO2', 'humidity': 405.0, 'temperature': 85.0, 'time': 1008.0, 'control_pce': 20.8, 'treated_pce': 23.9, 'control_voc': 1.13, 'treated_voc': 1.15, 'efficiency_control': None, 'efficiency_tret': 0.85, 'efficiency_cont': 0.58}, 'test_2': {'stability_type': 'ISOST', 'passivating_molecule': '22.38', 'humidity': None, 'temperature': 85.0, 'time': 1000.0, 'control_pce': 20.3, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.75, 'efficiency_cont': 0.51}, 'test_3': {'stability_type': None, 'passivating_molecule': 'ISOSLT', 'humidity': None, 'temperature': None, 'time': 1100.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.9, 'efficiency_cont': 0.6}}
# {'perovskite_composition': 'Cs0.05(MA0.05FA0.95)0.95Pb(I0.85Br0.15)3', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'time': 1000.0, 'humidity': 405.0, 'retained_proportion_cont': '58', 'retained_proportion_tret': '85', 'passivating_molecule': 'ortho-(phenylene)di(ethylammonium) iodide', 'control_pce': 21.9, 'control_voc': 1.13, 'treated_pce': 23.9, 'treated_voc': 1.15}}
# {'perovskite_composition': 'Cs 0.05 MA 0.1 FA 0.85 PbI 2.7 Br 0.3', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': 'secondary perovskite growth', 'test_1': {'stability_type': 'ISOSL', 'passivating_molecule': 'azetidinium lead iodide', 'humidity': None, 'temperature': 52.0, 'time': 1000.0, 'control_pce': None, 'treated_pce': 22.4, 'control_voc': 1.07, 'treated_voc': 1.14, 'efficiency_control': None, 'efficiency_tret': 0.85, 'efficiency_cont': 0.47}}
# {'perovskite_composition': None, 'electron_transport_layer': 'C60', 'hole_transport_layer': 'spiro-OMeTAD', 'test_1': {'test_name': 'ISOS-L', 'temperature': 52.0, 'humidity': None, 'retained_proportion_cont': '0.47', 'retained_proportion_tret': '0.85', 'passivating_molecule': 'azetidinium iodide', 'control_pce': None, 'treated_pce': 22.4, 'control_voc': None, 'treated_voc': 1.18}}
# {'perovskite_composition': 'formamidinium lead iodide', 'electron_transport_layer': None, 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': None, 'test_1': {'stability_type': 'ISOSD', 'passivating_molecule': None, 'humidity': 80.0, 'temperature': None, 'time': 500.0, 'control_pce': 23.0, 'treated_pce': 24.5, 'control_voc': 1.12, 'treated_voc': 1.15, 'efficiency_control': None, 'efficiency_tret': 0.47, 'efficiency_cont': 0.09}}
# {'perovskite_composition': 'FA0.90MA0.10PbI3•(CsPbI3)0.05 with excess PbI2 and FA0.8075MA0.10Cs0.05Pb(I0.854Br0.186)3', 'electron_transport_layer': 'mesoporous TiO2 (m-TiO2)', 'hole_transport_layer': 'spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 80.0, 'time': 500.0, 'humidity': 203.0, 'retained_proportion_cont': '9.65', 'retained_proportion_tret': '47.96', 'passivating_molecule': 'benzylamine hydroiodide (BAHI), poly[bis(4-phenyl)(2,5-trimethylphenyl)amine] (PTAA), and 4-tert-butylpyridine (tBP)', 'control_pce': 23.0, 'control_voc': 1.12, 'treated_pce': 24.5, 'treated_voc': 1.15}}
# {'perovskite_composition': 'MAPbI3', 'electron_transport_layer': None, 'hole_transport_layer': 'PTAA', 'structure_pin_nip': None, 'test_1': {'stability_type': 'ISOSLT', 'passivating_molecule': None, 'humidity': 60.0, 'temperature': 65.0, 'time': 1200.0, 'control_pce': 18.2, 'treated_pce': 24.2, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.96}}
# {'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'poly(bis(4-phenyl)(2,4,6-trimethylphenyl)amine)', 'structure_pin_nip': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 65.0, 'time': 1000.0, 'humidity': 60.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '96.8', 'passivating_molecule': 'lead sulfate', 'control_pce': 19.1, 'control_voc': 1.07, 'treated_pce': 21.1, 'treated_voc': 1.16}}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': 'PTAA', 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': None, 'passivating_molecule': 'PS Plastic Foam 1%', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': 16.9, 'treated_pce': 20.3, 'control_voc': 1.07, 'treated_voc': 1.1, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': 'Cs0.1FA0.9PbI3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'PTAA', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'humidity': 40.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '0.203', 'passivating_molecule': 'Polystyrene (PS), Teflon, and poly(vinylidene-trifluoroethylene) (PVDF-TrFE)', 'control_pce': 16.9, 'treated_pce': 20.3, 'control_voc': 1.07, 'treated_voc': 1.1}}
# {'perovskite_composition': None, 'electron_transport_layer': 'indium tin oxide', 'hole_transport_layer': 'spiro-OMeTAD/chlorobenzene', 'structure_pin_nip': None, 'test_1': {'stability_type': 'ISOSL', 'passivating_molecule': 'n-butylamine iodide', 'humidity': 65.0, 'temperature': None, 'time': 4680.0, 'control_pce': None, 'treated_pce': 16.2, 'control_voc': None, 'treated_voc': 1.31, 'efficiency_control': None, 'efficiency_tret': 0.93, 'efficiency_cont': 0.5}, 'test_2': {'stability_type': 'ISOST', 'passivating_molecule': None, 'humidity': None, 'temperature': 85.0, 'time': 558.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.95, 'efficiency_cont': 0.59}, 'test_3': {'stability_type': 'ISOSL', 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': 1100.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.96, 'efficiency_cont': 0.7}}
# {'perovskite_composition': 'phase-pure quantum wells', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'spiro-OMeTAD', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 85.0, 'time': 558.0, 'humidity': 65.0, 'retained_proportion_cont': '0.938', 'retained_proportion_tret': '0.962', 'passivating_molecule': 'n-butylamine acetate', 'control_pce': 13.8, 'control_voc': 1.12, 'treated_pce': 16.2, 'treated_voc': 1.31}}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': None, 'test_1': {'stability_type': None, 'passivating_molecule': 'butylammonium', 'humidity': None, 'temperature': None, 'time': 650.0, 'control_pce': None, 'treated_pce': 21.0, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.9}}
# {'perovskite_composition': 'FA0.82Cs0.13MA0.05PbI3', 'electron_transport_layer': 'PCBM', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'humidity': None, 'retained_proportion_cont': None, 'retained_proportion_tret': '90', 'passivating_molecule': 'allylammonium', 'control_pce': 11.5, 'treated_pce': 16.5, 'control_voc': 1.08, 'treated_voc': 1.07}}
# {'perovskite_composition': 'Methylammonium Lead Iodide', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': 'NIP'}
# {'perovskite_composition': 'MAPbI3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'poly(triarylamine)', 'pin_nip_structure': 'n-i-p', 'test_1': {'test_name': 'ISOS-L', 'temperature': 60.0, 'humidity': 50.0, 'retained_proportion_cont': '85', 'retained_proportion_tret': '95', 'passivating_molecule': 'phenethylammonium iodide', 'control_pce': 23.5, 'control_voc': 1.13, 'treated_pce': 25.1, 'treated_voc': 1.16}}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None}
# {'perovskite_composition': None, 'electron_transport_layer': 'boron-doped, p-type silicon wafer', 'pin_nip_structure': 'NIP', 'hole_transport_layer': None, 'test_1': {'test_name': 'ISOS-D', 'temperature': 85.0, 'humidity': 657.0, 'retained_proportion_cont': '0.70', 'retained_proportion_tret': '0.91', 'passivating_molecule': None, 'control_pce': 20.5, 'control_voc': None, 'treated_pce': 21.1, 'treated_voc': None}}
# {'perovskite_composition': 'FA0.85MA0.1Cs0.05PbI2.9Br0.1', 'electron_transport_layer': 'TinOxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': None, 'passivating_molecule': 'DMePDAI 2', 'humidity': 85.0, 'temperature': None, 'time': 740.0, 'control_pce': 20.9, 'treated_pce': 24.0, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.53}, 'test_1_2': {'stability_type': 'ISOSL1', 'passivating_molecule': None, 'humidity': None, 'temperature': 40.0, 'time': 1000.0, 'control_pce': 22.0, 'treated_pce': 24.7, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.9, 'efficiency_cont': 0.57}, 'test_2_2': {'stability_type': 'ISOSD', 'passivating_molecule': None, 'humidity': 85.0, 'temperature': None, 'time': 740.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.73, 'efficiency_cont': 0.27}, 'test_2': {'stability_type': None, 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': None, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.35}, 'test_3_2': {'stability_type': 'ISOST', 'passivating_molecule': None, 'humidity': 5.0, 'temperature': 85.0, 'time': 1008.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.81, 'efficiency_cont': 0.29}}
# {'perovskite_composition': 'FA0.85MA0.1Cs0.05PbI2.9Br0.1', 'electron_transport_layer': 'TiO2', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 85.0, 'time': 1000.0, 'humidity': None, 'retained_proportion_cont': '20.4', 'retained_proportion_tret': '23.7', 'passivating_molecule': 'N,N-dimethyl-1,3-propane diammonium diiodide', 'control_pce': 20.9, 'control_voc': None, 'treated_pce': 24.7, 'treated_voc': None}}
# {'perovskite_composition': 'methylammonium lead iodide', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None, 'test_1': {'stability_type': None, 'passivating_molecule': 'methylammonium', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': None, 'pin_nip_structure': None, 'test_1': {'test_name': 'ISOS-L', 'temperature': 320.0, 'time': 10.0, 'humidity': None, 'retained_proportion_cont': '0.5', 'retained_proportion_tret': '0.7', 'passivating_molecule': None, 'control_pce': None, 'treated_pce': None, 'treated_voc': None, 'control_voc': None}}
# {'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3', 'electron_transport_layer': 'TitaniumDioxide', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP'}
# {'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3', 'electron_transport_layer': 'C60', 'pin_nip_structure': 'PIN', 'hole_transport_layer': 'PEDOT:PSS', 'test_1': {'test_name': 'ISOS-D', 'temperature': 25.0, 'humidity': 507.0, 'time': 1000.0, 'retained_proportion_cont': '0.8', 'retained_proportion_tret': '0.92', 'passivating_molecule': 'FA0.83Cs0.17Pb0.5Sn0.5I3', 'control_pce': 24.5, 'control_voc': 1.15, 'treated_pce': 22.8, 'treated_voc': 1.08}}
# {'perovskite_composition': 'Cs 0.05 (FA0.83MA0.17)0.95Pb(I0.83Br0.17)3', 'electron_transport_layer': 'buckminsterfullerene', 'hole_transport_layer': 'poly(triarylamine)', 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': 'ISOSLT', 'passivating_molecule': None, 'humidity': None, 'temperature': 27.0, 'time': 350.0, 'control_pce': None, 'treated_pce': 21.0, 'control_voc': None, 'treated_voc': 1.09, 'efficiency_control': None, 'efficiency_tret': 0.95}}
# {'perovskite_composition': 'MA0.07FA0.93PbI3', 'electron_transport_layer': 'PTAA', 'hole_transport_layer': 'C60', 'pin_nip_structure': 'pin', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'time': 350.0, 'humidity': 25.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '95', 'passivating_molecule': None, 'control_pce': 21.8, 'control_voc': 1.09, 'treated_pce': 22.5, 'treated_voc': 1.23}}
# {'perovskite_composition': 'FA0.83Cs0.17Pb(I0.83Br0.17)3', 'electron_transport_layer': 'buckminsterfullerene', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': None, 'test_1': {'stability_type': None, 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': None, 'control_pce': None, 'treated_pce': 18.5, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': 'FA0.83Cs0.17Pb(I0.83Br0.17)3 with 1% PbI2 excess', 'electron_transport_layer': 'PCBM', 'hole_transport_layer': 'NiOx', 'pin_nip_structure': 'n-i-p', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'humidity': 506.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '0.8', 'passivating_molecule': None, 'control_pce': 23.5, 'control_voc': 1.13, 'treated_pce': 21.8, 'treated_voc': 1.12}}
# {'perovskite_composition': 'MAPbI 3', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': 'poly(triarylamine) (PTAA)/ indium tin oxide (ITO)/glass substrates', 'test_1': {'stability_type': None, 'passivating_molecule': 'NIP', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': 17.5, 'treated_pce': 19.0, 'control_voc': 1.16, 'treated_voc': 1.25, 'efficiency_control': None, 'efficiency_tret': None}}
# ...
# {'perovskite_composition': 'FA0.95MA0.05Pb(I0.92Br0.08)3', 'electron_transport_layer': 'Spiro-OMeTAD', 'hole_transport_layer': 'Me-4PACz', 'pin_nip_structure': 'p-i-n', 'test_1': {'test_name': 'ISOS-L', 'temperature': 85.0, 'time': 1000.0, 'humidity': 20.0, 'retained_proportion_cont': '20', 'retained_proportion_tret': '98', 'passivating_molecule': 'Al2O3', 'control_pce': 22.1, 'control_voc': 1.13, 'treated_pce': 24.5, 'treated_voc': 1.19}}
# {'perovskite_composition': 'Cs0.05(FAPbI3)0.85(MAPbBr3)0.15', 'electron_transport_layer': None, 'hole_transport_layer': 'DDT-treated spiro-OMeTAD', 'structure_pin_nip': None, 'test_1': {'stability_type': 'ISOSD', 'passivating_molecule': None, 'humidity': 50.0, 'temperature': None, 'time': 430.0, 'control_pce': 22.7, 'treated_pce': 23.1, 'control_voc': 1.17, 'treated_voc': 1.19, 'efficiency_control': None, 'efficiency_tret': 0.97, 'efficiency_cont': 0.68}, 'test_2': {'stability_type': 'ISOSLT', 'passivating_molecule': None, 'humidity': None, 'temperature': 508.0, 'time': None, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.95}, 'test_3': {'stability_type': 'ISOSLT', 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': 2000.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.93, 'efficiency_cont': 0.1}}
# {'perovskite_composition': 'Cs0.05(FAPbI3)0.85(MAPbBr3)0.15', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'spiro-OMeTAD', 'pin_nip_structure': None, 'test_1': {'test_name': 'ISOS-L', 'temperature': 30.0, 'time': 1000.0, 'humidity': 50.0, 'retained_proportion_cont': '19.0', 'retained_proportion_tret': '20.2', 'passivating_molecule': None, 'control_pce': 19.0, 'control_voc': 1.14, 'treated_pce': 20.2, 'treated_voc': 1.15}}
# {'perovskite_composition': 'Cs0.05FA0.9MA0.05Pb(I0.95Br0.05)3', 'electron_transport_layer': 'buckminsterfullerene', 'hole_transport_layer': 'Me-4PACz', 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': 'ISOSLT', 'passivating_molecule': 'sodium thioglycolate', 'humidity': None, 'temperature': None, 'time': 900.0, 'control_pce': 22.5, 'treated_pce': 24.2, 'control_voc': 1.14, 'treated_voc': 1.19, 'efficiency_control': None, 'efficiency_tret': 0.96}}
# {'perovskite_composition': 'Cs0.05FA0.9MA0.05Pb(I0.95Br0.05)3', 'electron_transport_layer': 'NiO2', 'hole_transport_layer': 'Me-4PACz', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'time': 900.0, 'humidity': 202.0, 'retained_proportion_cont': '0.7', 'retained_proportion_tret': '0.96', 'passivating_molecule': 'sodium thioglycolate', 'control_pce': 23.2, 'control_voc': 1.14, 'treated_pce': 24.2, 'treated_voc': 1.19}}
# {'perovskite_composition': None, 'electron_transport_layer': 'buckminsterfullerene', 'hole_transport_layer': None, 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': 'ISOSD2', 'passivating_molecule': '3-diammonium iodide,propane-1', 'humidity': None, 'temperature': 85.0, 'time': 1600.0, 'control_pce': None, 'treated_pce': 26.4, 'control_voc': None, 'treated_voc': 1.17, 'efficiency_control': None, 'efficiency_tret': 0.95, 'efficiency_cont': 0.84}, 'test_2': {'stability_type': 'ISOSL3', 'passivating_molecule': None, 'humidity': 50.0, 'temperature': 65.0, 'time': 2000.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.96, 'efficiency_cont': 0.7}}
# {'perovskite_composition': 'Cs0.05MA0.05FA0.90PbI3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'NiOx', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-D', 'temperature': 85.0, 'time': 1000.0, 'humidity': 50.0, 'retained_proportion_cont': '84', 'retained_proportion_tret': '96', 'passivating_molecule': 'PDAI2 and 3MTPAI', 'control_pce': 22.8, 'control_voc': 1.12, 'treated_pce': 25.5, 'treated_voc': 1.17}}
# {'perovskite_composition': 'Cs0.05MA0.10FA0.85PbI3', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': 'ISOSL3', 'passivating_molecule': None, 'humidity': 50.0, 'temperature': 65.0, 'time': 1000.0, 'control_pce': None, 'treated_pce': 25.3, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.95}}
# {'perovskite_composition': 'Cs0.05(MA0.1FA0.85)PbI3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'C60', 'pin_nip_structure': None, 'test_1': {'test_name': 'ISOS-L', 'temperature': 65.0, 'humidity': 50.0, 'retained_proportion_cont': '0.13', 'retained_proportion_tret': '7', 'passivating_molecule': '2-(9H-carbazol-9-yl)ethyl phosphonic acid', 'control_pce': 24.6, 'control_voc': 1.15, 'treated_pce': 24.6, 'treated_voc': 1.15}, 'test_2': {'test_name': 'ISOS-D', 'temperature': 85.0, 'humidity': 65.0, 'retained_proportion_cont': '0.09', 'retained_proportion_tret': '3', 'passivating_molecule': None, 'control_pce': None, 'control_voc': None, 'treated_pce': 24.6, 'treated_voc': 1.15}}
# {'perovskite_composition': 'FA0.95Cs0.05PbI3', 'electron_transport_layer': 'buckminsterfullerene', 'hole_transport_layer': 'poly(triaryl)amine', 'structure_pin_nip': 'PIN', 'test_1': {'stability_type': 'ISOSL1', 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': 2500.0, 'control_pce': 25.4, 'treated_pce': 23.5, 'control_voc': 1.14, 'treated_voc': 1.16, 'efficiency_control': None, 'efficiency_tret': 0.92, 'efficiency_cont': 0.8}, 'test_2': {'stability_type': 'ISOSD3', 'passivating_molecule': None, 'humidity': 85.0, 'temperature': 85.0, 'time': 300.0, 'control_pce': 19.2, 'treated_pce': 21.8, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.9, 'efficiency_cont': 0.8}}
# {'perovskite_composition': 'FA0.83Cs0.17PbI3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'PIN', 'test_1': {'test_name': 'ISOS-D', 'temperature': 85.0, 'humidity': 85.0, 'retained_proportion_cont': '20.6', 'retained_proportion_tret': '24.3', 'passivating_molecule': 'PSP', 'control_pce': 20.6, 'control_voc': 1.13, 'treated_pce': 24.3, 'treated_voc': 1.12}}
# {'perovskite_composition': 'formamidinium lead halides', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None, 'test_1': {'stability_type': None, 'passivating_molecule': None, 'humidity': None, 'temperature': 50.0, 'time': 1258.0, 'control_pce': None, 'treated_pce': 25.8, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.94}}
# {'perovskite_composition': 'FAPbI3', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 50.0, 'time': 1258.0, 'humidity': None, 'retained_proportion_cont': '0.94', 'retained_proportion_tret': '0.96', 'passivating_molecule': 'hexafluorobenzene', 'control_pce': 25.8, 'control_voc': None, 'treated_pce': 24.6, 'treated_voc': None}}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None, 'test_2': {'stability_type': None, 'passivating_molecule': None, 'humidity': None, 'temperature': 85.0, 'time': None, 'control_pce': None, 'treated_pce': 16.1, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.74}, 'test_1': {'stability_type': None, 'passivating_molecule': None, 'humidity': 65.0, 'temperature': None, 'time': 1200.0, 'control_pce': None, 'treated_pce': None, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.71}}
# {'perovskite_composition': 'MAPbI3', 'electron_transport_layer': 'TiO2', 'hole_transport_layer': '(BA)2(MA)n-1PbnI3n+1', 'stability_tests': [{'test_name': 'humidity', 'temperature': '65', 'time': '50', 'retained_proportion_cont': '0.29', 'retained_proportion_tret': '0.71', 'passivating_molecule': '(BA)2(MA)n-1PbnI3n+1', 'control_pce': '12.31', 'control_voc': '1.11', 'treated_pce': '16.13', 'treated_voc': '1.08'}, {'test_name': 'temperature', 'temperature': '85', 'time': '30', 'retained_proportion_cont': '0.15', 'retained_proportion_tret': '0.74', 'passivating_molecule': '(BA)2(MA)n-1PbnI3n+1', 'control_pce': '9.54', 'control_voc': '1.00', 'treated_pce': '13.15', 'treated_voc': '1.03'}, {'test_name': 'illumination', 'temperature': '25', 'humidity': '30', 'time': '96', 'retained_proportion_cont': None, 'retained_proportion_tret': None, 'passivating_molecule': '(BA)2(MA)n-1PbnI3n+1', 'control_pce': None, 'control_voc': None, 'treated_pce': '12.31', 'treated_voc': '1.11'}]}
# {'perovskite_composition': '(FAPbI3)0.77(MAPbBr3)0.14(CsPbI3)0.09', 'electron_transport_layer': None, 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': None, 'test_1': {'stability_type': None, 'passivating_molecule': 'fluorophenylethylammonium iodide', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': 17.6, 'treated_pce': 18.0, 'control_voc': 1.09, 'treated_voc': 1.08, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': '(FAPbI3)0.77 (MAPbBr3)0.14 (CsPbI3)0.09', 'electron_transport_layer': 'TiO2', 'hole_transport_layer': 'CuSCN', 'pin_nip_structure': 'NIP', 'test_1': {'test_name': 'ISOS-L', 'temperature': 407.0, 'humidity': None, 'retained_proportion_cont': None, 'retained_proportion_tret': '75.6', 'passivating_molecule': '2D perovskite', 'control_pce': 18.0, 'control_voc': 1130.0, 'treated_pce': 18.0, 'treated_voc': 1085.0}}
# {'perovskite_composition': None, 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None, 'test_1': {'stability_type': None, 'passivating_molecule': 'glycine hydrochloride', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': None, 'treated_pce': 23.6, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': None}}
# {'perovskite_composition': None, 'electron_transport_layer': 'C60', 'pin_nip_structure': 'NIP', 'hole_transport_layer': 'PTAA', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'humidity': 506.0, 'retained_proportion_cont': '0.89', 'retained_proportion_tret': '0.97', 'passivating_molecule': 'EDAI2', 'control_pce': 19.3, 'control_voc': 0.76, 'treated_pce': 21.7, 'treated_voc': 0.88}}
# {'perovskite_composition': 'Cs0.05(MA0.17FA0.83)0.95Pb(I0.83Br0.17)3', 'electron_transport_layer': None, 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': None, 'test_1': {'stability_type': 'ISOSLT', 'passivating_molecule': '4-fluoroaniline', 'humidity': None, 'temperature': None, 'time': 95.0, 'control_pce': 17.8, 'treated_pce': 20.4, 'control_voc': 1.02, 'treated_voc': 1.13, 'efficiency_control': None, 'efficiency_tret': 0.75, 'efficiency_cont': 0.5}}
# {'perovskite_composition': 'Cs0.05(MA0.17FA0.83)0.95Pb(I0.83Br0.17)3', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'humidity', 'temperature': 859.0, 'time': 66.0, 'humidity': 859.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '0.75', 'passivating_molecule': '4-fluoroaniline', 'control_pce': None, 'control_voc': None, 'treated_pce': 20.4, 'treated_voc': 1.14}}
# {'perovskite_composition': 'Cs0.05(MA0.05FA0.95)0.95Pb(I0.95Br0.05)3', 'electron_transport_layer': None, 'hole_transport_layer': None, 'structure_pin_nip': None, 'test_1': {'stability_type': None, 'passivating_molecule': 'ortho-carborane', 'humidity': 30.0, 'temperature': 40.0, 'time': 400.0, 'control_pce': None, 'treated_pce': 23.0, 'control_voc': None, 'treated_voc': 1.17, 'efficiency_control': None, 'efficiency_tret': 0.97, 'efficiency_cont': 0.89}}
# {'perovskite_composition': 'Cs0.05(FA0.05MA0.95)0.95Pb(I0.95Br0.05)3', 'electron_transport_layer': 'C60', 'hole_transport_layer': "2,2',7,7'-tetrakis(N,N-di(4-methoxyphenylamino)-9,9'-spirofluorene (BCP)", 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 26.0, 'time': 600.0, 'humidity': 304.0, 'retained_proportion_cont': '0.89', 'retained_proportion_tret': '0.97', 'passivating_molecule': 'CB-NH2', 'control_pce': 21.1, 'control_voc': 1.12, 'treated_pce': 23.0, 'treated_voc': 1.17}}
# {'perovskite_composition': 'formamidinium lead iodide', 'electron_transport_layer': None, 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'test_1': {'stability_type': 'ISOSD', 'passivating_molecule': 'carbazole-triphenylamine and phenylammonium iodide units', 'humidity': 85.0, 'temperature': 85.0, 'time': 1000.0, 'control_pce': 22.3, 'treated_pce': None, 'control_voc': None, 'treated_voc': 1.11, 'efficiency_control': None, 'efficiency_tret': 0.92}, 'test_2': {'stability_type': 'ISOSLT', 'passivating_molecule': None, 'humidity': None, 'temperature': None, 'time': 1100.0, 'control_pce': None, 'treated_pce': 24.7, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.94, 'efficiency_cont': 0.66}}
# {'perovskite_composition': 'FAPbI3', 'electron_transport_layer': 'Spiro-OMeTAD', 'hole_transport_layer': 'P3HT', 'pin_nip_structure': 'NIP', 'stability_tests': [{'test_name': 'ISOS-L', 'temperature': '85', 'humidity': '85', 'retained_proportion_cont': '66.6', 'retained_proportion_tret': '94.6', 'passivating_molecule': 'CBz-PAI', 'control_pce': '22.3', 'control_voc': '1.112', 'treated_pce': '24.7', 'treated_voc': '1.161'}]}
# {'perovskite_composition': 'Cs0.05FA0.85MA0.10Pb(I0.97Br0.03)3', 'electron_transport_layer': None, 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'test_1_2': {'stability_type': 'ISOSLT', 'passivating_molecule': 'phenylethylammonium iodide', 'humidity': 507.0, 'temperature': None, 'time': 500.0, 'control_pce': None, 'treated_pce': 0.84, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': None, 'efficiency_cont': 0.7}, 'test_1': {'stability_type': None, 'passivating_molecule': '4-tert-butyl-benzylammonium iodide', 'humidity': None, 'temperature': None, 'time': None, 'control_pce': 21.2, 'treated_pce': 22.7, 'control_voc': 1.09, 'treated_voc': 1.12, 'efficiency_control': None, 'efficiency_tret': 0.95}}
# {'perovskite_composition': 'Cs0.05 FA0.85 MA0.10 Pb(I0.97 Br0.03)3 with 5% excess of PbI2', 'electron_transport_layer': 'TiO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-LT', 'temperature': 25.0, 'time': 500.0, 'humidity': 507.0, 'retained_proportion_cont': None, 'retained_proportion_tret': '95', 'passivating_molecule': '4-tert-butyl-benzylammonium iodide', 'control_pce': 24.0, 'control_voc': 1.08, 'treated_pce': 25.1, 'treated_voc': 1.14}}
# {'perovskite_composition': 'FA0.7MA0.3Pb0.5Sn0.5I3', 'electron_transport_layer': 'buckminsterfullerene', 'hole_transport_layer': None, 'structure_pin_nip': None, 'test_1': {'stability_type': 'ISOSLT', 'passivating_molecule': '4-trifluoromethyl-phenylammonium', 'humidity': 305.0, 'temperature': 35.0, 'time': 600.0, 'control_pce': None, 'treated_pce': 26.4, 'control_voc': None, 'treated_voc': None, 'efficiency_control': None, 'efficiency_tret': 0.9}}
# {'perovskite_composition': 'FA0.8Cs0.2Pb0.5Sn0.5I3', 'electron_transport_layer': 'C60', 'hole_transport_layer': 'VNPB', 'pin_nip_structure': 'PIN', 'test_1': {'test_name': 'ISOS-L', 'temperature': 25.0, 'humidity': 305.0, 'retained_proportion_cont': '0.9', 'retained_proportion_tret': '0.96', 'passivating_molecule': '4-trifluoromethyl-phenylammonium', 'control_pce': 24.3, 'control_voc': 1.08, 'treated_pce': 25.6, 'treated_voc': 2.03}}

# %%
evaluate_df["annotation"][6]
# Out:
# {'perovskite_composition': 'Methylammonium Lead Iodide',
#  'electron_transport_layer': 'Titanium dioxide',
#  'hole_transport_layer': 'Spiro-OMeTAD',
#  'structure_pin_nip': None,
#  'test_1': {'stability_type': 'ISOSD',
#   'passivating_molecule': 'phenylethylammonium iodide',
#   'humidity': None,
#   'temperature': None,
#   'time': 1344.0,
#   'control_pce': None,
#   'treated_pce': 18.8,
#   'control_voc': None,
#   'treated_voc': 1.16,
#   'efficiency_control': None,
#   'efficiency_tret': 0.97}}

# %%
evaluate_df["extracted"][1]
# Out:
# {'perovskite_composition': 'FA1-x MAx PbI3 (FA: HC(NH2)2; MA: CH3NH3)',
#  'electron_transport_layer': 'SnO2',
#  'hole_transport_layer': 'spiro-OMeTAD',
#  'pin_nip_structure': 'PIN',
#  'test_1': {'test_name': 'ISOS-L',
#   'temperature': 85.0,
#   'time': 500.0,
#   'humidity': 25.0,
#   'retained_proportion_cont': '20',
#   'retained_proportion_tret': '40',
#   'passivating_molecule': 'phenethylammonium iodide (PEAI)',
#   'control_pce': 21.2,
#   'control_voc': 1.12,
#   'treated_pce': 23.3,
#   'treated_voc': 1.18}}

# %% [markdown]
# ## Evaluation
#
# - We need precision and recall for EACH variable
# - For each variable, calculate the F1 score - There is F1 score for each variable
# - Take a weighted average ***For now, just take the average.

# %%
def tests_comparison(stability_annotated, label_dict, stability_extracted, extract_dict):
    # print(stability_annotated, label_dict, stability_extracted, extract_dict)
    stability_entity_annotated = ['stability_type', 'passivating_molecule', 'temperature', 'time', 'humidity', 'efficiency_cont', 'efficiency_tret', 'control_pce', 'treated_pce', 'control_voc', 'treated_voc']
    stability_entity_extracted = ['test_name', 'passivating_molecule', 'temperature', 'time', 'humidity', 'control_efficiency', 'treatment_efficiency', 'control_pce', 'treated_pce', 'control_voc', 'treated_voc']
    
    compared_metric = []
    numeric_data_annotated = []
    numeric_data_extracted = []
    for entity_i in range(len(stability_entity_annotated)):
        if entity_i <= 1:
            if stability_entity_extracted[entity_i] not in extract_dict.keys():
                extract_dict[stability_entity_extracted[entity_i]] = None

            if (label_dict[stability_entity_annotated[entity_i]] == None) | (extract_dict[stability_entity_extracted[entity_i]] == None):
                compared_metric.append(None)
            else:
                ##Text entity, perform Sequence Matcher 
                compared = SequenceMatcher(None, label_dict[stability_entity_annotated[entity_i]], extract_dict[stability_entity_extracted[entity_i]]).ratio()
                # print(compared)
                if entity_i == 0:
                    if compared > 0.9:
                        compared_metric.append(1)
                    else:
                        compared_metric.append(0)
                else:
                    compared_metric.append(compared)
        else:
            if stability_entity_extracted[entity_i] not in extract_dict.keys():
                extract_dict[stability_entity_extracted[entity_i]] = 0
            elif extract_dict[stability_entity_extracted[entity_i]] == None:
                extract_dict[stability_entity_extracted[entity_i]] = 0

            if stability_entity_annotated[entity_i] not in label_dict.keys():
                label_dict[stability_entity_annotated[entity_i]] = 0
            elif label_dict[stability_entity_annotated[entity_i]] == None:
                label_dict[stability_entity_annotated[entity_i]] = 0

                
            numeric_data_annotated.append(label_dict[stability_entity_annotated[entity_i]])
            numeric_data_extracted.append(extract_dict[stability_entity_extracted[entity_i]])

    if isinstance(numeric_data_extracted[0], list):
        ##There was one column with two temperature recorded as a list (probably thermal cycling)
        numeric_data_extracted[0] = numeric_data_extracted[0][1]
    cos_sim = cosine_similarity([numeric_data_annotated], [numeric_data_extracted])
    compared_metric.append(cos_sim[0][0])
    
    return compared_metric

# %%
def entity_comparison(entity, label, extracted_dict, text_similarity_threshold = 0.75, numerical_tolerance = 0.027):
    '''
    The tolarance of 2.7% was what was reasonable looking at the absolute difference
    treated_voc 1.18, 1.149, absolute difference 0.026271186440677895

    The text similarity were set to 75% due to the structure example
    FP, NIP, n-i-p, 0.75
    This should be positive
    
    '''
    text_entity = ['stability_type', 'passivating_molecule']
    numerical_entity = ['temperature', 'time', 'humidity','efficiency_cont', 'efficiency_tret', 'control_pce', 'treated_pce', 'control_voc', 'treated_voc']

    if entity in text_entity:
        key_to_check = "test_name" if entity == "stability_type" else entity

        # If the key is missing in the extracted annotation, return False Negative
        if (label[entity]!=None) & (extracted_dict[key_to_check]==None):
            # print(f"FN, {label_annotation[id]}, {extraction_annotation[key_to_check]}")
            return "FN"
        elif (label[entity]==None) & (extracted_dict[key_to_check]!=None):
            # print(f"TN, {label_annotation[id]}, {extraction_annotation[key_to_check]}")
            return "TN"

        label_data = label.get(entity, "")
        extract_data = extracted_dict.get(key_to_check, "")

        # Convert lists to strings if necessary
        if isinstance(label_data, list):
            label_data = " ".join(map(str, label_data))  # Convert list to string
        if isinstance(extract_data, list):
            extract_data = " ".join(map(str, extract_data))  # Convert list to string

        # Ensure values are strings
        if not isinstance(label_data, str) or not isinstance(extract_data, str):
            # print(f"FP, {label_annotation[id]}, {extraction_annotation[key_to_check]}")
            return "FP"  # If data is still not a string, return False Positive

        # Compute similarity score
        similarity = SequenceMatcher(None, label_data.lower(), extract_data.lower()).ratio()

        if similarity > text_similarity_threshold:
            # print(f"TP,{entity} {label_data}, {extract_data}")
            return 'TP'
        else:
            # print(f"FP,{entity} {label_data}, {extract_data}, {similarity}")
            return "FP"
    else:
        # key_to_check = "control_efficiency" if entity == "efficiency_cont" else ("treatment_efficiency" if entity == "efficiency_tret" else entity)

        # print(f"annotated{label[entity]}")
        # print(f"extracted{extracted_dict[entity]}")
        if entity not in extracted_dict:
            return "FN"
        if extracted_dict[entity] == None:
            extracted_dict[entity] = 0

        # If the key is missing in the extracted annotation, return False Negative
        if (label[entity]!=0) & ((extracted_dict[entity]==0) | (entity not in extracted_dict.keys())):
            # print(f"FN, {label_annotation[id]}, {extraction_annotation[entity]}")
            return "FN"
        elif (label[entity]==0) & (extracted_dict[entity]!=0):
            # print(f"TN, {label_annotation[id]}, {extraction_annotation[entity]}")
            return "TN"
        elif (label[entity]==0) & (extracted_dict[entity]==0):
            # print(f"TN, {label_annotation[id]}, {extraction_annotation[entity]}")
            return "TN"


        if isinstance(extracted_dict[entity], list):
            ##There was one column with two temperature recorded as a list (probably thermal cycling)
            extracted_dict[entity] = extracted_dict[entity][1]

        # Apply numerical tolerance check
        if (abs(label[entity] - extracted_dict[entity])) / (abs(label[entity]) )<= numerical_tolerance:

            # print(f"Numerical differences matched: {entity} {label[entity]}, {extracted_dict[entity]}, absolute difference {(abs(label[entity] - extracted_dict[entity])) / (abs(label[entity]) )}")
            return "TP"  # True Positive: Correct numerical extraction
        else:

            # print(f"Numerical differences no match: {entity}, {label[entity]}, {extracted_dict[entity]}, absolute difference {(abs(label[entity] - extracted_dict[entity])) / (abs(label[entity]) )}")
            return "FP"  # False Positive: Incorrect numerical extraction

# %%
def safe_division(numerator, denominator):
    """Returns division result, or 0 if the denominator is zero."""
    return numerator / denominator if denominator != 0 else 0

# %%
def text_comparison(id, label_annotation, extraction_annotation, text_similarity_threshold=0.8):
    """Compares text values using string similarity matching.
    - THE 4 basic variable that is to compare is PEROVSKITE COMPOSITION, ETL, HTL, STRUCTURE
    """

    # Handle special case for structure_pin_nip
    # key_to_check = "pin_nip_structure" if id == "structure_pin_nip" else id

    # If the key is missing in the extracted annotation, return False Negative
    # if (label_annotation[id]!=None) & (extraction_annotation[id]==None):
    #     # print(f"FN, {label_annotation[id]}, {extraction_annotation[key_to_check]}")
    #     return "FN"}
    if id not in extraction_annotation:
        return "FP"
    elif (label_annotation[id]==None) & (extraction_annotation[id]!=None):
        # print(f"TN, {label_annotation[id]}, {extraction_annotation[key_to_check]}")
        return "TN"

    label_data = label_annotation.get(id, "")
    if id == 'electron_transport_layer' and label_data == "buckminsterfullerene":
        label_data = 'C60'
    extract_data = extraction_annotation.get(id, "")

    # Convert lists to strings if necessary
    if isinstance(label_data, list):
        label_data = " ".join(map(str, label_data))  # Convert list to string
    if isinstance(extract_data, list):
        extract_data = " ".join(map(str, extract_data))  # Convert list to string

    # Ensure values are strings
    if not isinstance(label_data, str) or not isinstance(extract_data, str):
        # print(f"FP, {label_annotation[id]}, {extraction_annotation[id]}")
        return "FP"  # If data is still not a string, return False Positive

    # Compute similarity score
    similarity = SequenceMatcher(None, label_data.lower(), extract_data.lower()).ratio()

    if similarity > text_similarity_threshold:
        # print(f"TP, {label_data}, {extract_data}, {similarity}")
        return 'TP'
    else:
        # print(f"FP, {label_data}, {extract_data}, {similarity}")
        return "FP"

# %%
def compare_json(df):
    """
    Compare labeled and extracted JSON data for correctness.

    TP: Correct value extracted by LLM.
    FN: LLM didn't extract this variable.
    FP: LLM extracted a value, but it was incorrect.
    TN: LLM halucinated and returned value that was not extracted
    """
    
    text_variables = ['perovskite_composition', 'electron_transport_layer', 'hole_transport_layer', 'structure_pin_nip']

    
    stability_entity_annotated = ['stability_type', 'temperature', 'time', 'humidity', 'passivating_molecule', 'efficiency_cont', 'efficiency_tret', 'control_pce', 'treated_pce', 'control_voc', 'treated_voc']
    stability_entity_extracted = ['test_name', 'temperature', 'time', 'humidity', 'passivating_molecule','control_efficiency', 'treatment_efficiency', 'control_pce', 'treated_pce', 'control_voc', 'treated_voc']
    
    # Initialize comparison dictionaries
    text_dict = {var: {"TP": 0, "FP": 0, "FN": 0, "TN": 0} for var in text_variables}
    stability_dict = {var: {"TP": 0, "FP": 0, "FN": 0, "TN": 0} for var in stability_entity_annotated}

    for row in df.itertuples():       
        label_value = row.annotation
        extracted_value = row.extracted

        # print(label_value)
        # print(extracted_value)

        for id, label in label_value.items():
            if ('test' in id) and (isinstance(label_value[id], dict)):
                ##Plan for stability test evaluation
                '''
                For each stability condition in annotation, 
                    Pair them with stability condition in extracted
                        With stability of annotation and extraction, use function tests_comparison that returns how similar 2 stabilities are
                    
                Once all the pair is calculated, find the stability name of extraction that was closest to annotation stability. 

                Using this dictionary, we will increment FN, FP, TN, TP for each element of the entity.
                '''
                matched = 0
                stability_match = {}
                for extract_id, extract_label in extracted_value.items():
                    if ('test' in extract_id) and (isinstance(extracted_value[extract_id], dict)):
                        matched += 1
                        match_list = tests_comparison(id, label, extract_id, extract_label)
                        match_list = [0 if item is None else item for item in match_list]
                        # print(extracted_value[extract_id])
                        # print(match_list)
                        stability_match[extract_id] = match_list
        
                if matched == 0:
                    #No stability were extracted, we will add stability_unmatched
                        ##We need to account for if there was NO stability extracted. 
                    for key in stability_dict:
                        if 'FN' in stability_dict[key]:
                            stability_dict[key]['FN'] += 1
                else:
                    stability_match_mean = {stability: np.mean(lis) for stability, lis in stability_match.items()}
                    max_key = max(stability_match_mean, key=stability_match_mean.get)  
                    # print(extracted_value[max_key])
                    ##Now, I need to compare each entity in that found max_key and fill in that FN, dictionary.
                    for entity in label_value[id].keys():
                        if entity == 'efficiency_control':
                            continue
                        entity_result = entity_comparison(entity, label, extracted_value[max_key])
                        stability_dict[entity][entity_result] += 1  
            else:  
                result = text_comparison(id, label_value, extracted_value)
                text_dict[id][result] += 1


    # Merge all results
    combined_dict = {**text_dict, **stability_dict}
    # print("Performance for each variable in dictionary:", combined_dict)

    # Compute precision, recall, and F1-score
    variable_list, precision_list, recall_list, f1_list = [], [], [], []
    for variable, performance in combined_dict.items():
        TP, FP, FN = performance["TP"], performance["FP"], performance["FN"]
        
        precision = safe_division(TP, TP + FP)
        recall = safe_division(TP, TP + FN)
        f1 = safe_division(2 * precision * recall, precision + recall)

        variable_list.append(variable)
        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)

    return combined_dict, variable_list, precision_list, recall_list, f1_list

# %%
dict_result, variables, precisions, recalls, f1s = compare_json(evaluate_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 dict_result, variables, precisions, recalls, f1s = compare_json(evaluate_df)
#
# Cell In[30], line 45, in compare_json(df)
#      43 if ('test' in extract_id) and (isinstance(extracted_value[extract_id], dict)):
#      44     matched += 1
# ---> 45     match_list = tests_comparison(id, label, extract_id, extract_label)
#      46     match_list = [0 if item is None else item for item in match_list]
#      47     # print(extracted_value[extract_id])
#      48     # print(match_list)
#
# Cell In[18], line 45, in tests_comparison(stability_annotated, label_dict, stability_extracted, extract_dict)
#      42 if isinstance(numeric_data_extracted[0], list):
#      43     ##There was one column with two temperature recorded as a list (probably thermal cycling)
#      44     numeric_data_extracted[0] = numeric_data_extracted[0][1]
# ---> 45 cos_sim = cosine_similarity([numeric_data_annotated], [numeric_data_extracted])
#      46 compared_metric.append(cos_sim[0][0])
#      48 return compared_metric
#
# File ~/DSC180_B11_Q2/mykernel/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/DSC180_B11_Q2/mykernel/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:1679, in cosine_similarity(X, Y, dense_output)
#    1635 """Compute cosine similarity between samples in X and Y.
#    1636
#    1637 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1675        [0.57..., 0.81...]])
#    1676 """
#    1677 # to avoid recursive import
# -> 1679 X, Y = check_pairwise_arrays(X, Y)
#    1681 X_normalized = normalize(X, copy=True)
#    1682 if X is Y:
#
# File ~/DSC180_B11_Q2/mykernel/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:194, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, ensure_2d, copy)
#     184 else:
#     185     X = check_array(
#     186         X,
#     187         accept_sparse=accept_sparse,
#    (...)
#     192         ensure_2d=ensure_2d,
#     193     )
# --> 194     Y = check_array(
#     195         Y,
#     196         accept_sparse=accept_sparse,
#     197         dtype=dtype,
#     198         copy=copy,
#     199         force_all_finite=force_all_finite,
#     200         estimator=estimator,
#     201         ensure_2d=ensure_2d,
#     202     )
#     204 if precomputed:
#     205     if X.shape[1] != Y.shape[0]:
#
# File ~/DSC180_B11_Q2/mykernel/lib/python3.11/site-packages/sklearn/utils/validation.py:1012, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1010         array = xp.astype(array, dtype, copy=False)
#    1011     else:
# -> 1012         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1013 except ComplexWarning as complex_warning:
#    1014     raise ValueError(
#    1015         "Complex data not supported\n{}\n".format(array)
#    1016     ) from complex_warning
#
# File ~/DSC180_B11_Q2/mykernel/lib/python3.11/site-packages/sklearn/utils/_array_api.py:745, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     743     array = numpy.array(array, order=order, dtype=dtype)
#     744 else:
# --> 745     array = numpy.asarray(array, order=order, dtype=dtype)
#     747 # At this point array is a NumPy ndarray. We convert it to an array
#     748 # container that is consistent with the input's namespace.
#     749 return xp.asarray(array)
#
# ValueError: could not convert string to float: np.str_('20-30')

# %%
dict_result
# Out:
# {'perovskite_composition': {'TP': 39, 'FP': 52, 'FN': 1, 'TN': 35},
#  'electron_transport_layer': {'TP': 11, 'FP': 62, 'FN': 3, 'TN': 51},
#  'hole_transport_layer': {'TP': 34, 'FP': 44, 'FN': 6, 'TN': 43},
#  'structure_pin_nip': {'TP': 35, 'FP': 48, 'FN': 11, 'TN': 33},
#  'stability_type': {'TP': 0, 'FP': 51, 'FN': 142, 'TN': 0},
#  'temperature': {'TP': 62, 'FP': 33, 'FN': 20, 'TN': 78},
#  'time': {'TP': 74, 'FP': 48, 'FN': 31, 'TN': 40},
#  'humidity': {'TP': 34, 'FP': 13, 'FN': 32, 'TN': 114},
#  'passivating_molecule': {'TP': 13, 'FP': 68, 'FN': 17, 'TN': 95},
#  'efficiency_cont': {'TP': 12, 'FP': 48, 'FN': 27, 'TN': 106},
#  'efficiency_tret': {'TP': 39, 'FP': 63, 'FN': 66, 'TN': 25},
#  'control_pce': {'TP': 22, 'FP': 29, 'FN': 18, 'TN': 124},
#  'treated_pce': {'TP': 66, 'FP': 34, 'FN': 25, 'TN': 68},
#  'control_voc': {'TP': 22, 'FP': 5, 'FN': 16, 'TN': 150},
#  'treated_voc': {'TP': 49, 'FP': 8, 'FN': 18, 'TN': 118}}

# %% [markdown]
# ## Calculate Macro f1 score

# %%
def macro_f1(f1_list, weight = None):
    if weight == None:
        #If no weight given, do unweighted average of f1 score
        return sum(f1_list) / len(f1_list)
    total_f1 = 0
    for i in range(len(f1_list)):
        total_f1 += (f1_list[i] * weight[i])
    return total_f1 / sum(weight)

# %%
variables
# Out:
# ['perovskite_composition',
#  'electron_transport_layer',
#  'hole_transport_layer',
#  'structure_pin_nip',
#  'stability_type',
#  'temperature',
#  'time',
#  'humidity',
#  'passivating_molecule',
#  'efficiency_cont',
#  'efficiency_tret',
#  'control_pce',
#  'treated_pce',
#  'control_voc',
#  'treated_voc']

# %%
weight_dict = {key: None for key in variables}
weight_dict['treated_pce'] = 2
weight_dict['efficiency_tret'] = 2
weight_dict['passivating_molecule'] = 1.7


weight_dict
# Out:
# {'perovskite_composition': None,
#  'electron_transport_layer': None,
#  'hole_transport_layer': None,
#  'structure_pin_nip': None,
#  'stability_type': None,
#  'temperature': None,
#  'time': None,
#  'humidity': None,
#  'passivating_molecule': 1.7,
#  'efficiency_cont': None,
#  'efficiency_tret': 2,
#  'control_pce': None,
#  'treated_pce': 2,
#  'control_voc': None,
#  'treated_voc': None}

# %%
f1s
# Out:
# [0.5954198473282443,
#  0.2528735632183908,
#  0.5762711864406781,
#  0.5426356589147286,
#  0,
#  0.7005649717514124,
#  0.6519823788546255,
#  0.6017699115044248,
#  0.2342342342342342,
#  0.24242424242424246,
#  0.37681159420289856,
#  0.4835164835164835,
#  0.6910994764397906,
#  0.6769230769230768,
#  0.7903225806451613]

# %%
weights = [1, 0.5, 0.5, 1, 1.5, 0.3, 0.5]

# %%
## The macro f1 score unweighted
macro_f1(f1s)
# Out:
# 0.49445661375989286

# %% [markdown]
# ### This concludes the pipeline of evaluating extraction quality
