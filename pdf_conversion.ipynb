# %%
import os
import requests

# %%
grobid_url = "http://localhost:8070/api/processFulltextDocument"
xml_names = os.listdir("data/xmls")

for pdf_file in os.listdir("data/pdfs"):
    #only looks at pdf files
    if pdf_file.endswith(".pdf"):
        pdf_path = os.path.join("data/pdfs", pdf_file)
        #doe not convert already converted files
        if pdf_path.replace('.pdf', '.xml') in xml_names:
            continue
        with open(pdf_path, 'rb') as file:
            #GROBID must be running on port 8070 for this to work
            response = requests.post(
                grobid_url,
                files={'input': file},
                headers={'Accept': 'application/xml'}
            )

            if response.status_code == 200:
                xml_file_path = os.path.join('data/xmls', pdf_file.replace('.pdf', '.xml'))
                with open(xml_file_path, 'w', encoding='utf-8') as xml_file:
                    xml_file.write(response.text)
            else:
                print(f"Failed to convert {pdf_file}. Status code: {response.status_code}")
                print(response.text)
# Out:
# Failed to convert 1293_4.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 1300_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 1305_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 1313_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 1873_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 1886_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 2107_3.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 3306_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 3307_3.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 3314_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 3333_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 3642_4.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 3649_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 3654_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 3662_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 3676_1.pdf. Status code: 500
# [BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1
# Failed to convert 4222_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 4235_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 4263_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 4456_3.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 448_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 449_3.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 456_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 475_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 5502_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 5503_3.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 5510_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 5529_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 5838_4.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 5845_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 5850_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 5858_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 6394_2.pdf. Status code: 500
# [BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1
# Failed to convert 6687_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 6688_3.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 6695_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 6714_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 7023_4.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 7030_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 7035_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 7043_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 7637_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 7638_3.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 7645_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 7664_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 781_2.pdf. Status code: 500
# [BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1
# Failed to convert 7973_4.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 7980_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 7985_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 7993_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 8573_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 8574_3.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 8581_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 8600_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 8909_4.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 8911_1.pdf. Status code: 500
# [BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1
# Failed to convert 8916_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 8921_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 8929_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 957_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 958_3.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 965_2.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
# Failed to convert 984_1.pdf. Status code: 500
# [NO_BLOCKS] PDF parsing resulted in empty content
