# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from difflib import SequenceMatcher
import numpy as np
import json
import os
import xml.etree.ElementTree as ET 
import pandas as pd

# %% [markdown]
# ## This file compares the teamtat annotation (Json) with Extraction performed by finetuned llama (Json)

# %%
label = {'passivating_molecule': 'phenethylammonium iodide', 'perovskite_composition': 'MAPbI3', 'ISOSD1': {'time': '240', 'treated_pce': '15.3', 'control_pce': '16.69', 'temperature': '25', 'humidity': '90', 'control_voc': '1.03', 'treated_voc': '1.06'}, 'electron_transport_layer': 'TiO2', 'hole_transport_layer': 'Spiro-OMeTAD'}

# %%
extraction = {
  "control_pce": None,
  "control_voc": None,
  "treated_pce": 15.3,
  "treated_voc": 1.06,
  "passivating_molecule": "Phenylethylammonium (PEA)",
  "perovskite_composition": "[C8H9NH3]2[(CH3NH3)2PbI3 – (n=60)]",
  "electron_transport_layer": "TiO2",
  "hole_transport_layer": "spiro-OMeTAD",
  "ISOS-L-1": None,
  "ISOS-L-2": None,
  "ISOS-T-1": None,
  "ISOS-T-2": None,
  "ISOS-LC": None,
  "ISOS-D-1": None,
  "ISOS-D-2": None
}

# %%
def compare_data(labeled_data, extracted_data, numerical_tolerance=0.05):
    results = {}
    total_fields = len(labeled_data)
    matched_fields = 0
    numerical_differences = []

    for key, value in labeled_data.items():
        if key in extracted_data:
            extracted_value = extracted_data[key]

            # Exact match
            if value == extracted_value:
                matched_fields += 1
                results[key] = "Match"

            # Numerical comparison
            elif isinstance(value, (int, float)) and isinstance(extracted_value, (int, float)):
                if abs(value - extracted_value) <= numerical_tolerance * abs(value):
                    matched_fields += 1
                    numerical_differences.append(abs(value - extracted_value))
                    results[key] = "Numerical Match"
                else:
                    results[key] = "Numerical Mismatch"

            # Fuzzy string match
            elif isinstance(value, str) and isinstance(extracted_value, str):
                similarity = SequenceMatcher(None, value.lower(), extracted_value.lower()).ratio()
                if similarity > 0.8:  # Threshold for similarity
                    matched_fields += 1
                    results[key] = f"Fuzzy Match ({similarity:.2f})"
                else:
                    results[key] = f"Mismatch ({similarity:.2f})"

            else:
                results[key] = "Mismatch"
        else:
            results[key] = "Missing in Extracted Data"

    accuracy = matched_fields / total_fields
    mean_absolute_error = np.mean(numerical_differences) if numerical_differences else None

    return {
        "results": results,
        "accuracy": accuracy,
        "mean_absolute_error": mean_absolute_error,
        "matched_fields": matched_fields,
        "total_fields": total_fields
    }

# %%
comparison_result = compare_data(label, extraction)
print(comparison_result)
# Out:
# {'results': {'passivating_molecule': 'Mismatch (0.78)', 'perovskite_composition': 'Mismatch (0.20)', 'ISOSD1': 'Missing in Extracted Data', 'electron_transport_layer': 'Match', 'hole_transport_layer': 'Fuzzy Match (1.00)'}, 'accuracy': 0.4, 'mean_absolute_error': None, 'matched_fields': 2, 'total_fields': 5}

# %% [markdown]
# ## Retrieving teamtat label

# %%
def parse_bioc(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    
    data = { }
    concept_ids = set()
    relations = {}
    for relation in root.findall(".//relation"):
        test_name = relation.find("infon[@key='type']").text
        node_ids = [node.get("refid") for node in relation.findall("node")]
        for node_id in node_ids:
            relations[node_id] = test_name

    for annotation in root.findall(".//annotation"):
        node_id = annotation.get("id")
        var_name = annotation.find("infon[@key='type']").text
        concept_id = annotation.find("infon[@key='identifier']").text
        value = annotation.find("text").text
        if node_id in relations:
            stability_test = relations[node_id]
            if stability_test not in data:
                data[stability_test] = {}
            if concept_id is None:
                concept_id = value
            data[stability_test][var_name] = concept_id
            concept_ids.add(concept_id)

        if concept_id is None:
            concept_id = value
        if concept_id in concept_ids: # duplicate annotation
            continue
        concept_ids.add(concept_id)
        if var_name not in data:
            data[var_name] = concept_id
        else:
            if isinstance(data[var_name], list):
                data[var_name].append(value)
            else:
                data[var_name] = [data[var_name], value]
    
    return data

# %%
def extract_papernum(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    first_text = root.find(".//text")
    full_text = first_text.text
    
    ##We want to extract article number from this format
    #Method: split by spaces and extract the last element in the list
    text_list = full_text.split()
    paper_num = text_list[-1]
    return paper_num

# %%
## See if we can extract the paper number correctly
bioc_dir = "../data/biocs"
for filename in os.listdir(bioc_dir):
    if filename.endswith(".xml"):
        file_path = os.path.join(bioc_dir, filename)
        paper_num = extract_papernum(file_path)

# %%
bioc_dir = "../data/biocs"
label_data = {}
for filename in os.listdir(bioc_dir):
    if filename.endswith(".xml"):
        file_path = os.path.join(bioc_dir, filename)
        paper_num = extract_papernum(file_path)
        row = parse_bioc(file_path)
        if len(row.keys()) > 0:
            label_data[paper_num] = row

print(label_data)   
print(f"There are {len(label_data)} annotated papers")
# Out:
# {'19': {'ISOSL3': {'temperature': '85', 'humidity': '50', 'time': '1560', 'treated_pce': '23.3', 'control_pce': '21', 'control_voc': '1.269', 'treated_voc': '1.271'}, 'perovskite_composition': ['Cs 0.05 MA 0.05 FA 0.9 Pb(I 0.95 Br 0.05 ) 3', 'Cs 0.05 MA 0.15 FA 0.8 PbI 3'], 'passivating_molecule': '3,4,5-trifluoroanilinium', 'hole_transport_layer': '2PACz', 'efficiency_tret': '84', 'electron_transport_layer': 'C60', 'structure_pin_nip': 'PIN'}, '84': {'structure_pin_nip': 'NIP', 'hole_transport_layer': ['Spiro-OMeTAD', 'fluorene-terminated hole-transporting material'], 'ISOST2': {'efficiency_tret': 'ISOS-T2', 'time': 'ISOS-T2', 'temperature': 'ISOS-T2'}, 'perovskite_composition': 'FAPbI 3 ) 0.95 (MAPbBr 3 ) 0.05', 'electron_transport_layer': 'mp-TIO2', 'ISOSL1': {'efficiency_tret': 'ISOS-L1', 'time': 'ISOS-L1'}, 'ISOSD1': {'efficiency_tret': 'ISOS-D1', 'time': 'ISOS-D1', 'temperature': 'ISOS-D1'}}, '56': {'treated_pce': '25.5%', 'perovskite_composition': 'FA 0.83 Cs 0.17 Pb 0.5 Sn 0.5 I 3', 'hole_transport_layer': 'PEDOT:PSS', 'electron_transport_layer': 'evaporated C 60 (30 nm) and bathocuproine (BCP) (8 nm),with a copper (Cu) electrode on top'}, '82': {'structure_pin_nip': 'PIN', 'treated_voc': 'QAHs', 'treated_pce_peak': 'QUAs', 'perovskite_composition': ['PCBM', 'choline chloride', 'FA 0.85 MA 0.15 Pb(I 0.85 Br 0.15 ) 3'], 'treated_voc_peak': ['L-α-phosphatidylcholine', '16.1 ± 1.1%'], 'treated_pce': 'Cl-ChloridepassibatedFA0.85MA0.15Pb(I0.85Br0.15)3', 'ISOSD1': {'temperature': 'ISOS-D1', 'humidity': 'ISOS-D1', 'efficiency_tret': 'ISOS-D1', 'efficiency_cont': 'ISOS-D1', 'time': 'ISOS-D1'}, 'ISOSL1': {'treated_pce': 'ISOS-L1', 'efficiency_tret': 'ISOS-L1', 'time': 'ISOS-L1'}}, '55': {'passivating_molecule': 'methylammonium lead iodide'}, '88': {'ISOSL1': {'treated_pce': 'ISOS-L1', 'time': 'ISOS-L1', 'efficiency_tret': 'ISOS-L1'}, 'perovskite_composition': 'triple cation perovskite', 'treated_pce': 'CsFAMA-F', 'control_pce': 'CsMAFA', 'ISOSL3': {'treated_pce': 'ISOS-L3', 'time': 'ISOS-L3'}, 'ISOST2': {'efficiency_tret': 'ISOS-T2', 'temperature': 'ISOS-T2', 'time': 'ISOS-T2', 'efficiency_cont': 'ISOS-T2'}, 'ISOSD1': {'efficiency_tret': 'ISOS-D1', 'time': 'ISOS-D1'}}, '92': {'electron_transport_layer': 'BaSnO3', 'structure_pin_nip': 'NIP', 'treated_pce': '21.3', 'ISOSD1': {'time': 'ISOS-D-1', 'humidity': 'ISOS-D-1', 'efficiency_cont': 'ISOS-D-1', 'efficiency_tret': 'ISOS-D-1'}, 'hole_transport_layer': ['Spiro-OMeTAD', 'PTAA']}, '5': {'structure_pin_nip': 'NIP', 'perovskite_molecule': 'iso-butylammonium', 'electron_transport_layer': ['C60', 'C 60'], 'perovskite_composition': 'FA(MA)PbI 3', 'hole_transport_layer': 'Spiro-OMeTAD', 'treated_voc': '1.135', 'treated_pce': '22.1'}, '18': {'perovskite_composition': '2-thiophenemethylammonium iodide', 'passivating_molecule': 'phenylethylammonium iodide', 'structure_pin_nip': 'NIP', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD'}, '9': {'perovskite_molecule': 'diammonium iodide', 'perovskite_composition': 'CH3NH3PbI3', 'electron_transport_layer': ['NiO', 'PCBM'], 'structure_pin_nip': 'PIN', 'treated_pce': '17.60', 'control_pce_peak': '14.64', 'control_voc': '1.08', 'treated_voc': '1.10'}, '13': {'passivating_molecule': '2-thiopheneethylammonium chloride', 'ISOSL2': {'control_voc': '1.29', 'treated_pce': '23.8', 'temperature': '60', 'efficiency_tret': '0.92', 'efficiency_cont': '0.82', 'control_pce': '15.1', 'treated_voc': '2.1'}, 'time': '265', 'electron_transport_layer': 'PCBM', 'perovskite_composition': 'Cs 0.12 FA 0.8 MA 0.08 PbI 1.8 Br 1.2', 'structure_pin_nip': 'PIN', 'hole_transport_layer': ['2PACz', 'PTAA']}, '86': {'electron_transport_layer': ['E-SnO2', 'SnO 2'], 'hole_transport_layer': 'Spiro-OMeTAD', 'treated_pce': 'Tin', 'ISOSD1': {'efficiency_tret': 'ISOS-D1', 'time': 'ISOS-D1', 'efficiency_cont': 'ISOS-D1'}, 'ISOSL1': {'time': 'ISOS-L1', 'efficiency_tret': 'ISOS-L1', 'efficiency_cont': 'ISOS-L1'}}, '80': {'perovskite_composition': 'PMMA', 'struct ...
# There are 54 annotated papers

# %% [markdown]
# ### Remove journal_publication and date_published key from teamtat since xml file didn't mentioned them.

# %%
def take_out_keys(json_obj, keys_to_remove):
    ##This function will be irrelevant Hopefully after we have markdown text to annotate and have publication info in the text
    if isinstance(json_obj, dict):
        # Process dictionaries
        return {
            key: take_out_keys(value, keys_to_remove)
            for key, value in json_obj.items()
            if key not in keys_to_remove
        }
    elif isinstance(json_obj, list):
        # Process lists
        return [take_out_keys(item, keys_to_remove) for item in json_obj]
    else:
        # Return the value as is for non-dict and non-list items
        return json_obj
key_remove = {'journal_publication', 'date_published'}

# %%
clean_label_data = take_out_keys(label_data, key_remove)
clean_label_data
# Out:
# {'19': {'ISOSL3': {'temperature': '85',
#    'humidity': '50',
#    'time': '1560',
#    'treated_pce': '23.3',
#    'control_pce': '21',
#    'control_voc': '1.269',
#    'treated_voc': '1.271'},
#   'perovskite_composition': ['Cs 0.05 MA 0.05 FA 0.9 Pb(I 0.95 Br 0.05 ) 3',
#    'Cs 0.05 MA 0.15 FA 0.8 PbI 3'],
#   'passivating_molecule': '3,4,5-trifluoroanilinium',
#   'hole_transport_layer': '2PACz',
#   'efficiency_tret': '84',
#   'electron_transport_layer': 'C60',
#   'structure_pin_nip': 'PIN'},
#  '84': {'structure_pin_nip': 'NIP',
#   'hole_transport_layer': ['Spiro-OMeTAD',
#    'fluorene-terminated hole-transporting material'],
#   'ISOST2': {'efficiency_tret': 'ISOS-T2',
#    'time': 'ISOS-T2',
#    'temperature': 'ISOS-T2'},
#   'perovskite_composition': 'FAPbI 3 ) 0.95 (MAPbBr 3 ) 0.05',
#   'electron_transport_layer': 'mp-TIO2',
#   'ISOSL1': {'efficiency_tret': 'ISOS-L1', 'time': 'ISOS-L1'},
#   'ISOSD1': {'efficiency_tret': 'ISOS-D1',
#    'time': 'ISOS-D1',
#    'temperature': 'ISOS-D1'}},
#  '56': {'treated_pce': '25.5%',
#   'perovskite_composition': 'FA 0.83 Cs 0.17 Pb 0.5 Sn 0.5 I 3',
#   'hole_transport_layer': 'PEDOT:PSS',
#   'electron_transport_layer': 'evaporated C 60 (30 nm) and bathocuproine (BCP) (8 nm),with a copper (Cu) electrode on top'},
#  '82': {'structure_pin_nip': 'PIN',
#   'treated_voc': 'QAHs',
#   'treated_pce_peak': 'QUAs',
#   'perovskite_composition': ['PCBM',
#    'choline chloride',
#    'FA 0.85 MA 0.15 Pb(I 0.85 Br 0.15 ) 3'],
#   'treated_voc_peak': ['L-α-phosphatidylcholine', '16.1 ± 1.1%'],
#   'treated_pce': 'Cl-ChloridepassibatedFA0.85MA0.15Pb(I0.85Br0.15)3',
#   'ISOSD1': {'temperature': 'ISOS-D1',
#    'humidity': 'ISOS-D1',
#    'efficiency_tret': 'ISOS-D1',
#    'efficiency_cont': 'ISOS-D1',
#    'time': 'ISOS-D1'},
#   'ISOSL1': {'treated_pce': 'ISOS-L1',
#    'efficiency_tret': 'ISOS-L1',
#    'time': 'ISOS-L1'}},
#  '55': {'passivating_molecule': 'methylammonium lead iodide'},
#  '88': {'ISOSL1': {'treated_pce': 'ISOS-L1',
#    'time': 'ISOS-L1',
#    'efficiency_tret': 'ISOS-L1'},
#   'perovskite_composition': 'triple cation perovskite',
#   'treated_pce': 'CsFAMA-F',
#   'control_pce': 'CsMAFA',
#   'ISOSL3': {'treated_pce': 'ISOS-L3', 'time': 'ISOS-L3'},
#   'ISOST2': {'efficiency_tret': 'ISOS-T2',
#    'temperature': 'ISOS-T2',
#    'time': 'ISOS-T2',
#    'efficiency_cont': 'ISOS-T2'},
#   'ISOSD1': {'efficiency_tret': 'ISOS-D1', 'time': 'ISOS-D1'}},
#  '92': {'electron_transport_layer': 'BaSnO3',
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '21.3',
#   'ISOSD1': {'time': 'ISOS-D-1',
#    'humidity': 'ISOS-D-1',
#    'efficiency_cont': 'ISOS-D-1',
#    'efficiency_tret': 'ISOS-D-1'},
#   'hole_transport_layer': ['Spiro-OMeTAD', 'PTAA']},
#  '5': {'structure_pin_nip': 'NIP',
#   'perovskite_molecule': 'iso-butylammonium',
#   'electron_transport_layer': ['C60', 'C 60'],
#   'perovskite_composition': 'FA(MA)PbI 3',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'treated_voc': '1.135',
#   'treated_pce': '22.1'},
#  '18': {'perovskite_composition': '2-thiophenemethylammonium iodide',
#   'passivating_molecule': 'phenylethylammonium iodide',
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '9': {'perovskite_molecule': 'diammonium iodide',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': ['NiO', 'PCBM'],
#   'structure_pin_nip': 'PIN',
#   'treated_pce': '17.60',
#   'control_pce_peak': '14.64',
#   'control_voc': '1.08',
#   'treated_voc': '1.10'},
#  '13': {'passivating_molecule': '2-thiopheneethylammonium chloride',
#   'ISOSL2': {'control_voc': '1.29',
#    'treated_pce': '23.8',
#    'temperature': '60',
#    'efficiency_tret': '0.92',
#    'efficiency_cont': '0.82',
#    'control_pce': '15.1',
#    'treated_voc': '2.1'},
#   'time': '265',
#   'electron_transport_layer': 'PCBM',
#   'perovskite_composition': 'Cs 0.12 FA 0.8 MA 0.08 PbI 1.8 Br 1.2',
#   'structure_pin_nip': 'PIN',
#   'hole_transport_layer': ['2PACz', 'PTAA']},
#  '86': {'electron_transport_layer': ['E-SnO2', 'SnO 2'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'treated_pce': 'Tin',
#   'ISOSD1': {'efficiency_tret': 'ISOS-D1',
#    'time': 'ISOS-D1',
#    'efficiency_cont': 'ISOS-D1'},
#   'ISOSL1': {'time': 'ISOS-L1',
#    'efficiency_tret': 'ISOS-L1',
#    'efficiency_cont': 'ISOS-L1'}},
#  '80': {'perovskite_composition': 'PMMA',
#   'structure_pin_nip': 'NIP',
#   'ISOSD2': {'efficiency_tret': 'ISOS-D-2',
#    'temperature': 'ISOS-D-2',
#    'time': 'ISOS-D-2'},
#   'electron_transport_layer': 'Mesoporous TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '89': {'perovskite_composition': 'FAPbI3',
#   'treated_pce': '20.87',
#   'structure_pin_nip': 'NIP',
#   'treated_voc': '1.145',
#   'electron_transport_layer': 'TinOxide'},
#  '46': {'humidity': '25%',
#   'temperature': '25C',
#   'passivating_molecule': 'tri-n-octylphosphine (TOPO) 26',
#   'treated_pce_peak': '19.22%'},
#  '6': {'perovskite_molecule': 'phenethylammonium iodide',
#   'perovskite_composition': 'MAPbI3',
#   'ISOSD1': {'time': '240',
#    'treated_pce': '15.3',
#    'control_pce': '16.69',
#    'temperature': '25',
#    'humidity': '90',
#    'control_voc': '1.03',
#    'treated_voc': '1.06'},
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '114': {'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'C 60',
#   'passivating_molecule': ['PI', 'Piperazinium Diiodide (PDI)'],
#   'treated_voc': '1.17',
#   'treated_pce': '23.37',
#   'structure_pin_nip': 'p-i-n',
#   'perovskite_composition': 'Cs 0.05 (FA 0.95 MA 0.05 ) 0.95 Pb(I 0.95 Br 0.05 ) 3',
#   'control_pce': '20.76',
#   'control_voc': '1.06'},
#  '83': {'structure_pin_nip': 'PIN',
#   'electron_transport_layer': 'TinOxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'treated_voc': 'FAMAPb3',
#   'ISOSD2': {'temperature': 'ISOS-D-2',
#    'humidity': 'ISOS-D-2',
#    'efficiency_tret': 'ISOS-D-2 - FA0.15MA0.85PbI3',
#    'time': 'ISOS-D-2 - FA0.15MA0.85PbI3',
#    'efficiency_cont': 'ISOS-D-2 - MAPbI3',
#    'treated_pce': 'ISOS-D-2 - FA0.15MA0.85PbI3'},
#   'perovskite_composition': 'MAPbI3'},
#  '17': {'passivating_molecule': 'hexyltrimethyl ammouniumbromide',
#   'perovskite_composition': 'Cs 0.05 FA 0.81 MA 0.14 PbI 2.55 Br 0.45',
#   'structure_pin_nip': 'NIP',
#   'ISOSL1': {'temperature': 'room temperature',
#    'humidity': '70-75',
#    'time': '48',
#    'efficiency_tret': '0.86',
#    'control_voc': '1.16',
#    'control_pce': '20.04',
#    'treated_voc': '1.19',
#    'treated_pce': '20.94'},
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'SnO2'},
#  '53': {'control_pce': ['4.9%', '20.5'],
#   'passivating_molecule': ['DMePDAI 2', 'BDAI2'],
#   'perovskite_composition': ['FA 0.85 MA 0.1 Cs 0.05 PbI 2.9 Br 0.1',
#    'Cs 0.05 FA 0.95 PbI 3 , (FAPbI 3 ) 0.95 (MAPbBr 3 ) 0.05 , and FAPbI 3'],
#   'electron_transport_layer': ['TiO 2', 'SnO 2'],
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'treated_pce': '24.0%',
#   'ISOSD2': {'humidity': '85% relative humidity',
#    'temperature': '85°C',
#    'time': '1008-h'},
#   'time': '1008-h'},
#  '49': {'passivating_molecule': 'n-butylamine acetate',
#   'treated_pce': '16.25%',
#   'treated_voc': '1.31',
#   'ISOSD2': {'humidity': '65 ± 10% humidity',
#    'time': '4,680H',
#    'temperature': '85 °C for 558 h'},
#   'perovskite_composition': '(BA 2 MA n-1 Pb n I 3n+1 )',
#   'perovskite_molecule': 'BA 2 MA n-1 Pb n I 3n+1',
#   'hole_transport_layer': 'spiro-OMeTAD'},
#  '79': {'electron_transport_layer': ['TinOxide', 'TiO 2'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'structure_pin_nip': 'NIP',
#   'perovskite_molecule': ['Formamidinium Lead Iodide', 'MAPbBr 3'],
#   'ISOSL1': {'treated_pce_peak': 'ISOS-L1', 'humidity': 'ISOS-L1'}},
#  '90': {'treated_pce': 'strain-free',
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15)',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'structure_pin_nip': 'NIP',
#   'control_pce': 'tensile-strained',
#   'ISOSL2': {'treated_voc': 'ISOS-L2', 'treated_pce': 'ISOS-L2'}},
#  '0': {'ISOSL3': {'control_pce': '24',
#    'efficiency_tret': '95%',
#    'time': '1200',
#    'treated_pce': '26.9',
#    'treated_voc': '1.18'},
#   'structure_pin_nip': 'PIN',
#   'passivating_molecule': '4Cl-BZS',
#   'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3',
#   'hole_transport_layer': '2PACz and Me-4PACz',
#   'electron_transport_layer': 'C60'},
#  '47': {'hole_transport_layer': '4,6trimethylphenyl)amine) (PTAA),poly(bis(4-phenyl)(2',
#   'perovskite_molecule': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'passivating_molecule': ['octylammonium sulfate', 'Octylammonium iodide'],
#   'ISOSD2': {'temperature': '65C'},
#   'control_voc': '1.07',
#   'control_pce': '19.16',
#   'treated_voc': 'methylammonium sulfate'},
#  '41': {'efficiency_tret': '23.9%',
#   'ISOSD2': {'time': '1000_hours', 'humidity': '40-50%', 'temperature': '85'},
#   'efficiency_cont': '21.4%',
#   'passivating_molecule': 'o-PDEAI 2',
#   'control_pce_peak': '19.27%',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'treated_voc': '1.157',
#   'control_pce': '21.94%',
#   'control_voc': '1.135'},
#  '40': {'ISOSD2': {'temperature': 'ISOSD2',
#    'humidity': 'ISOSD2',
#    'time': 'ISOSD2'},
#   'passivating_molecule': 'oleylammonium iodide',
#   'treated_pce': '24.3%',
#   'efficiency_cont': '95%',
#   'hole_transport_layer': 'PTAA',
#   'treated_voc': '1.29',
#   'control_voc': '1.54'},
#  '12': {'perovskite_molecule': 'butylammonium bromide',
#   'ISOSL1': {'control_voc': '1.24',
#    'treated_voc': '1.31',
#    'treated_pce': '19.8',
#    'efficiency_cont': '1.0',
#    'efficiency_tret': '1.0',
#    'time': '20',
#    'temperature': '25',
#    'control_pce': '17.5'},
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'Cs0.15FA0.85PbI2.19Br0.81'},
#  '59': {'passivating_molecule': 'PEAI',
#   'treated_pce': '19.07%',
#   'treated_voc': '1.25',
#   'control_voc': '1.16',
#   'hole_transport_layer': 'PTAA',
#   'control_pce': '17.5%',
#   'ISOSL1': {'temperature': '250 - 300 K'},
#   'perovskite_composition': 'FA0.8Cs0.2Pb(I0.7Br0.3)3 WBG',
#   'temperature': '250-300 K'},
#  '14': {'passivating_molecule': 'chlorophenylethylammonium iodide',
#   'ISOSL1': {'treated_pce': '23.7',
#    'treated_voc': '1.184',
#    'efficiency_cont': '0.9',
#    'time': '33',
#    'efficiency_tret': '1.0',
#    'control_voc': '1.109',
#    'control_pce': '21.58'},
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'PCBM',
#   'perovskite_composition': 'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.85 Br 0.15 ) 3',
#   'structure_pin_nip': 'PIN'},
#  '50': {'passivating_molecule': ['allylammonium',
#    'phenethylammonium',
#    'butylammonium'],
#   'treated_pce': '16.5%',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'perovskite_composition': '(L) 2 (MA) n-1 Pb n I 3n-1',
#   'control_pce': '10-12%',
#   'ISOSD2': {'time': '1000 h', 'temperature': '70 °C'}},
#  '58': {'electron_transport_layer': 'SnO 2 Tin oxide'},
#  '2': {'treated_voc': '1.185',
#   'ISOSD1': {'treated_voc': '1.185',
#    'temperature': '85',
#    'humidity': '85',
#    'treated_pce': '24.35',
#    'time': '1056',
#    'control_pce': '22.39'},
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'humidity': '85',
#   'perovskite_composition': '(C 4 H 9 NH 3 ) 2 PbI 4',
#   'efficiency_tret': '94',
#   'passivating_molecule': '(CH 3 (CH 2 ) 3 NH 2'},
#  '3': {'treated_pce': '24.5', 'control_pce': '21'},
#  '81': {'electron_transport_layer': ['TiO2- Cl', 'TiO 2'],
#   'ISOSL1': {'treated_pce': 'ISOS-L1',
#    'efficiency_tret': 'ISOS-L1',
#    'time': 'ISOS-L1'},
#   'control_voc_peak': 'TiO2',
#   'perovskite_composition': 'CsMAFA',
#   'ISOSD2': {'efficiency_cont': 'ISOS-D2',
#    'efficiency_tret': 'ISOS-D2',
#    'time': 'ISOS-D2',
#    'humidity': 'ISOS-D2'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '93': {'treated_pce': 'FA0.57MA0.43PbI2.87Br0.13 (Cl)',
#   'structure_pin_nip': 'NIP'},
#  '10': {'perovskite_molecule': 'octylammonium tosylate',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'structure_pin_nip': 'n-i-p',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'ISOSL1': {'treated_pce': '24.41',
#    'temperature': '40',
#    'efficiency_cont': '0.651',
#    'efficiency_tret': '0.885',
#    'time': '2,092'}},
#  '15': {'structure_pin_nip': 'PIN',
#   'passivating_molecule': '4-chloro-phenylethylammonium iodide',
#   'hole_transport_layer': 'PTAA',
#   'perovskite_composition': 'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.9 Br 0.1 ) 3',
#   'electron_transport_layer': 'PCBM',
#   'control_voc': '1.11',
#   'control_pce': '21.78',
#   'treated_voc': '1.17',
#   'treated_pce': '23.79'},
#  '149': {'electron_transport_layer': ['C60', 'C 60', 'BCP', 'Cu', 'SnO 2'],
#   'control_pce_average': '22',
#   'treated_pce_average': '26.4%',
#   'efficiency_tret': '90%',
#   'time': '600 h',
#   'control_pce_peak': 'phenethylammonium (PEA), phenylammonium (PA) and 4-trifluoromethyl-phenylammonium (CF3-PA)',
#   'treated_pce_peak': '26.7',
#   'hole_transport_layer': ['PEDOT:PSS', 'NiO'],
#   'temperature': '35'},
#  '11': {'structure_pin_nip': ['benzotriazole', 'n-i-p'],
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'ISOSL1': {'temperature': 'room temperature',
#    'control_pce': '20.2',
#    'control_voc': '1.11',
#    'treated_voc': '1.16',
#    'treated_pce': '21.8',
#    'time': '24',
#    'efficiency_cont': '0.98',
#    'efficiency_tret': '1.04'}},
#  '7': {'ISOSL1': {'temperature': 'room_temperature',
#    'control_pce': '10',
#    'treated_pce': '15.42',
#    'treated_voc': '1.45',
#    'efficiency_tret': '0.9',
#    'time': '1000',
#    'humidity': '65'},
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'C60',
#   'perovskite_molecule': 'phenylethylammonium',
#   'perovskite_composition': '2 (FA) 8 Sn 9 I 2'},
#  '1': {'ISOSD2': {'treated_pce': '23.32',
#    'treated_voc': '1.16',
#    'control_pce': '21.3',
#    'time': '500'},
#   'passivating_molecule': 'phenethylammonium iodide (PEAI)',
#   'electron_transport_layer': ['HC(NH 2 ) 2 -CH 3 NH 3', 'SnO 2'],
#   'hole_transport_layer': 'spiro-OMeTAD'},
#  '117': {'hole_transport_layer': 'spiro-OMeTAD',
#   'ISOSL1': {'humidity': '70',
#    'control_pce': '22.2',
#    'control_voc': '1.15',
#    'treated_voc': '1.17',
#    'treated_pce': '23.4',
#    'temperature': '25'},
#   'perovskite_composition': '(FAPbI 3 ) 0.99 (MAPbBr 3 ) 0.01',
#   'passivating_molecule': 'FAPbI 3',
#   'time': '500',
#   'electron_transport_layer': 'TiO2'},
#  '42': {'passivating_molecule': 'azetidinium lead iodide',
#   'treated_pce': '22.4%',
#   'treated_voc': '1.18',
#   'perovskite_composition': 'Cs 0.05 MA 0.1 FA 0.85 PbI 2.7 Br 0.3',
#   'ISOSL1': {'temperature': '52'}},
#  '43': {'hole_transport_layer': 'spiro-OMeTAD',
#   'perovskite_composition': 'FA0.8075MA0.10Cs0.05Pb(I0.854Br0.186)3',
#   'treated_pce': '24.5%',
#   'passivating_molecule': 'benzylamine hydroiodide (BAHI)',
#   'ISOSD2': {'humidity': '80 ± 20% relative humidity',
#    'time': '500 h',
#    'passivating_molecule': '60 °C'}},
#  '85': {'hole_transport_layer': 'P3HT',
#   'perovskite_composition': 'HTAB',
#   'ISOSL1': {'treated_pce': 'ISOS-L1',
#    'humidity': 'ISOS-L1',
#    'time': 'ISOS-L1',
#    'efficiency_tret': 'ISOS-L1'},
#   'structure_pin_nip': 'NIP'},
#  '8': {'temperature': 'NIP',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'ISOSL1': {'control_pce': '20.1',
#    'treated_pce': '23.0',
#    'temperature': '40',
#    'time': '2000',
#    'efficiency_tret': '0.85',
#    'efficiency_cont': '0.60',
#    'control_voc': '1.160',
#    'treated_voc': '1.177'},
#   'perovskite_molecule': 'ethylammonium'},
#  '116': {'hole_transport_layer': 'Spiro-OMeTAD',
#   'electron_transport_layer': 'TiO2',
#   'perovskite_composition': 'MACl',
#   'ISOSL2': {'temperature': '25',
#    'humidity': '30',
#    'control_voc': '1.153',
#    'efficiency_cont': '22.68',
#    'treated_voc': '1.169'},
#   'humidity': '30',
#   'treated_pce': '24.82',
#   'time': '500',
#   'control_pce': '23.44'},
#  '91': {'perovskite_composition': 'formamidinium lead iodide',
#   'treated_pce': 'methylammonium chloride - 40%',
#   'passivating_molecule': ['methylammonium chloride - 20%', 'MA-30', 'MA-50'],
#   'control_voc': 'methylammonium chloride',
#   'ISOST1': {'efficiency_tret': 'ISOS-T1', 'time': 'ISOS-T1'},
#   'ISOST2': {'efficiency_cont': 'ISOS-T2',
#    'time': 'ISOS-T2',
#    'efficiency_tret': 'ISOS-T2'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '57': {'perovskite_composition': 'MA 0.07 FA 0.93 PbI 3',
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'C 60',
#   'ISOSL2': {'humidity': '25%', 'temperature': '25'},
#   'treated_pce': '28.4%'},
#  '87': {'treated_pce': ['21.52', '20.7'],
#   'structure_pin_nip': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'control_pce_peak': '18.5'},
#  '115': {'time': '2000',
#   'ISOSD2': {'treated_pce': '24.27',
#    'control_voc': '1.16',
#    'temperature': '85',
#    'treated_voc': '1.163',
#    'control_pce': '21.66'},
#   'temperature': '85',
#   'electron_transport_layer': 'C60',
#   'passivating_molecule': 'FA1-x-yMAxCsyPbI3-zBrz',
#   'hole_transport_layer': 'Spiro-OMeTAD/PTAA'},
#  '16': {'structure_pin_nip': 'NIP',
#   'passivating_molecule': 'CF3-phenethylammonium',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FAPbI3',
#   'control_voc': '1.04',
#   'control_pce': '18.87',
#   'treated_voc': '1.11',
#   'treated_pce': '21.05'},
#  '48': {'hole_transport_layer': 'Poly(triaryl amine) (PTAA)',
#   'perovskite_molecule': '1.0 wt% 2,3,5,6-Tetrafl uoro-7,7,8,8-tetracyanoquinodimethane (F4-TCNQ)',
#   'perovskite_composition': 'Organolead trihalide perovskite (OTP)',
#   'humidity': '40%'}}

# %% [markdown]
# ## Retrieving LLama Prediction

# %%
import json

# Path to your JSON file
file_path = '../data/deepseek_5_progressive.json'

# Open and load the JSON file
with open(file_path, 'r') as file:
    llama_data = json.load(file)

# Print the data to verify
print(llama_data)
print(f"There are {len(llama_data)} papers that llama evaluated")
# Out:
# {'103': {'control_pce': 14.44, 'control_voc': 0.926, 'treated_pce': 23.7, 'treated_voc': 1.47, 'passivating_molecule': 'Methylenediammonium chloride (MDACl2)', 'perovskite_composition': 'FAPbI3 with 3.8 mol% MDACl2', 'electron_transport_layer': 'TiO2 (mesoporous)', 'pin_nip_structure': 'PIN', 'hole_transport_layer': 'CuPC', 'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 25, 'time': 600, 'humidity': '20-30%', 'control_efficiency': 14.44, 'treatment_efficiency': 23.7}]}, '77': {'control_pce': '21.2', 'control_voc': '1.07', 'treated_pce': '24.1', 'treated_voc': '1.14', 'passivating_molecule': 'PEAMAI', 'perovskite_composition': 'FA 0.9 Cs 0.1 PbI 3', 'electron_transport_layer': 'ITO', 'pin_nip_structure': 'PIN', 'hole_transport_layer': 'PTAA', 'stability_tests': [{'test_name': 'ISOS-D', 'temperature': '55', 'time': '800', 'humidity': 'N/A', 'control_efficiency': '90', 'treatment_efficiency': '90'}, {'test_name': 'ISOS-E', 'temperature': '85', 'time': '1500', 'humidity': 'N/A', 'control_efficiency': '20', 'treatment_efficiency': '90'}]}, '104': {'control_pce': None, 'control_voc': None, 'treated_pce': '25.2', 'treated_voc': '1196', 'passivating_molecule': 'methylammonium bromide (MAPbBr3)', 'perovskite_composition': None, 'electron_transport_layer': 'SnO2', 'pin_nip_structure': None, 'hole_transport_layer': 'Spiro-OMeTAD', 'stability_tests': [{'test_name': 'ISOS-L-1I', 'temperature': '45', 'time': '3600', 'humidity': 'ambient', 'control_efficiency': '25.2', 'treatment_efficiency': '25.2'}]}, '79': {'control_pce': 19.9, 'control_voc': 1.09, 'treated_pce': 19.9, 'treated_voc': 1.09, 'passivating_molecule': 'PbI2', 'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03', 'electron_transport_layer': 'SnO2', 'pin_nip_structure': 'n-i-p', 'hole_transport_layer': 'Spiro-OMeTAD', 'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 25, 'time': '40 days', 'humidity': 'dry air', 'control_efficiency': 19.9, 'treatment_efficiency': 19.9}]}, '138': {'control_pce': 24.6, 'control_voc': None, 'treated_pce': 25.3, 'treated_voc': None, 'passivating_molecule': '2PACz and 3-MPA', 'perovskite_composition': 'Cs0.05MA0.10FA0.85PbI3', 'electron_transport_layer': 'FTO', 'pin_nip_structure': 'NIP', 'hole_transport_layer': 'ITO', 'stability_tests': [{'test_name': 'ISOS-L-3', 'temperature': 65, 'time': 1000, 'humidity': '50% RH', 'control_efficiency': 24.6, 'treatment_efficiency': 24.8}]}, '144': {'control_pce': 19.3, 'control_voc': 0.76, 'treated_pce': 21.0, 'treated_voc': 0.88, 'passivating_molecule': 'GlyHCl', 'perovskite_composition': 'Cs0.1FA0.6MA0.3Sn0.5Pb0.5I3', 'electron_transport_layer': 'PEDOT:PSS', 'pin_nip_structure': 'PIN', 'hole_transport_layer': 'PTAA', 'stability_tests': [{'test_name': 'ISOS', 'temperature': 25, 'time': '100 days', 'humidity': 'controlled (glovebox)', 'control_efficiency': 19.3, 'treatment_efficiency': 21.0}]}, '37': {'control_pce': 0.19, 'control_voc': 1.35, 'treated_pce': 0.263, 'treated_voc': 2.19, 'passivating_molecule': '1,3-propanediammonium iodide', 'perovskite_composition': 'Cs0.2FA0.8Pb(I0.6Br0.4)3', 'electron_transport_layer': 'NiOx', 'pin_nip_structure': 'PIN', 'hole_transport_layer': 'Me-4PACz', 'stability_tests': [{'test_name': 'ISOS-L', 'temperature': 25, 'time': 500, 'humidity': 'ambient air', 'control_efficiency': 0.19, 'treatment_efficiency': 0.263}, {'test_name': 'ISOS-LT', 'temperature': 25, 'time': 500, 'humidity': 'ambient air', 'control_efficiency': 0.19, 'treatment_efficiency': 0.263}]}, '143': {'control_pce': '18.09', 'control_voc': '1.16', 'treated_pce': '18.09', 'treated_voc': '1.16', 'passivating_molecule': 'CuSCN', 'perovskite_composition': '(FAPbI3)0.77 (MAPbBr3)0.14 (CsPbI3)0.09', 'electron_transport_layer': 'CuSCN', 'pin_nip_structure': 'PIN', 'hole_transport_layer': 'CuSCN', 'stability_tests': [{'test_name': 'ISOS-D', 'temperature': '25', 'time': '400 days', 'humidity': '40-70%', 'control_efficiency': '18.09', 'treatment_efficiency': '18.09'}]}, '30': {'control_pce': 10.92, 'co ...
# There are 144 papers that llama evaluated

# %% [markdown]
# ### Clean Llama predictoin to get rid of key with None and 'Not mentioned' value

# %%
# Recursive function to clean the JSON
def clean_json(obj):
    if isinstance(obj, dict):
        # Recursively process dictionary
        return {
            key: clean_json(value)
            for key, value in obj.items()
            if value not in ['None', None, "Not mentioned"]
        }
    elif isinstance(obj, list):
        # Recursively process list
        return [clean_json(item) for item in obj if item not in ['None', None, "Not mentioned"]]
    else:
        # Return the value as is
        return obj

# %%
filtered_llama_data = clean_json(llama_data)
filtered_llama_data
# Out:
# {'103': {'control_pce': 14.44,
#   'control_voc': 0.926,
#   'treated_pce': 23.7,
#   'treated_voc': 1.47,
#   'passivating_molecule': 'Methylenediammonium chloride (MDACl2)',
#   'perovskite_composition': 'FAPbI3 with 3.8 mol% MDACl2',
#   'electron_transport_layer': 'TiO2 (mesoporous)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuPC',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 600,
#     'humidity': '20-30%',
#     'control_efficiency': 14.44,
#     'treatment_efficiency': 23.7}]},
#  '77': {'control_pce': '21.2',
#   'control_voc': '1.07',
#   'treated_pce': '24.1',
#   'treated_voc': '1.14',
#   'passivating_molecule': 'PEAMAI',
#   'perovskite_composition': 'FA 0.9 Cs 0.1 PbI 3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '55',
#     'time': '800',
#     'humidity': 'N/A',
#     'control_efficiency': '90',
#     'treatment_efficiency': '90'},
#    {'test_name': 'ISOS-E',
#     'temperature': '85',
#     'time': '1500',
#     'humidity': 'N/A',
#     'control_efficiency': '20',
#     'treatment_efficiency': '90'}]},
#  '104': {'treated_pce': '25.2',
#   'treated_voc': '1196',
#   'passivating_molecule': 'methylammonium bromide (MAPbBr3)',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1I',
#     'temperature': '45',
#     'time': '3600',
#     'humidity': 'ambient',
#     'control_efficiency': '25.2',
#     'treatment_efficiency': '25.2'}]},
#  '79': {'control_pce': 19.9,
#   'control_voc': 1.09,
#   'treated_pce': 19.9,
#   'treated_voc': 1.09,
#   'passivating_molecule': 'PbI2',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '40 days',
#     'humidity': 'dry air',
#     'control_efficiency': 19.9,
#     'treatment_efficiency': 19.9}]},
#  '138': {'control_pce': 24.6,
#   'treated_pce': 25.3,
#   'passivating_molecule': '2PACz and 3-MPA',
#   'perovskite_composition': 'Cs0.05MA0.10FA0.85PbI3',
#   'electron_transport_layer': 'FTO',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': 65,
#     'time': 1000,
#     'humidity': '50% RH',
#     'control_efficiency': 24.6,
#     'treatment_efficiency': 24.8}]},
#  '144': {'control_pce': 19.3,
#   'control_voc': 0.76,
#   'treated_pce': 21.0,
#   'treated_voc': 0.88,
#   'passivating_molecule': 'GlyHCl',
#   'perovskite_composition': 'Cs0.1FA0.6MA0.3Sn0.5Pb0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': '100 days',
#     'humidity': 'controlled (glovebox)',
#     'control_efficiency': 19.3,
#     'treatment_efficiency': 21.0}]},
#  '37': {'control_pce': 0.19,
#   'control_voc': 1.35,
#   'treated_pce': 0.263,
#   'treated_voc': 2.19,
#   'passivating_molecule': '1,3-propanediammonium iodide',
#   'perovskite_composition': 'Cs0.2FA0.8Pb(I0.6Br0.4)3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient air',
#     'control_efficiency': 0.19,
#     'treatment_efficiency': 0.263},
#    {'test_name': 'ISOS-LT',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient air',
#     'control_efficiency': 0.19,
#     'treatment_efficiency': 0.263}]},
#  '143': {'control_pce': '18.09',
#   'control_voc': '1.16',
#   'treated_pce': '18.09',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'CuSCN',
#   'perovskite_composition': '(FAPbI3)0.77 (MAPbBr3)0.14 (CsPbI3)0.09',
#   'electron_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuSCN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '400 days',
#     'humidity': '40-70%',
#     'control_efficiency': '18.09',
#     'treatment_efficiency': '18.09'}]},
#  '30': {'control_pce': 10.92,
#   'control_voc': 1.16,
#   'treated_pce': 23.21,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'NH3',
#   'perovskite_composition': 'FACsPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'PTAB',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21},
#    {'test_name': 'ISOS-L',
#     'temperature': 100,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21},
#    {'test_name': 'ISOS-T',
#     'temperature': -15,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21}]},
#  '2': {'control_pce': 0.2239,
#   'control_voc': 1098,
#   'treated_pce': 0.2459,
#   'treated_voc': 1185,
#   'passivating_molecule': '(BA)2PbI4',
#   'perovskite_composition': '(BA)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1056,
#     'humidity': '85% relative humidity',
#     'control_efficiency': 0.2239,
#     'treatment_efficiency': 0.2435}]},
#  '93': {'treated_pce': 20.5,
#   'perovskite_composition': 'FA1-x MAx PbI2.87 Br0.13(Cl)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '131': {'control_pce': '25.5%',
#   'control_voc': '1.208 V',
#   'treated_pce': '25.5%',
#   'treated_voc': '1.208 V',
#   'passivating_molecule': 'Al2O3',
#   'perovskite_composition': '1.55 eV',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz/PTAA',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '85°C',
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '98%',
#     'treatment_efficiency': '20%'}]},
#  '42': {'control_pce': 19.52,
#   'control_voc': 1.07,
#   'treated_pce': 22.03,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'AzPbI3',
#   'perovskite_composition': 'Cs0.05 MA0.1 FA0.85 PbI2.7 Br0.3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 52,
#     'time': 1000,
#     'control_efficiency': 47,
#     'treatment_efficiency': 85}]},
#  '5': {'control_pce': 22.1,
#   'control_voc': 1135,
#   'treated_pce': 22.1,
#   'treated_voc': 1205,
#   'passivating_molecule': 'iso-BAI and n-BAI',
#   'perovskite_composition': 'FA(MA)PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '94': {'control_pce': '19.11',
#   'control_voc': '1.112',
#   'treated_pce': '20.6',
#   'treated_voc': '1.129',
#   'passivating_molecule': 'P4VP',
#   'perovskite_composition': 'Perovskite',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'P4VP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25-40 °C',
#     'time': '6000 h',
#     'humidity': '25-50% RH',
#     'control_efficiency': '19.11',
#     'treatment_efficiency': '20.6'}]},
#  '136': {'control_pce': '25.4',
#   'control_voc': '1.21',
#   'treated_pce': '23.4',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'MPA-CPA',
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'MPA-CPA',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '45',
#     'time': '500 hours',
#     'humidity': '30-40% RH',
#     'control_efficiency': '25.4',
#     'treatment_efficiency': '23.4'},
#    {'test_name': 'damp heat',
#     'temperature': '85',
#     'time': '500 hours',
#     'humidity': '85% RH',
#     'control_efficiency': '25.4',
#     'treatment_efficiency': '23.4'}]},
#  '45': {'control_pce': '25.1',
#   'treated_pce': '25.1',
#   'perovskite_composition': 'poly-Si/c-Si',
#   'electron_transport_layer': 'c-Si',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'p-poly-Si',
#   'stability_tests': []},
#  '39': {'control_pce': 20.7,
#   'control_voc': 1.09,
#   'treated_pce': 20.82,
#   'treated_voc': 1.193,
#   'passivating_molecule': '2-TMABr',
#   'perovskite_composition': '[ (FAPbI3)0.87 (MAPbBr3)0.13 ]0.92 (CsPbI3)0.08',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 25,
#     'time': 1000,
#     'humidity': 'inert atmosphere (Ar)',
#     'control_efficiency': 20.7,
#     'treatment_efficiency': 20.82}]},
#  '127': {'control_pce': 18.5,
#   'control_voc': 1.048,
#   'treated_pce': 24.1,
#   'treated_voc': 1.198,
#   'passivating_molecule': 'tris(2,4-di-tert-butylphenyl) phosphite (TPPi)',
#   'perovskite_composition': 'PEA2ZnX4 (X = Cl/I)',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'Standard thermal stability test',
#     'temperature': 85,
#     'time': '1009 hours',
#     'humidity': 'controlled environment',
#     'control_efficiency': 18.5,
#     'treatment_efficiency': 24.1}]},
#  '54': {'passivating_molecule': 'Methylammonium iodide or bromide',
#   'perovskite_composition': 'Mixed halide perovskite (e.g., MAPbI3, MAPbBr3)',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{}]},
#  '85': {'control_pce': 16,
#   'control_voc': 0.8,
#   'treated_pce': 22.7,
#   'treated_voc': 1.0,
#   'passivating_molecule': 'n-hexyl trimethyl ammonium bromide',
#   'perovskite_composition': 'FAPbI3:MAPbBr3:HTAB = 0.3:0.95:0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'P3HT',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1008,
#     'humidity': '85%',
#     'control_efficiency': 80,
#     'treatment_efficiency': 0}]},
#  '28': {'control_pce': 0.17,
#   'control_voc': 1.2,
#   'treated_pce': 0.17,
#   'treated_voc': 1.2,
#   'perovskite_composition': 'CsPbI3',
#   'electron_transport_layer': 'TPBi',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '120': {'control_pce': 23.0,
#   'control_voc': 1.13,
#   'treated_pce': 25.0,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'ferrocenyl-bis-thiophene-2-carboxylate',
#   'perovskite_composition': '(FA0.98MA0.02)0.95Cs0.05Pb(I0.95Br0.02)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'poly(triaryl amine)',
#   'stability_tests': [{'test_name': 'IEC61215:2016',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 72,
#     'treatment_efficiency': 98}]},
#  '53': {'control_pce': '4.9%',
#   'treated_pce': '24.7%',
#   'passivating_molecule': 'DMePDAI2',
#   'perovskite_composition': 'FA0.85MA0.1Cs0.05PbI2.9Br0.1',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': '40°C',
#     'time': '1000 hours',
#     'humidity': 'N2',
#     'control_efficiency': '20.5%',
#     'treatment_efficiency': '23.1%'}]},
#  '82': {'control_pce': '17.1',
#   'control_voc': '1.04',
#   'treated_pce': '20.59',
#   'treated_voc': '1.13',
#   'passivating_molecule': 'Choline chloride',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Humidity stability test',
#     'time': 'Over one month',
#     'humidity': '50-85% RH',
#     'control_efficiency': '17.1%',
#     'treatment_efficiency': '20.59%'}]},
#  '21': {'control_pce': 22.6,
#   'treated_pce': 19.14,
#   'passivating_molecule': 'LP layer',
#   'perovskite_composition': '3D perovskite',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient',
#     'control_efficiency': 22.6,
#     'treatment_efficiency': 19.14}]},
#  '129': {'control_pce': 24.8,
#   'control_voc': 1.19,
#   'treated_pce': 24.5,
#   'treated_voc': 1.19,
#   'passivating_molecule': 'GBAC',
#   'perovskite_composition': 'Cs0.06MA0.14FA0.80PbI3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'DC-PA',
#   'stability_tests': [{'test_name': 'JET certification',
#     'temperature': 65,
#     'time': 1200,
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': 24.5,
#     'treatment_efficiency': 24.5},
#    {'test_name': 'Thermal stability',
#     'temperature': 65,
#     'time': 1200,
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': 24.8,
#     'treatment_efficiency': 24.8}]},
#  '13': {'control_pce': 25.7,
#   'control_voc': 1.15,
#   'treated_pce': 15.1,
#   'treated_voc': 1.29,
#   'passivating_molecule': '2-thiopheneethylammonium chloride',
#   'perovskite_composition': 'Cs0.12FA0.8PbI1.8Br1.2',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': '2PACz',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 265,
#     'humidity': 'ambient',
#     'control_efficiency': 13.1,
#     'treatment_efficiency': 15.1}]},
#  '14': {'control_pce': 25.5,
#   'control_voc': 1.184,
#   'treated_pce': 23.7,
#   'treated_voc': 1.184,
#   'passivating_molecule': 'F-PEAI',
#   'perovskite_composition': 'Cs0.1FA0.9PbI2.9Br0.1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{}]},
#  '68': {'control_pce': 12.8,
#   'control_voc': 0.95,
#   'treated_pce': 12.8,
#   'treated_voc': 0.95,
#   'passivating_molecule': 'SnOx',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'AZO',
#   'stability_tests': [{'temperature': 60,
#     'time': 1000,
#     'humidity': 'ambient air',
#     'control_efficiency': 12.8,
#     'treatment_efficiency': 12.8}]},
#  '66': {'control_pce': 25.5,
#   'control_voc': 0.8,
#   'treated_pce': 45,
#   'treated_voc': 0.8,
#   'perovskite_composition': 'Cs0.15FA0.85PbI2.55Br0.45',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'damp heat',
#     'temperature': 85,
#     'time': 1000,
#     'humidity': '85% RH',
#     'control_efficiency': 25.5,
#     'treatment_efficiency': 45}]},
#  '115': {'control_pce': '24.04',
#   'control_voc': '0.08 cm²',
#   'treated_pce': '23.15',
#   'treated_voc': '23.15',
#   'passivating_molecule': 'anisole',
#   'perovskite_composition': 'FA1-x-yMAxCsyPbI3-zBrz',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '95%',
#     'treatment_efficiency': '75%'},
#    {'test_name': 'SPO',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '5%',
#     'treatment_efficiency': '20%'}]},
#  '61': {'passivating_molecule': 'butylamine',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'temperature': 85,
#     'time': '125 hours',
#     'humidity': 'N2 atmosphere'}]},
#  '112': {'control_pce': 21.8,
#   'control_voc': 1.14,
#   'treated_pce': 23.2,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Benzylhydrazine hydrochloride (BHC)',
#   'perovskite_composition': 'MA0.7FA0.3PbI3',
#   'electron_transport_layer': 'Poly[bis(4-phenyl)(2,4,6-trimethylphenyl)amine] (PTAA)',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'Indium tin oxide (ITO)',
#   'stability_tests': [{'test_name': 'Stability under AM 1.5G light',
#     'temperature': 65,
#     'time': '1000 hours',
#     'humidity': '60% ± 10%',
#     'control_efficiency': 19.2,
#     'treatment_efficiency': 23.2}]},
#  '4': {'control_pce': '19.93',
#   'control_voc': '1.06',
#   'treated_pce': '21.90',
#   'treated_voc': '1.14',
#   'passivating_molecule': '4-vinylbenzylammonium bromide (VBABr)',
#   'perovskite_composition': '[[(VBABr)₂ (FA₉₅MA₀₅)ₙ₋₁ Pb₃ₙ₊₁]',
#   'electron_transport_layer': 'SnO₂',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '95': {'treated_pce': 22.9,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'octylammonium iodide',
#   'perovskite_composition': 'FAPbI3·0.95 and MAPbBr3·0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 65,
#     'time': '100 hours',
#     'humidity': '65% RH',
#     'treatment_efficiency': 22.9},
#    {'test_name': 'ISOS-H',
#     'temperature': 85,
#     'time': '100 hours',
#     'humidity': '85% RH'}]},
#  '137': {'control_pce': 23.0,
#   'control_voc': 1.12,
#   'treated_pce': 25.5,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'PDAI2 and 3MTPAI',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.90PbI3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx/4PACz',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1600,
#     'humidity': 'Nitrogen',
#     'control_efficiency': 23.0,
#     'treatment_efficiency': 25.5},
#    {'test_name': 'ISOS-L',
#     'temperature': 65,
#     'time': 2000,
#     'humidity': 'Air with 50% RH',
#     'control_efficiency': 23.0,
#     'treatment_efficiency': 25.5}]},
#  '44': {'control_pce': 25.8,
#   'control_voc': 731,
#   'treated_pce': 21.12,
#   'perovskite_composition': 'SiOx',
#   'electron_transport_layer': 'n+ poly-Si',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'n+ poly-Si'},
#  '3': {'control_pce': 24.5,
#   'control_voc': 1.2,
#   'treated_pce': 24.5,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'BA2MA2Pb3I10',
#   'perovskite_composition': 'Cs0.05(MA0.10FA0.85)Pb(I0.90Br0.10)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': 55,
#     'time': 2000,
#     'humidity': '70% RH',
#     'control_efficiency': 21,
#     'treatment_efficiency': 22.93}]},
#  '92': {'treated_pce': 21.3,
#   'passivating_molecule': 'BaSnO3',
#   'perovskite_composition': 'BaSnO3',
#   'electron_transport_layer': 'BaSnO3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD, PTAA',
#   'stability_tests': [{'temperature': 25,
#     'time': '24 hours',
#     'humidity': '40% RH',
#     'control_efficiency': 21.3,
#     'treatment_efficiency': 21.7}]},
#  '130': {'control_pce': 22.9,
#   'control_voc': 1.1,
#   'treated_pce': 25.4,
#   'treated_voc': 1.15,
#   'passivating_molecule': 'Pentanamidine hydrochloride (PAD)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 30,
#     'time': '1000 h',
#     'humidity': 'ambient',
#     'control_efficiency': 22.9,
#     'treatment_efficiency': 25.4},
#    {'test_name': 'ISOS-L',
#     'temperature': 65,
#     'time': '500 h',
#     'humidity': '85% RH',
#     'control_efficiency': 22.9,
#     'treatment_efficiency': 25.4}]},
#  '43': {'control_pce': '24.50%',
#   'control_voc': '1.150 V',
#   'treated_pce': '24.50%',
#   'treated_voc': '1.121 V',
#   'passivating_molecule': 'Benzylamine hydroiodide (BAHI)',
#   'perovskite_composition': 'FA0.90MA0.10PbI3•(CsPbI3)0.05 with excess PbI2',
#   'electron_transport_layer': 'TiO2 (mesoporous)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '80 °C',
#     'time': '500 h',
#     'humidity': '20-30% RH',
#     'control_efficiency': '24.50%',
#     'treatment_efficiency': '47.96 ± 3.21%'}]},
#  '142': {'control_pce': 13.15,
#   'treated_pce': 16.13,
#   'passivating_molecule': 'formamidinium iodide (FAI)',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Modified BA2MA(n)Pb(n+1)I3n+1',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 65,
#     'time': '50 days',
#     'humidity': '65%',
#     'control_efficiency': 71},
#    {'test_name': 'ISOS-T',
#     'temperature': 85,
#     'time': '30 days',
#     'control_efficiency': 74},
#    {'test_name': 'ISOS-L', 'time': '24 hours', 'control_efficiency': 90}]},
#  '31': {'control_pce': 23.39,
#   'control_voc': 1.12,
#   'treated_pce': 25.49,
#   'treated_voc': 1.19,
#   'passivating_molecule': '3-aminomethyl pyridine (3-APy)',
#   'perovskite_composition': 'Rb0.05 Cs0.05 MA0.05 FA0.85 PbI0.95 Br0.05',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '850 hours',
#     'humidity': '85% relative humidity',
#     'control_efficiency': '22.85%',
#     'treatment_efficiency': '25.35%'},
#    {'test_name': 'ISOS-L',
#     'temperature': 55,
#     'time': '2,400 hours',
#     'humidity': 'air',
#     'control_efficiency': '22.3%',
#     'treatment_efficiency': '24.6%'},
#    {'test_name': 'ISOS-T'}]},
#  '139': {'control_pce': 25.2,
#   'control_voc': 1.145,
#   'treated_pce': 26.1,
#   'treated_voc': 1.164,
#   'passivating_molecule': '1-(phenylsulfonyl)pyrrole',
#   'perovskite_composition': 'FA0.95Cs0.05PbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '2500h',
#     'humidity': '85%RH',
#     'control_efficiency': 80,
#     'treatment_efficiency': 92}]},
#  '145': {'control_pce': 17.08,
#   'control_voc': 1.02,
#   'treated_pce': 20.48,
#   'treated_voc': 1.13,
#   'passivating_molecule': '4-fluoroaniline (FAL)',
#   'perovskite_composition': 'Cs0.05(MA0.17FA0.83)0.95PbI0.83Br0.17',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 66,
#     'humidity': '85-95% RH',
#     'control_efficiency': 17.08,
#     'treatment_efficiency': 20.48},
#    {'test_name': 'ISOS-L',
#     'temperature': 85,
#     'time': 100,
#     'humidity': '85% RH'}]},
#  '36': {'control_pce': '20%',
#   'control_voc': '0.23 V',
#   'treated_pce': '19.6%',
#   'treated_voc': '0.19 V',
#   'passivating_molecule': 'C60',
#   'perovskite_composition': 'Cs0.05(FA0.83MA0.17)0.95Pb(I0.83Br0.17)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'pin',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '-20°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'},
#    {'test_name': 'ISOS-L',
#     'temperature': '80°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'},
#    {'test_name': 'ISOS-T',
#     'temperature': '-10°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'}]},
#  '78': {'control_voc': 1.06,
#   'treated_pce': 20.2,
#   'treated_voc': 1.06,
#   'passivating_molecule': 'DMSO',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '76': {'perovskite_composition': '2D lead halide perovskites',
#   'electron_transport_layer': 'organic spacer ligands',
#   'pin_nip_structure': '2D',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 140,
#     'time': '60 min',
#     'humidity': 'dry'},
#    {'test_name': 'ISOS-L',
#     'temperature': 23,
#     'time': 'room temperature',
#     'humidity': 'dry'}]},
#  '105': {'control_pce': '21.65%',
#   'control_voc': '1.172 V',
#   'treated_pce': '23.33%',
#   'treated_voc': '1.193 V',
#   'passivating_molecule': 'PMMA:PCBM',
#   'perovskite_composition': 'TiOxNy',
#   'electron_transport_layer': 'TiOxNy',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'P3HT:CuPc',
#   'stability_tests': [{'test_name': 'damp-heat',
#     'temperature': '85',
#     'time': '1000 hours',
#     'humidity': '85% relative humidity',
#     'control_efficiency': '96.5%',
#     'treatment_efficiency': '98.7%'}]},
#  '71': {'control_pce': 5,
#   'control_voc': 0.05,
#   'treated_pce': 15.3,
#   'treated_voc': 1.7,
#   'passivating_molecule': '(BA)2(MA)3Pb4I13',
#   'perovskite_composition': '(BA)2(MA)3Pb4I13',
#   'electron_transport_layer': 'BA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 260},
#    {'test_name': 'ISOS-L', 'temperature': 240}]},
#  '102': {'control_pce': 17.87,
#   'control_voc': 1.05,
#   'treated_pce': 21.07,
#   'treated_voc': 1.12,
#   'passivating_molecule': 'MACl',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{}]},
#  '113': {'treated_pce': 25.8,
#   'treated_voc': 1.1885,
#   'passivating_molecule': 'FASnCl x',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1I',
#     'temperature': 25,
#     'time': 500,
#     'control_efficiency': 25.5,
#     'treatment_efficiency': 25.8}]},
#  '67': {'passivating_molecule': 'formamidinium (FA)',
#   'perovskite_composition': 'FAPbI3 and CsPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L1',
#     'temperature': 298,
#     'time': '1000 hours',
#     'humidity': '25% RH'},
#    {'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH'},
#    {'test_name': 'ISOS-L2',
#     'temperature': 65,
#     'time': '1000 hours',
#     'humidity': '60% RH'},
#    {'test_name': 'ISOS-L3',
#     'temperature': 110,
#     'time': '2000 hours',
#     'humidity': 'unknown'}]},
#  '114': {'control_pce': 20.76,
#   'control_voc': 1.06,
#   'treated_pce': 23.37,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Piperazinium iodide (PI)',
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': []},
#  '15': {'control_pce': '21.78',
#   'control_voc': '1.11',
#   'treated_pce': '23.34',
#   'treated_voc': '1.15',
#   'passivating_molecule': 'Cl-PEAI and F-PEAI',
#   'perovskite_composition': 'Cs0.05(FA5/6MA1/6)0.95PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'temperature': '300'}]},
#  '69': {'passivating_molecule': 'SnOx',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'Al:ZnO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PEDOT:PSS',
#   'stability_tests': [{'temperature': 25, 'humidity': '60% RH'},
#    {'temperature': 60}]},
#  '12': {'control_pce': 16.7,
#   'control_voc': 1.23,
#   'treated_pce': 19.4,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylammonium bromide (BABr)',
#   'perovskite_composition': 'Cs0.17 FA0.83 Pb(I0.6 Br0.4)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'J-V measurements',
#     'temperature': 25,
#     'time': 'continuous illumination',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4},
#    {'test_name': 'PCE under different treatments',
#     'temperature': 25,
#     'time': 'under constant voltage',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4}]},
#  '128': {'control_pce': '24.6',
#   'control_voc': '1.16',
#   'treated_pce': '25.12',
#   'treated_voc': '1.165',
#   'passivating_molecule': '2-aminoindan hydrochloride (AICl)',
#   'perovskite_composition': 'Cs0.05FA0.95PbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '85',
#     'time': '1200 hours',
#     'humidity': '85% RH',
#     'control_efficiency': '24.32',
#     'treatment_efficiency': '24.58'},
#    {'test_name': 'ISOS-D',
#     'temperature': '55',
#     'time': '1500 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '21.73',
#     'treatment_efficiency': '24.42'}]},
#  '27': {'control_pce': '14.4',
#   'control_voc': '1.01',
#   'treated_pce': '18.5',
#   'treated_voc': '1.23',
#   'passivating_molecule': 'CF3-PEA',
#   'perovskite_composition': 'CsPbI3-xBrx',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '25',
#     'time': '1000',
#     'humidity': 'ambient',
#     'control_efficiency': '14.4',
#     'treatment_efficiency': '18.5'}]},
#  '20': {'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'MAPbI3, (PEA)2PbI4',
#   'electron_transport_layer': 'PMMA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{}]},
#  '121': {'control_pce': '26.08',
#   'treated_pce': '25.73',
#   'passivating_molecule': 'formamidinium lead iodide (FAPbI3)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'temperature': '60-80 °C',
#     'time': '40 min',
#     'humidity': 'controlled',
#     'control_efficiency': '26.08%',
#     'treatment_efficiency': '25.73%'}]},
#  '52': {'control_pce': '19.1%',
#   'control_voc': '658.4 mV',
#   'passivating_molecule': 'Al2O3',
#   'perovskite_composition': 'CH3NH3Pb',
#   'electron_transport_layer': 'Al-BSF',
#   'pin_nip_structure': 'PERC',
#   'hole_transport_layer': 'Al-BSF'},
#  '83': {'control_pce': '21.3',
#   'control_voc': '1.13',
#   'treated_pce': '21.38',
#   'treated_voc': '1.12',
#   'passivating_molecule': 'MAI and FA',
#   'perovskite_composition': 'MAPbI3 and FA0.15MA0.85PbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '792 hours',
#     'humidity': '40 ± 10%',
#     'control_efficiency': '21.3',
#     'treatment_efficiency': '21.38'}]},
#  '126': {'control_pce': 23.43,
#   'control_voc': 1.16,
#   'treated_pce': 25.39,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'PbC2O4',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': 550,
#     'humidity': 'ambient air',
#     'control_efficiency': 92,
#     'treatment_efficiency': 92}]},
#  '55': {'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'},
#    {'test_name': 'ISOS-L',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'}]},
#  '84': {'control_pce': 21.6,
#   'control_voc': 1.24,
#   'treated_pce': 23.2,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'DM',
#   'perovskite_composition': '(FAPbI3)0.95 (MAPbBr3)0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'DM',
#   'stability_tests': [{'test_name': 'thermal stability test',
#     'temperature': 60,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 70,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 80,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3}]},
#  '29': {'passivating_molecule': 'butylamine',
#   'perovskite_composition': 'PbI2-based',
#   'electron_transport_layer': 'linear PEI',
#   'stability_tests': []},
#  '18': {'control_pce': '26%',
#   'passivating_molecule': 'TMAI',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'SnO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'lower'},
#    {'test_name': 'ISOS-L',
#     'temperature': 100,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'higher'}]},
#  '117': {'control_pce': 22.2,
#   'control_voc': 1.15,
#   'treated_pce': 25.1,
#   'treated_voc': 1.17,
#   'passivating_molecule': '4-tert-butyl-1-methylpyridinium bis(trifluoromethanesulfonyl)imide (TBMP + TFSI -)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Stability test',
#     'temperature': '70 ± 5% RH',
#     'time': 'Long-term exposure',
#     'humidity': 'High relative humidity',
#     'control_efficiency': '22.2%',
#     'treatment_efficiency': '25.1%'}]},
#  '64': {'control_pce': 18.6,
#   'control_voc': 1057,
#   'treated_pce': 17.0,
#   'treated_voc': 1062,
#   'passivating_molecule': 'PEA2PbI4',
#   'perovskite_composition': 'Both MAPI and PEA2PbI4',
#   'electron_transport_layer': 'MoO3 and TATM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60'},
#  '110': {'control_pce': '23.92',
#   'control_voc': '1.15',
#   'treated_pce': '25.6',
#   'treated_voc': '1.21',
#   'passivating_molecule': 'formate',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'm-TiO2',
#   'stability_tests': [{'test_name': 'stability tests',
#     'temperature': '25 °C',
#     'time': '1000 h',
#     'humidity': '20% relative humidity',
#     'control_efficiency': '23.92',
#     'treatment_efficiency': '25.6'}]},
#  '11': {'control_pce': '20.2',
#   'control_voc': '1.11',
#   'treated_pce': '21.8',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'BTaBr',
#   'perovskite_composition': '(BTa)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '24 hours',
#     'humidity': 'ambient air',
#     'control_efficiency': '21.8',
#     'treatment_efficiency': '21.8'}]},
#  '16': {'control_pce': 18.87,
#   'control_voc': 1.04,
#   'treated_pce': 21.05,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'CF3PEAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '119': {'control_pce': 20.5,
#   'control_voc': 1.09,
#   'treated_pce': 23.9,
#   'treated_voc': 1.15,
#   'passivating_molecule': '1,1,2,2,3,3-hexafluoropropane-1,3-disulfonimide',
#   'perovskite_composition': 'formamidinium-based perovskite',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'HFDF',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 200,
#     'humidity': 'Not specified',
#     'control_efficiency': 23.9,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'ISOS-L',
#     'temperature': 85,
#     'time': 1000,
#     'humidity': 'Not specified',
#     'control_efficiency': 20.5,
#     'treatment_efficiency': 21.2}]},
#  '23': {'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'Cs0.05MA0.1FA0.85PbI3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L3',
#     'temperature': '65°C',
#     'time': '500 hours',
#     'humidity': 'Not explicitly mentioned',
#     'control_efficiency': '23.91%',
#     'treatment_efficiency': '92% of initial PCE'}]},
#  '58': {'control_pce': '25.5%',
#   'treated_pce': '18.5%',
#   'passivating_molecule': 'PCBM',
#   'perovskite_composition': 'FA0.83Cs0.17PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'poly-TPD or NiOx',
#   'stability_tests': [{}]},
#  '89': {'treated_pce': '20.87%',
#   'treated_voc': '413 mV',
#   'passivating_molecule': 'formamidine acetate (FAAc)',
#   'perovskite_composition': '(FA, MA, Cs)Pb(I, Br)3'},
#  '24': {'control_pce': '14.9',
#   'treated_pce': '17.4',
#   'passivating_molecule': 'Cs2PbI2Cl2',
#   'perovskite_composition': 'CsPbI3',
#   'electron_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuSCN',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 110,
#     'time': 2100,
#     'control_efficiency': 14.9,
#     'treatment_efficiency': 17.4}]},
#  '56': {'control_pce': 25.5,
#   'control_voc': 1.22,
#   'treated_pce': 20.5,
#   'treated_voc': 1.22,
#   'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{}]},
#  '125': {'control_pce': '91%',
#   'control_voc': '1.14 V',
#   'treated_pce': '23.7%',
#   'treated_voc': '1.14 V',
#   'passivating_molecule': 'Selenophene',
#   'perovskite_composition': 'FA0.9Cs0.1PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85°C',
#     'time': '3190 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '91%',
#     'treatment_efficiency': '91%'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '1000 hours',
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': '45°C',
#     'time': '500 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '80%',
#     'treatment_efficiency': '80%'}]},
#  '87': {'treated_pce': 21.52,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'FAI',
#   'perovskite_composition': 'CsI:20 mg, PbI2:530 mg, PbBr2:20 mg, PbCl2:20 mg, MAI:5 mg',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'temperature': 85,
#     'time': 1500,
#     'control_efficiency': 100,
#     'treatment_efficiency': 89}]},
#  '51': {'control_pce': '25%',
#   'treated_pce': '2x',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN'},
#  '122': {'control_pce': 25.6,
#   'control_voc': 1.182,
#   'treated_pce': 25.6,
#   'treated_voc': 1.182,
#   'passivating_molecule': '(PbI2)2RbCl',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'thermal stability test',
#     'temperature': 85,
#     'time': 500,
#     'humidity': 'Unknown',
#     'control_efficiency': 80,
#     'treatment_efficiency': 96}]},
#  '80': {'control_pce': 21.6,
#   'control_voc': 1.14,
#   'treated_pce': 21.6,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'PMMA',
#   'perovskite_composition': 'Mixed cation perovskite (FAI, PbI2, MABr, PbBr2)',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': '2 months',
#     'humidity': 'ambient air',
#     'control_efficiency': 21.0,
#     'treatment_efficiency': 21.0}]},
#  '0': {'control_pce': '25.5',
#   'control_voc': '1.17',
#   'treated_pce': '24.7',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'formamidinium lead triiodide (FAPbI3)',
#   'electron_transport_layer': 'Cs2O',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '1500',
#     'humidity': '50',
#     'control_efficiency': '19.9',
#     'treatment_efficiency': '95'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65',
#     'time': '1200',
#     'humidity': '50',
#     'control_efficiency': '23.2',
#     'treatment_efficiency': '91'}]},
#  '91': {'control_pce': '19.66',
#   'control_voc': '1.027',
#   'treated_pce': '24.02',
#   'treated_voc': '1.130',
#   'passivating_molecule': 'methylammonium chloride (MACl)',
#   'perovskite_composition': 'formamidinium lead iodide (FAPbI3)',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '1200 hours',
#     'humidity': 'Room temperature',
#     'control_efficiency': '90',
#     'treatment_efficiency': '90'},
#    {'test_name': 'ISOS-L',
#     'temperature': 40,
#     'time': '300 hours',
#     'humidity': '40°C',
#     'control_efficiency': '60',
#     'treatment_efficiency': '90'}]},
#  '40': {'control_pce': 24.3,
#   'control_voc': 1.2,
#   'treated_pce': 24.3,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'Oleylammonium iodide (OLAI)',
#   'perovskite_composition': 'Cs0.03(FA0.90MA0.10)PbI3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'damp-heat',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 24.3,
#     'treatment_efficiency': 19.3}]},
#  '133': {'control_pce': '22.34%',
#   'control_voc': '1.14 V',
#   'treated_pce': '24.04%',
#   'treated_voc': '1.19 V',
#   'passivating_molecule': 'Sodium thioglycolate',
#   'perovskite_composition': 'FA0.75MA0.25PbI3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '25 °C',
#     'time': '900 hours',
#     'humidity': 'controlled',
#     'control_efficiency': '22.34%',
#     'treatment_efficiency': '24.04%'},
#    {'test_name': 'AM1.5G',
#     'temperature': '25 °C',
#     'time': '800 hours',
#     'humidity': 'controlled',
#     'control_efficiency': '22.25%',
#     'treatment_efficiency': '23.5%'}]},
#  '7': {'control_pce': 23.5,
#   'control_voc': 1.2,
#   'treated_pce': 28.7,
#   'treated_voc': 1.5,
#   'passivating_molecule': '4-FPEA',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Au',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '24 hours',
#     'humidity': '50% RH',
#     'control_efficiency': 22.5,
#     'treatment_efficiency': 28.7},
#    {'test_name': 'ISOS-L',
#     'temperature': 60,
#     'time': '48 hours',
#     'humidity': '30% RH',
#     'control_efficiency': 23.5,
#     'treatment_efficiency': 28.7}]},
#  '96': {'control_pce': 22.19,
#   'control_voc': 1.13,
#   'treated_pce': 16.7,
#   'passivating_molecule': 'tin(II) acetylacetonate',
#   'perovskite_composition': 'lead halide perovskite',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 160,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 200,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 220,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 350,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7}]},
#  '47': {'treated_pce': 21.1,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'PbSO4',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 65,
#     'time': '1200 hours',
#     'humidity': 'air, RH ~60%',
#     'control_efficiency': 21.1,
#     'treatment_efficiency': 96.8}]},
#  '134': {'control_pce': 23.13,
#   'control_voc': 1.141,
#   'treated_pce': 25.08,
#   'treated_voc': 1.174,
#   'passivating_molecule': 'Guanabenz acetate salt',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Moisture stability test',
#     'temperature': 55,
#     'time': '24 hours',
#     'humidity': '55% RH',
#     'control_efficiency': 23.13,
#     'treatment_efficiency': 25.32},
#    {'test_name': 'Damp heat test',
#     'temperature': 85,
#     'time': '300 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 23.13,
#     'treatment_efficiency': 25.08}]},
#  '148': {'control_pce': 20.1,
#   'control_voc': 1.077,
#   'treated_pce': 23.5,
#   'treated_voc': 1.142,
#   'passivating_molecule': '4-tert-butylbenzylammonium iodide (tBBAI)',
#   'perovskite_composition': 'Cs0.05FA0.85MA0.10PbI0.97Br0.03',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 50,
#     'time': '500 hours',
#     'humidity': '50-70% RH',
#     'control_efficiency': 20.1,
#     'treatment_efficiency': 23.5}]},
#  '9': {'control_pce': 14.64,
#   'treated_pce': 17.6,
#   'passivating_molecule': 'C8',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'NiOx'},
#  '98': {'control_pce': '24.2',
#   'control_voc': '1.28',
#   'treated_pce': '21.54',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'FN-Br',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'MPP under 1-sun illumination',
#     'temperature': '25',
#     'time': '500',
#     'humidity': 'Ambient air',
#     'control_efficiency': '21.54',
#     'treatment_efficiency': '20.24'}]},
#  '49': {'control_pce': '13.81',
#   'control_voc': '1.12',
#   'treated_pce': '16.25',
#   'treated_voc': '1.31',
#   'passivating_molecule': 'n-butylamine acetate (BAAc)',
#   'perovskite_composition': '(BA)2(MA)n-1Pb3n+1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '558',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '13.81',
#     'treatment_efficiency': '16.25'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65 ± 10%',
#     'time': '4680',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '49.4',
#     'treatment_efficiency': '93.8'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '85',
#     'time': '1100',
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': '70.8',
#     'treatment_efficiency': '96.2'}]},
#  '35': {'perovskite_composition': 'CsPbI3_0.05(FAPbI3_0.83MAPbBr3_0.17)_0.95',
#   'electron_transport_layer': 'C60, PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PEDOT:PSS, PC61BM',
#   'stability_tests': []},
#  '146': {'control_pce': 21.5,
#   'control_voc': 1.128,
#   'treated_pce': 23.04,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'CB-NH2',
#   'perovskite_composition': 'Cs0.05FA0.95PbI0.95Br0.05',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
# ...
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 100,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6},
#    {'test_name': 'ISOS-LT',
#     'temperature': 60,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6}]},
#  '59': {'control_pce': '19.07',
#   'control_voc': '1.25',
#   'treated_pce': '19.07',
#   'treated_voc': '1.25',
#   'passivating_molecule': 'phenethylammonium iodide',
#   'perovskite_composition': 'FA0.8Cs0.2PbI0.7Br0.3',
#   'electron_transport_layer': 'poly(triarylamine)',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{}]},
#  '88': {'control_pce': 19.03,
#   'control_voc': 0.92,
#   'treated_pce': 21.46,
#   'treated_voc': 0.94,
#   'passivating_molecule': 'NaF',
#   'perovskite_composition': 'Cs0.05FA0.54MA0.41PbI0.98Br0.02)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1000,
#     'control_efficiency': 19.03,
#     'treatment_efficiency': 21.46}]},
#  '25': {'passivating_molecule': 'formamidinium',
#   'perovskite_composition': 'FAPbI3, FAPbBr3',
#   'stability_tests': []},
#  '22': {'control_pce': 25.5,
#   'control_voc': 1.092,
#   'treated_pce': 24.0,
#   'treated_voc': 1.154,
#   'passivating_molecule': 'Cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PCBM',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 50,
#     'time': 500,
#     'humidity': '40 ± 10%',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 93},
#    {'test_name': 'ISOS-L',
#     'temperature': 50,
#     'time': 500,
#     'humidity': '40 ± 10%',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 93}]},
#  '17': {'control_pce': 25.2,
#   'control_voc': 1.16,
#   'treated_pce': 22.02,
#   'treated_voc': 1.19,
#   'passivating_molecule': 'hexyltrimethylammonium bromide',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': '1F-PTAA',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': '1F-PTAA',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '90 min',
#     'humidity': 'N2-filled glove-box',
#     'control_efficiency': 20.04,
#     'treatment_efficiency': 22.16}]},
#  '118': {'control_pce': 0.1961,
#   'control_voc': 1.16,
#   'treated_pce': 0.2154,
#   'treated_voc': 1.24,
#   'passivating_molecule': 'n-Butylammonium bromide (BABr)',
#   'perovskite_composition': '1.63 eV bandgap system (RbCsMAFA)',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 35,
#     'time': '24 h',
#     'humidity': '20-30% RH',
#     'control_efficiency': 0.1961,
#     'treatment_efficiency': 0.2154},
#    {'test_name': 'ISOS-L',
#     'temperature': 60,
#     'time': '500 h',
#     'humidity': '30-40% RH',
#     'control_efficiency': 0.1961,
#     'treatment_efficiency': 0.2154}]},
#  '10': {'treated_pce': 24.41,
#   'treated_voc': 4.77,
#   'passivating_molecule': 'OATsO',
#   'perovskite_composition': '(FAPbI3)0.95((MAPbBr3)0.05)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'test_name': 'OC',
#     'temperature': 40,
#     'time': '1,000 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41},
#    {'test_name': 'MPP',
#     'temperature': 40,
#     'time': '800 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41}]},
#  '111': {'treated_pce': 23.9,
#   'treated_voc': 0.68,
#   'passivating_molecule': 'isopropylammonium chloride',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-MeOTAD',
#   'stability_tests': [{}]},
#  '62': {'control_pce': 17.3,
#   'control_voc': 1.01,
#   'treated_pce': 16.5,
#   'treated_voc': 1.02,
#   'passivating_molecule': 'BAI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 55,
#     'time': '30 days',
#     'humidity': '55% RH',
#     'control_efficiency': 44,
#     'treatment_efficiency': 83},
#    {'test_name': 'ISOS-L',
#     'temperature': 80,
#     'time': '30 days',
#     'humidity': '80°C',
#     'control_efficiency': 27,
#     'treatment_efficiency': 73}]},
#  '19': {'treated_pce': 24.09,
#   'passivating_molecule': '3FPEA',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.9Pb(I0.95Br0.05)3',
#   'electron_transport_layer': '2PACz',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': 85,
#     'time': 1560,
#     'humidity': '50% RH',
#     'treatment_efficiency': 24.09}]},
#  '116': {'control_pce': 23.44,
#   'control_voc': 1.152,
#   'treated_pce': 24.82,
#   'treated_voc': 1.1814,
#   'passivating_molecule': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': 500,
#     'control_efficiency': 13.74,
#     'treatment_efficiency': 87}]},
#  '65': {'control_pce': 4.73,
#   'control_voc': 1.18,
#   'treated_pce': 4.73,
#   'treated_voc': 1.18,
#   'passivating_molecule': '(PEA)2(MA)2[Pb3I10]',
#   'perovskite_composition': '(PEA)2(MA)2[Pb3I10]',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '52',
#     'time': '40 days',
#     'humidity': '52% relative humidity',
#     'control_efficiency': 4.73,
#     'treatment_efficiency': 4.73}]},
#  '107': {'treated_pce': 21.25,
#   'passivating_molecule': 'SF-PEA',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 1000,
#     'time': '1000',
#     'humidity': '50-60%',
#     'treatment_efficiency': 0.91}]},
#  '74': {'control_pce': 21.2,
#   'control_voc': 1.13,
#   'passivating_molecule': 'CLP',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 4390,
#     'humidity': 'N2',
#     'control_efficiency': 21.2,
#     'treatment_efficiency': 21.2}]},
#  '100': {'control_pce': '23.24',
#   'control_voc': '1.17',
#   'treated_pce': '22.54',
#   'treated_voc': '1.16',
#   'electron_transport_layer': 'In2O3/SnO2',
#   'hole_transport_layer': 'SnO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25 °C',
#     'time': '80 days',
#     'humidity': 'N2',
#     'control_efficiency': '97.5%',
#     'treatment_efficiency': '91%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': '75% RH',
#     'time': '120 h',
#     'humidity': 'High',
#     'control_efficiency': '71%',
#     'treatment_efficiency': '80%'}]},
#  '73': {'control_pce': 22.6,
#   'control_voc': 1.176,
#   'treated_pce': 25.1,
#   'treated_voc': 1.176,
#   'passivating_molecule': '2CF3-PEAI',
#   'perovskite_composition': 'FA0.98Cs0.02PbI3',
#   'electron_transport_layer': 'p-PY',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'temperature': 85,
#     'time': 1000,
#     'humidity': '85% RH',
#     'control_efficiency': 97.4}]},
#  '109': {'control_pce': '17.27%',
#   'control_voc': '1.13 V',
#   'treated_pce': '25.7%',
#   'treated_voc': '1.16 V',
#   'passivating_molecule': 'PAA',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': '25°C',
#     'time': '1000 hours',
#     'humidity': '25% RH',
#     'control_efficiency': '25.7%',
#     'treatment_efficiency': '80%'},
#    {'test_name': 'Shelf life',
#     'temperature': '25°C',
#     'time': '1000 hours',
#     'humidity': '25% RH',
#     'control_efficiency': '17.27%',
#     'treatment_efficiency': '25.7%'}]},
#  '33': {'control_pce': 25,
#   'treated_pce': 25,
#   'passivating_molecule': 'Benzene',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'FAI-terminated',
#   'hole_transport_layer': 'PbI2',
#   'stability_tests': []},
#  '140': {'control_pce': '26.07%',
#   'control_voc': '25.8%',
#   'treated_pce': '24.63%',
#   'treated_voc': '26.07%',
#   'passivating_molecule': 'HFB',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'temperature': '50 ± 5 °C',
#     'time': '1258 h',
#     'control_efficiency': '26.07%',
#     'treatment_efficiency': '24.63%'}]},
#  '8': {'control_pce': '20.1',
#   'control_voc': '1.16',
#   'treated_pce': '23.0',
#   'treated_voc': '1.177',
#   'passivating_molecule': 'PREA',
#   'perovskite_composition': 'CsPbI2Br',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'ambient',
#     'control_efficiency': '85',
#     'treatment_efficiency': '60'}]},
#  '99': {'control_pce': 18.08,
#   'control_voc': 1.087,
#   'treated_pce': 21.01,
#   'treated_voc': 1.146,
#   'passivating_molecule': 'ClMPI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Outdoor Solar Irradiation',
#     'temperature': 25,
#     'time': 180,
#     'humidity': 'outdoor',
#     'control_efficiency': 16.25,
#     'treatment_efficiency': 20.17},
#    {'test_name': 'UV Irradiation',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'controlled',
#     'control_efficiency': 10,
#     'treatment_efficiency': 82},
#    {'test_name': '1-Sun Illumination with UV Filter',
#     'temperature': 25,
#     'time': 200,
#     'humidity': 'indoor',
#     'control_efficiency': 50,
#     'treatment_efficiency': 90}]},
#  '48': {'control_pce': '16.9',
#   'control_voc': '1.07',
#   'treated_pce': '20.3',
#   'treated_voc': '1.10',
#   'passivating_molecule': 'Fluoro-silane',
#   'perovskite_composition': 'Perovskite films',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA:F4-TCNQ',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 'Room temperature',
#     'time': 'After fabrication',
#     'humidity': '40%',
#     'control_efficiency': '16.9',
#     'treatment_efficiency': '18.9'}]},
#  '34': {'stability_tests': []},
#  '147': {'control_pce': 22.3,
#   'control_voc': 1.112,
#   'treated_pce': 24.7,
#   'treated_voc': 1.161,
#   'passivating_molecule': 'CBz-PAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'P3HT',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Damp heat test',
#     'temperature': 85,
#     'time': '1,000 h',
#     'humidity': '85% relative humidity',
#     'control_efficiency': 66.6,
#     'treatment_efficiency': 92.3},
#    {'test_name': 'MPP tracking',
#     'temperature': 45,
#     'time': '1,100 h',
#     'control_efficiency': 66.6,
#     'treatment_efficiency': 94.6}]},
#  '6': {'control_pce': '20.1',
#   'control_voc': '1.03',
#   'treated_pce': '15.3',
#   'treated_voc': '1.06',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'PEA2PbI4',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'null',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '100',
#     'time': '36',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-L',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '55',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '90',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'}]},
#  '97': {'treated_pce': '22.3',
#   'treated_voc': '1.17',
#   'passivating_molecule': 'Oleylamine (OAm)',
#   'perovskite_composition': 'Cs 0.05 (FA 0.92 MA 0.08) 0.95 Pb(I 0.92 Br 0.08) 3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '70-75 °C',
#     'time': '1,800 h',
#     'humidity': 'Air',
#     'control_efficiency': '22.3%',
#     'treatment_efficiency': '23.0%'}]},
#  '46': {'control_voc': 1.12,
#   'treated_pce': 20,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'PFN-P2',
#   'perovskite_composition': 'CsPbI0.05[(FAPbI3)0.89]',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': 25,
#     'time': '100 hours',
#     'humidity': 'air',
#     'control_efficiency': 19.83,
#     'treatment_efficiency': 20}]},
#  '135': {'control_pce': '25.6',
#   'control_voc': '1.19',
#   'treated_pce': '25.6',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'MeO-4PADBC',
#   'perovskite_composition': 'Perovskite (assumed standard formula)',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'MeO-4PADBC',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '65',
#     'time': '1200',
#     'control_efficiency': '25.6',
#     'treatment_efficiency': '90'}]},
#  '149': {'control_pce': '22.2',
#   'control_voc': '0.841',
#   'treated_pce': '24.3',
#   'treated_voc': '2.03',
#   'passivating_molecule': 'CF3-PA',
#   'perovskite_composition': 'FA0.75MA0.25Pb0.5Sn0.5I3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'VNPB',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '35',
#     'humidity': '30-50%',
#     'control_efficiency': '22.2',
#     'treatment_efficiency': '24.3'}]},
#  '1': {'control_pce': 20,
#   'control_voc': 1.18,
#   'treated_pce': 23.32,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'FA 1-x MA x PbI 3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 500,
#     'control_efficiency': 20,
#     'treatment_efficiency': 23.32}]},
#  '90': {'control_pce': 20.7,
#   'control_voc': 1.17,
#   'treated_pce': 20.7,
#   'treated_voc': 1.17,
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '41': {'control_pce': 20.71,
#   'control_voc': 1.135,
#   'treated_pce': 23.9,
#   'treated_voc': 1.157,
#   'passivating_molecule': 'o-PDEAI2',
#   'perovskite_composition': 'PDEAI2',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Humidity test',
#     'temperature': 40,
#     'time': '24 hours',
#     'humidity': '40-50% RH',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Thermal stability',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Module performance',
#     'temperature': 'Module performance',
#     'time': 'Module performance',
#     'humidity': 'Module performance',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 23.9}]}}

# %%
def drop_fake_stability(obj):
    for value in obj.values():
        if 'stability_tests' in value:
            value['stability_tests'] = [
                test for test in value['stability_tests'] if len(test.keys()) > 1
            ]
    return obj

# %%
filtered_llama_data = drop_fake_stability(filtered_llama_data)
filtered_llama_data
# Out:
# {'103': {'control_pce': 14.44,
#   'control_voc': 0.926,
#   'treated_pce': 23.7,
#   'treated_voc': 1.47,
#   'passivating_molecule': 'Methylenediammonium chloride (MDACl2)',
#   'perovskite_composition': 'FAPbI3 with 3.8 mol% MDACl2',
#   'electron_transport_layer': 'TiO2 (mesoporous)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuPC',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 600,
#     'humidity': '20-30%',
#     'control_efficiency': 14.44,
#     'treatment_efficiency': 23.7}]},
#  '77': {'control_pce': '21.2',
#   'control_voc': '1.07',
#   'treated_pce': '24.1',
#   'treated_voc': '1.14',
#   'passivating_molecule': 'PEAMAI',
#   'perovskite_composition': 'FA 0.9 Cs 0.1 PbI 3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '55',
#     'time': '800',
#     'humidity': 'N/A',
#     'control_efficiency': '90',
#     'treatment_efficiency': '90'},
#    {'test_name': 'ISOS-E',
#     'temperature': '85',
#     'time': '1500',
#     'humidity': 'N/A',
#     'control_efficiency': '20',
#     'treatment_efficiency': '90'}]},
#  '104': {'treated_pce': '25.2',
#   'treated_voc': '1196',
#   'passivating_molecule': 'methylammonium bromide (MAPbBr3)',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1I',
#     'temperature': '45',
#     'time': '3600',
#     'humidity': 'ambient',
#     'control_efficiency': '25.2',
#     'treatment_efficiency': '25.2'}]},
#  '79': {'control_pce': 19.9,
#   'control_voc': 1.09,
#   'treated_pce': 19.9,
#   'treated_voc': 1.09,
#   'passivating_molecule': 'PbI2',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '40 days',
#     'humidity': 'dry air',
#     'control_efficiency': 19.9,
#     'treatment_efficiency': 19.9}]},
#  '138': {'control_pce': 24.6,
#   'treated_pce': 25.3,
#   'passivating_molecule': '2PACz and 3-MPA',
#   'perovskite_composition': 'Cs0.05MA0.10FA0.85PbI3',
#   'electron_transport_layer': 'FTO',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': 65,
#     'time': 1000,
#     'humidity': '50% RH',
#     'control_efficiency': 24.6,
#     'treatment_efficiency': 24.8}]},
#  '144': {'control_pce': 19.3,
#   'control_voc': 0.76,
#   'treated_pce': 21.0,
#   'treated_voc': 0.88,
#   'passivating_molecule': 'GlyHCl',
#   'perovskite_composition': 'Cs0.1FA0.6MA0.3Sn0.5Pb0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': '100 days',
#     'humidity': 'controlled (glovebox)',
#     'control_efficiency': 19.3,
#     'treatment_efficiency': 21.0}]},
#  '37': {'control_pce': 0.19,
#   'control_voc': 1.35,
#   'treated_pce': 0.263,
#   'treated_voc': 2.19,
#   'passivating_molecule': '1,3-propanediammonium iodide',
#   'perovskite_composition': 'Cs0.2FA0.8Pb(I0.6Br0.4)3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient air',
#     'control_efficiency': 0.19,
#     'treatment_efficiency': 0.263},
#    {'test_name': 'ISOS-LT',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient air',
#     'control_efficiency': 0.19,
#     'treatment_efficiency': 0.263}]},
#  '143': {'control_pce': '18.09',
#   'control_voc': '1.16',
#   'treated_pce': '18.09',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'CuSCN',
#   'perovskite_composition': '(FAPbI3)0.77 (MAPbBr3)0.14 (CsPbI3)0.09',
#   'electron_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuSCN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '400 days',
#     'humidity': '40-70%',
#     'control_efficiency': '18.09',
#     'treatment_efficiency': '18.09'}]},
#  '30': {'control_pce': 10.92,
#   'control_voc': 1.16,
#   'treated_pce': 23.21,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'NH3',
#   'perovskite_composition': 'FACsPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'PTAB',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21},
#    {'test_name': 'ISOS-L',
#     'temperature': 100,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21},
#    {'test_name': 'ISOS-T',
#     'temperature': -15,
#     'time': 'N/A',
#     'humidity': 'N/A',
#     'control_efficiency': 10.92,
#     'treatment_efficiency': 23.21}]},
#  '2': {'control_pce': 0.2239,
#   'control_voc': 1098,
#   'treated_pce': 0.2459,
#   'treated_voc': 1185,
#   'passivating_molecule': '(BA)2PbI4',
#   'perovskite_composition': '(BA)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1056,
#     'humidity': '85% relative humidity',
#     'control_efficiency': 0.2239,
#     'treatment_efficiency': 0.2435}]},
#  '93': {'treated_pce': 20.5,
#   'perovskite_composition': 'FA1-x MAx PbI2.87 Br0.13(Cl)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '131': {'control_pce': '25.5%',
#   'control_voc': '1.208 V',
#   'treated_pce': '25.5%',
#   'treated_voc': '1.208 V',
#   'passivating_molecule': 'Al2O3',
#   'perovskite_composition': '1.55 eV',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz/PTAA',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '85°C',
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '98%',
#     'treatment_efficiency': '20%'}]},
#  '42': {'control_pce': 19.52,
#   'control_voc': 1.07,
#   'treated_pce': 22.03,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'AzPbI3',
#   'perovskite_composition': 'Cs0.05 MA0.1 FA0.85 PbI2.7 Br0.3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 52,
#     'time': 1000,
#     'control_efficiency': 47,
#     'treatment_efficiency': 85}]},
#  '5': {'control_pce': 22.1,
#   'control_voc': 1135,
#   'treated_pce': 22.1,
#   'treated_voc': 1205,
#   'passivating_molecule': 'iso-BAI and n-BAI',
#   'perovskite_composition': 'FA(MA)PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '94': {'control_pce': '19.11',
#   'control_voc': '1.112',
#   'treated_pce': '20.6',
#   'treated_voc': '1.129',
#   'passivating_molecule': 'P4VP',
#   'perovskite_composition': 'Perovskite',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'P4VP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25-40 °C',
#     'time': '6000 h',
#     'humidity': '25-50% RH',
#     'control_efficiency': '19.11',
#     'treatment_efficiency': '20.6'}]},
#  '136': {'control_pce': '25.4',
#   'control_voc': '1.21',
#   'treated_pce': '23.4',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'MPA-CPA',
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'MPA-CPA',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '45',
#     'time': '500 hours',
#     'humidity': '30-40% RH',
#     'control_efficiency': '25.4',
#     'treatment_efficiency': '23.4'},
#    {'test_name': 'damp heat',
#     'temperature': '85',
#     'time': '500 hours',
#     'humidity': '85% RH',
#     'control_efficiency': '25.4',
#     'treatment_efficiency': '23.4'}]},
#  '45': {'control_pce': '25.1',
#   'treated_pce': '25.1',
#   'perovskite_composition': 'poly-Si/c-Si',
#   'electron_transport_layer': 'c-Si',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'p-poly-Si',
#   'stability_tests': []},
#  '39': {'control_pce': 20.7,
#   'control_voc': 1.09,
#   'treated_pce': 20.82,
#   'treated_voc': 1.193,
#   'passivating_molecule': '2-TMABr',
#   'perovskite_composition': '[ (FAPbI3)0.87 (MAPbBr3)0.13 ]0.92 (CsPbI3)0.08',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 25,
#     'time': 1000,
#     'humidity': 'inert atmosphere (Ar)',
#     'control_efficiency': 20.7,
#     'treatment_efficiency': 20.82}]},
#  '127': {'control_pce': 18.5,
#   'control_voc': 1.048,
#   'treated_pce': 24.1,
#   'treated_voc': 1.198,
#   'passivating_molecule': 'tris(2,4-di-tert-butylphenyl) phosphite (TPPi)',
#   'perovskite_composition': 'PEA2ZnX4 (X = Cl/I)',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'Standard thermal stability test',
#     'temperature': 85,
#     'time': '1009 hours',
#     'humidity': 'controlled environment',
#     'control_efficiency': 18.5,
#     'treatment_efficiency': 24.1}]},
#  '54': {'passivating_molecule': 'Methylammonium iodide or bromide',
#   'perovskite_composition': 'Mixed halide perovskite (e.g., MAPbI3, MAPbBr3)',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': []},
#  '85': {'control_pce': 16,
#   'control_voc': 0.8,
#   'treated_pce': 22.7,
#   'treated_voc': 1.0,
#   'passivating_molecule': 'n-hexyl trimethyl ammonium bromide',
#   'perovskite_composition': 'FAPbI3:MAPbBr3:HTAB = 0.3:0.95:0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'P3HT',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1008,
#     'humidity': '85%',
#     'control_efficiency': 80,
#     'treatment_efficiency': 0}]},
#  '28': {'control_pce': 0.17,
#   'control_voc': 1.2,
#   'treated_pce': 0.17,
#   'treated_voc': 1.2,
#   'perovskite_composition': 'CsPbI3',
#   'electron_transport_layer': 'TPBi',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '120': {'control_pce': 23.0,
#   'control_voc': 1.13,
#   'treated_pce': 25.0,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'ferrocenyl-bis-thiophene-2-carboxylate',
#   'perovskite_composition': '(FA0.98MA0.02)0.95Cs0.05Pb(I0.95Br0.02)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'poly(triaryl amine)',
#   'stability_tests': [{'test_name': 'IEC61215:2016',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 72,
#     'treatment_efficiency': 98}]},
#  '53': {'control_pce': '4.9%',
#   'treated_pce': '24.7%',
#   'passivating_molecule': 'DMePDAI2',
#   'perovskite_composition': 'FA0.85MA0.1Cs0.05PbI2.9Br0.1',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': '40°C',
#     'time': '1000 hours',
#     'humidity': 'N2',
#     'control_efficiency': '20.5%',
#     'treatment_efficiency': '23.1%'}]},
#  '82': {'control_pce': '17.1',
#   'control_voc': '1.04',
#   'treated_pce': '20.59',
#   'treated_voc': '1.13',
#   'passivating_molecule': 'Choline chloride',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Humidity stability test',
#     'time': 'Over one month',
#     'humidity': '50-85% RH',
#     'control_efficiency': '17.1%',
#     'treatment_efficiency': '20.59%'}]},
#  '21': {'control_pce': 22.6,
#   'treated_pce': 19.14,
#   'passivating_molecule': 'LP layer',
#   'perovskite_composition': '3D perovskite',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'ambient',
#     'control_efficiency': 22.6,
#     'treatment_efficiency': 19.14}]},
#  '129': {'control_pce': 24.8,
#   'control_voc': 1.19,
#   'treated_pce': 24.5,
#   'treated_voc': 1.19,
#   'passivating_molecule': 'GBAC',
#   'perovskite_composition': 'Cs0.06MA0.14FA0.80PbI3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'DC-PA',
#   'stability_tests': [{'test_name': 'JET certification',
#     'temperature': 65,
#     'time': 1200,
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': 24.5,
#     'treatment_efficiency': 24.5},
#    {'test_name': 'Thermal stability',
#     'temperature': 65,
#     'time': 1200,
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': 24.8,
#     'treatment_efficiency': 24.8}]},
#  '13': {'control_pce': 25.7,
#   'control_voc': 1.15,
#   'treated_pce': 15.1,
#   'treated_voc': 1.29,
#   'passivating_molecule': '2-thiopheneethylammonium chloride',
#   'perovskite_composition': 'Cs0.12FA0.8PbI1.8Br1.2',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': '2PACz',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 265,
#     'humidity': 'ambient',
#     'control_efficiency': 13.1,
#     'treatment_efficiency': 15.1}]},
#  '14': {'control_pce': 25.5,
#   'control_voc': 1.184,
#   'treated_pce': 23.7,
#   'treated_voc': 1.184,
#   'passivating_molecule': 'F-PEAI',
#   'perovskite_composition': 'Cs0.1FA0.9PbI2.9Br0.1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '68': {'control_pce': 12.8,
#   'control_voc': 0.95,
#   'treated_pce': 12.8,
#   'treated_voc': 0.95,
#   'passivating_molecule': 'SnOx',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'AZO',
#   'stability_tests': [{'temperature': 60,
#     'time': 1000,
#     'humidity': 'ambient air',
#     'control_efficiency': 12.8,
#     'treatment_efficiency': 12.8}]},
#  '66': {'control_pce': 25.5,
#   'control_voc': 0.8,
#   'treated_pce': 45,
#   'treated_voc': 0.8,
#   'perovskite_composition': 'Cs0.15FA0.85PbI2.55Br0.45',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'damp heat',
#     'temperature': 85,
#     'time': 1000,
#     'humidity': '85% RH',
#     'control_efficiency': 25.5,
#     'treatment_efficiency': 45}]},
#  '115': {'control_pce': '24.04',
#   'control_voc': '0.08 cm²',
#   'treated_pce': '23.15',
#   'treated_voc': '23.15',
#   'passivating_molecule': 'anisole',
#   'perovskite_composition': 'FA1-x-yMAxCsyPbI3-zBrz',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '95%',
#     'treatment_efficiency': '75%'},
#    {'test_name': 'SPO',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '5%',
#     'treatment_efficiency': '20%'}]},
#  '61': {'passivating_molecule': 'butylamine',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'temperature': 85,
#     'time': '125 hours',
#     'humidity': 'N2 atmosphere'}]},
#  '112': {'control_pce': 21.8,
#   'control_voc': 1.14,
#   'treated_pce': 23.2,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Benzylhydrazine hydrochloride (BHC)',
#   'perovskite_composition': 'MA0.7FA0.3PbI3',
#   'electron_transport_layer': 'Poly[bis(4-phenyl)(2,4,6-trimethylphenyl)amine] (PTAA)',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'Indium tin oxide (ITO)',
#   'stability_tests': [{'test_name': 'Stability under AM 1.5G light',
#     'temperature': 65,
#     'time': '1000 hours',
#     'humidity': '60% ± 10%',
#     'control_efficiency': 19.2,
#     'treatment_efficiency': 23.2}]},
#  '4': {'control_pce': '19.93',
#   'control_voc': '1.06',
#   'treated_pce': '21.90',
#   'treated_voc': '1.14',
#   'passivating_molecule': '4-vinylbenzylammonium bromide (VBABr)',
#   'perovskite_composition': '[[(VBABr)₂ (FA₉₅MA₀₅)ₙ₋₁ Pb₃ₙ₊₁]',
#   'electron_transport_layer': 'SnO₂',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '95': {'treated_pce': 22.9,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'octylammonium iodide',
#   'perovskite_composition': 'FAPbI3·0.95 and MAPbBr3·0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 65,
#     'time': '100 hours',
#     'humidity': '65% RH',
#     'treatment_efficiency': 22.9},
#    {'test_name': 'ISOS-H',
#     'temperature': 85,
#     'time': '100 hours',
#     'humidity': '85% RH'}]},
#  '137': {'control_pce': 23.0,
#   'control_voc': 1.12,
#   'treated_pce': 25.5,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'PDAI2 and 3MTPAI',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.90PbI3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx/4PACz',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1600,
#     'humidity': 'Nitrogen',
#     'control_efficiency': 23.0,
#     'treatment_efficiency': 25.5},
#    {'test_name': 'ISOS-L',
#     'temperature': 65,
#     'time': 2000,
#     'humidity': 'Air with 50% RH',
#     'control_efficiency': 23.0,
#     'treatment_efficiency': 25.5}]},
#  '44': {'control_pce': 25.8,
#   'control_voc': 731,
#   'treated_pce': 21.12,
#   'perovskite_composition': 'SiOx',
#   'electron_transport_layer': 'n+ poly-Si',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'n+ poly-Si'},
#  '3': {'control_pce': 24.5,
#   'control_voc': 1.2,
#   'treated_pce': 24.5,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'BA2MA2Pb3I10',
#   'perovskite_composition': 'Cs0.05(MA0.10FA0.85)Pb(I0.90Br0.10)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': 55,
#     'time': 2000,
#     'humidity': '70% RH',
#     'control_efficiency': 21,
#     'treatment_efficiency': 22.93}]},
#  '92': {'treated_pce': 21.3,
#   'passivating_molecule': 'BaSnO3',
#   'perovskite_composition': 'BaSnO3',
#   'electron_transport_layer': 'BaSnO3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD, PTAA',
#   'stability_tests': [{'temperature': 25,
#     'time': '24 hours',
#     'humidity': '40% RH',
#     'control_efficiency': 21.3,
#     'treatment_efficiency': 21.7}]},
#  '130': {'control_pce': 22.9,
#   'control_voc': 1.1,
#   'treated_pce': 25.4,
#   'treated_voc': 1.15,
#   'passivating_molecule': 'Pentanamidine hydrochloride (PAD)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 30,
#     'time': '1000 h',
#     'humidity': 'ambient',
#     'control_efficiency': 22.9,
#     'treatment_efficiency': 25.4},
#    {'test_name': 'ISOS-L',
#     'temperature': 65,
#     'time': '500 h',
#     'humidity': '85% RH',
#     'control_efficiency': 22.9,
#     'treatment_efficiency': 25.4}]},
#  '43': {'control_pce': '24.50%',
#   'control_voc': '1.150 V',
#   'treated_pce': '24.50%',
#   'treated_voc': '1.121 V',
#   'passivating_molecule': 'Benzylamine hydroiodide (BAHI)',
#   'perovskite_composition': 'FA0.90MA0.10PbI3•(CsPbI3)0.05 with excess PbI2',
#   'electron_transport_layer': 'TiO2 (mesoporous)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '80 °C',
#     'time': '500 h',
#     'humidity': '20-30% RH',
#     'control_efficiency': '24.50%',
#     'treatment_efficiency': '47.96 ± 3.21%'}]},
#  '142': {'control_pce': 13.15,
#   'treated_pce': 16.13,
#   'passivating_molecule': 'formamidinium iodide (FAI)',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Modified BA2MA(n)Pb(n+1)I3n+1',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 65,
#     'time': '50 days',
#     'humidity': '65%',
#     'control_efficiency': 71},
#    {'test_name': 'ISOS-T',
#     'temperature': 85,
#     'time': '30 days',
#     'control_efficiency': 74},
#    {'test_name': 'ISOS-L', 'time': '24 hours', 'control_efficiency': 90}]},
#  '31': {'control_pce': 23.39,
#   'control_voc': 1.12,
#   'treated_pce': 25.49,
#   'treated_voc': 1.19,
#   'passivating_molecule': '3-aminomethyl pyridine (3-APy)',
#   'perovskite_composition': 'Rb0.05 Cs0.05 MA0.05 FA0.85 PbI0.95 Br0.05',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '850 hours',
#     'humidity': '85% relative humidity',
#     'control_efficiency': '22.85%',
#     'treatment_efficiency': '25.35%'},
#    {'test_name': 'ISOS-L',
#     'temperature': 55,
#     'time': '2,400 hours',
#     'humidity': 'air',
#     'control_efficiency': '22.3%',
#     'treatment_efficiency': '24.6%'}]},
#  '139': {'control_pce': 25.2,
#   'control_voc': 1.145,
#   'treated_pce': 26.1,
#   'treated_voc': 1.164,
#   'passivating_molecule': '1-(phenylsulfonyl)pyrrole',
#   'perovskite_composition': 'FA0.95Cs0.05PbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '2500h',
#     'humidity': '85%RH',
#     'control_efficiency': 80,
#     'treatment_efficiency': 92}]},
#  '145': {'control_pce': 17.08,
#   'control_voc': 1.02,
#   'treated_pce': 20.48,
#   'treated_voc': 1.13,
#   'passivating_molecule': '4-fluoroaniline (FAL)',
#   'perovskite_composition': 'Cs0.05(MA0.17FA0.83)0.95PbI0.83Br0.17',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 66,
#     'humidity': '85-95% RH',
#     'control_efficiency': 17.08,
#     'treatment_efficiency': 20.48},
#    {'test_name': 'ISOS-L',
#     'temperature': 85,
#     'time': 100,
#     'humidity': '85% RH'}]},
#  '36': {'control_pce': '20%',
#   'control_voc': '0.23 V',
#   'treated_pce': '19.6%',
#   'treated_voc': '0.19 V',
#   'passivating_molecule': 'C60',
#   'perovskite_composition': 'Cs0.05(FA0.83MA0.17)0.95Pb(I0.83Br0.17)3',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'pin',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '-20°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'},
#    {'test_name': 'ISOS-L',
#     'temperature': '80°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'},
#    {'test_name': 'ISOS-T',
#     'temperature': '-10°C',
#     'time': '1h',
#     'humidity': '30% RH',
#     'control_efficiency': '20%',
#     'treatment_efficiency': '19.6%'}]},
#  '78': {'control_voc': 1.06,
#   'treated_pce': 20.2,
#   'treated_voc': 1.06,
#   'passivating_molecule': 'DMSO',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '76': {'perovskite_composition': '2D lead halide perovskites',
#   'electron_transport_layer': 'organic spacer ligands',
#   'pin_nip_structure': '2D',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 140,
#     'time': '60 min',
#     'humidity': 'dry'},
#    {'test_name': 'ISOS-L',
#     'temperature': 23,
#     'time': 'room temperature',
#     'humidity': 'dry'}]},
#  '105': {'control_pce': '21.65%',
#   'control_voc': '1.172 V',
#   'treated_pce': '23.33%',
#   'treated_voc': '1.193 V',
#   'passivating_molecule': 'PMMA:PCBM',
#   'perovskite_composition': 'TiOxNy',
#   'electron_transport_layer': 'TiOxNy',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'P3HT:CuPc',
#   'stability_tests': [{'test_name': 'damp-heat',
#     'temperature': '85',
#     'time': '1000 hours',
#     'humidity': '85% relative humidity',
#     'control_efficiency': '96.5%',
#     'treatment_efficiency': '98.7%'}]},
#  '71': {'control_pce': 5,
#   'control_voc': 0.05,
#   'treated_pce': 15.3,
#   'treated_voc': 1.7,
#   'passivating_molecule': '(BA)2(MA)3Pb4I13',
#   'perovskite_composition': '(BA)2(MA)3Pb4I13',
#   'electron_transport_layer': 'BA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 260},
#    {'test_name': 'ISOS-L', 'temperature': 240}]},
#  '102': {'control_pce': 17.87,
#   'control_voc': 1.05,
#   'treated_pce': 21.07,
#   'treated_voc': 1.12,
#   'passivating_molecule': 'MACl',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': []},
#  '113': {'treated_pce': 25.8,
#   'treated_voc': 1.1885,
#   'passivating_molecule': 'FASnCl x',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1I',
#     'temperature': 25,
#     'time': 500,
#     'control_efficiency': 25.5,
#     'treatment_efficiency': 25.8}]},
#  '67': {'passivating_molecule': 'formamidinium (FA)',
#   'perovskite_composition': 'FAPbI3 and CsPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L1',
#     'temperature': 298,
#     'time': '1000 hours',
#     'humidity': '25% RH'},
#    {'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH'},
#    {'test_name': 'ISOS-L2',
#     'temperature': 65,
#     'time': '1000 hours',
#     'humidity': '60% RH'},
#    {'test_name': 'ISOS-L3',
#     'temperature': 110,
#     'time': '2000 hours',
#     'humidity': 'unknown'}]},
#  '114': {'control_pce': 20.76,
#   'control_voc': 1.06,
#   'treated_pce': 23.37,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Piperazinium iodide (PI)',
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': []},
#  '15': {'control_pce': '21.78',
#   'control_voc': '1.11',
#   'treated_pce': '23.34',
#   'treated_voc': '1.15',
#   'passivating_molecule': 'Cl-PEAI and F-PEAI',
#   'perovskite_composition': 'Cs0.05(FA5/6MA1/6)0.95PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '69': {'passivating_molecule': 'SnOx',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'Al:ZnO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PEDOT:PSS',
#   'stability_tests': [{'temperature': 25, 'humidity': '60% RH'}]},
#  '12': {'control_pce': 16.7,
#   'control_voc': 1.23,
#   'treated_pce': 19.4,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylammonium bromide (BABr)',
#   'perovskite_composition': 'Cs0.17 FA0.83 Pb(I0.6 Br0.4)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'J-V measurements',
#     'temperature': 25,
#     'time': 'continuous illumination',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4},
#    {'test_name': 'PCE under different treatments',
#     'temperature': 25,
#     'time': 'under constant voltage',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4}]},
#  '128': {'control_pce': '24.6',
#   'control_voc': '1.16',
#   'treated_pce': '25.12',
#   'treated_voc': '1.165',
#   'passivating_molecule': '2-aminoindan hydrochloride (AICl)',
#   'perovskite_composition': 'Cs0.05FA0.95PbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '85',
#     'time': '1200 hours',
#     'humidity': '85% RH',
#     'control_efficiency': '24.32',
#     'treatment_efficiency': '24.58'},
#    {'test_name': 'ISOS-D',
#     'temperature': '55',
#     'time': '1500 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '21.73',
#     'treatment_efficiency': '24.42'}]},
#  '27': {'control_pce': '14.4',
#   'control_voc': '1.01',
#   'treated_pce': '18.5',
#   'treated_voc': '1.23',
#   'passivating_molecule': 'CF3-PEA',
#   'perovskite_composition': 'CsPbI3-xBrx',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '25',
#     'time': '1000',
#     'humidity': 'ambient',
#     'control_efficiency': '14.4',
#     'treatment_efficiency': '18.5'}]},
#  '20': {'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'MAPbI3, (PEA)2PbI4',
#   'electron_transport_layer': 'PMMA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '121': {'control_pce': '26.08',
#   'treated_pce': '25.73',
#   'passivating_molecule': 'formamidinium lead iodide (FAPbI3)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'temperature': '60-80 °C',
#     'time': '40 min',
#     'humidity': 'controlled',
#     'control_efficiency': '26.08%',
#     'treatment_efficiency': '25.73%'}]},
#  '52': {'control_pce': '19.1%',
#   'control_voc': '658.4 mV',
#   'passivating_molecule': 'Al2O3',
#   'perovskite_composition': 'CH3NH3Pb',
#   'electron_transport_layer': 'Al-BSF',
#   'pin_nip_structure': 'PERC',
#   'hole_transport_layer': 'Al-BSF'},
#  '83': {'control_pce': '21.3',
#   'control_voc': '1.13',
#   'treated_pce': '21.38',
#   'treated_voc': '1.12',
#   'passivating_molecule': 'MAI and FA',
#   'perovskite_composition': 'MAPbI3 and FA0.15MA0.85PbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '792 hours',
#     'humidity': '40 ± 10%',
#     'control_efficiency': '21.3',
#     'treatment_efficiency': '21.38'}]},
#  '126': {'control_pce': 23.43,
#   'control_voc': 1.16,
#   'treated_pce': 25.39,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'PbC2O4',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': 550,
#     'humidity': 'ambient air',
#     'control_efficiency': 92,
#     'treatment_efficiency': 92}]},
#  '55': {'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'},
#    {'test_name': 'ISOS-L',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'}]},
#  '84': {'control_pce': 21.6,
#   'control_voc': 1.24,
#   'treated_pce': 23.2,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'DM',
#   'perovskite_composition': '(FAPbI3)0.95 (MAPbBr3)0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'DM',
#   'stability_tests': [{'test_name': 'thermal stability test',
#     'temperature': 60,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 70,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 80,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3}]},
#  '29': {'passivating_molecule': 'butylamine',
#   'perovskite_composition': 'PbI2-based',
#   'electron_transport_layer': 'linear PEI',
#   'stability_tests': []},
#  '18': {'control_pce': '26%',
#   'passivating_molecule': 'TMAI',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'SnO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'lower'},
#    {'test_name': 'ISOS-L',
#     'temperature': 100,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'higher'}]},
#  '117': {'control_pce': 22.2,
#   'control_voc': 1.15,
#   'treated_pce': 25.1,
#   'treated_voc': 1.17,
#   'passivating_molecule': '4-tert-butyl-1-methylpyridinium bis(trifluoromethanesulfonyl)imide (TBMP + TFSI -)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Stability test',
#     'temperature': '70 ± 5% RH',
#     'time': 'Long-term exposure',
#     'humidity': 'High relative humidity',
#     'control_efficiency': '22.2%',
#     'treatment_efficiency': '25.1%'}]},
#  '64': {'control_pce': 18.6,
#   'control_voc': 1057,
#   'treated_pce': 17.0,
#   'treated_voc': 1062,
#   'passivating_molecule': 'PEA2PbI4',
#   'perovskite_composition': 'Both MAPI and PEA2PbI4',
#   'electron_transport_layer': 'MoO3 and TATM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60'},
#  '110': {'control_pce': '23.92',
#   'control_voc': '1.15',
#   'treated_pce': '25.6',
#   'treated_voc': '1.21',
#   'passivating_molecule': 'formate',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'm-TiO2',
#   'stability_tests': [{'test_name': 'stability tests',
#     'temperature': '25 °C',
#     'time': '1000 h',
#     'humidity': '20% relative humidity',
#     'control_efficiency': '23.92',
#     'treatment_efficiency': '25.6'}]},
#  '11': {'control_pce': '20.2',
#   'control_voc': '1.11',
#   'treated_pce': '21.8',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'BTaBr',
#   'perovskite_composition': '(BTa)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '24 hours',
#     'humidity': 'ambient air',
#     'control_efficiency': '21.8',
#     'treatment_efficiency': '21.8'}]},
#  '16': {'control_pce': 18.87,
#   'control_voc': 1.04,
#   'treated_pce': 21.05,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'CF3PEAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '119': {'control_pce': 20.5,
#   'control_voc': 1.09,
#   'treated_pce': 23.9,
#   'treated_voc': 1.15,
#   'passivating_molecule': '1,1,2,2,3,3-hexafluoropropane-1,3-disulfonimide',
#   'perovskite_composition': 'formamidinium-based perovskite',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'HFDF',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 200,
#     'humidity': 'Not specified',
#     'control_efficiency': 23.9,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'ISOS-L',
#     'temperature': 85,
#     'time': 1000,
#     'humidity': 'Not specified',
#     'control_efficiency': 20.5,
#     'treatment_efficiency': 21.2}]},
#  '23': {'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'Cs0.05MA0.1FA0.85PbI3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L3',
#     'temperature': '65°C',
#     'time': '500 hours',
#     'humidity': 'Not explicitly mentioned',
#     'control_efficiency': '23.91%',
#     'treatment_efficiency': '92% of initial PCE'}]},
#  '58': {'control_pce': '25.5%',
#   'treated_pce': '18.5%',
#   'passivating_molecule': 'PCBM',
#   'perovskite_composition': 'FA0.83Cs0.17PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'poly-TPD or NiOx',
#   'stability_tests': []},
#  '89': {'treated_pce': '20.87%',
#   'treated_voc': '413 mV',
#   'passivating_molecule': 'formamidine acetate (FAAc)',
#   'perovskite_composition': '(FA, MA, Cs)Pb(I, Br)3'},
#  '24': {'control_pce': '14.9',
#   'treated_pce': '17.4',
#   'passivating_molecule': 'Cs2PbI2Cl2',
#   'perovskite_composition': 'CsPbI3',
#   'electron_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'CuSCN',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': 110,
#     'time': 2100,
#     'control_efficiency': 14.9,
#     'treatment_efficiency': 17.4}]},
#  '56': {'control_pce': 25.5,
#   'control_voc': 1.22,
#   'treated_pce': 20.5,
#   'treated_voc': 1.22,
#   'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '125': {'control_pce': '91%',
#   'control_voc': '1.14 V',
#   'treated_pce': '23.7%',
#   'treated_voc': '1.14 V',
#   'passivating_molecule': 'Selenophene',
#   'perovskite_composition': 'FA0.9Cs0.1PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85°C',
#     'time': '3190 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '91%',
#     'treatment_efficiency': '91%'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '1000 hours',
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': '45°C',
#     'time': '500 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': '80%',
#     'treatment_efficiency': '80%'}]},
#  '87': {'treated_pce': 21.52,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'FAI',
#   'perovskite_composition': 'CsI:20 mg, PbI2:530 mg, PbBr2:20 mg, PbCl2:20 mg, MAI:5 mg',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'temperature': 85,
#     'time': 1500,
#     'control_efficiency': 100,
#     'treatment_efficiency': 89}]},
#  '51': {'control_pce': '25%',
#   'treated_pce': '2x',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN'},
#  '122': {'control_pce': 25.6,
#   'control_voc': 1.182,
#   'treated_pce': 25.6,
#   'treated_voc': 1.182,
#   'passivating_molecule': '(PbI2)2RbCl',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'thermal stability test',
#     'temperature': 85,
#     'time': 500,
#     'humidity': 'Unknown',
#     'control_efficiency': 80,
#     'treatment_efficiency': 96}]},
#  '80': {'control_pce': 21.6,
#   'control_voc': 1.14,
#   'treated_pce': 21.6,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'PMMA',
#   'perovskite_composition': 'Mixed cation perovskite (FAI, PbI2, MABr, PbBr2)',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': '2 months',
#     'humidity': 'ambient air',
#     'control_efficiency': 21.0,
#     'treatment_efficiency': 21.0}]},
#  '0': {'control_pce': '25.5',
#   'control_voc': '1.17',
#   'treated_pce': '24.7',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'formamidinium lead triiodide (FAPbI3)',
#   'electron_transport_layer': 'Cs2O',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '1500',
#     'humidity': '50',
#     'control_efficiency': '19.9',
#     'treatment_efficiency': '95'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65',
#     'time': '1200',
#     'humidity': '50',
#     'control_efficiency': '23.2',
#     'treatment_efficiency': '91'}]},
#  '91': {'control_pce': '19.66',
#   'control_voc': '1.027',
#   'treated_pce': '24.02',
#   'treated_voc': '1.130',
#   'passivating_molecule': 'methylammonium chloride (MACl)',
#   'perovskite_composition': 'formamidinium lead iodide (FAPbI3)',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '1200 hours',
#     'humidity': 'Room temperature',
#     'control_efficiency': '90',
#     'treatment_efficiency': '90'},
#    {'test_name': 'ISOS-L',
#     'temperature': 40,
#     'time': '300 hours',
#     'humidity': '40°C',
#     'control_efficiency': '60',
#     'treatment_efficiency': '90'}]},
#  '40': {'control_pce': 24.3,
#   'control_voc': 1.2,
#   'treated_pce': 24.3,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'Oleylammonium iodide (OLAI)',
#   'perovskite_composition': 'Cs0.03(FA0.90MA0.10)PbI3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'damp-heat',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 24.3,
#     'treatment_efficiency': 19.3}]},
#  '133': {'control_pce': '22.34%',
#   'control_voc': '1.14 V',
#   'treated_pce': '24.04%',
#   'treated_voc': '1.19 V',
#   'passivating_molecule': 'Sodium thioglycolate',
#   'perovskite_composition': 'FA0.75MA0.25PbI3',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Me-4PACz',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '25 °C',
#     'time': '900 hours',
#     'humidity': 'controlled',
#     'control_efficiency': '22.34%',
#     'treatment_efficiency': '24.04%'},
#    {'test_name': 'AM1.5G',
#     'temperature': '25 °C',
#     'time': '800 hours',
#     'humidity': 'controlled',
#     'control_efficiency': '22.25%',
#     'treatment_efficiency': '23.5%'}]},
#  '7': {'control_pce': 23.5,
#   'control_voc': 1.2,
#   'treated_pce': 28.7,
#   'treated_voc': 1.5,
#   'passivating_molecule': '4-FPEA',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Au',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '24 hours',
#     'humidity': '50% RH',
#     'control_efficiency': 22.5,
#     'treatment_efficiency': 28.7},
#    {'test_name': 'ISOS-L',
#     'temperature': 60,
#     'time': '48 hours',
#     'humidity': '30% RH',
#     'control_efficiency': 23.5,
#     'treatment_efficiency': 28.7}]},
#  '96': {'control_pce': 22.19,
#   'control_voc': 1.13,
#   'treated_pce': 16.7,
#   'passivating_molecule': 'tin(II) acetylacetonate',
#   'perovskite_composition': 'lead halide perovskite',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 160,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 200,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 220,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7},
#    {'test_name': 'ISOS-D',
#     'temperature': 350,
#     'time': '1 hour',
#     'humidity': 'controlled',
#     'control_efficiency': 22.19,
#     'treatment_efficiency': 16.7}]},
#  '47': {'treated_pce': 21.1,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'PbSO4',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 65,
#     'time': '1200 hours',
#     'humidity': 'air, RH ~60%',
#     'control_efficiency': 21.1,
#     'treatment_efficiency': 96.8}]},
#  '134': {'control_pce': 23.13,
#   'control_voc': 1.141,
#   'treated_pce': 25.08,
#   'treated_voc': 1.174,
#   'passivating_molecule': 'Guanabenz acetate salt',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Moisture stability test',
#     'temperature': 55,
#     'time': '24 hours',
#     'humidity': '55% RH',
#     'control_efficiency': 23.13,
#     'treatment_efficiency': 25.32},
#    {'test_name': 'Damp heat test',
#     'temperature': 85,
#     'time': '300 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 23.13,
#     'treatment_efficiency': 25.08}]},
#  '148': {'control_pce': 20.1,
#   'control_voc': 1.077,
#   'treated_pce': 23.5,
#   'treated_voc': 1.142,
#   'passivating_molecule': '4-tert-butylbenzylammonium iodide (tBBAI)',
#   'perovskite_composition': 'Cs0.05FA0.85MA0.10PbI0.97Br0.03',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 50,
#     'time': '500 hours',
#     'humidity': '50-70% RH',
#     'control_efficiency': 20.1,
#     'treatment_efficiency': 23.5}]},
#  '9': {'control_pce': 14.64,
#   'treated_pce': 17.6,
#   'passivating_molecule': 'C8',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'NiOx'},
#  '98': {'control_pce': '24.2',
#   'control_voc': '1.28',
#   'treated_pce': '21.54',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'FN-Br',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'MPP under 1-sun illumination',
#     'temperature': '25',
#     'time': '500',
#     'humidity': 'Ambient air',
#     'control_efficiency': '21.54',
#     'treatment_efficiency': '20.24'}]},
#  '49': {'control_pce': '13.81',
#   'control_voc': '1.12',
#   'treated_pce': '16.25',
#   'treated_voc': '1.31',
#   'passivating_molecule': 'n-butylamine acetate (BAAc)',
#   'perovskite_composition': '(BA)2(MA)n-1Pb3n+1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '558',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '13.81',
#     'treatment_efficiency': '16.25'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65 ± 10%',
#     'time': '4680',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '49.4',
#     'treatment_efficiency': '93.8'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '85',
#     'time': '1100',
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': '70.8',
#     'treatment_efficiency': '96.2'}]},
#  '35': {'perovskite_composition': 'CsPbI3_0.05(FAPbI3_0.83MAPbBr3_0.17)_0.95',
#   'electron_transport_layer': 'C60, PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PEDOT:PSS, PC61BM',
#   'stability_tests': []},
#  '146': {'control_pce': 21.5,
#   'control_voc': 1.128,
#   'treated_pce': 23.04,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'CB-NH2',
#   'perovskite_composition': 'Cs0.05FA0.95PbI0.95Br0.05',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': 40,
# ...
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 100,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6},
#    {'test_name': 'ISOS-LT',
#     'temperature': 60,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6}]},
#  '59': {'control_pce': '19.07',
#   'control_voc': '1.25',
#   'treated_pce': '19.07',
#   'treated_voc': '1.25',
#   'passivating_molecule': 'phenethylammonium iodide',
#   'perovskite_composition': 'FA0.8Cs0.2PbI0.7Br0.3',
#   'electron_transport_layer': 'poly(triarylamine)',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '88': {'control_pce': 19.03,
#   'control_voc': 0.92,
#   'treated_pce': 21.46,
#   'treated_voc': 0.94,
#   'passivating_molecule': 'NaF',
#   'perovskite_composition': 'Cs0.05FA0.54MA0.41PbI0.98Br0.02)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1000,
#     'control_efficiency': 19.03,
#     'treatment_efficiency': 21.46}]},
#  '25': {'passivating_molecule': 'formamidinium',
#   'perovskite_composition': 'FAPbI3, FAPbBr3',
#   'stability_tests': []},
#  '22': {'control_pce': 25.5,
#   'control_voc': 1.092,
#   'treated_pce': 24.0,
#   'treated_voc': 1.154,
#   'passivating_molecule': 'Cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PCBM',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 50,
#     'time': 500,
#     'humidity': '40 ± 10%',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 93},
#    {'test_name': 'ISOS-L',
#     'temperature': 50,
#     'time': 500,
#     'humidity': '40 ± 10%',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 93}]},
#  '17': {'control_pce': 25.2,
#   'control_voc': 1.16,
#   'treated_pce': 22.02,
#   'treated_voc': 1.19,
#   'passivating_molecule': 'hexyltrimethylammonium bromide',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': '1F-PTAA',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': '1F-PTAA',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '90 min',
#     'humidity': 'N2-filled glove-box',
#     'control_efficiency': 20.04,
#     'treatment_efficiency': 22.16}]},
#  '118': {'control_pce': 0.1961,
#   'control_voc': 1.16,
#   'treated_pce': 0.2154,
#   'treated_voc': 1.24,
#   'passivating_molecule': 'n-Butylammonium bromide (BABr)',
#   'perovskite_composition': '1.63 eV bandgap system (RbCsMAFA)',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 35,
#     'time': '24 h',
#     'humidity': '20-30% RH',
#     'control_efficiency': 0.1961,
#     'treatment_efficiency': 0.2154},
#    {'test_name': 'ISOS-L',
#     'temperature': 60,
#     'time': '500 h',
#     'humidity': '30-40% RH',
#     'control_efficiency': 0.1961,
#     'treatment_efficiency': 0.2154}]},
#  '10': {'treated_pce': 24.41,
#   'treated_voc': 4.77,
#   'passivating_molecule': 'OATsO',
#   'perovskite_composition': '(FAPbI3)0.95((MAPbBr3)0.05)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'test_name': 'OC',
#     'temperature': 40,
#     'time': '1,000 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41},
#    {'test_name': 'MPP',
#     'temperature': 40,
#     'time': '800 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41}]},
#  '111': {'treated_pce': 23.9,
#   'treated_voc': 0.68,
#   'passivating_molecule': 'isopropylammonium chloride',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-MeOTAD',
#   'stability_tests': []},
#  '62': {'control_pce': 17.3,
#   'control_voc': 1.01,
#   'treated_pce': 16.5,
#   'treated_voc': 1.02,
#   'passivating_molecule': 'BAI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 55,
#     'time': '30 days',
#     'humidity': '55% RH',
#     'control_efficiency': 44,
#     'treatment_efficiency': 83},
#    {'test_name': 'ISOS-L',
#     'temperature': 80,
#     'time': '30 days',
#     'humidity': '80°C',
#     'control_efficiency': 27,
#     'treatment_efficiency': 73}]},
#  '19': {'treated_pce': 24.09,
#   'passivating_molecule': '3FPEA',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.9Pb(I0.95Br0.05)3',
#   'electron_transport_layer': '2PACz',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': 85,
#     'time': 1560,
#     'humidity': '50% RH',
#     'treatment_efficiency': 24.09}]},
#  '116': {'control_pce': 23.44,
#   'control_voc': 1.152,
#   'treated_pce': 24.82,
#   'treated_voc': 1.1814,
#   'passivating_molecule': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': 500,
#     'control_efficiency': 13.74,
#     'treatment_efficiency': 87}]},
#  '65': {'control_pce': 4.73,
#   'control_voc': 1.18,
#   'treated_pce': 4.73,
#   'treated_voc': 1.18,
#   'passivating_molecule': '(PEA)2(MA)2[Pb3I10]',
#   'perovskite_composition': '(PEA)2(MA)2[Pb3I10]',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '52',
#     'time': '40 days',
#     'humidity': '52% relative humidity',
#     'control_efficiency': 4.73,
#     'treatment_efficiency': 4.73}]},
#  '107': {'treated_pce': 21.25,
#   'passivating_molecule': 'SF-PEA',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 1000,
#     'time': '1000',
#     'humidity': '50-60%',
#     'treatment_efficiency': 0.91}]},
#  '74': {'control_pce': 21.2,
#   'control_voc': 1.13,
#   'passivating_molecule': 'CLP',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 4390,
#     'humidity': 'N2',
#     'control_efficiency': 21.2,
#     'treatment_efficiency': 21.2}]},
#  '100': {'control_pce': '23.24',
#   'control_voc': '1.17',
#   'treated_pce': '22.54',
#   'treated_voc': '1.16',
#   'electron_transport_layer': 'In2O3/SnO2',
#   'hole_transport_layer': 'SnO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25 °C',
#     'time': '80 days',
#     'humidity': 'N2',
#     'control_efficiency': '97.5%',
#     'treatment_efficiency': '91%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': '75% RH',
#     'time': '120 h',
#     'humidity': 'High',
#     'control_efficiency': '71%',
#     'treatment_efficiency': '80%'}]},
#  '73': {'control_pce': 22.6,
#   'control_voc': 1.176,
#   'treated_pce': 25.1,
#   'treated_voc': 1.176,
#   'passivating_molecule': '2CF3-PEAI',
#   'perovskite_composition': 'FA0.98Cs0.02PbI3',
#   'electron_transport_layer': 'p-PY',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'temperature': 85,
#     'time': 1000,
#     'humidity': '85% RH',
#     'control_efficiency': 97.4}]},
#  '109': {'control_pce': '17.27%',
#   'control_voc': '1.13 V',
#   'treated_pce': '25.7%',
#   'treated_voc': '1.16 V',
#   'passivating_molecule': 'PAA',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': '25°C',
#     'time': '1000 hours',
#     'humidity': '25% RH',
#     'control_efficiency': '25.7%',
#     'treatment_efficiency': '80%'},
#    {'test_name': 'Shelf life',
#     'temperature': '25°C',
#     'time': '1000 hours',
#     'humidity': '25% RH',
#     'control_efficiency': '17.27%',
#     'treatment_efficiency': '25.7%'}]},
#  '33': {'control_pce': 25,
#   'treated_pce': 25,
#   'passivating_molecule': 'Benzene',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'FAI-terminated',
#   'hole_transport_layer': 'PbI2',
#   'stability_tests': []},
#  '140': {'control_pce': '26.07%',
#   'control_voc': '25.8%',
#   'treated_pce': '24.63%',
#   'treated_voc': '26.07%',
#   'passivating_molecule': 'HFB',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'temperature': '50 ± 5 °C',
#     'time': '1258 h',
#     'control_efficiency': '26.07%',
#     'treatment_efficiency': '24.63%'}]},
#  '8': {'control_pce': '20.1',
#   'control_voc': '1.16',
#   'treated_pce': '23.0',
#   'treated_voc': '1.177',
#   'passivating_molecule': 'PREA',
#   'perovskite_composition': 'CsPbI2Br',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'ambient',
#     'control_efficiency': '85',
#     'treatment_efficiency': '60'}]},
#  '99': {'control_pce': 18.08,
#   'control_voc': 1.087,
#   'treated_pce': 21.01,
#   'treated_voc': 1.146,
#   'passivating_molecule': 'ClMPI',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Outdoor Solar Irradiation',
#     'temperature': 25,
#     'time': 180,
#     'humidity': 'outdoor',
#     'control_efficiency': 16.25,
#     'treatment_efficiency': 20.17},
#    {'test_name': 'UV Irradiation',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'controlled',
#     'control_efficiency': 10,
#     'treatment_efficiency': 82},
#    {'test_name': '1-Sun Illumination with UV Filter',
#     'temperature': 25,
#     'time': 200,
#     'humidity': 'indoor',
#     'control_efficiency': 50,
#     'treatment_efficiency': 90}]},
#  '48': {'control_pce': '16.9',
#   'control_voc': '1.07',
#   'treated_pce': '20.3',
#   'treated_voc': '1.10',
#   'passivating_molecule': 'Fluoro-silane',
#   'perovskite_composition': 'Perovskite films',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA:F4-TCNQ',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 'Room temperature',
#     'time': 'After fabrication',
#     'humidity': '40%',
#     'control_efficiency': '16.9',
#     'treatment_efficiency': '18.9'}]},
#  '34': {'stability_tests': []},
#  '147': {'control_pce': 22.3,
#   'control_voc': 1.112,
#   'treated_pce': 24.7,
#   'treated_voc': 1.161,
#   'passivating_molecule': 'CBz-PAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'P3HT',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Damp heat test',
#     'temperature': 85,
#     'time': '1,000 h',
#     'humidity': '85% relative humidity',
#     'control_efficiency': 66.6,
#     'treatment_efficiency': 92.3},
#    {'test_name': 'MPP tracking',
#     'temperature': 45,
#     'time': '1,100 h',
#     'control_efficiency': 66.6,
#     'treatment_efficiency': 94.6}]},
#  '6': {'control_pce': '20.1',
#   'control_voc': '1.03',
#   'treated_pce': '15.3',
#   'treated_voc': '1.06',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'PEA2PbI4',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'null',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '100',
#     'time': '36',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-L',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '55',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '90',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'}]},
#  '97': {'treated_pce': '22.3',
#   'treated_voc': '1.17',
#   'passivating_molecule': 'Oleylamine (OAm)',
#   'perovskite_composition': 'Cs 0.05 (FA 0.92 MA 0.08) 0.95 Pb(I 0.92 Br 0.08) 3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '70-75 °C',
#     'time': '1,800 h',
#     'humidity': 'Air',
#     'control_efficiency': '22.3%',
#     'treatment_efficiency': '23.0%'}]},
#  '46': {'control_voc': 1.12,
#   'treated_pce': 20,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'PFN-P2',
#   'perovskite_composition': 'CsPbI0.05[(FAPbI3)0.89]',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': 25,
#     'time': '100 hours',
#     'humidity': 'air',
#     'control_efficiency': 19.83,
#     'treatment_efficiency': 20}]},
#  '135': {'control_pce': '25.6',
#   'control_voc': '1.19',
#   'treated_pce': '25.6',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'MeO-4PADBC',
#   'perovskite_composition': 'Perovskite (assumed standard formula)',
#   'electron_transport_layer': 'NiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'MeO-4PADBC',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '65',
#     'time': '1200',
#     'control_efficiency': '25.6',
#     'treatment_efficiency': '90'}]},
#  '149': {'control_pce': '22.2',
#   'control_voc': '0.841',
#   'treated_pce': '24.3',
#   'treated_voc': '2.03',
#   'passivating_molecule': 'CF3-PA',
#   'perovskite_composition': 'FA0.75MA0.25Pb0.5Sn0.5I3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'VNPB',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '35',
#     'humidity': '30-50%',
#     'control_efficiency': '22.2',
#     'treatment_efficiency': '24.3'}]},
#  '1': {'control_pce': 20,
#   'control_voc': 1.18,
#   'treated_pce': 23.32,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'FA 1-x MA x PbI 3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 500,
#     'control_efficiency': 20,
#     'treatment_efficiency': 23.32}]},
#  '90': {'control_pce': 20.7,
#   'control_voc': 1.17,
#   'treated_pce': 20.7,
#   'treated_voc': 1.17,
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '41': {'control_pce': 20.71,
#   'control_voc': 1.135,
#   'treated_pce': 23.9,
#   'treated_voc': 1.157,
#   'passivating_molecule': 'o-PDEAI2',
#   'perovskite_composition': 'PDEAI2',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Humidity test',
#     'temperature': 40,
#     'time': '24 hours',
#     'humidity': '40-50% RH',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Thermal stability',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Module performance',
#     'temperature': 'Module performance',
#     'time': 'Module performance',
#     'humidity': 'Module performance',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 23.9}]}}

# %% [markdown]
# ### Subsetting the LLama Prediction since we only have 54 true lables

# %%
# Extract the subset from json_150 where keys match with json_54
subset_llama = {key: filtered_llama_data[key] for key in label_data.keys() if key in filtered_llama_data}

# Print the result
print(len(subset_llama))
# Out:
# 54

# %% [markdown]
# ## First, we will evaluate one pair of papers and adjust specific formatting

# %%
##0th paper prediction
subset_llama
# Out:
# {'19': {'treated_pce': 24.09,
#   'passivating_molecule': '3FPEA',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.9Pb(I0.95Br0.05)3',
#   'electron_transport_layer': '2PACz',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': 85,
#     'time': 1560,
#     'humidity': '50% RH',
#     'treatment_efficiency': 24.09}]},
#  '84': {'control_pce': 21.6,
#   'control_voc': 1.24,
#   'treated_pce': 23.2,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'DM',
#   'perovskite_composition': '(FAPbI3)0.95 (MAPbBr3)0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'DM',
#   'stability_tests': [{'test_name': 'thermal stability test',
#     'temperature': 60,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 70,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'thermal stability test',
#     'temperature': 80,
#     'time': 50,
#     'humidity': 'air (~25% RH)',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 22.3}]},
#  '56': {'control_pce': 25.5,
#   'control_voc': 1.22,
#   'treated_pce': 20.5,
#   'treated_voc': 1.22,
#   'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '82': {'control_pce': '17.1',
#   'control_voc': '1.04',
#   'treated_pce': '20.59',
#   'treated_voc': '1.13',
#   'passivating_molecule': 'Choline chloride',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Humidity stability test',
#     'time': 'Over one month',
#     'humidity': '50-85% RH',
#     'control_efficiency': '17.1%',
#     'treatment_efficiency': '20.59%'}]},
#  '55': {'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'},
#    {'test_name': 'ISOS-L',
#     'temperature': '263-323',
#     'time': '102 s',
#     'humidity': 'controlled environment'}]},
#  '88': {'control_pce': 19.03,
#   'control_voc': 0.92,
#   'treated_pce': 21.46,
#   'treated_voc': 0.94,
#   'passivating_molecule': 'NaF',
#   'perovskite_composition': 'Cs0.05FA0.54MA0.41PbI0.98Br0.02)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1000,
#     'control_efficiency': 19.03,
#     'treatment_efficiency': 21.46}]},
#  '92': {'treated_pce': 21.3,
#   'passivating_molecule': 'BaSnO3',
#   'perovskite_composition': 'BaSnO3',
#   'electron_transport_layer': 'BaSnO3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD, PTAA',
#   'stability_tests': [{'temperature': 25,
#     'time': '24 hours',
#     'humidity': '40% RH',
#     'control_efficiency': 21.3,
#     'treatment_efficiency': 21.7}]},
#  '5': {'control_pce': 22.1,
#   'control_voc': 1135,
#   'treated_pce': 22.1,
#   'treated_voc': 1205,
#   'passivating_molecule': 'iso-BAI and n-BAI',
#   'perovskite_composition': 'FA(MA)PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '18': {'control_pce': '26%',
#   'passivating_molecule': 'TMAI',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'SnO2',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'lower'},
#    {'test_name': 'ISOS-L',
#     'temperature': 100,
#     'time': '6 min',
#     'humidity': 'dry',
#     'control_efficiency': '26%',
#     'treatment_efficiency': 'higher'}]},
#  '9': {'control_pce': 14.64,
#   'treated_pce': 17.6,
#   'passivating_molecule': 'C8',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'NiOx'},
#  '13': {'control_pce': 25.7,
#   'control_voc': 1.15,
#   'treated_pce': 15.1,
#   'treated_voc': 1.29,
#   'passivating_molecule': '2-thiopheneethylammonium chloride',
#   'perovskite_composition': 'Cs0.12FA0.8PbI1.8Br1.2',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': '2PACz',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 265,
#     'humidity': 'ambient',
#     'control_efficiency': 13.1,
#     'treatment_efficiency': 15.1}]},
#  '86': {'control_pce': 21.6,
#   'control_voc': 1.11,
#   'treated_pce': 21.6,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'EDTA-complexed SnO2',
#   'perovskite_composition': 'FA0.95Cs0.05PbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'p-i-n',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 100,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6},
#    {'test_name': 'ISOS-LT',
#     'temperature': 60,
#     'time': 1000,
#     'humidity': '35%',
#     'control_efficiency': 21.6,
#     'treatment_efficiency': 21.6}]},
#  '80': {'control_pce': 21.6,
#   'control_voc': 1.14,
#   'treated_pce': 21.6,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'PMMA',
#   'perovskite_composition': 'Mixed cation perovskite (FAI, PbI2, MABr, PbBr2)',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'TiO2',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': '2 months',
#     'humidity': 'ambient air',
#     'control_efficiency': 21.0,
#     'treatment_efficiency': 21.0}]},
#  '89': {'treated_pce': '20.87%',
#   'treated_voc': '413 mV',
#   'passivating_molecule': 'formamidine acetate (FAAc)',
#   'perovskite_composition': '(FA, MA, Cs)Pb(I, Br)3'},
#  '46': {'control_voc': 1.12,
#   'treated_pce': 20,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'PFN-P2',
#   'perovskite_composition': 'CsPbI0.05[(FAPbI3)0.89]',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': 25,
#     'time': '100 hours',
#     'humidity': 'air',
#     'control_efficiency': 19.83,
#     'treatment_efficiency': 20}]},
#  '6': {'control_pce': '20.1',
#   'control_voc': '1.03',
#   'treated_pce': '15.3',
#   'treated_voc': '1.06',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'PEA2PbI4',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'null',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '100',
#     'time': '36',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-L',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '55',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': 'null',
#     'time': '2',
#     'humidity': '90',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'}]},
#  '114': {'control_pce': 20.76,
#   'control_voc': 1.06,
#   'treated_pce': 23.37,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Piperazinium iodide (PI)',
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': []},
#  '83': {'control_pce': '21.3',
#   'control_voc': '1.13',
#   'treated_pce': '21.38',
#   'treated_voc': '1.12',
#   'passivating_molecule': 'MAI and FA',
#   'perovskite_composition': 'MAPbI3 and FA0.15MA0.85PbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '792 hours',
#     'humidity': '40 ± 10%',
#     'control_efficiency': '21.3',
#     'treatment_efficiency': '21.38'}]},
#  '17': {'control_pce': 25.2,
#   'control_voc': 1.16,
#   'treated_pce': 22.02,
#   'treated_voc': 1.19,
#   'passivating_molecule': 'hexyltrimethylammonium bromide',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': '1F-PTAA',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': '1F-PTAA',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '90 min',
#     'humidity': 'N2-filled glove-box',
#     'control_efficiency': 20.04,
#     'treatment_efficiency': 22.16}]},
#  '53': {'control_pce': '4.9%',
#   'treated_pce': '24.7%',
#   'passivating_molecule': 'DMePDAI2',
#   'perovskite_composition': 'FA0.85MA0.1Cs0.05PbI2.9Br0.1',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': '40°C',
#     'time': '1000 hours',
#     'humidity': 'N2',
#     'control_efficiency': '20.5%',
#     'treatment_efficiency': '23.1%'}]},
#  '49': {'control_pce': '13.81',
#   'control_voc': '1.12',
#   'treated_pce': '16.25',
#   'treated_voc': '1.31',
#   'passivating_molecule': 'n-butylamine acetate (BAAc)',
#   'perovskite_composition': '(BA)2(MA)n-1Pb3n+1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '558',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '13.81',
#     'treatment_efficiency': '16.25'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65 ± 10%',
#     'time': '4680',
#     'humidity': '65 ± 10%',
#     'control_efficiency': '49.4',
#     'treatment_efficiency': '93.8'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '85',
#     'time': '1100',
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': '70.8',
#     'treatment_efficiency': '96.2'}]},
#  '79': {'control_pce': 19.9,
#   'control_voc': 1.09,
#   'treated_pce': 19.9,
#   'treated_voc': 1.09,
#   'passivating_molecule': 'PbI2',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '40 days',
#     'humidity': 'dry air',
#     'control_efficiency': 19.9,
#     'treatment_efficiency': 19.9}]},
#  '90': {'control_pce': 20.7,
#   'control_voc': 1.17,
#   'treated_pce': 20.7,
#   'treated_voc': 1.17,
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '0': {'control_pce': '25.5',
#   'control_voc': '1.17',
#   'treated_pce': '24.7',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'formamidinium lead triiodide (FAPbI3)',
#   'electron_transport_layer': 'Cs2O',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '1500',
#     'humidity': '50',
#     'control_efficiency': '19.9',
#     'treatment_efficiency': '95'},
#    {'test_name': 'ISOS-L',
#     'temperature': '65',
#     'time': '1200',
#     'humidity': '50',
#     'control_efficiency': '23.2',
#     'treatment_efficiency': '91'}]},
#  '47': {'treated_pce': 21.1,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'PbSO4',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 65,
#     'time': '1200 hours',
#     'humidity': 'air, RH ~60%',
#     'control_efficiency': 21.1,
#     'treatment_efficiency': 96.8}]},
#  '41': {'control_pce': 20.71,
#   'control_voc': 1.135,
#   'treated_pce': 23.9,
#   'treated_voc': 1.157,
#   'passivating_molecule': 'o-PDEAI2',
#   'perovskite_composition': 'PDEAI2',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Humidity test',
#     'temperature': 40,
#     'time': '24 hours',
#     'humidity': '40-50% RH',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Thermal stability',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': 'N2 atmosphere',
#     'control_efficiency': 20.71,
#     'treatment_efficiency': 23.9},
#    {'test_name': 'Module performance',
#     'temperature': 'Module performance',
#     'time': 'Module performance',
#     'humidity': 'Module performance',
#     'control_efficiency': 21.4,
#     'treatment_efficiency': 23.9}]},
#  '40': {'control_pce': 24.3,
#   'control_voc': 1.2,
#   'treated_pce': 24.3,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'Oleylammonium iodide (OLAI)',
#   'perovskite_composition': 'Cs0.03(FA0.90MA0.10)PbI3',
#   'electron_transport_layer': 'ITO',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'test_name': 'damp-heat',
#     'temperature': 85,
#     'time': '1000 hours',
#     'humidity': '85% RH',
#     'control_efficiency': 24.3,
#     'treatment_efficiency': 19.3}]},
#  '12': {'control_pce': 16.7,
#   'control_voc': 1.23,
#   'treated_pce': 19.4,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylammonium bromide (BABr)',
#   'perovskite_composition': 'Cs0.17 FA0.83 Pb(I0.6 Br0.4)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'J-V measurements',
#     'temperature': 25,
#     'time': 'continuous illumination',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4},
#    {'test_name': 'PCE under different treatments',
#     'temperature': 25,
#     'time': 'under constant voltage',
#     'humidity': 'controlled',
#     'control_efficiency': 16.7,
#     'treatment_efficiency': 19.4}]},
#  '59': {'control_pce': '19.07',
#   'control_voc': '1.25',
#   'treated_pce': '19.07',
#   'treated_voc': '1.25',
#   'passivating_molecule': 'phenethylammonium iodide',
#   'perovskite_composition': 'FA0.8Cs0.2PbI0.7Br0.3',
#   'electron_transport_layer': 'poly(triarylamine)',
#   'pin_nip_structure': 'inverted',
#   'hole_transport_layer': 'ITO',
#   'stability_tests': []},
#  '14': {'control_pce': 25.5,
#   'control_voc': 1.184,
#   'treated_pce': 23.7,
#   'treated_voc': 1.184,
#   'passivating_molecule': 'F-PEAI',
#   'perovskite_composition': 'Cs0.1FA0.9PbI2.9Br0.1',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '50': {'control_pce': '11-12%',
#   'control_voc': '1.08 V',
#   'treated_pce': '14.4%',
#   'treated_voc': '1.05 V',
#   'passivating_molecule': 'allylamine',
#   'perovskite_composition': '(C4H9NH3+)2Pb10I29',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25 °C',
#     'time': '650 h',
#     'humidity': 'ambient',
#     'control_efficiency': '11.2%',
#     'treatment_efficiency': '14.4%'}]},
#  '58': {'control_pce': '25.5%',
#   'treated_pce': '18.5%',
#   'passivating_molecule': 'PCBM',
#   'perovskite_composition': 'FA0.83Cs0.17PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'poly-TPD or NiOx',
#   'stability_tests': []},
#  '2': {'control_pce': 0.2239,
#   'control_voc': 1098,
#   'treated_pce': 0.2459,
#   'treated_voc': 1185,
#   'passivating_molecule': '(BA)2PbI4',
#   'perovskite_composition': '(BA)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1056,
#     'humidity': '85% relative humidity',
#     'control_efficiency': 0.2239,
#     'treatment_efficiency': 0.2435}]},
#  '3': {'control_pce': 24.5,
#   'control_voc': 1.2,
#   'treated_pce': 24.5,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'BA2MA2Pb3I10',
#   'perovskite_composition': 'Cs0.05(MA0.10FA0.85)Pb(I0.90Br0.10)3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'temperature': 55,
#     'time': 2000,
#     'humidity': '70% RH',
#     'control_efficiency': 21,
#     'treatment_efficiency': 22.93}]},
#  '81': {'control_pce': '20.1',
#   'control_voc': '1.06',
#   'treated_pce': '19.5',
#   'treated_voc': '1.15',
#   'passivating_molecule': 'Cl-capped TiO2 colloidal nanocrystal film',
#   'perovskite_composition': 'MAPbI3-xClx',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 500,
#     'humidity': 'dry',
#     'control_efficiency': 90,
#     'treatment_efficiency': 97}]},
#  '93': {'treated_pce': 20.5,
#   'perovskite_composition': 'FA1-x MAx PbI2.87 Br0.13(Cl)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': []},
#  '10': {'treated_pce': 24.41,
#   'treated_voc': 4.77,
#   'passivating_molecule': 'OATsO',
#   'perovskite_composition': '(FAPbI3)0.95((MAPbBr3)0.05)',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'test_name': 'OC',
#     'temperature': 40,
#     'time': '1,000 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41},
#    {'test_name': 'MPP',
#     'temperature': 40,
#     'time': '800 h',
#     'humidity': '40% RH',
#     'control_efficiency': 4.77,
#     'treatment_efficiency': 24.41}]},
#  '15': {'control_pce': '21.78',
#   'control_voc': '1.11',
#   'treated_pce': '23.34',
#   'treated_voc': '1.15',
#   'passivating_molecule': 'Cl-PEAI and F-PEAI',
#   'perovskite_composition': 'Cs0.05(FA5/6MA1/6)0.95PbI0.9Br0.1',
#   'electron_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '149': {'control_pce': '22.2',
#   'control_voc': '0.841',
#   'treated_pce': '24.3',
#   'treated_voc': '2.03',
#   'passivating_molecule': 'CF3-PA',
#   'perovskite_composition': 'FA0.75MA0.25Pb0.5Sn0.5I3',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'VNPB',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '35',
#     'humidity': '30-50%',
#     'control_efficiency': '22.2',
#     'treatment_efficiency': '24.3'}]},
#  '11': {'control_pce': '20.2',
#   'control_voc': '1.11',
#   'treated_pce': '21.8',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'BTaBr',
#   'perovskite_composition': '(BTa)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '25',
#     'time': '24 hours',
#     'humidity': 'ambient air',
#     'control_efficiency': '21.8',
#     'treatment_efficiency': '21.8'}]},
#  '7': {'control_pce': 23.5,
#   'control_voc': 1.2,
#   'treated_pce': 28.7,
#   'treated_voc': 1.5,
#   'passivating_molecule': '4-FPEA',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiOx',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Au',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 80,
#     'time': '24 hours',
#     'humidity': '50% RH',
#     'control_efficiency': 22.5,
#     'treatment_efficiency': 28.7},
#    {'test_name': 'ISOS-L',
#     'temperature': 60,
#     'time': '48 hours',
#     'humidity': '30% RH',
#     'control_efficiency': 23.5,
#     'treatment_efficiency': 28.7}]},
#  '1': {'control_pce': 20,
#   'control_voc': 1.18,
#   'treated_pce': 23.32,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'FA 1-x MA x PbI 3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'planar',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 500,
#     'control_efficiency': 20,
#     'treatment_efficiency': 23.32}]},
#  '117': {'control_pce': 22.2,
#   'control_voc': 1.15,
#   'treated_pce': 25.1,
#   'treated_voc': 1.17,
#   'passivating_molecule': '4-tert-butyl-1-methylpyridinium bis(trifluoromethanesulfonyl)imide (TBMP + TFSI -)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'Stability test',
#     'temperature': '70 ± 5% RH',
#     'time': 'Long-term exposure',
#     'humidity': 'High relative humidity',
#     'control_efficiency': '22.2%',
#     'treatment_efficiency': '25.1%'}]},
#  '42': {'control_pce': 19.52,
#   'control_voc': 1.07,
#   'treated_pce': 22.03,
#   'treated_voc': 1.18,
#   'passivating_molecule': 'AzPbI3',
#   'perovskite_composition': 'Cs0.05 MA0.1 FA0.85 PbI2.7 Br0.3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 52,
#     'time': 1000,
#     'control_efficiency': 47,
#     'treatment_efficiency': 85}]},
#  '43': {'control_pce': '24.50%',
#   'control_voc': '1.150 V',
#   'treated_pce': '24.50%',
#   'treated_voc': '1.121 V',
#   'passivating_molecule': 'Benzylamine hydroiodide (BAHI)',
#   'perovskite_composition': 'FA0.90MA0.10PbI3•(CsPbI3)0.05 with excess PbI2',
#   'electron_transport_layer': 'TiO2 (mesoporous)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '80 °C',
#     'time': '500 h',
#     'humidity': '20-30% RH',
#     'control_efficiency': '24.50%',
#     'treatment_efficiency': '47.96 ± 3.21%'}]},
#  '85': {'control_pce': 16,
#   'control_voc': 0.8,
#   'treated_pce': 22.7,
#   'treated_voc': 1.0,
#   'passivating_molecule': 'n-hexyl trimethyl ammonium bromide',
#   'perovskite_composition': 'FAPbI3:MAPbBr3:HTAB = 0.3:0.95:0.05',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'P3HT',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1008,
#     'humidity': '85%',
#     'control_efficiency': 80,
#     'treatment_efficiency': 0}]},
#  '8': {'control_pce': '20.1',
#   'control_voc': '1.16',
#   'treated_pce': '23.0',
#   'treated_voc': '1.177',
#   'passivating_molecule': 'PREA',
#   'perovskite_composition': 'CsPbI2Br',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'ambient',
#     'control_efficiency': '85',
#     'treatment_efficiency': '60'}]},
#  '116': {'control_pce': 23.44,
#   'control_voc': 1.152,
#   'treated_pce': 24.82,
#   'treated_voc': 1.1814,
#   'passivating_molecule': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'pin_nip_structure': 'n-i-p',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 25,
#     'time': 500,
#     'control_efficiency': 13.74,
#     'treatment_efficiency': 87}]},
#  '91': {'control_pce': '19.66',
#   'control_voc': '1.027',
#   'treated_pce': '24.02',
#   'treated_voc': '1.130',
#   'passivating_molecule': 'methylammonium chloride (MACl)',
#   'perovskite_composition': 'formamidinium lead iodide (FAPbI3)',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': '1200 hours',
#     'humidity': 'Room temperature',
#     'control_efficiency': '90',
#     'treatment_efficiency': '90'},
#    {'test_name': 'ISOS-L',
#     'temperature': 40,
#     'time': '300 hours',
#     'humidity': '40°C',
#     'control_efficiency': '60',
#     'treatment_efficiency': '90'}]},
#  '57': {'treated_pce': 22.5,
#   'treated_voc': 1.098,
#   'perovskite_composition': 'MA 0.07 FA 0.93 PbI 3',
#   'electron_transport_layer': 'PTAA',
#   'pin_nip_structure': 'pin',
#   'hole_transport_layer': 'C60',
#   'stability_tests': [{'temperature': 25,
#     'time': 350,
#     'control_efficiency': 22.5,
#     'treatment_efficiency': 22.5}]},
#  '87': {'treated_pce': 21.52,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'FAI',
#   'perovskite_composition': 'CsI:20 mg, PbI2:530 mg, PbBr2:20 mg, PbCl2:20 mg, MAI:5 mg',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'stability_tests': [{'temperature': 85,
#     'time': 1500,
#     'control_efficiency': 100,
#     'treatment_efficiency': 89}]},
#  '115': {'control_pce': '24.04',
#   'control_voc': '0.08 cm²',
#   'treated_pce': '23.15',
#   'treated_voc': '23.15',
#   'passivating_molecule': 'anisole',
#   'perovskite_composition': 'FA1-x-yMAxCsyPbI3-zBrz',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '95%',
#     'treatment_efficiency': '75%'},
#    {'test_name': 'SPO',
#     'temperature': '40',
#     'time': '2000 hours',
#     'humidity': 'none',
#     'control_efficiency': '5%',
#     'treatment_efficiency': '20%'}]},
#  '16': {'control_pce': 18.87,
#   'control_voc': 1.04,
#   'treated_pce': 21.05,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'CF3PEAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': []},
#  '48': {'control_pce': '16.9',
#   'control_voc': '1.07',
#   'treated_pce': '20.3',
#   'treated_voc': '1.10',
#   'passivating_molecule': 'Fluoro-silane',
#   'perovskite_composition': 'Perovskite films',
#   'electron_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PTAA:F4-TCNQ',
#   'stability_tests': [{'test_name': 'ISOS',
#     'temperature': 'Room temperature',
#     'time': 'After fabrication',
#     'humidity': '40%',
#     'control_efficiency': '16.9',
#     'treatment_efficiency': '18.9'}]}}

# %%
#The actual label
clean_label_data['0']
# Out:
# {'ISOSL3': {'control_pce': '24',
#   'efficiency_tret': '95%',
#   'time': '1200',
#   'treated_pce': '26.9',
#   'treated_voc': '1.18'},
#  'structure_pin_nip': 'PIN',
#  'passivating_molecule': '4Cl-BZS',
#  'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3',
#  'hole_transport_layer': '2PACz and Me-4PACz',
#  'electron_transport_layer': 'C60'}

# %% [markdown]
# #### Evaluation in parts
# - numerical data
# - text data (molecule)
# - stability
#     - Change how to parse xml
#     - Change the output of the model as ID but no specification on number

# %%
## We need precision and recall for EACH variable
## For each variable, calculate the F1 score - There is F1 score for each variable
## Take a weighted average ***For now, just take the average.

# %% [markdown]
# Variables (number)
# - control_pce
# - treatment_pce
# - control_voc
# - treatment_voc
#
# Variable (text)
# - structure_pin_nip
# - passivating_molecule
# - perovskite_composition
# - hole_transport_layer
# - electron_transport_layer
#
# Stability (later)

# %%
def check_float(value):
    for char in value:
        if (char == ".") | (char.isdigit()):
            continue
        else:
            return False
    return True

# %%
import re

def check_float(value):
    """Returns True if value can be converted to a float, otherwise False."""
    try:
        float(value)
        return True
    except ValueError:
        return False

def clean_numeric_value(value):
    """
    Cleans a numeric value by removing non-numeric characters except decimals.
    Ensures the output is either a float or a string that can be converted.
    """
    if value is None:
        return None
    
    value = str(value).strip()  # Convert to string and remove leading/trailing spaces
    cleaned_value = re.sub(r"[^\d.]", "", value)  # Remove all non-numeric characters except "."

    return cleaned_value if check_float(cleaned_value) else None

def numerical_comparison(id, label_annotation, extraction_annotation, numerical_tolerance=0.1):
    """
    Compares numerical values with a tolerance, handling different formatting issues.
    """
    if id not in extraction_annotation:
        return "FN"  # False Negative: Missing extracted value
    
    label_data = label_annotation.get(id)
    extract_data = extraction_annotation.get(id)

    # Clean and convert numeric values
    label_data = clean_numeric_value(label_data)
    extract_data = clean_numeric_value(extract_data)

    if label_data is None or extract_data is None:
        return "FN"  # False Negative: If either value is invalid

    label_data = float(label_data)
    extract_data = float(extract_data)

    # Apply numerical tolerance check
    if abs(label_data - extract_data) <= numerical_tolerance * abs(label_data):
        return "TP"  # True Positive: Correct numerical extraction
    else:
        return "FP"  # False Positive: Incorrect numerical extraction

# %%
from difflib import SequenceMatcher

def text_comparison(id, label_annotation, extraction_annotation, text_similarity_threshold=0.8):
    """Compares text values using string similarity matching."""

    # Handle special case for structure_pin_nip
    key_to_check = "pin_nip_structure" if id == "structure_pin_nip" else id

    # If the key is missing in the extracted annotation, return False Negative
    if key_to_check not in extraction_annotation:
        return "FN"

    label_data = label_annotation.get(id, "")
    extract_data = extraction_annotation.get(key_to_check, "")

    # Convert lists to strings if necessary
    if isinstance(label_data, list):
        label_data = " ".join(map(str, label_data))  # Convert list to string
    if isinstance(extract_data, list):
        extract_data = " ".join(map(str, extract_data))  # Convert list to string

    # Ensure values are strings
    if not isinstance(label_data, str) or not isinstance(extract_data, str):
        return "FP"  # If data is still not a string, return False Positive

    # Compute similarity score
    similarity = SequenceMatcher(None, label_data.lower(), extract_data.lower()).ratio()

    return "TP" if similarity > text_similarity_threshold else "FP"

# %%
def stability_comparison(id, label_annotation, extraction_annotation):
    # Ensure "stability_tests" exists and is a list
    if "stability_tests" not in extraction_annotation or not isinstance(extraction_annotation["stability_tests"], list):
        return "FN"  # No stability test data found

    # If "stability_tests" is empty, return False Negative
    if len(extraction_annotation["stability_tests"]) == 0:
        return "FN"

    for dictionary in extraction_annotation["stability_tests"]:
        # Skip if "test_name" is missing or invalid
        if "test_name" not in dictionary or not isinstance(dictionary["test_name"], str):
            continue
        
        test_name = dictionary["test_name"]
        if id[4] == test_name[-1]:  # Match last character of ID and test name
            return "TP"  # True Positive: Test correctly extracted

    return "FN"  # No match found

# %%
def safe_division(numerator, denominator):
    """Returns division result, or 0 if the denominator is zero."""
    return numerator / denominator if denominator != 0 else 0

def compare_json(labeled_data, extracted_data):
    """
    Compare labeled and extracted JSON data for correctness.

    TP: Correct value extracted by LLM.
    FN: LLM didn't extract this variable.
    FP: LLM extracted a value, but it was incorrect.
    """
    
    numerical_variables = ["control_pce", "treated_pce", "control_voc", "treated_voc"]
    text_variables = ["structure_pin_nip", "passivating_molecule", "perovskite_composition", 
                      "electron_transport_layer", "hole_transport_layer"]
    
    # Initialize comparison dictionaries
    numerical_dict = {var: {"TP": 0, "FP": 0, "FN": 0} for var in numerical_variables}
    text_dict = {var: {"TP": 0, "FP": 0, "FN": 0} for var in text_variables}
    stability_dict = {
        "ISOS-D": {"TP": 0, "FP": 0, "FN": 0},
        "ISOS-L": {"TP": 0, "FP": 0, "FN": 0},
        "ISOS-T": {"TP": 0, "FP": 0, "FN": 0}
    }

    for key, label_value in labeled_data.items():
        if key not in extracted_data:
            print(f"Extraction was not performed. Paper num: {key}")
            continue
        
        extracted_value = extracted_data[key]

        for id, label in label_value.items():
            # Handle numerical values
            if id in numerical_variables:
                if isinstance(label, str) and label.replace(".", "").isdigit():
                    result = numerical_comparison(id, label_value, extracted_value)
                    numerical_dict[id][result] += 1

            # Handle text values
            elif id in text_variables:
                if isinstance(label, str):
                    result = text_comparison(id, label_value, extracted_value)
                    text_dict[id][result] += 1

            # Handle stability tests
            elif "ISOS" in id:
                result = stability_comparison(id, label_value, extracted_value)
                stability_type = f"ISOS-{id[4]}"  # Extract stability type
                if stability_type in stability_dict:
                    stability_dict[stability_type][result] += 1

    # Merge all results
    combined_dict = {**numerical_dict, **text_dict, **stability_dict}
    print("Performance for each variable in dictionary:", combined_dict)

    # Compute precision, recall, and F1-score
    variable_list, precision_list, recall_list, f1_list = [], [], [], []
    for variable, performance in combined_dict.items():
        TP, FP, FN = performance["TP"], performance["FP"], performance["FN"]
        
        precision = safe_division(TP, TP + FP)
        recall = safe_division(TP, TP + FN)
        f1 = safe_division(2 * precision * recall, precision + recall)

        variable_list.append(variable)
        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)

    return variable_list, precision_list, recall_list, f1_list

# %%
variables, precisions, recalls, f1s = compare_json(clean_label_data, subset_llama)
# Out:
# Performance for each variable in dictionary: {'control_pce': {'TP': 4, 'FP': 1, 'FN': 1}, 'treated_pce': {'TP': 9, 'FP': 0, 'FN': 0}, 'control_voc': {'TP': 5, 'FP': 1, 'FN': 2}, 'treated_voc': {'TP': 8, 'FP': 3, 'FN': 1}, 'structure_pin_nip': {'TP': 7, 'FP': 17, 'FN': 1}, 'passivating_molecule': {'TP': 6, 'FP': 13, 'FN': 1}, 'perovskite_composition': {'TP': 15, 'FP': 19, 'FN': 1}, 'electron_transport_layer': {'TP': 12, 'FP': 14, 'FN': 1}, 'hole_transport_layer': {'TP': 27, 'FP': 12, 'FN': 0}, 'ISOS-D': {'TP': 11, 'FP': 0, 'FN': 8}, 'ISOS-L': {'TP': 2, 'FP': 0, 'FN': 22}, 'ISOS-T': {'TP': 0, 'FP': 0, 'FN': 4}}

# %% [markdown]
# ## Calculate Macro f1 score

# %%
def macro_f1(f1_list, weight = None):
    if weight == None:
        #If no weight given, do unweighted average of f1 score
        return sum(f1_list) / len(f1_list)
    total_f1 = 0
    for i in range(len(f1_list)):
        total_f1 += (f1_list[i] * weight[i])
    return total_f1 / sum(weight)

# %%
## The macro f1 score unweighted
macro_f1(f1s)
# Out:
# 0.599084595959596

# %% [markdown]
# ### This concludes the pipeline of evaluating extraction quality

# %% [markdown]
# # Todo:
# - stability evaluation
#     - Need to reiterate on the teamtat annotation
#
# - Putting weights on F1 Score
# - Using Bert!!

# %% [markdown]
# ## Stability annotation brainstorm
#
# - We will have as at most 5 realation (if there is an overlap, choose the stability test that offers more info)
#     - Exp there is ISOS L1 and ISOS L2. If there is more iformation in IsosL2, use that as a test and compare on ISOSL that llama extracted (if any)
# - We will iterate through different test recorded on annotation and compared it with suitable stability extracted on Llama
