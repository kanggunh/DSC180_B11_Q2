# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from difflib import SequenceMatcher
import numpy as np
import json
import os
import xml.etree.ElementTree as ET 
import pandas as pd

# %% [markdown]
# ## This file compares the teamtat annotation (Json) with Extraction performed by finetuned llama (Json)

# %%
label = {'passivating_molecule': 'phenethylammonium iodide', 'perovskite_composition': 'MAPbI3', 'ISOSD1': {'time': '240', 'treated_pce': '15.3', 'control_pce': '16.69', 'temperature': '25', 'humidity': '90', 'control_voc': '1.03', 'treated_voc': '1.06'}, 'electron_transport_layer': 'TiO2', 'hole_transport_layer': 'Spiro-OMeTAD'}

# %%
extraction = {
  "control_pce": None,
  "control_voc": None,
  "treated_pce": 15.3,
  "treated_voc": 1.06,
  "passivating_molecule": "Phenylethylammonium (PEA)",
  "perovskite_composition": "[C8H9NH3]2[(CH3NH3)2PbI3 – (n=60)]",
  "electron_transport_layer": "TiO2",
  "hole_transport_layer": "spiro-OMeTAD",
  "ISOS-L-1": None,
  "ISOS-L-2": None,
  "ISOS-T-1": None,
  "ISOS-T-2": None,
  "ISOS-LC": None,
  "ISOS-D-1": None,
  "ISOS-D-2": None
}

# %%
def compare_data(labeled_data, extracted_data, numerical_tolerance=0.05):
    results = {}
    total_fields = len(labeled_data)
    matched_fields = 0
    numerical_differences = []

    for key, value in labeled_data.items():
        if key in extracted_data:
            extracted_value = extracted_data[key]

            # Exact match
            if value == extracted_value:
                matched_fields += 1
                results[key] = "Match"

            # Numerical comparison
            elif isinstance(value, (int, float)) and isinstance(extracted_value, (int, float)):
                if abs(value - extracted_value) <= numerical_tolerance * abs(value):
                    matched_fields += 1
                    numerical_differences.append(abs(value - extracted_value))
                    results[key] = "Numerical Match"
                else:
                    results[key] = "Numerical Mismatch"

            # Fuzzy string match
            elif isinstance(value, str) and isinstance(extracted_value, str):
                similarity = SequenceMatcher(None, value.lower(), extracted_value.lower()).ratio()
                if similarity > 0.8:  # Threshold for similarity
                    matched_fields += 1
                    results[key] = f"Fuzzy Match ({similarity:.2f})"
                else:
                    results[key] = f"Mismatch ({similarity:.2f})"

            else:
                results[key] = "Mismatch"
        else:
            results[key] = "Missing in Extracted Data"

    accuracy = matched_fields / total_fields
    mean_absolute_error = np.mean(numerical_differences) if numerical_differences else None

    return {
        "results": results,
        "accuracy": accuracy,
        "mean_absolute_error": mean_absolute_error,
        "matched_fields": matched_fields,
        "total_fields": total_fields
    }

# %%
comparison_result = compare_data(label, extraction)
print(comparison_result)
# Out:
# {'results': {'passivating_molecule': 'Mismatch (0.78)', 'perovskite_composition': 'Mismatch (0.20)', 'ISOSD1': 'Missing in Extracted Data', 'electron_transport_layer': 'Match', 'hole_transport_layer': 'Fuzzy Match (1.00)'}, 'accuracy': 0.4, 'mean_absolute_error': None, 'matched_fields': 2, 'total_fields': 5}

# %% [markdown]
# ## Retrieving teamtat label

# %%
def parse_bioc(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    
    data = { }
    concept_ids = set()
    relations = {}
    for relation in root.findall(".//relation"):
        test_name = relation.find("infon[@key='type']").text
        node_ids = [node.get("refid") for node in relation.findall("node")]
        for node_id in node_ids:
            relations[node_id] = test_name

    for annotation in root.findall(".//annotation"):
        node_id = annotation.get("id")
        var_name = annotation.find("infon[@key='type']").text
        concept_id = annotation.find("infon[@key='identifier']").text
        value = annotation.find("text").text
        if node_id in relations:
            stability_test = relations[node_id]
            if stability_test not in data:
                data[stability_test] = {}
            if concept_id is None:
                concept_id = value
            data[stability_test][var_name] = concept_id
            concept_ids.add(concept_id)

        if concept_id is None:
            concept_id = value
        if concept_id in concept_ids: # duplicate annotation
            continue
        concept_ids.add(concept_id)
        if var_name not in data:
            data[var_name] = concept_id
        else:
            if isinstance(data[var_name], list):
                data[var_name].append(value)
            else:
                data[var_name] = [data[var_name], value]
    
    return data

# %%
def extract_papernum(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    first_text = root.find(".//text")
    full_text = first_text.text
    
    ##We want to extract article number from this format
    #Method: split by spaces and extract the last element in the list
    text_list = full_text.split()
    paper_num = text_list[-1]
    return paper_num

# %%
## See if we can extract the paper number correctly
bioc_dir = "../data/biocs"
for filename in os.listdir(bioc_dir):
    if filename.endswith(".xml"):
        file_path = os.path.join(bioc_dir, filename)
        paper_num = extract_papernum(file_path)

# %%
bioc_dir = "../data/biocs"
label_data = {}
for filename in os.listdir(bioc_dir):
    if filename.endswith(".xml"):
        file_path = os.path.join(bioc_dir, filename)
        paper_num = extract_papernum(file_path)
        row = parse_bioc(file_path)
        if len(row.keys()) > 0:
            label_data[paper_num] = row

print(label_data)   
print(f"There are {len(label_data)} annotated papers")
# Out:
# {'0': {'ISOSL3': {'control_pce': '24', 'efficiency_tret': '95%', 'time': '1200', 'treated_pce': '26.9', 'treated_voc': '1.18'}, 'structure_pin_nip': 'PIN', 'passivating_molecule': '4Cl-BZS', 'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3', 'hole_transport_layer': '2PACz and Me-4PACz', 'electron_transport_layer': 'C60', 'journal_publication': ['Science', 'science'], 'date_published': '4/11/2024'}, '1': {'ISOSD2': {'treated_pce': '23.32', 'treated_voc': '1.16', 'control_pce': '21.3', 'time': '500'}, 'passivating_molecule': 'phenethylammonium iodide (PEAI)', 'electron_transport_layer': ['HC(NH 2 ) 2 -CH 3 NH 3', 'SnO 2'], 'journal_publication': 'nature', 'hole_transport_layer': 'spiro-OMeTAD', 'date_published': '1 April 2019'}, '2': {'treated_voc': '1.185', 'ISOSD1': {'treated_voc': '1.185', 'temperature': '85', 'humidity': '85', 'treated_pce': '24.35', 'time': '1056', 'control_pce': '22.39'}, 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'humidity': '85', 'perovskite_composition': '(C 4 H 9 NH 3 ) 2 PbI 4', 'efficiency_tret': '94', 'passivating_molecule': '(CH 3 (CH 2 ) 3 NH 2', 'journal_publication': 'nature', 'date_published': 'JANUARY 2021'}, '3': {'treated_pce': '24.5', 'control_pce': '21'}, '5': {'structure_pin_nip': 'NIP', 'perovskite_molecule': 'iso-butylammonium', 'electron_transport_layer': ['C60', 'C 60'], 'perovskite_composition': 'FA(MA)PbI 3', 'hole_transport_layer': 'Spiro-OMeTAD', 'treated_voc': '1.135', 'treated_pce': '22.1'}, '6': {'perovskite_molecule': 'phenethylammonium iodide', 'perovskite_composition': 'MAPbI3', 'ISOSD1': {'time': '240', 'treated_pce': '15.3', 'control_pce': '16.69', 'temperature': '25', 'humidity': '90', 'control_voc': '1.03', 'treated_voc': '1.06'}, 'electron_transport_layer': 'TiO2', 'hole_transport_layer': 'Spiro-OMeTAD'}, '7': {'ISOSL1': {'temperature': 'room_temperature', 'control_pce': '10', 'treated_pce': '15.42', 'treated_voc': '1.45', 'efficiency_tret': '0.9', 'time': '1000', 'humidity': '65'}, 'structure_pin_nip': 'NIP', 'electron_transport_layer': 'C60', 'perovskite_molecule': 'phenylethylammonium', 'perovskite_composition': '2 (FA) 8 Sn 9 I 2'}, '8': {'temperature': 'NIP', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'ISOSL1': {'control_pce': '20.1', 'treated_pce': '23.0', 'temperature': '40', 'time': '2000', 'efficiency_tret': '0.85', 'efficiency_cont': '0.60', 'control_voc': '1.160', 'treated_voc': '1.177'}, 'perovskite_molecule': 'ethylammonium'}, '9': {'perovskite_molecule': 'diammonium iodide', 'perovskite_composition': 'CH3NH3PbI3', 'electron_transport_layer': ['NiO', 'PCBM'], 'structure_pin_nip': 'PIN', 'treated_pce': '17.60', 'control_pce_peak': '14.64', 'control_voc': '1.08', 'treated_voc': '1.10'}, '10': {'perovskite_molecule': 'octylammonium tosylate', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'n-i-p', 'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05', 'ISOSL1': {'treated_pce': '24.41', 'temperature': '40', 'efficiency_cont': '0.651', 'efficiency_tret': '0.885', 'time': '2,092'}}, '11': {'structure_pin_nip': ['benzotriazole', 'n-i-p'], 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'ISOSL1': {'temperature': 'room temperature', 'control_pce': '20.2', 'control_voc': '1.11', 'treated_voc': '1.16', 'treated_pce': '21.8', 'time': '24', 'efficiency_cont': '0.98', 'efficiency_tret': '1.04'}}, '12': {'perovskite_molecule': 'butylammonium bromide', 'ISOSL1': {'control_voc': '1.24', 'treated_voc': '1.31', 'treated_pce': '19.8', 'efficiency_cont': '1.0', 'efficiency_tret': '1.0', 'time': '20', 'temperature': '25', 'control_pce': '17.5'}, 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'perovskite_composition': 'Cs0.15FA0.85PbI2.19Br0.81'}, '13': {'passivating_molecule': '2-thiopheneethylammonium chloride', 'ISOSL2': {'control_voc': '1.29', 'treated_pce': '23.8', 'temp ...
# There are 54 annotated papers

# %% [markdown]
# ### Remove journal_publication and date_published key from teamtat since xml file didn't mentioned them.

# %%
def take_out_keys(json_obj, keys_to_remove):
    ##This function will be irrelevant Hopefully after we have markdown text to annotate and have publication info in the text
    if isinstance(json_obj, dict):
        # Process dictionaries
        return {
            key: take_out_keys(value, keys_to_remove)
            for key, value in json_obj.items()
            if key not in keys_to_remove
        }
    elif isinstance(json_obj, list):
        # Process lists
        return [take_out_keys(item, keys_to_remove) for item in json_obj]
    else:
        # Return the value as is for non-dict and non-list items
        return json_obj
key_remove = {'journal_publication', 'date_published'}

# %%
clean_label_data = take_out_keys(label_data, key_remove)
clean_label_data
# Out:
# {'0': {'ISOSL3': {'control_pce': '24',
#    'efficiency_tret': '95%',
#    'time': '1200',
#    'treated_pce': '26.9',
#    'treated_voc': '1.18'},
#   'structure_pin_nip': 'PIN',
#   'passivating_molecule': '4Cl-BZS',
#   'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3',
#   'hole_transport_layer': '2PACz and Me-4PACz',
#   'electron_transport_layer': 'C60'},
#  '1': {'ISOSD2': {'treated_pce': '23.32',
#    'treated_voc': '1.16',
#    'control_pce': '21.3',
#    'time': '500'},
#   'passivating_molecule': 'phenethylammonium iodide (PEAI)',
#   'electron_transport_layer': ['HC(NH 2 ) 2 -CH 3 NH 3', 'SnO 2'],
#   'hole_transport_layer': 'spiro-OMeTAD'},
#  '2': {'treated_voc': '1.185',
#   'ISOSD1': {'treated_voc': '1.185',
#    'temperature': '85',
#    'humidity': '85',
#    'treated_pce': '24.35',
#    'time': '1056',
#    'control_pce': '22.39'},
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'humidity': '85',
#   'perovskite_composition': '(C 4 H 9 NH 3 ) 2 PbI 4',
#   'efficiency_tret': '94',
#   'passivating_molecule': '(CH 3 (CH 2 ) 3 NH 2'},
#  '3': {'treated_pce': '24.5', 'control_pce': '21'},
#  '5': {'structure_pin_nip': 'NIP',
#   'perovskite_molecule': 'iso-butylammonium',
#   'electron_transport_layer': ['C60', 'C 60'],
#   'perovskite_composition': 'FA(MA)PbI 3',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'treated_voc': '1.135',
#   'treated_pce': '22.1'},
#  '6': {'perovskite_molecule': 'phenethylammonium iodide',
#   'perovskite_composition': 'MAPbI3',
#   'ISOSD1': {'time': '240',
#    'treated_pce': '15.3',
#    'control_pce': '16.69',
#    'temperature': '25',
#    'humidity': '90',
#    'control_voc': '1.03',
#    'treated_voc': '1.06'},
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '7': {'ISOSL1': {'temperature': 'room_temperature',
#    'control_pce': '10',
#    'treated_pce': '15.42',
#    'treated_voc': '1.45',
#    'efficiency_tret': '0.9',
#    'time': '1000',
#    'humidity': '65'},
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'C60',
#   'perovskite_molecule': 'phenylethylammonium',
#   'perovskite_composition': '2 (FA) 8 Sn 9 I 2'},
#  '8': {'temperature': 'NIP',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'ISOSL1': {'control_pce': '20.1',
#    'treated_pce': '23.0',
#    'temperature': '40',
#    'time': '2000',
#    'efficiency_tret': '0.85',
#    'efficiency_cont': '0.60',
#    'control_voc': '1.160',
#    'treated_voc': '1.177'},
#   'perovskite_molecule': 'ethylammonium'},
#  '9': {'perovskite_molecule': 'diammonium iodide',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': ['NiO', 'PCBM'],
#   'structure_pin_nip': 'PIN',
#   'treated_pce': '17.60',
#   'control_pce_peak': '14.64',
#   'control_voc': '1.08',
#   'treated_voc': '1.10'},
#  '10': {'perovskite_molecule': 'octylammonium tosylate',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'structure_pin_nip': 'n-i-p',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'ISOSL1': {'treated_pce': '24.41',
#    'temperature': '40',
#    'efficiency_cont': '0.651',
#    'efficiency_tret': '0.885',
#    'time': '2,092'}},
#  '11': {'structure_pin_nip': ['benzotriazole', 'n-i-p'],
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'ISOSL1': {'temperature': 'room temperature',
#    'control_pce': '20.2',
#    'control_voc': '1.11',
#    'treated_voc': '1.16',
#    'treated_pce': '21.8',
#    'time': '24',
#    'efficiency_cont': '0.98',
#    'efficiency_tret': '1.04'}},
#  '12': {'perovskite_molecule': 'butylammonium bromide',
#   'ISOSL1': {'control_voc': '1.24',
#    'treated_voc': '1.31',
#    'treated_pce': '19.8',
#    'efficiency_cont': '1.0',
#    'efficiency_tret': '1.0',
#    'time': '20',
#    'temperature': '25',
#    'control_pce': '17.5'},
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'structure_pin_nip': 'NIP',
#   'perovskite_composition': 'Cs0.15FA0.85PbI2.19Br0.81'},
#  '13': {'passivating_molecule': '2-thiopheneethylammonium chloride',
#   'ISOSL2': {'control_voc': '1.29',
#    'treated_pce': '23.8',
#    'temperature': '60',
#    'efficiency_tret': '0.92',
#    'efficiency_cont': '0.82',
#    'control_pce': '15.1',
#    'treated_voc': '2.1'},
#   'time': '265',
#   'electron_transport_layer': 'PCBM',
#   'perovskite_composition': 'Cs 0.12 FA 0.8 MA 0.08 PbI 1.8 Br 1.2',
#   'structure_pin_nip': 'PIN',
#   'hole_transport_layer': ['2PACz', 'PTAA']},
#  '14': {'passivating_molecule': 'chlorophenylethylammonium iodide',
#   'ISOSL1': {'treated_pce': '23.7',
#    'treated_voc': '1.184',
#    'efficiency_cont': '0.9',
#    'time': '33',
#    'efficiency_tret': '1.0',
#    'control_voc': '1.109',
#    'control_pce': '21.58'},
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'PCBM',
#   'perovskite_composition': 'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.85 Br 0.15 ) 3',
#   'structure_pin_nip': 'PIN'},
#  '15': {'structure_pin_nip': 'PIN',
#   'passivating_molecule': '4-chloro-phenylethylammonium iodide',
#   'hole_transport_layer': 'PTAA',
#   'perovskite_composition': 'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.9 Br 0.1 ) 3',
#   'electron_transport_layer': 'PCBM',
#   'control_voc': '1.11',
#   'control_pce': '21.78',
#   'treated_voc': '1.17',
#   'treated_pce': '23.79'},
#  '16': {'structure_pin_nip': 'NIP',
#   'passivating_molecule': 'CF3-phenethylammonium',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': 'FAPbI3',
#   'control_voc': '1.04',
#   'control_pce': '18.87',
#   'treated_voc': '1.11',
#   'treated_pce': '21.05'},
#  '17': {'passivating_molecule': 'hexyltrimethyl ammouniumbromide',
#   'perovskite_composition': 'Cs 0.05 FA 0.81 MA 0.14 PbI 2.55 Br 0.45',
#   'structure_pin_nip': 'NIP',
#   'ISOSL1': {'temperature': 'room temperature',
#    'humidity': '70-75',
#    'time': '48',
#    'efficiency_tret': '0.86',
#    'control_voc': '1.16',
#    'control_pce': '20.04',
#    'treated_voc': '1.19',
#    'treated_pce': '20.94'},
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'SnO2'},
#  '18': {'perovskite_composition': '2-thiophenemethylammonium iodide',
#   'passivating_molecule': 'phenylethylammonium iodide',
#   'structure_pin_nip': 'NIP',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '19': {'ISOSL3': {'temperature': '85',
#    'humidity': '50',
#    'time': '1560',
#    'treated_pce': '23.3',
#    'control_pce': '21',
#    'control_voc': '1.269',
#    'treated_voc': '1.271'},
#   'perovskite_composition': ['Cs 0.05 MA 0.05 FA 0.9 Pb(I 0.95 Br 0.05 ) 3',
#    'Cs 0.05 MA 0.15 FA 0.8 PbI 3'],
#   'passivating_molecule': '3,4,5-trifluoroanilinium',
#   'hole_transport_layer': '2PACz',
#   'efficiency_tret': '84',
#   'electron_transport_layer': 'C60',
#   'structure_pin_nip': 'PIN'},
#  '40': {'ISOSD2': {'temperature': 'ISOSD2',
#    'humidity': 'ISOSD2',
#    'time': 'ISOSD2'},
#   'passivating_molecule': 'oleylammonium iodide',
#   'treated_pce': '24.3%',
#   'efficiency_cont': '95%',
#   'hole_transport_layer': 'PTAA',
#   'treated_voc': '1.29',
#   'control_voc': '1.54'},
#  '41': {'efficiency_tret': '23.9%',
#   'ISOSD2': {'time': '1000_hours', 'humidity': '40-50%', 'temperature': '85'},
#   'efficiency_cont': '21.4%',
#   'passivating_molecule': 'o-PDEAI 2',
#   'control_pce_peak': '19.27%',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'treated_voc': '1.157',
#   'control_pce': '21.94%',
#   'control_voc': '1.135'},
#  '42': {'passivating_molecule': 'azetidinium lead iodide',
#   'treated_pce': '22.4%',
#   'treated_voc': '1.18',
#   'perovskite_composition': 'Cs 0.05 MA 0.1 FA 0.85 PbI 2.7 Br 0.3',
#   'ISOSL1': {'temperature': '52'}},
#  '43': {'hole_transport_layer': 'spiro-OMeTAD',
#   'perovskite_composition': 'FA0.8075MA0.10Cs0.05Pb(I0.854Br0.186)3',
#   'treated_pce': '24.5%',
#   'passivating_molecule': 'benzylamine hydroiodide (BAHI)',
#   'ISOSD2': {'humidity': '80 ± 20% relative humidity',
#    'time': '500 h',
#    'passivating_molecule': '60 °C'}},
#  '46': {'humidity': '25%',
#   'temperature': '25C',
#   'passivating_molecule': 'tri-n-octylphosphine (TOPO) 26',
#   'treated_pce_peak': '19.22%'},
#  '47': {'hole_transport_layer': '4,6trimethylphenyl)amine) (PTAA),poly(bis(4-phenyl)(2',
#   'perovskite_molecule': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'passivating_molecule': ['octylammonium sulfate', 'Octylammonium iodide'],
#   'ISOSD2': {'temperature': '65C'},
#   'control_voc': '1.07',
#   'control_pce': '19.16',
#   'treated_voc': 'methylammonium sulfate'},
#  '48': {'hole_transport_layer': 'Poly(triaryl amine) (PTAA)',
#   'perovskite_molecule': '1.0 wt% 2,3,5,6-Tetrafl uoro-7,7,8,8-tetracyanoquinodimethane (F4-TCNQ)',
#   'perovskite_composition': 'Organolead trihalide perovskite (OTP)',
#   'humidity': '40%'},
#  '49': {'passivating_molecule': 'n-butylamine acetate',
#   'treated_pce': '16.25%',
#   'treated_voc': '1.31',
#   'ISOSD2': {'humidity': '65 ± 10% humidity',
#    'time': '4,680H',
#    'temperature': '85 °C for 558 h'},
#   'perovskite_composition': '(BA 2 MA n-1 Pb n I 3n+1 )',
#   'perovskite_molecule': 'BA 2 MA n-1 Pb n I 3n+1',
#   'hole_transport_layer': 'spiro-OMeTAD'},
#  '50': {'passivating_molecule': ['allylammonium',
#    'phenethylammonium',
#    'butylammonium'],
#   'treated_pce': '16.5%',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'perovskite_composition': '(L) 2 (MA) n-1 Pb n I 3n-1',
#   'control_pce': '10-12%',
#   'ISOSD2': {'time': '1000 h', 'temperature': '70 °C'}},
#  '53': {'control_pce': ['4.9%', '20.5'],
#   'passivating_molecule': ['DMePDAI 2', 'BDAI2'],
#   'perovskite_composition': ['FA 0.85 MA 0.1 Cs 0.05 PbI 2.9 Br 0.1',
#    'Cs 0.05 FA 0.95 PbI 3 , (FAPbI 3 ) 0.95 (MAPbBr 3 ) 0.05 , and FAPbI 3'],
#   'electron_transport_layer': ['TiO 2', 'SnO 2'],
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'treated_pce': '24.0%',
#   'ISOSD2': {'humidity': '85% relative humidity',
#    'temperature': '85°C',
#    'time': '1008-h'},
#   'time': '1008-h'},
#  '55': {'passivating_molecule': 'methylammonium lead iodide'},
#  '56': {'treated_pce': '25.5%',
#   'perovskite_composition': 'FA 0.83 Cs 0.17 Pb 0.5 Sn 0.5 I 3',
#   'hole_transport_layer': 'PEDOT:PSS',
#   'electron_transport_layer': 'evaporated C 60 (30 nm) and bathocuproine (BCP) (8 nm),with a copper (Cu) electrode on top'},
#  '57': {'perovskite_composition': 'MA 0.07 FA 0.93 PbI 3',
#   'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'C 60',
#   'ISOSL2': {'humidity': '25%', 'temperature': '25'},
#   'treated_pce': '28.4%'},
#  '58': {'electron_transport_layer': 'SnO 2 Tin oxide'},
#  '59': {'passivating_molecule': 'PEAI',
#   'treated_pce': '19.07%',
#   'treated_voc': '1.25',
#   'control_voc': '1.16',
#   'hole_transport_layer': 'PTAA',
#   'control_pce': '17.5%',
#   'ISOSL1': {'temperature': '250 - 300 K'},
#   'perovskite_composition': 'FA0.8Cs0.2Pb(I0.7Br0.3)3 WBG',
#   'temperature': '250-300 K'},
#  '79': {'electron_transport_layer': ['TinOxide', 'TiO 2'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'structure_pin_nip': 'NIP',
#   'perovskite_molecule': ['Formamidinium Lead Iodide', 'MAPbBr 3'],
#   'ISOSL1': {'treated_pce_peak': 'ISOS-L1', 'humidity': 'ISOS-L1'}},
#  '80': {'perovskite_composition': 'PMMA',
#   'structure_pin_nip': 'NIP',
#   'ISOSD2': {'efficiency_tret': 'ISOS-D-2',
#    'temperature': 'ISOS-D-2',
#    'time': 'ISOS-D-2'},
#   'electron_transport_layer': 'Mesoporous TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '81': {'electron_transport_layer': ['TiO2- Cl', 'TiO 2'],
#   'ISOSL1': {'treated_pce': 'ISOS-L1',
#    'efficiency_tret': 'ISOS-L1',
#    'time': 'ISOS-L1'},
#   'control_voc_peak': 'TiO2',
#   'perovskite_composition': 'CsMAFA',
#   'ISOSD2': {'efficiency_cont': 'ISOS-D2',
#    'efficiency_tret': 'ISOS-D2',
#    'time': 'ISOS-D2',
#    'humidity': 'ISOS-D2'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '82': {'structure_pin_nip': 'PIN',
#   'treated_voc': 'QAHs',
#   'treated_pce_peak': 'QUAs',
#   'perovskite_composition': ['PCBM',
#    'choline chloride',
#    'FA 0.85 MA 0.15 Pb(I 0.85 Br 0.15 ) 3'],
#   'treated_voc_peak': ['L-α-phosphatidylcholine', '16.1 ± 1.1%'],
#   'treated_pce': 'Cl-ChloridepassibatedFA0.85MA0.15Pb(I0.85Br0.15)3',
#   'ISOSD1': {'temperature': 'ISOS-D1',
#    'humidity': 'ISOS-D1',
#    'efficiency_tret': 'ISOS-D1',
#    'efficiency_cont': 'ISOS-D1',
#    'time': 'ISOS-D1'},
#   'ISOSL1': {'treated_pce': 'ISOS-L1',
#    'efficiency_tret': 'ISOS-L1',
#    'time': 'ISOS-L1'}},
#  '83': {'structure_pin_nip': 'PIN',
#   'electron_transport_layer': 'TinOxide',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'treated_voc': 'FAMAPb3',
#   'ISOSD2': {'temperature': 'ISOS-D-2',
#    'humidity': 'ISOS-D-2',
#    'efficiency_tret': 'ISOS-D-2 - FA0.15MA0.85PbI3',
#    'time': 'ISOS-D-2 - FA0.15MA0.85PbI3',
#    'efficiency_cont': 'ISOS-D-2 - MAPbI3',
#    'treated_pce': 'ISOS-D-2 - FA0.15MA0.85PbI3'},
#   'perovskite_composition': 'MAPbI3'},
#  '84': {'structure_pin_nip': 'NIP',
#   'hole_transport_layer': ['Spiro-OMeTAD',
#    'fluorene-terminated hole-transporting material'],
#   'ISOST2': {'efficiency_tret': 'ISOS-T2',
#    'time': 'ISOS-T2',
#    'temperature': 'ISOS-T2'},
#   'perovskite_composition': 'FAPbI 3 ) 0.95 (MAPbBr 3 ) 0.05',
#   'electron_transport_layer': 'mp-TIO2',
#   'ISOSL1': {'efficiency_tret': 'ISOS-L1', 'time': 'ISOS-L1'},
#   'ISOSD1': {'efficiency_tret': 'ISOS-D1',
#    'time': 'ISOS-D1',
#    'temperature': 'ISOS-D1'}},
#  '85': {'hole_transport_layer': 'P3HT',
#   'perovskite_composition': 'HTAB',
#   'ISOSL1': {'treated_pce': 'ISOS-L1',
#    'humidity': 'ISOS-L1',
#    'time': 'ISOS-L1',
#    'efficiency_tret': 'ISOS-L1'},
#   'structure_pin_nip': 'NIP'},
#  '86': {'electron_transport_layer': ['E-SnO2', 'SnO 2'],
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'treated_pce': 'Tin',
#   'ISOSD1': {'efficiency_tret': 'ISOS-D1',
#    'time': 'ISOS-D1',
#    'efficiency_cont': 'ISOS-D1'},
#   'ISOSL1': {'time': 'ISOS-L1',
#    'efficiency_tret': 'ISOS-L1',
#    'efficiency_cont': 'ISOS-L1'}},
#  '87': {'treated_pce': ['21.52', '20.7'],
#   'structure_pin_nip': 'NIP',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'control_pce_peak': '18.5'},
#  '88': {'ISOSL1': {'treated_pce': 'ISOS-L1',
#    'time': 'ISOS-L1',
#    'efficiency_tret': 'ISOS-L1'},
#   'perovskite_composition': 'triple cation perovskite',
#   'treated_pce': 'CsFAMA-F',
#   'control_pce': 'CsMAFA',
#   'ISOSL3': {'treated_pce': 'ISOS-L3', 'time': 'ISOS-L3'},
#   'ISOST2': {'efficiency_tret': 'ISOS-T2',
#    'temperature': 'ISOS-T2',
#    'time': 'ISOS-T2',
#    'efficiency_cont': 'ISOS-T2'},
#   'ISOSD1': {'efficiency_tret': 'ISOS-D1', 'time': 'ISOS-D1'}},
#  '89': {'perovskite_composition': 'FAPbI3',
#   'treated_pce': '20.87',
#   'structure_pin_nip': 'NIP',
#   'treated_voc': '1.145',
#   'electron_transport_layer': 'TinOxide'},
#  '90': {'treated_pce': 'strain-free',
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15)',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'structure_pin_nip': 'NIP',
#   'control_pce': 'tensile-strained',
#   'ISOSL2': {'treated_voc': 'ISOS-L2', 'treated_pce': 'ISOS-L2'}},
#  '91': {'perovskite_composition': 'formamidinium lead iodide',
#   'treated_pce': 'methylammonium chloride - 40%',
#   'passivating_molecule': ['methylammonium chloride - 20%', 'MA-30', 'MA-50'],
#   'control_voc': 'methylammonium chloride',
#   'ISOST1': {'efficiency_tret': 'ISOS-T1', 'time': 'ISOS-T1'},
#   'ISOST2': {'efficiency_cont': 'ISOS-T2',
#    'time': 'ISOS-T2',
#    'efficiency_tret': 'ISOS-T2'},
#   'hole_transport_layer': 'Spiro-OMeTAD'},
#  '92': {'electron_transport_layer': 'BaSnO3',
#   'structure_pin_nip': 'NIP',
#   'treated_pce': '21.3',
#   'ISOSD1': {'time': 'ISOS-D-1',
#    'humidity': 'ISOS-D-1',
#    'efficiency_cont': 'ISOS-D-1',
#    'efficiency_tret': 'ISOS-D-1'},
#   'hole_transport_layer': ['Spiro-OMeTAD', 'PTAA']},
#  '93': {'treated_pce': 'FA0.57MA0.43PbI2.87Br0.13 (Cl)',
#   'structure_pin_nip': 'NIP'},
#  '114': {'hole_transport_layer': 'PTAA',
#   'electron_transport_layer': 'C 60',
#   'passivating_molecule': ['PI', 'Piperazinium Diiodide (PDI)'],
#   'treated_voc': '1.17',
#   'treated_pce': '23.37',
#   'structure_pin_nip': 'p-i-n',
#   'perovskite_composition': 'Cs 0.05 (FA 0.95 MA 0.05 ) 0.95 Pb(I 0.95 Br 0.05 ) 3',
#   'control_pce': '20.76',
#   'control_voc': '1.06'},
#  '115': {'time': '2000',
#   'ISOSD2': {'treated_pce': '24.27',
#    'control_voc': '1.16',
#    'temperature': '85',
#    'treated_voc': '1.163',
#    'control_pce': '21.66'},
#   'temperature': '85',
#   'electron_transport_layer': 'C60',
#   'passivating_molecule': 'FA1-x-yMAxCsyPbI3-zBrz',
#   'hole_transport_layer': 'Spiro-OMeTAD/PTAA'},
#  '116': {'hole_transport_layer': 'Spiro-OMeTAD',
#   'electron_transport_layer': 'TiO2',
#   'perovskite_composition': 'MACl',
#   'ISOSL2': {'temperature': '25',
#    'humidity': '30',
#    'control_voc': '1.153',
#    'efficiency_cont': '22.68',
#    'treated_voc': '1.169'},
#   'humidity': '30',
#   'treated_pce': '24.82',
#   'time': '500',
#   'control_pce': '23.44'},
#  '117': {'hole_transport_layer': 'spiro-OMeTAD',
#   'ISOSL1': {'humidity': '70',
#    'control_pce': '22.2',
#    'control_voc': '1.15',
#    'treated_voc': '1.17',
#    'treated_pce': '23.4',
#    'temperature': '25'},
#   'perovskite_composition': '(FAPbI 3 ) 0.99 (MAPbBr 3 ) 0.01',
#   'passivating_molecule': 'FAPbI 3',
#   'time': '500',
#   'electron_transport_layer': 'TiO2'},
#  '149': {'electron_transport_layer': ['C60', 'C 60', 'BCP', 'Cu', 'SnO 2'],
#   'control_pce_average': '22',
#   'treated_pce_average': '26.4%',
#   'efficiency_tret': '90%',
#   'time': '600 h',
#   'control_pce_peak': 'phenethylammonium (PEA), phenylammonium (PA) and 4-trifluoromethyl-phenylammonium (CF3-PA)',
#   'treated_pce_peak': '26.7',
#   'hole_transport_layer': ['PEDOT:PSS', 'NiO'],
#   'temperature': '35'}}

# %% [markdown]
# ## Retrieving LLama Prediction

# %%
import json

# Path to your JSON file
file_path = '../data/finetuned_llama_output.json'

# Open and load the JSON file
with open(file_path, 'r') as file:
    llama_data = json.load(file)

# Print the data to verify
print(llama_data)
print(f"There are {len(llama_data)} papers that llama evaluated")
# Out:
# {'111': {'control_pce': None, 'control_voc': None, 'treated_pce': 23.9, 'treated_voc': 1.51, 'passivating_molecule': 'isopropylammonium chloride', 'perovskite_composition': 'FAPbI3', 'electron_transport_layer': None, 'hole_transport_layer': None, 'pin_nip_structure': 'PIN', 'stability_tests': [{'test_name': 'ISOS-D', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-L', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-T', 'temperature': 150, 'time': 30, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-LC', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-LT', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}]}, '56': {'control_pce': None, 'control_voc': None, 'treated_pce': 21.1, 'treated_voc': 1.23, 'passivating_molecule': 'LiTFSI', 'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3', 'electron_transport_layer': 'PEDOT:PSS', 'hole_transport_layer': 'C60 and BCP', 'pin_nip_structure': 'PIN', 'stability_tests': [{'test_name': 'ISOS-D', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-L', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-T', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-LC', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-LT', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}]}, '87': {'control_pce': None, 'control_voc': None, 'treated_pce': 21.52, 'treated_voc': 1.15, 'passivating_molecule': 'Eu 3+ -Eu 2+ ion pair', 'perovskite_composition': 'PbX2 layer (CsI 20 mg, PbI2 530 mg, PbBr2 20 mg, PbCl2 20 mg, MAI 5 mg dissolved in 900 μL DMF and 100 μL DMSO mixed solvent)', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'polymer modified spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'stability_tests': [{'test_name': '1 sun illumination', 'temperature': None, 'time': 1000, 'humidity': None, 'control_efficiency': 19.21, 'treatment_efficiency': 21.52}, {'test_name': '85°C heating', 'temperature': 85, 'time': 1000, 'humidity': None, 'control_efficiency': 18.05, 'treatment_efficiency': 21.52}, {'test_name': '1 sun illumination', 'temperature': None, 'time': 500, 'humidity': None, 'control_efficiency': 19.21, 'treatment_efficiency': 21.52}, {'test_name': '85°C heating', 'temperature': 85, 'time': 500, 'humidity': None, 'control_efficiency': 18.05, 'treatment_efficiency': 21.52}]}, '116': {'control_pce': '23.44', 'control_voc': '1.152', 'treated_pce': '24.82', 'treated_voc': '1.164', 'passivating_molecule': 'Spiro-mF', 'perovskite_composition': 'FAPbI3', 'electron_transport_layer': 'compact TiO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'pin_nip_structure': 'PIN', 'stability_tests': [{'test_name': 'ISOS-D', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-L', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-T', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-LC', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}, {'test_name': 'ISOS-LT', 'temperature': None, 'time': None, 'humidity': None, 'control_efficiency': None, 'treatment_efficiency': None}]}, '51': {'control_pce' ...
# There are 149 papers that llama evaluated

# %% [markdown]
# ### Clean Llama predictoin to get rid of key with None and 'Not mentioned' value

# %%
# Recursive function to clean the JSON
def clean_json(obj):
    if isinstance(obj, dict):
        # Recursively process dictionary
        return {
            key: clean_json(value)
            for key, value in obj.items()
            if value not in ['None', None, "Not mentioned"]
        }
    elif isinstance(obj, list):
        # Recursively process list
        return [clean_json(item) for item in obj if item not in ['None', None, "Not mentioned"]]
    else:
        # Return the value as is
        return obj

# %%
filtered_llama_data = clean_json(llama_data)
filtered_llama_data
# Out:
# {'111': {'treated_pce': 23.9,
#   'treated_voc': 1.51,
#   'passivating_molecule': 'isopropylammonium chloride',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T', 'temperature': 150, 'time': 30},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '56': {'treated_pce': 21.1,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'LiTFSI',
#   'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'hole_transport_layer': 'C60 and BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '87': {'treated_pce': 21.52,
#   'treated_voc': 1.15,
#   'passivating_molecule': 'Eu 3+ -Eu 2+ ion pair',
#   'perovskite_composition': 'PbX2 layer (CsI 20 mg, PbI2 530 mg, PbBr2 20 mg, PbCl2 20 mg, MAI 5 mg dissolved in 900 μL DMF and 100 μL DMSO mixed solvent)',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'polymer modified spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': '1 sun illumination',
#     'time': 1000,
#     'control_efficiency': 19.21,
#     'treatment_efficiency': 21.52},
#    {'test_name': '85°C heating',
#     'temperature': 85,
#     'time': 1000,
#     'control_efficiency': 18.05,
#     'treatment_efficiency': 21.52},
#    {'test_name': '1 sun illumination',
#     'time': 500,
#     'control_efficiency': 19.21,
#     'treatment_efficiency': 21.52},
#    {'test_name': '85°C heating',
#     'temperature': 85,
#     'time': 500,
#     'control_efficiency': 18.05,
#     'treatment_efficiency': 21.52}]},
#  '116': {'control_pce': '23.44',
#   'control_voc': '1.152',
#   'treated_pce': '24.82',
#   'treated_voc': '1.164',
#   'passivating_molecule': 'Spiro-mF',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'compact TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '51': {'treated_pce': 23.1,
#   'treated_voc': 1.28,
#   'passivating_molecule': 'R-NH3I',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-LT'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-D'}]},
#  '80': {'control_pce': 21.6,
#   'control_voc': 1.14,
#   'treated_pce': 21.6,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'Poly(methyl methacrylate) (PMMA)',
#   'perovskite_composition': '[FAI]0.81[PbI2]0.85[MAPbBr3]0.15',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '118': {'control_pce': '19.61%',
#   'control_voc': '1.161 V',
#   'treated_pce': '21.54%',
#   'treated_voc': '1.24 V',
#   'passivating_molecule': 'n-Butylammonium bromide (BABr)',
#   'perovskite_composition': 'RbCsMAFA',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Gold',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '23': {'treated_pce': 23.91,
#   'treated_voc': 1.15,
#   'passivating_molecule': '3-fluoro-phenethylammonium (3F-PEA)',
#   'perovskite_composition': 'Cs0.05MA0.1FA0.85PbI3',
#   'electron_transport_layer': 'C60/ALD-SnO2 or PCBM/BCP',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1I'},
#    {'test_name': 'ISOS-L-3', 'temperature': 65, 'humidity': 50}]},
#  '24': {'control_pce': '14.9',
#   'treated_pce': '17.4',
#   'passivating_molecule': 'Cs2PbI2Cl2',
#   'perovskite_composition': 'CsPbI3',
#   'electron_transport_layer': 'CuSCN',
#   'hole_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T',
#     'temperature': 110,
#     'time': 2100,
#     'control_efficiency': '20%'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT', 'temperature': 110}]},
#  '58': {'passivating_molecule': 'PCBM, C60, spiro-OMeTAD, poly-TPD, NiO x, PTAA',
#   'perovskite_composition': 'FA 0.83 Cs 0.17 Pb(I 0.83 Br 0.1 ) 3, FA 0.75 Cs 0.25 Pb(I 0.8 Br 0.2 ) 3',
#   'electron_transport_layer': 'SnO2, NiO x, Poly-TPD, PCBM, C60',
#   'hole_transport_layer': 'PCBM, C60, spiro-OMeTAD, poly-TPD, PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{}]},
#  '89': {'treated_pce': 20.87,
#   'treated_voc': 1.147,
#   'passivating_molecule': 'Formamidine acetate',
#   'perovskite_composition': '(FA,MA,Cs)Pb(I,Br)3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '11': {'treated_pce': 21.8,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'Benzotriazole',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'PCBA',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{}]},
#  '16': {'control_pce': '18.87',
#   'control_voc': '1.04',
#   'treated_pce': '21.05',
#   'treated_voc': '1.11',
#   'passivating_molecule': 'CF3 PEAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '85',
#     'humidity': '70-80%',
#     'control_efficiency': '18.87',
#     'treatment_efficiency': '21.05'}]},
#  '123': {'control_pce': '24.0',
#   'control_voc': '1.19',
#   'treated_pce': '24.3',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'PbPyA2',
#   'perovskite_composition': 'FAPbI3 0.95(MAPbBr3) 0.05',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'TPBi',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '2200',
#     'control_efficiency': '91.8',
#     'treatment_efficiency': '91.8'},
#    {'test_name': 'ISOS-L',
#     'time': '1000',
#     'control_efficiency': '77.6',
#     'treatment_efficiency': '90.5'},
#    {'test_name': 'ISOS-T',
#     'temperature': '85',
#     'time': '2200',
#     'control_efficiency': '73.2',
#     'treatment_efficiency': '91.8'},
#    {'test_name': 'ISOS-LC', 'time': '1000'},
#    {'test_name': 'ISOS-LT', 'time': '1000'}]},
#  '64': {'control_pce': '18.6',
#   'control_voc': '1057',
#   'treated_pce': '13.9',
#   'treated_voc': '1050',
#   'passivating_molecule': 'phenethylammonium lead iodide (PEA 2 PbI 4 )',
#   'perovskite_composition': 'MAPI (3D) and PEA 2 PbI 4 (2D)',
#   'electron_transport_layer': 'molybdenum oxide (MoO 3 )',
#   'hole_transport_layer': 'N4,N4,N4″,N4″tetra([1,1′-biphenyl]-4-yl)-[1,1′:4′,1″-terphenyl]-4,4″-diamine (TaTm)',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '18': {'treated_pce': 23.3,
#   'treated_voc': 1.23,
#   'passivating_molecule': '2-thiophenemethylammonium iodide (TMAI) and phenylethylammonium iodide (PEAI)',
#   'perovskite_composition': '[(FAPbI3)0.87(MAPbBr3)0.13]0.92(CsPbI3)0.08',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '124': {'control_pce': '22.3',
#   'control_voc': '1.13',
#   'treated_pce': '24.6',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'b-poly(1,1-difluoroethylene)',
#   'perovskite_composition': 'Cs0.05(FA0.98MA0.02)0.95Pb(I0.98Br0.02)3',
#   'electron_transport_layer': 'MeO-2PACz',
#   'hole_transport_layer': 'PC61BM',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT', 'treatment_efficiency': '96'}]},
#  '63': {'treated_pce': 11.66,
#   'treated_voc': 938,
#   'passivating_molecule': 'CH3NH3I',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'mTiO2',
#   'hole_transport_layer': 'Spiro-MeOTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '149': {'treated_pce': 26.4,
#   'treated_voc': 2.03,
#   'passivating_molecule': '4-trifluoromethyl-phenylammonium (CF3-PA)',
#   'perovskite_composition': 'FA 0.7 MA 0.3 Pb 0.5 Sn 0.5 I 3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '72': {'treated_pce': 19.9,
#   'treated_voc': 1.05,
#   'passivating_molecule': 'allylammonium (ALA)',
#   'perovskite_composition': 'Cs0.05FA0.8MA0.15PbI2.88Br0.04Cl0.08',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '135': {'treated_pce': 25.6,
#   'treated_voc': 1.19,
#   'passivating_molecule': '(4-(3,11-dimethoxy-7H-dibenzo[c,g]carbazol-7-yl)butyl)phosphonic acid (MeO-4PADBC)',
#   'electron_transport_layer': 'NiO x',
#   'hole_transport_layer': 'NiO x /MeO-4PADBC',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T',
#     'temperature': 65,
#     'time': 1200,
#     'treatment_efficiency': 90},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '75': {'control_pce': '19.6',
#   'treated_pce': '19.8',
#   'treated_voc': '19.3',
#   'passivating_molecule': '[(FAPbI3)0.87(MAPbBr3)0.13]0.92(CsPbI3)0.08',
#   'perovskite_composition': 'R2MAPb2I7',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-LT'}]},
#  '5': {'treated_pce': 22.1,
#   'treated_voc': 1135,
#   'passivating_molecule': 'iso-BAI',
#   'perovskite_composition': 'FA(MA)PbI3',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'TPBI',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-LT'}, {'test_name': 'ISOS-D'}]},
#  '140': {'control_pce': '26.07',
#   'treated_pce': '24.63',
#   'passivating_molecule': 'hexafluorobenzene (HFB)',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '147': {'control_pce': '22.3',
#   'control_voc': '1.112',
#   'treated_pce': '24.7',
#   'treated_voc': '1.161',
#   'passivating_molecule': '4-(3,6-bis(4-(bis(4-methoxyphenyl)amino)phenyl)-9H-carbazol-9-yl)benzenaminium iodide (CBz-PAI)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '2': {'control_pce': '22.39%',
#   'control_voc': '1.095 V',
#   'treated_pce': '24.59%',
#   'treated_voc': '1.185 V',
#   'perovskite_composition': '(A*)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T',
#     'temperature': '85 °C',
#     'time': '1,056 h',
#     'humidity': '85% relative humidity',
#     'control_efficiency': '21.70%',
#     'treatment_efficiency': '24.35%'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '35': {'passivating_molecule': 'PFN-P2',
#   'perovskite_composition': '(CsPbI3)0.05[(FAPbI3)0.83(MAPbBr3)0.17]0.95',
#   'electron_transport_layer': 'PC61BM',
#   'hole_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{}]},
#  '98': {'treated_pce': 21.54,
#   'treated_voc': 1.186,
#   'passivating_molecule': '3,3′-(2,7-dibromo-9H-fluorene-9,9-diyl) bis(n,n-dimethylpropan-1-amine) (FN-Br)',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'DFS',
#   'pin_nip_structure': 'N-I-P',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '49': {'treated_pce': 16.25,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylamine acetate (BAAc)',
#   'perovskite_composition': 'BA2MAn-1PbI3n+1',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 558,
#     'humidity': '65 ± 10%',
#     'treatment_efficiency': 95.7},
#    {'test_name': 'ISOS-L',
#     'time': 1100,
#     'humidity': '65 ± 10%',
#     'treatment_efficiency': 96.2}]},
#  '109': {'treated_pce': 25.7,
#   'treated_voc': 1.177,
#   'passivating_molecule': 'Polyacrylic acid (PAA)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'Compact-TiO2 (c-TiO2) and polyacrylic acid-stabilized tin(IV) oxide quantum dots (paa-QD-SnO2)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': '1000-hour shelf life',
#     'temperature': 25,
#     'time': 1000,
#     'humidity': '25% RH',
#     'treatment_efficiency': '80% of initial efficiency retained'},
#    {'test_name': 'Operational stability test',
#     'temperature': 25,
#     'time': 350,
#     'humidity': '25% RH',
#     'treatment_efficiency': '95% of initial efficiency retained'},
#    {'test_name': 'MPP tracking test',
#     'temperature': 25,
#     'time': 100,
#     'humidity': '25% RH',
#     'treatment_efficiency': 'Higher PCE than the reference cell'}]},
#  '32': {'treated_pce': 21.0,
#   'treated_voc': 1.07,
#   'passivating_molecule': 'CH3NH3+',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '91': {'control_pce': 'null',
#   'control_voc': 'null',
#   'treated_pce': '24.02',
#   'treated_voc': '1.130',
#   'passivating_molecule': 'Methylammonium chloride (MACl)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'null',
#   'hole_transport_layer': 'null',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': '90%'},
#    {'test_name': 'ISOS-L',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': '40 C',
#     'time': '300 h',
#     'humidity': 'null',
#     'control_efficiency': '60%',
#     'treatment_efficiency': '90%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-LT',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'}]},
#  '40': {'control_pce': '24.3',
#   'treated_pce': '24.3',
#   'treated_voc': '1.20',
#   'passivating_molecule': 'Oleylammonium iodide (OLAI)',
#   'perovskite_composition': 'Cs0.03(FA0.90MA0.10)0.97PbI3',
#   'electron_transport_layer': 'ITO',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Damp-heat test',
#     'temperature': '85',
#     'time': '1000',
#     'humidity': '85%',
#     'treatment_efficiency': '19.3 ± 0.69%'}]},
#  '107': {'treated_pce': 21.25,
#   'treated_voc': 1.127,
#   'passivating_molecule': 'sulfonyl-functionalized phenethylammonium salt (SF-PEA)',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-LT',
#     'humidity': '50-60%',
#     'treatment_efficiency': 91}]},
#  '96': {'treated_pce': 22.19,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'tin(IV) bis(acetylacetonate) dichloride (Cl2) and tin(IV) bis(acetylacetonate) dibromide (Br2)',
#   'electron_transport_layer': 'tin oxide',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-LT'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'}]},
#  '47': {'control_pce': '19.16%',
#   'control_voc': '1.07 V',
#   'treated_pce': '21.1%',
#   'treated_voc': '1.16 V',
#   'passivating_molecule': 'PbSO4',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T',
#     'temperature': 65,
#     'control_efficiency': '18.2%',
#     'treatment_efficiency': '21.1%'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT',
#     'temperature': 65,
#     'control_efficiency': '8.54%',
#     'treatment_efficiency': '96.8%'}]},
#  '100': {'treated_pce': 23.24,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'In2O3',
#   'electron_transport_layer': 'In2O3/SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PCBM',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '125': {'treated_pce': 23.7,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'selenophene',
#   'perovskite_composition': 'Cs1-xFAxPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'PTAA/Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T', 'temperature': 85, 'time': 1750},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT', 'temperature': 85, 'time': 960}]},
#  '62': {'control_pce': '16.50',
#   'control_voc': '1.01',
#   'treated_pce': '16.50',
#   'treated_voc': '1.02',
#   'passivating_molecule': 'BAI',
#   'perovskite_composition': '2D-(BA) 2 (MA) n-1 Pb n I 3n+1',
#   'electron_transport_layer': 'TiO 2',
#   'hole_transport_layer': 'C 60',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'humidity': '55%',
#     'control_efficiency': '16.07',
#     'treatment_efficiency': '15.40'},
#    {'test_name': 'ISOS-L',
#     'humidity': '80°C',
#     'control_efficiency': '13.88',
#     'treatment_efficiency': '11.05'},
#    {'test_name': 'ISOS-T',
#     'temperature': '80°C',
#     'time': '30 days',
#     'control_efficiency': '44%',
#     'treatment_efficiency': '73%'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '80°C',
#     'time': '30 days',
#     'control_efficiency': '27%',
#     'treatment_efficiency': '10.88'}]},
#  '122': {'control_pce': '25.6',
#   'control_voc': '1.1824',
#   'treated_pce': '25.86',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'RbCl',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '1000',
#     'control_efficiency': '96%',
#     'treatment_efficiency': '96%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': '85',
#     'time': '500',
#     'treatment_efficiency': '80%'}]},
#  '65': {'control_pce': '4.73',
#   'control_voc': '1.18',
#   'treated_pce': '4.73',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'PEA (C6H5(CH2)2NH3+)',
#   'perovskite_composition': '(PEA)2(MA)2[Pb3I10]',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '52%'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '19': {'control_pce': 'null',
#   'control_voc': 'null',
#   'treated_pce': '24.09',
#   'treated_voc': '1.1595',
#   'passivating_molecule': '3,4,5-trifluoroanilinium (345FAn)',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.9Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'C60/bathocuproine (BCP)',
#   'hole_transport_layer': '2PACz',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L-3-85°C',
#     'temperature': '85',
#     'time': '1560',
#     'humidity': '50%',
#     'control_efficiency': '19.9%',
#     'treatment_efficiency': '24.09%'}]},
#  '17': {'control_pce': '20.04',
#   'control_voc': '1.16',
#   'treated_pce': '22.02',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'hexyltrimethylammonium bromide',
#   'perovskite_composition': 'Cs0.05 FA0.81 MA0.14 PbI2.55 Br0.45',
#   'electron_transport_layer': 'doped spiro-OMeTAD',
#   'hole_transport_layer': 'doped spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '70-75%'},
#    {'test_name': 'ISOS-L', 'humidity': '70-75%'},
#    {'test_name': 'ISOS-T', 'temperature': '80 °C', 'time': '90 min'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '10': {'treated_pce': 24.41,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'Tosylate ([TsO] -)',
#   'perovskite_composition': '(FAPbI3) 0.95 (MAPbBr3) 0.05',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T', 'temperature': 40},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '25': {'passivating_molecule': 'FAac (formamidinium acetate)',
#   'perovskite_composition': 'FAPbI3 or FAPbBr3',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': '85'}]},
#  '59': {'control_pce': '19.07%',
#   'control_voc': '1.25',
#   'treated_pce': '19.07%',
#   'treated_voc': '1.25',
#   'passivating_molecule': 'phenethylammonium iodide (PEAI)',
#   'perovskite_composition': 'FA0.8Cs0.2Pb(I0.7Br0.3)3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '88': {'control_pce': '19.03',
#   'treated_pce': '21.46',
#   'treated_voc': '0.94',
#   'passivating_molecule': 'NaF',
#   'perovskite_composition': '(Cs 0.05 FA 0.54 MA 0.41 )Pb(I 0.98 Br 0.02 ) 3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T',
#     'temperature': '85 °C',
#     'time': '1,000 h',
#     'control_efficiency': '19.03',
#     'treatment_efficiency': '21.46'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '119': {'treated_pce': 23.9,
#   'treated_voc': 1.15,
#   'passivating_molecule': '1,1,2,2,3,3-hexafluoropropane-1,3-disulfonimide (HFDF-)',
#   'electron_transport_layer': 'Poly(triarylamine) (PTAA)',
#   'hole_transport_layer': 'Poly(triarylamine) (PTAA) doped with 1,1,2,2,3,3-hexafluoropropane-1,3-disulfonimide (HFDF-)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L', 'temperature': 85, 'time': 200},
#    {'test_name': 'ISOS-T', 'temperature': 120},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT', 'temperature': 85, 'time': 1000}]},
#  '22': {'control_pce': '21.40',
#   'control_voc': '1.092',
#   'treated_pce': '23.77',
#   'treated_voc': '1.145',
#   'passivating_molecule': 'Cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'α-formamidinium lead triiodide (FAPbI3)',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT', 'treatment_efficiency': '95%'}]},
#  '117': {'control_pce': 0.22,
#   'control_voc': 1.15,
#   'treated_pce': 25.1,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'spiro-OMeTAD 2•+ (TFSI -)2',
#   'perovskite_composition': '(FAPbI3)0.99(MAPbBr3)0.01',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'doped spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 1200,
#     'humidity': '70 ± 5%',
#     'control_efficiency': 0.22,
#     'treatment_efficiency': 25.1},
#    {'test_name': 'ISOS-L',
#     'temperature': 25,
#     'time': 800,
#     'humidity': '70 ± 3°C',
#     'control_efficiency': 0.22,
#     'treatment_efficiency': 25.1}]},
#  '50': {'treated_pce': 14.4,
#   'treated_voc': 1.05,
#   'passivating_molecule': 'allylammonium',
#   'perovskite_composition': 'L2(MA)n-1Pb(nI3)n',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{}, {}]},
#  '81': {'control_pce': '20.1',
#   'control_voc': '1.140',
#   'treated_pce': '19.9',
#   'treated_voc': '1.145',
#   'passivating_molecule': 'Chlorine',
#   'perovskite_composition': 'MAPbI3-xClx',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '110': {'treated_pce': 25.6,
#   'treated_voc': 1.21,
#   'passivating_molecule': 'Formamidinium formate',
#   'perovskite_composition': 'α-FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '57': {'treated_pce': 22.5,
#   'treated_voc': 1.098,
#   'perovskite_composition': 'MA 0.07 FA 0.93 PbI 3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'C 60',
#   'pin_nip_structure': 'pin',
#   'stability_tests': [{},
#    {'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '86': {'treated_pce': 21.6,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'Ethylene diamine tetraacetic acid (EDTA)',
#   'electron_transport_layer': 'EDTA-complexed SnO2 (E-SnO2)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '97': {'control_pce': '20.5%',
#   'control_voc': '1.06 V',
#   'treated_pce': '22.3%',
#   'treated_voc': '1.17 V',
#   'passivating_molecule': 'Alkylammonium ligands (AALs)',
#   'perovskite_composition': 'Cs 0.05 (FA 0.92 MA 0.08 ) 0.95 Pb(I 0.92 Br 0.08 ) 3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'PCBM',
#   'pin_nip_structure': 'p-i-n',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': '40 °C',
#     'time': '1000 h',
#     'humidity': 'constant nitrogen atmosphere',
#     'control_efficiency': '17%',
#     'treatment_efficiency': '21.2%'},
#    {'test_name': 'Thermal stability',
#     'temperature': '85 °C',
#     'time': '1020 h',
#     'humidity': 'constant nitrogen atmosphere',
#     'control_efficiency': '17%',
#     'treatment_efficiency': '18%'}]},
#  '46': {'treated_pce': 20.0,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'PFN-P2 and LiF',
#   'perovskite_composition': 'CsPbI0.05[(FAPbI3)0.89(MAPbBr3)0.11]0.95',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '101': {'treated_pce': 20.19,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'DTB(3%DEG)',
#   'hole_transport_layer': 'DTB(xDEG)',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '90': {'treated_pce': 20.7,
#   'treated_voc': 1.17,
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-LT'},
#    {'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'}]},
#  '41': {'control_pce': '21.94',
#   'control_voc': '1.135',
#   'treated_pce': '23.92',
#   'treated_voc': '1.157',
#   'passivating_molecule': 'ortho-(phenylene)di(ethylammonium) iodide (o-PDEAI 2 )',
#   'perovskite_composition': 'PbI2 :PbBr2 :FAI:MAI:CsI:MACl = 0.98:0.02:0.81:0.04:0.05:0.20',
#   'electron_transport_layer': 'fluorine-doped tin oxide (FTO)',
#   'hole_transport_layer': '2,2′,7,7′-tetrakis-(N,N-di-4-methoxyphenylamino)-9,9′spirobifluorene (spiro-OMeTAD)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'long-term stability',
#     'temperature': '25 °C',
#     'time': '1000 h',
#     'humidity': '40-50% RH',
#     'control_efficiency': '85%',
#     'treatment_efficiency': '90.2%'},
#    {'test_name': 'thermal stability',
#     'temperature': '85 °C',
#     'time': '1000 h',
#     'humidity': 'air',
#     'control_efficiency': '49%',
#     'treatment_efficiency': '25%'},
#    {'test_name': 'light-soaking stability',
#     'temperature': '25 °C',
#     'time': '1100 h',
#     'humidity': 'air',
#     'control_efficiency': '>60%',
#     'treatment_efficiency': '>90%'}]},
#  '106': {'treated_pce': 0.22802,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'ZrL3',
#   'perovskite_composition': 'Zr6O4(OH)4(L3)2(OH)6(H2O)27(DMF)',
#   'electron_transport_layer': 'PC61BM',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T', 'temperature': 85, 'time': 1000},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '108': {'control_pce': '24.48%',
#   'control_voc': '1.138 V',
#   'treated_pce': '25.17%',
#   'treated_voc': '1.168 V',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'mp-TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85°C',
#     'time': '1300 hours',
#     'humidity': '15 to 25% RH',
#     'control_efficiency': '80%',
#     'treatment_efficiency': '90%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': '150°C',
#     'time': '20 hours',
#     'humidity': '15 to 25% RH',
#     'control_efficiency': '60%',
#     'treatment_efficiency': '80%'}]},
#  '33': {'treated_pce': 23.7,
#   'passivating_molecule': 'Benzene',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '34': {'pin_nip_structure': 'PIN', 'stability_tests': [{}]},
#  '99': {'control_pce': '18.08',
#   'control_voc': '1.087',
#   'treated_pce': '21.01',
#   'treated_voc': '1.146',
#   'passivating_molecule': 'Chlorine-rich mixed-halide perovskite (ClMPI)',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'Outdoor solar irradiation',
#     'control_efficiency': '90%',
#     'treatment_efficiency': '94%'},
#    {'test_name': 'High-intensity UV irradiation',
#     'treatment_efficiency': '82%'},
#    {'test_name': '1-sun full spectrum illumination (including UV light)',
#     'treatment_efficiency': '80%'}]},
#  '48': {'control_pce': '16.9%',
#   'control_voc': '1.07 V',
#   'treated_pce': '20.3%',
#   'treated_voc': '1.07 V',
#   'passivating_molecule': 'PCBM',
#   'perovskite_composition': 'Lead iodide (PbI2) and methylammonium iodide (MAI)',
#   'electron_transport_layer': 'PTAA: F4-TCNQ',
#   'hole_transport_layer': 'PTAA: F4-TCNQ',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': 'air'},
#    {'test_name': 'ISOS-L', 'humidity': 'air'},
#    {'test_name': 'ISOS-T', 'humidity': 'air'},
#    {'test_name': 'ISOS-LC', 'humidity': 'air'},
#    {'test_name': 'ISOS-LT', 'humidity': 'air'}]},
#  '146': {'control_pce': '21.5%',
#   'control_voc': 1.128,
#   'treated_pce': '23.05%',
#   'treated_voc': 1.17,
#   'passivating_molecule': 'CB-NH2',
#   'perovskite_composition': 'Cs0.05 (MA0.05 FA0.95)0.95 Pb(I0.95 Br0.05)3',
#   'electron_transport_layer': 'C60',
#   'hole_transport_layer': 'BCP',
#   'pin_structure': 'PIN',
#   'stability_tests': [{'test_name': 'MPP tracking in glovebox',
#     'temperature': 26,
#     'time': 400,
#     'humidity': '30%',
#     'control_efficiency': '21.10%',
#     'treatment_efficiency': '23.04%'},
#    {'test_name': 'MPP tracking in air',
#     'temperature': 40,
#     'time': 400,
#     'humidity': '30%',
#     'control_efficiency': '89%',
#     'treatment_efficiency': '97%'}]},
#  '3': {'control_pce': '24.5',
#   'control_voc': '1.20',
#   'treated_pce': '24.5',
#   'treated_voc': '1.20',
#   'passivating_molecule': 'BA2MA2Pb3I10',
#   'perovskite_composition': 'BA2MA2Pb3I10',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'humidity': '70 ± 5 %RH',
#     'control_efficiency': '21%',
#     'treatment_efficiency': '23.75%'}]},
#  '4': {'treated_pce': 21.06,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'vinylbenzylammonium bromide (VBABr)',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{}]},
#  '141': {'control_pce': '21.3',
#   'treated_pce': '22.0',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'Cl 6 SubPc',
#   'electron_transport_layer': 'C 60',
#   'hole_transport_layer': 'Cu:NiO x',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'treatment_efficiency': '99%'},
#    {'test_name': 'ISOS-L', 'treatment_efficiency': '95%'},
#    {'test_name': 'ISOS-T',
#     'temperature': '80 °C',
#     'time': '2000 h',
#     'control_efficiency': '25%',
#     'treatment_efficiency': '5%'},
#    {'test_name': 'ISOS-LC', 'treatment_efficiency': '90%'},
#    {'test_name': 'ISOS-LT', 'time': '1272 h', 'treatment_efficiency': '95%'}]},
#  '74': {'treated_pce': 21.17,
#   'treated_voc': 1.13,
#   'passivating_molecule': '4F-PEAI',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T', 'temperature': 100, 'time': 120},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '133': {'control_pce': '22.34%',
#   'treated_pce': '24.56%',
#   'treated_voc': '1.19 V',
#   'passivating_molecule': 'Sodium thioglycolate',
#   'perovskite_composition': 'FA0.75MA0.25Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'NiOx',
#   'hole_transport_layer': 'Me-4PACz',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'treatment_efficiency': '24.04%'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '148': {'control_pce': '23.5',
#   'treated_pce': '23.5',
#   'treated_voc': '1.142',
#   'passivating_molecule': '4-tert-butyl-benzylammonium iodide (tBBAI)',
#   'perovskite_composition': 'Cs0.05 FA0.85 MA0.10 Pb(I0.97 Br0.03)3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '73': {'treated_pce': 22.6,
#   'treated_voc': 1.091,
#   'passivating_molecule': '2CF3-PEAI',
#   'perovskite_composition': 'FA0.98MA0.02PbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-LT',
#     'temperature': 85,
#     'time': 1000,
#     'humidity': '85%'},
#    {'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'}]},
#  '134': {'control_pce': '23.13',
#   'control_voc': '1.141',
#   'treated_pce': '25.32',
#   'treated_voc': '1.174',
#   'passivating_molecule': 'Guanabenz acetate salt',
#   'perovskite_composition': 'α-FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '20',
#     'time': '500',
#     'humidity': '85%',
#     'control_efficiency': '25.90',
#     'treatment_efficiency': '25.96'},
#    {'test_name': 'ISOS-LC',
#     'temperature': '25',
#     'time': '300',
#     'humidity': '85%',
#     'control_efficiency': '22.39',
#     'treatment_efficiency': '24.76'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '85',
#     'time': '300',
#     'humidity': '85%',
#     'control_efficiency': '22.30',
#     'treatment_efficiency': '24.50'}]},
#  '93': {'treated_pce': 21.21,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'spiro-OMeTAD',
#   'perovskite_composition': 'FA 1-x MA x PbI 2.87 Br 0.13 (Cl)',
#   'electron_transport_layer': 'SnO 2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '42': {'control_pce': '19.52%',
#   'control_voc': '1.07',
#   'treated_pce': '22.03%',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'Azetidinium lead iodide (AzPbI3)',
#   'perovskite_composition': 'Cs0.05MA0.1FA0.85PbI2.7Br0.3',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'control_efficiency': '47%',
#     'treatment_efficiency': '85%'}]},
#  '105': {'control_pce': 21.65,
#   'control_voc': 1.172,
#   'treated_pce': 23.36,
#   'treated_voc': 1.193,
#   'passivating_molecule': 'Nitrogen-doped titanium oxide (TiO x N y)',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'Nitrogen-doped titanium oxide (TiO x N y)',
#   'hole_transport_layer': 'Poly(3-hexylthiophene) and copper phthalocyanine',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Light-soaking'},
#    {'test_name': 'Damp-heat', 'temperature': 85, 'humidity': '85%'}]},
#  '39': {'control_pce': '19.9',
#   'control_voc': '1.09',
#   'treated_pce': '20.82',
#   'treated_voc': '1.193',
#   'passivating_molecule': '2-thiophenemethylammonium bromide (2-TMABr)',
#   'perovskite_composition': '[FAPbI3]0.87[MABr3]0.13[CspI3]0.08',
#   'electron_transport_layer': 'mesoporous TiO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '94': {'control_pce': '19.98',
#   'control_voc': '1.112',
#   'treated_pce': '20.84',
#   'treated_voc': '1.129',
#   'passivating_molecule': 'P4VP',
#   'perovskite_composition': 'PbI2, CsI, MAI, MABr, MACl, FAI',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'P4VP',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'humidity': '25-50%',
#     'control_efficiency': '19.98',
#     'treatment_efficiency': '20.84'},
#    {'test_name': 'ISOS-L',
#     'humidity': '25-50%',
#     'control_efficiency': '19.98',
#     'treatment_efficiency': '20.84'},
#    {'test_name': 'ISOS-T',
#     'humidity': '25-50%',
#     'control_efficiency': '19.98',
#     'treatment_efficiency': '20.84'},
#    {'test_name': 'ISOS-LC',
#     'humidity': '25-50%',
#     'control_efficiency': '19.98',
#     'treatment_efficiency': '20.84'},
#    {'test_name': 'ISOS-LT',
#     'humidity': '25-50%',
#     'control_efficiency': '19.98',
#     'treatment_efficiency': '20.84'}]},
#  '45': {'treated_pce': 25.1,
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{}]},
#  '102': {'treated_pce': 21.07,
#   'treated_voc': 1.122,
#   'passivating_molecule': 'Spiro-MeOTAD',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'FTO',
#   'hole_transport_layer': 'MACl',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '37': {'treated_pce': 26.29,
#   'treated_voc': 2.13,
#   'passivating_molecule': '1,3-propylene diammonium (PDA)',
#   'perovskite_composition': 'Cs0.2FA0.8Pb(I0.6Br0.4)3',
#   'electron_transport_layer': 'NiOx/Me-4PACz',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx/Me-4PACz',
#   'stability_tests': [{'test_name': 'ISOS-LT'},
#    {'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-LC'}]},
#  '30': {'treated_pce': 23.21,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'ammonia',
#   'perovskite_composition': 'α-FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{},
#    {'test_name': 'shelf-life stability', 'humidity': '10-30%'},
#    {'test_name': 'light-soaking stability'}]},
#  '132': {'control_pce': 8.7,
#   'control_voc': 1.13,
#   'treated_pce': 23.1,
#   'treated_voc': 1.177,
#   'passivating_molecule': '1-dodecanethiol (DDT)',
#   'perovskite_composition': 'Cs0.05 FA0.81 MA0.14 PbI2.55 Br0.45',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'dark storage (ISOS-D)'},
#    {'test_name': 'light-soaking (ISOS-L)'},
#    {'test_name': 'thermal cycling (ISOS-T)'},
#    {'test_name': 'light cycling (ISOS-LC)'},
#    {'test_name': 'solar-thermal cycling (ISOS-LT)'}]},
#  '79': {'treated_pce': 20.27,
#   'treated_voc': 1.1,
#   'passivating_molecule': 'PbI2',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'n-i-p',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '145': {'treated_pce': 20.48,
#   'treated_voc': 1.13,
#   'passivating_molecule': '4-fluoroaniline (FAL)',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T', 'temperature': 85, 'time': 100, 'humidity': 95},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT', 'temperature': 85, 'time': 100, 'humidity': 95}]},
#  '0': {'control_pce': '25.7',
#   'control_voc': '1.17',
#   'treated_pce': '26.15',
#   'treated_voc': '1.18',
#   'passivating_molecule': '4-chlorobenzenesulfonate (4Cl-BZS)',
#   'perovskite_composition': 'α-phase FAPbI3',
#   'electron_transport_layer': 'C60',
#   'hole_transport_layer': 'SAMs (self-assembled monolayers)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D-2I',
#     'temperature': 85,
#     'time': 1500,
#     'humidity': '50 ± 10%',
#     'control_efficiency': '19.9%',
#     'treatment_efficiency': '95%'},
#    {'test_name': 'ISOS-L-3',
#     'temperature': 65,
#     'time': 1200,
#     'humidity': '50 ± 10%',
#     'control_efficiency': '23.2%',
#     'treatment_efficiency': '95%'}]},
#  '139': {'treated_pce': 26.09,
#   'treated_voc': 1.164,
#   'passivating_molecule': '1-(phenylsulfonyl)pyrrole (PSP)',
#   'perovskite_composition': 'FA 0.95 Cs 0.05 PbI 3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'treatment_efficiency': 92},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T',
#     'temperature': 85,
#     'time': 300,
#     'humidity': 85,
#     'control_efficiency': 80,
#     'treatment_efficiency': 90},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '70': {'control_pce': '17.7',
#   'control_voc': '1105',
#   'treated_pce': '19.7',
#   'treated_voc': '1138',
#   'passivating_molecule': 'Spiro-MeOTAD',
#   'perovskite_composition': 'FA0.83MA0.17Pb(I0.83Br0.17)3',
#   'electron_transport_layer': 'Spiro-MeOTAD',
#   'hole_transport_layer': 'Au',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T', 'temperature': 70},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '137': {'control_pce': '22.8',
#   'treated_pce': '25.5',
#   'passivating_molecule': '3-(methylthio)propylamine hydroiodide (3MTPAI) and diammonium molecules',
#   'perovskite_composition': 'PbI3',
#   'electron_transport_layer': 'C60',
#   'hole_transport_layer': 'NiOx/4PACz',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1600,
#     'humidity': '50%',
#     'control_efficiency': '22.8',
#     'treatment_efficiency': '25.5'},
#    {'test_name': 'ISOS-L',
#     'temperature': 65,
#     'time': 2000,
#     'humidity': '50%',
#     'control_efficiency': '24.7',
#     'treatment_efficiency': '96'}]},
#  '9': {'control_pce': '14.70%',
#   'treated_pce': '17.60%',
#   'passivating_molecule': 'C8',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'Cu-doped NiOx',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '77': {'treated_pce': 24.1,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'PEAMA +',
#   'perovskite_composition': 'FA 0.9 Cs 0.1 PbI 3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T',
#     'temperature': 85,
#     'time': 1500,
#     'control_efficiency': 90,
#     'treatment_efficiency': 90},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT',
#     'temperature': 100,
#     'time': 500,
#     'treatment_efficiency': 90}]},
#  '130': {'control_pce': '22.9',
#   'control_voc': '25.1',
#   'treated_pce': '25.4',
#   'treated_voc': '25.0',
#   'passivating_molecule': 'Pentanamidine hydrochloride (PAD)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '121': {'control_pce': '26.08',
#   'treated_pce': '26.08',
#   'passivating_molecule': 'Propylammonium chloride (PACl)',
#   'perovskite_composition': 'α-FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '66': {'treated_pce': 21.1,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'Cs 0.15 FA 0.85 PbI 2.55 Br 0.45',
#   'perovskite_composition': 'Cs 0.15 FA 0.85 PbI 2.55 Br 0.45',
#   'electron_transport_layer': 'ITO',
#   'hole_transport_layer': 'Cu',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D1'},
#    {'test_name': 'ISOS-D3', 'temperature': 85, 'humidity': 85},
#    {'test_name': 'ISOS-O3'}]},
#  '126': {'control_pce': '23.43%',
#   'control_voc': '1.16 V',
#   'treated_pce': '25.39%',
#   'treated_voc': '1.18 V',
#   'passivating_molecule': 'PbC2O4',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'UV-Vis absorption spectra',
#     'control_efficiency': '23.43%',
#     'treatment_efficiency': '25.39%'},
# ...
#     'humidity': '~50% RH',
#     'control_efficiency': '24.6%',
#     'treatment_efficiency': '24.6%'},
#    {'test_name': 'ISOS-L-3',
#     'temperature': '85°C',
#     'time': '500 h',
#     'humidity': '~85% RH',
#     'control_efficiency': '25.0%',
#     'treatment_efficiency': '23.35%'},
#    {'test_name': 'ISOS-L-3',
#     'temperature': '65°C',
#     'time': '500 h',
#     'humidity': '~50% RH',
#     'control_efficiency': '23.1%',
#     'treatment_efficiency': 'N.A.'},
#    {'test_name': 'ISOS-L-3',
#     'temperature': '85°C',
#     'time': '500 h',
#     'humidity': '~65% RH',
#     'control_efficiency': 'N.A.',
#     'treatment_efficiency': '23.1%'},
#    {'test_name': 'ISOS-L-3',
#     'temperature': '85°C',
#     'time': '4000 h',
#     'humidity': '~50% RH',
#     'control_efficiency': 'N.A.',
#     'treatment_efficiency': 'N.A.'}]},
#  '6': {'treated_pce': 15.3,
#   'treated_voc': 1.06,
#   'passivating_molecule': 'phenylethylammonium',
#   'perovskite_composition': 'PEA2(CH3NH3)n-1Pb(nI3n+1)',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '90%'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '78': {'treated_pce': 20.2,
#   'treated_voc': 1.06,
#   'passivating_molecule': 'dimethylsulfoxide (DMSO)',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'n-i-p',
#   'stability_tests': [{}]},
#  '143': {'control_pce': '19.3',
#   'control_voc': '1.18',
#   'treated_pce': '18',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'CuSCN',
#   'perovskite_composition': '(FAPbI3)0.77(MAPbBr3)0.14(CsPbI3)0.09',
#   'electron_transport_layer': 'CuSCN',
#   'hole_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '31': {'control_pce': '23.39',
#   'control_voc': '1.12',
#   'treated_pce': '25.49',
#   'treated_voc': '1.15',
#   'passivating_molecule': '3-(aminomethyl)pyridine (3-APy)',
#   'perovskite_composition': 'Rb0.05Cs0.05MA0.05FA0.85Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-LT',
#     'temperature': '55',
#     'time': '2408',
#     'control_efficiency': '24.35',
#     'treatment_efficiency': '25.49'},
#    {'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '850',
#     'humidity': '94',
#     'control_efficiency': '22.3',
#     'treatment_efficiency': '24.6'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-L'}]},
#  '36': {'treated_pce': 20.4,
#   'treated_voc': 1.149,
#   'passivating_molecule': 'C60',
#   'perovskite_composition': 'Cs0.05(FA0.83MA0.17)0.95Pb(I0.83Br0.17)3',
#   'electron_transport_layer': 'PTAA:PFN',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '95': {'treated_pce': 22.9,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'Octylammonium iodide (OAI)',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-LT',
#     'temperature': 65,
#     'time': 100,
#     'humidity': '65%',
#     'treatment_efficiency': 80},
#    {'test_name': 'ISOS-D',
#     'temperature': 65,
#     'time': 100,
#     'humidity': '65%',
#     'treatment_efficiency': 20},
#    {'test_name': 'ISOS-L', 'temperature': 65, 'time': 100, 'humidity': '65%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': 65,
#     'time': 100,
#     'humidity': '65%'}]},
#  '44': {'treated_pce': 21.12,
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '103': {'control_pce': '22.57',
#   'control_voc': '0.926',
#   'treated_pce': '22.97',
#   'treated_voc': '0.886',
#   'passivating_molecule': 'MDACl2',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'CuPC',
#   'hole_transport_layer': 'chlorobenzene',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '92': {'treated_pce': 21.7,
#   'treated_voc': 21.3,
#   'passivating_molecule': 'BaSnO3',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'BaSnO3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '10%'},
#    {'test_name': 'ISOS-L', 'humidity': '40%'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '43': {'treated_pce': 24.5,
#   'treated_voc': 1.15,
#   'passivating_molecule': "2,2',7,7'-tetrakis(N,N-di-p-methoxyphenyl-amine)-9,9'-spirobifluorene (spiro-OMeTAD)",
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '104': {'treated_pce': 25.2,
#   'treated_voc': 1.225,
#   'passivating_molecule': 'MAPbBr3',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1I',
#     'temperature': 45,
#     'humidity': 'ambient',
#     'treatment_efficiency': 25.2}]},
#  '115': {'control_pce': '23.7%',
#   'treated_pce': '24.04%',
#   'passivating_molecule': 'Anisole',
#   'perovskite_composition': 'FA1-x-yMAxCsyPbI3-zBrz',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '52': {'control_pce': '19.1%',
#   'control_voc': '658.4 mV',
#   'treated_pce': '25%',
#   'treated_voc': '25% (estimated)',
#   'passivating_molecule': 'Dielectric oxide',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '83': {'control_pce': '21.3',
#   'treated_pce': '21.38',
#   'treated_voc': '1.12',
#   'passivating_molecule': 'MAPbI3',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '29': {'passivating_molecule': 'butylamine',
#   'electron_transport_layer': 'linear-PEI',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '112': {'control_pce': 21.8,
#   'control_voc': 1.14,
#   'treated_pce': 23.2,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Benzylhydrazine hydrochloride (BHC)',
#   'perovskite_composition': 'MA0.7FA0.3PbI3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'n-dodecylammonium iodide',
#   'pin_nip_structure': 'p-i-n',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 65},
#    {'test_name': 'ISOS-L', 'temperature': 65},
#    {'test_name': 'ISOS-T', 'temperature': 65},
#    {'test_name': 'ISOS-LC', 'temperature': 65},
#    {'test_name': 'ISOS-LT', 'temperature': 65}]},
#  '55': {'treated_pce': 11.8,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'Methylammonium (CH3NH3+)',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'Fluorine-doped tin oxide (F:SnO2)',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 263},
#    {'test_name': 'ISOS-L', 'temperature': 263},
#    {'test_name': 'ISOS-T', 'temperature': 323},
#    {'test_name': 'ISOS-LC', 'temperature': 263},
#    {'test_name': 'ISOS-LT', 'temperature': 323}]},
#  '84': {'treated_pce': 22.1,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'DM',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'DM',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 500,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T', 'temperature': 70, 'time': 50},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT', 'temperature': 80, 'time': 50}]},
#  '27': {'control_pce': 'null',
#   'control_voc': 'null',
#   'treated_pce': '18.5',
#   'treated_voc': '1.23',
#   'passivating_molecule': 'CF3-PEA',
#   'perovskite_composition': 'CsPbI3-xBrx',
#   'electron_transport_layer': 'NiOx',
#   'hole_transport_layer': 'SAM',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-L',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-LC',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-LT',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'}]},
#  '20': {'passivating_molecule': 'phenylethylammonium (PEA)',
#   'perovskite_composition': 'MAPbI3 (3D) and (PEA)2PbI4 (2D)',
#   'electron_transport_layer': 'poly(methyl methacrylate) (PMMA)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'poly(methyl methacrylate) (PMMA)',
#   'stability_tests': [{'test_name': 'ISOS-LT', 'temperature': 60, 'time': 450},
#    {'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'}]},
#  '69': {'treated_pce': 20.0,
#   'passivating_molecule': 'Tetrakis(dimethylamino)tin(IV) (TDMASn)',
#   'electron_transport_layer': 'Al:ZnO',
#   'hole_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T', 'temperature': 60},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT', 'temperature': 60}]},
#  '15': {'control_pce': '90.17',
#   'control_voc': '1.11',
#   'treated_pce': '90.17',
#   'treated_voc': '1.15',
#   'passivating_molecule': 'phenylethylammonium (PEAI) and 4-fluoro-phenylethylammonium iodide (F-PEAI)',
#   'perovskite_composition': 'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.9 Br 0.1 ) 3',
#   'electron_transport_layer': 'PC61BM',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'p-i-n',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '12': {'treated_pce': 19.4,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylammonium bromide (BABr)',
#   'perovskite_composition': 'Cs0.17 FA0.83 Pb(I0.6 Br0.4 ) 3',
#   'electron_transport_layer': 'nanoparticle-based SnO 2',
#   'hole_transport_layer': '2,2′,7,7′-tetrakis(N, N′-di-p-methoxy phenylamine)-9,9′-spirobifluorene (spiro-OMeTAD)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '129': {'control_pce': '22.8%',
#   'control_voc': '1.12',
#   'treated_pce': '24.8%',
#   'treated_voc': '1.19',
#   'passivating_molecule': '4-guanidinobenzoic acid hydrochloride (GBAC)',
#   'perovskite_composition': 'Cs0.06MA0.14FA0.80PbI3',
#   'electron_transport_layer': 'ITO',
#   'hole_transport_layer': 'DC-PA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '65 ± 5 °C',
#     'time': '300 s'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T', 'temperature': '65 ± 5 °C', 'time': '300 s'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT', 'temperature': '65 ± 5 °C', 'time': '300 s'}]},
#  '127': {'treated_pce': 24.1,
#   'treated_voc': 1.198,
#   'passivating_molecule': 'PEA2ZnX4',
#   'perovskite_composition': 'Rb5Cs10/PEA2ZnX4',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T', 'temperature': 85},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '60': {'control_pce': '19.0(±0.4)%',
#   'treated_pce': '21.4(±0.3)%',
#   'passivating_molecule': '4-vinylbenzylammonium bromide',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D'},
#    {'test_name': 'ISOS-L'},
#    {'test_name': 'ISOS-T'},
#    {'test_name': 'ISOS-LC'},
#    {'test_name': 'ISOS-LT'}]},
#  '120': {'control_pce': '23.0%',
#   'control_voc': '1.13',
#   'treated_pce': '25.0%',
#   'treated_voc': '1.184',
#   'passivating_molecule': 'ferrocenyl-bis-thiophene-2-carboxylate (FcTc2)',
#   'perovskite_composition': '(FA0.98MA0.02)0.95Cs0.05Pb(I0.95Br0.02)3',
#   'electron_transport_layer': 'poly(triaryl amine) (PTAA)',
#   'hole_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'damp heat test',
#     'temperature': '85',
#     'humidity': '85%'},
#    {'test_name': 'long-term operational stability',
#     'temperature': '25',
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': '72%',
#     'treatment_efficiency': '>98%'}]},
#  '67': {'treated_pce': 22.1,
#   'treated_voc': 21.3,
#   'passivating_molecule': 'formamidinium formate (FAHCOO)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'polybisphenyl(trimethylphenyl)amine (PTAA)',
#   'pin_nip_structure': 'n-i-p',
#   'stability_tests': [{'test_name': 'ISOS-L1',
#     'temperature': 60,
#     'time': 1000,
#     'control_efficiency': 21.1,
#     'treatment_efficiency': 22.1},
#    {'test_name': 'ISOS-L3',
#     'temperature': 65,
#     'time': 1000,
#     'humidity': 60,
#     'control_efficiency': 23.1,
#     'treatment_efficiency': 22.1}]},
#  '7': {'passivating_molecule': 'Methylhydrazinium', 'stability_tests': [{}]},
#  '142': {'control_pce': '13.15',
#   'control_voc': 'null',
#   'treated_pce': '16.13',
#   'treated_voc': '1.03',
#   'passivating_molecule': 'BA (4-ethyl-3-methoxy-4-methylpyridine)',
#   'perovskite_composition': 'MAPbI3-(BA)2(MA)nÀ1Pb(nI)3n+1',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': '2D perovskite layer doped with FAI',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Humidity stability',
#     'temperature': '25°C',
#     'time': '50 days',
#     'humidity': '65%',
#     'control_efficiency': '71%',
#     'treatment_efficiency': '71%'},
#    {'test_name': 'Thermal stability',
#     'temperature': '85°C',
#     'time': '30 days',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': '74%'},
#    {'test_name': 'Illumination stability',
#     'temperature': 'null',
#     'time': '24 hours',
#     'humidity': 'null',
#     'control_efficiency': '90%',
#     'treatment_efficiency': '90%'}]},
#  '28': {'treated_pce': 22.0,
#   'treated_voc': 1.4,
#   'perovskite_composition': 'CsPbI3-xBrx',
#   'electron_transport_layer': 'TPBi',
#   'hole_transport_layer': 'Al',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{}]}}

# %%
def drop_fake_stability(obj):
    for value in obj.values():
        if 'stability_tests' in value:
            value['stability_tests'] = [
                test for test in value['stability_tests'] if len(test.keys()) > 1
            ]
    return obj

# %%
filtered_llama_data = drop_fake_stability(filtered_llama_data)
filtered_llama_data
# Out:
# {'111': {'treated_pce': 23.9,
#   'treated_voc': 1.51,
#   'passivating_molecule': 'isopropylammonium chloride',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 150,
#     'time': 30}]},
#  '56': {'treated_pce': 21.1,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'LiTFSI',
#   'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'hole_transport_layer': 'C60 and BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '87': {'treated_pce': 21.52,
#   'treated_voc': 1.15,
#   'passivating_molecule': 'Eu 3+ -Eu 2+ ion pair',
#   'perovskite_composition': 'PbX2 layer (CsI 20 mg, PbI2 530 mg, PbBr2 20 mg, PbCl2 20 mg, MAI 5 mg dissolved in 900 μL DMF and 100 μL DMSO mixed solvent)',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'polymer modified spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': '1 sun illumination',
#     'time': 1000,
#     'control_efficiency': 19.21,
#     'treatment_efficiency': 21.52},
#    {'test_name': '85°C heating',
#     'temperature': 85,
#     'time': 1000,
#     'control_efficiency': 18.05,
#     'treatment_efficiency': 21.52},
#    {'test_name': '1 sun illumination',
#     'time': 500,
#     'control_efficiency': 19.21,
#     'treatment_efficiency': 21.52},
#    {'test_name': '85°C heating',
#     'temperature': 85,
#     'time': 500,
#     'control_efficiency': 18.05,
#     'treatment_efficiency': 21.52}]},
#  '116': {'control_pce': '23.44',
#   'control_voc': '1.152',
#   'treated_pce': '24.82',
#   'treated_voc': '1.164',
#   'passivating_molecule': 'Spiro-mF',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'compact TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '51': {'treated_pce': 23.1,
#   'treated_voc': 1.28,
#   'passivating_molecule': 'R-NH3I',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '80': {'control_pce': 21.6,
#   'control_voc': 1.14,
#   'treated_pce': 21.6,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'Poly(methyl methacrylate) (PMMA)',
#   'perovskite_composition': '[FAI]0.81[PbI2]0.85[MAPbBr3]0.15',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '118': {'control_pce': '19.61%',
#   'control_voc': '1.161 V',
#   'treated_pce': '21.54%',
#   'treated_voc': '1.24 V',
#   'passivating_molecule': 'n-Butylammonium bromide (BABr)',
#   'perovskite_composition': 'RbCsMAFA',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Gold',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '23': {'treated_pce': 23.91,
#   'treated_voc': 1.15,
#   'passivating_molecule': '3-fluoro-phenethylammonium (3F-PEA)',
#   'perovskite_composition': 'Cs0.05MA0.1FA0.85PbI3',
#   'electron_transport_layer': 'C60/ALD-SnO2 or PCBM/BCP',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': 65,
#     'humidity': 50}]},
#  '24': {'control_pce': '14.9',
#   'treated_pce': '17.4',
#   'passivating_molecule': 'Cs2PbI2Cl2',
#   'perovskite_composition': 'CsPbI3',
#   'electron_transport_layer': 'CuSCN',
#   'hole_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 110,
#     'time': 2100,
#     'control_efficiency': '20%'},
#    {'test_name': 'ISOS-LT', 'temperature': 110}]},
#  '58': {'passivating_molecule': 'PCBM, C60, spiro-OMeTAD, poly-TPD, NiO x, PTAA',
#   'perovskite_composition': 'FA 0.83 Cs 0.17 Pb(I 0.83 Br 0.1 ) 3, FA 0.75 Cs 0.25 Pb(I 0.8 Br 0.2 ) 3',
#   'electron_transport_layer': 'SnO2, NiO x, Poly-TPD, PCBM, C60',
#   'hole_transport_layer': 'PCBM, C60, spiro-OMeTAD, poly-TPD, PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '89': {'treated_pce': 20.87,
#   'treated_voc': 1.147,
#   'passivating_molecule': 'Formamidine acetate',
#   'perovskite_composition': '(FA,MA,Cs)Pb(I,Br)3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '11': {'treated_pce': 21.8,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'Benzotriazole',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'PCBA',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '16': {'control_pce': '18.87',
#   'control_voc': '1.04',
#   'treated_pce': '21.05',
#   'treated_voc': '1.11',
#   'passivating_molecule': 'CF3 PEAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '85',
#     'humidity': '70-80%',
#     'control_efficiency': '18.87',
#     'treatment_efficiency': '21.05'}]},
#  '123': {'control_pce': '24.0',
#   'control_voc': '1.19',
#   'treated_pce': '24.3',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'PbPyA2',
#   'perovskite_composition': 'FAPbI3 0.95(MAPbBr3) 0.05',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'TPBi',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '2200',
#     'control_efficiency': '91.8',
#     'treatment_efficiency': '91.8'},
#    {'test_name': 'ISOS-L',
#     'time': '1000',
#     'control_efficiency': '77.6',
#     'treatment_efficiency': '90.5'},
#    {'test_name': 'ISOS-T',
#     'temperature': '85',
#     'time': '2200',
#     'control_efficiency': '73.2',
#     'treatment_efficiency': '91.8'},
#    {'test_name': 'ISOS-LC', 'time': '1000'},
#    {'test_name': 'ISOS-LT', 'time': '1000'}]},
#  '64': {'control_pce': '18.6',
#   'control_voc': '1057',
#   'treated_pce': '13.9',
#   'treated_voc': '1050',
#   'passivating_molecule': 'phenethylammonium lead iodide (PEA 2 PbI 4 )',
#   'perovskite_composition': 'MAPI (3D) and PEA 2 PbI 4 (2D)',
#   'electron_transport_layer': 'molybdenum oxide (MoO 3 )',
#   'hole_transport_layer': 'N4,N4,N4″,N4″tetra([1,1′-biphenyl]-4-yl)-[1,1′:4′,1″-terphenyl]-4,4″-diamine (TaTm)',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '18': {'treated_pce': 23.3,
#   'treated_voc': 1.23,
#   'passivating_molecule': '2-thiophenemethylammonium iodide (TMAI) and phenylethylammonium iodide (PEAI)',
#   'perovskite_composition': '[(FAPbI3)0.87(MAPbBr3)0.13]0.92(CsPbI3)0.08',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '124': {'control_pce': '22.3',
#   'control_voc': '1.13',
#   'treated_pce': '24.6',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'b-poly(1,1-difluoroethylene)',
#   'perovskite_composition': 'Cs0.05(FA0.98MA0.02)0.95Pb(I0.98Br0.02)3',
#   'electron_transport_layer': 'MeO-2PACz',
#   'hole_transport_layer': 'PC61BM',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-LT', 'treatment_efficiency': '96'}]},
#  '63': {'treated_pce': 11.66,
#   'treated_voc': 938,
#   'passivating_molecule': 'CH3NH3I',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'mTiO2',
#   'hole_transport_layer': 'Spiro-MeOTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '149': {'treated_pce': 26.4,
#   'treated_voc': 2.03,
#   'passivating_molecule': '4-trifluoromethyl-phenylammonium (CF3-PA)',
#   'perovskite_composition': 'FA 0.7 MA 0.3 Pb 0.5 Sn 0.5 I 3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '72': {'treated_pce': 19.9,
#   'treated_voc': 1.05,
#   'passivating_molecule': 'allylammonium (ALA)',
#   'perovskite_composition': 'Cs0.05FA0.8MA0.15PbI2.88Br0.04Cl0.08',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '135': {'treated_pce': 25.6,
#   'treated_voc': 1.19,
#   'passivating_molecule': '(4-(3,11-dimethoxy-7H-dibenzo[c,g]carbazol-7-yl)butyl)phosphonic acid (MeO-4PADBC)',
#   'electron_transport_layer': 'NiO x',
#   'hole_transport_layer': 'NiO x /MeO-4PADBC',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 65,
#     'time': 1200,
#     'treatment_efficiency': 90}]},
#  '75': {'control_pce': '19.6',
#   'treated_pce': '19.8',
#   'treated_voc': '19.3',
#   'passivating_molecule': '[(FAPbI3)0.87(MAPbBr3)0.13]0.92(CsPbI3)0.08',
#   'perovskite_composition': 'R2MAPb2I7',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '5': {'treated_pce': 22.1,
#   'treated_voc': 1135,
#   'passivating_molecule': 'iso-BAI',
#   'perovskite_composition': 'FA(MA)PbI3',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'TPBI',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '140': {'control_pce': '26.07',
#   'treated_pce': '24.63',
#   'passivating_molecule': 'hexafluorobenzene (HFB)',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '147': {'control_pce': '22.3',
#   'control_voc': '1.112',
#   'treated_pce': '24.7',
#   'treated_voc': '1.161',
#   'passivating_molecule': '4-(3,6-bis(4-(bis(4-methoxyphenyl)amino)phenyl)-9H-carbazol-9-yl)benzenaminium iodide (CBz-PAI)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'hole_transport_layer': 'PTAA',
#   'stability_tests': []},
#  '2': {'control_pce': '22.39%',
#   'control_voc': '1.095 V',
#   'treated_pce': '24.59%',
#   'treated_voc': '1.185 V',
#   'perovskite_composition': '(A*)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '85 °C',
#     'time': '1,056 h',
#     'humidity': '85% relative humidity',
#     'control_efficiency': '21.70%',
#     'treatment_efficiency': '24.35%'}]},
#  '35': {'passivating_molecule': 'PFN-P2',
#   'perovskite_composition': '(CsPbI3)0.05[(FAPbI3)0.83(MAPbBr3)0.17]0.95',
#   'electron_transport_layer': 'PC61BM',
#   'hole_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '98': {'treated_pce': 21.54,
#   'treated_voc': 1.186,
#   'passivating_molecule': '3,3′-(2,7-dibromo-9H-fluorene-9,9-diyl) bis(n,n-dimethylpropan-1-amine) (FN-Br)',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'DFS',
#   'pin_nip_structure': 'N-I-P',
#   'stability_tests': []},
#  '49': {'treated_pce': 16.25,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylamine acetate (BAAc)',
#   'perovskite_composition': 'BA2MAn-1PbI3n+1',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 558,
#     'humidity': '65 ± 10%',
#     'treatment_efficiency': 95.7},
#    {'test_name': 'ISOS-L',
#     'time': 1100,
#     'humidity': '65 ± 10%',
#     'treatment_efficiency': 96.2}]},
#  '109': {'treated_pce': 25.7,
#   'treated_voc': 1.177,
#   'passivating_molecule': 'Polyacrylic acid (PAA)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'Compact-TiO2 (c-TiO2) and polyacrylic acid-stabilized tin(IV) oxide quantum dots (paa-QD-SnO2)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': '1000-hour shelf life',
#     'temperature': 25,
#     'time': 1000,
#     'humidity': '25% RH',
#     'treatment_efficiency': '80% of initial efficiency retained'},
#    {'test_name': 'Operational stability test',
#     'temperature': 25,
#     'time': 350,
#     'humidity': '25% RH',
#     'treatment_efficiency': '95% of initial efficiency retained'},
#    {'test_name': 'MPP tracking test',
#     'temperature': 25,
#     'time': 100,
#     'humidity': '25% RH',
#     'treatment_efficiency': 'Higher PCE than the reference cell'}]},
#  '32': {'treated_pce': 21.0,
#   'treated_voc': 1.07,
#   'passivating_molecule': 'CH3NH3+',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '91': {'control_pce': 'null',
#   'control_voc': 'null',
#   'treated_pce': '24.02',
#   'treated_voc': '1.130',
#   'passivating_molecule': 'Methylammonium chloride (MACl)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'null',
#   'hole_transport_layer': 'null',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': '90%'},
#    {'test_name': 'ISOS-L',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': '40 C',
#     'time': '300 h',
#     'humidity': 'null',
#     'control_efficiency': '60%',
#     'treatment_efficiency': '90%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-LT',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'}]},
#  '40': {'control_pce': '24.3',
#   'treated_pce': '24.3',
#   'treated_voc': '1.20',
#   'passivating_molecule': 'Oleylammonium iodide (OLAI)',
#   'perovskite_composition': 'Cs0.03(FA0.90MA0.10)0.97PbI3',
#   'electron_transport_layer': 'ITO',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Damp-heat test',
#     'temperature': '85',
#     'time': '1000',
#     'humidity': '85%',
#     'treatment_efficiency': '19.3 ± 0.69%'}]},
#  '107': {'treated_pce': 21.25,
#   'treated_voc': 1.127,
#   'passivating_molecule': 'sulfonyl-functionalized phenethylammonium salt (SF-PEA)',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-LT',
#     'humidity': '50-60%',
#     'treatment_efficiency': 91}]},
#  '96': {'treated_pce': 22.19,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'tin(IV) bis(acetylacetonate) dichloride (Cl2) and tin(IV) bis(acetylacetonate) dibromide (Br2)',
#   'electron_transport_layer': 'tin oxide',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '47': {'control_pce': '19.16%',
#   'control_voc': '1.07 V',
#   'treated_pce': '21.1%',
#   'treated_voc': '1.16 V',
#   'passivating_molecule': 'PbSO4',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 65,
#     'control_efficiency': '18.2%',
#     'treatment_efficiency': '21.1%'},
#    {'test_name': 'ISOS-LT',
#     'temperature': 65,
#     'control_efficiency': '8.54%',
#     'treatment_efficiency': '96.8%'}]},
#  '100': {'treated_pce': 23.24,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'In2O3',
#   'electron_transport_layer': 'In2O3/SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'PCBM',
#   'stability_tests': []},
#  '125': {'treated_pce': 23.7,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'selenophene',
#   'perovskite_composition': 'Cs1-xFAxPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'PTAA/Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T', 'temperature': 85, 'time': 1750},
#    {'test_name': 'ISOS-LT', 'temperature': 85, 'time': 960}]},
#  '62': {'control_pce': '16.50',
#   'control_voc': '1.01',
#   'treated_pce': '16.50',
#   'treated_voc': '1.02',
#   'passivating_molecule': 'BAI',
#   'perovskite_composition': '2D-(BA) 2 (MA) n-1 Pb n I 3n+1',
#   'electron_transport_layer': 'TiO 2',
#   'hole_transport_layer': 'C 60',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'humidity': '55%',
#     'control_efficiency': '16.07',
#     'treatment_efficiency': '15.40'},
#    {'test_name': 'ISOS-L',
#     'humidity': '80°C',
#     'control_efficiency': '13.88',
#     'treatment_efficiency': '11.05'},
#    {'test_name': 'ISOS-T',
#     'temperature': '80°C',
#     'time': '30 days',
#     'control_efficiency': '44%',
#     'treatment_efficiency': '73%'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '80°C',
#     'time': '30 days',
#     'control_efficiency': '27%',
#     'treatment_efficiency': '10.88'}]},
#  '122': {'control_pce': '25.6',
#   'control_voc': '1.1824',
#   'treated_pce': '25.86',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'RbCl',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '1000',
#     'control_efficiency': '96%',
#     'treatment_efficiency': '96%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': '85',
#     'time': '500',
#     'treatment_efficiency': '80%'}]},
#  '65': {'control_pce': '4.73',
#   'control_voc': '1.18',
#   'treated_pce': '4.73',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'PEA (C6H5(CH2)2NH3+)',
#   'perovskite_composition': '(PEA)2(MA)2[Pb3I10]',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '52%'}]},
#  '19': {'control_pce': 'null',
#   'control_voc': 'null',
#   'treated_pce': '24.09',
#   'treated_voc': '1.1595',
#   'passivating_molecule': '3,4,5-trifluoroanilinium (345FAn)',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.9Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'C60/bathocuproine (BCP)',
#   'hole_transport_layer': '2PACz',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L-3-85°C',
#     'temperature': '85',
#     'time': '1560',
#     'humidity': '50%',
#     'control_efficiency': '19.9%',
#     'treatment_efficiency': '24.09%'}]},
#  '17': {'control_pce': '20.04',
#   'control_voc': '1.16',
#   'treated_pce': '22.02',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'hexyltrimethylammonium bromide',
#   'perovskite_composition': 'Cs0.05 FA0.81 MA0.14 PbI2.55 Br0.45',
#   'electron_transport_layer': 'doped spiro-OMeTAD',
#   'hole_transport_layer': 'doped spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '70-75%'},
#    {'test_name': 'ISOS-L', 'humidity': '70-75%'},
#    {'test_name': 'ISOS-T', 'temperature': '80 °C', 'time': '90 min'}]},
#  '10': {'treated_pce': 24.41,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'Tosylate ([TsO] -)',
#   'perovskite_composition': '(FAPbI3) 0.95 (MAPbBr3) 0.05',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T', 'temperature': 40}]},
#  '25': {'passivating_molecule': 'FAac (formamidinium acetate)',
#   'perovskite_composition': 'FAPbI3 or FAPbBr3',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': '85'}]},
#  '59': {'control_pce': '19.07%',
#   'control_voc': '1.25',
#   'treated_pce': '19.07%',
#   'treated_voc': '1.25',
#   'passivating_molecule': 'phenethylammonium iodide (PEAI)',
#   'perovskite_composition': 'FA0.8Cs0.2Pb(I0.7Br0.3)3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '88': {'control_pce': '19.03',
#   'treated_pce': '21.46',
#   'treated_voc': '0.94',
#   'passivating_molecule': 'NaF',
#   'perovskite_composition': '(Cs 0.05 FA 0.54 MA 0.41 )Pb(I 0.98 Br 0.02 ) 3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '85 °C',
#     'time': '1,000 h',
#     'control_efficiency': '19.03',
#     'treatment_efficiency': '21.46'}]},
#  '119': {'treated_pce': 23.9,
#   'treated_voc': 1.15,
#   'passivating_molecule': '1,1,2,2,3,3-hexafluoropropane-1,3-disulfonimide (HFDF-)',
#   'electron_transport_layer': 'Poly(triarylamine) (PTAA)',
#   'hole_transport_layer': 'Poly(triarylamine) (PTAA) doped with 1,1,2,2,3,3-hexafluoropropane-1,3-disulfonimide (HFDF-)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L', 'temperature': 85, 'time': 200},
#    {'test_name': 'ISOS-T', 'temperature': 120},
#    {'test_name': 'ISOS-LT', 'temperature': 85, 'time': 1000}]},
#  '22': {'control_pce': '21.40',
#   'control_voc': '1.092',
#   'treated_pce': '23.77',
#   'treated_voc': '1.145',
#   'passivating_molecule': 'Cyclohexylmethylammonium iodide (CMAI)',
#   'perovskite_composition': 'α-formamidinium lead triiodide (FAPbI3)',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-LT',
#     'treatment_efficiency': '95%'}]},
#  '117': {'control_pce': 0.22,
#   'control_voc': 1.15,
#   'treated_pce': 25.1,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'spiro-OMeTAD 2•+ (TFSI -)2',
#   'perovskite_composition': '(FAPbI3)0.99(MAPbBr3)0.01',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'doped spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 1200,
#     'humidity': '70 ± 5%',
#     'control_efficiency': 0.22,
#     'treatment_efficiency': 25.1},
#    {'test_name': 'ISOS-L',
#     'temperature': 25,
#     'time': 800,
#     'humidity': '70 ± 3°C',
#     'control_efficiency': 0.22,
#     'treatment_efficiency': 25.1}]},
#  '50': {'treated_pce': 14.4,
#   'treated_voc': 1.05,
#   'passivating_molecule': 'allylammonium',
#   'perovskite_composition': 'L2(MA)n-1Pb(nI3)n',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '81': {'control_pce': '20.1',
#   'control_voc': '1.140',
#   'treated_pce': '19.9',
#   'treated_voc': '1.145',
#   'passivating_molecule': 'Chlorine',
#   'perovskite_composition': 'MAPbI3-xClx',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '110': {'treated_pce': 25.6,
#   'treated_voc': 1.21,
#   'passivating_molecule': 'Formamidinium formate',
#   'perovskite_composition': 'α-FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '57': {'treated_pce': 22.5,
#   'treated_voc': 1.098,
#   'perovskite_composition': 'MA 0.07 FA 0.93 PbI 3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'C 60',
#   'pin_nip_structure': 'pin',
#   'stability_tests': []},
#  '86': {'treated_pce': 21.6,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'Ethylene diamine tetraacetic acid (EDTA)',
#   'electron_transport_layer': 'EDTA-complexed SnO2 (E-SnO2)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '97': {'control_pce': '20.5%',
#   'control_voc': '1.06 V',
#   'treated_pce': '22.3%',
#   'treated_voc': '1.17 V',
#   'passivating_molecule': 'Alkylammonium ligands (AALs)',
#   'perovskite_composition': 'Cs 0.05 (FA 0.92 MA 0.08 ) 0.95 Pb(I 0.92 Br 0.08 ) 3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'PCBM',
#   'pin_nip_structure': 'p-i-n',
#   'stability_tests': [{'test_name': 'MPP tracking',
#     'temperature': '40 °C',
#     'time': '1000 h',
#     'humidity': 'constant nitrogen atmosphere',
#     'control_efficiency': '17%',
#     'treatment_efficiency': '21.2%'},
#    {'test_name': 'Thermal stability',
#     'temperature': '85 °C',
#     'time': '1020 h',
#     'humidity': 'constant nitrogen atmosphere',
#     'control_efficiency': '17%',
#     'treatment_efficiency': '18%'}]},
#  '46': {'treated_pce': 20.0,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'PFN-P2 and LiF',
#   'perovskite_composition': 'CsPbI0.05[(FAPbI3)0.89(MAPbBr3)0.11]0.95',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '101': {'treated_pce': 20.19,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'DTB(3%DEG)',
#   'hole_transport_layer': 'DTB(xDEG)',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '90': {'treated_pce': 20.7,
#   'treated_voc': 1.17,
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '41': {'control_pce': '21.94',
#   'control_voc': '1.135',
#   'treated_pce': '23.92',
#   'treated_voc': '1.157',
#   'passivating_molecule': 'ortho-(phenylene)di(ethylammonium) iodide (o-PDEAI 2 )',
#   'perovskite_composition': 'PbI2 :PbBr2 :FAI:MAI:CsI:MACl = 0.98:0.02:0.81:0.04:0.05:0.20',
#   'electron_transport_layer': 'fluorine-doped tin oxide (FTO)',
#   'hole_transport_layer': '2,2′,7,7′-tetrakis-(N,N-di-4-methoxyphenylamino)-9,9′spirobifluorene (spiro-OMeTAD)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'long-term stability',
#     'temperature': '25 °C',
#     'time': '1000 h',
#     'humidity': '40-50% RH',
#     'control_efficiency': '85%',
#     'treatment_efficiency': '90.2%'},
#    {'test_name': 'thermal stability',
#     'temperature': '85 °C',
#     'time': '1000 h',
#     'humidity': 'air',
#     'control_efficiency': '49%',
#     'treatment_efficiency': '25%'},
#    {'test_name': 'light-soaking stability',
#     'temperature': '25 °C',
#     'time': '1100 h',
#     'humidity': 'air',
#     'control_efficiency': '>60%',
#     'treatment_efficiency': '>90%'}]},
#  '106': {'treated_pce': 0.22802,
#   'treated_voc': 1.2,
#   'passivating_molecule': 'ZrL3',
#   'perovskite_composition': 'Zr6O4(OH)4(L3)2(OH)6(H2O)27(DMF)',
#   'electron_transport_layer': 'PC61BM',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 85,
#     'time': 1000}]},
#  '108': {'control_pce': '24.48%',
#   'control_voc': '1.138 V',
#   'treated_pce': '25.17%',
#   'treated_voc': '1.168 V',
#   'passivating_molecule': 'PEAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'mp-TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '85°C',
#     'time': '1300 hours',
#     'humidity': '15 to 25% RH',
#     'control_efficiency': '80%',
#     'treatment_efficiency': '90%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': '150°C',
#     'time': '20 hours',
#     'humidity': '15 to 25% RH',
#     'control_efficiency': '60%',
#     'treatment_efficiency': '80%'}]},
#  '33': {'treated_pce': 23.7,
#   'passivating_molecule': 'Benzene',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '34': {'pin_nip_structure': 'PIN', 'stability_tests': []},
#  '99': {'control_pce': '18.08',
#   'control_voc': '1.087',
#   'treated_pce': '21.01',
#   'treated_voc': '1.146',
#   'passivating_molecule': 'Chlorine-rich mixed-halide perovskite (ClMPI)',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'Outdoor solar irradiation',
#     'control_efficiency': '90%',
#     'treatment_efficiency': '94%'},
#    {'test_name': 'High-intensity UV irradiation',
#     'treatment_efficiency': '82%'},
#    {'test_name': '1-sun full spectrum illumination (including UV light)',
#     'treatment_efficiency': '80%'}]},
#  '48': {'control_pce': '16.9%',
#   'control_voc': '1.07 V',
#   'treated_pce': '20.3%',
#   'treated_voc': '1.07 V',
#   'passivating_molecule': 'PCBM',
#   'perovskite_composition': 'Lead iodide (PbI2) and methylammonium iodide (MAI)',
#   'electron_transport_layer': 'PTAA: F4-TCNQ',
#   'hole_transport_layer': 'PTAA: F4-TCNQ',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': 'air'},
#    {'test_name': 'ISOS-L', 'humidity': 'air'},
#    {'test_name': 'ISOS-T', 'humidity': 'air'},
#    {'test_name': 'ISOS-LC', 'humidity': 'air'},
#    {'test_name': 'ISOS-LT', 'humidity': 'air'}]},
#  '146': {'control_pce': '21.5%',
#   'control_voc': 1.128,
#   'treated_pce': '23.05%',
#   'treated_voc': 1.17,
#   'passivating_molecule': 'CB-NH2',
#   'perovskite_composition': 'Cs0.05 (MA0.05 FA0.95)0.95 Pb(I0.95 Br0.05)3',
#   'electron_transport_layer': 'C60',
#   'hole_transport_layer': 'BCP',
#   'pin_structure': 'PIN',
#   'stability_tests': [{'test_name': 'MPP tracking in glovebox',
#     'temperature': 26,
#     'time': 400,
#     'humidity': '30%',
#     'control_efficiency': '21.10%',
#     'treatment_efficiency': '23.04%'},
#    {'test_name': 'MPP tracking in air',
#     'temperature': 40,
#     'time': 400,
#     'humidity': '30%',
#     'control_efficiency': '89%',
#     'treatment_efficiency': '97%'}]},
#  '3': {'control_pce': '24.5',
#   'control_voc': '1.20',
#   'treated_pce': '24.5',
#   'treated_voc': '1.20',
#   'passivating_molecule': 'BA2MA2Pb3I10',
#   'perovskite_composition': 'BA2MA2Pb3I10',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'humidity': '70 ± 5 %RH',
#     'control_efficiency': '21%',
#     'treatment_efficiency': '23.75%'}]},
#  '4': {'treated_pce': 21.06,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'vinylbenzylammonium bromide (VBABr)',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '141': {'control_pce': '21.3',
#   'treated_pce': '22.0',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'Cl 6 SubPc',
#   'electron_transport_layer': 'C 60',
#   'hole_transport_layer': 'Cu:NiO x',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'treatment_efficiency': '99%'},
#    {'test_name': 'ISOS-L', 'treatment_efficiency': '95%'},
#    {'test_name': 'ISOS-T',
#     'temperature': '80 °C',
#     'time': '2000 h',
#     'control_efficiency': '25%',
#     'treatment_efficiency': '5%'},
#    {'test_name': 'ISOS-LC', 'treatment_efficiency': '90%'},
#    {'test_name': 'ISOS-LT', 'time': '1272 h', 'treatment_efficiency': '95%'}]},
#  '74': {'treated_pce': 21.17,
#   'treated_voc': 1.13,
#   'passivating_molecule': '4F-PEAI',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 100,
#     'time': 120}]},
#  '133': {'control_pce': '22.34%',
#   'treated_pce': '24.56%',
#   'treated_voc': '1.19 V',
#   'passivating_molecule': 'Sodium thioglycolate',
#   'perovskite_composition': 'FA0.75MA0.25Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'NiOx',
#   'hole_transport_layer': 'Me-4PACz',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'treatment_efficiency': '24.04%'}]},
#  '148': {'control_pce': '23.5',
#   'treated_pce': '23.5',
#   'treated_voc': '1.142',
#   'passivating_molecule': '4-tert-butyl-benzylammonium iodide (tBBAI)',
#   'perovskite_composition': 'Cs0.05 FA0.85 MA0.10 Pb(I0.97 Br0.03)3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '73': {'treated_pce': 22.6,
#   'treated_voc': 1.091,
#   'passivating_molecule': '2CF3-PEAI',
#   'perovskite_composition': 'FA0.98MA0.02PbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-LT',
#     'temperature': 85,
#     'time': 1000,
#     'humidity': '85%'}]},
#  '134': {'control_pce': '23.13',
#   'control_voc': '1.141',
#   'treated_pce': '25.32',
#   'treated_voc': '1.174',
#   'passivating_molecule': 'Guanabenz acetate salt',
#   'perovskite_composition': 'α-FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '20',
#     'time': '500',
#     'humidity': '85%',
#     'control_efficiency': '25.90',
#     'treatment_efficiency': '25.96'},
#    {'test_name': 'ISOS-LC',
#     'temperature': '25',
#     'time': '300',
#     'humidity': '85%',
#     'control_efficiency': '22.39',
#     'treatment_efficiency': '24.76'},
#    {'test_name': 'ISOS-LT',
#     'temperature': '85',
#     'time': '300',
#     'humidity': '85%',
#     'control_efficiency': '22.30',
#     'treatment_efficiency': '24.50'}]},
#  '93': {'treated_pce': 21.21,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'spiro-OMeTAD',
#   'perovskite_composition': 'FA 1-x MA x PbI 2.87 Br 0.13 (Cl)',
#   'electron_transport_layer': 'SnO 2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '42': {'control_pce': '19.52%',
#   'control_voc': '1.07',
#   'treated_pce': '22.03%',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'Azetidinium lead iodide (AzPbI3)',
#   'perovskite_composition': 'Cs0.05MA0.1FA0.85PbI2.7Br0.3',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'control_efficiency': '47%',
#     'treatment_efficiency': '85%'}]},
#  '105': {'control_pce': 21.65,
#   'control_voc': 1.172,
#   'treated_pce': 23.36,
#   'treated_voc': 1.193,
#   'passivating_molecule': 'Nitrogen-doped titanium oxide (TiO x N y)',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'Nitrogen-doped titanium oxide (TiO x N y)',
#   'hole_transport_layer': 'Poly(3-hexylthiophene) and copper phthalocyanine',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Damp-heat',
#     'temperature': 85,
#     'humidity': '85%'}]},
#  '39': {'control_pce': '19.9',
#   'control_voc': '1.09',
#   'treated_pce': '20.82',
#   'treated_voc': '1.193',
#   'passivating_molecule': '2-thiophenemethylammonium bromide (2-TMABr)',
#   'perovskite_composition': '[FAPbI3]0.87[MABr3]0.13[CspI3]0.08',
#   'electron_transport_layer': 'mesoporous TiO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '94': {'control_pce': '19.98',
#   'control_voc': '1.112',
#   'treated_pce': '20.84',
#   'treated_voc': '1.129',
#   'passivating_molecule': 'P4VP',
#   'perovskite_composition': 'PbI2, CsI, MAI, MABr, MACl, FAI',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'P4VP',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'humidity': '25-50%',
#     'control_efficiency': '19.98',
#     'treatment_efficiency': '20.84'},
#    {'test_name': 'ISOS-L',
#     'humidity': '25-50%',
#     'control_efficiency': '19.98',
#     'treatment_efficiency': '20.84'},
#    {'test_name': 'ISOS-T',
#     'humidity': '25-50%',
#     'control_efficiency': '19.98',
#     'treatment_efficiency': '20.84'},
#    {'test_name': 'ISOS-LC',
#     'humidity': '25-50%',
#     'control_efficiency': '19.98',
#     'treatment_efficiency': '20.84'},
#    {'test_name': 'ISOS-LT',
#     'humidity': '25-50%',
#     'control_efficiency': '19.98',
#     'treatment_efficiency': '20.84'}]},
#  '45': {'treated_pce': 25.1,
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '102': {'treated_pce': 21.07,
#   'treated_voc': 1.122,
#   'passivating_molecule': 'Spiro-MeOTAD',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'FTO',
#   'hole_transport_layer': 'MACl',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '37': {'treated_pce': 26.29,
#   'treated_voc': 2.13,
#   'passivating_molecule': '1,3-propylene diammonium (PDA)',
#   'perovskite_composition': 'Cs0.2FA0.8Pb(I0.6Br0.4)3',
#   'electron_transport_layer': 'NiOx/Me-4PACz',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'NiOx/Me-4PACz',
#   'stability_tests': []},
#  '30': {'treated_pce': 23.21,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'ammonia',
#   'perovskite_composition': 'α-FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'shelf-life stability',
#     'humidity': '10-30%'}]},
#  '132': {'control_pce': 8.7,
#   'control_voc': 1.13,
#   'treated_pce': 23.1,
#   'treated_voc': 1.177,
#   'passivating_molecule': '1-dodecanethiol (DDT)',
#   'perovskite_composition': 'Cs0.05 FA0.81 MA0.14 PbI2.55 Br0.45',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '79': {'treated_pce': 20.27,
#   'treated_voc': 1.1,
#   'passivating_molecule': 'PbI2',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'n-i-p',
#   'stability_tests': []},
#  '145': {'treated_pce': 20.48,
#   'treated_voc': 1.13,
#   'passivating_molecule': '4-fluoroaniline (FAL)',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 85,
#     'time': 100,
#     'humidity': 95},
#    {'test_name': 'ISOS-LT', 'temperature': 85, 'time': 100, 'humidity': 95}]},
#  '0': {'control_pce': '25.7',
#   'control_voc': '1.17',
#   'treated_pce': '26.15',
#   'treated_voc': '1.18',
#   'passivating_molecule': '4-chlorobenzenesulfonate (4Cl-BZS)',
#   'perovskite_composition': 'α-phase FAPbI3',
#   'electron_transport_layer': 'C60',
#   'hole_transport_layer': 'SAMs (self-assembled monolayers)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D-2I',
#     'temperature': 85,
#     'time': 1500,
#     'humidity': '50 ± 10%',
#     'control_efficiency': '19.9%',
#     'treatment_efficiency': '95%'},
#    {'test_name': 'ISOS-L-3',
#     'temperature': 65,
#     'time': 1200,
#     'humidity': '50 ± 10%',
#     'control_efficiency': '23.2%',
#     'treatment_efficiency': '95%'}]},
#  '139': {'treated_pce': 26.09,
#   'treated_voc': 1.164,
#   'passivating_molecule': '1-(phenylsulfonyl)pyrrole (PSP)',
#   'perovskite_composition': 'FA 0.95 Cs 0.05 PbI 3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'treatment_efficiency': 92},
#    {'test_name': 'ISOS-T',
#     'temperature': 85,
#     'time': 300,
#     'humidity': 85,
#     'control_efficiency': 80,
#     'treatment_efficiency': 90}]},
#  '70': {'control_pce': '17.7',
#   'control_voc': '1105',
#   'treated_pce': '19.7',
#   'treated_voc': '1138',
#   'passivating_molecule': 'Spiro-MeOTAD',
#   'perovskite_composition': 'FA0.83MA0.17Pb(I0.83Br0.17)3',
#   'electron_transport_layer': 'Spiro-MeOTAD',
#   'hole_transport_layer': 'Au',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-T', 'temperature': 70}]},
#  '137': {'control_pce': '22.8',
#   'treated_pce': '25.5',
#   'passivating_molecule': '3-(methylthio)propylamine hydroiodide (3MTPAI) and diammonium molecules',
#   'perovskite_composition': 'PbI3',
#   'electron_transport_layer': 'C60',
#   'hole_transport_layer': 'NiOx/4PACz',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1600,
#     'humidity': '50%',
#     'control_efficiency': '22.8',
#     'treatment_efficiency': '25.5'},
#    {'test_name': 'ISOS-L',
#     'temperature': 65,
#     'time': 2000,
#     'humidity': '50%',
#     'control_efficiency': '24.7',
#     'treatment_efficiency': '96'}]},
#  '9': {'control_pce': '14.70%',
#   'treated_pce': '17.60%',
#   'passivating_molecule': 'C8',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'Cu-doped NiOx',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '77': {'treated_pce': 24.1,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'PEAMA +',
#   'perovskite_composition': 'FA 0.9 Cs 0.1 PbI 3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 85,
#     'time': 1500,
#     'control_efficiency': 90,
#     'treatment_efficiency': 90},
#    {'test_name': 'ISOS-LT',
#     'temperature': 100,
#     'time': 500,
#     'treatment_efficiency': 90}]},
#  '130': {'control_pce': '22.9',
#   'control_voc': '25.1',
#   'treated_pce': '25.4',
#   'treated_voc': '25.0',
#   'passivating_molecule': 'Pentanamidine hydrochloride (PAD)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '121': {'control_pce': '26.08',
#   'treated_pce': '26.08',
#   'passivating_molecule': 'Propylammonium chloride (PACl)',
#   'perovskite_composition': 'α-FAPbI3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '66': {'treated_pce': 21.1,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'Cs 0.15 FA 0.85 PbI 2.55 Br 0.45',
#   'perovskite_composition': 'Cs 0.15 FA 0.85 PbI 2.55 Br 0.45',
#   'electron_transport_layer': 'ITO',
#   'hole_transport_layer': 'Cu',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D3',
#     'temperature': 85,
#     'humidity': 85}]},
#  '126': {'control_pce': '23.43%',
#   'control_voc': '1.16 V',
#   'treated_pce': '25.39%',
#   'treated_voc': '1.18 V',
#   'passivating_molecule': 'PbC2O4',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'UV-Vis absorption spectra',
#     'control_efficiency': '23.43%',
#     'treatment_efficiency': '25.39%'}]},
#  '61': {'treated_pce': 23.1,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'Butylamine',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 85},
#    {'test_name': 'ISOS-T', 'temperature': 85}]},
#  '13': {'treated_pce': 22.6,
#   'treated_voc': 2.1,
#   'passivating_molecule': '2-(9H-carbazol-9-yl)ethyl] phosphonic acid (2PACz)',
#   'perovskite_composition': 'Cs0.12 FA0.8 MA0.08 PbI1.8 Br1.2',
#   'electron_transport_layer': '[2-(9H-carbazol-9-yl)ethyl] phosphonic acid (2PACz)',
#   'hole_transport_layer': '[6,6]-Phenyl-C61-butyric acid methyl ester (PCBM)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 60,
#     'time': 265,
#     'control_efficiency': 13.1,
#     'treatment_efficiency': 14.6},
#    {'test_name': 'ISOS-LT',
#     'temperature': 60,
#     'time': 195,
#     'control_efficiency': 12.7,
#     'treatment_efficiency': 14.5}]},
#  '128': {'control_pce': '21.94',
#   'control_voc': '1.12',
#   'treated_pce': '25.12',
#   'treated_voc': '1.156',
#   'passivating_molecule': '2-aminoindan hydrochloride',
#   'perovskite_composition': 'Cs0.05 FA0.95 PbI3',
#   'electron_transport_layer': 'NiOx',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 85,
#     'time': 1200,
#     'humidity': 85,
#     'control_efficiency': 22.15,
#     'treatment_efficiency': 24.32},
#    {'test_name': 'ISOS-LT',
#     'temperature': 85,
#     'time': 1500,
#     'humidity': 85,
#     'control_efficiency': 21.73,
#     'treatment_efficiency': 24.42}]},
#  '68': {'treated_pce': 12.8,
#   'treated_voc': 0.95,
#   'passivating_molecule': 'SnOx',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T', 'temperature': 60, 'time': 360},
#    {'test_name': 'ISOS-LT', 'temperature': 60, 'time': 1032}]},
#  '14': {'control_pce': '21.58',
#   'control_voc': '1.109',
#   'treated_pce': '23.72',
#   'treated_voc': '1.162',
#   'passivating_molecule': '2-phenylethylammonium iodide (PEAI), 4-chlorophenylethylammonium iodide (Cl-PEAI), and 4-fluorophenylethylammonium iodide (F-PEAI)',
#   'perovskite_composition': 'Cs 0.05 (FA 0.9 MA 0.1 ) 0.95 Pb(I 0.85 Br 0.15 ) 3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '21': {'control_pce': '22.6',
#   'treated_pce': '22.6',
#   'passivating_molecule': 'n-octylammonium bromide (C8 Br)',
#   'perovskite_composition': '(FAPbI3)0.92(MAPbBr3)0.08',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'control_efficiency': '22.6',
#     'treatment_efficiency': '22.6'},
#    {'test_name': 'ISOS-L',
#     'control_efficiency': '22.6',
#     'treatment_efficiency': '22.6'},
#    {'test_name': 'ISOS-T',
#     'control_efficiency': '22.6',
#     'treatment_efficiency': '22.6'},
#    {'test_name': 'ISOS-LC',
#     'control_efficiency': '22.6',
#     'treatment_efficiency': '22.6'},
#    {'test_name': 'ISOS-LT',
#     'control_efficiency': '22.6',
#     'treatment_efficiency': '22.6'}]},
#  '26': {'passivating_molecule': 'Methylammonium',
#   'perovskite_composition': 'MAPbX3',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '113': {'treated_pce': 25.8,
#   'treated_voc': 1.1885,
#   'passivating_molecule': 'Cl-bSO',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Cl-bSO',
#   'stability_tests': []},
#  '54': {'passivating_molecule': 'Methylammonium iodide (MAI) and lead iodide (PbI2) or Methylammonium bromide (MABr) and lead bromide (PbBr2)',
#   'perovskite_composition': 'Cs0.17FA0.83Pb(I0.83Br0.17)3 or Cs0.25FA0.75Pb(I0.8Br0.2)3 or MAPb(IxBr1-x)3',
#   'electron_transport_layer': 'NiO',
#   'hole_transport_layer': 'Zn-containing SnO2 or DC sputtered ITO',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '85': {'control_pce': '16.0',
#   'treated_pce': '23.3',
#   'passivating_molecule': 'n-hexyl trimethyl ammonium bromide',
#   'perovskite_composition': 'FAPbI3 0.95MAPbBr3 0.05',
#   'electron_transport_layer': 'P3HT',
#   'hole_transport_layer': 'P3HT',
#   'pin_nip_structure': 'DHA',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '85%'}]},
#  '114': {'treated_pce': 23.37,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Piperazinium iodide (PI)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '53': {'control_pce': '4.9',
#   'treated_pce': '24.7',
#   'passivating_molecule': 'N,N-dimethyl-1,3-propane diammonium (DMePDAI2)',
#   'perovskite_composition': 'PbI6',
#   'electron_transport_layer': 'TiO2 or SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'control_efficiency': '20.5',
#     'treatment_efficiency': '23.1'},
#    {'test_name': 'ISOS-LT', 'treatment_efficiency': '81'}]},
#  '82': {'control_pce': '17.1',
#   'control_voc': '1.04',
#   'treated_pce': '20.59',
#   'treated_voc': '1.13',
#   'passivating_molecule': 'Choline chloride',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '50-85%'}]},
#  '8': {'treated_pce': 23.0,
#   'treated_voc': 1.177,
#   'passivating_molecule': '2-(pyren-1-yl)ethan-1-amine',
#   'perovskite_composition': 'CsPbI2Br',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '76': {'treated_pce': 20.1,
#   'treated_voc': 1.92,
#   'passivating_molecule': 'phenylethylammonium',
#   'perovskite_composition': 'R2A n-1BnX3n+1',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 23},
#    {'test_name': 'ISOS-L', 'temperature': 140, 'time': 60}]},
#  '131': {'control_pce': '25.5%',
#   'control_voc': '1.203 V',
#   'treated_pce': '25.6%',
#   'treated_voc': '1.208 V',
#   'passivating_molecule': 'Al2O3',
#   'perovskite_composition': 'FA0.95MA0.05Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'Me-4PACz',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 1000,
#     'control_efficiency': '24.9%',
#     'treatment_efficiency': '25.5%'},
#    {'test_name': 'ISOS-T', 'temperature': 35, 'time': 300}]},
#  '71': {'treated_pce': 15.3,
#   'passivating_molecule': 'organic n-butylammonium (BA) spacer cations',
#   'perovskite_composition': '(BA)2(MA)3Pb4I13',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-LT', 'temperature': 330},
#    {'test_name': 'ISOS-L', 'temperature': 240}]},
#  '136': {'treated_pce': 25.4,
#   'treated_voc': 1.21,
#   'passivating_molecule': '[(2-(4-(bis(4-methoxyphenyl)amino)phenyl)-1-cyanovinyl)phosphonic acid, or MPA-CPA]',
#   'perovskite_composition': 'Cs0.05(FA0.95MA0.05)0.95Pb(I0.95Br0.05)3',
#   'electron_transport_layer': '[(2-(4-(bis(4-methoxyphenyl)amino)phenyl)-1-cyanovinyl)phosphonic acid, or MPA-CPA]',
#   'hole_transport_layer': '[(2-(4-(bis(4-methoxyphenyl)amino)phenyl)-1-cyanovinyl)phosphonic acid, or MPA-CPA]',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '144': {'control_pce': '19.3',
#   'control_voc': '0.88',
#   'treated_pce': '21.0',
#   'treated_voc': '0.88',
#   'passivating_molecule': 'GlyHCl',
#   'perovskite_composition': 'Cs0.1FA0.6MA0.3Sn0.5Pb0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '1': {'control_pce': '20.95%',
#   'control_voc': '1.11',
#   'treated_pce': '23.32%',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'phenethylammonium iodide (PEAI)',
#   'perovskite_composition': 'FA1-xMAxPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'thermal cycling',
#     'temperature': '85°C',
#     'time': '500h',
#     'control_efficiency': '21.24%',
#     'treatment_efficiency': '22.73%'},
#    {'test_name': 'light-soaking',
#     'temperature': '25°C',
#     'time': '40h',
#     'control_efficiency': '21.24%',
#     'treatment_efficiency': '22.73%'}]},
#  '138': {'control_pce': '25.3',
#   'treated_pce': '24.8',
#   'passivating_molecule': '2-(9H-carbazol-9-yl)ethyl)phosphonic acid (2PACz) and 3-mercaptopropionic acid (3-MPA)',
#   'perovskite_composition': 'Cs 0.05 MA 0.10 FA 0.85 PbI 3',
#   'electron_transport_layer': 'FTO',
#   'hole_transport_layer': '345FAn',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L-3',
#     'temperature': '65°C',
#     'time': '1,000 h',
#     'humidity': '~50% RH',
#     'control_efficiency': '24.6%',
#     'treatment_efficiency': '24.6%'},
#    {'test_name': 'ISOS-L-3',
#     'temperature': '85°C',
#     'time': '500 h',
#     'humidity': '~85% RH',
#     'control_efficiency': '25.0%',
#     'treatment_efficiency': '23.35%'},
#    {'test_name': 'ISOS-L-3',
#     'temperature': '65°C',
#     'time': '500 h',
#     'humidity': '~50% RH',
#     'control_efficiency': '23.1%',
#     'treatment_efficiency': 'N.A.'},
#    {'test_name': 'ISOS-L-3',
#     'temperature': '85°C',
#     'time': '500 h',
#     'humidity': '~65% RH',
#     'control_efficiency': 'N.A.',
#     'treatment_efficiency': '23.1%'},
#    {'test_name': 'ISOS-L-3',
#     'temperature': '85°C',
#     'time': '4000 h',
#     'humidity': '~50% RH',
#     'control_efficiency': 'N.A.',
#     'treatment_efficiency': 'N.A.'}]},
#  '6': {'treated_pce': 15.3,
#   'treated_voc': 1.06,
#   'passivating_molecule': 'phenylethylammonium',
#   'perovskite_composition': 'PEA2(CH3NH3)n-1Pb(nI3n+1)',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '90%'}]},
#  '78': {'treated_pce': 20.2,
#   'treated_voc': 1.06,
#   'passivating_molecule': 'dimethylsulfoxide (DMSO)',
#   'perovskite_composition': 'FAPbI3',
#   'pin_nip_structure': 'n-i-p',
#   'stability_tests': []},
#  '143': {'control_pce': '19.3',
#   'control_voc': '1.18',
#   'treated_pce': '18',
#   'treated_voc': '1.16',
#   'passivating_molecule': 'CuSCN',
#   'perovskite_composition': '(FAPbI3)0.77(MAPbBr3)0.14(CsPbI3)0.09',
#   'electron_transport_layer': 'CuSCN',
#   'hole_transport_layer': 'CuSCN',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '31': {'control_pce': '23.39',
#   'control_voc': '1.12',
#   'treated_pce': '25.49',
#   'treated_voc': '1.15',
#   'passivating_molecule': '3-(aminomethyl)pyridine (3-APy)',
#   'perovskite_composition': 'Rb0.05Cs0.05MA0.05FA0.85Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-LT',
#     'temperature': '55',
#     'time': '2408',
#     'control_efficiency': '24.35',
#     'treatment_efficiency': '25.49'},
#    {'test_name': 'ISOS-D',
#     'temperature': '85',
#     'time': '850',
#     'humidity': '94',
#     'control_efficiency': '22.3',
#     'treatment_efficiency': '24.6'}]},
#  '36': {'treated_pce': 20.4,
#   'treated_voc': 1.149,
#   'passivating_molecule': 'C60',
#   'perovskite_composition': 'Cs0.05(FA0.83MA0.17)0.95Pb(I0.83Br0.17)3',
#   'electron_transport_layer': 'PTAA:PFN',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '95': {'treated_pce': 22.9,
#   'treated_voc': 1.13,
#   'passivating_molecule': 'Octylammonium iodide (OAI)',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-LT',
#     'temperature': 65,
#     'time': 100,
#     'humidity': '65%',
#     'treatment_efficiency': 80},
#    {'test_name': 'ISOS-D',
#     'temperature': 65,
#     'time': 100,
#     'humidity': '65%',
#     'treatment_efficiency': 20},
#    {'test_name': 'ISOS-L', 'temperature': 65, 'time': 100, 'humidity': '65%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': 65,
#     'time': 100,
#     'humidity': '65%'}]},
#  '44': {'treated_pce': 21.12,
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '103': {'control_pce': '22.57',
#   'control_voc': '0.926',
#   'treated_pce': '22.97',
#   'treated_voc': '0.886',
#   'passivating_molecule': 'MDACl2',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'CuPC',
#   'hole_transport_layer': 'chlorobenzene',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '92': {'treated_pce': 21.7,
#   'treated_voc': 21.3,
#   'passivating_molecule': 'BaSnO3',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'BaSnO3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '10%'},
#    {'test_name': 'ISOS-L', 'humidity': '40%'}]},
#  '43': {'treated_pce': 24.5,
#   'treated_voc': 1.15,
#   'passivating_molecule': "2,2',7,7'-tetrakis(N,N-di-p-methoxyphenyl-amine)-9,9'-spirobifluorene (spiro-OMeTAD)",
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '104': {'treated_pce': 25.2,
#   'treated_voc': 1.225,
#   'passivating_molecule': 'MAPbBr3',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1I',
#     'temperature': 45,
#     'humidity': 'ambient',
#     'treatment_efficiency': 25.2}]},
#  '115': {'control_pce': '23.7%',
#   'treated_pce': '24.04%',
#   'passivating_molecule': 'Anisole',
#   'perovskite_composition': 'FA1-x-yMAxCsyPbI3-zBrz',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '52': {'control_pce': '19.1%',
#   'control_voc': '658.4 mV',
#   'treated_pce': '25%',
#   'treated_voc': '25% (estimated)',
#   'passivating_molecule': 'Dielectric oxide',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '83': {'control_pce': '21.3',
#   'treated_pce': '21.38',
#   'treated_voc': '1.12',
#   'passivating_molecule': 'MAPbI3',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '29': {'passivating_molecule': 'butylamine',
#   'electron_transport_layer': 'linear-PEI',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '112': {'control_pce': 21.8,
#   'control_voc': 1.14,
#   'treated_pce': 23.2,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Benzylhydrazine hydrochloride (BHC)',
#   'perovskite_composition': 'MA0.7FA0.3PbI3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'n-dodecylammonium iodide',
#   'pin_nip_structure': 'p-i-n',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 65},
#    {'test_name': 'ISOS-L', 'temperature': 65},
#    {'test_name': 'ISOS-T', 'temperature': 65},
#    {'test_name': 'ISOS-LC', 'temperature': 65},
#    {'test_name': 'ISOS-LT', 'temperature': 65}]},
#  '55': {'treated_pce': 11.8,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'Methylammonium (CH3NH3+)',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'Fluorine-doped tin oxide (F:SnO2)',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 263},
#    {'test_name': 'ISOS-L', 'temperature': 263},
#    {'test_name': 'ISOS-T', 'temperature': 323},
#    {'test_name': 'ISOS-LC', 'temperature': 263},
#    {'test_name': 'ISOS-LT', 'temperature': 323}]},
#  '84': {'treated_pce': 22.1,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'DM',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'DM',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 500,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'ISOS-T', 'temperature': 70, 'time': 50},
#    {'test_name': 'ISOS-LT', 'temperature': 80, 'time': 50}]},
#  '27': {'control_pce': 'null',
#   'control_voc': 'null',
#   'treated_pce': '18.5',
#   'treated_voc': '1.23',
#   'passivating_molecule': 'CF3-PEA',
#   'perovskite_composition': 'CsPbI3-xBrx',
#   'electron_transport_layer': 'NiOx',
#   'hole_transport_layer': 'SAM',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-L',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-LC',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-LT',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'}]},
#  '20': {'passivating_molecule': 'phenylethylammonium (PEA)',
#   'perovskite_composition': 'MAPbI3 (3D) and (PEA)2PbI4 (2D)',
#   'electron_transport_layer': 'poly(methyl methacrylate) (PMMA)',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'poly(methyl methacrylate) (PMMA)',
#   'stability_tests': [{'test_name': 'ISOS-LT',
#     'temperature': 60,
#     'time': 450}]},
#  '69': {'treated_pce': 20.0,
#   'passivating_molecule': 'Tetrakis(dimethylamino)tin(IV) (TDMASn)',
#   'electron_transport_layer': 'Al:ZnO',
#   'hole_transport_layer': 'PCBM',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T', 'temperature': 60},
#    {'test_name': 'ISOS-LT', 'temperature': 60}]},
#  '15': {'control_pce': '90.17',
#   'control_voc': '1.11',
#   'treated_pce': '90.17',
#   'treated_voc': '1.15',
#   'passivating_molecule': 'phenylethylammonium (PEAI) and 4-fluoro-phenylethylammonium iodide (F-PEAI)',
#   'perovskite_composition': 'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.9 Br 0.1 ) 3',
#   'electron_transport_layer': 'PC61BM',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'p-i-n',
#   'stability_tests': []},
#  '12': {'treated_pce': 19.4,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylammonium bromide (BABr)',
#   'perovskite_composition': 'Cs0.17 FA0.83 Pb(I0.6 Br0.4 ) 3',
#   'electron_transport_layer': 'nanoparticle-based SnO 2',
#   'hole_transport_layer': '2,2′,7,7′-tetrakis(N, N′-di-p-methoxy phenylamine)-9,9′-spirobifluorene (spiro-OMeTAD)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '129': {'control_pce': '22.8%',
#   'control_voc': '1.12',
#   'treated_pce': '24.8%',
#   'treated_voc': '1.19',
#   'passivating_molecule': '4-guanidinobenzoic acid hydrochloride (GBAC)',
#   'perovskite_composition': 'Cs0.06MA0.14FA0.80PbI3',
#   'electron_transport_layer': 'ITO',
#   'hole_transport_layer': 'DC-PA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': '65 ± 5 °C',
#     'time': '300 s'},
#    {'test_name': 'ISOS-T', 'temperature': '65 ± 5 °C', 'time': '300 s'},
#    {'test_name': 'ISOS-LT', 'temperature': '65 ± 5 °C', 'time': '300 s'}]},
#  '127': {'treated_pce': 24.1,
#   'treated_voc': 1.198,
#   'passivating_molecule': 'PEA2ZnX4',
#   'perovskite_composition': 'Rb5Cs10/PEA2ZnX4',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T', 'temperature': 85}]},
#  '60': {'control_pce': '19.0(±0.4)%',
#   'treated_pce': '21.4(±0.3)%',
#   'passivating_molecule': '4-vinylbenzylammonium bromide',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '120': {'control_pce': '23.0%',
#   'control_voc': '1.13',
#   'treated_pce': '25.0%',
#   'treated_voc': '1.184',
#   'passivating_molecule': 'ferrocenyl-bis-thiophene-2-carboxylate (FcTc2)',
#   'perovskite_composition': '(FA0.98MA0.02)0.95Cs0.05Pb(I0.95Br0.02)3',
#   'electron_transport_layer': 'poly(triaryl amine) (PTAA)',
#   'hole_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'damp heat test',
#     'temperature': '85',
#     'humidity': '85%'},
#    {'test_name': 'long-term operational stability',
#     'temperature': '25',
#     'humidity': 'N2-filled glovebox',
#     'control_efficiency': '72%',
#     'treatment_efficiency': '>98%'}]},
#  '67': {'treated_pce': 22.1,
#   'treated_voc': 21.3,
#   'passivating_molecule': 'formamidinium formate (FAHCOO)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'polybisphenyl(trimethylphenyl)amine (PTAA)',
#   'pin_nip_structure': 'n-i-p',
#   'stability_tests': [{'test_name': 'ISOS-L1',
#     'temperature': 60,
#     'time': 1000,
#     'control_efficiency': 21.1,
#     'treatment_efficiency': 22.1},
#    {'test_name': 'ISOS-L3',
#     'temperature': 65,
#     'time': 1000,
#     'humidity': 60,
#     'control_efficiency': 23.1,
#     'treatment_efficiency': 22.1}]},
#  '7': {'passivating_molecule': 'Methylhydrazinium', 'stability_tests': []},
#  '142': {'control_pce': '13.15',
#   'control_voc': 'null',
#   'treated_pce': '16.13',
#   'treated_voc': '1.03',
#   'passivating_molecule': 'BA (4-ethyl-3-methoxy-4-methylpyridine)',
#   'perovskite_composition': 'MAPbI3-(BA)2(MA)nÀ1Pb(nI)3n+1',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': '2D perovskite layer doped with FAI',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Humidity stability',
#     'temperature': '25°C',
#     'time': '50 days',
#     'humidity': '65%',
#     'control_efficiency': '71%',
#     'treatment_efficiency': '71%'},
#    {'test_name': 'Thermal stability',
#     'temperature': '85°C',
#     'time': '30 days',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': '74%'},
#    {'test_name': 'Illumination stability',
#     'temperature': 'null',
#     'time': '24 hours',
#     'humidity': 'null',
#     'control_efficiency': '90%',
#     'treatment_efficiency': '90%'}]},
#  '28': {'treated_pce': 22.0,
#   'treated_voc': 1.4,
#   'perovskite_composition': 'CsPbI3-xBrx',
#   'electron_transport_layer': 'TPBi',
#   'hole_transport_layer': 'Al',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []}}

# %% [markdown]
# ### Subsetting the LLama Prediction since we only have 54 true lables

# %%
# Extract the subset from json_150 where keys match with json_54
subset_llama = {key: filtered_llama_data[key] for key in label_data.keys() if key in filtered_llama_data}

# Print the result
print(len(subset_llama))
# Out:
# 54

# %% [markdown]
# ## First, we will evaluate one pair of papers and adjust specific formatting

# %%
##0th paper prediction
subset_llama
# Out:
# {'0': {'control_pce': '25.7',
#   'control_voc': '1.17',
#   'treated_pce': '26.15',
#   'treated_voc': '1.18',
#   'passivating_molecule': '4-chlorobenzenesulfonate (4Cl-BZS)',
#   'perovskite_composition': 'α-phase FAPbI3',
#   'electron_transport_layer': 'C60',
#   'hole_transport_layer': 'SAMs (self-assembled monolayers)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D-2I',
#     'temperature': 85,
#     'time': 1500,
#     'humidity': '50 ± 10%',
#     'control_efficiency': '19.9%',
#     'treatment_efficiency': '95%'},
#    {'test_name': 'ISOS-L-3',
#     'temperature': 65,
#     'time': 1200,
#     'humidity': '50 ± 10%',
#     'control_efficiency': '23.2%',
#     'treatment_efficiency': '95%'}]},
#  '1': {'control_pce': '20.95%',
#   'control_voc': '1.11',
#   'treated_pce': '23.32%',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'phenethylammonium iodide (PEAI)',
#   'perovskite_composition': 'FA1-xMAxPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'thermal cycling',
#     'temperature': '85°C',
#     'time': '500h',
#     'control_efficiency': '21.24%',
#     'treatment_efficiency': '22.73%'},
#    {'test_name': 'light-soaking',
#     'temperature': '25°C',
#     'time': '40h',
#     'control_efficiency': '21.24%',
#     'treatment_efficiency': '22.73%'}]},
#  '2': {'control_pce': '22.39%',
#   'control_voc': '1.095 V',
#   'treated_pce': '24.59%',
#   'treated_voc': '1.185 V',
#   'perovskite_composition': '(A*)2PbI4',
#   'electron_transport_layer': 'SnO2',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '85 °C',
#     'time': '1,056 h',
#     'humidity': '85% relative humidity',
#     'control_efficiency': '21.70%',
#     'treatment_efficiency': '24.35%'}]},
#  '3': {'control_pce': '24.5',
#   'control_voc': '1.20',
#   'treated_pce': '24.5',
#   'treated_voc': '1.20',
#   'passivating_molecule': 'BA2MA2Pb3I10',
#   'perovskite_composition': 'BA2MA2Pb3I10',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'humidity': '70 ± 5 %RH',
#     'control_efficiency': '21%',
#     'treatment_efficiency': '23.75%'}]},
#  '5': {'treated_pce': 22.1,
#   'treated_voc': 1135,
#   'passivating_molecule': 'iso-BAI',
#   'perovskite_composition': 'FA(MA)PbI3',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'TPBI',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '6': {'treated_pce': 15.3,
#   'treated_voc': 1.06,
#   'passivating_molecule': 'phenylethylammonium',
#   'perovskite_composition': 'PEA2(CH3NH3)n-1Pb(nI3n+1)',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '90%'}]},
#  '7': {'passivating_molecule': 'Methylhydrazinium', 'stability_tests': []},
#  '8': {'treated_pce': 23.0,
#   'treated_voc': 1.177,
#   'passivating_molecule': '2-(pyren-1-yl)ethan-1-amine',
#   'perovskite_composition': 'CsPbI2Br',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '9': {'control_pce': '14.70%',
#   'treated_pce': '17.60%',
#   'passivating_molecule': 'C8',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'PCBM',
#   'hole_transport_layer': 'Cu-doped NiOx',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '10': {'treated_pce': 24.41,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'Tosylate ([TsO] -)',
#   'perovskite_composition': '(FAPbI3) 0.95 (MAPbBr3) 0.05',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-MeOTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T', 'temperature': 40}]},
#  '11': {'treated_pce': 21.8,
#   'treated_voc': 1.16,
#   'passivating_molecule': 'Benzotriazole',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'PCBA',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': []},
#  '12': {'treated_pce': 19.4,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylammonium bromide (BABr)',
#   'perovskite_composition': 'Cs0.17 FA0.83 Pb(I0.6 Br0.4 ) 3',
#   'electron_transport_layer': 'nanoparticle-based SnO 2',
#   'hole_transport_layer': '2,2′,7,7′-tetrakis(N, N′-di-p-methoxy phenylamine)-9,9′-spirobifluorene (spiro-OMeTAD)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '13': {'treated_pce': 22.6,
#   'treated_voc': 2.1,
#   'passivating_molecule': '2-(9H-carbazol-9-yl)ethyl] phosphonic acid (2PACz)',
#   'perovskite_composition': 'Cs0.12 FA0.8 MA0.08 PbI1.8 Br1.2',
#   'electron_transport_layer': '[2-(9H-carbazol-9-yl)ethyl] phosphonic acid (2PACz)',
#   'hole_transport_layer': '[6,6]-Phenyl-C61-butyric acid methyl ester (PCBM)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 60,
#     'time': 265,
#     'control_efficiency': 13.1,
#     'treatment_efficiency': 14.6},
#    {'test_name': 'ISOS-LT',
#     'temperature': 60,
#     'time': 195,
#     'control_efficiency': 12.7,
#     'treatment_efficiency': 14.5}]},
#  '14': {'control_pce': '21.58',
#   'control_voc': '1.109',
#   'treated_pce': '23.72',
#   'treated_voc': '1.162',
#   'passivating_molecule': '2-phenylethylammonium iodide (PEAI), 4-chlorophenylethylammonium iodide (Cl-PEAI), and 4-fluorophenylethylammonium iodide (F-PEAI)',
#   'perovskite_composition': 'Cs 0.05 (FA 0.9 MA 0.1 ) 0.95 Pb(I 0.85 Br 0.15 ) 3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '15': {'control_pce': '90.17',
#   'control_voc': '1.11',
#   'treated_pce': '90.17',
#   'treated_voc': '1.15',
#   'passivating_molecule': 'phenylethylammonium (PEAI) and 4-fluoro-phenylethylammonium iodide (F-PEAI)',
#   'perovskite_composition': 'Cs 0.05 (FA 5/6 MA 1/6 ) 0.95 Pb(I 0.9 Br 0.1 ) 3',
#   'electron_transport_layer': 'PC61BM',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'p-i-n',
#   'stability_tests': []},
#  '16': {'control_pce': '18.87',
#   'control_voc': '1.04',
#   'treated_pce': '21.05',
#   'treated_voc': '1.11',
#   'passivating_molecule': 'CF3 PEAI',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L',
#     'temperature': '85',
#     'humidity': '70-80%',
#     'control_efficiency': '18.87',
#     'treatment_efficiency': '21.05'}]},
#  '17': {'control_pce': '20.04',
#   'control_voc': '1.16',
#   'treated_pce': '22.02',
#   'treated_voc': '1.19',
#   'passivating_molecule': 'hexyltrimethylammonium bromide',
#   'perovskite_composition': 'Cs0.05 FA0.81 MA0.14 PbI2.55 Br0.45',
#   'electron_transport_layer': 'doped spiro-OMeTAD',
#   'hole_transport_layer': 'doped spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '70-75%'},
#    {'test_name': 'ISOS-L', 'humidity': '70-75%'},
#    {'test_name': 'ISOS-T', 'temperature': '80 °C', 'time': '90 min'}]},
#  '18': {'treated_pce': 23.3,
#   'treated_voc': 1.23,
#   'passivating_molecule': '2-thiophenemethylammonium iodide (TMAI) and phenylethylammonium iodide (PEAI)',
#   'perovskite_composition': '[(FAPbI3)0.87(MAPbBr3)0.13]0.92(CsPbI3)0.08',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '19': {'control_pce': 'null',
#   'control_voc': 'null',
#   'treated_pce': '24.09',
#   'treated_voc': '1.1595',
#   'passivating_molecule': '3,4,5-trifluoroanilinium (345FAn)',
#   'perovskite_composition': 'Cs0.05MA0.05FA0.9Pb(I0.95Br0.05)3',
#   'electron_transport_layer': 'C60/bathocuproine (BCP)',
#   'hole_transport_layer': '2PACz',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-L-3-85°C',
#     'temperature': '85',
#     'time': '1560',
#     'humidity': '50%',
#     'control_efficiency': '19.9%',
#     'treatment_efficiency': '24.09%'}]},
#  '40': {'control_pce': '24.3',
#   'treated_pce': '24.3',
#   'treated_voc': '1.20',
#   'passivating_molecule': 'Oleylammonium iodide (OLAI)',
#   'perovskite_composition': 'Cs0.03(FA0.90MA0.10)0.97PbI3',
#   'electron_transport_layer': 'ITO',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'Damp-heat test',
#     'temperature': '85',
#     'time': '1000',
#     'humidity': '85%',
#     'treatment_efficiency': '19.3 ± 0.69%'}]},
#  '41': {'control_pce': '21.94',
#   'control_voc': '1.135',
#   'treated_pce': '23.92',
#   'treated_voc': '1.157',
#   'passivating_molecule': 'ortho-(phenylene)di(ethylammonium) iodide (o-PDEAI 2 )',
#   'perovskite_composition': 'PbI2 :PbBr2 :FAI:MAI:CsI:MACl = 0.98:0.02:0.81:0.04:0.05:0.20',
#   'electron_transport_layer': 'fluorine-doped tin oxide (FTO)',
#   'hole_transport_layer': '2,2′,7,7′-tetrakis-(N,N-di-4-methoxyphenylamino)-9,9′spirobifluorene (spiro-OMeTAD)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'long-term stability',
#     'temperature': '25 °C',
#     'time': '1000 h',
#     'humidity': '40-50% RH',
#     'control_efficiency': '85%',
#     'treatment_efficiency': '90.2%'},
#    {'test_name': 'thermal stability',
#     'temperature': '85 °C',
#     'time': '1000 h',
#     'humidity': 'air',
#     'control_efficiency': '49%',
#     'treatment_efficiency': '25%'},
#    {'test_name': 'light-soaking stability',
#     'temperature': '25 °C',
#     'time': '1100 h',
#     'humidity': 'air',
#     'control_efficiency': '>60%',
#     'treatment_efficiency': '>90%'}]},
#  '42': {'control_pce': '19.52%',
#   'control_voc': '1.07',
#   'treated_pce': '22.03%',
#   'treated_voc': '1.18',
#   'passivating_molecule': 'Azetidinium lead iodide (AzPbI3)',
#   'perovskite_composition': 'Cs0.05MA0.1FA0.85PbI2.7Br0.3',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'control_efficiency': '47%',
#     'treatment_efficiency': '85%'}]},
#  '43': {'treated_pce': 24.5,
#   'treated_voc': 1.15,
#   'passivating_molecule': "2,2',7,7'-tetrakis(N,N-di-p-methoxyphenyl-amine)-9,9'-spirobifluorene (spiro-OMeTAD)",
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '46': {'treated_pce': 20.0,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'PFN-P2 and LiF',
#   'perovskite_composition': 'CsPbI0.05[(FAPbI3)0.89(MAPbBr3)0.11]0.95',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'C60',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '47': {'control_pce': '19.16%',
#   'control_voc': '1.07 V',
#   'treated_pce': '21.1%',
#   'treated_voc': '1.16 V',
#   'passivating_molecule': 'PbSO4',
#   'perovskite_composition': 'Cs0.05FA0.81MA0.14PbI2.55Br0.45',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': 65,
#     'control_efficiency': '18.2%',
#     'treatment_efficiency': '21.1%'},
#    {'test_name': 'ISOS-LT',
#     'temperature': 65,
#     'control_efficiency': '8.54%',
#     'treatment_efficiency': '96.8%'}]},
#  '48': {'control_pce': '16.9%',
#   'control_voc': '1.07 V',
#   'treated_pce': '20.3%',
#   'treated_voc': '1.07 V',
#   'passivating_molecule': 'PCBM',
#   'perovskite_composition': 'Lead iodide (PbI2) and methylammonium iodide (MAI)',
#   'electron_transport_layer': 'PTAA: F4-TCNQ',
#   'hole_transport_layer': 'PTAA: F4-TCNQ',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': 'air'},
#    {'test_name': 'ISOS-L', 'humidity': 'air'},
#    {'test_name': 'ISOS-T', 'humidity': 'air'},
#    {'test_name': 'ISOS-LC', 'humidity': 'air'},
#    {'test_name': 'ISOS-LT', 'humidity': 'air'}]},
#  '49': {'treated_pce': 16.25,
#   'treated_voc': 1.31,
#   'passivating_molecule': 'n-butylamine acetate (BAAc)',
#   'perovskite_composition': 'BA2MAn-1PbI3n+1',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 85,
#     'time': 558,
#     'humidity': '65 ± 10%',
#     'treatment_efficiency': 95.7},
#    {'test_name': 'ISOS-L',
#     'time': 1100,
#     'humidity': '65 ± 10%',
#     'treatment_efficiency': 96.2}]},
#  '50': {'treated_pce': 14.4,
#   'treated_voc': 1.05,
#   'passivating_molecule': 'allylammonium',
#   'perovskite_composition': 'L2(MA)n-1Pb(nI3)n',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '53': {'control_pce': '4.9',
#   'treated_pce': '24.7',
#   'passivating_molecule': 'N,N-dimethyl-1,3-propane diammonium (DMePDAI2)',
#   'perovskite_composition': 'PbI6',
#   'electron_transport_layer': 'TiO2 or SnO2',
#   'pin_nip_structure': 'PIN',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'stability_tests': [{'test_name': 'ISOS-L-1',
#     'control_efficiency': '20.5',
#     'treatment_efficiency': '23.1'},
#    {'test_name': 'ISOS-LT', 'treatment_efficiency': '81'}]},
#  '55': {'treated_pce': 11.8,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'Methylammonium (CH3NH3+)',
#   'perovskite_composition': 'CH3NH3PbI3',
#   'electron_transport_layer': 'Fluorine-doped tin oxide (F:SnO2)',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'temperature': 263},
#    {'test_name': 'ISOS-L', 'temperature': 263},
#    {'test_name': 'ISOS-T', 'temperature': 323},
#    {'test_name': 'ISOS-LC', 'temperature': 263},
#    {'test_name': 'ISOS-LT', 'temperature': 323}]},
#  '56': {'treated_pce': 21.1,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'LiTFSI',
#   'perovskite_composition': 'FA0.83Cs0.17Pb0.5Sn0.5I3',
#   'electron_transport_layer': 'PEDOT:PSS',
#   'hole_transport_layer': 'C60 and BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '57': {'treated_pce': 22.5,
#   'treated_voc': 1.098,
#   'perovskite_composition': 'MA 0.07 FA 0.93 PbI 3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'C 60',
#   'pin_nip_structure': 'pin',
#   'stability_tests': []},
#  '58': {'passivating_molecule': 'PCBM, C60, spiro-OMeTAD, poly-TPD, NiO x, PTAA',
#   'perovskite_composition': 'FA 0.83 Cs 0.17 Pb(I 0.83 Br 0.1 ) 3, FA 0.75 Cs 0.25 Pb(I 0.8 Br 0.2 ) 3',
#   'electron_transport_layer': 'SnO2, NiO x, Poly-TPD, PCBM, C60',
#   'hole_transport_layer': 'PCBM, C60, spiro-OMeTAD, poly-TPD, PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '59': {'control_pce': '19.07%',
#   'control_voc': '1.25',
#   'treated_pce': '19.07%',
#   'treated_voc': '1.25',
#   'passivating_molecule': 'phenethylammonium iodide (PEAI)',
#   'perovskite_composition': 'FA0.8Cs0.2Pb(I0.7Br0.3)3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'BCP',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '79': {'treated_pce': 20.27,
#   'treated_voc': 1.1,
#   'passivating_molecule': 'PbI2',
#   'perovskite_composition': '(FAPbI3)0.97(MAPbBr3)0.03',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'n-i-p',
#   'stability_tests': []},
#  '80': {'control_pce': 21.6,
#   'control_voc': 1.14,
#   'treated_pce': 21.6,
#   'treated_voc': 1.14,
#   'passivating_molecule': 'Poly(methyl methacrylate) (PMMA)',
#   'perovskite_composition': '[FAI]0.81[PbI2]0.85[MAPbBr3]0.15',
#   'electron_transport_layer': 'Spiro-OMeTAD',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '81': {'control_pce': '20.1',
#   'control_voc': '1.140',
#   'treated_pce': '19.9',
#   'treated_voc': '1.145',
#   'passivating_molecule': 'Chlorine',
#   'perovskite_composition': 'MAPbI3-xClx',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '82': {'control_pce': '17.1',
#   'control_voc': '1.04',
#   'treated_pce': '20.59',
#   'treated_voc': '1.13',
#   'passivating_molecule': 'Choline chloride',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'PTAA',
#   'hole_transport_layer': 'PTAA',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '50-85%'}]},
#  '83': {'control_pce': '21.3',
#   'treated_pce': '21.38',
#   'treated_voc': '1.12',
#   'passivating_molecule': 'MAPbI3',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'TiO2',
#   'hole_transport_layer': 'spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '84': {'treated_pce': 22.1,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'DM',
#   'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05',
#   'electron_transport_layer': 'spiro-OMeTAD',
#   'hole_transport_layer': 'DM',
#   'pin_nip_structure': 'NIP',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 60,
#     'time': 500,
#     'treatment_efficiency': 22.3},
#    {'test_name': 'ISOS-T', 'temperature': 70, 'time': 50},
#    {'test_name': 'ISOS-LT', 'temperature': 80, 'time': 50}]},
#  '85': {'control_pce': '16.0',
#   'treated_pce': '23.3',
#   'passivating_molecule': 'n-hexyl trimethyl ammonium bromide',
#   'perovskite_composition': 'FAPbI3 0.95MAPbBr3 0.05',
#   'electron_transport_layer': 'P3HT',
#   'hole_transport_layer': 'P3HT',
#   'pin_nip_structure': 'DHA',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '85%'}]},
#  '86': {'treated_pce': 21.6,
#   'treated_voc': 1.11,
#   'passivating_molecule': 'Ethylene diamine tetraacetic acid (EDTA)',
#   'electron_transport_layer': 'EDTA-complexed SnO2 (E-SnO2)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '87': {'treated_pce': 21.52,
#   'treated_voc': 1.15,
#   'passivating_molecule': 'Eu 3+ -Eu 2+ ion pair',
#   'perovskite_composition': 'PbX2 layer (CsI 20 mg, PbI2 530 mg, PbBr2 20 mg, PbCl2 20 mg, MAI 5 mg dissolved in 900 μL DMF and 100 μL DMSO mixed solvent)',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'polymer modified spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': '1 sun illumination',
#     'time': 1000,
#     'control_efficiency': 19.21,
#     'treatment_efficiency': 21.52},
#    {'test_name': '85°C heating',
#     'temperature': 85,
#     'time': 1000,
#     'control_efficiency': 18.05,
#     'treatment_efficiency': 21.52},
#    {'test_name': '1 sun illumination',
#     'time': 500,
#     'control_efficiency': 19.21,
#     'treatment_efficiency': 21.52},
#    {'test_name': '85°C heating',
#     'temperature': 85,
#     'time': 500,
#     'control_efficiency': 18.05,
#     'treatment_efficiency': 21.52}]},
#  '88': {'control_pce': '19.03',
#   'treated_pce': '21.46',
#   'treated_voc': '0.94',
#   'passivating_molecule': 'NaF',
#   'perovskite_composition': '(Cs 0.05 FA 0.54 MA 0.41 )Pb(I 0.98 Br 0.02 ) 3',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-T',
#     'temperature': '85 °C',
#     'time': '1,000 h',
#     'control_efficiency': '19.03',
#     'treatment_efficiency': '21.46'}]},
#  '89': {'treated_pce': 20.87,
#   'treated_voc': 1.147,
#   'passivating_molecule': 'Formamidine acetate',
#   'perovskite_composition': '(FA,MA,Cs)Pb(I,Br)3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '90': {'treated_pce': 20.7,
#   'treated_voc': 1.17,
#   'perovskite_composition': '(FAPbI3)0.85(MAPbBr3)0.15',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '91': {'control_pce': 'null',
#   'control_voc': 'null',
#   'treated_pce': '24.02',
#   'treated_voc': '1.130',
#   'passivating_molecule': 'Methylammonium chloride (MACl)',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'null',
#   'hole_transport_layer': 'null',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': '90%'},
#    {'test_name': 'ISOS-L',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-T',
#     'temperature': '40 C',
#     'time': '300 h',
#     'humidity': 'null',
#     'control_efficiency': '60%',
#     'treatment_efficiency': '90%'},
#    {'test_name': 'ISOS-LC',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'},
#    {'test_name': 'ISOS-LT',
#     'temperature': 'null',
#     'time': 'null',
#     'humidity': 'null',
#     'control_efficiency': 'null',
#     'treatment_efficiency': 'null'}]},
#  '92': {'treated_pce': 21.7,
#   'treated_voc': 21.3,
#   'passivating_molecule': 'BaSnO3',
#   'perovskite_composition': 'MAPbI3',
#   'electron_transport_layer': 'BaSnO3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D', 'humidity': '10%'},
#    {'test_name': 'ISOS-L', 'humidity': '40%'}]},
#  '93': {'treated_pce': 21.21,
#   'treated_voc': 1.23,
#   'passivating_molecule': 'spiro-OMeTAD',
#   'perovskite_composition': 'FA 1-x MA x PbI 2.87 Br 0.13 (Cl)',
#   'electron_transport_layer': 'SnO 2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '114': {'treated_pce': 23.37,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'Piperazinium iodide (PI)',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '115': {'control_pce': '23.7%',
#   'treated_pce': '24.04%',
#   'passivating_molecule': 'Anisole',
#   'perovskite_composition': 'FA1-x-yMAxCsyPbI3-zBrz',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '116': {'control_pce': '23.44',
#   'control_voc': '1.152',
#   'treated_pce': '24.82',
#   'treated_voc': '1.164',
#   'passivating_molecule': 'Spiro-mF',
#   'perovskite_composition': 'FAPbI3',
#   'electron_transport_layer': 'compact TiO2',
#   'hole_transport_layer': 'Spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []},
#  '117': {'control_pce': 0.22,
#   'control_voc': 1.15,
#   'treated_pce': 25.1,
#   'treated_voc': 1.17,
#   'passivating_molecule': 'spiro-OMeTAD 2•+ (TFSI -)2',
#   'perovskite_composition': '(FAPbI3)0.99(MAPbBr3)0.01',
#   'electron_transport_layer': 'SnO2',
#   'hole_transport_layer': 'doped spiro-OMeTAD',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': [{'test_name': 'ISOS-D',
#     'temperature': 25,
#     'time': 1200,
#     'humidity': '70 ± 5%',
#     'control_efficiency': 0.22,
#     'treatment_efficiency': 25.1},
#    {'test_name': 'ISOS-L',
#     'temperature': 25,
#     'time': 800,
#     'humidity': '70 ± 3°C',
#     'control_efficiency': 0.22,
#     'treatment_efficiency': 25.1}]},
#  '149': {'treated_pce': 26.4,
#   'treated_voc': 2.03,
#   'passivating_molecule': '4-trifluoromethyl-phenylammonium (CF3-PA)',
#   'perovskite_composition': 'FA 0.7 MA 0.3 Pb 0.5 Sn 0.5 I 3',
#   'pin_nip_structure': 'PIN',
#   'stability_tests': []}}

# %%
#The actual label
clean_label_data['0']
# Out:
# {'ISOSL3': {'control_pce': '24',
#   'efficiency_tret': '95%',
#   'time': '1200',
#   'treated_pce': '26.9',
#   'treated_voc': '1.18'},
#  'structure_pin_nip': 'PIN',
#  'passivating_molecule': '4Cl-BZS',
#  'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3',
#  'hole_transport_layer': '2PACz and Me-4PACz',
#  'electron_transport_layer': 'C60'}

# %% [markdown]
# #### Evaluation in parts
# - numerical data
# - text data (molecule)
# - stability
#     - Change how to parse xml
#     - Change the output of the model as ID but no specification on number

# %%
## We need precision and recall for EACH variable
## For each variable, calculate the F1 score - There is F1 score for each variable
## Take a weighted average ***For now, just take the average.

# %% [markdown]
# Variables (number)
# - control_pce
# - treatment_pce
# - control_voc
# - treatment_voc
#
# Variable (text)
# - structure_pin_nip
# - passivating_molecule
# - perovskite_composition
# - hole_transport_layer
# - electron_transport_layer
#
# Stability (later)

# %%
def check_float(value):
    for char in value:
        if (char == ".") | (char.isdigit()):
            continue
        else:
            return False
    return True

# %%
def numerical_comparison(id, label_annotation, extraction_annotation, numerical_tolerance = 0.1):
    ##We are given an id to make numerical annotation
    #The argument is id, and 2 json annotation from label and extraction

    if id not in extraction_annotation:
        # print(f"FN_{id}")
        return f"FN"
    else:
        label_data = label_annotation[id]
        ##This code is because of imperfect annotation on teamtat, Delete this once annotation is perfect
        #When label_data highlights the unit
        if check_float(label_data):
            label_data = float(label_data)
        else:
            label_data = float(label_data[:-1].strip())

        extract_data = str(extraction_annotation[id])
        if check_float(extract_data):
            extract_data = float(extract_data)
        else:
            extract_data = float(extract_data[:-1].strip())

        if abs(label_data - extract_data) <= numerical_tolerance * abs(label_data):
            # print(f"TP_{id}")
            return f"TP"
        else:
            # print(f"FP_{id}")
            return f"FP"

# %%
def text_comparison(id, label_annotation, extraction_annotation, text_similarity_threshold = 0.8):

    if id == "structure_pin_nip":
        if "pin_nip_structure" not in extraction_annotation:
            return f"FN"
        else:
            label_data = label_annotation[id]
            extract_data = extraction_annotation["pin_nip_structure"]

            similarity = SequenceMatcher(None, label_data.lower(), extract_data.lower()).ratio()
            if similarity > text_similarity_threshold:  # Threshold for similarity
                # print(f"TP_{id}")
                return f"TP"
            else:
                # print(f"FP_{id}")
                return f"FP"
    else:
        if id not in extraction_annotation:
            # print(f"FN_{id}")
            return f"FN"
        else:
            label_data = label_annotation[id]
            extract_data = extraction_annotation[id]

            similarity = SequenceMatcher(None, label_data.lower(), extract_data.lower()).ratio()
            if similarity > text_similarity_threshold:  # Threshold for similarity
                # print(f"TP_{id}")
                return f"TP"
            else:
                # print(f"FP_{id}")
                return f"FP"

# %%
def stability_comparison(id, label_annotation, extraction_annotation):
    ## Return FN if id is not in extraction_annotation
    if len(extraction_annotation['stability_tests']) == 0:
        return f"FN"
    for dictionary in extraction_annotation['stability_tests']:
        test_name = dictionary['test_name']
        if id[4] == test_name[-1]:
            return f"TP"
    return f"FN"

# %%
def compare_json(labeled_data, extracted_data):
    ## List of variable for TP, FP, FN
    '''Just as summary
    TP: Corrected value extracted by LLM
    FN: LLM didn't extract this variable
    FP: LLM DID extract the value, but it was wrong value
    '''
    numerical_variable = ["control_pce", "treated_pce", "control_voc", "treated_voc"]
    #First numerical comparison!!
    numerical_dict = {
    "control_pce" : {"TP": 0, "FP":0, "FN":0},
    "treated_pce" : {"TP": 0, "FP":0, "FN":0},
    "control_voc" : {"TP": 0, "FP":0, "FN":0},
    "treated_voc" : {"TP": 0, "FP":0, "FN":0}}


    text_variable = ["structure_pin_nip", "passivating_molecule", "perovskite_composition", "electron_transport_layer", "hole_transport_layer"]
    text_dict = {
    "structure_pin_nip" : {"TP": 0, "FP":0, "FN":0},
    "passivating_molecule" : {"TP": 0, "FP":0, "FN":0},
    "perovskite_composition" : {"TP": 0, "FP":0, "FN":0},
    "electron_transport_layer" : {"TP": 0, "FP":0, "FN":0},
    "hole_transport_layer" : {"TP": 0, "FP":0, "FN":0}}

    stability_dict = {
    "ISOS-D" : {"TP": 0, "FP":0, "FN":0},
    "ISOS-L" : {"TP": 0, "FP":0, "FN":0},
    "ISOS-T" : {"TP": 0, "FP":0, "FN":0}}
    # "ISOS-LC" : {"TP": 0, "FP":0, "FN":0},
    # "ISOS-LT" : {"TP": 0, "FP":0, "FN":0}}

    for key, label_value in labeled_data.items():
        if key in extracted_data:
            ##Make sure that there is extracted data associated with the anotation
            extracted_value = extracted_data[key]
            for id in label_value.keys():
                # print(id)
                ##Check if id is the numerical value
                if id in numerical_variable:
                    # print(id, label_value[id])
                    ##This is handling incorrect annotation, annotation that is not just numbers
                        # Came accross id of treated_voc: methylammonium sulfate
                        # Came accross control_pce ['4.9%', '20.5']
                    if type(label_value[id]) != str:
                        # print("value not string")
                        continue
                    if not label_value[id].replace(".", '').isdigit():
                        # print("value including units")
                        continue
                    ##Perform numerical comparison
                    result = numerical_comparison(id, label_value, extracted_value)
                    
                    # print(result)
                    numerical_dict[id][result] += 1

                # ##Check if id is text value
                elif id in text_variable:
                    if type(label_value[id]) != str:
                        # print("value not string", label_value[id])
                        continue

                    result = text_comparison(id, label_value, extracted_value)
                    # print(result)
                    text_dict[id][result] += 1

                #SUBJECT TO CHANGE AFTER Q1 
                ##Check if id is stability
                if "ISOS" in id:
                    result = stability_comparison(id, label_value, extracted_value)
                    if id[4] == "D":
                        stability_dict["ISOS-D"][result] += 1
                    elif id[4] == "L":
                        stability_dict["ISOS-L"][result] += 1
                    if id[4] == "T":
                        stability_dict["ISOS-T"][result] += 1

                    
                    
        else:
            print(f"Extraction were not performed. Paper num: {key}")

    # print("Numerical comparison dictionary",numerical_dict)
    # print("Text comparison dictionary",text_dict)

    combined_dict = numerical_dict.copy()
    combined_dict.update(text_dict)
    combined_dict.update(stability_dict)
    print("Performance for each variable in dictionary",combined_dict)
    
    # Perform recall, precision, f1 score computation
    variable_list = []
    precision_list = []
    recall_list = []
    f1_list = []
    for variable, performance in combined_dict.items():
        precision = performance["TP"] / (performance["TP"] + performance["FP"])
        recall = performance["TP"] / (performance["TP"] + performance["FN"])
        f1 = (2 * precision * recall) / (precision + recall)
        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)
        variable_list.append(variable)

    return variable_list, precision_list, recall_list, f1_list

# %%
variables, precisions, recalls, f1s = compare_json(clean_label_data, subset_llama)
# Out:
# Performance for each variable in dictionary {'control_pce': {'TP': 3, 'FP': 2, 'FN': 1}, 'treated_pce': {'TP': 8, 'FP': 1, 'FN': 0}, 'control_voc': {'TP': 5, 'FP': 0, 'FN': 3}, 'treated_voc': {'TP': 10, 'FP': 1, 'FN': 1}, 'structure_pin_nip': {'TP': 7, 'FP': 17, 'FN': 1}, 'passivating_molecule': {'TP': 6, 'FP': 13, 'FN': 1}, 'perovskite_composition': {'TP': 17, 'FP': 16, 'FN': 2}, 'electron_transport_layer': {'TP': 6, 'FP': 16, 'FN': 5}, 'hole_transport_layer': {'TP': 18, 'FP': 14, 'FN': 7}, 'ISOS-D': {'TP': 5, 'FP': 0, 'FN': 14}, 'ISOS-L': {'TP': 2, 'FP': 0, 'FN': 22}, 'ISOS-T': {'TP': 4, 'FP': 0, 'FN': 0}}

# %% [markdown]
# ## Calculate Macro f1 score

# %%
def macro_f1(f1_list, weight = None):
    if weight == None:
        #If no weight given, do unweighted average of f1 score
        return sum(f1_list) / len(f1_list)
    total_f1 = 0
    for i in range(len(f1_list)):
        total_f1 += (f1_list[i] * weight[i])
    return total_f1 / sum(weight)

# %%
## The macro f1 score unweighted
macro_f1(f1s)
# Out:
# 0.6170647968732333

# %% [markdown]
# ### This concludes the pipeline of evaluating extraction quality

# %% [markdown]
# # Todo:
# - stability evaluation
#     - Need to reiterate on the teamtat annotation
#
# - Putting weights on F1 Score
# - Using Bert!!

# %% [markdown]
# ## Stability annotation brainstorm
#
# - We will have as at most 5 realation (if there is an overlap, choose the stability test that offers more info)
#     - Exp there is ISOS L1 and ISOS L2. If there is more iformation in IsosL2, use that as a test and compare on ISOSL that llama extracted (if any)
# - We will iterate through different test recorded on annotation and compared it with suitable stability extracted on Llama
